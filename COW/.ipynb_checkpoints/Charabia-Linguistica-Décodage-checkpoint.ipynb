# %% [markdown]
# # Décodage du charabia avec linguistica
# Produire trois version du texte avec :
# - la phrase d'origine
# - la phrase découpée
# - la glose pour chaque morphème
#
# À terme produire un document LaTeX avec en plus une ligne pour noter la traduction

# %%
import linguistica as lxa
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import re,tabulate
from itertools import combinations
lxa.__version__  # show version number
# Out:
# '5.2.1'

# %% [markdown]
# ## Lire le corpus

# %%
charabia="Aveugle"
repName="/Users/gilles/ownCloud/Cours/Bordeaux/M2-TraitementsCorpus/"
fName="Corpus%s-Sentenced.txt"%charabia
# lxaCorpus = lxa.read_corpus(repName+fName)

# %%
texteBrut=pd.read_csv(repName+fName,encoding="utf8",header=None,sep="\t").values.tolist()
texteBrut=[t[0] for t in texteBrut]
compW=re.compile(u"(\W)+",re.U)
texteBrut=[re.sub(compW," ",l) for l in texteBrut]
lxaCorpus = lxa.from_corpus(texteBrut)

# %%
# %store -r conteLines

lineConte={}
nContes=[]
nConte=""
nDebutConte=0
for nLine,line in enumerate(texteBrut):
    m=re.search(u"(\d+)",line)
    if m:
        nConte=m.group(1)
        nContes.append(nConte)
    lineConte[nLine]=nConte
lineConte

# %%
#  tradContes=set(nContes).intersection(set(conteLines))

# %% [markdown]
# ## Basic information

# %%
print "mots-occurrences",lxaCorpus.number_of_word_tokens()
print "mots-types",lxaCorpus.number_of_word_types()
# Out:
# mots-occurrences 207170
# mots-types 8748

# %% [markdown]
# ## Séquences fréquentes
# Liste des séquences de mots au dessus du *seuil* de fréquence pour :
# - les mots seuls
# - les bigrammes
# - les trigrammes

# %%
def spreadListe(liste,cols):
    result=[]
    if isinstance(liste[0][0],tuple):
        locListe=[" ".join(seq)+" : "+unicode(nb) for seq,nb in liste]
    else:
        locListe=[seq+" : "+unicode(nb) for seq,nb in liste]
#     print locListe
    pos=[None for c in range(cols)]
    for n,l in enumerate(locListe):
        i=n%cols
        pos[i]=l
        if i+1==cols:
            result.append(pos)
            pos=[None for c in range(cols)]
    print (tabulate.tabulate(result))
    return

# %%
seuilUnigram=1000
dUnigram=lxaCorpus.word_unigram_counter()
pUnigram=sorted(dUnigram.items(), key=lambda kv: (kv[1], kv[0]), reverse=True)
print "mots de fréquence supérieure à %d"%seuilUnigram
freqUnigrams=[]
for w,f in pUnigram:
    if f>seuilUnigram:
#         print w,f
        freqUnigrams.append((w,f))
    else:
        break
spreadListe(freqUnigrams,6)
# Out:
# mots de fréquence supérieure à 1000
# ----------  ------------  ----------  ------------  -----------  ----------
# ed : 10309  ñax : 5022    o : 4130    zix : 4077    zih : 4058   ah : 3812
# ix : 3566   hoy : 3447    wta : 3118  tid : 2741    ossi : 2649  raq : 2616
# zi : 2592   ñux : 2575    vta : 2566  wadzi : 2409  ziq : 2340   za : 2215
# ap : 2054   cix : 1955    zu : 1935   ciz : 1838    wod : 1770   iq : 1757
# peq : 1604  ñarzi : 1473  ñac : 1440  sec : 1395    xu : 1376    ih : 1331
# ----------  ------------  ----------  ------------  -----------  ----------

# %%
seuilBigram=200
dBigram=lxaCorpus.word_bigram_counter()
pBigram=sorted(dBigram.items(), key=lambda kv: (kv[1], kv[0]), reverse=True)
print "séquences de deux mots de fréquence supérieure à %d"%seuilBigram
freqBigram=[]
for w,f in pBigram:
    if f>seuilBigram:
#         print " ".join(w),f
        freqBigram.append((w,f))
    else:
        break
spreadListe(freqBigram,4)
# Out:
# séquences de deux mots de fréquence supérieure à 200
# ---------------  --------------  ---------------  ---------------
# hoy ah : 531     ed wadzi : 516  za ñax : 494     ed za : 470
# peq ah : 458     zih iq : 435    zih raq : 401    wadzi ñax : 398
# ziq raq : 393    ah ñax : 368    oxz o : 358      zix dacyi : 299
# ñax ñarzi : 291  o ix : 258      tid ñaq : 254    ed wta : 253
# za zi : 252      ap whiz : 243   za ñux : 233     ed dos : 227
# ed zi : 223      ñix hoy : 222   wadzi zix : 217  ev ed : 216
# ---------------  --------------  ---------------  ---------------

# %%
seuilTrigram=50
dTrigram=lxaCorpus.word_trigram_counter()
pTrigram=sorted(dTrigram.items(), key=lambda kv: (kv[1], kv[0]), reverse=True)
print "séquences de trois mots de fréquence supérieure à %d"%seuilTrigram
freqTrigram=[]
for w,f in pTrigram:
    if f>seuilTrigram:
#         print " ".join(w),f
        freqTrigram.append((w,f))
    else:
        break
spreadListe(freqTrigram,4)
# Out:
# séquences de trois mots de fréquence supérieure à 50
# ------------------  --------------------  -----------------  --------------------
# ed za ñax : 151     ziq raq ixdaxd : 119  za ñax sec : 109   raq ixdaxd ix : 107
# wod hoy ah : 94     riz wozix ap : 89     ed za ñux : 84     ah zih raq : 79
# uz o wserix : 71    za ñax ñarzi : 68     yer hoy ah : 66    o ix paqh : 65
# ed za zi : 62       za zi ñarzi : 59      o wserix ed : 58   ah ñax wsuyyi : 58
# ed wahhi wod : 56   ed wadzi hoy : 56     za ñax wta : 55    ykwh hoy ah : 55
# wadzi ñax hoy : 55  za zi sec : 54        za ñax raq : 53    wadzi zix dacyi : 53
# ed hoy wozwh : 53   cix za ñax : 53       tid wsay xes : 51  ed wadzi ah : 51
# ------------------  --------------------  -----------------  --------------------

# %% [markdown]
# # Découpage

# %%
dictBrokenWords=lxaCorpus.broken_words_left_to_right()
dictGlossWords={k:"-".join(v) for k,v in dictBrokenWords.iteritems()}
dictHyphenWords={k:"-".join(v) for k,v in dictBrokenWords.iteritems()}

# %%
dictFoundGloss={
    "zesheq":"docteur[nom1]",
    "zeshiq":"docteur[nom2]",
    "zesheq-ix":"docteur-DEF",
    "tet-i":"œil",
    "ñocy-ix":"ciel-DEF",
    "taxz-ix":"esprit-DEF",
    "wyaxd-i":"serpent",
    "pyaws-ix":"bouteille-DEF",
    "ayrozixzi":"universel[adj]",
    "jexz-ix":"paysan-DEF",
    "jexz-i":"paysan",
    "vixd-i":"seigneur?",
    "vixd-ixi":"seigneur?",
    "wtexx-iq":"fils",
    "jqtezq-i":"frère",
    "sex-i":"femme",
    "sex-ix":"femme-DEF",
    "pudy":"oiseau",
    "pudy-ix":"oiseau-DEF",
    "sexd-i":"roi",
    "piqzoxaxz":"Fernand",
    "ñrozi":"blanc",
    "syed":"sage",
    "syed-i":"sage",
    "syed-h":"sage",
    "syed-ix":"sage",
    "yoyyi":"petit",
    "uxziqyod":"merveilleux",
    "uxziqyod-i":"merveilleux",
    "uxziqyod-h":"merveilleux",
    "roz-uxziqyod":"merveilleux",
    "roz-uxziqyod-i":"merveilleux",
    "wvuqdhi":"demander?",
    "ñreq":"être[PRS?]",
    "ñric":"être[PST?]",
    "ñraz":"être[?]",
    "ñax":"PRO.3SG",
    "ñaxw":"POSS.3SG",
    "zix":"DEF[SG.x]",
    "zih":"DEF[SG.y]",
    "ed":"ET",
    "ix":"1-INDEF",
    "ih":"INDEF",
    "he":"2",
    "hqi":"3",
    "wkr":"7",
    "zi":"DEF[PL]",
    "o":"DANS",
    }

# %%
for k,v in dictFoundGloss.iteritems():
    dictGlossWords[k]=k+"@"+v

# %%
texteHyphen=[]
texteGloss=[]
for nLineOrig,lineOrig in enumerate(texteBrut):
    lineHyphen=[]
    lineGloss=[]
    print nLineOrig+1
    for word in lineOrig.split(" "):
        if word:
            lineHyphen.append(dictHyphenWords[word])
            lineGloss.append(dictGlossWords[word])
    texteHyphen.append(" ".join(lineHyphen))
    texteGloss.append(" ".join(lineGloss))
    print texteHyphen[-1]
    print
    if texteHyphen[-1]!=texteGloss[-1]:
        print texteGloss[-1]
    print
# Out:
# 1
# 098 zesheq ayrozixzi
#
# 098 zesheq@docteur[nom1] ayrozixzi@universel[adj]
#
# 2
# ziq raq ixdaxd ix pahhod jexzi wec ñiz sqijw
#
# ziq raq ixdaxd ix@1-INDEF pahhod jexzi wec ñiz sqijw
#
# 3
# ñax steqhi ciz he eswiq ih ytiw jqtixzi oxz hoy jkix ed weydhi zih hoy ix zeshiq
#
# ñax steqhi ciz he@2 eswiq ih@INDEF ytiw jqtixzi oxz hoy jkix ed@ET weydhi zih@DEF[SG.y] hoy ix@1-INDEF zeshiq@docteur[nom2]
#
# 4
# zesheqix waz xihev hoy jeqzw za ñax hayhi vixdixi ev ed za jexzix wta ñreq zityodh ñax wvowhi ed zqas pos ñax ykwh hoy edwta ah rtiqi zesheq
#
# zesheqix@docteur[nom-aut] waz xihev hoy jeqzw za ñax hayhi vixdixi ev ed@ET za jexzix@paysan[nom] wta ñreq zityodh ñax wvowhi ed@ET zqas pos ñax ykwh hoy edwta ah rtiqi zesheq@docteur[nom1]
#
# 5
# ñax jyir whtaixzi ziq o xedix hoz ed wvuqdhi ixziyod ec ñax ossi suxxi ytiqi ah jyori zesheq
#
# ñax jyir whtaixzi ziq o@DANS xedix hoz ed@ET wvuqdhi@demander? ixziyod ec ñax ossi suxxi ytiqi ah jyori zesheq@docteur[nom1]
#
# 6
# zih iq wtactixz xich xes wraqizi zesheqix
#
# zih@DEF[SG.y] iq wtactixz xich xes wraqizi zesheqix@docteur[nom-aut]
#
# 7
# ñraz wsay tid za dteqi
#
#
# 8
# wvuqdhi jexzix
#
# wvuqdhi@demander? jexzix@paysan[nom]
#
# 9
# peq zih pteqwhi wsay zu steji zod ix ajl ñreqo ziq iq ix dtaqz-ñaxi peq zih axzih wsay zu wtiydi zox redx ed zoxi eswiq wta zu ptaq vixdi hoy ah steji zod sytiziq ed ñraz ziq iyyiqw ñteqiq ciz hoy ytidi-suxwhix peq zih hqizoi wsay zu vta ih wsoyh yazi cayi ñiq jeq zesheq ayrozixzi ed wtihhi zih ev eriq zox zteq
#
# peq zih@DEF[SG.y] pteqwhi wsay zu steji zod ix@1-INDEF ajl ñreqo ziq iq ix@1-INDEF dtaqz-ñaxi peq zih@DEF[SG.y] axzih wsay zu wtiydi zox redx ed@ET zoxi eswiq wta zu ptaq vixdi hoy ah steji zod sytiziq ed@ET ñraz ziq iyyiqw ñteqiq ciz hoy ytidi-suxwhix peq zih@DEF[SG.y] hqizoi wsay zu vta ih@INDEF wsoyh yazi cayi ñiq jeq zesheq@docteur[nom1] ayrozixzi@universel[adj] ed@ET wtihhi zih@DEF[SG.y] ev eriq zox zteq
#
# 10
# jexzix dteqzi zih ayhwaccix
#
# jexzix@paysan[nom] dteqzi zih@DEF[SG.y] ayhwaccix
#
# 11
# za ñax ñarzi rtiqih zesheq o xedix hoz jyir ziq whttayih xedyi vixdi pqa ix peqxic ñiqqi
#
# za ñax ñarzi rtiqih zesheq@docteur[nom1] o@DANS xedix hoz jyir ziq whttayih xedyi vixdi pqa ix@1-INDEF peqxic ñiqqi
#
# 12
# ñax pos ah ñteqi ah ziq ziq o yaxz-wjkix jeizi ix caxz wec ñiz zesheq ayrozixzi ed ayhwta ctahhi rozi ñreq vixdixi raq
#
# ñax pos ah ñteqi ah ziq ziq o@DANS yaxz-wjkix jeizi ix@1-INDEF caxz wec ñiz zesheq@docteur[nom1] ayrozixzi@universel[adj] ed@ET ayhwta ctahhi rozi ñreq vixdixi raq
#
# 13
# ñax yez wta wvtixz-i peq steqhi ñix hoy jexzix ed wvuqdhi ec ñax raq zesheq ayrozixzi
#
# ñax yez wta wvtixz-i peq steqhi ñix hoy jexzix@paysan[nom] ed@ET wvuqdhi@demander? ec ñax raq zesheq@docteur[nom1] ayrozixzi@universel[adj]
#
# 14
# te zih raq ñax za
#
# te zih@DEF[SG.y] raq ñax za
#
# 15
# wta wsuyyi ñax dta ciz ed wsappi zi whttayxi vixdi odix
#
# wta wsuyyi ñax dta ciz ed@ET wsappi zi@DEF[PL] whttayxi vixdi odix
#
# 16
# jexzix royyi edwta ñari wox sexi dqihi ciz ed zi whid wta ayyi hqi ev o redxix ed steqhi ap whiz
#
# jexzix@paysan[nom] royyi edwta ñari wox sexi dqihi ciz ed@ET zi@DEF[PL] whid wta ayyi hqi@3 ev o@DANS redxix ed@ET steqhi ap whiz
#
# 17
# za zi sec hoy wyehhih whez jeqzih ztissih ed ñax wsuyyi pteqwh wvowi
#
# za zi@DEF[PL] sec hoy wyehhih whez jeqzih ztissih ed@ET ñax wsuyyi pteqwh wvowi
#
# 18
# dqihi wsay edwta wvowi ciz
#
#
# 19
# wadzi ñax ed wahhi wod hoy jeqzw ciz ñixzi
#
# wadzi ñax ed@ET wahhi wod hoy jeqzw ciz ñixzi
#
# 20
# za zix pteqwhi htixiq sec ciz zix dezi caz dar jexzix wox sexi ih vup ed wadzi zih iq zix pteqwhi
#
# za zix@DEF[SG.x] pteqwhi htixiq sec ciz zix@DEF[SG.x] dezi caz dar jexzix@paysan[nom] wox sexi ih@INDEF vup ed@ET wadzi zih@DEF[SG.y] iq zix@DEF[SG.x] pteqwhi
#
# 21
# ñax cixhi ah zih raq zix pteqwhi wec sec ciz cazix cix htixiqix hqeizi ah ñax cixhi zih raq zix pteqwhi hkr ed za ñax roqsiyod ñarzi whttayih jyir ñax jaxdi ed wadzi hoy woxi sacciqahiq zix zesheq riz ayhoxd
#
# ñax cixhi ah zih@DEF[SG.y] raq zix@DEF[SG.x] pteqwhi wec sec ciz cazix cix htixiqix hqeizi ah ñax cixhi zih@DEF[SG.y] raq zix@DEF[SG.x] pteqwhi hkr ed@ET za ñax roqsiyod ñarzi whttayih jyir ñax jaxdi ed@ET wadzi hoy woxi sacciqahiq zix@DEF[SG.x] zesheq@docteur[nom1] riz ayhoxd
#
# 22
# zih dtaq dayh
#
# zih@DEF[SG.y] dtaq dayh
#
# 23
# ñax wadzi ah tid raq zix pteqwhi
#
# ñax wadzi ah tid raq zix@DEF[SG.x] pteqwhi
#
# 24
# zix axzix htixiq royyi wyih ossi dta oxz cix ñax ctahhi zed hoy zih
#
# zix@DEF[SG.x] axzix htixiq royyi wyih ossi dta oxz cix ñax ctahhi zed hoy zih@DEF[SG.y]
#
# 25
# za ñax sec ciz pazih vuppizi jexzix hoy wox sexi ed wadzi zih iq zix axzix
#
# za ñax sec ciz pazih vuppizi jexzix@paysan[nom] hoy wox sexi ed@ET wadzi zih@DEF[SG.y] iq zix@DEF[SG.x] axzix
#
# 26
# ñax jyir yodiw-ta jaxdi ed sec uz o ix paqh
#
# ñax jyir yodiw-ta jaxdi ed@ET sec uz o@DANS ix@1-INDEF paqh
#
# 27
# zix hqizoi dos zih ossi ix wcuyi jizqi
#
# zix@DEF[SG.x] hqizoi dos zih@DEF[SG.y] ossi ix@1-INDEF wcuyi jizqi
#
# 28
# jexzix wadzi zih iq zix hqizoi dqihi
#
# jexzix@paysan[nom] wadzi zih@DEF[SG.y] iq zix@DEF[SG.x] hqizoi dqihi
#
# 29
# xu sec ziq ix ptiqzi htixiq ciz ih hoyztissih paz ed ñiqqix wadzi hoy zesheqix ah xu wsuyyi ñax dori ix vqteri vta wox suxwh ed wodi ñraz ziq raq o pazih
#
# xu sec ziq ix@1-INDEF ptiqzi htixiq ciz ih@INDEF hoyztissih paz ed@ET ñiqqix wadzi hoy zesheqix@docteur[nom-aut] ah xu wsuyyi ñax dori ix@1-INDEF vqteri vta wox suxwh ed@ET wodi ñraz ziq raq o@DANS pazih
#
# 30
# zih raq ocozyiqhoz sqijw
#
# zih@DEF[SG.y] raq ocozyiqhoz sqijw
#
# 31
# jexzix wta vta pazih ed rozwhi ossi woxi yirixzi qtaz
#
# jexzix@paysan[nom] wta vta pazih ed@ET rozwhi ossi woxi yirixzi qtaz
#
# 32
# ta tid whassiyw sqijw wadzi ñax
#
#
# 33
# za ñiqqix ñteqhi zih qtajhi ñax wi ñax riz zih
#
# za ñiqqix ñteqhi zih@DEF[SG.y] qtajhi ñax wi ñax riz zih@DEF[SG.y]
#
# 34
# wta riz ñax edwta ñreq vixdixi iq
#
#
# 35
# htixiqxi raq ocozyiqhoz peqptiqziyod axdwh ed dteqzi hidx hoy zesheqix ah ñax wsuyyi secci uz hoy zic
#
# htixiqxi raq ocozyiqhoz peqptiqziyod axdwh ed@ET dteqzi hidx hoy zesheqix@docteur[nom-aut] ah ñax wsuyyi secci uz hoy zic
#
# 36
# za ñax sec hoywh-ez zi ah zi ñarzi hadih vixdixi
#
# za ñax sec hoywh-ez zi@DEF[PL] ah zi@DEF[PL] ñarzi hadih vixdixi
#
# 37
# zi royyi diqxi dori ñac zic ed caxdi pyiqi ñrow ñax royyi yeri ossi ah peqqtaz-i zic peq wta raq zi ec ix ñayw
#
# zi@DEF[PL] royyi diqxi dori ñac zic ed@ET caxdi pyiqi ñrow ñax royyi yeri ossi ah peqqtaz-i zic peq wta raq zi@DEF[PL] ec ix@1-INDEF ñayw
#
# 38
# zi pteqhi ñac wta ziqñix ñreq zi ñarzi wstuyh vixdixi ed ziqciz raq ñax peqxtetih
#
# zi@DEF[PL] pteqhi ñac wta ziqñix ñreq zi@DEF[PL] ñarzi wstuyh vixdixi ed@ET ziqciz raq ñax peqxtetih
#
# 39
# ñax dos odix oxz wahhi wod hoy jeqzw ed wadzi xu wsay tid wi iphiq o cox jed ñreq vixdixi iq
#
# ñax dos odix oxz wahhi wod hoy jeqzw ed@ET wadzi xu wsay tid wi iphiq o@DANS cox jed ñreq vixdixi iq
#
# 40
# zix pichi htixiq sqtej oxz o erxix peq ah ñteqi ec zesheqix rozwhi ciqi ixzxu
#
# zix@DEF[SG.x] pichi htixiq sqtej oxz o@DANS erxix peq ah ñteqi ec zesheqix@docteur[nom-aut] rozwhi ciqi ixzxu
#
# 41
# jexzix waz ed jyazizi o wox ajljed ed yizhi iphiq ñaxix
#
# jexzix@paysan[nom] waz ed@ET jyazizi o@DANS wox ajljed ed@ET yizhi iphiq ñaxix
#
# 42
# za ñax ossi whqasw suxxi poxzi zix wadzi ñax zu iq te zed ñiqoxzi wta zu wsay xes secci uz
#
# za ñax ossi whqasw suxxi poxzi zix@DEF[SG.x] wadzi ñax zu iq te zed ñiqoxzi wta zu wsay xes secci uz
#
# 43
# htixiqix o erxix hqeizi ah zih raq ñac wvqaxd peqwsqtissih uz ed qtajhi zix caxz riz ayhoxd
#
# htixiqix o@DANS erxix hqeizi ah zih@DEF[SG.y] raq ñac wvqaxd peqwsqtissih uz ed@ET qtajhi zix@DEF[SG.x] caxz riz ayhoxd
#
# 44
# zesheq ayrozixzi rowhi xu ñiqqix ñreq vixdixi yta cix wadzi ossi ñric ziq ñarzi whttayih zic
#
# zesheq@docteur[nom1] ayrozixzi@universel[adj] rowhi xu ñiqqix ñreq vixdixi yta cix wadzi ossi ñric ziq ñarzi whttayih zic
#
# 45
# ñax pos wheqi jiyt-exx-oxdiq jtazi ap ñac ed htixiqxi ed jyir ix jiqtech caxz
#
# ñax pos wheqi jiyt-exx-oxdiq jtazi ap ñac ed@ET htixiqxi ed@ET jyir ix@1-INDEF jiqtech caxz
#
# 46
# 099 taxzix o pyawsix
#
# 099 taxzix o@DANS pyawsix
#
# 47
# ziq raq ixdaxd ix pahhod jqtixzi-ñuddiq wec aqjitzizi pqa zix ykwi ceqdix hoy yaxdh uz vta aphixix
#
# ziq raq ixdaxd ix@1-INDEF pahhod jqtixzi-ñuddiq wec aqjitzizi pqa zix@DEF[SG.x] ykwi ceqdix hoy yaxdh uz vta aphixix
#
# 48
# za ñax yaxdh ec ytixdi ñarzi ptaih wvaqih xedyi vixdi waccix wadzi ñax hoy wox wtex zu iq coh ixiwhi jaqx
#
#
# 49
# zi vixdi tid ñaq htixh o coh axwodhw wriz wsay jqud-iw hoy zox evzqadi-ywi
#
# zi@DEF[PL] vixdi tid ñaq htixh o@DANS coh axwodhw wriz wsay jqud-iw hoy zox evzqadi-ywi
#
# 50
# ytiq xedih eqzixhyodh wta zu sax iqxtiqi cod xtaq tid iq jyirih dacciy ed whor ed cta wozzi ñticci ed ossi ciqi sax dta vta aqjitzi
#
# ytiq xedih eqzixhyodh wta zu sax iqxtiqi cod xtaq tid iq jyirih dacciy ed@ET whor ed@ET cta wozzi ñticci ed@ET ossi ciqi sax dta vta aqjitzi
#
# 51
# zqixdix sec wta o wseyi ed raq pyohhod ed ñaxw ytiqiq qewhi ñac
#
# zqixdix sec wta o@DANS wseyi ed@ET raq pyohhod ed@ET ñaxw ytiqiq qewhi ñac
#
# 52
# za ñax ñarzi dtaih ih vaq wsey-i-q odixxic cix ayyodiriy ossi raq ñiyh uzytiqh ixzxu raq ñaxw paqw wcuyi vixdi wyuvvih ev ed ñax ctahhi rixzi ñtic
#
# za ñax ñarzi dtaih ih@INDEF vaq wsey-i-q odixxic cix ayyodiriy ossi raq ñiyh uzytiqh ixzxu raq ñaxw paqw wcuyi vixdi wyuvvih ev ed@ET ñax ctahhi rixzi ñtic
#
# 53
# tid sax ossi dori zod xedih wadzi paziqix jizqterih ed o zowwi zkqi hoziq sax tid ossi peqh-tixi ix teqi ciqi ixz ñraz ro jqudiq hoy zih zadyodi jqtez
#
# tid sax ossi dori zod xedih wadzi paziqix jizqterih ed@ET o@DANS zowwi zkqi hoziq sax tid ossi peqh-tixi ix@1-INDEF teqi ciqi ixz ñraz ro jqudiq hoy zih@DEF[SG.y] zadyodi jqtez
#
# 54
# zu wsay ossi wteqdi eriq zih yoyyi paq wadzi wtexxix tid wsay xes poxzi cod o zih
#
# zu wsay ossi wteqdi eriq zih@DEF[SG.y] yoyyi@petit paq wadzi wtexxix tid wsay xes poxzi cod o@DANS zih@DEF[SG.y]
#
# 55
# xtaq zih iq duzw royti iq zih riy edwta zih jizwhi
#
# xtaq zih@DEF[SG.y] iq duzw royti iq zih@DEF[SG.y] riy edwta zih@DEF[SG.y] jizwhi
#
# 56
# za paziqix royyi dta uz o wserix peq ah htixi xedih riz ah ñuddi jqtixzi ed whajyi zih ev wadzi wtexxix tid dtaq ciz ed ñttiyviq zod
#
# za paziqix royyi dta uz o@DANS wserix peq ah htixi xedih riz ah ñuddi jqtixzi ed@ET whajyi zih@DEF[SG.y] ev wadzi wtexxix tid dtaq ciz ed@ET ñttiyviq zod
#
# 57
# zih jyoriq ayh peq wrtiqh peq zod wadzi paziqix zu iq ossi raxh hoy zih ñtaqzi aqjitzi zu sax ossi ñeyzi zih uz
#
# zih@DEF[SG.y] jyoriq ayh peq wrtiqh peq zod wadzi paziqix zu iq ossi raxh hoy zih@DEF[SG.y] ñtaqzi aqjitzi zu sax ossi ñeyzi zih@DEF[SG.y] uz
#
# 58
# ed peq qiwhix ñaq tid oxdix teswi ed ñiyyiq oxdix vixdi hoy ah steji ix peq
#
# ed@ET peq qiwhix ñaq tid oxdix teswi ed@ET ñiyyiq oxdix vixdi hoy ah steji ix@1-INDEF peq
#
# 59
# dta sux ñix hoy reqiw xaje wadzi wtexxix ñax ytax-iq zod xes ix teswi hoy tid wiyr ñaq htixh cod ix
#
# dta sux ñix hoy reqiw xaje wadzi wtexxix ñax ytax-iq zod xes ix@1-INDEF teswi hoy tid wiyr ñaq htixh cod ix@1-INDEF
#
# 60
# paziqix ytaxhi wta ix teswi ñew xajeix ed riz zaddqk dos zi waccix uz o wserix
#
# paziqix ytaxhi wta ix@1-INDEF teswi ñew xajeix ed@ET riz zaddqk dos zi@DEF[PL] waccix uz o@DANS wserix
#
# 61
# wtexxix ñtayv paziqix ed raq dyaz ed peqxtetih
#
# wtexxix ñtayv paziqix ed@ET raq dyaz ed@ET peqxtetih
#
# 62
# za weyix whez cozh vta ñocyix wadzi paziqix yaz ew xu ñeyzi cozzad ed ñroyi ew yozh
#
# za weyix whez cozh vta ñocyix wadzi paziqix yaz ew xu ñeyzi cozzad ed@ET ñroyi ew yozh
#
# 63
# wta dtaq zih zejjiyh wta dezh jadiphiq
#
# wta dtaq zih@DEF[SG.y] zejjiyh wta dezh jadiphiq
#
# 64
# wtexxix hed woh jqtez ed wadzi ñroy zu zod sux paq
#
# wtexxix hed woh jqtez ed@ET wadzi ñroy zu zod sux paq
#
# 65
# tid iq ossi hqtih tid dtaq yozh quxzh o wserix ed wtediq iphiq pudyiqiziq
#
# tid iq ossi hqtih tid dtaq yozh quxzh o@DANS wserix ed@ET wtediq iphiq pudyiqiziq
#
# 66
# zox xaq wadzi paziqix ñreqpeq roy zu xu qixzi ecsqoxd
#
#
# 67
# zu jyoriq te jaqi wta hqtih ah zu ossi sax qteqi aqcixi
#
#
# 68
# jyor ñiyyiqi qeyod ñiq
#
#
# 69
# cix wtexxix dos oxz o wserix ed soddizi ev o zi dqtexxi dqixi peq ah wi iphiq pudyiqiziq
#
# cix wtexxix dos oxz o@DANS wserix ed@ET soddizi ev o@DANS zi@DEF[PL] dqtexxi dqixi peq ah wi iphiq pudyiqiziq
#
# 70
# ñax dos pqic ed hoyjadi hoy ñax hoy wozwh sec hoy ix rtiyzod wheq id wec wossiqh raq caxdi ñuxzqizi taq dacciy ed wta hks ah ossi pic cixxiwsiq suxxi wvtixz-i ec zix
#
# ñax dos pqic ed@ET hoyjadi hoy ñax hoy wozwh sec hoy ix@1-INDEF rtiyzod wheq id wec wossiqh raq caxdi ñuxzqizi taq dacciy ed@ET wta hks ah ossi pic cixxiwsiq suxxi wvtixz-i ec zix@DEF[SG.x]
#
# 71
# ñax whaxzwizi wta vta zix ed htixshi ziq cta zed caxdi pudyi ñari jkddih qizi
#
# ñax whaxzwizi wta vta zix@DEF[SG.x] ed@ET htixshi ziq cta zed caxdi pudyi ñari jkddih qizi
#
# 72
# vyuzwiyod wkxhiw ñax ah ñax ñteqhi ix whicci ed za ñax ykhhizi iphiq ñteqhi ñax ah xedix jaqws qtajhi yaz cod secci uz yaz cod secci uz
#
# vyuzwiyod wkxhiw ñax ah ñax ñteqhi ix@1-INDEF whicci ed@ET za ñax ykhhizi iphiq ñteqhi ñax ah xedix jaqws qtajhi yaz cod secci uz yaz cod secci uz
#
# 73
# ñax wta wod ec cix suxxi ossi evzadi xedih ed zih peqisec ñac wec ec whiccix sec xizi pqa teqzix
#
# ñax wta wod ec cix suxxi ossi evzadi xedih ed@ET zih@DEF[SG.y] peqisec ñac wec ec whiccix sec xizi pqa teqzix
#
# 74
# ñreq iq zu
#
#
# 75
# wvuqdhi ñax
#
# wvuqdhi@demander? ñax
#
# 76
# tid wozziq ñiq uxziq idi qtezziqxi wraqizi whiccix yaz cod secci uz yaz cod secci uz
#
#
# 77
# zix uxdi caxz jidkxzhi ah qezi uxziq hqtiih jyaxzh qtezziqxi ed hoy wozwh evzadizi ñax o ix ñuyxoxd ix yoyyi dyawpyawsi
#
# zix@DEF[SG.x] uxdi caxz jidkxzhi ah qezi uxziq hqtiih jyaxzh qtezziqxi ed@ET hoy wozwh evzadizi ñax o@DANS ix@1-INDEF ñuyxoxd ix@1-INDEF yoyyi@petit dyawpyawsi
#
# 78
# ñax ytephizi zix ev ed ñeyzh zix ocez ykwih ed wta za xedih wec yodxizi ix pqte wvqoxdi pqic ed hoyjadi ziqoxzi
#
# ñax ytephizi zix@DEF[SG.x] ev ed@ET ñeyzh zix@DEF[SG.x] ocez ykwih ed@ET wta za xedih wec yodxizi ix@1-INDEF pqte wvqoxdi pqic ed@ET hoyjadi ziqoxzi
#
# 79
# yaz cod secci uz yaz cod secci uz qtajhi whiccix odix
#
#
# 80
# ñax hed vqevvix ap ed whqasw whid ziq ix taxz ev ed reswizi ed reswizi ed jyir iphiq ih teti-jyos-w peqytej peqptiqziyod wheq ñayr wta wheq wec zih dacyi idihqti
#
# ñax hed vqevvix ap ed@ET whqasw whid ziq ix@1-INDEF taxz ev ed@ET reswizi ed@ET reswizi ed@ET jyir iphiq ih@INDEF teti-jyos-w peqytej peqptiqziyod wheq ñayr wta wheq wec zih@DEF[SG.y] dacyi idihqti
#
# 81
# riz zu ñraz zu ptaq hoy ytex peqzo zu ñaq yazih cod secci uz
#
#
# 82
# qtajhi taxzix ciz wox wsqtis-siyod-i whicci
#
#
# 83
# ñreqzax wsuyyi tid zed rozi zih wadzi caxzix ossi ix wcuyi jaxdi
#
# ñreqzax wsuyyi tid zed rozi zih@DEF[SG.y] wadzi caxzix ossi ix@1-INDEF wcuyi jaxdi
#
# 84
# wta wsay tid wodi zod zih qtajhi taxzix tid rqoziq ñaywix ec vta zod
#
# wta wsay tid wodi zod zih@DEF[SG.y] qtajhi taxzix tid rqoziq ñaywix ec vta zod
#
# 85
# zih wsuyyi zu ñari wadh cod xedih pteq wadzi caxzix wta ñarzi tid yazih zod jyori ziqoxzi
#
# zih@DEF[SG.y] wsuyyi zu ñari wadh cod xedih pteq wadzi caxzix wta ñarzi tid yazih zod jyori ziqoxzi
#
# 86
# cix cez zod wsay tid xes whta cod ziq iq riy axzqi peys ziq ñaq ih eqz ciz ah wodi
#
# cix cez zod wsay tid xes whta cod ziq iq riy axzqi peys ziq ñaq ih@INDEF eqz ciz ah wodi
#
# 87
# jytiwi ciz axzqi peys
#
#
# 88
# qtajhi taxzix zu wsay ñari zox peqhtixhi ytex
#
#
# 89
# hqeq zu zih raq peq cox peqxtetiy-wiw wskyz ah tid ñaq wozzih ziq wta ytixdi xit zih raq cox whqap
#
# hqeq zu zih@DEF[SG.y] raq peq cox peqxtetiy-wiw wskyz ah tid ñaq wozzih ziq wta ytixdi xit zih@DEF[SG.y] raq cox whqap
#
# 90
# tid iq zix wheqi ciqsuq ed zix ziq wyovviq cod uz zqitiq tid ñaywix ec vta
#
# tid iq zix@DEF[SG.x] wheqi ciqsuq ed@ET zix@DEF[SG.x] ziq wyovviq cod uz zqitiq tid ñaywix ec vta
#
# 91
# wta wadhi wta wadhi wadzi caxzix wta ñuqhodh dtaq zih ñiyyiq ossi
#
# wta wadhi wta wadhi wadzi caxzix wta ñuqhodh dtaq zih@DEF[SG.y] ñiyyiq ossi
#
# 92
# tid cta za pteqwh rozi ec zu iq zix qodhodi taxz
#
# tid cta za pteqwh rozi ec zu iq zix@DEF[SG.x] qodhodi taxz
#
# 93
# ñrow zu sax secci oxz o pyawsix odix roy tid hqe zih ed wta sax zu dteqi ciz cod ñraz zu roy
#
# ñrow zu sax secci oxz o@DANS pyawsix odix roy tid hqe zih@DEF[SG.y] ed@ET wta sax zu dteqi ciz cod ñraz zu roy
#
# 94
# zih iq cox coxzwhi suxwh wadzi taxzix eriqy-idixh wraxzh oxz ed jyir daxwsi yoyyi ed hkxz wta zix odix suxxi wyovvi oxz dixxic pyawsiñaywix
#
# zih@DEF[SG.y] iq cox coxzwhi suxwh wadzi taxzix eriqy-idixh wraxzh oxz ed@ET jyir daxwsi yoyyi@petit ed@ET hkxz wta zix@DEF[SG.x] odix suxxi wyovvi oxz dixxic pyawsiñaywix
#
# 95
# cix yodiw-ec zix raq ziqoxzi wahhi caxzix vqevvix vta yadzi pyawsix xiz odix ciyyic idi qtezziqxi ed wtazax jyir taxzix xaqqih
#
# cix yodiw-ec zix@DEF[SG.x] raq ziqoxzi wahhi caxzix vqevvix vta yadzi pyawsix xiz odix ciyyic idi qtezziqxi ed@ET wtazax jyir taxzix xaqqih
#
# 96
# ñax royyi xu dta hoyjadi hoy wox paq cix taxzix qtajhi kxsiyodh yaz cod secci uz yaz cod secci uz
#
#
# 97
# xit wraqizi ñax zih dteq tid ossi ix daxd hoy
#
# xit wraqizi ñax zih@DEF[SG.y] dteq tid ossi ix@1-INDEF daxd hoy
#
# 98
# hqeq zu tid wyovviq zix ytew ziq roy wyta cod oñtiy xtaq tid ixziyod ñaq ptaih pah vta ñac odix
#
# hqeq zu tid wyovviq zix@DEF[SG.x] ytew ziq roy wyta cod oñtiy xtaq tid ixziyod ñaq ptaih pah vta ñac odix
#
# 99
# ñrow zu wyovviq cod ytew roy tid dori zod wta cidih ah zu ñaq xes peq ñiyi zoh yor
#
#
# 100
# xit has zu xaqqiq cod sux odix
#
#
# 101
# zu peqwstiqhwiq zox ykssi wadzi taxzix tid roy roqsiyod ossi dteqi zod xedih cix dori zod ix jiytexxoxd
#
# zu peqwstiqhwiq zox ykssi wadzi taxzix tid roy roqsiyod ossi dteqi zod xedih cix dori zod ix@1-INDEF jiytexxoxd
#
# 102
# tid hqeq tid roy reri zih htixshi ñax ctawsi ñeyziq zix eqz ed zix wsay ossi pta yer hoy ah dteqi cod xedih
#
# tid hqeq tid roy reri zih@DEF[SG.y] htixshi ñax ctawsi ñeyziq zix@DEF[SG.x] eqz ed@ET zix@DEF[SG.x] wsay ossi pta yer hoy ah dteqi cod xedih
#
# 103
# ñax hed wta vqevvix ap ed taxzix whid ev odix whqashi ed qashi wod ed jyir hoy ix wheq sticvi
#
# ñax hed wta vqevvix ap ed@ET taxzix whid ev odix whqashi ed@ET qashi wod ed@ET jyir hoy ix@1-INDEF wheq sticvi
#
# 104
# xu wsay zu pta zox ytex wadzi zix ed qashi ñac ix yoyyi yav ziq yodxizi ih whkssi vyawhiq ed wadzi xtaq zu ciz zix ixi ixzi jiwhq-kdiq ih wtaq ñiyi-w zih ed jiwhq-kdiq zu whtay ed tiqx ciz zix axzix ixzi jyoriq zih hoy wteyr
#
# xu wsay zu pta zox ytex wadzi zix@DEF[SG.x] ed@ET qashi ñac ix@1-INDEF yoyyi@petit yav ziq yodxizi ih@INDEF whkssi vyawhiq ed@ET wadzi xtaq zu ciz zix@DEF[SG.x] ixi ixzi jiwhq-kdiq ih@INDEF wtaq ñiyi-w zih@DEF[SG.y] ed@ET jiwhq-kdiq zu whtay ed@ET tiqx ciz zix@DEF[SG.x] axzix ixzi jyoriq zih@DEF[SG.y] hoy wteyr
#
# 105
# zih cta tid zed pteqwh vqteri wadzi caxzix
#
# zih@DEF[SG.y] cta tid zed pteqwh vqteri wadzi caxzix
#
# 106
# ñax dos ñix hoy ih hqti wsaq o jaqs-ix ciz wox teswi ed whqted vyaw-hqih ñix eriq zih ed whqasw reswizi jaqs-ix waccix odix
#
# ñax dos ñix hoy ih@INDEF hqti wsaq o@DANS jaqs-ix ciz wox teswi ed@ET whqted vyaw-hqih ñix eriq zih@DEF[SG.y] ed@ET whqasw reswizi jaqs-ix waccix odix
#
# 107
# ta zih iq te qodhod xes wadzi ñax hoy taxzix xu sax ro wsoy-yiw odix
#
# ta zih@DEF[SG.y] iq te qodhod xes wadzi ñax hoy taxzix xu sax ro wsoy-yiw odix
#
# 108
# taxzix hassizi ñac peq wox pqiywi ed ñax hassizi zix peq dari-x ed dos hoyjadi hoy wox paq
#
# taxzix hassizi ñac peq wox pqiywi ed@ET ñax hassizi zix@DEF[SG.x] peq dari-x ed@ET dos hoyjadi hoy wox paq
#
# 109
# ñreq ñaq zu rtiqih ñixxi wadzi paziqix zu dyic-ciq te ñiyh ah jiwhoyyi xedih
#
#
# 110
# cix tid wadzi te xes whqasw ah zu jyir ossi hoy xedih
#
#
# 111
# rtiq jaqi qeyod paq tid wsay xes oxzñixhi zih peqwt-ec-hi
#
# rtiq jaqi qeyod paq tid wsay xes oxzñixhi zih@DEF[SG.y] peqwt-ec-hi
#
# 112
# oxzñixhi zih wadzi paziqix rqizh
#
# oxzñixhi zih@DEF[SG.y] wadzi paziqix rqizh
#
# 113
# zih iq ix wsozh caxiq
#
# zih@DEF[SG.y] iq ix@1-INDEF wsozh caxiq
#
# 114
# wi xu jaqi xu wsay tid ñuddi zih hqti ec wta zih wsay sxadi ed jqadi
#
# wi xu jaqi xu wsay tid ñuddi zih@DEF[SG.y] hqti ec wta zih@DEF[SG.y] wsay sxadi ed@ET jqadi
#
# 115
# ziqvta hed ñax woh vyawhiq whqted zih eriq teswix ed dteqzi ih rtiyzodh ñud cix za tiqx-ih raq jyirih peqraxzyih hoy wteyr yadzi tiddi-x wod
#
# ziqvta hed ñax woh vyawhiq whqted zih@DEF[SG.y] eriq teswix ed@ET dteqzi ih@INDEF rtiyzodh ñud cix za tiqx-ih raq jyirih peqraxzyih hoy wteyr yadzi tiddi-x wod
#
# 116
# wossix ix ztaqyod teswi zu ñaq dorih cod paq zix iq jyirih ñiyh wstir
#
# wossix ix@1-INDEF ztaqyod teswi zu ñaq dorih cod paq zix@DEF[SG.x] iq jyirih ñiyh wstir
#
# 117
# ñraz ñaq zu dteqh wadzi paziqix peqwsqtissih xu cta tid jihayi teswix ed ñreq wsay tid hadi vixdixi pqa
#
# ñraz ñaq zu dteqh wadzi paziqix peqwsqtissih xu cta tid jihayi teswix ed@ET ñreq wsay tid hadi vixdixi pqa
#
# 118
# zih iq zix darx tid ñaq ap zoh aqjitzi
#
# zih@DEF[SG.y] iq zix@DEF[SG.x] darx tid ñaq ap zoh aqjitzi
#
# 119
# zu cta ossi rtiqi rqiz paq wadzi wtexxix tid wsay xes jihayi teswix
#
#
# 120
# ñraz roy zu jihayi ciz zox zucqoax wadzi paziqix zu ñaq te ossi axzih ixz ñraz tid doriq zod
#
#
# 121
# zih iq zi whuz-i-qixkssiq ziq wozziq zod o ñerizih
#
# zih@DEF[SG.y] iq zi@DEF[PL] whuz-i-qixkssiq ziq wozziq zod o@DANS ñerizih
#
# 122
# cix vta ah ñuddi jqtixzi ñaq zu qodhodxes oxdix peqw-haxz
#
#
# 123
# yozh iphiq wadzi wtexxix yaz ew xu ñeyzi pkqaphix paq
#
#
# 124
# tid sax ayyodiriy ossi jiwhoyyi ciqi
#
#
# 125
# wta zu hqeq tid roy ytiddi ñtixz-iqxi o wste-zih yodiw-ec zu wadzi caxzix
#
# wta zu hqeq tid roy ytiddi ñtixz-iqxi o@DANS wste-zih yodiw-ec zu wadzi caxzix
#
# 126
# tid cta aqjitzi cidih ciqi dta zu jaqi ñtic ayixi
#
#
# 127
# tacix tid sax ossi poxzi rit o wserix paq zih iq te pteqwhi daxd tiq iq ñiq
#
# tacix tid sax ossi poxzi rit o@DANS wserix paq zih@DEF[SG.y] iq te pteqwhi daxd tiq iq ñiq
#
# 128
# sec xu
#
#
# 129
# ed za paziqixw rqizi ñarzi yadh wod yez ñax wod eriqhayi ed dos ciz
#
# ed@ET za paziqixw rqizi ñarzi yadh wod yez ñax wod eriqhayi ed@ET dos ciz
#
# 130
# dta wta ñix ed wtiyd zix teziyadh-i teswi wadzi ñax hoy wtexxix ed wi ñreq cidih zu sax pta peq zix
#
# dta wta ñix ed@ET wtiyd zix@DEF[SG.x] teziyadh-i teswi wadzi ñax hoy wtexxix ed@ET wi ñreq cidih zu sax pta peq zix@DEF[SG.x]
#
# 131
# qiwhix cta tid wi ah peqh-tixi peq ah tid sax jihayi xajeix
#
#
# 132
# wtexxix dos oxz hoy jkix hoy ix duyzwciz ziq wta vta teswix ritizi zix ed wadzi zix iq woxi poqi ñuxzqizi zayiq rtiqz cix wta cidih ñaq tid ossi o qizi vixdi
#
# wtexxix dos oxz hoy jkix hoy ix@1-INDEF duyzwciz ziq wta vta teswix ritizi zix@DEF[SG.x] ed@ET wadzi zix@DEF[SG.x] iq woxi poqi ñuxzqizi zayiq rtiqz cix wta cidih ñaq tid ossi o@DANS qizi vixdi
#
# 133
# dor cod ñraz o ñaq wadzi zix uxdi caxz wta sax o wskyzi cod qiwhix
#
# dor cod ñraz o@DANS ñaq wadzi zix@DEF[SG.x] uxdi caxz wta sax o@DANS wskyzi cod qiwhix
#
# 134
# duyz-wcizix dar ñac xu hqi ñuxzqizi zayiq ed jyir ñac ñuxzqizi wsky-zod
#
# duyz-wcizix dar ñac xu hqi@3 ñuxzqizi zayiq ed@ET jyir ñac ñuxzqizi wsky-zod
#
# 135
# xu ñaq tid vixdi paq wadzi wtexxix za ñax raq seccih ñtic dta wta ñix ed wvteqd xajeix ñraz ñax roy ñari peq teswix
#
# xu ñaq tid vixdi paq wadzi wtexxix za ñax raq seccih ñtic dta wta ñix ed@ET wvteqd xajeix ñraz ñax roy ñari peq teswix
#
# 136
# zih riz tid dezh wadzi paziqix ñax roy ñari ix zayiq ed wisw wsoyyoxd
#
# zih@DEF[SG.y] riz tid dezh wadzi paziqix ñax roy ñari ix@1-INDEF zayiq ed@ET wisw wsoyyoxd
#
# 137
# dor ñac wta he zayiq ed heyr wsoyyoxd zih iq yodi zih zejjiyhi
#
# dor ñac wta he@2 zayiq ed@ET heyr wsoyyoxd zih@DEF[SG.y] iq yodi zih@DEF[SG.y] zejjiyhi
#
# 138
# sax zu wi tid ñaq vixdi xes
#
#
# 139
# ziqvta dar ñax wox paq ñuxzqizi zayiq
#
#
# 140
# zu wsay ayzqod caxdyi xedih wta ytixdi zu yiriq wadzi ñax
#
#
# 141
# ñreqpqa secciq zed ayyi zi vixdi
#
# ñreqpqa secciq zed ayyi zi@DEF[PL] vixdi
#
# 142
# wvuqdhi zix dacyi peqjarwih
#
# wvuqdhi@demander? zix@DEF[SG.x] dacyi peqjarwih
#
# 143
# wtexxix peqhayhi ñac xu ñreqzax ñax ñarzi ñaph ykssix ciz wod
#
#
# 144
# qiwhix ap vixdixi jqud-h-i ñax hoy ah ytiwi roziqi peq o wsey-i-x ed za ñax ciz woh vyawhiq suxxi ñiyjqizi ayyi wtaq jyir ñax zix jiqte-chiwhi ytidi o riqzix
#
# qiwhix ap vixdixi jqud-h-i ñax hoy ah ytiwi roziqi peq o@DANS wsey-i-x ed@ET za ñax ciz woh vyawhiq suxxi ñiyjqizi ayyi wtaq jyir ñax zix@DEF[SG.x] jiqte-chiwhi ytidi o@DANS riqzix
#
# 145
# 126 piqzoxaxz hqe ed piqzoxaxz uhqe
#
# 126 piqzoxaxz@Fernand hqe ed@ET piqzoxaxz@Fernand uhqe
#
# 146
# ziq raq ixdaxd ix caxz ed ix sexi
#
# ziq raq ixdaxd ix@1-INDEF caxz ed@ET ix@1-INDEF sexi
#
# 147
# wta ytixdi zi raq qodi ñarzi zi oxdix jteqx cix za zi raq jyirih pahhodi pos zi ix yoyyi zqixd
#
# wta ytixdi zi@DEF[PL] raq qodi ñarzi zi@DEF[PL] oxdix jteqx cix za zi@DEF[PL] raq jyirih pahhodi pos zi@DEF[PL] ix@1-INDEF yoyyi@petit zqixd
#
# 148
# zi suxxi ossi ñohhi vta ñric ziq wsuyyi whta pazziq hoy ñac ed caxzix jiwhichi za ah ñax royyi dta uz ed wi ah poxzi ix
#
# zi@DEF[PL] suxxi ossi ñohhi vta ñric ziq wsuyyi whta pazziq hoy ñac ed@ET caxzix jiwhichi za ah ñax royyi dta uz ed@ET wi ah poxzi ix@1-INDEF
#
# 149
# vta ritix ctezhi ñax ix pahhod caxz ziq wvuqdhi ñreq ñax wsuyyi ñix
#
# vta ritix ctezhi ñax ix@1-INDEF pahhod caxz ziq wvuqdhi@demander? ñreq ñax wsuyyi ñix
#
# 150
# ñax peqhayhi xu ah ñax raq uzi peq ah yizi iphiq ix ziq royyi whta pazziq hoy ñaxw wtex cix ñax raq wta pahhod ah ñax ossi suxxi pta xedix hoy zih
#
# ñax peqhayhi xu ah ñax raq uzi peq ah yizi iphiq ix@1-INDEF ziq royyi whta pazziq hoy ñaxw wtex cix ñax raq wta pahhod ah ñax ossi suxxi pta xedix hoy zih@DEF[SG.y]
#
# 151
# zih vawwiq dezh wadzi caxzix tid iq edwta pahhod
#
# zih@DEF[SG.y] vawwiq dezh wadzi caxzix tid iq edwta pahhod
#
# 152
# tid roy diqxi whta pazziq hoy jaqxih cix xedix dari sax tid ossi dori
#
#
# 153
# dta ñtic ed wod hoy teqziceziqix ah ñux wsay secci ñix o soqsix ciz jaqxih
#
# dta ñtic ed@ET wod hoy teqziceziqix ah ñux wsay secci ñix o@DANS soqsix ciz jaqxih
#
# 154
# za zi sec ziqñix raq hoddiqix ziq ayyiqizi ed jaqxih jyir ztejh ed pos xarxih piqzoxaxz hqe
#
# za zi@DEF[PL] sec ziqñix raq hoddiqix ziq ayyiqizi ed@ET jaqxih jyir ztejh ed@ET pos xarxih piqzoxaxz@Fernand hqe
#
# 155
# za zi sec uz wadzi hoddiqix xu dtaq tid ñtic
#
# za zi@DEF[PL] sec uz wadzi hoddiqix xu dtaq tid ñtic
#
# 156
# tid sax ossi dori tiq xedih ed o wsay ñiyyiq ossi dori cod xedih
#
# tid sax ossi dori tiq xedih ed@ET o@DANS wsay ñiyyiq ossi dori cod xedih
#
# 157
# ziqvta dar ñax teqziceziqix ix xtedyi ed wadzi ah ñux wsuyyi dori paziqix zix xtaq ñux sec ñtic
#
# ziqvta dar ñax teqziceziqix ix@1-INDEF xtedyi ed@ET wadzi ah ñux wsuyyi dori paziqix zix@DEF[SG.x] xtaq ñux sec ñtic
#
# 158
# ñax wsuyyi dicci zix hoy zqixdix raq pteqhix taq wta wsuyyi ñax dta uz vta ñizix ed ziquzi yta ih wyeh wec xtedyix suxxi yussi ev hoy
#
# ñax wsuyyi dicci zix@DEF[SG.x] hoy zqixdix raq pteqhix taq wta wsuyyi ñax dta uz vta ñizix ed@ET ziquzi yta ih@INDEF wyeh wec xtedyix suxxi yussi ev hoy
#
# 159
# zih ñax paxzh ziq ctahhi ñax jiñeyzi
#
# zih@DEF[SG.y] ñax paxzh ziq ctahhi ñax jiñeyzi
#
# 160
# za zqixdix raq jyirih ix wheq pkq vta wkr taq yidizi ñax ix zad ciz xedyi axzqi zqixdi ed zi peqhayhi za ec ayh ñraz zi ñarzi ptaih ap ziqiw duzp-tizqi
#
# za zqixdix raq jyirih ix@1-INDEF wheq pkq vta wkr@7 taq yidizi ñax ix@1-INDEF zad ciz xedyi axzqi zqixdi ed@ET zi@DEF[PL] peqhayhi za ec ayh ñraz zi@DEF[PL] ñarzi ptaih ap ziqiw duzp-tizqi
#
# 161
# zqixdix dos dqtizixzi ñtic
#
#
# 162
# ñaq tid wyih ossi ptaih xedih ap cox duzpaq
#
#
# 163
# wvuqdhi ñax
#
# wvuqdhi@demander? ñax
#
# 164
# te wraqizi paziqix zu ñaq ptaih ix xtedyi ziq sax yussi ev hoy ih wyeh wec yoddiq uzi vta ñizix
#
# te wraqizi paziqix zu ñaq ptaih ix@1-INDEF xtedyi ziq sax yussi ev hoy ih@INDEF wyeh wec yoddiq uzi vta ñizix
#
# 165
# ñax dos ziquz cix ziq raq ossi xedih wyeh ah wi
#
#
# 166
# wkr taq iphiq za ñax raq jyirih pteqhix taq dacciy dos ñax odix ziquz ed za whez wyehhih ziq
#
# wkr@7 taq iphiq za ñax raq jyirih pteqhix taq dacciy dos ñax odix ziquz ed@ET za whez wyehhih ziq
#
# 167
# ñax dos ziqoxz ed paxzh ix ñiwh ziq whez o whayzix ed jyir cidih dyaz ed qiz whqasw ñtic hoy wox paq
#
# ñax dos ziqoxz ed@ET paxzh ix@1-INDEF ñiwh ziq whez o@DANS whayzix ed@ET jyir cidih dyaz ed@ET qiz whqasw ñtic hoy wox paq
#
# 168
# xu ñaq tid ix ñiwh xu roy tid edwta qitwi wadzi ñax
#
# xu ñaq tid ix@1-INDEF ñiwh xu roy tid edwta qitwi wadzi ñax
#
# 169
# ñax qiz xu ñticcipqa ed za ñax ñarzi qizih ih yoyyi whkssi wta ñax ah ziq yta ix ptiq vta teqzix
#
# ñax qiz xu ñticcipqa ed@ET za ñax ñarzi qizih ih@INDEF yoyyi@petit whkssi wta ñax ah ziq yta ix@1-INDEF ptiq vta teqzix
#
# 170
# ñax royyi jussi wod xiz ed hadi zix ev cix yez zix ayyodiriy yoddi ed htixshi tid sax riy xes pta pah o ix vix xtaq tid wsay jqudi ix
#
# ñax royyi jussi wod xiz ed@ET hadi zix@DEF[SG.x] ev cix yez zix@DEF[SG.x] ayyodiriy yoddi ed@ET htixshi tid sax riy xes pta pah o@DANS ix@1-INDEF vix xtaq tid wsay jqudi ix@1-INDEF
#
# 171
# cix za ñteqhi ñax ix ziq qtajhi had cod ciz piqzoxaxz hqe
#
# cix za ñteqhi ñax ix@1-INDEF ziq qtajhi had cod ciz piqzoxaxz@Fernand hqe
#
# 172
# ñax rixzhi wod ec cix za ñax ossi suxxi evzadi xedix hed ñax ptiq-ix ev
#
#
# 173
# za ñax odix ñarzi qizih xedix hoz sec ñax hoy ix jtis
#
# za ñax odix ñarzi qizih xedix hoz sec ñax hoy ix@1-INDEF jtis
#
# 174
# vta jqizzix yta ix pows ed rqiz wod ed wxavvizi iphiq ritqih
#
# vta jqizzix yta ix@1-INDEF pows ed@ET rqiz wod ed@ET wxavvizi iphiq ritqih
#
# 175
# xu wsay tid ñttiyvi zod wadzi ñax hed zix o ñayix ed sawhizi zix o raxzih
#
# xu wsay tid ñttiyvi zod wadzi ñax hed zix@DEF[SG.x] o@DANS ñayix ed@ET sawhizi zix@DEF[SG.x] o@DANS raxzih
#
# 176
# powsix whas ñerizih ev ap raxzih ed wadzi peqzo zu ñaq pqiywh cod roy tid dori zod zixxi pytet-hi
#
# powsix whas ñerizih ev ap raxzih ed@ET wadzi peqzo zu ñaq pqiywh cod roy tid dori zod zixxi pytet-hi
#
# 177
# xtaq zu iq o xtez jiñteriq zu jyeh ah jytiwi o zix wta secciq tid ed ñttiyviq zod ed ñrow zu ixdaxd ñaq hajh xedih o raxzih wsay tid hadi zih ev hoy zod
#
# xtaq zu iq o@DANS xtez jiñteriq zu jyeh ah jytiwi o@DANS zix@DEF[SG.x] wta secciq tid ed@ET ñttiyviq zod ed@ET ñrow zu ixdaxd ñaq hajh xedih o@DANS raxzih wsay tid hadi zih@DEF[SG.y] ev hoy zod
#
# 178
# ñax qiz xu roziqi ed ctezhi yozh iphiq ix caxz ziq wvuqdhi ñreq ñax wsuyyi ñix
#
# ñax qiz xu roziqi ed@ET ctezhi yozh iphiq ix@1-INDEF caxz ziq wvuqdhi@demander? ñreq ñax wsuyyi ñix
#
# 179
# yodi uz ap yaxz-iritix wraqizi ñax
#
#
# 180
# ziqvta wvuqdhi caxzix ñraz ñax ñiz ed za ñax ñarzi ptaih zih ah rozi wadzi ñax wta ñizziq ro te echqixh zih wacci
#
# ziqvta wvuqdhi@demander? caxzix ñraz ñax ñiz ed@ET za ñax ñarzi ptaih zih@DEF[SG.y] ah rozi wadzi ñax wta ñizziq ro te echqixh zih@DEF[SG.y] wacci
#
# 181
# tid ñizziq piqzoxaxz uhqe
#
# tid ñizziq piqzoxaxz@Fernand uhqe
#
# 182
# zi puydh-iw wta az hoy zix xtiqciwhi sqe
#
# zi@DEF[PL] puydh-iw wta az hoy zix@DEF[SG.x] xtiqciwhi sqe
#
# 183
# piqzoxaxz uhqe suxxi ocozyiqhoz ix ñiy cawwi hqeyzzecwsuxwhiq ed rozwhi ziqpeq ayhoz ñraz piqzoxaxz hqe htixshi vta ed ñarzi o woxzi ah dteqi
#
# piqzoxaxz@Fernand uhqe suxxi ocozyiqhoz ix@1-INDEF ñiy cawwi hqeyzzecwsuxwhiq ed@ET rozwhi ziqpeq ayhoz ñraz piqzoxaxz@Fernand hqe htixshi vta ed@ET ñarzi o@DANS woxzi ah dteqi
#
# 184
# o sqeix raq ziq ix wcus uxd vodi ciz ih wtez-h rixyodh axwodh
#
# o@DANS sqeix raq ziq ix@1-INDEF wcus uxd vodi ciz ih@INDEF wtez-h rixyodh axwodh
#
# 185
# ñux jyir peqiywsih o piqzoxaxz hqe peq ñax raq ih vtixh uxdh cixxiwsi ed wvuqdhi ñreq ñax wsuyyi ñix
#
# ñux jyir peqiywsih o@DANS piqzoxaxz@Fernand hqe peq ñax raq ih@INDEF vtixh uxdh cixxiwsi ed@ET wvuqdhi@demander? ñreq ñax wsuyyi ñix
#
# 186
# ñax wraqizi ah ñax royyi wi wod yozh ec o riqzix
#
# ñax wraqizi ah ñax royyi wi wod yozh ec o@DANS riqzix
#
# 187
# vodix wadzi za ah ñax wsuyyi cidih ñiyyiqi jyori ziq ñax suxxi xes pta htix-iwhi ñew sexdix wec htixiq iyyiq peqqozziq
#
#
# 188
# piqzoxaxz hqe ñarzi ossi roziqi ykwh hoy ah dta ev ed jizi ec zih cix vodix hoyjtez za ah dteqi zih peq ñac
#
# piqzoxaxz@Fernand hqe ñarzi ossi roziqi ykwh hoy ah dta ev ed@ET jizi ec zih@DEF[SG.y] cix vodix hoyjtez za ah dteqi zih@DEF[SG.y] peq ñac
#
# 189
# ñux dos whqasw ev hoy sexdix ed wadzi ah ñux ñarzi puxzih ix vtix htixiq hoy ñac
#
# ñux dos whqasw ev hoy sexdix ed@ET wadzi ah ñux ñarzi puxzih ix@1-INDEF vtix htixiq hoy ñac
#
# 190
# ñax raq cidih riypeqxtetih ziqciz ed piqzoxaxz hqe sec ziqev
#
# ñax raq cidih riypeqxtetih ziqciz ed@ET piqzoxaxz@Fernand hqe sec ziqev
#
# 191
# ñax royyi ñiyw-h rtiqi peqq-oziq peq wta suxxi ñax jiñeyzi wox ñiwh ed zih jyir ñax za edwta
#
# ñax royyi ñiyw-h rtiqi peqq-oziq peq wta suxxi ñax jiñeyzi wox ñiwh ed@ET zih@DEF[SG.y] jyir ñax za edwta
#
# 192
# za piqzoxaxz uhqe ñteqhi zih wadzi ñax hoy vodix ñteq sax zu ossi edwta ñttiyvi cod
#
# za piqzoxaxz@Fernand uhqe ñteqhi zih@DEF[SG.y] wadzi ñax hoy vodix ñteq sax zu ossi edwta ñttiyvi cod
#
# 193
# vodix htixshi ah zih raq ossi rtiqz ah ñari ñac hoy urix ed dos ziqpeq hoy sexdix wec edwta hed piqzoxaxz uhqe o wox htix-iwhi
#
# vodix htixshi ah zih@DEF[SG.y] raq ossi rtiqz ah ñari ñac hoy urix ed@ET dos ziqpeq hoy sexdix wec edwta hed piqzoxaxz@Fernand uhqe o@DANS wox htix-iwhi
#
# 194
# xtaq piqzoxaxz uhqe ec ceqdixix sytizhi sexdix vta wussizi zixxi jiwh-axzod jaqi cox stiqiwhi raq ñiq
#
# xtaq piqzoxaxz@Fernand uhqe ec ceqdixix sytizhi sexdix vta wussizi zixxi jiwh-axzod jaqi cox stiqiwhi raq ñiq
#
# 195
# piqzoxaxz uhqe wec ñarzi ih ñeqx o wozix vta piqzoxaxz hqe wadzi za hoy ñac ziqiw catiwhtih ñaq te ix peqq-oziq
#
# piqzoxaxz@Fernand uhqe wec ñarzi ih@INDEF ñeqx o@DANS wozix vta piqzoxaxz@Fernand hqe wadzi za hoy ñac ziqiw catiwhtih ñaq te ix@1-INDEF peqq-oziq
#
# 196
# wixz ñac ap whiz iphiq ñixzi ed yaz ñac cowh-i woh ñerizi ñrow ñax ossi jqoxdiq ñixzi
#
# wixz ñac ap whiz iphiq ñixzi ed@ET yaz ñac cowh-i woh ñerizi ñrow ñax ossi jqoxdiq ñixzi
#
# 197
# sexdix yez za piqzoxaxz hqe sayzi hoy wod ed jipayizi ñac ah ñixhi ñaxw stiqiwhi ed dteqzi ñax zih ossi wsuyyi ñax zte
#
# sexdix yez za piqzoxaxz@Fernand hqe sayzi hoy wod ed@ET jipayizi ñac ah ñixhi ñaxw stiqiwhi ed@ET dteqzi ñax zih@DEF[SG.y] ossi wsuyyi ñax zte
#
# 198
# piqzoxaxz hqe dos xiz o whayzix hoy wox ñiwh ed dqtiz
#
# piqzoxaxz@Fernand hqe dos xiz o@DANS whayzix hoy wox ñiwh ed@ET dqtiz
#
# 199
# ñreq iq tid zed ih uykssiyod-h cixxiwsi ñuysizi ñax
#
# ñreq iq tid zed ih@INDEF uykssiyod-h cixxiwsi ñuysizi ñax
#
# 200
# ñraz dqtiziq zu peq
#
#
# 201
# qtajhi ix whicci jadriz ñac
#
# qtajhi ix@1-INDEF whicci jadriz ñac
#
# 202
# ñax wta wod ec cix suxxi ossi evzadi xedix ed jyir riz ah tacqi xu cta tid peqya-zi zod cox yoyyi ñiwh xu wsay tid zte
#
# ñax wta wod ec cix suxxi ossi evzadi xedix ed@ET jyir riz ah tacqi xu cta tid peqya-zi zod cox yoyyi@petit ñiwh xu wsay tid zte
#
# 203
# ñraz dqtiziq zu peq
#
#
# 204
# wadzi whiccix odix ed ñax evzadizi xu ah zih raq ñaxw ñiwh ziq hayhi
#
# wadzi whiccix odix ed@ET ñax evzadizi xu ah zih@DEF[SG.y] raq ñaxw ñiwh ziq hayhi
#
# 205
# sax zu wxassi yoyyi ñiwh
#
# sax zu wxassi yoyyi@petit ñiwh
#
# 206
# wadzi ñax peqjarwih
#
#
# 207
# tid wsay ñix ed ñixhi sexdixw stiqiwhi ed tid sax ossi jidqoji ñreqzax tid wsay jtiqi cod az
#
# tid wsay ñix ed@ET ñixhi sexdixw stiqiwhi ed@ET tid sax ossi jidqoji ñreqzax tid wsay jtiqi cod az
#
# 208
# dta ñix hoy sexdix ed wod ah ñax wsay dori zod ñraz zu peqya-xdiq wadzi ñiwh-ix ed jiz wta ec ih wsoj puyzh ap stez ed ih puyzh ap jqtez wta wsay zih xes ykssiw peq zod
#
# dta ñix hoy sexdix ed@ET wod ah ñax wsay dori zod ñraz zu peqya-xdiq wadzi ñiwh-ix ed@ET jiz wta ec ih@INDEF wsoj puyzh ap stez ed@ET ih@INDEF puyzh ap jqtez wta wsay zih@DEF[SG.y] xes ykssiw peq zod
#
# 209
# uzi vta raxzih roy zu xicyod hqti-ppi xedyi sticviq wec wtex-ziq-q-oriq zod ñrow zu ossi ñaq stez ciz hoy zic ed xedyi wheqi pudyi wec ñassi-q tetxixi uz vta zod ñrow zi ossi ptaq jqtez
#
# uzi vta raxzih roy zu xicyod hqti-ppi xedyi sticviq wec wtex-ziq-q-oriq zod ñrow zu ossi ñaq stez ciz hoy zic ed@ET xedyi wheqi pudyi wec ñassi-q tetxixi uz vta zod ñrow zi@DEF[PL] ossi ptaq jqtez
#
# 210
# sexdix yez xu ix ctixdzi srtid wyadhi ed jadh-i ix juxsi jqtez ed zih jyir jqadh ecjeqz vta wsojixi
#
# sexdix yez xu ix@1-INDEF ctixdzi srtid wyadhi ed@ET jadh-i ix@1-INDEF juxsi jqtez ed@ET zih@DEF[SG.y] jyir jqadh ecjeqz vta wsojixi
#
# 211
# wity xu jaqi ap whiz wadzi ñiwh-ix ed xtaq sticviqxi secciq wsay zu jyeh wodi
#
# wity xu jaqi ap whiz wadzi ñiwh-ix ed@ET xtaq sticviqxi secciq wsay zu jyeh wodi
#
# 212
# hkw hkw coxi sticviq wcta
#
#
# 213
# ytissiqh stez wsay
#
#
# 214
# ap cod o pta
#
# ap cod o@DANS pta
#
# 215
# hoy pudyixi wodiq zu
#
#
# 216
# hkw hkw coxi pudyi wcta
#
#
# 217
# ytissiqh jqtez wsay
#
#
# 218
# ap cod o pta
#
# ap cod o@DANS pta
#
# 219
# wta dteq zi zod ossi xedih
#
# wta dteq zi@DEF[PL] zod ossi xedih
#
# 220
# zu wsay pta ih vaq ap sticviqxi ciz ev vta wyehhih ñreq vqoxwiwwix yoddiq ed weriq ed zi wsay jtiqi ñixzi ecjeqz ciz wixdix ed zih ñiyi
#
# zu wsay pta ih@INDEF vaq ap sticviqxi ciz ev vta wyehhih ñreq vqoxwiwwix yoddiq ed@ET weriq ed@ET zi@DEF[PL] wsay jtiqi ñixzi ecjeqz ciz wixdix ed@ET zih@DEF[SG.y] ñiyi
#
# 221
# zih dos ayhwaccix wec ñiwh-ix ñarzi wadh
#
# zih@DEF[SG.y] dos ayhwaccix wec ñiwh-ix ñarzi wadh
#
# 222
# piqzoxaxz dar sticviqxi ed pudyixi stezih ed jqtezih ed sticviqxi ñtayv ñac ciz ah jtiqi vqoxwiwwix xiz vta wsojih
#
# piqzoxaxz@Fernand dar sticviqxi ed@ET pudyixi stezih ed@ET jqtezih ed@ET sticviqxi ñtayv ñac ciz ah jtiqi vqoxwiwwix xiz vta wsojih
#
# 223
# za ñux sec hoy sexdix wadzi ñux ah ñux suxxi ossi yiri ñrow ñux ossi pos woxi jqiri ed axzqi vavoq-i-q ziq yta ñticci vta wyehhih
#
# za ñux sec hoy sexdix wadzi ñux ah ñux suxxi ossi yiri ñrow ñux ossi pos woxi jqiri ed@ET axzqi vavoq-i-q ziq yta ñticci vta wyehhih
#
# 224
# piqzoxaxz uhqe pos zih odix eqzxih wtazax ah piqzoxaxz hqe jyir wixzh ap whiz ed wsuyyi jtezi ciz woh yor ñrow ñax ossi pos pah o jqirixi
#
# piqzoxaxz@Fernand uhqe pos zih@DEF[SG.y] odix eqzxih wtazax ah piqzoxaxz@Fernand hqe jyir wixzh ap whiz ed@ET wsuyyi jtezi ciz woh yor ñrow ñax ossi pos pah o@DANS jqirixi
#
# 225
# ñax dos dqtizixzi xiz o whayzix ed wadzi xu wsay tid ap whiz odix yoyyi ñiwh ñraz wsay tid xu dteqi
#
# ñax dos dqtizixzi xiz o@DANS whayzix ed@ET wadzi xu wsay tid ap whiz odix yoyyi@petit ñiwh ñraz wsay tid xu dteqi
#
# 226
# ñiwh-ix wadzi za ah ñax wsuyyi yazi wsojixi wec peqqodi daxd
#
#
# 227
# zih dos yodiw-ec wozwh sticviqxi ed pudyixi jyir whoyyih hoypqizw ciz stezih ed jqtezih
#
# zih@DEF[SG.y] dos yodiw-ec wozwh sticviqxi ed@ET pudyixi jyir whoyyih hoypqizw ciz stezih ed@ET jqtezih
#
# 228
# za zi sec hoy wyehhih wadzi ñiwh-ix ah ñax wsuyyi dta oxz o vqoxwiwwixw werisacciq ziq yta jqirixi vta jeqzih
#
# za zi@DEF[PL] sec hoy wyehhih wadzi ñiwh-ix ah ñax wsuyyi dta oxz o@DANS vqoxwiwwixw werisacciq ziq yta jqirixi vta jeqzih
#
# 229
# piqzoxaxz hqe dos oxz ed ñixhizi zic ed sec ecjeqz odix cix vta ritix ñtic hajhi ñax wox dtawivix o raxzih
#
# piqzoxaxz@Fernand hqe dos oxz ed@ET ñixhizi zic ed@ET sec ecjeqz odix cix vta ritix ñtic hajhi ñax wox dtawivix o@DANS raxzih
#
# 230
# zix sax tid ossi wsappi zod odix wadzi ñiwh-ix cix piqzoxaxz sec za o haxsiq ec pyte-thix ed whqasw za ñax ñarzi jytiwh o zix sec powsix wrteccixzi ciz vixxix o cuxzix
#
# zix@DEF[SG.x] sax tid ossi wsappi zod odix wadzi ñiwh-ix cix piqzoxaxz@Fernand sec za o@DANS haxsiq ec pyte-thix ed@ET whqasw za ñax ñarzi jytiwh o@DANS zix@DEF[SG.x] sec powsix wrteccixzi ciz vixxix o@DANS cuxzix
#
# 231
# ñax jqadhi xu vavoq-i-q-xi hoy vqoxwiwwix ed jqkyyuvvih jyir pitqih
#
# ñax jqadhi xu vavoq-i-q-xi hoy vqoxwiwwix ed@ET jqkyyuvvih jyir pitqih
#
# 232
# zqexxoxdix suxxi ocozyiqhoz ossi qodhod yozi sexdix peqzo ñax oxdix xtiwi ñarzi ziqocez wkxhiw ñux wrtiqh dezh ec piqzoxaxz hqe
#
# zqexxoxdix suxxi ocozyiqhoz ossi qodhod yozi sexdix peqzo ñax oxdix xtiwi ñarzi ziqocez wkxhiw ñux wrtiqh dezh ec piqzoxaxz@Fernand hqe
#
# 233
# ixdaxd za ñiyi ñeppih raq wacyih wadzi zqexxoxdix ah ñux suxxi dteqi ih suxwh-whkssi
#
# ixdaxd za ñiyi ñeppih raq wacyih wadzi zqexxoxdix ah ñux suxxi dteqi ih@INDEF suxwh-whkssi
#
# 234
# ñux suxxi ñuddi ñerizih ap ih cixxiwsi ed wtihhi zih vta odix
#
# ñux suxxi ñuddi ñerizih ap ih@INDEF cixxiwsi ed@ET wtihhi zih@DEF[SG.y] vta odix
#
# 235
# ziq raq oxdix ziq ñarzi ykwh hoy ah vqteri cix piqzoxaxz uhqe pos zih hoy wozwh yarih wtazax ah piqzoxaxz hqe ctahhi hoy zih
#
# ziq raq oxdix ziq ñarzi ykwh hoy ah vqteri cix piqzoxaxz@Fernand uhqe pos zih@DEF[SG.y] hoy wozwh yarih wtazax ah piqzoxaxz@Fernand hqe ctahhi hoy zih@DEF[SG.y]
#
# 236
# zqexxoxdix ñuddizi wta ñerizih ap ñac ed pos zih whqasw hoy ah reswi pawh odix ziq raq sux ix qtez whqoji quxzh ec ñaywix
#
# zqexxoxdix ñuddizi wta ñerizih ap ñac ed@ET pos zih@DEF[SG.y] whqasw hoy ah reswi pawh odix ziq raq sux ix@1-INDEF qtez whqoji quxzh ec ñaywix
#
# 237
# ñreq ñaq zu ytiqh zix suxwh
#
# ñreq ñaq zu ytiqh zix@DEF[SG.x] suxwh
#
# 238
# wvuqdhi sexdix
#
# wvuqdhi@demander? sexdix
#
# 239
# zix sax tid xu ixdaxd wraqizi ñux wsay tid edwta vqteri ciz zod
#
# zix@DEF[SG.x] sax tid xu ixdaxd wraqizi ñux wsay tid edwta vqteri ciz zod
#
# 240
# ñax wadzi ta ed ñux ñuddizi xu ñerizih ap ñac cix yez wec ec ñux ossi suxxi pta zih hoy ah wozzi pawh odix
#
# ñax wadzi ta ed@ET ñux ñuddizi xu ñerizih ap ñac cix yez wec ec ñux ossi suxxi pta zih@DEF[SG.y] hoy ah wozzi pawh odix
#
# 241
# sexdix jyir wta jidqari-h ed zqexxoxdix dophi-zi wod ciz piqzoxaxz hqe
#
# sexdix jyir wta jidqari-h ed@ET zqexxoxdix dophi-zi wod ciz piqzoxaxz@Fernand hqe
#
# 242
# piqzoxaxz qiz whazod vta wox ñiwh ed ix zad wadzi zix hoy ñac ah ñax wsuyyi qozi uz vta ñizix ed ziq qozi hqi daxdi o ix quxz-sqizw
#
# piqzoxaxz@Fernand qiz whazod vta wox ñiwh ed@ET ix@1-INDEF zad wadzi zix@DEF[SG.x] hoy ñac ah ñax wsuyyi qozi uz vta ñizix ed@ET ziq qozi hqi@3 daxdi o@DANS ix@1-INDEF quxz-sqizw
#
# 243
# za ñax ñarzi dteqh zih qitwhi ñiwh-ix wod vta jadjixixi ed jyir peqraxzyih hoy ix sexdiwtex
#
# za ñax ñarzi dteqh zih@DEF[SG.y] qitwhi ñiwh-ix wod vta jadjixixi ed@ET jyir peqraxzyih hoy ix@1-INDEF sexdiwtex
#
# 244
# 090 zix uxdi sticvi
#
# 090 zix@DEF[SG.x] uxdi sticvi
#
# 245
# ziq raq ixdaxd ix jexzi wec ñarzi ix wtex ziq ossi raq whteqqi ixz ix hecci-ypoxdiq ed ñax reswizi o ytejih ap pyiqi taq ossi wta cidih wec ix ñtaq-wjqizzi
#
# ziq raq ixdaxd ix@1-INDEF jexzi wec ñarzi ix@1-INDEF wtex ziq ossi raq whteqqi ixz ix@1-INDEF hecci-ypoxdiq ed@ET ñax reswizi o@DANS ytejih ap pyiqi taq ossi wta cidih wec ix@1-INDEF ñtaq-wjqizzi
#
# 246
# ix zad za jexzix royyi uz vta caqsix ed vyteti wadzi zix yoyyi pkq cta tid secci ciz paq
#
# ix@1-INDEF zad za jexzix@paysan[nom] royyi uz vta caqsix ed@ET vyteti wadzi zix@DEF[SG.x] yoyyi@petit pkq cta tid secci ciz paq
#
# 247
# roy zu ciz
#
#
# 248
# wadzi paziqix
#
#
# 249
# jyor zu ñiyyiqi ñticci
#
#
# 250
# zu sax zed ossi dteqi xedix riqzixw xkhhi ed zu suxxi edwta yih jyori jeqhi peq cod
#
# zu sax zed ossi dteqi xedix riqzixw xkhhi ed@ET zu suxxi edwta yih jyori jeqhi peq cod
#
# 251
# cix za dar ñax wod hoy ah dqtizi ed peq ah pta qe peq ñac whas paziqix ñac o yeccix ed dos ziquz
#
# cix za dar ñax wod hoy ah dqtizi ed@ET peq ah pta qe peq ñac whas paziqix ñac o@DANS yeccix ed@ET dos ziquz
#
# 252
# vta caqsix hed ñax ñac ev odix ed wahhi ñac o ix xkvytetih puqi
#
# vta caqsix hed ñax ñac ev odix ed@ET wahhi ñac o@DANS ix@1-INDEF xkvytetih puqi
#
# 253
# cixw ñax waz ziq sec ix rtiyzod sticvi dtaixzi eriq jtiqdih
#
# cixw ñax waz ziq sec ix@1-INDEF rtiyzod sticvi dtaixzi eriq jtiqdih
#
# 254
# sax zu wi zix wheqi juwwicaxz wadzi paziqix ed royyi dteqi zix yoyyi jaxdi peq ah pta ñac hoy ah rtiqi aqhod ñax secciq ed hadiq zod
#
# sax zu wi zix@DEF[SG.x] wheqi juwwicaxz wadzi paziqix ed@ET royyi dteqi zix@DEF[SG.x] yoyyi@petit jaxdi peq ah pta ñac hoy ah rtiqi aqhod ñax secciq ed@ET hadiq zod
#
# 255
# za sticvix ñarzi dtaih ih vaq wsqozh vta woxi yaxdi jix raq ñax ñixxi riz puqi-x hed peqw-odhodh zix yoyyi pkq ciyyic he poxd-qi wta vta ñac ed dos jeqh ciz ñac uzix ah wodi ih eqz
#
# za sticvix ñarzi dtaih ih@INDEF vaq wsqozh vta woxi yaxdi jix raq ñax ñixxi riz puqi-x hed peqw-odhodh zix@DEF[SG.x] yoyyi@petit pkq ciyyic he@2 poxd-qi wta vta ñac ed@ET dos jeqh ciz ñac uzix ah wodi ih@INDEF eqz
#
# 256
# paziqix whez riz wozix ap ed raq wta jaxdi ah ñax ossi suxxi pta ix ykz pqic
#
# paziqix whez riz wozix ap ed@ET raq wta jaxdi ah ñax ossi suxxi pta ix@1-INDEF ykz pqic
#
# 257
# ñax hqeizi ah ñax peq jiwh-axzod ñarzi cowh-i-h woh jaqx ed ayzqod ciqi wsuyyi wi zih peq woxi tetxi
#
# ñax hqeizi ah ñax peq jiwh-axzod ñarzi cowh-i-h woh jaqx ed@ET ayzqod ciqi wsuyyi wi zih@DEF[SG.y] peq woxi tetxi
#
# 258
# sticvix hed ocozyiqhoz zqixdix ciz wod ñtic dar ñac zoi wta ñax reswizi ed jyir wheq ed whtiqs wec ix sticvi
#
# sticvix hed ocozyiqhoz zqixdix ciz wod ñtic dar ñac zoi wta ñax reswizi ed@ET jyir wheq ed@ET whtiqs wec ix@1-INDEF sticvi
#
# 259
# iphiq he taqw peqytej royyi zix dacyi vqteri ñaxw sqtiphiq ed hed ñac ciz uz o wserix hqti-s zih qow ev wadzi ñax ed zqixdix raq ayyiqizi wta whtiqs ah ñax qir ih uxdh hqti ev ciz qezi
#
# iphiq he@2 taqw peqytej royyi zix@DEF[SG.x] dacyi vqteri ñaxw sqtiphiq ed@ET hed ñac ciz uz o@DANS wserix hqti-s zih@DEF[SG.y] qow ev wadzi ñax ed@ET zqixdix raq ayyiqizi wta whtiqs ah ñax qir ih@INDEF uxdh hqti ev ciz qezi
#
# 260
# zih wsay jyori jizqi ixzxu wadzi sticvix hed ñac ciz wod ñtic ed dar ñac zoi o he taq
#
# zih@DEF[SG.y] wsay jyori jizqi ixzxu wadzi sticvix hed ñac ciz wod ñtic ed@ET dar ñac zoi o@DANS he@2 taq
#
# 261
# wta raq ñax jyirih wta whtiqs ah ñax suxxi qkssi ih dacciyh hqti ev
#
# wta raq ñax jyirih wta whtiqs ah ñax suxxi qkssi ih@INDEF dacciyh hqti ev
#
# 262
# cix sticvix wkxhiw ixzxu ossi zih raq xes ed dar ñac zoi ixzxu o he taq
#
# cix sticvix wkxhiw ixzxu ossi zih@DEF[SG.y] raq xes ed@ET dar ñac zoi ixzxu o@DANS he@2 taq
#
# 263
# wta dos zi uz o wserix odix ed ñax wadzi hoy zqixdix had xu ih eqzixhyodh qow ed ciz ih jqad qir zqixdix zih hkssiwhi idihqti ev ed zih dos peq ñac wec ix yid
#
# wta dos zi@DEF[PL] uz o@DANS wserix odix ed@ET ñax wadzi hoy zqixdix had xu ih@INDEF eqzixhyodh qow ed@ET ciz ih@INDEF jqad qir zqixdix zih@DEF[SG.y] hkssiwhi idihqti ev ed@ET zih@DEF[SG.y] dos peq ñac wec ix@1-INDEF yid
#
# 264
# xu iq zih xes wadzi sticvix xu iq zu uzytiqh
#
# xu iq zih@DEF[SG.y] xes wadzi sticvix xu iq zu uzytiqh
#
# 265
# ziqvta dos ñax ciz ñac ñix vta zix caqs ñreq ñax ñarzi ñixhih ñac
#
# ziqvta dos ñax ciz ñac ñix vta zix@DEF[SG.x] caqs ñreq ñax ñarzi ñixhih ñac
#
# 266
# paziqix dos jadriz vyerix ed zix uxdi sticvi dos ñix hoy ñac ed wadzi dezzad paq
#
# paziqix dos jadriz vyerix ed@ET zix@DEF[SG.x] uxdi sticvi dos ñix hoy ñac ed@ET wadzi dezzad paq
#
# 267
# ziq sax zu wi ñraz peq ix caxz zox wtex iq jyirih
#
# ziq sax zu wi ñraz peq ix@1-INDEF caxz zox wtex iq jyirih
#
# 268
# jexzix jyir peqptiqzih
#
# jexzix@paysan[nom] jyir peqptiqzih
#
# 269
# zu iq ossi cox wtex wadzi ñax tid roy ossi rozi xedih ap zod dta zox rit
#
#
# 270
# rowh iq tid zox wtex
#
#
# 271
# yaz cod ñttiyvi zod
#
#
# 272
# tid sax vyteti yodi wta dezh wec zu ed jizqi
#
# tid sax vyteti yodi wta dezh wec zu ed@ET jizqi
#
# 273
# xit zu iq ossi cox wtex ed zu sax ñiyyiq ossi vyteti
#
# xit zu iq ossi cox wtex ed@ET zu sax ñiyyiq ossi vyteti
#
# 274
# dta zox rit
#
#
# 275
# cix za ñax raq jaxdi peq zix wheqi caxz dos ñax jeqh pqa vyerix ed wahhi wod ih whkssi jeqhi
#
# cix za ñax raq jaxdi peq zix@DEF[SG.x] wheqi caxz dos ñax jeqh pqa vyerix ed@ET wahhi wod ih@INDEF whkssi jeqhi
#
# 276
# zqixdix hqkssizi xu jyeh ciz zix ixi ñtaxz vta zix cix wta sqaph-od-h raq hqkssih ah vyerix waxs ñiyh xiz o teqzix
#
# zqixdix hqkssizi xu jyeh ciz zix@DEF[SG.x] ixi ñtaxz vta zix@DEF[SG.x] cix wta sqaph-od-h raq hqkssih ah vyerix waxs ñiyh xiz o@DANS teqzix
#
# 277
# zih suxxi jexzix ossi hoi whoyyi hoy ed qtajhi ñrow zu roy vyteti cta zu ossi hqkssi wta ñtaqzh
#
# zih@DEF[SG.y] suxxi jexzix@paysan[nom] ossi hoi whoyyi hoy ed@ET qtajhi ñrow zu roy vyteti cta zu ossi hqkssi wta ñtaqzh
#
# 278
# zih zuiq ossi
#
# zih@DEF[SG.y] zuiq ossi
#
# 279
# zqixdix wvtixzhi xu ñiwhixi pqa ed hqas wiyr vyerix
#
# zqixdix wvtixzhi xu ñiwhixi pqa ed@ET hqas wiyr vyerix
#
# 280
# dta sux ñtic paq wadzi ñax ed yaz ceq sedi ih wheqh paz caz
#
# dta sux ñtic paq wadzi ñax ed@ET yaz ceq sedi ih@INDEF wheqh paz caz
#
# 281
# wta wsay tid ocozyiqhoz jyori ptiqzod ciz caqsix
#
#
# 282
# jexzix dos ñtic ed jaz wox sexi yari cazix ed zqixdix vytetizi daxwsi ayixi caqsix wec raq he htexziq yaxz wheq wvtixzhi wod wiyr peq ñaqri-x ed ñaqri-zi ciz he vta ix daxd
#
# jexzix@paysan[nom] dos ñtic ed@ET jaz wox sexi yari cazix ed@ET zqixdix vytetizi daxwsi ayixi caqsix wec raq he@2 htexziq yaxz wheq wvtixzhi wod wiyr peq ñaqri-x ed@ET ñaqri-zi ciz he@2 vta ix@1-INDEF daxd
#
# 283
# za ñax raq ptiqzod dos ñax oxz o wserix qir he idihqtiiq ev yadzi zic eriq wsuyziqix ed ñtixdhi ix ñiwh ed ix ñaqri peq ed ix jad ed jaq zih ñtic hoy woxi peqt-i-yzqiw ñuw wta yih wec zih raq ih sxovvi ñayc
#
# za ñax raq ptiqzod dos ñax oxz o@DANS wserix qir he@2 idihqtiiq ev yadzi zic eriq wsuyziqix ed@ET ñtixdhi ix@1-INDEF ñiwh ed@ET ix@1-INDEF ñaqri peq ed@ET ix@1-INDEF jad ed@ET jaq zih@DEF[SG.y] ñtic hoy woxi peqt-i-yzqiw ñuw wta yih wec zih@DEF[SG.y] raq ih@INDEF sxovvi ñayc
#
# 284
# za ñax sec oxz o dtaqzix suxxi ñaxw ceq ossi sixzi ñac odix ed wvuqdhi ñric iq zix peqptiqziyod wheqi caxz
#
# za ñax sec oxz o@DANS dtaqzix suxxi ñaxw ceq ossi sixzi ñac odix ed@ET wvuqdhi@demander? ñric iq zix@DEF[SG.x] peqptiqziyod wheqi caxz
#
# 285
# zih iq reqiw wtex wraqizi jexzix
#
# zih@DEF[SG.y] iq reqiw wtex wraqizi jexzix@paysan[nom]
#
# 286
# ayzqod o yorih wadzi ñux zih raq te ix daxwsi yoyyi pkq
#
# ...
#
# 12418
# cixw zix raq o puyz paqh wtiji-zi ñax zix oxz ed jaqjiq-i-zi zix ix sxij-i-y-wjaqh uzix ah wstiqi zix ix wcuyi iyyiq qori ih ñtaq ap
#
# cixw zix@DEF[SG.x] raq o@DANS puyz paqh wtiji-zi ñax zix@DEF[SG.x] oxz ed@ET jaqjiq-i-zi zix@DEF[SG.x] ix@1-INDEF sxij-i-y-wjaqh uzix ah wstiqi zix@DEF[SG.x] ix@1-INDEF wcuyi iyyiq qori ih@INDEF ñtaq ap
#
# 12419
# zih raq dezh dteqh wadzi paziqix ñrow zi axzqi ossi dteq wod uñkqi axwhqixd-iywiq iq ñuwih zoh
#
# zih@DEF[SG.y] raq dezh dteqh wadzi paziqix ñrow zi@DEF[PL] axzqi ossi dteq wod uñkqi axwhqixd-iywiq iq ñuwih zoh
#
# 12420
# yozh iphiq sec ix ñiqqi steqixzi peqjo o puyz dayev
#
# yozh iphiq sec ix@1-INDEF ñiqqi steqixzi peqjo o@DANS puyz dayev
#
# 12421
# xu wsay o wi ñraz tid sax wadzi wciz-ix qir o paqhix zi poqi ñiwhi-w-se ap ñiwh-ix ed wyed xk vta
#
# xu wsay o@DANS wi ñraz tid sax wadzi wciz-ix qir o@DANS paqhix zi@DEF[PL] poqi ñiwhi-w-se ap ñiwh-ix ed@ET wyed xk vta
#
# 12422
# zu iq ix zkdhod pkq wadzi paziqix zu dteq zoxi wadiq yodi wta dezh wec zox jqeq
#
# zu iq ix@1-INDEF zkdhod pkq wadzi paziqix zu dteq zoxi wadiq yodi wta dezh wec zox jqeq
#
# 12423
# tid riz roqsiyod ossi ñric tid wsay dori ñuwih
#
#
# 12424
# yaz xu cod vqteri ixdaxd wadzi zix kxdwhi
#
# yaz xu cod vqteri ixdaxd wadzi zix@DEF[SG.x] kxdwhi
#
# 12425
# o zih wacci jidkxzhi zih ah qidxi ed ñax hqas wox staqzi ed wroxdizi zix o sqkzw-ñud eriq woh ñeriz wta ziq ossi payzh ix zqtaji vta ñac
#
# o@DANS zih@DEF[SG.y] wacci jidkxzhi zih@DEF[SG.y] ah qidxi ed@ET ñax hqas wox staqzi ed@ET wroxdizi zix@DEF[SG.x] o@DANS sqkzw-ñud eriq woh ñeriz wta ziq ossi payzh ix@1-INDEF zqtaji vta ñac
#
# 12426
# qidxix jyir whtiqsiqi ed whtiqsiqi zih tewizi wvaxzi xiz cix ñax wraxd staqzix ñuqhodiqi ed ñuqhodiqi ed raq yodi wta hteq wec ec ñax waz uxziq ih htih had
#
# qidxix jyir whtiqsiqi ed@ET whtiqsiqi zih@DEF[SG.y] tewizi wvaxzi xiz cix ñax wraxd staqzix ñuqhodiqi ed@ET ñuqhodiqi ed@ET raq yodi wta hteq wec ec ñax waz uxziq ih@INDEF htih had
#
# 12427
# paziqix raq cidih pequxzqih ed wadzi zu ñaq dteqh zih jizwhi ciwhiqwhkssi ñuwih iq zoh
#
# paziqix raq cidih pequxzqih ed@ET wadzi zu ñaq dteqh zih@DEF[SG.y] jizwhi ciwhiqwhkssi ñuwih iq zoh
#
# 12428
# zi he axzqi jqtezqi raq hoyp-qizwi ciz zix eqzx-oxd wtazax wec zi ñarzi yerih o peqritix
#
# zi@DEF[PL] he@2 axzqi jqtezqi raq hoyp-qizwi ciz zix@DEF[SG.x] eqzx-oxd wtazax wec zi@DEF[PL] ñarzi yerih o@DANS peqritix
#
# 12429
# zi ñeyzh wta cidih ap ñoxaxzix ah zi ayyi hqi jyir jeixzi o ñuwih ed zqir ziqiw peqwsiyyodi ñtaxzrtiqs
#
# zi@DEF[PL] ñeyzh wta cidih ap ñoxaxzix ah zi@DEF[PL] ayyi hqi@3 jyir jeixzi o@DANS ñuwih ed@ET zqir ziqiw peqwsiyyodi ñtaxzrtiqs
#
# 12430
# za zi raq wta pyoxsi ed zkdhod-i htixhi zi iphiqñtaxzix caxdi vixdi
#
# za zi@DEF[PL] raq wta pyoxsi ed@ET zkdhod-i htixhi zi@DEF[PL] iphiqñtaxzix caxdi vixdi
#
# 12431
# zi yirizi dyazi waccix hoy zi jyir dacyi za jyir zix ixi wkd ed ztezi ed zi axzqi wteqdizi wta cidih ziqeriq ah zi edwta jyir wkdi ed ztezi seqh iphiq
#
# zi@DEF[PL] yirizi dyazi waccix hoy zi@DEF[PL] jyir dacyi za jyir zix@DEF[SG.x] ixi wkd ed@ET ztezi ed@ET zi@DEF[PL] axzqi wteqdizi wta cidih ziqeriq ah zi@DEF[PL] edwta jyir wkdi ed@ET ztezi seqh iphiq
#
# 12432
# ed za zi ñarzi ñeyzh wta cidih ap ñoxaxzix jyir zi ayyi hqi jidqari-h o wacci dqar
#
# ed@ET za zi@DEF[PL] ñarzi ñeyzh wta cidih ap ñoxaxzix jyir zi@DEF[PL] ayyi hqi@3 jidqari-h o@DANS wacci dqar
#
# 12433
# 125 zttiriyix ed ñaxw jizwhiceq
#
# 125 zttiriyix ed@ET ñaxw jizwhiceq
#
# 12434
# ixdaxd raq ziq sqod o yaxzih
#
# ixdaxd raq ziq sqod o@DANS yaxzih
#
# 12435
# sexdix ñarzi caxdi weyzahiq cix ñax dar zic ossi wta cidih weyz ah zi suxxi yiri ap zih
#
# sexdix ñarzi caxdi weyzahiq cix ñax dar zic ossi wta cidih weyz ah zi@DEF[PL] suxxi yiri ap zih@DEF[SG.y]
#
# 12436
# hqi ap zic jyir za ixodi ec ah qitwi jeqh waccix
#
# hqi@3 ap zic jyir za ixodi ec ah qitwi jeqh waccix
#
# 12437
# ñrow zi poxziq ew jyoriq ro sykx-dih ev o ih hqti wadzi zix ixi ñreqzax wsay ro idixhyod jtiqi ew az
#
# ñrow zi@DEF[PL] poxziq ew jyoriq ro sykx-dih ev o@DANS ih@INDEF hqti wadzi zix@DEF[SG.x] ixi ñreqzax wsay ro idixhyod jtiqi ew az
#
# 12438
# sax o wi zix caqs ziqñixxi wadzi zix axzix xtaq ro wstuy-iq ew ziq iq ziq ossi ih cixxiwsi wec sax poxzi ew
#
# sax o@DANS wi zix@DEF[SG.x] caqs ziqñixxi wadzi zix@DEF[SG.x] axzix xtaq ro wstuy-iq ew ziq iq ziq ossi ih@INDEF cixxiwsi wec sax poxzi ew
#
# 12439
# weyzahiqxi hteq ossi dta ziqoxz ed o ceqdix zqadiq ñtiq-ix roziqi
#
# weyzahiqxi hteq ossi dta ziqoxz ed@ET o@DANS ceqdix zqadiq ñtiq-ix roziqi
#
# 12440
# zi sqtej wta oxz o seqxih cix ñtiq-ix jyir daxwsi qeyodh yoddixzi quxzh ec
#
# zi@DEF[PL] sqtej wta oxz o@DANS seqxih cix ñtiq-ix jyir daxwsi qeyodh yoddixzi quxzh ec
#
# 12441
# he ñiyi ztedx waz zi oxzi vta caqsix
#
# he@2 ñiyi ztedx waz zi@DEF[PL] oxzi vta caqsix
#
# 12442
# zi raq ñayrh ztezi ap wyuh cix zi huqzi ossi secci pqic peq wta ñarzi ztezix rtiqih zic row
#
# zi@DEF[PL] raq ñayrh ztezi ap wyuh cix zi@DEF[PL] huqzi ossi secci pqic peq wta ñarzi ztezix rtiqih zic row
#
# 12443
# ñraz sax zih xu xkhhi ew ah ro iq wyuvvih jeqh wadzi ix ap zic ro cta zed yozi ix kxsiyod ztez ñiq
#
# ñraz sax zih@DEF[SG.y] xu xkhhi ew ah ro iq wyuvvih jeqh wadzi ix@1-INDEF ap zic ro cta zed yozi ix@1-INDEF kxsiyod ztez ñiq
#
# 12444
# ocozyiqhoz sec ix oxzz-qadi pykrixzi zayizi xiz ed wvuqdhi ñreqpeq zi ñarzi dich wod ziq
#
# ocozyiqhoz sec ix@1-INDEF oxzz-qadi pykrixzi zayizi xiz ed@ET wvuqdhi@demander? ñreqpeq zi@DEF[PL] ñarzi dich wod ziq
#
# 12445
# ro iq weyzahiq wec iq ytejih jeqh peqzo ro pos wtazax sxav ytex wraqizi zix ixi cix xu zteq ro ap wuyh ñrow ro jyoriq ñiq ed dtaq ro pqic secciq ro hoy ah zoxdyi o daydix
#
# ro iq weyzahiq wec iq ytejih jeqh peqzo ro pos wtazax sxav ytex wraqizi zix@DEF[SG.x] ixi cix xu zteq ro ap wuyh ñrow ro jyoriq ñiq ed@ET dtaq ro pqic secciq ro hoy ah zoxdyi o@DANS daydix
#
# 12446
# roy o htixi cod o wkr taq wadzi zqadix wta wsay tid pteqi tiq cozh odixxic ñtiq-ix uzix ah xedix ptaq pah vta tiq
#
# roy o@DANS htixi cod o@DANS wkr@7 taq wadzi zqadix wta wsay tid pteqi tiq cozh odixxic ñtiq-ix uzix ah xedix ptaq pah vta tiq
#
# 12447
# ñiq iq oxhih rayd ro iq xtezh hoy ah wodi ta wraqizi weyzahiqxi
#
#
# 12448
# zqadix dqij zic za o woxi syteq pteqhi zic dixxic yuphix ñixeriq ñtiq-ix ed wahhi zic xiz odix yaxdh jeqhi pqa zix
#
# zqadix dqij zic za o@DANS woxi syteq pteqhi zic dixxic yuphix ñixeriq ñtiq-ix ed@ET wahhi zic xiz odix yaxdh jeqhi pqa zix@DEF[SG.x]
#
# 12449
# zqadix raq ocozyiqhoz oxdix axzix ixz zttiriyix
#
#
# 12450
# ñax dar zic ñriq ix yoyyi vows ed wadzi xtaq o wytaq ih sxayz ciz zix sax o pta yodi wta caxdi vixdi o roy ñari
#
# ñax dar zic ñriq ix@1-INDEF yoyyi@petit vows ed@ET wadzi xtaq o@DANS wytaq ih@INDEF sxayz ciz zix@DEF[SG.x] sax o@DANS pta yodi wta caxdi vixdi o@DANS roy ñari
#
# 12451
# o sax yiri wec peqxicci ñiqqi-q ñeyzi ñiwh ed redx cix iphiq wkr taqw peqytej iq o coxi
#
# o@DANS sax yiri wec peqxicci ñiqqi-q ñeyzi ñiwh ed@ET redx cix iphiq wkr@7 taqw peqytej iq o@DANS coxi
#
# 12452
# zi ctahhi xu ayyi hqi wsqo-r-i ziqiw xarx o ix jed
#
# zi@DEF[PL] ctahhi xu ayyi hqi@3 wsqo-r-i ziqiw xarx o@DANS ix@1-INDEF jed
#
# 12453
# tid roy zed pteqwh dori tiq ix dtazi wadzi zttiriyix ed ñrow o sax dtihhi zix wsay o rtiqi tiqiw idxi ñiqqi-q odix
#
# tid roy zed pteqwh dori tiq ix@1-INDEF dtazi wadzi zttiriyix ed@ET ñrow o@DANS sax dtihhi zix@DEF[SG.x] wsay o@DANS rtiqi tiqiw idxi ñiqqi-q odix
#
# 12454
# zqadix pytet xu jeqh odix ed zi qitwhi ap whiz ciz ziqiw vows ed ñarzi puyzh ev ap vixdi
#
# zqadix pytet xu jeqh odix ed@ET zi@DEF[PL] qitwhi ap whiz ciz ziqiw vows ed@ET ñarzi puyzh ev ap vixdi
#
# 12455
# zi stejhi wod sewh-jaqi sytiziq ed ñreq zi sec ñix yirizi zi o pqkz ed dytizi steqhi o ziqiw idix redx wvowhi ed zqas cix dteqzi ossi xedih exzh
#
# zi@DEF[PL] stejhi wod sewh-jaqi sytiziq ed@ET ñreq zi@DEF[PL] sec ñix yirizi zi@DEF[PL] o@DANS pqkz ed@ET dytizi steqhi o@DANS ziqiw idix redx wvowhi ed@ET zqas cix dteqzi ossi xedih exzh
#
# 12456
# hozix dos ñuqhodh peq zic ed za zi wkr taq xtiwhix raq dtaih jyir zi he peqptiqziyod axdwh cix zix hqizoi hed wadix yih ed wadzi rtiq xu ossi jaxdi
#
# hozix dos ñuqhodh peq zic ed@ET za zi@DEF[PL] wkr@7 taq xtiwhix raq dtaih jyir zi@DEF[PL] he@2 peqptiqziyod axdwh cix zix@DEF[SG.x] hqizoi hed wadix yih ed@ET wadzi rtiq xu ossi jaxdi
#
# 12457
# tid iq ossi hajh jad ap ix redx tid wsay xes dtihhi zix dtazi
#
# tid iq ossi hajh jad ap ix@1-INDEF redx tid wsay xes dtihhi zix@DEF[SG.x] dtazi
#
# 12458
# zi wahhi wod uzi vta caqsix ed zi he ñaxd qodhodxes wrtiqh ciz xtijjih
#
# zi@DEF[PL] wahhi wod uzi vta caqsix ed@ET zi@DEF[PL] he@2 ñaxd qodhodxes wrtiqh ciz xtijjih
#
# 12459
# cixw zi waz ziq sec ix dacciy sexi dtaixzi peqjo ed wvuqdhi ñraz ziq raq o ritix ciz zic
#
# cixw zi@DEF[PL] waz ziq sec ix@1-INDEF dacciy sexi dtaixzi peqjo ed@ET wvuqdhi@demander? ñraz ziq raq o@DANS ritix ciz zic
#
# 12460
# ñraz sax zih xkhhi ah peqhtiyyi tiq zih o sax te zed ossi ñttiyvi ew wadzi zi
#
# ñraz sax zih@DEF[SG.y] xkhhi ah peqhtiyyi tiq zih@DEF[SG.y] o@DANS sax te zed ossi ñttiyvi ew wadzi zi@DEF[PL]
#
# 12461
# ñric riz wraqizi ñux jihq-e sux tiqiw weqd hoy cod
#
#
# 12462
# zi peqhayhi ñixzi xu ah zi o echqixh wkr taq ñarzi htixh zttiriyix
#
# zi@DEF[PL] peqhayhi ñixzi xu ah zi@DEF[PL] o@DANS echqixh wkr@7 taq ñarzi htixh zttiriyix
#
# 12463
# zi ñarzi ñaph puyzh ev ap vixdi cix hoy dixdtiyz ñarzi zi peqwsqirih wod hoy ñac ed raq xu ñaxw ciz ñuz ed ñtaq ñrow zi ossi suxxi dtihhi ix dtazi
#
# zi@DEF[PL] ñarzi ñaph puyzh ev ap vixdi cix hoy dixdtiyz ñarzi zi@DEF[PL] peqwsqirih wod hoy ñac ed@ET raq xu ñaxw ciz ñuz ed@ET ñtaq ñrow zi@DEF[PL] ossi suxxi dtihhi ix@1-INDEF dtazi
#
# 12464
# ñrow tid wsay suxxi ñttiyvi tiq cta ix ap tiq dta uz o wserix wadzi zix dacyi ziq secciq ñax hoy ix waccix-w-hkqhih syov-virtid ziq wiq uz wec ih yoyyi ñuw
#
# ñrow tid wsay suxxi ñttiyvi tiq cta ix@1-INDEF ap tiq dta uz o@DANS wserix wadzi zix@DEF[SG.x] dacyi ziq secciq ñax hoy ix@1-INDEF waccix-w-hkqhih syov-virtid ziq wiq uz wec ih@INDEF yoyyi@petit ñuw
#
# 12465
# ziq wsay ñax dta oxz wta roy ñax jyori ñtuyvih
#
#
# 12466
# zih roy wtactixz ossi xkhhi xedih htixshi zi he jizqterizi ed jyir wozzixzi ziquzi cix zix hqizoi qitwhi wod ed dos oxz o wserix hoy ñax sec hoy syovviñ-khhix
#
# zih@DEF[SG.y] roy wtactixz ossi xkhhi xedih htixshi zi@DEF[PL] he@2 jizqterizi ed@ET jyir wozzixzi ziquzi cix zix@DEF[SG.x] hqizoi qitwhi wod ed@ET dos oxz o@DANS wserix hoy ñax sec hoy syovviñ-khhix
#
# 12467
# ziqoxzi waz ix tiyzdacciy sexi
#
# ziqoxzi waz ix@1-INDEF tiyzdacciy sexi
#
# 12468
# zih raq zttiriyixw jizwhiceq ed ñux wvuqdhi ñreq ñax sec pqa ed ñraz ñax royyi ñiq
#
# zih@DEF[SG.y] raq zttiriyixw jizwhiceq ed@ET ñux wvuqdhi@demander? ñreq ñax sec pqa ed@ET ñraz ñax royyi ñiq
#
# 12469
# ñax peqhayhi ñixzi ayh ñraz ziq raq wsih ed za ñux wkxhiw dezh ec ñax pos ñux exzh ap ñac ed wadzi ah ñux royyi ñttiyvi ñac
#
# ñax peqhayhi ñixzi ayh ñraz ziq raq wsih ed@ET za ñux wkxhiw dezh ec ñax pos ñux exzh ap ñac ed@ET wadzi ah ñux royyi ñttiyvi ñac
#
# 12470
# ñux ytephizi ix wheq whix ev ed wadzi sqkj xiz o stiyziqix ñiq wta sax zu ñteqi ayh ñraz ziq jyoriq wadh ñiqevvi
#
# ñux ytephizi ix@1-INDEF wheq whix ev ed@ET wadzi sqkj xiz o@DANS stiyziqix ñiq wta sax zu ñteqi ayh ñraz ziq jyoriq wadh ñiqevvi
#
# 12471
# yod daxwsi whoyyi uzix ah qteqi zod
#
#
# 12472
# xtaq zqadix wta secciq roy tid wvteqdi ñac ec dtazix ed cod peqhti-yyiq ñax ayhoxd
#
# xtaq zqadix wta secciq roy tid wvteqdi ñac ec dtazix ed@ET cod peqhti-yyiq ñax ayhoxd
#
# 12473
# ytid wta ctiqsi hoy ñraz ñax wraqiq
#
#
# 12474
# riz cozxah sec zqadix ed royyi ñari caz
#
# riz cozxah sec zqadix ed@ET royyi ñari caz
#
# 12475
# jizwhiceziqix ztissizi jeqz ed wahhi caz ed zqossi pqic ed zi wvowhi ed zqas qodhod peqx-tetizi
#
# jizwhiceziqix ztissizi jeqz ed@ET wahhi caz ed@ET zqossi pqic ed@ET zi@DEF[PL] wvowhi ed@ET zqas qodhod peqx-tetizi
#
# 12476
# o wachayixw ytej wvuqdhi ñux ñreqzax zadix raq dtaih ed ñreq caxdi wttiyi ñax ñarzi ptaih pah vta
#
# o@DANS wachayixw ytej wvuqdhi@demander? ñux ñreqzax zadix raq dtaih ed@ET ñreq caxdi wttiyi ñax ñarzi ptaih pah vta
#
# 12477
# o zad ñaq tid ossi qodhod ñaph ñiyz ciz cod wraqizi ñax cix tid riz za ah tid xu wossiqh ptaq pah o hqi weyzahiq
#
# o@DANS zad ñaq tid ossi qodhod ñaph ñiyz ciz cod wraqizi ñax cix tid riz za ah tid xu wossiqh ptaq pah o@DANS hqi@3 weyzahiq
#
# 12478
# weyzahiq wadzi zix dacyi zih iq xedyi idxi pkqi
#
# weyzahiq wadzi zix@DEF[SG.x] dacyi zih@DEF[SG.y] iq xedyi idxi pkqi
#
# 12479
# zi sax wtactixz wyovvi pqa zod ixzxu
#
# zi@DEF[PL] sax wtactixz wyovvi pqa zod ixzxu
#
# 12480
# xit zih sax zi ossi wraqizi zttiriyix ñtaxyodh tid doriq zic ix dtazi wec zi ayzqod sax dtihhi
#
# xit zih@DEF[SG.y] sax zi@DEF[PL] ossi wraqizi zttiriyix ñtaxyodh tid doriq zic ix@1-INDEF dtazi wec zi@DEF[PL] ayzqod sax dtihhi
#
# 12481
# ñraz iq zih za peq ix
#
# ñraz iq zih@DEF[SG.y] za peq ix@1-INDEF
#
# 12482
# wvuqdhi ñux
#
# wvuqdhi@demander? ñux
#
# 12483
# zih wsay tid wtactixz wodi zod wraqizi ñax tid wvte-qd-iq zic ñraz peq ix whid zi ptaq ñiq ed wta wsay zi wraqi ah uzi o xeqzñarih yoddiq ziq ix ztez ñarsah ih ñraypowsiqojjix wsay zi jqudi wec wsi ed ix dacciy ñuy ñiwhi-ñer wec dyaw
#
# zih@DEF[SG.y] wsay tid wtactixz wodi zod wraqizi ñax tid wvte-qd-iq zic ñraz peq ix@1-INDEF whid zi@DEF[PL] ptaq ñiq ed@ET wta wsay zi@DEF[PL] wraqi ah uzi o@DANS xeqzñarih yoddiq ziq ix@1-INDEF ztez ñarsah ih@INDEF ñraypowsiqojjix wsay zi@DEF[PL] jqudi wec wsi ed@ET ix@1-INDEF dacciy ñuy ñiwhi-ñer wec dyaw
#
# 12484
# za zttiriyix raq dtaih o wixd ytephizi zix dacyi jizwhiceq whixix ev ed weyzahix sqaryizi pqic
#
# za zttiriyix raq dtaih o@DANS wixd ytephizi zix@DEF[SG.x] dacyi jizwhiceq whixix ev ed@ET weyzahix sqaryizi pqic
#
# 12485
# ñaq zu peqwh-taih zih ayhwaccix
#
# ñaq zu peqwh-taih zih@DEF[SG.y] ayhwaccix
#
# 12486
# wvuqdhi ñux
#
# wvuqdhi@demander? ñux
#
# 12487
# ta xu wsay tid xes syaqi cod wraqizi ñax
#
#
# 12488
# ñax ctahhi xu sqaryi uz az roxzuih ed wskxzi wod ix axzix rit ñtic hoy woxi sacciqahiq
#
# ñax ctahhi xu sqaryi uz az roxzuih ed@ET wskxzi wod ix@1-INDEF axzix rit ñtic hoy woxi sacciqahiq
#
# 12489
# ñax peqhayhi zic xu ñreqzax zttiriyix raq jyirih xaqqih ap wox dacyi jizwhiceq wta ah ñax xu rozwhi ytew-xoxd-ix vta dtazix
#
#
# 12490
# za jyir zi ayyiwaccix dyazi hed vowsi-xi pqic ed sxayzizi ciz zic wta vixdixi wvqaxd ed ñevvizi vta teqzix
#
# za jyir zi@DEF[PL] ayyiwaccix dyazi hed vowsi-xi pqic ed@ET sxayzizi ciz zic wta vixdixi wvqaxd ed@ET ñevvizi vta teqzix
#
# 12491
# za zi wkr taq raq peqjo sec zttiriyix ciz jedix rowhi zic ziqiw uxzi-qwsqophiq ed wadzi tid roy xu hadi tiq ciz hoy ñiyrizi ed ziq wsay o pta xedih ah wvowi
#
# za zi@DEF[PL] wkr@7 taq raq peqjo sec zttiriyix ciz jedix rowhi zic ziqiw uxzi-qwsqophiq ed@ET wadzi tid roy xu hadi tiq ciz hoy ñiyrizi ed@ET ziq wsay o@DANS pta xedih ah wvowi
#
# 12492
# sax o dtihhi ñraz peq ix whid o wsay ñari wta wsay o rtiqi pqo ed erix o stejih pta yer hoy ah jiñeyzi vowsi-xi
#
# sax o@DANS dtihhi ñraz peq ix@1-INDEF whid o@DANS wsay ñari wta wsay o@DANS rtiqi pqo ed@ET erix o@DANS stejih pta yer hoy ah jiñeyzi vowsi-xi
#
# 12493
# uzi o xeqzñarih yoddiq ziq ix ztez ñarsah zih iq riy zix ro wsay ñari wadzi zix pteqwhi
#
# uzi o@DANS xeqzñarih yoddiq ziq ix@1-INDEF ztez ñarsah zih@DEF[SG.y] iq riy zix@DEF[SG.x] ro wsay ñari wadzi zix@DEF[SG.x] pteqwhi
#
# 12494
# zttiriyix qtecci-zi wod dxari-xh ed wvuqdhi zix axzix ñraz peq ix wsi wsay o wvowi ciz
#
# zttiriyix qtecci-zi wod dxari-xh ed@ET wvuqdhi@demander? zix@DEF[SG.x] axzix ñraz peq ix@1-INDEF wsi wsay o@DANS wvowi ciz
#
# 12495
# ih ñraypowsiqojjix wraqizi zix axzix
#
# ih@INDEF ñraypowsiqojjix wraqizi zix@DEF[SG.x] axzix
#
# 12496
# zttiriyix wsaq xedyi wyicci axwodhiq ed jquccizi rqizh riz o edwta ñraz o wsay zqossi ap
#
# zttiriyix wsaq xedyi wyicci axwodhiq ed@ET jquccizi rqizh riz o@DANS edwta ñraz o@DANS wsay zqossi ap
#
# 12497
# wvuqdhi ñax zix hqizoi
#
# wvuqdhi@demander? ñax zix@DEF[SG.x] hqizoi
#
# 12498
# ro wsay jqudi ix dacciy uzñuyih ñiwhi-ñer hoy roxdyaw wraqizi zix hqizoi
#
# ro wsay jqudi ix@1-INDEF dacciy uzñuyih ñiwhi-ñer hoy roxdyaw wraqizi zix@DEF[SG.x] hqizoi
#
# 12499
# zttiriyix pytet wsqodixzi ap whiz peq xu ñarzi ñax ossi ciqi cadh eriq zic
#
#
# 12500
# weyzahiqxi jiñeyzh vowsi-xi sxayzizi wta caxdi vixdi pqic zi ykwh-izi ed yirizi peqx-tetizi ed dyazi hoy zi ztezi
#
# weyzahiqxi jiñeyzh vowsi-xi sxayzizi wta caxdi vixdi pqic zi@DEF[PL] ykwh-izi ed@ET yirizi peqx-tetizi ed@ET dyazi hoy zi@DEF[PL] ztezi

# %% [markdown]
# ## Concordances

# %% [markdown]
# ### Texte brut

# %%
concordance=u" sexd"
fenetre=50

blancGauche=concordance.startswith(" ")
blancDroite=concordance.endswith(" ")

dfConcordance=pd.DataFrame(columns=["conte","num","gauche",concordance,"droite"])
p=re.compile("(.*)(%s)(.*)"%concordance,re.U)
for nLine,line in enumerate(texteBrut[:]):
    occurrences=re.findall(p,line)
    if occurrences:
        for occurrence in occurrences:
            if len(occurrence[0])>fenetre:
                gauche=occurrence[0][-fenetre:]
            else:
                gauche=occurrence[0]
            if not blancGauche and gauche and gauche[-1]!=" ":
                gauche=gauche+"-"
            
            if len(occurrence[2])>fenetre:
                droite=occurrence[2][:fenetre]
            else:
                droite=occurrence[2]
            if not blancDroite and droite and droite[0]!=" ":
                droite="-"+droite

            dfLine={"conte":lineConte[nLine],"num":nLine+1,"gauche":gauche,concordance:occurrence[1],"droite":droite}
            dfConcordance=dfConcordance.append(dfLine,ignore_index=True)

# dfStyler=dfConcordance.style.set_properties(subset=[concordance],**{'font-weight': 'bold'})
dfStyler=dfConcordance.style.set_properties(subset=['gauche'],**{'text-align': 'right'})
dfStyler=dfConcordance.style.set_properties(subset=['droite'],**{'text-align': 'left'}).hide_index()
display(dfStyler)
# Out:
# <style  type="text/css" >
#     #T_66855da8_74c3_11ed_ab7f_322aba482e74row0_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row1_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row2_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row3_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row4_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row5_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row6_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row7_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row8_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row9_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row10_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row11_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row12_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row13_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row14_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row15_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row16_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row17_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row18_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row19_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row20_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row21_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row22_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row23_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row24_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row25_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row26_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row27_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row28_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row29_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row30_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row31_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row32_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row33_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row34_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row35_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row36_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row37_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row38_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row39_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row40_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row41_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row42_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row43_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row44_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row45_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row46_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row47_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row48_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row49_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row50_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row51_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row52_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row53_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row54_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row55_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row56_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row57_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row58_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row59_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row60_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row61_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row62_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row63_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row64_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row65_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row66_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row67_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row68_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row69_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row70_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row71_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row72_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row73_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row74_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row75_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row76_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row77_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row78_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row79_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row80_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row81_col4 {
#             text-align:  left;
#         }    #T_66855da8_74c3_11ed_ab7f_322aba482e74row82_col4 {
#             text-align:  left;
#         }    #T_66855da8_

# %% [raw]
# conte="136"
# if conte in tradContes:
#     print "\n\n".join(conteLines[conte])

# %% [markdown]
# ### Texte glosé

# %%
concordance=u"docteur"
fenetre=50

blancGauche=concordance.startswith(" ")
blancDroite=concordance.endswith(" ")

dfConcordance=pd.DataFrame(columns=["conte","num","gauche",concordance,"droite"])
p=re.compile("(.*)(%s)(.*)"%concordance,re.U)
for nLine,line in enumerate(texteGloss[:]):
    occurrences=re.findall(p,line)
    if occurrences:
        for occurrence in occurrences:
            if len(occurrence[0])>fenetre:
                gauche=occurrence[0][-fenetre:]
            else:
                gauche=occurrence[0]
            if not blancGauche and gauche and gauche[-1]!=" ":
                gauche=gauche+"-"
            
            if len(occurrence[2])>fenetre:
                droite=occurrence[2][:fenetre]
            else:
                droite=occurrence[2]
            if not blancDroite and droite and droite[0]!=" ":
                droite="-"+droite

            dfLine={"conte":lineConte[nLine],"num":nLine+1,"gauche":gauche,concordance:concordance,"droite":droite}
            dfConcordance=dfConcordance.append(dfLine,ignore_index=True)

# dfStyler=dfConcordance.style.set_properties(subset=[concordance],**{'font-weight': 'bold'})
dfStyler=dfConcordance.style.set_properties(subset=['gauche'],**{'text-align': 'right'})
dfStyler=dfConcordance.style.set_properties(subset=['droite'],**{'text-align': 'left'}).hide_index()
display(dfStyler)
# Out:
# <style  type="text/css" >
#     #T_af813a99_74a8_11ed_b498_322aba482e74row0_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row1_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row2_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row3_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row4_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row5_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row6_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row7_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row8_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row9_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row10_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row11_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row12_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row13_col4 {
#             text-align:  left;
#         }    #T_af813a99_74a8_11ed_b498_322aba482e74row14_col4 {
#             text-align:  left;
#         }</style><table id="T_af813a99_74a8_11ed_b498_322aba482e74" ><thead>    <tr>        <th class="col_heading level0 col0" >conte</th>        <th class="col_heading level0 col1" >num</th>        <th class="col_heading level0 col2" >gauche</th>        <th class="col_heading level0 col3" >docteur</th>        <th class="col_heading level0 col4" >droite</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_af813a99_74a8_11ed_b498_322aba482e74row0_col0" class="data row0 col0" >098</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row0_col2" class="data row0 col2" >098 zesheq@-</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row0_col3" class="data row0 col3" >docteur</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row0_col4" class="data row0 col4" >-[nom] ayrozixzi@universel[adj]</td>
#             </tr>
#             <tr>
#                                 <td id="T_af813a99_74a8_11ed_b498_322aba482e74row1_col0" class="data row1 col0" >098</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row1_col1" class="data row1 col1" >3</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row1_col2" class="data row1 col2" > jqtixzi oxz hoy jkix ed weydhi zih hoy ix zeshiq@-</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row1_col3" class="data row1 col3" >docteur</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row1_col4" class="data row1 col4" >-[nom-spec]</td>
#             </tr>
#             <tr>
#                                 <td id="T_af813a99_74a8_11ed_b498_322aba482e74row2_col0" class="data row2 col0" >098</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row2_col1" class="data row2 col1" >4</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row2_col2" class="data row2 col2" >hi ed zqas pos ñax ykwh hoy edwta ah rtiqi zesheq@-</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row2_col3" class="data row2 col3" >docteur</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row2_col4" class="data row2 col4" >-[nom]</td>
#             </tr>
#             <tr>
#                                 <td id="T_af813a99_74a8_11ed_b498_322aba482e74row3_col0" class="data row3 col0" >098</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row3_col1" class="data row3 col1" >5</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row3_col2" class="data row3 col2" >i ixziyod ec ñax ossi suxxi ytiqi ah jyori zesheq@-</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row3_col3" class="data row3 col3" >docteur</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row3_col4" class="data row3 col4" >-[nom]</td>
#             </tr>
#             <tr>
#                                 <td id="T_af813a99_74a8_11ed_b498_322aba482e74row4_col0" class="data row4 col0" >098</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row4_col1" class="data row4 col1" >6</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row4_col2" class="data row4 col2" >zih iq wtactixz xich xes wraqizi zesheqix@-</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row4_col3" class="data row4 col3" >docteur</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row4_col4" class="data row4 col4" >-[nom-aut]</td>
#             </tr>
#             <tr>
#                                 <td id="T_af813a99_74a8_11ed_b498_322aba482e74row5_col0" class="data row5 col0" >098</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row5_col1" class="data row5 col1" >9</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row5_col2" class="data row5 col2" >zoi wsay zu vta ih wsoyh yazi cayi ñiq jeq zesheq@-</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row5_col3" class="data row5 col3" >docteur</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row5_col4" class="data row5 col4" >-[nom] ayrozixzi@universel[adj] ed wtihhi zih ev er</td>
#             </tr>
#             <tr>
#                                 <td id="T_af813a99_74a8_11ed_b498_322aba482e74row6_col0" class="data row6 col0" >098</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row6_col1" class="data row6 col1" >11</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row6_col2" class="data row6 col2" >za ñax ñarzi rtiqih zesheq@-</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row6_col3" class="data row6 col3" >docteur</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row6_col4" class="data row6 col4" >-[nom] o xedix hoz jyir ziq whttayih xedyi vixdi pq</td>
#             </tr>
#             <tr>
#                                 <td id="T_af813a99_74a8_11ed_b498_322aba482e74row7_col0" class="data row7 col0" >098</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row7_col1" class="data row7 col1" >12</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row7_col2" class="data row7 col2" >ziq ziq o yaxz-wjkix jeizi ix caxz wec ñiz zesheq@-</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row7_col3" class="data row7 col3" >docteur</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row7_col4" class="data row7 col4" >-[nom] ayrozixzi@universel[adj] ed ayhwta ctahhi ro</td>
#             </tr>
#             <tr>
#                                 <td id="T_af813a99_74a8_11ed_b498_322aba482e74row8_col0" class="data row8 col0" >098</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row8_col1" class="data row8 col1" >13</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row8_col2" class="data row8 col2" >y jexzix@paysan[nom] ed wvuqdhi ec ñax raq zesheq@-</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row8_col3" class="data row8 col3" >docteur</td>
#                         <td id="T_af813a99_74a8_11ed_b498_322aba482e74row8_col4" class="data row8 col4" >-[nom] ayrozixzi@universel[adj]</td>
#             </tr>
#             <tr>

# %% [markdown]
# -----

# %% [markdown]
# ## Calculer une hiérarchie de signatures morphologiques
# Les signatures morphologiques de Linguistica correspondent à un paradigme flexionnel réduit aux variantes attestées dans le corpus pour un même lexème. Hiérarchiser les signatures permet d'étudier les regroupements possibles entre paradigmes partiels.

# %%
morphGraph=nx.Graph()
sigGraph=nx.DiGraph()

# %%
for sig in lxaCorpus.signatures():
    for a,b in combinations(sig,2):
        if (a,b) not in morphGraph.edges:
            morphGraph.add_edge(a,b,weight=1)
        else:
            morphGraph[a][b]["weight"]+=1

# %%
options = {
    "font_size": 12,
    "node_size": 750,
    "node_color": "white",
    "edgecolors": "black",
    "linewidths": 1,
    "width": 1,
    }
pos = nx.spring_layout(morphGraph,k=2,iterations=150,seed=2363)

fig = plt.figure(1, figsize=(20, 20), dpi=72)
nx.draw(morphGraph,pos,with_labels=True,**options)

# Set margins for the axes so that nodes aren't clipped
ax = plt.gca()
ax.margins(0.20)
plt.show()

# %% [markdown]
# ### Cliques maximales parmi les signatures

# %%
maxCliques=list(nx.find_cliques(morphGraph))
# maxCliques

# %%
dCliques={tuple(c):set() for c in maxCliques}
for sig in lxaCorpus.signatures():
    sSig=set(sig)
    for clique in dCliques:
        sClique=set(clique)
        if sSig.intersection(sClique)==sSig:
            dCliques[clique].add(sig)
print "Les cliques maximales et leurs sous-cliques sont :"
print
for cMax,lCliques in dCliques.iteritems():
    if len(lCliques)>1:
        print cMax,":"
        print "\t",list(lCliques)
    else:
        print cMax
    print

# %%
sigMax={}
for k,l in dCliques.iteritems():
    for e in l:
        if e not in sigMax:
            sigMax[e]=set()
        sigMax[e].add(k)
sigMax[(u'NULL', u'ix')]

# %%
lxaCorpus.stems()
lxaCorpus.affixes()
lxaCorpus.signatures_to_stems()[(u'NULL', u'ix')]

# %%
lxaCorpus.signatures_to_words()
lxaCorpus.affixes_to_signatures()

# %%
lxaCorpus.stems_to_signatures()["zesheq"]

# %%
lxaCorpus.words_in_signatures()
lxaCorpus.words_to_signatures()
lxaCorpus.words_to_sigtransforms()

# %% [markdown]
# ## Words manifolds and syntactic word neighborhood

# %%
# sorted(lxaCorpus.words_to_neighbors().keys())
lxaCorpus.words_to_neighbors()["jexzix"]

# %%
network=lxaCorpus.neighbor_graph()
# plt.figure(1,figsize=(100,100))
# nx.draw(network)
# plt.show()

# %%
lxaCorpus.words_to_contexts()

# %% [markdown]
# ## Phonology

# %%
lxaCorpus.phone_unigram_counter()
lxaCorpus.phone_bigram_counter()
lxaCorpus.phone_trigram_counter()
