# %%
import codecs,unidecode,yaml,glob,os,shutil,re
import itertools as it
import numpy as np
import pandas as pd
# print(pd.__version__)

# %%
nQuizz=5
fMajeure=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Majeure.csv"
fMineure=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Mineure.csv"
fCM=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/CM.csv"
fAliasQDLE=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Quizz-Alias.yaml"
fQuizzoodle=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Quizz%02d.csv"%nQuizz
fNotes=fQuizzoodle.replace(u".csv",u"-Notes.csv")

# %%
'''https://stackoverflow.com/a/35491326/3986209'''
def invert_dict(d): 
    inverse = dict() 
    for key in d: 
        # Go through the list that is saved in the dict:
        for item in d[key]:
            # Check if in the inverted dict the key exists
            if item not in inverse: 
                # If not create a new list
                inverse[item] = [key] 
            else: 
                inverse[item].append(key) 
    return inverse

# %% [markdown]
# # Lecture des données

# %%
try:
    with codecs.open(fAliasQDLE, 'r', encoding="utf8") as inFile:
        correspondances=yaml.safe_load(inFile)
    alias=correspondances["alias2etu"]
except:
    alias={}
alias
# Out:
# {'ALINA': ['433401'],
#  'Agathe / Liliana': ['430440', '430952'],
#  'Agathe Martin': ['430440'],
#  'Alex Helvert': ['380824'],
#  'Alice LOOF': ['427886'],
#  'Alima Gassama': ['418366'],
#  'Alissa Bessettes': ['429623'],
#  'Alix DEBUR': ['427449'],
#  u'Ali\xe9nor Riou': ['428930'],
#  'Amandine B': ['429252'],
#  'Amelie Mitlehner': ['433485'],
#  u'Am\xe9lie rochefort': ['432360'],
#  u'Ana\xeblle DINA-SAME': ['432151'],
#  'Auriault justin': ['430711'],
#  'Axel Meunier': ['429855'],
#  'BENTO Elena': ['428999'],
#  u'BOUSSARD L\xe9a': ['428452'],
#  'Baptiste phelip': ['397583'],
#  u'Barsacq Th\xe9o': ['403123'],
#  'Berloin Amandine': ['429252'],
#  'Bertrand Sascha': ['419149'],
#  'Blanc Sheryl': ['427234'],
#  'Bonnet Nathan': ['433074'],
#  u'Bordelais Cl\xe9a': ['429396'],
#  'CHADDOU hilel': ['430892'],
#  'CLOCHET': ['427924'],
#  'CLOCHET LYSON': ['427924'],
#  'CLOCHET lyson': ['427924'],
#  'Camille Villechalanne': ['429928'],
#  'Carla': ['433437'],
#  'Chaigne Elise': ['429273'],
#  'Chihiro Kamikanda': ['424085'],
#  'Clara LEGER': ['385051'],
#  'Clochet Lyson': ['427924'],
#  'Cloe Destaminil': ['427625'],
#  'Cout. Elsa': ['432447'],
#  'Coutard Elsa': ['432447'],
#  'DJUNGA LENYAMA Esther': ['433322'],
#  'DJUNGALENYAMA': ['433322'],
#  'Daniela Gomes': ['427433'],
#  'Daniela Gomes et Kiara Dugas': ['432817', '427433'],
#  'Darriba Anna': ['429228'],
#  'De Girardi Leelou': ['431463'],
#  'Dehoulle Fanny': ['396374'],
#  'Delalande Laly': ['430635'],
#  u'Depluche Le\xefla': ['412746'],
#  'Detrie Margot, Esperon Astrid': ['428233', '433135'],
#  u'Dina-Same Ana\xeblle': ['432151'],
#  u'D\xe9trie Margot': ['428233'],
#  u'D\xe9trie Margot, Enjalbal Emma': ['429793', '428233'],
#  u'D\xe9trie Margot, Esperon Astrid': ['433135', '428233'],
#  'EL ASRI Safaa': ['426688'],
#  'ESPERON Astrid': ['433135'],
#  'Edwina Segaud': ['426706'],
#  'Eliane Megarus': ['413748'],
#  'Eliazord Priscilla': ['432298'],
#  'Elizazord Priscilla': ['432298'],
#  'Elysa Ravet': ['431986'],
#  'Elysa Ravet et Mariah Gotter': ['432488', '431986'],
#  'Elysa Ravet, Mariah Gotter': ['432488', '431986'],
#  'Emilie Escapoulade': ['432459'],
#  'Emma enjalbal ettouil sahra': ['431767', '429793'],
#  'Emma enjalbal sahra ettouil': ['429793', '431767'],
#  'Enjalbal emma': ['429793'],
#  'Erwan LECUL': ['426946'],
#  'Escapoulade Emilie': ['432459'],
#  'Esclave Jason Silva': ['431560'],
#  'Estelle Veau': ['428170'],
#  'Estelle veau': ['428170'],
#  'Eva DELAHODDE': ['427303'],
#  'FRECHET Manon': ['429499'],
#  'Fall Mariem': ['429625'],
#  'Frechet Manon, Klopstein Emma': ['429499', '428316'],
#  'Gaelle Dubroca': ['382457'],
#  'Gaelle Lamarque': ['427542'],
#  'Gaudin': ['428033'],
#  u'Ga\xeblle Dub': ['382457'],
#  u'Ga\xeblle Dubroca': ['382457'],
#  u'Ga\xeblle Jegorel': ['431199'],
#  u'Ga\xeblle Jgl': ['431199'],
#  u'Ga\xeblle Lamarque': ['427542'],
#  'Ghenima': ['432082'],
#  'Heloise Gouardes Arazola': ['433055'],
#  'Hongyi': ['433672'],
#  u'H\xe9lo\xefse Gouardes Arazola': ['433055'],
#  u'H\xe9l\xe8ne': ['428168'],
#  u'H\xe9l\xe8ne Rougier': ['428168'],
#  'Ilona TECHER': ['432270'],
#  'Jason Silva': ['431560'],
#  'Jeanne robin': ['431378'],
#  'Joana Fehr': ['433345'],
#  'Jonatan Mangel': ['429540'],
#  'Jonatan-Mangel': ['429540'],
#  'Julie Boatto': ['430230'],
#  'Katharina Froitzheim': ['433364'],
#  'Kiara Dugas': ['432817'],
#  'Kristin': ['433205'],
#  'LECUL Erwan': ['426946'],
#  'LEDROIT Katell': ['427577'],
#  'LOVRIC': ['433447'],
#  'Labille Romane': ['431590'],
#  'Labille romane': ['431590'],
#  'Laly DELALANDE': ['430635'],
#  'Laly Delalande': ['430635'],
#  'Laly Dugue': ['427109'],
#  u'Laly Dugu\xe9': ['427109'],
#  'Laurine Biglione': ['431375'],
#  'Laurine biglione': ['431375'],
#  u'La\xebtitia Capelo': ['427987'],
#  u'Lebidan Ga\xebl': ['427403'],
#  'Leelou De Girardi': ['431463'],
#  'Lemoine Charline': ['429034'],
#  'Liliana Correia Santos': ['430952'],
#  'Lisa Carlin': ['428292'],
#  'Lola Leblois': ['429694'],
#  'LolaKaci': ['426735'],
#  'Louann le corf': ['431735'],
#  'Lucy Birkett': ['433225'],
#  'Luna Lombard': ['432206'],
#  'Maeve Shea': ['433612'],
#  'Maewenn Gaudin': ['428033'],
#  'Mangel Jonatan': ['429540'],
#  'Manon Baranger': ['431129'],
#  'Manon Baranger 2': ['431129'],
#  'Manon bout': ['428729'],
#  'Manon bout manon frechet': ['428729', '429499'],
#  'Maria SAINDOU': ['411936'],
#  'Mariah Gotter': ['432488'],
#  'Marion Calise': ['431451'],
#  'Marius Reculet': ['426755'],
#  'Mathis Monteiro': ['427574'],
#  'Matisse ROGER': ['433263'],
#  'Maureen viard': ['432229'],
#  'Mazieux Coraline': ['430747'],
#  'MeresseCapucine,MignotCamille': ['431197', '432314'],
#  u'Mesquita L\xe9o': ['426732'],
#  u'Monge Cl\xe9mence': ['428617'],
#  u'Monge Cl\xe9mence et Estelle Veau': ['428617', '428170'],
#  'Moreau Coleen': ['426930'],
#  u'Moreau Coleen et Riou Ali\xe9nor': ['426930', '428930'],
#  'Morgan rabou': ['419808'],
#  'Morgane Roose': ['431114'],
#  'Naida': ['417479'],
#  'Nathan bonnet': ['433074'],
#  u'Na\xefda': ['417479'],
#  'Noriko ROBINSON': ['428114'],
#  'Noriko Robinson': ['428114'],
#  'Phelip Baptiste': ['397583'],
#  'Phelip baptiste': ['397583'],
#  'Pohu Emma-Lou': ['426820'],
#  'Posso Manon': ['432712'],
#  'Prevost': ['432779'],
#  u'Pr\xe9vost Mathilde': ['432779'],
#  'ROBINSON Noriko': ['428114'],
#  'ROGER Matisse': ['433263'],
#  u'Ra\xfcl Sim\xf3': ['433618'],
#  'Robinson Noriko': ['428114'],
#  'Romain Dubois': ['417953'],
#  'Roukaya': ['416084'],
#  'Ruby Fischer': ['433357'],
#  'SHADRINA Yelyzaveta': ['425485'],
#  'Sila Karaketir': ['427702'],
#  u'Soilihi N\xe9mati': ['413350'],
#  'Ugo Gameiro': ['429545'],
#  'Ugo gameiro': ['429545'],
#  u'VERHEYDE Chlo\xe9': ['432826'],
#  'VERHEYDE chloe': ['432826'],
#  'Vadim Olivan': ['414257'],
#  'Veau Estelle': ['428170'],
#  'Velleine Marie': ['430513'],
#  'Yelyzaveta Shadrina': ['425485'],
#  'csrhiri001': ['434189'],
#  'de girardi leelou': ['431463'],
#  'elea hirigoyen': ['428197'],
#  'isa g': ['433367'],
#  'jeanne massias': ['431183'],
#  'kiara dugas': ['432817'],
#  'lola lebloid': ['429694'],
#  'lola vignaud': ['415342'],
#  'lucie monteyne': ['429412'],
#  'lucie monteyne amelie roche': ['429412', '432360'],
#  'lucie monteyne, amelie roche': ['429412', '432360'],
#  'luna lombard': ['432206'],
#  u'l\xe9a yousfi': ['429397'],
#  'marilyne kouame': ['432548'],
#  'maryline kouame': ['432548'],
#  'massias': ['431183'],
#  'massias , delahodde': ['427303', '431183'],
#  'massias,  duplan, delahodde': ['431183', '431361', '427303'],
#  'maureen viard': ['432229'],
#  'mila.carruezco': ['433803'],
#  'nell duplan': ['431361'],
#  'pointemma': ['430808'],
#  'quisha': ['433411'],
#  'sheryl blanc': ['427234'],
#  'sheryl blanc, marius reculet': ['427234', '426755'],
#  'super rabou': ['419808']}

# %%
len(alias)
# Out:
# 197

# %%
colCM=[u"id",u"nom",u"prénom",u"email",u"ine"]
colQuizz=["pseudo","points","temps"]

try:
    dfCM=pd.read_csv(filepath_or_buffer=fCM,sep="\t",encoding="utf8",header=0,names=colCM)
    lQuizz=pd.read_csv(filepath_or_buffer=fQuizzoodle,sep=";",encoding="utf8",header=0,names=colQuizz)
    lQuizz.pseudo=lQuizz.pseudo.str.strip()
except:
    dfCM=None
    lQuizz=None

# %%
# lQuizz, dfCM

# %% [markdown]
# # Listage des alias

# %%
dfCM["PN"]=dfCM[u"prénom"].str.lower().str.strip()+" "+dfCM[u"nom"].str.lower().str.strip()
dfCM["NP"]=dfCM[u"nom"].str.lower().str.strip()+" "+dfCM[u"prénom"].str.lower().str.strip()
dfCM
# Out:
#          id               nom            prénom  \
# 0    415923             AKKUL          EMMANUEL
# 1    432822            AUBERT              EMMA
# 2    430711          AURIAULT            JUSTIN
# 3    431129          BARANGER             MANON
# 4    403123           BARSACQ              THEO
# 5    433205            BEFORT           KRISTIN
# 6    428999             BENTO             ELENA
# 7    429252           BERLOIN          AMANDINE
# 8    419149          BERTRAND            SASCHA
# 9    429623         BESSETTES            ALISSA
# 10   431375          BIGLIONE           LAURINE
# 11   433225           BIRKETT              LUCY
# 12   427234             BLANC            SHERYL
# 13   430230            BOATTO             JULIE
# 14   433074            BONNET            NATHAN
# 15   429396         BORDELAIS              CLEA
# 16   433229           BOSSLET            AMELIE
# 17   431767  BOUDEMIA ETTOUIL             SAHRA
# 18   428452          BOUSSARD               LEA
# 19   428729              BOUT             MANON
# 20   415694           BREUILS          MATHILDE
# 21   335539   BRICOUT-TEITGEN               EMI
# 22   431451            CALISE            MARION
# 23   427987            CAPELO          LAETITIA
# 24   428292     CARLIN-ROBERT              LISA
# 25   433803         CARRUEZCO              MILA
# 26   430916         CASTAIGNA            THOMAS
# 27   430892           CHADDOU             HILEL
# 28   417479          CHAHIROU             NAIDA
# 29   429273           CHAIGNE             ELISE
# ..      ...               ...               ...
# 129  428114          ROBINSON            NORIKO
# 130  432360         ROCHEFORT            AMELIE
# 131  433263             ROGER           MATISSE
# 132  431114      ROOSE-THEMYR           MORGANE
# 133  428168           ROUGIER            HELENE
# 134  431944           SAILHAN             LUCIE
# 135  411936           SAINDOU             MARIA
# 136  428798      SAINT-GIRONS            SATINE
# 137  429633           SANCHEZ              LOLA
# 138  430001           SAUBION              LISE
# 139  426706            SEGAUD            EDWINA
# 140  425485          SHADRINA        YELYZAVETA
# 141  433612              SHEA  MAEVE FITZGERALD
# 142  431560             SILVA             JASON
# 143  433618         SIMO FAUS              RAUL
# 144  413350           SOILIHI            NEMATI
# 145  434189            SRHIRI            CHAIMA
# 146  432270            TECHER             ILONA
# 147  433651        TIMMERMANS            JASMIN
# 148  384255             TORKI            ILIANA
# 149  412521            TOUNDA       IMANI-KIMIA
# 150  428170              VEAU           ESTELLE
# 151  430513          VELLEINE             MARIE
# 152  432826          VERHEYDE             CHLOE
# 153  432229             VIARD           MAUREEN
# 154  415342           VIGNAUD              LOLA
# 155  429928     VILLECHALANNE           CAMILLE
# 156  369443            VIRION            LORICK
# 157  429397            YOUSFI               LEA
# 158  433672             ZHANG            HONGYI
#
#                                                  email         ine  \
# 0           emmanuel.akkul@etu.u-bordeaux-montaigne.fr  1664938189
# 1              emma.aubert@etu.u-bordeaux-montaigne.fr  1664938189
# 2          justin.auriault@etu.u-bordeaux-montaigne.fr  1664938189
# 3           manon.baranger@etu.u-bordeaux-montaigne.fr  1664938189
# 4             theo.barsacq@etu.u-bordeaux-montaigne.fr  1664938189
# 5           kristin.befort@etu.u-bordeaux-montaigne.fr  1664938189
# 6              elena.bento@etu.u-bordeaux-montaigne.fr  1664938189
# 7         amandine.berloin@etu.u-bordeaux-montaigne.fr  1664938189
# 8          sascha.bertrand@etu.u-bordeaux-montaigne.fr  1664938189
# 9         alissa.bessettes@etu.u-bordeaux-montaigne.fr  1664938189
# 10        laurine.biglione@etu.u-bordeaux-montaigne.fr  1664938189
# 11            lucy.birkett@etu.u-bordeaux-montaigne.fr  1664938189
# 12            sheryl.blanc@etu.u-bordeaux-montaigne.fr  1664938189
# 13            julie.boatto@etu.u-bordeaux-montaigne.fr  1664938189
# 14           nathan.bonnet@etu.u-bordeaux-montaigne.fr  1664938189
# 15          clea.bordelais@etu.u-bordeaux-montaigne.fr  1664938189
# 16          amelie.bosslet@etu.u-bordeaux-montaigne.fr  1664938189
# 17   sahra.boudemia-ettouil@etu.u-bordeaux-montaign...  1664938189
# 18            lea.boussard@etu.u-bordeaux-montaigne.fr  1664938189
# 19              manon.bout@etu.u-bordeaux-montaigne.fr  1664938189
# 20        mathilde.breuils@etu.u-bordeaux-montaigne.fr  1664938189
# 21     emi.bricout-teitgen@etu.u-bordeaux-montaigne.fr  1664938189
# 22           marion.calise@etu.u-bordeaux-montaigne.fr  1664938189
# 23         laetitia.capelo@etu.u-bordeaux-montaigne.fr  1664938189
# 24      lisa.carlin-robert@etu.u-bordeaux-montaigne.fr  1664938189
# 25          mila.carruezco@etu.u-bordeaux-montaigne.fr  1664938189
# 26        thomas.castaigna@etu.u-bordeaux-montaigne.fr  1664938189
# 27           hilel.chaddou@etu.u-bordeaux-montaigne.fr  1664938189
# 28          naida.chahirou@etu.u-bordeaux-montaigne.fr  1664938189
# 29           elise.chaigne@etu.u-bordeaux-montaigne.fr  1664938189
# ..                                                 ...         ...
# 129        noriko.robinson@etu.u-bordeaux-montaigne.fr  1664938189
# 130       amelie.rochefort@etu.u-bordeaux-montaigne.fr  1664938189
# 131          matisse.roger@etu.u-bordeaux-montaigne.fr  1664938189
# 132   morgane.roose-themyr@etu.u-bordeaux-montaigne.fr  1664938189
# 133         helene.rougier@etu.u-bordeaux-montaigne.fr  1664938189
# 134          lucie.sailhan@etu.u-bordeaux-montaigne.fr  1664938189
# 135          maria.saindou@etu.u-bordeaux-montaigne.fr  1664938189
# 136    satine.saint-girons@etu.u-bordeaux-montaigne.fr  1664938189
# 137          lola.sanchez1@etu.u-bordeaux-montaigne.fr  1664938189
# 138           lise.saubion@etu.u-bordeaux-montaigne.fr  1664938189
# 139          edwina.segaud@etu.u-bordeaux-montaigne.fr  1664938189
# 140    yelyzaveta.shadrina@etu.u-bordeaux-montaigne.fr  1664938189
# 141  maeve-fitzgerald.shea@etu.u-bordeaux-montaigne.fr  1664938189
# 142            jason.silva@etu.u-bordeaux-montaigne.fr  1664938189
# 143         raul.simo-faus@etu.u-bordeaux-montaigne.fr  1664938189
# 144         nemati.soilihi@etu.u-bordeaux-montaigne.fr  1664938189
# 145          chaima.srhiri@etu.u-bordeaux-montaigne.fr  1664938189
# 146           ilona.techer@etu.u-bordeaux-montaigne.fr  1664938189
# 147      jasmin.timmermans@etu.u-bordeaux-montaigne.fr  1664938189
# 148           iliana.torki@etu.u-bordeaux-montaigne.fr  1664938189
# 149     imani-kimia.tounda@etu.u-bordeaux-montaigne.fr  1664938189
# 150           estelle.veau@etu.u-bordeaux-montaigne.fr  1664938189
# 151         marie.velleine@etu.u-bordeaux-montaigne.fr  1664938189
# 152         chloe.verheyde@etu.u-bordeaux-montaigne.fr  1664938189
# 153          maureen.viard@etu.u-bordeaux-montaigne.fr  1664938189
# 154           lola.vignaud@etu.u-bordeaux-montaigne.fr  1664938189
# 155  camille.villechalanne@etu.u-bordeaux-montaigne.fr  1664938189
# 156          lorick.virion@etu.u-bordeaux-montaigne.fr  1664938189
# 157             lea.yousfi@etu.u-bordeaux-montaigne.fr  1664938189
# 158           hongyi.zhang@etu.u-bordeaux-montaigne.fr  1664938189
#
#                          PN                      NP
# 0            emmanuel akkul          akkul emmanuel
# 1               emma aubert             aubert emma
# 2           justin auriault         auriault justin
# 3            manon baranger          baranger manon
# 4              theo barsacq            barsacq theo
# 5            kristin befort          befort kristin
# 6               elena bento             bento elena
# 7          amandine berloin        berloin amandine
# 8           sascha bertrand         bertrand sascha
# 9          alissa bessettes        bessettes alissa
# 10         laurine biglione        biglione laurine
# 11             lucy birkett            birkett lucy
# 12             sheryl blanc            blanc sheryl
# 13             julie boatto            boatto julie
# 14            nathan bonnet           bonnet nathan
# 15           clea bordelais          bordelais clea
# 16           amelie bosslet          bosslet amelie
# 17   sahra boudemia ettouil  boudemia ettouil sahra
# 18             lea boussard            boussard lea
# 19               manon bout              bout manon
# 20         mathilde breuils        breuils mathilde
# 21      emi bricout-teitgen     bricout-teitgen emi
# 22            marion calise           calise marion
# 23          laetitia capelo         capelo laetitia
# 24       lisa carlin-robert      carlin-robert lisa
# 25           mila carruezco          carruezco mila
# 26         thomas castaigna        castaigna thomas
# 27            hilel chaddou           chaddou hilel
# 28           naida chahirou          chahirou naida
# 29            elise chaigne           chaigne elise
# ..                      ...                     ...
# 129         noriko robinson         robinson noriko
# 130        amelie rochefort        rochefort amelie
# 131           matisse roger           roger matisse
# 132    morgane roose-themyr    roose-themyr morgane
# 133          helene rougier          rougier helene
# 134           lucie sailhan           sailhan lucie
# 135           maria saindou           saindou maria
# 136     satine saint-girons     saint-girons satine
# 137            lola sanchez            sanchez lola
# 138            lise saubion            saubion lise
# 139           edwina segaud           segaud edwina
# 140     yelyzaveta shadrina     shadrina yelyzaveta
# 141   maeve fitzgerald shea   shea maeve fitzgerald
# 142             jason silva             silva jason
# 143          raul simo faus          simo faus raul
# 144          nemati soilihi          soilihi nemati
# 145           chaima srhiri           srhiri chaima
# 146            ilona techer            techer ilona
# 147       jasmin timmermans       timmermans jasmin
# 148            iliana torki            torki iliana
# 149      imani-kimia tounda      tounda imani-kimia
# 150            estelle veau            veau estelle
# 151          marie velleine          velleine marie
# 152          chloe verheyde          verheyde chloe
# 153           maureen viard           viard maureen
# 154            lola vignaud            vignaud lola
# 155   camille villechalanne   villechalanne camille
# 156           lorick virion           virion lorick
# 157              lea yousfi              yousfi lea
# 158            hongyi zhang            zhang hongyi
#
# [159 rows x 7 columns]

# %%
pseudos=lQuizz[~(lQuizz["pseudo"].isin(alias))]["pseudo"].str.strip().tolist()
print "\n".join(pseudos)
# Out:
# Sidneyy
# AB

# %%
for nP,pseudoBrut in enumerate(pseudos):
    pseudo=unidecode.unidecode(pseudoBrut)
    print pseudo
    sPseudo = raw_input("Nom a chercher:\n")
    if sPseudo:
        print dfCM[dfCM["PN"].str.contains(sPseudo.lower())][["PN","id"]]
        idPseudo=raw_input("id :\n")
        if idPseudo:
            alias[pseudoBrut]=idPseudo
# Out:
# Sidneyy
# Nom a chercher:
#
# AB
# Nom a chercher:

# %% [raw]
# for k,v in alias.iteritems():
#     print k,v[0][0][0]
#     alias[k]=v[0][0][0].split(" ")
# alias

# %%
# pseudo=u"csaintavi001 ebismes001"
# alias[pseudo]=["415962","413429"]

# %%
sPseudo="bisme"
print dfCM[dfCM["PN"].str.contains(sPseudo.lower())][["PN","id"]]
# Out:
# Empty DataFrame
# Columns: [PN, id]
# Index: []

# %%
pseudos
# Out:
# [u'Sidneyy', u'AB']

# %%
# alias["Sofiane"]

# %%
pn=dfCM["PN"].tolist()
np=dfCM["NP"].tolist()

# %%
for pseudo in pseudos:
    if unidecode.unidecode(pseudo.lower()) in pn:
        print pseudo,dfCM[dfCM["PN"]==unidecode.unidecode(pseudo.lower())]["id"].values[0]
        alias[pseudo]=[str(dfCM[dfCM["PN"]==unidecode.unidecode(pseudo.lower())]["id"].values[0])]
    elif unidecode.unidecode(pseudo.lower()) in np:
        print pseudo,dfCM[dfCM["NP"]==unidecode.unidecode(pseudo.lower())]["id"].values[0]
        alias[pseudo]=[str(dfCM[dfCM["NP"]==unidecode.unidecode(pseudo.lower())]["id"].values[0])]

# %%
for al in alias:
    if not isinstance(alias[al],list):
        if " " in alias[al]:
            alias[al]=alias[al].split(" ")
        else:
            alias[al]=[alias[al]]

# %%
len(alias)
# Out:
# 197

# %%
invAlias=invert_dict(alias)
#invAlias[385732]=[u'adiarra001, cbeauvais004']
correspondances={"alias2etu":alias,"etu2alias":invAlias}
correspondances
# Out:
# {'alias2etu': {'ALINA': ['433401'],
#   'Agathe / Liliana': ['430440', '430952'],
#   'Agathe Martin': ['430440'],
#   'Alex Helvert': ['380824'],
#   'Alice LOOF': ['427886'],
#   'Alima Gassama': ['418366'],
#   'Alissa Bessettes': ['429623'],
#   'Alix DEBUR': ['427449'],
#   u'Ali\xe9nor Riou': ['428930'],
#   'Amandine B': ['429252'],
#   'Amelie Mitlehner': ['433485'],
#   u'Am\xe9lie rochefort': ['432360'],
#   u'Ana\xeblle DINA-SAME': ['432151'],
#   'Auriault justin': ['430711'],
#   'Axel Meunier': ['429855'],
#   'BENTO Elena': ['428999'],
#   u'BOUSSARD L\xe9a': ['428452'],
#   'Baptiste phelip': ['397583'],
#   u'Barsacq Th\xe9o': ['403123'],
#   'Berloin Amandine': ['429252'],
#   'Bertrand Sascha': ['419149'],
#   'Blanc Sheryl': ['427234'],
#   'Bonnet Nathan': ['433074'],
#   u'Bordelais Cl\xe9a': ['429396'],
#   'CHADDOU hilel': ['430892'],
#   'CLOCHET': ['427924'],
#   'CLOCHET LYSON': ['427924'],
#   'CLOCHET lyson': ['427924'],
#   'Camille Villechalanne': ['429928'],
#   'Carla': ['433437'],
#   'Chaigne Elise': ['429273'],
#   'Chihiro Kamikanda': ['424085'],
#   'Clara LEGER': ['385051'],
#   'Clochet Lyson': ['427924'],
#   'Cloe Destaminil': ['427625'],
#   'Cout. Elsa': ['432447'],
#   'Coutard Elsa': ['432447'],
#   'DJUNGA LENYAMA Esther': ['433322'],
#   'DJUNGALENYAMA': ['433322'],
#   'Daniela Gomes': ['427433'],
#   'Daniela Gomes et Kiara Dugas': ['432817', '427433'],
#   'Darriba Anna': ['429228'],
#   'De Girardi Leelou': ['431463'],
#   'Dehoulle Fanny': ['396374'],
#   'Delalande Laly': ['430635'],
#   u'Depluche Le\xefla': ['412746'],
#   'Detrie Margot, Esperon Astrid': ['428233', '433135'],
#   u'Dina-Same Ana\xeblle': ['432151'],
#   u'D\xe9trie Margot': ['428233'],
#   u'D\xe9trie Margot, Enjalbal Emma': ['429793', '428233'],
#   u'D\xe9trie Margot, Esperon Astrid': ['433135', '428233'],
#   'EL ASRI Safaa': ['426688'],
#   'ESPERON Astrid': ['433135'],
#   'Edwina Segaud': ['426706'],
#   'Eliane Megarus': ['413748'],
#   'Eliazord Priscilla': ['432298'],
#   'Elizazord Priscilla': ['432298'],
#   'Elysa Ravet': ['431986'],
#   'Elysa Ravet et Mariah Gotter': ['432488', '431986'],
#   'Elysa Ravet, Mariah Gotter': ['432488', '431986'],
#   'Emilie Escapoulade': ['432459'],
#   'Emma enjalbal ettouil sahra': ['431767', '429793'],
#   'Emma enjalbal sahra ettouil': ['429793', '431767'],
#   'Enjalbal emma': ['429793'],
#   'Erwan LECUL': ['426946'],
#   'Escapoulade Emilie': ['432459'],
#   'Esclave Jason Silva': ['431560'],
#   'Estelle Veau': ['428170'],
#   'Estelle veau': ['428170'],
#   'Eva DELAHODDE': ['427303'],
#   'FRECHET Manon': ['429499'],
#   'Fall Mariem': ['429625'],
#   'Frechet Manon, Klopstein Emma': ['429499', '428316'],
#   'Gaelle Dubroca': ['382457'],
#   'Gaelle Lamarque': ['427542'],
#   'Gaudin': ['428033'],
#   u'Ga\xeblle Dub': ['382457'],
#   u'Ga\xeblle Dubroca': ['382457'],
#   u'Ga\xeblle Jegorel': ['431199'],
#   u'Ga\xeblle Jgl': ['431199'],
#   u'Ga\xeblle Lamarque': ['427542'],
#   'Ghenima': ['432082'],
#   'Heloise Gouardes Arazola': ['433055'],
#   'Hongyi': ['433672'],
#   u'H\xe9lo\xefse Gouardes Arazola': ['433055'],
#   u'H\xe9l\xe8ne': ['428168'],
#   u'H\xe9l\xe8ne Rougier': ['428168'],
#   'Ilona TECHER': ['432270'],
#   'Jason Silva': ['431560'],
#   'Jeanne robin': ['431378'],
#   'Joana Fehr': ['433345'],
#   'Jonatan Mangel': ['429540'],
#   'Jonatan-Mangel': ['429540'],
#   'Julie Boatto': ['430230'],
#   'Katharina Froitzheim': ['433364'],
#   'Kiara Dugas': ['432817'],
#   'Kristin': ['433205'],
#   'LECUL Erwan': ['426946'],
#   'LEDROIT Katell': ['427577'],
#   'LOVRIC': ['433447'],
#   'Labille Romane': ['431590'],
#   'Labille romane': ['431590'],
#   'Laly DELALANDE': ['430635'],
#   'Laly Delalande': ['430635'],
#   'Laly Dugue': ['427109'],
#   u'Laly Dugu\xe9': ['427109'],
#   'Laurine Biglione': ['431375'],
#   'Laurine biglione': ['431375'],
#   u'La\xebtitia Capelo': ['427987'],
#   u'Lebidan Ga\xebl': ['427403'],
#   'Leelou De Girardi': ['431463'],
#   'Lemoine Charline': ['429034'],
#   'Liliana Correia Santos': ['430952'],
#   'Lisa Carlin': ['428292'],
#   'Lola Leblois': ['429694'],
#   'LolaKaci': ['426735'],
#   'Louann le corf': ['431735'],
#   'Lucy Birkett': ['433225'],
#   'Luna Lombard': ['432206'],
#   'Maeve Shea': ['433612'],
#   'Maewenn Gaudin': ['428033'],
#   'Mangel Jonatan': ['429540'],
#   'Manon Baranger': ['431129'],
#   'Manon Baranger 2': ['431129'],
#   'Manon bout': ['428729'],
#   'Manon bout manon frechet': ['428729', '429499'],
#   'Maria SAINDOU': ['411936'],
#   'Mariah Gotter': ['432488'],
#   'Marion Calise': ['431451'],
#   'Marius Reculet': ['426755'],
#   'Mathis Monteiro': ['427574'],
#   'Matisse ROGER': ['433263'],
#   'Maureen viard': ['432229'],
#   'Mazieux Coraline': ['430747'],
#   'MeresseCapucine,MignotCamille': ['431197', '432314'],
#   u'Mesquita L\xe9o': ['426732'],
#   u'Monge Cl\xe9mence': ['428617'],
#   u'Monge Cl\xe9mence et Estelle Veau': ['428617', '428170'],
#   'Moreau Coleen': ['426930'],
#   u'Moreau Coleen et Riou Ali\xe9nor': ['426930', '428930'],
#   'Morgan rabou': ['419808'],
#   'Morgane Roose': ['431114'],
#   'Naida': ['417479'],
#   'Nathan bonnet': ['433074'],
#   u'Na\xefda': ['417479'],
#   'Noriko ROBINSON': ['428114'],
#   'Noriko Robinson': ['428114'],
#   'Phelip Baptiste': ['397583'],
#   'Phelip baptiste': ['397583'],
#   'Pohu Emma-Lou': ['426820'],
#   'Posso Manon': ['432712'],
#   'Prevost': ['432779'],
#   u'Pr\xe9vost Mathilde': ['432779'],
#   'ROBINSON Noriko': ['428114'],
#   'ROGER Matisse': ['433263'],
#   u'Ra\xfcl Sim\xf3': ['433618'],
#   'Robinson Noriko': ['428114'],
#   'Romain Dubois': ['417953'],
#   'Roukaya': ['416084'],
#   'Ruby Fischer': ['433357'],
#   'SHADRINA Yelyzaveta': ['425485'],
#   'Sila Karaketir': ['427702'],
#   u'Soilihi N\xe9mati': ['413350'],
#   'Ugo Gameiro': ['429545'],
#   'Ugo gameiro': ['429545'],
#   u'VERHEYDE Chlo\xe9': ['432826'],
#   'VERHEYDE chloe': ['432826'],
#   'Vadim Olivan': ['414257'],
#   'Veau Estelle': ['428170'],
#   'Velleine Marie': ['430513'],
#   'Yelyzaveta Shadrina': ['425485'],
#   'csrhiri001': ['434189'],
#   'de girardi leelou': ['431463'],
#   'elea hirigoyen': ['428197'],
#   'isa g': ['433367'],
#   'jeanne massias': ['431183'],
#   'kiara dugas': ['432817'],
#   'lola lebloid': ['429694'],
#   'lola vignaud': ['415342'],
#   'lucie monteyne': ['429412'],
#   'lucie monteyne amelie roche': ['429412', '432360'],
#   'lucie monteyne, amelie roche': ['429412', '432360'],
#   'luna lombard': ['432206'],
#   u'l\xe9a yousfi': ['429397'],
#   'marilyne kouame': ['432548'],
#   'maryline kouame': ['432548'],
#   'massias': ['431183'],
#   'massias , delahodde': ['427303', '431183'],
#   'massias,  duplan, delahodde': ['431183', '431361', '427303'],
#   'maureen viard': ['432229'],
#   'mila.carruezco': ['433803'],
#   'nell duplan': ['431361'],
#   'pointemma': ['430808'],
#   'quisha': ['433411'],
#   'sheryl blanc': ['427234'],
#   'sheryl blanc, marius reculet': ['427234', '426755'],
#   'super rabou': ['419808']},
#  'etu2alias': {'380824': ['Alex Helvert'],
#   '382457': ['Gaelle Dubroca', u'Ga\xeblle Dub', u'Ga\xeblle Dubroca'],
#   '385051': ['Clara LEGER'],
#   '396374': ['Dehoulle Fanny'],
#   '397583': ['Phelip Baptiste', 'Phelip baptiste', 'Baptiste phelip'],
#   '403123': [u'Barsacq Th\xe9o'],
#   '411936': ['Maria SAINDOU'],
#   '412746': [u'Depluche Le\xefla'],
#   '413350': [u'Soilihi N\xe9mati'],
#   '413748': ['Eliane Megarus'],
#   '414257': ['Vadim Olivan'],
#   '415342': ['lola vignaud'],
#   '416084': ['Roukaya'],
#   '417479': [u'Na\xefda', 'Naida'],
#   '417953': ['Romain Dubois'],
#   '418366': ['Alima Gassama'],
#   '419149': ['Bertrand Sascha'],
#   '419808': ['Morgan rabou', 'super rabou'],
#   '424085': ['Chihiro Kamikanda'],
#   '425485': ['SHADRINA Yelyzaveta', 'Yelyzaveta Shadrina'],
#   '426688': ['EL ASRI Safaa'],
#   '426706': ['Edwina Segaud'],
#   '426732': [u'Mesquita L\xe9o'],
#   '426735': ['LolaKaci'],
#   '426755': ['Marius Reculet', 'sheryl blanc, marius reculet'],
#   '426820': ['Pohu Emma-Lou'],
#   '426930': [u'Moreau Coleen et Riou Ali\xe9nor', 'Moreau Coleen'],
#   '426946': ['LECUL Erwan', 'Erwan LECUL'],
#   '427109': [u'Laly Dugu\xe9', 'Laly Dugue'],
#   '427234': ['sheryl blanc, marius reculet', 'sheryl blanc', 'Blanc Sheryl'],
#   '427303': ['massias,  duplan, delahodde',
#    'massias , delahodde',
#    'Eva DELAHODDE'],
#   '427403': [u'Lebidan Ga\xebl'],
#   '427433': ['Daniela Gomes et Kiara Dugas', 'Daniela Gomes'],
#   '427449': ['Alix DEBUR'],
#   '427542': [u'Ga\xeblle Lamarque', 'Gaelle Lamarque'],
#   '427574': ['Mathis Monteiro'],
#   '427577': ['LEDROIT Katell'],
#   '427625': ['Cloe Destaminil'],
#   '427702': ['Sila Karaketir'],
#   '427886': ['Alice LOOF'],
#   '427924': ['CLOCHET', 'CLOCHET LYSON', 'Clochet Lyson', 'CLOCHET lyson'],
#   '427987': [u'La\xebtitia Capelo'],
#   '428033': ['Maewenn Gaudin', 'Gaudin'],
#   '428114': ['Noriko Robinson',
#    'Noriko ROBINSON',
#    'ROBINSON Noriko',
#    'Robinson Noriko'],
#   '428168': [u'H\xe9l\xe8ne', u'H\xe9l\xe8ne Rougier'],
#   '428170': ['Veau Estelle',
#    u'Monge Cl\xe9mence et Estelle Veau',
#    'Estelle veau',
#    'Estelle Veau'],
#   '428197': ['elea hirigoyen'],
#   '428233': ['Detrie Margot, Esperon Astrid',
#    u'D\xe9trie Margot',
#    u'D\xe9trie Margot, Enjalbal Emma',
#    u'D\xe9trie Margot, Esperon Astrid'],
#   '428292': ['Lisa Carlin'],
#   '428316': ['Frechet Manon, Klopstein Emma'],
#   '428452': [u'BOUSSARD L\xe9a'],
#   '428617': [u'Monge Cl\xe9mence', u'Monge Cl\xe9mence et Estelle Veau'],
#   '428729': ['Manon bout', 'Manon bout manon frechet'],
#   '428930': [u'Ali\xe9nor Riou', u'Moreau Coleen et Riou Ali\xe9nor'],
#   '428999': ['BENTO Elena'],
#   '429034': ['Lemoine Charline'],
#   '429228': ['Darriba Anna'],
#   '429252': ['Berloin Amandine', 'Amandine B'],
#   '429273': ['Chaigne Elise'],
#   '429396': [u'Bordelais Cl\xe9a'],
#   '429397': [u'l\xe9a yousfi'],
#   '429412': ['lucie monteyne amelie roche',
#    'lucie monteyne',
#    'lucie monteyne, amelie roche'],
#   '429499': ['FRECHET Manon',
#    'Manon bout manon frechet',
#    'Frechet Manon, Klopstein Emma'],
#   '429540': ['Jonatan Mangel', 'Mangel Jonatan', 'Jonatan-Mangel'],
#   '429545': ['Ugo Gameiro', 'Ugo gameiro'],
#   '429623': ['Alissa Bessettes'],
#   '429625': ['Fall Mariem'],
#   '429694': ['Lola Leblois', 'lola lebloid'],
#   '429793': ['Emma enjalbal sahra ettouil',
#    u'D\xe9trie Margot, Enjalbal Emma',
#    'Enjalbal emma',
#    'Emma enjalbal ettouil sahra'],
#   '429855': ['Axel Meunier'],
#   '429928': ['Camille Villechalanne'],
#   '430230': ['Julie Boatto'],
#   '430440': ['Agathe / Liliana', 'Agathe Martin'],
#   '430513': ['Velleine Marie'],
#   '430635': ['Delalande Laly', 'Laly DELALANDE', 'Laly Delalande'],
#   '430711': ['Auriault justin'],
#   '430747': ['Mazieux Coraline'],
#   '430808': ['pointemma'],
#   '430892': ['CHADDOU hilel'],
#   '430952': ['Agathe / Liliana', 'Liliana Correia Santos'],
#   '431114': ['Morgane Roose'],
#   '431129': ['Manon Baranger 2', 'Manon Baranger'],
#   '431183': ['massias,  duplan, delahodde',
#    'massias , delahodde',
#    'jeanne massias',
#    'massias'],
#   '431197': ['MeresseCapucine,MignotCamille'],
#   '431199': [u'Ga\xeblle Jegorel', u'Ga\xeblle Jgl'],
#   '431361': ['massias,  duplan, delahodde', 'nell duplan'],
#   '431375': ['Laurine Biglione', 'Laurine biglione'],
#   '431378': ['Jeanne robin'],
#   '431451': ['Marion Calise'],
#   '431463': ['De Girardi Leelou', 'Leelou De Girardi', 'de girardi leelou'],
#   '431560': ['Jason Silva', 'Esclave Jason Silva'],
#   '431590': ['Labille Romane', 'Labille romane'],
#   '431735': ['Louann le corf'],
#   '431767': ['Emma enjalbal sahra ettouil', 'Emma enjalbal ettouil sahra'],
#   '431986': ['Elysa Ravet et Mariah Gotter',
#    'Elysa Ravet, Mariah Gotter',
#    'Elysa Ravet'],
#   '432082': ['Ghenima'],
#   '432151': [u'Ana\xeblle DINA-SAME', u'Dina-Same Ana\xeblle'],
#   '432206': ['luna lombard', 'Luna Lombard'],
#   '432229': ['Maureen viard', 'maureen viard'],
#   '432270': ['Ilona TECHER'],
#   '432298': ['Elizazord Priscilla', 'Eliazord Priscilla'],
#   '432314': ['MeresseCapucine,MignotCamille'],
#   '432360': ['lucie monteyne amelie roche',
#    u'Am\xe9lie rochefort',
#    'lucie monteyne, amelie roche'],
#   '432447': ['Coutard Elsa', 'Cout. Elsa'],
#   '432459': ['Escapoulade Emilie', 'Emilie Escapoulade'],
#   '432488': ['Mariah Gotter',
#    'Elysa Ravet et Mariah Gotter',
#    'Elysa Ravet, Mariah Gotter'],
#   '432548': ['marilyne kouame', 'maryline kouame'],
#   '432712': ['Posso Manon'],
#   '432779': ['Prevost', u'Pr\xe9vost Mathilde'],
#   '432817': ['Daniela Gomes et Kiara Dugas', 'kiara dugas', 'Kiara Dugas'],
#   '432826': ['VERHEYDE chloe', u'VERHEYDE Chlo\xe9'],
#   '433055': [u'H\xe9lo\xefse Gouardes Arazola', 'Heloise Gouardes Arazola'],
#   '433074': ['Bonnet Nathan', 'Nathan bonnet'],
#   '433135': ['Detrie Margot, Esperon Astrid',
#    u'D\xe9trie Margot, Esperon Astrid',
#    'ESPERON Astrid'],
#   '433205': ['Kristin'],
#   '433225': ['Lucy Birkett'],
#   '433263': ['Matisse ROGER', 'ROGER Matisse'],
#   '433322': ['DJUNGALENYAMA', 'DJUNGA LENYAMA Esther'],
#   '433345': ['Joana Fehr'],
#   '433357': ['Ruby Fischer'],
#   '433364': ['Katharina Froitzheim'],
#   '433367': ['isa g'],
#   '433401': ['ALINA'],
#   '433411': ['quisha'],
#   '433437': ['Carla'],
#   '433447': ['LOVRIC'],
#   '433485': ['Amelie Mitlehner'],
#   '433612': ['Maeve Shea'],
#   '433618': [u'Ra\xfcl Sim\xf3'],
#   '433672': ['Hongyi'],
#   '433803': ['mila.carruezco'],
#   '434189': ['csrhiri001']}}

# %%
with codecs.open(fAliasQDLE, 'w', encoding="utf8") as outfile:
    yaml.safe_dump(correspondances, outfile, default_flow_style=False)

# %% [markdown]
# # Calcul des notes
# Attention au nombre de questions

# %%
nbQ=7.0

# %%
def aliasQuizz(pseudo):
    result=None
    if pseudo in alias:
        result=alias[pseudo]
    return result

def noteQuizz(points):   
    result=8
    if points>0:
        result=int(round(10*(1+points/nbQ),0))
    return result
        
        

lQuizz["id"]=lQuizz["pseudo"].apply(aliasQuizz)
lQuizz["note"]=lQuizz["points"].apply(noteQuizz)

# %%
def splitPseudo1(id):
    result=None
    if id and len(id)>0:
        result=id[0]
    return result

def splitPseudo2(id):
    result=None
    if id and len(id)>1:
        result=id[1]
    return result

def splitPseudo3(id):
    result=None
    if id and len(id)>2:
        result=id[2]
    return result

lQuizz["id1"]=lQuizz["id"].apply(splitPseudo1)
lQuizz["id2"]=lQuizz["id"].apply(splitPseudo2)
lQuizz["id3"]=lQuizz["id"].apply(splitPseudo3)

lQuizz
# Out:
#                            pseudo  points   temps                id  note  \
# 0                    Axel Meunier       7    8.40          [429855]    20
# 1                  Marius Reculet       7   54.08          [426755]    20
# 2                    Vadim Olivan       7   96.70          [414257]    20
# 3                     Lisa Carlin       7  102.47          [428292]    20
# 4                  LEDROIT Katell       7  133.66          [427577]    20
# 5                    Darriba Anna       7  138.42          [429228]    20
# 6                      Amandine B       7  173.04          [429252]    20
# 7                  Manon Baranger       7  180.25          [431129]    20
# 8                       Raül Simó       6   28.36          [433618]    19
# 9              Eliazord Priscilla       6  124.37          [432298]    19
# 10                   Lucy Birkett       6  132.46          [433225]    19
# 11  Moreau Coleen et Riou Aliénor       6  133.12  [426930, 428930]    19
# 12             Emilie Escapoulade       6  150.04          [432459]    19
# 13                  Détrie Margot       6  151.55          [428233]    19
# 14                    kiara dugas       6  153.34          [432817]    19
# 15                  Marion Calise       6  153.70          [431451]    19
# 16                 ESPERON Astrid       6  156.50          [433135]    19
# 17                 Louann le corf       6  156.87          [431735]    19
# 18                   Ilona TECHER       6  160.42          [432270]    19
# 19                        CLOCHET       6  163.09          [427924]    19
# 20              Chihiro Kamikanda       6  167.86          [424085]    19
# 21                 Bordelais Cléa       6  182.81          [429396]    19
# 22                  Bonnet Nathan       5   65.76          [433074]    17
# 23                Cloe Destaminil       5   91.84          [427625]    17
# 24                     Gaëlle Dub       5   94.97          [382457]    17
# 25                       LolaKaci       5  117.78          [426735]    17
# 26                     Alice LOOF       5  128.80          [427886]    17
# 27                 Labille romane       5  129.85          [431590]    17
# 28               Agathe / Liliana       5  137.55  [430440, 430952]    17
# 29                Mathis Monteiro       5  140.53          [427574]    17
# ..                            ...     ...     ...               ...   ...
# 62                             AB       4  165.93              None    16
# 63               Mazieux Coraline       4  168.18          [430747]    16
# 64                          ALINA       4  173.35          [433401]    16
# 65                   BOUSSARD Léa       4  176.16          [428452]    16
# 66                     Alix DEBUR       4  179.33          [427449]    16
# 67       Manon bout manon frechet       4  181.80  [428729, 429499]    16
# 68               Amélie rochefort       3   78.07          [432360]    14
# 69                  Chaigne Elise       3   94.46          [429273]    14
# 70                    nell duplan       3  119.74          [431361]    14
# 71                 mila.carruezco       3  124.63          [433803]    14
# 72               Lemoine Charline       3  140.02          [429034]    14
# 73                Gaëlle Lamarque       3  168.25          [427542]    14
# 74                   lola lebloid       3  196.63          [429694]    14
# 75                  Edwina Segaud       2  109.50          [426706]    13
# 76            SHADRINA Yelyzaveta       2  111.17          [425485]    13
# 77   Elysa Ravet et Mariah Gotter       2  116.04  [432488, 431986]    13
# 78                 Hélène Rougier       2  131.02          [428168]    13
# 79                 Delalande Laly       2  132.19          [430635]    13
# 80                Baptiste phelip       1   51.04          [397583]    11
# 81                        Roukaya       1   67.10          [416084]    11
# 82                  Eva DELAHODDE       1   82.70          [427303]    11
# 83                        Prevost       1   98.78          [432779]    11
# 84                 VERHEYDE chloe       1  116.61          [432826]    11
# 85               Amelie Mitlehner       1  160.57          [433485]    11
# 86                   luna lombard       0    0.00          [432206]     8
# 87                Phelip Baptiste       0    0.00          [397583]     8
# 88                 VERHEYDE Chloé       0    0.00          [432826]     8
# 89                        Kristin       0    0.00          [433205]     8
# 90                 lucie monteyne       0    0.00          [429412]     8
# 91                   Blanc Sheryl       0  154.92          [427234]     8
#
#        id1     id2   id3
# 0   429855    None  None
# 1   426755    None  None
# 2   414257    None  None
# 3   428292    None  None
# 4   427577    None  None
# 5   429228    None  None
# 6   429252    None  None
# 7   431129    None  None
# 8   433618    None  None
# 9   432298    None  None
# 10  433225    None  None
# 11  426930  428930  None
# 12  432459    None  None
# 13  428233    None  None
# 14  432817    None  None
# 15  431451    None  None
# 16  433135    None  None
# 17  431735    None  None
# 18  432270    None  None
# 19  427924    None  None
# 20  424085    None  None
# 21  429396    None  None
# 22  433074    None  None
# 23  427625    None  None
# 24  382457    None  None
# 25  426735    None  None
# 26  427886    None  None
# 27  431590    None  None
# 28  430440  430952  None
# 29  427574    None  None
# ..     ...     ...   ...
# 62    None    None  None
# 63  430747    None  None
# 64  433401    None  None
# 65  428452    None  None
# 66  427449    None  None
# 67  428729  429499  None
# 68  432360    None  None
# 69  429273    None  None
# 70  431361    None  None
# 71  433803    None  None
# 72  429034    None  None
# 73  427542    None  None
# 74  429694    None  None
# 75  426706    None  None
# 76  425485    None  None
# 77  432488  431986  None
# 78  428168    None  None
# 79  430635    None  None
# 80  397583    None  None
# 81  416084    None  None
# 82  427303    None  None
# 83  432779    None  None
# 84  432826    None  None
# 85  433485    None  None
# 86  432206    None  None
# 87  397583    None  None
# 88  432826    None  None
# 89  433205    None  None
# 90  429412    None  None
# 91  427234    None  None
#
# [92 rows x 8 columns]

# %%
df1=lQuizz[["pseudo","note","temps","id1"]].dropna()
df2=lQuizz[["pseudo","note","temps","id2"]].dropna()
df3=lQuizz[["pseudo","note","temps","id3"]].dropna()
df1.columns=["pseudo","note","temps","id"]
df2.columns=["pseudo","note","temps","id"]
df3.columns=["pseudo","note","temps","id"]

# %%
df123=pd.concat([df1,df2,df3]).sort_values(["note","temps"],ascending=[False,True])
df123
# Out:
#                            pseudo  note   temps      id
# 0                    Axel Meunier    20    8.40  429855
# 1                  Marius Reculet    20   54.08  426755
# 2                    Vadim Olivan    20   96.70  414257
# 3                     Lisa Carlin    20  102.47  428292
# 4                  LEDROIT Katell    20  133.66  427577
# 5                    Darriba Anna    20  138.42  429228
# 6                      Amandine B    20  173.04  429252
# 7                  Manon Baranger    20  180.25  431129
# 8                       Raül Simó    19   28.36  433618
# 9              Eliazord Priscilla    19  124.37  432298
# 10                   Lucy Birkett    19  132.46  433225
# 11  Moreau Coleen et Riou Aliénor    19  133.12  426930
# 11  Moreau Coleen et Riou Aliénor    19  133.12  428930
# 12             Emilie Escapoulade    19  150.04  432459
# 13                  Détrie Margot    19  151.55  428233
# 14                    kiara dugas    19  153.34  432817
# 15                  Marion Calise    19  153.70  431451
# 16                 ESPERON Astrid    19  156.50  433135
# 17                 Louann le corf    19  156.87  431735
# 18                   Ilona TECHER    19  160.42  432270
# 19                        CLOCHET    19  163.09  427924
# 20              Chihiro Kamikanda    19  167.86  424085
# 21                 Bordelais Cléa    19  182.81  429396
# 22                  Bonnet Nathan    17   65.76  433074
# 23                Cloe Destaminil    17   91.84  427625
# 24                     Gaëlle Dub    17   94.97  382457
# 25                       LolaKaci    17  117.78  426735
# 26                     Alice LOOF    17  128.80  427886
# 27                 Labille romane    17  129.85  431590
# 28               Agathe / Liliana    17  137.55  430440
# ..                            ...   ...     ...     ...
# 64                          ALINA    16  173.35  433401
# 65                   BOUSSARD Léa    16  176.16  428452
# 66                     Alix DEBUR    16  179.33  427449
# 67       Manon bout manon frechet    16  181.80  428729
# 67       Manon bout manon frechet    16  181.80  429499
# 68               Amélie rochefort    14   78.07  432360
# 69                  Chaigne Elise    14   94.46  429273
# 70                    nell duplan    14  119.74  431361
# 71                 mila.carruezco    14  124.63  433803
# 72               Lemoine Charline    14  140.02  429034
# 73                Gaëlle Lamarque    14  168.25  427542
# 74                   lola lebloid    14  196.63  429694
# 75                  Edwina Segaud    13  109.50  426706
# 76            SHADRINA Yelyzaveta    13  111.17  425485
# 77   Elysa Ravet et Mariah Gotter    13  116.04  432488
# 77   Elysa Ravet et Mariah Gotter    13  116.04  431986
# 78                 Hélène Rougier    13  131.02  428168
# 79                 Delalande Laly    13  132.19  430635
# 80                Baptiste phelip    11   51.04  397583
# 81                        Roukaya    11   67.10  416084
# 82                  Eva DELAHODDE    11   82.70  427303
# 83                        Prevost    11   98.78  432779
# 84                 VERHEYDE chloe    11  116.61  432826
# 85               Amelie Mitlehner    11  160.57  433485
# 86                   luna lombard     8    0.00  432206
# 87                Phelip Baptiste     8    0.00  397583
# 88                 VERHEYDE Chloé     8    0.00  432826
# 89                        Kristin     8    0.00  433205
# 90                 lucie monteyne     8    0.00  429412
# 91                   Blanc Sheryl     8  154.92  427234
#
# [96 rows x 4 columns]

# %%
df123.at[0, 'note'] = 20
if df123.loc[1, "note"]<18:
    df123.at[1, 'note'] = 18
df123
# Out:
#                            pseudo  note   temps      id
# 0                    Axel Meunier    20    8.40  429855
# 1                  Marius Reculet    20   54.08  426755
# 2                    Vadim Olivan    20   96.70  414257
# 3                     Lisa Carlin    20  102.47  428292
# 4                  LEDROIT Katell    20  133.66  427577
# 5                    Darriba Anna    20  138.42  429228
# 6                      Amandine B    20  173.04  429252
# 7                  Manon Baranger    20  180.25  431129
# 8                       Raül Simó    19   28.36  433618
# 9              Eliazord Priscilla    19  124.37  432298
# 10                   Lucy Birkett    19  132.46  433225
# 11  Moreau Coleen et Riou Aliénor    19  133.12  426930
# 11  Moreau Coleen et Riou Aliénor    19  133.12  428930
# 12             Emilie Escapoulade    19  150.04  432459
# 13                  Détrie Margot    19  151.55  428233
# 14                    kiara dugas    19  153.34  432817
# 15                  Marion Calise    19  153.70  431451
# 16                 ESPERON Astrid    19  156.50  433135
# 17                 Louann le corf    19  156.87  431735
# 18                   Ilona TECHER    19  160.42  432270
# 19                        CLOCHET    19  163.09  427924
# 20              Chihiro Kamikanda    19  167.86  424085
# 21                 Bordelais Cléa    19  182.81  429396
# 22                  Bonnet Nathan    17   65.76  433074
# 23                Cloe Destaminil    17   91.84  427625
# 24                     Gaëlle Dub    17   94.97  382457
# 25                       LolaKaci    17  117.78  426735
# 26                     Alice LOOF    17  128.80  427886
# 27                 Labille romane    17  129.85  431590
# 28               Agathe / Liliana    17  137.55  430440
# ..                            ...   ...     ...     ...
# 64                          ALINA    16  173.35  433401
# 65                   BOUSSARD Léa    16  176.16  428452
# 66                     Alix DEBUR    16  179.33  427449
# 67       Manon bout manon frechet    16  181.80  428729
# 67       Manon bout manon frechet    16  181.80  429499
# 68               Amélie rochefort    14   78.07  432360
# 69                  Chaigne Elise    14   94.46  429273
# 70                    nell duplan    14  119.74  431361
# 71                 mila.carruezco    14  124.63  433803
# 72               Lemoine Charline    14  140.02  429034
# 73                Gaëlle Lamarque    14  168.25  427542
# 74                   lola lebloid    14  196.63  429694
# 75                  Edwina Segaud    13  109.50  426706
# 76            SHADRINA Yelyzaveta    13  111.17  425485
# 77   Elysa Ravet et Mariah Gotter    13  116.04  432488
# 77   Elysa Ravet et Mariah Gotter    13  116.04  431986
# 78                 Hélène Rougier    13  131.02  428168
# 79                 Delalande Laly    13  132.19  430635
# 80                Baptiste phelip    11   51.04  397583
# 81                        Roukaya    11   67.10  416084
# 82                  Eva DELAHODDE    11   82.70  427303
# 83                        Prevost    11   98.78  432779
# 84                 VERHEYDE chloe    11  116.61  432826
# 85               Amelie Mitlehner    11  160.57  433485
# 86                   luna lombard     8    0.00  432206
# 87                Phelip Baptiste     8    0.00  397583
# 88                 VERHEYDE Chloé     8    0.00  432826
# 89                        Kristin     8    0.00  433205
# 90                 lucie monteyne     8    0.00  429412
# 91                   Blanc Sheryl     8  154.92  427234
#
# [96 rows x 4 columns]

# %%
dfNotes=df123.groupby("id").max().sort_values("note",ascending=False)
dfNotes.to_csv(fNotes,sep="\t",encoding="utf8")
