# %%
import codecs,unidecode,yaml,glob,os,shutil,re
import itertools as it
import numpy as np
import pandas as pd
# print(pd.__version__)

# %%
sQuizz="03"
nQuizz=int(sQuizz)
fCM=u"/Users/gilles/sDrive/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/CM.csv"
fAliasQDLE=u"/Users/gilles/sDrive/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Quizz-Alias.yaml"
fQuizzoodle=u"/Users/gilles/sDrive/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Quizz-%s.csv"%sQuizz
# fQuizzoodle=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-UE4-Morphologie/24-Quizz/Quizz-%s.csv"%sQuizz
fNotes=fQuizzoodle.replace(u".csv",u"-Notes.csv")
print fCM,fQuizzoodle
# Out:
# /Users/gilles/sDrive/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/CM.csv /Users/gilles/sDrive/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Quizz-02.csv

# %%
'''https://stackoverflow.com/a/35491326/3986209'''
def invert_dict(d): 
    inverse = dict() 
    for key in d: 
        # Go through the list that is saved in the dict:
        for item in d[key]:
            # Check if in the inverted dict the key exists
            if item not in inverse: 
                # If not create a new list
                inverse[item] = [key] 
            else: 
                inverse[item].append(key) 
    return inverse

# %% [markdown]
# # Lecture des données

# %%
try:
    with codecs.open(fAliasQDLE, 'r', encoding="utf8") as inFile:
        correspondances=yaml.safe_load(inFile)
    alias=correspondances["alias2etu"]
except:
    alias={}
# alias

# %%
len(alias)
# Out:
# 0

# %%
colCM=[u"id",u"nom",u"prénom",u"email",u"ine"]
colQuizz=["pseudo","points","temps"]

try:
    dfCM=pd.read_csv(fCM,sep="\t",encoding="utf8",header=0,names=colCM)
    lQuizz=pd.read_csv(fQuizzoodle,sep=";",encoding="utf8",header=0,names=colQuizz)
    lQuizz.pseudo=lQuizz.pseudo.str.strip()
except:
    dfCM=None
    lQuizz=None

# %%
lQuizz, dfCM
# Out:
# (                         pseudo  points   temps
#  0                 Elisa-Fougere       7  122.70
#  1            anais - bonetbelts       7  207.85
#  2                Kameron rouyat       6  155.40
#  3                 louise-laveau       6  174.30
#  4                   lwann-albon       6  175.06
#  5               nélia-agletiner       6  191.11
#  6                louhane-crowin       6  200.09
#  7                Fevre Faustine       6  205.62
#  8            Tiphaine-Mignardot       5  163.42
#  9              Eleonore Courtot       5  203.58
#  10   élisa-coureau. manon-rhode       5  204.03
#  11              ingrid fletcher       5  230.75
#  12    roxane Saïs, Nina callede       5  238.89
#  13                         lana       5  250.73
#  14           Alaïa Robin Deguil       5  263.92
#  15                   Sema-Canli       5  264.03
#  16                Manon-freyche       5  292.83
#  17              victoria-delhay       4  161.33
#  18            Mélissandre-Riaud       4  166.19
#  19                     lena-erc       4  190.56
#  20  Juliette-camut Lila-Capraja       4  197.00
#  21               Coppélia seydi       4  204.80
#  22                Adèle-stidler       4  204.85
#  23           Mathilde Bessonart       4  205.38
#  24            Mathieu-Monteille       4  215.20
#  25             melissa-johannet       4  231.20
#  26                  Nassim Zahi       4  234.29
#  27   Yuna-Gicquel. Adelie-almon       4  245.18
#  28                Elisa Lucante       4  246.37
#  29                Léonie-Dupouy       4  256.86
#  30              Chloé- Cartigny       4  262.24
#  31             Sannah MAURINIER       4  267.33
#  32              milena-hamilton       4  273.05
#  33                       Andréa       4  275.49
#  34       Maëna -Lamolère Phelep       4  277.01
#  35              Pagnoux Albanne       4  317.92
#  36                 Joakim-Lubin       4  349.84
#  37           Simone_PRISCA_VAVY       4  402.67
#  38                lucie riviere       3  152.64
#  39               elisa-specogna       3  172.00
#  40             Oceane-defreitas       3  199.36
#  41               rihanna - lair       3  204.45
#  42                mintou_ndiaye       3  212.51
#  43                sarah-guellil       3  213.35
#  44               Jérémie-Dubois       3  219.54
#  45                Maela-Auguste       3  237.99
#  46                  Anais-manus       3  241.58
#  47              timothy-andrade       3  250.71
#  48       Julia-Anoge-Elsa-Dumas       3  280.16
#  49                 chloé-artola       2  182.47
#  50                manon-olivier       2  196.09
#  51            Lina-Bourchachene       2  211.12
#  52                zoé-marostica       2  217.69
#  53                    Mame-Diop       2  267.99
#  54               Omeïma-Bourema       2  280.30
#  55               louise dutheil       1  184.02
#  56                Giulia Nisini       0    4.06
#  57               GUETATFA Ilhem       0  192.95,
#           id                 nom                prénom  \
#  0    455717     ABDALLAH TOMANY                SHAIMA
#  1    429665          ABDELJALIL                  LINA
#  2    461076               AGGAR                 LYDIA
#  3    458113           AGLETINER                 NELIA
#  4    396581               ALBON                 LWANN
#  5    459692               ALMON                ADELIE
#  6    446215             ALTENOR               SERIANE
#  7    435583    ANDRAC-PEPERMANS                  NELL
#  8    414295             ANDRADE               TIMOTHY
#  9    461104               ANOGE                 JULIA
#  10   458613              ARTOLA                 CHLOE
#  11   441237     ATAM-KASSIGADOU                 ELIZA
#  12   456651             AUGUSTE                 MAELA
#  13   457795              BARBRY                  LILY
#  14   445372               BARBU          MATEI-TEODOR
#  15   460351          BELFERKOUS                MAISSA
#  16   434036           BENAOUDIA                AHCENE
#  17   457173           BESSONART              MATHILDE
#  18   460714               BLANC               LAURINE
#  19   458790           BLANCHARD                ANDREA
#  20   454875          BONETBELTS                 ANAIS
#  21   460512               BOUIN             VALENTINE
#  22   458727        BOURCHACHENE                  LINA
#  23   416701             BOUREMA                OMEIMA
#  24   450856        CAID ESSEBSI                  NOUR
#  25   458609             CALLEDE                  NINA
#  26   459964           CAMBARRAT               MARGAUX
#  27   446384               CAMUT              JULIETTE
#  28   456710               CANLI                  SEMA
#  29   457965             CAPRAJA                  LILA
#  ..      ...                 ...                   ...
#  132  460309             POINSOT              KATHLEEN
#  133  459745  POULET--CONSTANTIN                  ANNA
#  134  454341   POVEDA-DURASTANTI                MAELLE
#  135  458341              PREVOT                  EMMA
#  136  462574         PRISCA VAVY                SIMONE
#  137  458209              QARTIT                SHAIMA
#  138  457340            RAFFALLI           MARIE-DIANE
#  139  461334         RAHARIJAONA  MIARANA HAMY FITAHIA
#  140  460054     RAOULT--DESTOUR               ARTEMIS
#  141  426755             RECULET                MARIUS
#  142  458667               RHODE                 MANON
#  143  450931               RIAUD           MELISSANDRE
#  144  458319             RICHAUD                 CHLOE
#  145  461303            RICHAUME                JULIEN
#  146  441018             RIVIERE                 LUCIE
#  147  458551       ROBIN--DEGUIL                 ALAIA
#  148  461847              ROUYAT               KAMERON
#  149  454123               SAIDI              NOUHAILA
#  150  455153                SAIS                ROXANE
#  151  382568               SAUZE                THOMAS
#  152  460084               SEYDI              COPPELIA
#  153  446347            SIGISCAR               CANDYCE
#  154  459660             SOUCHET              BEATRICE
#  155  458747            SPECOGNA                 ELISA
#  156  460488             STIDLER                 ADELE
#  157  457363                TANG           YING CHEUNG
#  158  459756              TIXIER               AMELYNE
#  159  453907              VAGNER               CORALIE
#  160  460525                ZAHI                NASSIM
#  161  460114               ZAIRI                NAOMIE
#
#                                                   email         ine
#  0    shaima.abdallah-tomany@etu.u-bordeaux-montaign...  1772291711
#  1          lina.abdeljalil@etu.u-bordeaux-montaigne.fr  1772291711
#  2              lydia.aggar@etu.u-bordeaux-montaigne.fr  1772291711
#  3          nelia.agletiner@etu.u-bordeaux-montaigne.fr  1772291711
#  4              lwann.albon@etu.u-bordeaux-montaigne.fr  1772291711
#  5             adelie.almon@etu.u-bordeaux-montaigne.fr  1772291711
#  6          seriane.altenor@etu.u-bordeaux-montaigne.fr  1772291711
#  7    nell.andrac-pepermans@etu.u-bordeaux-montaigne.fr  1772291711
#  8          timothy.andrade@etu.u-bordeaux-montaigne.fr  1772291711
#  9              julia.anoge@etu.u-bordeaux-montaigne.fr  1772291711
#  10            chloe.artola@etu.u-bordeaux-montaigne.fr  1772291711
#  11   eliza.atam-kassigadou@etu.u-bordeaux-montaigne.fr  1772291711
#  12           maela.auguste@etu.u-bordeaux-montaigne.fr  1772291711
#  13             lily.barbry@etu.u-bordeaux-montaigne.fr  1772291711
#  14      matei-teodor.barbu@etu.u-bordeaux-montaigne.fr  1772291711
#  15       maissa.belferkous@etu.u-bordeaux-montaigne.fr  1772291711
#  16        ahcene.benaoudia@etu.u-bordeaux-montaigne.fr  1772291711
#  17      mathilde.bessonart@etu.u-bordeaux-montaigne.fr  1772291711
#  18           laurine.blanc@etu.u-bordeaux-montaigne.fr  1772291711
#  19        andrea.blanchard@etu.u-bordeaux-montaigne.fr  1772291711
#  20        anais.bonetbelts@etu.u-bordeaux-montaigne.fr  1772291711
#  21         valentine.bouin@etu.u-bordeaux-montaigne.fr  1772291711
#  22       lina.bourchachene@etu.u-bordeaux-montaigne.fr  1772291711
#  23          omeima.bourema@etu.u-bordeaux-montaigne.fr  1772291711
#  24       nour.caid-essebsi@etu.u-bordeaux-montaigne.fr  1772291711
#  25            nina.callede@etu.u-bordeaux-montaigne.fr  1772291711
#  26       margaux.cambarrat@etu.u-bordeaux-montaigne.fr  1772291711
#  27          juliette.camut@etu.u-bordeaux-montaigne.fr  1772291711
#  28              sema.canli@etu.u-bordeaux-montaigne.fr  1772291711
#  29            lila.capraja@etu.u-bordeaux-montaigne.fr  1772291711
#  ..                                                 ...         ...
#  132       kathleen.poinsot@etu.u-bordeaux-montaigne.fr  1772291711
#  133  anna.poulet--constantin@etu.u-bordeaux-montaig...  1772291711
#  134  maelle.poveda-durastanti@etu.u-bordeaux-montai...  1772291711
#  135            emma.prevot@etu.u-bordeaux-montaigne.fr  1772291711
#  136     simone.prisca-vavy@etu.u-bordeaux-montaigne.fr  1772291711
#  137          shaima.qartit@etu.u-bordeaux-montaigne.fr  1772291711
#  138   marie-diane.raffalli@etu.u-bordeaux-montaigne.fr  1772291711
#  139  miarana-hamy-fitahia.raharijaona@etu.u-bordeau...  1772291711
#  140  artemis.raoult--destour@etu.u-bordeaux-montaig...  1772291711
#  141         marius.reculet@etu.u-bordeaux-montaigne.fr  1772291711
#  142            manon.rhode@etu.u-bordeaux-montaigne.fr  1772291711
#  143      melissandre.riaud@etu.u-bordeaux-montaigne.fr  1772291711
#  144          chloe.richaud@etu.u-bordeaux-montaigne.fr  1772291711
#  145        julien.richaume@etu.u-bordeaux-montaigne.fr  1772291711
#  146         lucie.riviere1@etu.u-bordeaux-montaigne.fr  1772291711
#  147    alaia.robin--deguil@etu.u-bordeaux-montaigne.fr  1772291711
#  148         kameron.rouyat@etu.u-bordeaux-montaigne.fr  1772291711
#  149         nouhaila.saidi@etu.u-bordeaux-montaigne.fr  1772291711
#  150            roxane.sais@etu.u-bordeaux-montaigne.fr  1772291711
#  151           thomas.sauze@etu.u-bordeaux-montaigne.fr  1772291711
#  152         coppelia.seydi@etu.u-bordeaux-montaigne.fr  1772291711
#  153       candyce.sigiscar@etu.u-bordeaux-montaigne.fr  1772291711
#  154       beatrice.souchet@etu.u-bordeaux-montaigne.fr  1772291711
#  155         elisa.specogna@etu.u-bordeaux-montaigne.fr  1772291711
#  156          adele.stidler@etu.u-bordeaux-montaigne.fr  1772291711
#  157       ying-cheung.tang@etu.u-bordeaux-montaigne.fr  1772291711
#  158         amelyne.tixier@etu.u-bordeaux-montaigne.fr  1772291711
#  159         coralie.vagner@etu.u-bordeaux-montaigne.fr  1772291711
#  160            nassim.zahi@etu.u-bordeaux-montaigne.fr  1772291711
#  161           naomie.zairi@etu.u-bordeaux-montaigne.fr  1772291711
#
#  [162 rows x 5 columns])

# %%
pseudos=lQuizz[~(lQuizz["pseudo"].isin(alias))]["pseudo"].str.strip().tolist()
print "\n".join(pseudos)
# Out:
# Elisa-Fougere
# anais - bonetbelts
# Kameron rouyat
# louise-laveau
# lwann-albon
# nélia-agletiner
# louhane-crowin
# Fevre Faustine
# Tiphaine-Mignardot
# Eleonore Courtot
# élisa-coureau. manon-rhode
# ingrid fletcher
# roxane Saïs, Nina callede
# lana
# Alaïa Robin Deguil
# Sema-Canli
# Manon-freyche
# victoria-delhay
# Mélissandre-Riaud
# lena-erc
# Juliette-camut Lila-Capraja
# Coppélia seydi
# Adèle-stidler
# Mathilde Bessonart
# Mathieu-Monteille
# melissa-johannet
# Nassim Zahi
# Yuna-Gicquel. Adelie-almon
# Elisa Lucante
# Léonie-Dupouy
# Chloé- Cartigny
# Sannah MAURINIER
# milena-hamilton
# Andréa
# Maëna -Lamolère Phelep
# Pagnoux Albanne
# Joakim-Lubin
# Simone_PRISCA_VAVY
# lucie riviere
# elisa-specogna
# Oceane-defreitas
# rihanna - lair
# mintou_ndiaye
# sarah-guellil
# Jérémie-Dubois
# Maela-Auguste
# Anais-manus
# timothy-andrade
# Julia-Anoge-Elsa-Dumas
# chloé-artola
# manon-olivier
# Lina-Bourchachene
# zoé-marostica
# Mame-Diop
# Omeïma-Bourema
# louise dutheil
# Giulia Nisini
# GUETATFA Ilhem

# %% [markdown]
# # Listage des alias

# %%
dfCM["PN"]=dfCM[u"prénom"].str.lower().str.strip()+" "+dfCM[u"nom"].str.lower().str.strip()
dfCM["NP"]=dfCM[u"nom"].str.lower().str.strip()+" "+dfCM[u"prénom"].str.lower().str.strip()
dfCM["P-N"]=dfCM[u"prénom"].str.lower().str.strip()+"-"+dfCM[u"nom"].str.lower().str.strip()
dfCM["N-P"]=dfCM[u"nom"].str.lower().str.strip()+"-"+dfCM[u"prénom"].str.lower().str.strip()
dfCM["P.N"]=dfCM[u"prénom"].str.lower().str.strip()+"."+dfCM[u"nom"].str.lower().str.strip()
dfCM["N.P"]=dfCM[u"nom"].str.lower().str.strip()+"."+dfCM[u"prénom"].str.lower().str.strip()
# dfCM

# %% [raw]
# pn=dfCM["PN"].tolist()
# p_n=dfCM["P-N"].tolist()
# np=dfCM["NP"].tolist()
# n_p=dfCM["N-P"].tolist()

# %%
pn=dfCM["PN"].tolist()
pnT=dfCM["P-N"].tolist()
pnD=dfCM["P.N"].tolist()
np=dfCM["NP"].tolist()
npT=dfCM["N-P"].tolist()
npD=dfCM["N.P"].tolist()
lNomPrenom={"PN":pn,"P-N":pnT,"P.N":pnD,"NP":np,"N-P":npT,"N.P":npD}

# %%
for pseudo in pseudos:
    for nomPrenom in lNomPrenom:
        if unidecode.unidecode(pseudo.lower()) in lNomPrenom[nomPrenom]:
            print pseudo,dfCM[dfCM[nomPrenom]==unidecode.unidecode(pseudo.lower())]["id"].values[0]
            alias[pseudo]=[str(dfCM[dfCM[nomPrenom]==unidecode.unidecode(pseudo.lower())]["id"].values[0])]
# Out:
# Elisa-Fougere 463682
# Kameron rouyat 461847
# louise-laveau 457952
# lwann-albon 396581
# nélia-agletiner 458113
# louhane-crowin 453815
# Fevre Faustine 456672
# Tiphaine-Mignardot 456686
# Sema-Canli 456710
# Manon-freyche 457558
# victoria-delhay 458356
# Mélissandre-Riaud 450931
# Coppélia seydi 460084
# Adèle-stidler 460488
# Mathilde Bessonart 457173
# Mathieu-Monteille 454079
# melissa-johannet 455719
# Nassim Zahi 460525
# Elisa Lucante 457483
# Léonie-Dupouy 456690
# Sannah MAURINIER 460392
# milena-hamilton 452779
# Joakim-Lubin 457111
# lucie riviere 441018
# elisa-specogna 458747
# sarah-guellil 461900
# Jérémie-Dubois 459971
# Maela-Auguste 456651
# Anais-manus 457731
# timothy-andrade 414295
# chloé-artola 458613
# manon-olivier 454852
# Lina-Bourchachene 458727
# zoé-marostica 453892
# Mame-Diop 462309
# Omeïma-Bourema 416701
# louise dutheil 449639
# Giulia Nisini 463562
# GUETATFA Ilhem 447671

# %%
pseudos=lQuizz[~(lQuizz["pseudo"].isin(alias))]["pseudo"].str.strip().tolist()
print "\n".join(pseudos)
# Out:
# anais - bonetbelts
# Eleonore Courtot
# élisa-coureau. manon-rhode
# ingrid fletcher
# roxane Saïs, Nina callede
# lana
# Alaïa Robin Deguil
# lena-erc
# Juliette-camut Lila-Capraja
# Yuna-Gicquel. Adelie-almon
# Chloé- Cartigny
# Andréa
# Maëna -Lamolère Phelep
# Pagnoux Albanne
# Simone_PRISCA_VAVY
# Oceane-defreitas
# rihanna - lair
# mintou_ndiaye
# Julia-Anoge-Elsa-Dumas

# %%
for nP,pseudoBrut in enumerate(pseudos):
    pseudo=unidecode.unidecode(pseudoBrut)
    print pseudo
    sPseudo = raw_input("Nom a chercher:\n")
    if sPseudo:
        print dfCM[dfCM["PN"].str.contains(sPseudo.lower())][["PN","id"]]
        idPseudo=raw_input("id :\n")
        if idPseudo:
            alias[pseudoBrut]=idPseudo
# Out:
# anais - bonetbelts
# Nom a chercher:
#  bone
#                   PN      id
# 20  anais bonetbelts  454875
# id :
#  454875
# Eleonore Courtot
# Nom a chercher:
#  courto
#                            PN      id
# 40  eleonore courtot--coussel  459136
# id :
#  459136
# elisa-coureau. manon-rhode
# Nom a chercher:
#  coureau
#                PN      id
# 39  elisa coureau  459406
# id :
#  459406 458667
# ingrid fletcher
# Nom a chercher:
#  fletch
#                                PN      id
# 66  ingrid jayne mcgowan fletcher  463523
# id :
#  463523
# roxane Sais, Nina callede
# Nom a chercher:
#  sais
#               PN      id
# 150  roxane sais  455153
# id :
#  455153 458609
# lana
# Nom a chercher:
#  lana
#                 PN      id
# 87  lana jansonnie  460037
# id :
#  460037
# Alaia Robin Deguil
# Nom a chercher:
#  robin
#                       PN      id
# 147  alaia robin--deguil  458551
# id :
#  458551
# lena-erc
# Nom a chercher:
#  lena
#                       PN      id
# 58  lena erceau--coussel  460829
# 78       milena hamilton  452779
# id :
#  460829
# Juliette-camut Lila-Capraja
# Nom a chercher:
#  camut
#                 PN      id
# 27  juliette camut  446384
# id :
#  446384 457965
# Yuna-Gicquel. Adelie-almon
# Nom a chercher:
#  gicqu
#               PN      id
# 72  yuna gicquel  456846
# id :
#  456846 459692
# Chloe- Cartigny
# Nom a chercher:
#  cartig
#                 PN      id
# 32  chloe cartigny  453789
# id :
#  453789
# Andrea
# Nom a chercher:
#  andrea
#                   PN      id
# 19  andrea blanchard  458790
# id :
#  458790
# Maena -Lamolere Phelep
# Nom a chercher:
#  lamoler
#                         PN      id
# 96  maena lamolere--phelep  457961
# id :
#  457961
# Pagnoux Albanne
# Nom a chercher:
#  pagnou
#                               PN      id
# 128  albanne pagnoux--pellegrino  460344
# id :
#  460344
# Simone_PRISCA_VAVY
# Nom a chercher:
#  prisca
#                      PN      id
# 136  simone prisca vavy  462574
# id :
#  462574
# Oceane-defreitas
# Nom a chercher:
#  oceane
#                    PN      id
# 45  oceane de freitas  458657
# id :
#  458657
# rihanna - lair
# Nom a chercher:
#  lair
#               PN      id
# 95  rihanna lair  456402
# id :
#  456402
# mintou_ndiaye
# Nom a chercher:
#  mintou
#                 PN      id
# 125  mintou ndiaye  460169
# id :
#  460169
# Julia-Anoge-Elsa-Dumas
# Nom a chercher:
#  anoge
#             PN      id
# 9  julia anoge  461104
# id :
#  461104 461325

# %% [raw]
# for k,v in alias.iteritems():
#     print k,v[0][0][0]
#     alias[k]=v[0][0][0].split(" ")
# alias

# %%
# pseudo=u"csaintavi001 ebismes001"
# alias[pseudo]=["415962","413429"]

# %%
sPseudo="bisme"
print dfCM[dfCM["PN"].str.contains(sPseudo.lower())][["PN","id"]]
# Out:
# Empty DataFrame
# Columns: [PN, id]
# Index: []

# %%
pseudos
# Out:
# [u'anais - bonetbelts',
#  u'Eleonore Courtot',
#  u'\xe9lisa-coureau. manon-rhode',
#  u'ingrid fletcher',
#  u'roxane Sa\xefs, Nina callede',
#  u'lana',
#  u'Ala\xefa Robin Deguil',
#  u'lena-erc',
#  u'Juliette-camut Lila-Capraja',
#  u'Yuna-Gicquel. Adelie-almon',
#  u'Chlo\xe9- Cartigny',
#  u'Andr\xe9a',
#  u'Ma\xebna -Lamol\xe8re Phelep',
#  u'Pagnoux Albanne',
#  u'Simone_PRISCA_VAVY',
#  u'Oceane-defreitas',
#  u'rihanna - lair',
#  u'mintou_ndiaye',
#  u'Julia-Anoge-Elsa-Dumas']

# %%
# alias["Sofiane"]

# %%
for al in alias:
    if not isinstance(alias[al],list):
        if " " in alias[al]:
            alias[al]=alias[al].split(" ")
        else:
            alias[al]=[alias[al]]

# %%
len(alias)
# Out:
# 58

# %%
invAlias=invert_dict(alias)
#invAlias[385732]=[u'adiarra001, cbeauvais004']
correspondances={"alias2etu":alias,"etu2alias":invAlias}
correspondances
# Out:
# {'alias2etu': {u'Ad\xe8le-stidler': ['460488'],
#   u'Ala\xefa Robin Deguil': ['458551'],
#   u'Anais-manus': ['457731'],
#   u'Andr\xe9a': ['458790'],
#   u'Chlo\xe9- Cartigny': ['453789'],
#   u'Copp\xe9lia seydi': ['460084'],
#   u'Eleonore Courtot': ['459136'],
#   u'Elisa Lucante': ['457483'],
#   u'Elisa-Fougere': ['463682'],
#   u'Fevre Faustine': ['456672'],
#   u'GUETATFA Ilhem': ['447671'],
#   u'Giulia Nisini': ['463562'],
#   u'Joakim-Lubin': ['457111'],
#   u'Julia-Anoge-Elsa-Dumas': ['461104', '461325'],
#   u'Juliette-camut Lila-Capraja': ['446384', '457965'],
#   u'J\xe9r\xe9mie-Dubois': ['459971'],
#   u'Kameron rouyat': ['461847'],
#   u'Lina-Bourchachene': ['458727'],
#   u'L\xe9onie-Dupouy': ['456690'],
#   u'Maela-Auguste': ['456651'],
#   u'Mame-Diop': ['462309'],
#   u'Manon-freyche': ['457558'],
#   u'Mathieu-Monteille': ['454079'],
#   u'Mathilde Bessonart': ['457173'],
#   u'Ma\xebna -Lamol\xe8re Phelep': ['457961'],
#   u'M\xe9lissandre-Riaud': ['450931'],
#   u'Nassim Zahi': ['460525'],
#   u'Oceane-defreitas': ['458657'],
#   u'Ome\xefma-Bourema': ['416701'],
#   u'Pagnoux Albanne': ['460344'],
#   u'Sannah MAURINIER': ['460392'],
#   u'Sema-Canli': ['456710'],
#   u'Simone_PRISCA_VAVY': ['462574'],
#   u'Tiphaine-Mignardot': ['456686'],
#   u'Yuna-Gicquel. Adelie-almon': ['456846', '459692'],
#   u'anais - bonetbelts': ['454875'],
#   u'chlo\xe9-artola': ['458613'],
#   u'elisa-specogna': ['458747'],
#   u'ingrid fletcher': ['463523'],
#   u'lana': ['460037'],
#   u'lena-erc': ['460829'],
#   u'louhane-crowin': ['453815'],
#   u'louise dutheil': ['449639'],
#   u'louise-laveau': ['457952'],
#   u'lucie riviere': ['441018'],
#   u'lwann-albon': ['396581'],
#   u'manon-olivier': ['454852'],
#   u'melissa-johannet': ['455719'],
#   u'milena-hamilton': ['452779'],
#   u'mintou_ndiaye': ['460169'],
#   u'n\xe9lia-agletiner': ['458113'],
#   u'rihanna - lair': ['456402'],
#   u'roxane Sa\xefs, Nina callede': ['455153', '458609'],
#   u'sarah-guellil': ['461900'],
#   u'timothy-andrade': ['414295'],
#   u'victoria-delhay': ['458356'],
#   u'zo\xe9-marostica': ['453892'],
#   u'\xe9lisa-coureau. manon-rhode': ['459406', '458667']},
#  'etu2alias': {'396581': [u'lwann-albon'],
#   '414295': [u'timothy-andrade'],
#   '416701': [u'Ome\xefma-Bourema'],
#   '441018': [u'lucie riviere'],
#   '446384': [u'Juliette-camut Lila-Capraja'],
#   '447671': [u'GUETATFA Ilhem'],
#   '449639': [u'louise dutheil'],
#   '450931': [u'M\xe9lissandre-Riaud'],
#   '452779': [u'milena-hamilton'],
#   '453789': [u'Chlo\xe9- Cartigny'],
#   '453815': [u'louhane-crowin'],
#   '453892': [u'zo\xe9-marostica'],
#   '454079': [u'Mathieu-Monteille'],
#   '454852': [u'manon-olivier'],
#   '454875': [u'anais - bonetbelts'],
#   '455153': [u'roxane Sa\xefs, Nina callede'],
#   '455719': [u'melissa-johannet'],
#   '456402': [u'rihanna - lair'],
#   '456651': [u'Maela-Auguste'],
#   '456672': [u'Fevre Faustine'],
#   '456686': [u'Tiphaine-Mignardot'],
#   '456690': [u'L\xe9onie-Dupouy'],
#   '456710': [u'Sema-Canli'],
#   '456846': [u'Yuna-Gicquel. Adelie-almon'],
#   '457111': [u'Joakim-Lubin'],
#   '457173': [u'Mathilde Bessonart'],
#   '457483': [u'Elisa Lucante'],
#   '457558': [u'Manon-freyche'],
#   '457731': [u'Anais-manus'],
#   '457952': [u'louise-laveau'],
#   '457961': [u'Ma\xebna -Lamol\xe8re Phelep'],
#   '457965': [u'Juliette-camut Lila-Capraja'],
#   '458113': [u'n\xe9lia-agletiner'],
#   '458356': [u'victoria-delhay'],
#   '458551': [u'Ala\xefa Robin Deguil'],
#   '458609': [u'roxane Sa\xefs, Nina callede'],
#   '458613': [u'chlo\xe9-artola'],
#   '458657': [u'Oceane-defreitas'],
#   '458667': [u'\xe9lisa-coureau. manon-rhode'],
#   '458727': [u'Lina-Bourchachene'],
#   '458747': [u'elisa-specogna'],
#   '458790': [u'Andr\xe9a'],
#   '459136': [u'Eleonore Courtot'],
#   '459406': [u'\xe9lisa-coureau. manon-rhode'],
#   '459692': [u'Yuna-Gicquel. Adelie-almon'],
#   '459971': [u'J\xe9r\xe9mie-Dubois'],
#   '460037': [u'lana'],
#   '460084': [u'Copp\xe9lia seydi'],
#   '460169': [u'mintou_ndiaye'],
#   '460344': [u'Pagnoux Albanne'],
#   '460392': [u'Sannah MAURINIER'],
#   '460488': [u'Ad\xe8le-stidler'],
#   '460525': [u'Nassim Zahi'],
#   '460829': [u'lena-erc'],
#   '461104': [u'Julia-Anoge-Elsa-Dumas'],
#   '461325': [u'Julia-Anoge-Elsa-Dumas'],
#   '461847': [u'Kameron rouyat'],
#   '461900': [u'sarah-guellil'],
#   '462309': [u'Mame-Diop'],
#   '462574': [u'Simone_PRISCA_VAVY'],
#   '463523': [u'ingrid fletcher'],
#   '463562': [u'Giulia Nisini'],
#   '463682': [u'Elisa-Fougere']}}

# %%
with codecs.open(fAliasQDLE, 'w', encoding="utf8") as outfile:
    yaml.safe_dump(correspondances, outfile, default_flow_style=False)

# %% [markdown]
# # Calcul des notes
# Attention au nombre de questions

# %%
nbQuestions=[7,7,7,7,7,7,7,6,6,6,6]
nbQuestions=[7,7,7,7,7,7,6,6,6,6,6]
nbQ=float(nbQuestions[nQuizz-1])
print nbQ
# Out:
# 7.0

# %%
def aliasQuizz(pseudo):
    result=None
    if pseudo in alias:
        result=alias[pseudo]
    return result

def noteQuizz(points):   
    result=8
    if points>0:
        result=int(round(10*(1+points/nbQ),0))
    return result
        
        

lQuizz["id"]=lQuizz["pseudo"].apply(aliasQuizz)
lQuizz["note"]=lQuizz["points"].apply(noteQuizz)

# %%
def splitPseudo1(id):
    result=None
    if id and len(id)>0:
        result=id[0]
    return result

def splitPseudo2(id):
    result=None
    if id and len(id)>1:
        result=id[1]
    return result

def splitPseudo3(id):
    result=None
    if id and len(id)>2:
        result=id[2]
    return result

lQuizz["id1"]=lQuizz["id"].apply(splitPseudo1)
lQuizz["id2"]=lQuizz["id"].apply(splitPseudo2)
lQuizz["id3"]=lQuizz["id"].apply(splitPseudo3)

lQuizz
# Out:
#                          pseudo  points   temps                id  note  \
# 0                 Elisa-Fougere       7  122.70          [463682]    20
# 1            anais - bonetbelts       7  207.85          [454875]    20
# 2                Kameron rouyat       6  155.40          [461847]    19
# 3                 louise-laveau       6  174.30          [457952]    19
# 4                   lwann-albon       6  175.06          [396581]    19
# 5               nélia-agletiner       6  191.11          [458113]    19
# 6                louhane-crowin       6  200.09          [453815]    19
# 7                Fevre Faustine       6  205.62          [456672]    19
# 8            Tiphaine-Mignardot       5  163.42          [456686]    17
# 9              Eleonore Courtot       5  203.58          [459136]    17
# 10   élisa-coureau. manon-rhode       5  204.03  [459406, 458667]    17
# 11              ingrid fletcher       5  230.75          [463523]    17
# 12    roxane Saïs, Nina callede       5  238.89  [455153, 458609]    17
# 13                         lana       5  250.73          [460037]    17
# 14           Alaïa Robin Deguil       5  263.92          [458551]    17
# 15                   Sema-Canli       5  264.03          [456710]    17
# 16                Manon-freyche       5  292.83          [457558]    17
# 17              victoria-delhay       4  161.33          [458356]    16
# 18            Mélissandre-Riaud       4  166.19          [450931]    16
# 19                     lena-erc       4  190.56          [460829]    16
# 20  Juliette-camut Lila-Capraja       4  197.00  [446384, 457965]    16
# 21               Coppélia seydi       4  204.80          [460084]    16
# 22                Adèle-stidler       4  204.85          [460488]    16
# 23           Mathilde Bessonart       4  205.38          [457173]    16
# 24            Mathieu-Monteille       4  215.20          [454079]    16
# 25             melissa-johannet       4  231.20          [455719]    16
# 26                  Nassim Zahi       4  234.29          [460525]    16
# 27   Yuna-Gicquel. Adelie-almon       4  245.18  [456846, 459692]    16
# 28                Elisa Lucante       4  246.37          [457483]    16
# 29                Léonie-Dupouy       4  256.86          [456690]    16
# 30              Chloé- Cartigny       4  262.24          [453789]    16
# 31             Sannah MAURINIER       4  267.33          [460392]    16
# 32              milena-hamilton       4  273.05          [452779]    16
# 33                       Andréa       4  275.49          [458790]    16
# 34       Maëna -Lamolère Phelep       4  277.01          [457961]    16
# 35              Pagnoux Albanne       4  317.92          [460344]    16
# 36                 Joakim-Lubin       4  349.84          [457111]    16
# 37           Simone_PRISCA_VAVY       4  402.67          [462574]    16
# 38                lucie riviere       3  152.64          [441018]    14
# 39               elisa-specogna       3  172.00          [458747]    14
# 40             Oceane-defreitas       3  199.36          [458657]    14
# 41               rihanna - lair       3  204.45          [456402]    14
# 42                mintou_ndiaye       3  212.51          [460169]    14
# 43                sarah-guellil       3  213.35          [461900]    14
# 44               Jérémie-Dubois       3  219.54          [459971]    14
# 45                Maela-Auguste       3  237.99          [456651]    14
# 46                  Anais-manus       3  241.58          [457731]    14
# 47              timothy-andrade       3  250.71          [414295]    14
# 48       Julia-Anoge-Elsa-Dumas       3  280.16  [461104, 461325]    14
# 49                 chloé-artola       2  182.47          [458613]    13
# 50                manon-olivier       2  196.09          [454852]    13
# 51            Lina-Bourchachene       2  211.12          [458727]    13
# 52                zoé-marostica       2  217.69          [453892]    13
# 53                    Mame-Diop       2  267.99          [462309]    13
# 54               Omeïma-Bourema       2  280.30          [416701]    13
# 55               louise dutheil       1  184.02          [449639]    11
# 56                Giulia Nisini       0    4.06          [463562]     8
# 57               GUETATFA Ilhem       0  192.95          [447671]     8
#
#        id1     id2   id3
# 0   463682    None  None
# 1   454875    None  None
# 2   461847    None  None
# 3   457952    None  None
# 4   396581    None  None
# 5   458113    None  None
# 6   453815    None  None
# 7   456672    None  None
# 8   456686    None  None
# 9   459136    None  None
# 10  459406  458667  None
# 11  463523    None  None
# 12  455153  458609  None
# 13  460037    None  None
# 14  458551    None  None
# 15  456710    None  None
# 16  457558    None  None
# 17  458356    None  None
# 18  450931    None  None
# 19  460829    None  None
# 20  446384  457965  None
# 21  460084    None  None
# 22  460488    None  None
# 23  457173    None  None
# 24  454079    None  None
# 25  455719    None  None
# 26  460525    None  None
# 27  456846  459692  None
# 28  457483    None  None
# 29  456690    None  None
# 30  453789    None  None
# 31  460392    None  None
# 32  452779    None  None
# 33  458790    None  None
# 34  457961    None  None
# 35  460344    None  None
# 36  457111    None  None
# 37  462574    None  None
# 38  441018    None  None
# 39  458747    None  None
# 40  458657    None  None
# 41  456402    None  None
# 42  460169    None  None
# 43  461900    None  None
# 44  459971    None  None
# 45  456651    None  None
# 46  457731    None  None
# 47  414295    None  None
# 48  461104  461325  None
# 49  458613    None  None
# 50  454852    None  None
# 51  458727    None  None
# 52  453892    None  None
# 53  462309    None  None
# 54  416701    None  None
# 55  449639    None  None
# 56  463562    None  None
# 57  447671    None  None

# %%
df1=lQuizz[["pseudo","note","temps","id1"]].dropna()
df2=lQuizz[["pseudo","note","temps","id2"]].dropna()
df3=lQuizz[["pseudo","note","temps","id3"]].dropna()
df1.columns=["pseudo","note","temps","id"]
df2.columns=["pseudo","note","temps","id"]
df3.columns=["pseudo","note","temps","id"]

# %%
df123=pd.concat([df1,df2,df3]).sort_values(["note","temps"],ascending=[False,True]).reset_index(drop=True)
df123
# Out:
#                          pseudo  note   temps      id
# 0                 Elisa-Fougere    20  122.70  463682
# 1            anais - bonetbelts    20  207.85  454875
# 2                Kameron rouyat    19  155.40  461847
# 3                 louise-laveau    19  174.30  457952
# 4                   lwann-albon    19  175.06  396581
# 5               nélia-agletiner    19  191.11  458113
# 6                louhane-crowin    19  200.09  453815
# 7                Fevre Faustine    19  205.62  456672
# 8            Tiphaine-Mignardot    17  163.42  456686
# 9              Eleonore Courtot    17  203.58  459136
# 10   élisa-coureau. manon-rhode    17  204.03  459406
# 11   élisa-coureau. manon-rhode    17  204.03  458667
# 12              ingrid fletcher    17  230.75  463523
# 13    roxane Saïs, Nina callede    17  238.89  455153
# 14    roxane Saïs, Nina callede    17  238.89  458609
# 15                         lana    17  250.73  460037
# 16           Alaïa Robin Deguil    17  263.92  458551
# 17                   Sema-Canli    17  264.03  456710
# 18                Manon-freyche    17  292.83  457558
# 19              victoria-delhay    16  161.33  458356
# 20            Mélissandre-Riaud    16  166.19  450931
# 21                     lena-erc    16  190.56  460829
# 22  Juliette-camut Lila-Capraja    16  197.00  446384
# 23  Juliette-camut Lila-Capraja    16  197.00  457965
# 24               Coppélia seydi    16  204.80  460084
# 25                Adèle-stidler    16  204.85  460488
# 26           Mathilde Bessonart    16  205.38  457173
# 27            Mathieu-Monteille    16  215.20  454079
# 28             melissa-johannet    16  231.20  455719
# 29                  Nassim Zahi    16  234.29  460525
# ..                          ...   ...     ...     ...
# 33                Léonie-Dupouy    16  256.86  456690
# 34              Chloé- Cartigny    16  262.24  453789
# 35             Sannah MAURINIER    16  267.33  460392
# 36              milena-hamilton    16  273.05  452779
# 37                       Andréa    16  275.49  458790
# 38       Maëna -Lamolère Phelep    16  277.01  457961
# 39              Pagnoux Albanne    16  317.92  460344
# 40                 Joakim-Lubin    16  349.84  457111
# 41           Simone_PRISCA_VAVY    16  402.67  462574
# 42                lucie riviere    14  152.64  441018
# 43               elisa-specogna    14  172.00  458747
# 44             Oceane-defreitas    14  199.36  458657
# 45               rihanna - lair    14  204.45  456402
# 46                mintou_ndiaye    14  212.51  460169
# 47                sarah-guellil    14  213.35  461900
# 48               Jérémie-Dubois    14  219.54  459971
# 49                Maela-Auguste    14  237.99  456651
# 50                  Anais-manus    14  241.58  457731
# 51              timothy-andrade    14  250.71  414295
# 52       Julia-Anoge-Elsa-Dumas    14  280.16  461104
# 53       Julia-Anoge-Elsa-Dumas    14  280.16  461325
# 54                 chloé-artola    13  182.47  458613
# 55                manon-olivier    13  196.09  454852
# 56            Lina-Bourchachene    13  211.12  458727
# 57                zoé-marostica    13  217.69  453892
# 58                    Mame-Diop    13  267.99  462309
# 59               Omeïma-Bourema    13  280.30  416701
# 60               louise dutheil    11  184.02  449639
# 61                Giulia Nisini     8    4.06  463562
# 62               GUETATFA Ilhem     8  192.95  447671
#
# [63 rows x 4 columns]

# %%
df123.loc[(df123.note==8)&(df123.temps>0),"note"]=10

# %%
df123.loc[1,"note"]
# Out:
# 20

# %%
df123.at[0, 'note'] = 20
if df123.loc[1, "note"]<18:
    df123.at[1, 'note'] = 18
df123
# Out:
#                          pseudo  note   temps      id
# 0                 Elisa-Fougere    20  122.70  463682
# 1            anais - bonetbelts    20  207.85  454875
# 2                Kameron rouyat    19  155.40  461847
# 3                 louise-laveau    19  174.30  457952
# 4                   lwann-albon    19  175.06  396581
# 5               nélia-agletiner    19  191.11  458113
# 6                louhane-crowin    19  200.09  453815
# 7                Fevre Faustine    19  205.62  456672
# 8            Tiphaine-Mignardot    17  163.42  456686
# 9              Eleonore Courtot    17  203.58  459136
# 10   élisa-coureau. manon-rhode    17  204.03  459406
# 11   élisa-coureau. manon-rhode    17  204.03  458667
# 12              ingrid fletcher    17  230.75  463523
# 13    roxane Saïs, Nina callede    17  238.89  455153
# 14    roxane Saïs, Nina callede    17  238.89  458609
# 15                         lana    17  250.73  460037
# 16           Alaïa Robin Deguil    17  263.92  458551
# 17                   Sema-Canli    17  264.03  456710
# 18                Manon-freyche    17  292.83  457558
# 19              victoria-delhay    16  161.33  458356
# 20            Mélissandre-Riaud    16  166.19  450931
# 21                     lena-erc    16  190.56  460829
# 22  Juliette-camut Lila-Capraja    16  197.00  446384
# 23  Juliette-camut Lila-Capraja    16  197.00  457965
# 24               Coppélia seydi    16  204.80  460084
# 25                Adèle-stidler    16  204.85  460488
# 26           Mathilde Bessonart    16  205.38  457173
# 27            Mathieu-Monteille    16  215.20  454079
# 28             melissa-johannet    16  231.20  455719
# 29                  Nassim Zahi    16  234.29  460525
# ..                          ...   ...     ...     ...
# 33                Léonie-Dupouy    16  256.86  456690
# 34              Chloé- Cartigny    16  262.24  453789
# 35             Sannah MAURINIER    16  267.33  460392
# 36              milena-hamilton    16  273.05  452779
# 37                       Andréa    16  275.49  458790
# 38       Maëna -Lamolère Phelep    16  277.01  457961
# 39              Pagnoux Albanne    16  317.92  460344
# 40                 Joakim-Lubin    16  349.84  457111
# 41           Simone_PRISCA_VAVY    16  402.67  462574
# 42                lucie riviere    14  152.64  441018
# 43               elisa-specogna    14  172.00  458747
# 44             Oceane-defreitas    14  199.36  458657
# 45               rihanna - lair    14  204.45  456402
# 46                mintou_ndiaye    14  212.51  460169
# 47                sarah-guellil    14  213.35  461900
# 48               Jérémie-Dubois    14  219.54  459971
# 49                Maela-Auguste    14  237.99  456651
# 50                  Anais-manus    14  241.58  457731
# 51              timothy-andrade    14  250.71  414295
# 52       Julia-Anoge-Elsa-Dumas    14  280.16  461104
# 53       Julia-Anoge-Elsa-Dumas    14  280.16  461325
# 54                 chloé-artola    13  182.47  458613
# 55                manon-olivier    13  196.09  454852
# 56            Lina-Bourchachene    13  211.12  458727
# 57                zoé-marostica    13  217.69  453892
# 58                    Mame-Diop    13  267.99  462309
# 59               Omeïma-Bourema    13  280.30  416701
# 60               louise dutheil    11  184.02  449639
# 61                Giulia Nisini    10    4.06  463562
# 62               GUETATFA Ilhem    10  192.95  447671
#
# [63 rows x 4 columns]

# %%
dfNotes=df123.groupby("id").max().sort_values("note",ascending=False)
dfNotes.to_csv(fNotes,sep="\t",encoding="utf8")

# %%
dfNotes
# Out:
#                              pseudo  note   temps
# id
# 463682                Elisa-Fougere    20  122.70
# 454875           anais - bonetbelts    20  207.85
# 453815               louhane-crowin    19  200.09
# 461847               Kameron rouyat    19  155.40
# 458113              nélia-agletiner    19  191.11
# 457952                louise-laveau    19  174.30
# 456672               Fevre Faustine    19  205.62
# 396581                  lwann-albon    19  175.06
# 458609    roxane Saïs, Nina callede    17  238.89
# 456686           Tiphaine-Mignardot    17  163.42
# 457558                Manon-freyche    17  292.83
# 458667   élisa-coureau. manon-rhode    17  204.03
# 459136             Eleonore Courtot    17  203.58
# 459406   élisa-coureau. manon-rhode    17  204.03
# 456710                   Sema-Canli    17  264.03
# 460037                         lana    17  250.73
# 455153    roxane Saïs, Nina callede    17  238.89
# 463523              ingrid fletcher    17  230.75
# 458551           Alaïa Robin Deguil    17  263.92
# 460392             Sannah MAURINIER    16  267.33
# 460344              Pagnoux Albanne    16  317.92
# 460084               Coppélia seydi    16  204.80
# 458356              victoria-delhay    16  161.33
# 459692   Yuna-Gicquel. Adelie-almon    16  245.18
# 460488                Adèle-stidler    16  204.85
# 460525                  Nassim Zahi    16  234.29
# 460829                     lena-erc    16  190.56
# 458790                       Andréa    16  275.49
# 462574           Simone_PRISCA_VAVY    16  402.67
# 453789              Chloé- Cartigny    16  262.24
# ...                             ...   ...     ...
# 446384  Juliette-camut Lila-Capraja    16  197.00
# 450931            Mélissandre-Riaud    16  166.19
# 457483                Elisa Lucante    16  246.37
# 454079            Mathieu-Monteille    16  215.20
# 457173           Mathilde Bessonart    16  205.38
# 457111                 Joakim-Lubin    16  349.84
# 456846   Yuna-Gicquel. Adelie-almon    16  245.18
# 456690                Léonie-Dupouy    16  256.86
# 455719             melissa-johannet    16  231.20
# 460169                mintou_ndiaye    14  212.51
# 461900                sarah-guellil    14  213.35
# 461325       Julia-Anoge-Elsa-Dumas    14  280.16
# 461104       Julia-Anoge-Elsa-Dumas    14  280.16
# 456402               rihanna - lair    14  204.45
# 414295              timothy-andrade    14  250.71
# 441018                lucie riviere    14  152.64
# 459971               Jérémie-Dubois    14  219.54
# 458747               elisa-specogna    14  172.00
# 458657             Oceane-defreitas    14  199.36
# 457731                  Anais-manus    14  241.58
# 456651                Maela-Auguste    14  237.99
# 454852                manon-olivier    13  196.09
# 458727            Lina-Bourchachene    13  211.12
# 416701               Omeïma-Bourema    13  280.30
# 458613                 chloé-artola    13  182.47
# 462309                    Mame-Diop    13  267.99
# 453892                zoé-marostica    13  217.69
# 449639               louise dutheil    11  184.02
# 447671               GUETATFA Ilhem    10  192.95
# 463562                Giulia Nisini    10    4.06
#
# [63 rows x 3 columns]
