# %%
import codecs,unidecode,yaml,glob,os,shutil,re
import itertools as it
import numpy as np
import pandas as pd
# print(pd.__version__)

# %%
nQuizz=10
fMajeure=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Majeure.csv"
fMineure=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Mineure.csv"
fCM=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/CM.csv"
fAliasQDLE=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Quizz-Alias.yaml"
fQuizzoodle=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Quizz%02d.csv"%nQuizz
fNotes=fQuizzoodle.replace(u".csv",u"-Notes.csv")

# %%
'''https://stackoverflow.com/a/35491326/3986209'''
def invert_dict(d): 
    inverse = dict() 
    for key in d: 
        # Go through the list that is saved in the dict:
        for item in d[key]:
            # Check if in the inverted dict the key exists
            if item not in inverse: 
                # If not create a new list
                inverse[item] = [key] 
            else: 
                inverse[item].append(key) 
    return inverse

# %% [markdown]
# # Lecture des données

# %%
try:
    with codecs.open(fAliasQDLE, 'r', encoding="utf8") as inFile:
        correspondances=yaml.safe_load(inFile)
    alias=correspondances["alias2etu"]
except:
    alias={}
alias
# Out:
# {'APPADOO et VICENTINI': ['412653', '415269'],
#  'Aaron Dieu': ['413093'],
#  'Abel': ['417920'],
#  'Abigail raguraj': ['397598'],
#  'Afonso Peleja': ['415773'],
#  'Agathe Corbier': ['398357'],
#  'Agleizes001': ['412341'],
#  'Aiden Bertin': ['415098'],
#  'Alexis peyen': ['414807'],
#  'Alice': ['400421'],
#  'Alice Dupouy': ['400421'],
#  'Alicia PARISET': ['397359'],
#  'Alicia PARISET Axel Hennebert': ['397359', '414202'],
#  u'Aliz\xe9e Artaud': ['415398'],
#  'Amblard Juline': ['415539'],
#  'Ambre Sovieri': ['402017'],
#  'Amelie Martin': ['398003'],
#  'Amine Elhaloui': ['415818'],
#  'Amine elhaloui': ['415818'],
#  u'Am\xe9lie Martin': ['398003'],
#  'Anais Bernou': ['413687'],
#  u'Ana\xefs AURIAULT': ['418584'],
#  u'Ana\xefs Bernou': ['413687'],
#  'Angele': ['417705'],
#  u'Anna\xeblle Gatien': ['417456'],
#  'Anne-Emmanuelle': ['421063'],
#  'Appadoo': ['412653'],
#  'Appadoo et Vicentini': ['415269', '412653'],
#  'Archi': ['397427'],
#  'Archibald Schmidt': ['397427'],
#  u'Artaud Aliz\xe9e': ['415398'],
#  u'Astrid Barri\xe8re': ['402714'],
#  u'Astrid barri\xe8re': ['402714'],
#  'Aude-Lise': ['398735'],
#  'Aude-Lise Ledentu': ['398735'],
#  'Aure': ['414227'],
#  'Aure girard': ['414227'],
#  'Aurel@700': ['416671'],
#  'Aurelm7000': ['416671'],
#  'Axel Hennebert': ['414202'],
#  u'BARNOLE Myl\xe9nie': ['413653'],
#  'BENZONI Enzo': ['414854'],
#  'BOTROS': ['404379'],
#  'Banaszak': ['416541'],
#  'Banizette shirley': ['416087'],
#  'Baptiste': ['413439'],
#  'Baptiste Bakri': ['413439'],
#  'Baptistebakri': ['413439'],
#  'Barnole Mylenie': ['413653'],
#  u'Barnole Myl\xe9nie': ['413653'],
#  'Bastien Aroztegui': ['417876'],
#  'Bennadjema': ['396567'],
#  'Bernede Manon': ['415466'],
#  'Blanchard Laura': ['417797'],
#  'Bonvarlet': ['416527'],
#  'Bonvarlet/ Papadacci': ['416527', '413048'],
#  'Boutelet Lilly': ['387089'],
#  'Breuils Mathilde': ['415694'],
#  'C.Desmond': ['417162'],
#  u'CHAMPERNAU_L\xe9andre': ['323999'],
#  'CHOQUET Lisa': ['418807'],
#  'COTENTIN Amandine': ['414180'],
#  'Camille Alvarez': ['418829'],
#  'Camille morvan': ['413395'],
#  'Camille v': ['412887'],
#  'Carla Dos Santos': ['417682'],
#  'Carla Vicentini': ['415269'],
#  'Carla-Marie': ['416713'],
#  'Carla-Marie BARTOLOMUCCI': ['416713'],
#  'Carla.D': ['417162'],
#  'Casanova Thomas': ['413481'],
#  'Cassy': ['397207'],
#  u'Castello-- Iturria Na\xefa': ['415449'],
#  'Cazenave Laura': ['415613'],
#  'Chambaud': ['417705'],
#  'Charlotte': ['415747'],
#  'Charlynelecar': ['414055'],
#  'Chavier Charlotte': ['415747'],
#  'Chloe Lamouroux': ['412398'],
#  u'Chlo\xe9 Gravelat': ['413916'],
#  u'Chlo\xe9 l': ['412398'],
#  'Chrystal': ['414222'],
#  'Claire & Baptiste': ['413439'],
#  'Claire Vancostenoble': ['413018'],
#  'Claire vergnes': ['413133'],
#  'Clara General': ['403239'],
#  'Clemence BEGAY': ['416982'],
#  u'Clo\xe9 Di Sotto': ['413510'],
#  u'Clo\xe9 DiSotto': ['413510'],
#  u'Cl\xe9mence Labbe': ['413822'],
#  'Coline Camille Saint-Avit': ['415962'],
#  'Coline G': ['413501'],
#  'Coline GOURSAUD': ['413501'],
#  'Coline Labat': ['414705'],
#  'Coline Lbt': ['414705'],
#  'Colinegoursaud': ['413501'],
#  'Colinegoursaud21': ['413501'],
#  'Colline Cherel': ['411946'],
#  'Corentin MORTIER': ['416867'],
#  'Cotentin Amandine': ['414180'],
#  'Cotentin, Pailhes': ['414180', '411916'],
#  u'Coutou Matt\xe9o': ['414878'],
#  'Crampe marie': ['413323'],
#  'Cyrielle Tavera': ['417982'],
#  'DA CUNHA Mathilde': ['415439'],
#  u'DEPLUCHE Le\xefla': ['412746'],
#  'Damien Guerrero': ['405648'],
#  'Daria': ['419530'],
#  'De Sousa Rodrigues Pedro': ['397324'],
#  'Delage et Panechou': ['415223', '413009'],
#  'Delage et Saint-Joanis': ['415223', '398903'],
#  'Deneka--Collin Cassandre': ['413543'],
#  'Denisa': ['420093'],
#  u'Depluche Le\xefla': ['412746'],
#  'Descamp Steve': ['416926'],
#  'Descamp steve': ['416926'],
#  'Deysse': ['418797'],
#  'Dos Santos carla': ['417682'],
#  'Dos santos carla': ['417682'],
#  'Doussan Eva': ['416247'],
#  'Dupouy Manon': ['416062'],
#  'Duthilleul Chrystal': ['414222'],
#  'Dylan GABORIAU': ['411880'],
#  'Edouard et Campanerutto': ['413643', '417531'],
#  'Eleanor': ['418398'],
#  'Elhaloui amine': ['415818'],
#  'Eliane m': ['413748'],
#  'Elisa J': ['414416'],
#  'Elisa joly': ['414416'],
#  'Elisa mel': ['418155'],
#  'Elliot (Lena) SAINT JOANIS': ['398903'],
#  'Elsa PICARD': ['414527'],
#  'Emeline': ['396761'],
#  'Emeline E': ['396761'],
#  'Emi Altava': ['335539'],
#  'Emma Gozillon': ['414454'],
#  'Emma Laujac': ['410131'],
#  'Emma Luzinski': ['413297'],
#  'Emma galiana': ['398743'],
#  'Enji ghirardelli': ['413128'],
#  'Esteban BENTO': ['415618'],
#  'Eva Belanger': ['418716'],
#  'Eva Hery': ['370384'],
#  'Eva hery': ['370384'],
#  u'FAVRE L\xe9na': ['416564'],
#  'FIGUEIREDO-RAMOS': ['413895'],
#  'FIGUEIREDO-RAMOS-ENFI-BELIAL': ['413895'],
#  'FLEURANCEAU Sarah': ['418543'],
#  'Falc-Arnould Yagoub': ['414345', '415533'],
#  'Fanny albanel': ['416758'],
#  u'Ferrand Tha\xefs': ['415136'],
#  u'Foudi ma\xefra': ['418467'],
#  'GATIEN, PONTHIER': ['417456', '412228'],
#  'GRAVELAT CHLOE': ['413916'],
#  'GUILLEMBET WILLIAM-JUNIOR': ['419041'],
#  'GUINAT': ['414017'],
#  'Gabrielle': ['420584'],
#  'Galerneau': ['416842'],
#  'General Clara': ['403239'],
#  'Goundoba, riziki': ['402539', '415258'],
#  'Gozillon Emma': ['414454'],
#  'HAUSER triquang': ['413262'],
#  'Hania Abdel Gawwad': ['416792'],
#  'Hannah': ['419663'],
#  'Harrydsha': ['415826'],
#  'Hderiaz001': ['417143'],
#  'Heiura Wong': ['413487'],
#  'Hinger laura': ['414210'],
#  'Hoffmann Justine': ['413002'],
#  'Hope Wilburn et Lucie Coiffard': ['419120', '418632'],
#  'Hope et Lucie': ['419120'],
#  'Hugo Gendron': ['415691'],
#  'Imanol Cartier': ['416148'],
#  'Imanol cartier': ['416148'],
#  u'In\xe8s': ['416125'],
#  u'In\xe8s Pigeot': ['415808'],
#  u'In\xe8s pigeot': ['415808'],
#  u'In\xe8s.p': ['415808'],
#  u'In\xe8slapeyre001 /eepaud002': ['413291', '414403'],
#  'Irati': ['415149'],
#  'Irati URREIZTI': ['415149'],
#  'Irati Urreizti': ['415149'],
#  'Isasti Ludivine': ['416085'],
#  'J.Lavaud': ['416038'],
#  'Jade CHRISTOPHE': ['414981'],
#  'Jade Christophe': ['414981'],
#  'Jade Hazera': ['414101'],
#  'Jayson faucheux': ['400000'],
#  'Jeanne Grand-Jean': ['417730'],
#  'Jeanne Lasnier': ['396182'],
#  'Jeanne Mina': ['373611'],
#  'Jennifer Lesueur': ['419162'],
#  'Jgonzalez': ['414967'],
#  'Joana Marques': ['415143'],
#  u'Joana Marques et L\xe9os Giret': ['413211', '415143'],
#  'Joana Marques et Marine Orset': ['415143', '413202'],
#  'Joana et Loann': ['415143', '411916'],
#  'Jocelyn mbilima': ['416328'],
#  'Joseph atkin': ['416596'],
#  'JosephAtkin': ['416596'],
#  'Jouanmiqueou Emma': ['414283'],
#  'Joye Masson': ['413201'],
#  'Julia gonzalez': ['414967'],
#  'Julie-Marie': ['401388'],
#  'Julie-Marie Berlon': ['401388'],
#  'Juliette Roussel': ['417822'],
#  'Justine A klelia A': ['412072'],
#  'Justine Alphonsine': ['397859'],
#  'Justine Andrieux': ['416801'],
#  'Justine Andrieuxx': ['416801'],
#  'Justine Lavaud': ['416038'],
#  'Justine Parent': ['416906'],
#  u'J\xe9riel': ['419152'],
#  'KaeliaGirol': ['351536'],
#  'Karine Barsacq': ['416502'],
#  'Kellian': ['406806'],
#  'Khysanth Laporte': ['417392'],
#  'Killian Adrover': ['415014'],
#  'Kimberley Boquillon': ['411934'],
#  'Kirkorian': ['418372'],
#  u'Kl\xe9lia ANTOINETTE': ['412072'],
#  'Kolar': ['416026'],
#  'Kristina': ['419651'],
#  'L.CHAMPERNAU': ['323999'],
#  'L.Champernau': ['323999'],
#  'LEBLAIN': ['415886'],
#  'Ladji Saidou Doumbia': ['411994'],
#  'Ladji saidou Doumbia': ['411994'],
#  'Lajus Kali': ['413269'],
#  u'Lamarque No\xe9mie': ['416090'],
#  u'Lamouroux Chlo\xe9': ['412398'],
#  'Laura Bagnolini': ['402514'],
#  'Laura EDOUARD': ['413643'],
#  'Laura hinger': ['414210'],
#  'Laure Garnaud': ['414877'],
#  'Laurine Marrel': ['414603'],
#  'Laurine marrel': ['414603'],
#  'Lavialle Marie': ['412991'],
#  'Le car - aguirre': ['414055'],
#  'Lehobey': ['401449'],
#  'Lehobey, lachehab gros': ['401449', '416438'],
#  'Lehobey, lachehab gros,': ['401449', '416438'],
#  'Lena Regazzoni': ['411861'],
#  'Lena Roucou': ['417786'],
#  'Lena Roucou, Baptiste Bakri': ['417786', '413439'],
#  'LenaRoucou': ['417786'],
#  'Lenny mussard-benabdelkader': ['412931'],
#  'Lilly Boutelet': ['387089'],
#  'Lilly Boutelet 001': ['387089'],
#  'Lilly Boutelet 1': ['387089'],
#  'Lilou SANCHO': ['414464'],
#  'Lilou Samson': ['413833'],
#  'Lilou Samson et JiancHao Wang': ['413833', '414000'],
#  'Lilou Samson et Juliette Autor': ['413833', '415791'],
#  'Lilou Sancho': ['414464'],
#  'Lisa Brettes': ['415598'],
#  'Lisa Brt': ['415598'],
#  'Lisa Villepontoux': ['414030'],
#  'LisaB': ['415598'],
#  'Lise': ['417575'],
#  'Lise Baron': ['417575'],
#  'Loann Pailhes': ['411916'],
#  'Loann Pailhes et Marine Orset': ['411916', '413202'],
#  'Logan': ['418489'],
#  'Logan charneau': ['418489'],
#  'Lolli Natasha': ['412227'],
#  'Loona Dieu': ['413093'],
#  'Loquet Mathilde': ['415368'],
#  'Loste lou-anne': ['413966'],
#  'Lou Anne Lhermitte': ['416530'],
#  'Lou Falc-Arnould': ['414345'],
#  'Louann': ['412308'],
#  'Louann Hours': ['412308'],
#  'Louisa': ['396567'],
#  u'Lo\xefse Hollaender Adrien Delluc': ['414434', '415209'],
#  'Lucas Muguruza': ['403161'],
#  'Lucia CAMPANERUTTO': ['417531'],
#  'Lucie Coiffard': ['418632'],
#  'Lucile': ['413321'],
#  'Lucy': ['419573'],
#  'Ludovic Leconte': ['384868'],
#  u'L\xe9a Caumes': ['412372'],
#  u'L\xe9a Hardouin': ['413012'],
#  u'L\xe9a Maniaci': ['415356'],
#  u'L\xe9a Maniaci1': ['415356'],
#  u'L\xe9a M\xe9mon': ['416406'],
#  u'L\xe9a Sainpaul': ['413553'],
#  u'L\xe9a Sainpaul (ordi)': ['413553'],
#  u'L\xe9na Favre': ['416564'],
#  u'L\xe9onie': ['412772'],
#  u'L\xe9onie Turb\xe9': ['412772'],
#  u'L\xe9os Giret': ['413211'],
#  'MARCELLIN Hugo': ['399179'],
#  'MARTY Louise': ['418883'],
#  'Mailley Melissa Marie': ['416955'],
#  'Malik Lachehab Gros': ['416438'],
#  'Manon Bernede': ['415466'],
#  'Manon bernede': ['415466'],
#  'Marcellin Hugo': ['399179'],
#  'Margaux Morin': ['414077'],
#  'Maria': ['411936'],
#  'Maria Saindou': ['411936'],
#  'Marie Lavialle': ['412991'],
#  'Marine Orset': ['413202'],
#  'Marrel Laurine': ['414603'],
#  'Mathilde Breuils': ['415694'],
#  'Mathilde DA CUNHA': ['415439'],
#  'Mathilde Loquet': ['415368'],
#  'Mathilde Paulet': ['413961'],
#  'Mathilde Pon': ['380572'],
#  'Mathis Chapeau': ['413874'],
#  'MathisChapeau': ['413874'],
#  'Matias neyrinck': ['417559'],
#  u'Matt\xe9o Coutou': ['414878'],
#  u'Mat\xe9o Natario': ['413925'],
#  'Maxine Martineau': ['413026'],
#  u'Ma\xebline': ['417965'],
#  u'Ma\xebline hosteins': ['417965'],
#  u'Ma\xeblle Duran': ['399338'],
#  u'Ma\xeblle Yagoub': ['415533'],
#  u'Ma\xeflysse Robarraud': ['416203'],
#  'Melinka': ['403569'],
#  'Meunier Theo': ['414747'],
#  u'Meyrignac-Platon Cl\xe9lia': ['408800'],
#  'Michaux Flore': ['412314'],
#  'Mila Poirier': ['416157'],
#  'Mina Feuillois': ['373611'],
#  'Morin Margaux': ['414077'],
#  'Morvan Camille': ['413395'],
#  u'M\xe9linka': ['403569'],
#  'Nawell Bachani': ['414683'],
#  'Nawell Bachani 2': ['414683'],
#  u'Na\xefda': ['417479'],
#  'Neugebauer Yohan': ['414060'],
#  'Ninon Renou': ['416705'],
#  'Nkoghe': ['416004'],
#  u'N\xe9mati': ['413350'],
#  'OYE NTOUTOUME Reve': ['408717'],
#  u'Oc\xe9ane Hondagneu Td10': ['415920'],
#  'Orlane Galland': ['416381'],
#  'Ornella Martin': ['400802'],
#  'PAILHES Loann': ['411916'],
#  'PAILLASSA Sofia': ['412891'],
#  'PARENT Justine': ['416906'],
#  'PARENT Justine + LEBLAIN': ['416906', '415886'],
#  'PEGORER Emma': ['416129'],
#  'PONTHIER Fidji': ['412228'],
#  'PONTHIER, GATIEN, URREIZTI': ['412228', '417456', '415149'],
#  'PONTHIER, LOVELACE': ['403643', '412228'],
#  'Panechou Priscilla': ['413009'],
#  'Papadacci/Morin': ['413048', '414077'],
#  'Pardo Emma': ['413735'],
#  'Parent Justine': ['416906'],
#  'Paul B': ['414024'],
#  'Paul bnf': ['414024'],
#  'Paul bonnefon': ['414024'],
#  'Pauline Sorel': ['412484'],
#  'Pegorer Emma': ['416129'],
#  'Peleja': ['415773'],
#  u'Pelus Chlo\xe9': ['413571'],
#  'Pierre-Marie bitot': ['418113'],
#  u'Piveteau Oc\xe9ane': ['412145'],
#  'Raffin Loanne': ['415516'],
#  u'Rapha\xebl Thiollier': ['415521'],
#  'Rio Emma': ['413268'],
#  'Romane HAMON': ['413546'],
#  'Roncato Marine': ['418724'],
#  'Roucou Lena': ['417786'],
#  'Roucou Lena, Loste Lou-Anne': ['417786', '413966'],
#  'Ruby Roussel': ['417822'],
#  u'R\xe9mi Tronel': ['415701'],
#  'S. Denoyelle': ['413073'],
#  'SOATTO Tania': ['414952'],
#  'SOATTO Tania - MARONGIN Sophie': ['405421', '414952'],
#  'SUZIE BLEMER': ['402638'],
#  'Sandy Bigey': ['415860'],
#  'Sarah Anton': ['418476'],
#  'Serena': ['415714'],
#  'Shirley': ['416087'],
#  'Sihame Fappani': ['415099'],
#  'Simon': ['413050'],
#  'Simon SAINTARAILLES': ['413050'],
#  'Simon et Jeanne': ['413050'],
#  'Soatto Tania': ['414952'],
#  u'Soilihi N\xe9mati': ['413350'],
#  'Sombre Denoyelle': ['413073'],
#  'Sophie MARONGIN': ['405421'],
#  'Sovieri Ambre': ['402017'],
#  'Suzie Blemer': ['402638'],
#  u'S\xf6ren': ['412396'],
#  u'S\xf6ren Benazet': ['412396'],
#  u'TAPSOBA M\xe9lika': ['418310'],
#  u'Tejerizo La\xefs et Honore Emmy': ['414261', '401188'],
#  u'Tha\xefs': ['415136'],
#  u'Tha\xefs Ferrand': ['415136'],
#  'Theo Albrespy': ['414118'],
#  'Theo alb': ['414118'],
#  'Thomas Casanova': ['413481'],
#  'Thomas Casanova 1': ['413481'],
#  'Thomas Fayolle': ['398605'],
#  u'Th\xe9o Forestier': ['414539'],
#  u'Th\xe9o Joffre': ['415169'],
#  u'Th\xe9o Pr\xe9vot': ['413245'],
#  'Tia Maeva Vespuce Michel': ['416851'],
#  u'Titouan Bouch\xe9': ['419051'],
#  'Tjappa': ['415826'],
#  'Tom dablemont': ['415077'],
#  'URREIZTI et GATIEN': ['415149', '417456'],
#  'URREIZTI irati': ['415149'],
#  'URREIZTI, GATIEN': ['415149', '417456'],
#  'VILLAGEOIS ANNE EMMANUELLE': ['421063'],
#  'VILLAGEOIS ANNE-EMMANUELLE': ['421063'],
#  'VSR': ['417001'],
#  'Vadim Olivan': ['414257'],
#  'Vergnes claire': ['413133'],
#  'Vicentini et Appadoo': ['415269', '412653'],
#  'Victor Samuel Richardson': ['417001'],
#  'Virion lorick': ['369443'],
#  'Waeghemacker': ['401460'],
#  'Waeghemacker Guillaume': ['401460'],
#  'Wang JiangHao': ['414000'],
#  'Wang JiangHao Atkin Joseph': ['414000', '416596'],
#  'WangJiangHao': ['414000'],
#  'Weina Zado': ['412906'],
#  'Wendy et Priscilla': ['415223', '413009'],
#  'William': ['419041'],
#  'Y.auger': ['415389'],
#  'YARDIN-APPADOO Gwenaelle': ['412653'],
#  u'Yagoub--Beaus\xe9jour': ['415533'],
#  u'Yagoub--Beaus\xe9jour Ma\xeblle': ['415533'],
#  'Yardin-Appado': ['412653'],
#  'Yardin-Appadoo Gwenaelle': ['412653'],
#  'Yohan Neugebauer': ['414060'],
#  u'Zo\xe9': ['396936'],
#  u'Zo\xe9 Samson': ['396936'],
#  'abarriere004': ['402714'],
#  'alarroque005': ['417920'],
#  u'ana\xefs zappino': ['413303'],
#  'andrea mautre cassandre deneka': ['413543', '400271'],
#  'bayart': ['413397'],
#  'csaintavi001': ['415962'],
#  'csaintavi001 ebismes001': ['415962', '413429'],
#  'ebismes': ['413429'],
#  'ebismes coline': ['413429'],
#  'ebismes csaintavit001': ['413429', '415962'],
#  'ebismes001': ['413429'],
#  'ebismes001 et csaintavi001': ['413429', '415962'],
#  'eepaud002': ['414403'],
#  'eepaud002 jaguilar003': ['417623', '414403'],
#  'egary002': ['415194'],
#  'eleana': ['414688'],
#  'eleana klein': ['414688'],
#  'eliane': ['413748'],
#  'eliane.M': ['413748'],
#  'elisa f': ['417890'],
#  'elisa ferreira': ['417890'],
#  'emma.lilli': ['414146'],
#  'emmalilli': ['414146'],
#  'epetit009': ['412189'],
#  'esimonell001': ['413159'],
#  'esteban bento': ['415618'],
#  'esteban.bento': ['415618'],
#  'eva doussan': ['416247'],
#  'evaj mathildel': ['412425', '415368'],
#  'evajosephine': ['412425'],
#  'hannah': ['419663'],
#  'ilapeyre001': ['413291'],
#  'ilapeyre001 / eepaud002': ['413291', '414403'],
#  'jchinarro001': ['323516'],
#  'jeanne lapeyre': ['415732'],
#  'jnais001': ['417410'],
#  'june': ['416415'],
#  'lalou.naves': ['415893'],
#  u'la\xefs': ['401188'],
#  u'la\xefs tejerizo': ['401188'],
#  'lchampern': ['323999'],
#  'lchampern001': ['323999'],
#  'lenny valmy': ['414714'],
#  'lnaves001': ['415893'],
#  'louisa': ['396567'],
#  u'l\xe9na martins': ['412885'],
#  'm.cantin': ['416125'],
#  'm.cantin001': ['416125'],
#  'mariam fath': ['416862'],
#  'marylou': ['416541'],
#  u'mar\xe9va durqu\xe9ty': ['418392'],
#  u'mar\xe9va durqu\xe9ty / hazera manon': ['418392', '414076'],
#  'mathis melendez': ['414896'],
#  'mathis melendez 2': ['414896'],
#  u'ma\xeblle pate': ['417735'],
#  'mcantin': ['416125'],
#  'mcantin001': ['416125'],
#  'mdupont015': ['414742'],
#  'melendez barnole': ['414896', '413653'],
#  'melendez mathis': ['414896'],
#  'mila': ['416157'],
#  'mmelendez003': ['414896'],
#  u'm\xe9line': ['414203'],
#  'nawell bachani': ['414683'],
#  'nchahirou001': ['417479'],
#  'nrenou001': ['416705'],
#  'odavid002': ['416347'],
#  'ohiana Fougeray': ['416012'],
#  'oriane.szwertak': ['418797'],
#  'paul_bnf_': ['414024'],
#  'paulineguinle': ['397050'],
#  'psene003': ['413716'],
#  'rose mayor': ['413529'],
#  'scherlinger amandine': ['416365'],
#  'sdenoyell001': ['413073'],
#  'shirley': ['416087'],
#  'sofia paillassa': ['412891'],
#  'szwertak': ['418797'],
#  u'tia-ma\xe9va.vespuce--michel': ['416851'],
#  'tia.vespuce- clelia.meyrignac': ['408800', '416851'],
#  'tostain jade': ['385552'],
#  'wilburn, Hope': ['419120'],
#  'zappino': ['413303']}

# %%
len(alias)
# Out:
# 518

# %%
colCM=[u"id",u"nom",u"prénom",u"email",u"ine"]
colQuizz=["pseudo","points","temps"]

try:
    dfCM=pd.read_csv(filepath_or_buffer=fCM,sep="\t",encoding="utf8",header=0,names=colCM)
    lQuizz=pd.read_csv(filepath_or_buffer=fQuizzoodle,sep=";",encoding="utf8",header=0,names=colQuizz)
    lQuizz.pseudo=lQuizz.pseudo.str.strip()
except:
    dfCM=None
    lQuizz=None

# %%
# lQuizz, dfCM

# %% [markdown]
# # Listage des alias

# %%
dfCM["PN"]=dfCM[u"prénom"].str.lower().str.strip()+" "+dfCM[u"nom"].str.lower().str.strip()
dfCM["NP"]=dfCM[u"nom"].str.lower().str.strip()+" "+dfCM[u"prénom"].str.lower().str.strip()
dfCM
# Out:
#          id                 nom           prénom  \
# 0    416792        ABDEL GAWWAD            HANIA
# 1    415014             ADROVER          KILLIAN
# 2    417623             AGUILAR         JULIETTE
# 3    421315             AKARIDE            IKRAM
# 4    416758             ALBANEL            FANNY
# 5    414118            ALBRESPY             THEO
# 6    420573          ALESSANDRI          ORNELLA
# 7    397859          ALPHONSINE          JUSTINE
# 8    418829             ALVAREZ          CAMILLE
# 9    415539             AMBLARD           JULINE
# 10   416801            ANDRIEUX          JUSTINE
# 11   412072          ANTOINETTE           KLELIA
# 12   418476               ANTON            SARAH
# 13   417876           AROZTEGUI          BASTIEN
# 14   415398              ARTAUD           ALIZEE
# 15   412821              ASHTON           PHOEBE
# 16   412869         ASSELBERGHS           SAMUEL
# 17   416596               ATKIN           JOSEPH
# 18   357781               AUBIN           AMELIE
# 19   416539               AUBRY            LILOU
# 20   415389               AUGER             YANN
# 21   418584            AURIAULT            ANAIS
# 22   415791               AUTOR         JULIETTE
# 23   414683             BACHANI           NAWELL
# 24   402514           BAGNOLINI            LAURA
# 25   413439               BAKRI         BAPTISTE
# 26   416541            BANASZAK          MARYLOU
# 27   416087           BANIZETTE          SHIRLEY
# 28   413653             BARNOLE          MYLENIE
# 29   417575               BARON             LISE
# ..      ...                 ...              ...
# 465  412772               TURBE           LEONIE
# 466  415149            URREIZTI            IRATI
# 467  419172                VAIN           CELINE
# 468  261173         VALBOUSQUET            MAEVA
# 469  414714               VALMY            LENNY
# 470  413018       VANCOSTENOBLE           CLAIRE
# 471  372722               VELLO          RAPHAEL
# 472  413133             VERGNES           CLAIRE
# 473  412853            VERLAINE      JULIEN-PAUL
# 474  416851     VESPUCE--MICHEL        TIA-MAEVA
# 475  416252              VIALAN             EMMA
# 476  415269           VICENTINI            CARLA
# 477  412887             VIGNIER          CAMILLE
# 478  421063          VILLAGEOIS  ANNE-EMMANUELLE
# 479  414030        VILLEPONTOUX             LISA
# 480  416733              VIOLIN           LORANN
# 481  372473                VIOT           LAURIC
# 482  369443              VIRION           LORICK
# 483  245608               VOGEL            DAVID
# 484  401460        WAEGHEMACKER        GUILLAUME
# 485  414000                WANG        JIANG HAO
# 486  420748              WATTEZ            JULIE
# 487  419120             WILBURN             HOPE
# 488  413487                WONG           HEIURA
# 489  415533  YAGOUB--BEAUSEJOUR           MAELLE
# 490  412653      YARDIN-APPADOO        GWENAELLE
# 491  420013           ZAGHOUANI        SHERIHENE
# 492  413303             ZAPPINO            ANAIS
# 493  417942             ZEGOURI            LEILI
# 494  404630         ZINE EDDINE           ISHRAF
#
#                                                  email          ine  \
# 0       hania.abdel-gawwad@etu.u-bordeaux-montaigne.fr  080761564FE
# 1          killian.adrover@etu.u-bordeaux-montaigne.fr  081310016EA
# 2         juliette.aguilar@etu.u-bordeaux-montaigne.fr  061226840EF
# 3            ikram.akaride@etu.u-bordeaux-montaigne.fr  0756AU00FD1
# 4            fanny.albanel@etu.u-bordeaux-montaigne.fr  090927602AE
# 5            theo.albrespy@etu.u-bordeaux-montaigne.fr  061057341JF
# 6       ornella.alessandri@etu.u-bordeaux-montaigne.fr  213042901EC
# 7       justine.alphonsine@etu.u-bordeaux-montaigne.fr  091152973GB
# 8          camille.alvarez@etu.u-bordeaux-montaigne.fr  072082252KH
# 9           juline.amblard@etu.u-bordeaux-montaigne.fr  060012103FB
# 10       justine.andrieux1@etu.u-bordeaux-montaigne.fr  080423150DF
# 11       klelia.antoinette@etu.u-bordeaux-montaigne.fr  101015248GH
# 12             sarah.anton@etu.u-bordeaux-montaigne.fr  060029886BK
# 13       bastien.aroztegui@etu.u-bordeaux-montaigne.fr  072057721JH
# 14           alizee.artaud@etu.u-bordeaux-montaigne.fr  071590475JE
# 15           phoebe.ashton@etu.u-bordeaux-montaigne.fr  1610040182B
# 16      samuel.asselberghs@etu.u-bordeaux-montaigne.fr  080141274CK
# 17            joseph.atkin@etu.u-bordeaux-montaigne.fr  130509353HD
# 18            amelie.aubin@etu.u-bordeaux-montaigne.fr  1310002382H
# 19             lilou.aubry@etu.u-bordeaux-montaigne.fr  110354974JD
# 20              yann.auger@etu.u-bordeaux-montaigne.fr  2214000973X
# 21          anais.auriault@etu.u-bordeaux-montaigne.fr  060145376FG
# 22          juliette.autor@etu.u-bordeaux-montaigne.fr  070540618BD
# 23          nawell.bachani@etu.u-bordeaux-montaigne.fr  081761952CH
# 24         laura.bagnolini@etu.u-bordeaux-montaigne.fr  081079466CB
# 25          baptiste.bakri@etu.u-bordeaux-montaigne.fr  080423109HG
# 26        marylou.banaszak@etu.u-bordeaux-montaigne.fr  081166949DC
# 27       shirley.banizette@etu.u-bordeaux-montaigne.fr  070520879GB
# 28         mylenie.barnole@etu.u-bordeaux-montaigne.fr  081050929EA
# 29              lise.baron@etu.u-bordeaux-montaigne.fr  120986765HE
# ..                                                 ...          ...
# 465           leonie.turbe@etu.u-bordeaux-montaigne.fr  123829273FE
# 466         irati.urreizti@etu.u-bordeaux-montaigne.fr  143214870AE
# 467            celine.vain@etu.u-bordeaux-montaigne.fr  1893028508H
# 468      maeva.valbousquet@etu.u-bordeaux-montaigne.fr  0404002158F
# 469            lenny.valmy@etu.u-bordeaux-montaigne.fr  071631372CE
# 470   claire.vancostenoble@etu.u-bordeaux-montaigne.fr  0710002867X
# 471          raphael.vello@etu.u-bordeaux-montaigne.fr  2307030195S
# 472         claire.vergnes@etu.u-bordeaux-montaigne.fr  071340363DD
# 473   julien-paul.verlaine@etu.u-bordeaux-montaigne.fr  110640530KF
# 474  tia-maeva.vespuce--michel@etu.u-bordeaux-monta...  081369080EK
# 475            emma.vialan@etu.u-bordeaux-montaigne.fr  072022756DF
# 476        carla.vicentini@etu.u-bordeaux-montaigne.fr  071941496AK
# 477        camille.vignier@etu.u-bordeaux-montaigne.fr  091138152EB
# 478  anne-emmanuelle.villageois@etu.u-bordeaux-mont...  090805239FA
# 479      lisa.villepontoux@etu.u-bordeaux-montaigne.fr  060049333GK
# 480          lorann.violin@etu.u-bordeaux-montaigne.fr  123074852AK
# 481            lauric.viot@etu.u-bordeaux-montaigne.fr  070317193EH
# 482          lorick.virion@etu.u-bordeaux-montaigne.fr  091124902AC
# 483            david.vogel@etu.u-bordeaux-montaigne.fr  073ZQK00PI4
# 484  guillaume.waeghemacker@etu.u-bordeaux-montaign...  0407025852E
# 485         jiang-hao.wang@etu.u-bordeaux-montaigne.fr  143114592JB
# 486           julie.wattez@etu.u-bordeaux-montaigne.fr  213048368AH
# 487           hope.wilburn@etu.u-bordeaux-montaigne.fr  203421280DK
# 488            heiura.wong@etu.u-bordeaux-montaigne.fr  4110004544U
# 489  maelle.yagoub--beausejour@etu.u-bordeaux-monta...  060344549CE
# 490  gwenaelle.yardin-appadoo@etu.u-bordeaux-montai...  061103323JB
# 491    sherihene.zaghouani@etu.u-bordeaux-montaigne.fr  071248129CA
# 492          anais.zappino@etu.u-bordeaux-montaigne.fr  130831143DC
# 493          leili.zegouri@etu.u-bordeaux-montaigne.fr  203292113AC
# 494     ishraf.zine-eddine@etu.u-bordeaux-montaigne.fr  070402041HE
#
#                              PN                          NP
# 0            hania abdel gawwad          abdel gawwad hania
# 1               killian adrover             adrover killian
# 2              juliette aguilar            aguilar juliette
# 3                 ikram akaride               akaride ikram
# 4                 fanny albanel               albanel fanny
# 5                 theo albrespy               albrespy theo
# 6            ornella alessandri          alessandri ornella
# 7            justine alphonsine          alphonsine justine
# 8               camille alvarez             alvarez camille
# 9                juline amblard              amblard juline
# 10             justine andrieux            andrieux justine
# 11            klelia antoinette           antoinette klelia
# 12                  sarah anton                 anton sarah
# 13            bastien aroztegui           aroztegui bastien
# 14                alizee artaud               artaud alizee
# 15                phoebe ashton               ashton phoebe
# 16           samuel asselberghs          asselberghs samuel
# 17                 joseph atkin                atkin joseph
# 18                 amelie aubin                aubin amelie
# 19                  lilou aubry                 aubry lilou
# 20                   yann auger                  auger yann
# 21               anais auriault              auriault anais
# 22               juliette autor              autor juliette
# 23               nawell bachani              bachani nawell
# 24              laura bagnolini             bagnolini laura
# 25               baptiste bakri              bakri baptiste
# 26             marylou banaszak            banaszak marylou
# 27            shirley banizette           banizette shirley
# 28              mylenie barnole             barnole mylenie
# 29                   lise baron                  baron lise
# ..                          ...                         ...
# 465                leonie turbe                turbe leonie
# 466              irati urreizti              urreizti irati
# 467                 celine vain                 vain celine
# 468           maeva valbousquet           valbousquet maeva
# 469                 lenny valmy                 valmy lenny
# 470        claire vancostenoble        vancostenoble claire
# 471               raphael vello               vello raphael
# 472              claire vergnes              vergnes claire
# 473        julien-paul verlaine        verlaine julien-paul
# 474   tia-maeva vespuce--michel   vespuce--michel tia-maeva
# 475                 emma vialan                 vialan emma
# 476             carla vicentini             vicentini carla
# 477             camille vignier             vignier camille
# 478  anne-emmanuelle villageois  villageois anne-emmanuelle
# 479           lisa villepontoux           villepontoux lisa
# 480               lorann violin               violin lorann
# 481                 lauric viot                 viot lauric
# 482               lorick virion               virion lorick
# 483                 david vogel                 vogel david
# 484      guillaume waeghemacker      waeghemacker guillaume
# 485              jiang hao wang              wang jiang hao
# 486                julie wattez                wattez julie
# 487                hope wilburn                wilburn hope
# 488                 heiura wong                 wong heiura
# 489   maelle yagoub--beausejour   yagoub--beausejour maelle
# 490    gwenaelle yardin-appadoo    yardin-appadoo gwenaelle
# 491         sherihene zaghouani         zaghouani sherihene
# 492               anais zappino               zappino anais
# 493               leili zegouri               zegouri leili
# 494          ishraf zine eddine          zine eddine ishraf
#
# [495 rows x 7 columns]

# %%
pseudos=lQuizz[~(lQuizz["pseudo"].isin(alias))]["pseudo"].str.strip().tolist()
print "\n".join(pseudos)
# Out:
# Théo
# Marie
# Minou minou
# Tintin
# Justine A
# XuehangWang
# Archiboule le plus fort
# Mina
# lulu
# Patoox
# Romane
# camilleS
# minou
# Sasa
# Sali

# %%
for nP,pseudo in enumerate(pseudos):
    print pseudo
    sPseudo = raw_input("Nom a chercher:\n")
    if sPseudo:
        print dfCM[dfCM["PN"].str.contains(sPseudo.lower())][["PN","id"]]
        idPseudo=raw_input("id :\n")
        if idPseudo:
            alias[pseudo]=idPseudo
# Out:
# Théo
# Nom a chercher:
#
# Marie
# Nom a chercher:
#
# Minou minou
# Nom a chercher:
#
# Tintin
# Nom a chercher:
#
# Justine A
# Nom a chercher:
#
# XuehangWang
# Nom a chercher:
#
# Archiboule le plus fort
# Nom a chercher:
#
# Mina
# Nom a chercher:
#
# lulu
# Nom a chercher:
#
# Patoox
# Nom a chercher:
#
# Romane
# Nom a chercher:
#
# camilleS
# Nom a chercher:
#
# minou
# Nom a chercher:
#
# Sasa
# Nom a chercher:
#
# Sali
# Nom a chercher:

# %%
alias["Lilly Boutelet 1"]
# Out:
# ['387089']

# %%
# pseudo=u"csaintavi001 ebismes001"
# alias[pseudo]=["415962","413429"]

# %%
sPseudo="bisme"
print dfCM[dfCM["PN"].str.contains(sPseudo.lower())][["PN","id"]]
# Out:
#              PN      id
# 56  emma bismes  413429

# %%
len(pseudos)
# Out:
# 15

# %%
# alias["Sofiane"]

# %%
pn=dfCM["PN"].tolist()
np=dfCM["NP"].tolist()

# %%
for pseudo in pseudos:
    if unidecode.unidecode(pseudo.lower()) in pn:
        print pseudo,dfCM[dfCM["PN"]==unidecode.unidecode(pseudo.lower())]["id"].values[0]
        alias[pseudo]=[str(dfCM[dfCM["PN"]==unidecode.unidecode(pseudo.lower())]["id"].values[0])]
    elif unidecode.unidecode(pseudo.lower()) in np:
        print pseudo,dfCM[dfCM["NP"]==unidecode.unidecode(pseudo.lower())]["id"].values[0]
        alias[pseudo]=[str(dfCM[dfCM["NP"]==unidecode.unidecode(pseudo.lower())]["id"].values[0])]

# %%
for al in alias:
    if not isinstance(alias[al],list):
        alias[al]=[alias[al]]

# %%
len(alias)
# Out:
# 518

# %%
invAlias=invert_dict(alias)
#invAlias[385732]=[u'adiarra001, cbeauvais004']
correspondances={"alias2etu":alias,"etu2alias":invAlias}
correspondances
# Out:
# {'alias2etu': {'APPADOO et VICENTINI': ['412653', '415269'],
#   'Aaron Dieu': ['413093'],
#   'Abel': ['417920'],
#   'Abigail raguraj': ['397598'],
#   'Afonso Peleja': ['415773'],
#   'Agathe Corbier': ['398357'],
#   'Agleizes001': ['412341'],
#   'Aiden Bertin': ['415098'],
#   'Alexis peyen': ['414807'],
#   'Alice': ['400421'],
#   'Alice Dupouy': ['400421'],
#   'Alicia PARISET': ['397359'],
#   'Alicia PARISET Axel Hennebert': ['397359', '414202'],
#   u'Aliz\xe9e Artaud': ['415398'],
#   'Amblard Juline': ['415539'],
#   'Ambre Sovieri': ['402017'],
#   'Amelie Martin': ['398003'],
#   'Amine Elhaloui': ['415818'],
#   'Amine elhaloui': ['415818'],
#   u'Am\xe9lie Martin': ['398003'],
#   'Anais Bernou': ['413687'],
#   u'Ana\xefs AURIAULT': ['418584'],
#   u'Ana\xefs Bernou': ['413687'],
#   'Angele': ['417705'],
#   u'Anna\xeblle Gatien': ['417456'],
#   'Anne-Emmanuelle': ['421063'],
#   'Appadoo': ['412653'],
#   'Appadoo et Vicentini': ['415269', '412653'],
#   'Archi': ['397427'],
#   'Archibald Schmidt': ['397427'],
#   u'Artaud Aliz\xe9e': ['415398'],
#   u'Astrid Barri\xe8re': ['402714'],
#   u'Astrid barri\xe8re': ['402714'],
#   'Aude-Lise': ['398735'],
#   'Aude-Lise Ledentu': ['398735'],
#   'Aure': ['414227'],
#   'Aure girard': ['414227'],
#   'Aurel@700': ['416671'],
#   'Aurelm7000': ['416671'],
#   'Axel Hennebert': ['414202'],
#   u'BARNOLE Myl\xe9nie': ['413653'],
#   'BENZONI Enzo': ['414854'],
#   'BOTROS': ['404379'],
#   'Banaszak': ['416541'],
#   'Banizette shirley': ['416087'],
#   'Baptiste': ['413439'],
#   'Baptiste Bakri': ['413439'],
#   'Baptistebakri': ['413439'],
#   'Barnole Mylenie': ['413653'],
#   u'Barnole Myl\xe9nie': ['413653'],
#   'Bastien Aroztegui': ['417876'],
#   'Bennadjema': ['396567'],
#   'Bernede Manon': ['415466'],
#   'Blanchard Laura': ['417797'],
#   'Bonvarlet': ['416527'],
#   'Bonvarlet/ Papadacci': ['416527', '413048'],
#   'Boutelet Lilly': ['387089'],
#   'Breuils Mathilde': ['415694'],
#   'C.Desmond': ['417162'],
#   u'CHAMPERNAU_L\xe9andre': ['323999'],
#   'CHOQUET Lisa': ['418807'],
#   'COTENTIN Amandine': ['414180'],
#   'Camille Alvarez': ['418829'],
#   'Camille morvan': ['413395'],
#   'Camille v': ['412887'],
#   'Carla Dos Santos': ['417682'],
#   'Carla Vicentini': ['415269'],
#   'Carla-Marie': ['416713'],
#   'Carla-Marie BARTOLOMUCCI': ['416713'],
#   'Carla.D': ['417162'],
#   'Casanova Thomas': ['413481'],
#   'Cassy': ['397207'],
#   u'Castello-- Iturria Na\xefa': ['415449'],
#   'Cazenave Laura': ['415613'],
#   'Chambaud': ['417705'],
#   'Charlotte': ['415747'],
#   'Charlynelecar': ['414055'],
#   'Chavier Charlotte': ['415747'],
#   'Chloe Lamouroux': ['412398'],
#   u'Chlo\xe9 Gravelat': ['413916'],
#   u'Chlo\xe9 l': ['412398'],
#   'Chrystal': ['414222'],
#   'Claire & Baptiste': ['413439'],
#   'Claire Vancostenoble': ['413018'],
#   'Claire vergnes': ['413133'],
#   'Clara General': ['403239'],
#   'Clemence BEGAY': ['416982'],
#   u'Clo\xe9 Di Sotto': ['413510'],
#   u'Clo\xe9 DiSotto': ['413510'],
#   u'Cl\xe9mence Labbe': ['413822'],
#   'Coline Camille Saint-Avit': ['415962'],
#   'Coline G': ['413501'],
#   'Coline GOURSAUD': ['413501'],
#   'Coline Labat': ['414705'],
#   'Coline Lbt': ['414705'],
#   'Colinegoursaud': ['413501'],
#   'Colinegoursaud21': ['413501'],
#   'Colline Cherel': ['411946'],
#   'Corentin MORTIER': ['416867'],
#   'Cotentin Amandine': ['414180'],
#   'Cotentin, Pailhes': ['414180', '411916'],
#   u'Coutou Matt\xe9o': ['414878'],
#   'Crampe marie': ['413323'],
#   'Cyrielle Tavera': ['417982'],
#   'DA CUNHA Mathilde': ['415439'],
#   u'DEPLUCHE Le\xefla': ['412746'],
#   'Damien Guerrero': ['405648'],
#   'Daria': ['419530'],
#   'De Sousa Rodrigues Pedro': ['397324'],
#   'Delage et Panechou': ['415223', '413009'],
#   'Delage et Saint-Joanis': ['415223', '398903'],
#   'Deneka--Collin Cassandre': ['413543'],
#   'Denisa': ['420093'],
#   u'Depluche Le\xefla': ['412746'],
#   'Descamp Steve': ['416926'],
#   'Descamp steve': ['416926'],
#   'Deysse': ['418797'],
#   'Dos Santos carla': ['417682'],
#   'Dos santos carla': ['417682'],
#   'Doussan Eva': ['416247'],
#   'Dupouy Manon': ['416062'],
#   'Duthilleul Chrystal': ['414222'],
#   'Dylan GABORIAU': ['411880'],
#   'Edouard et Campanerutto': ['413643', '417531'],
#   'Eleanor': ['418398'],
#   'Elhaloui amine': ['415818'],
#   'Eliane m': ['413748'],
#   'Elisa J': ['414416'],
#   'Elisa joly': ['414416'],
#   'Elisa mel': ['418155'],
#   'Elliot (Lena) SAINT JOANIS': ['398903'],
#   'Elsa PICARD': ['414527'],
#   'Emeline': ['396761'],
#   'Emeline E': ['396761'],
#   'Emi Altava': ['335539'],
#   'Emma Gozillon': ['414454'],
#   'Emma Laujac': ['410131'],
#   'Emma Luzinski': ['413297'],
#   'Emma galiana': ['398743'],
#   'Enji ghirardelli': ['413128'],
#   'Esteban BENTO': ['415618'],
#   'Eva Belanger': ['418716'],
#   'Eva Hery': ['370384'],
#   'Eva hery': ['370384'],
#   u'FAVRE L\xe9na': ['416564'],
#   'FIGUEIREDO-RAMOS': ['413895'],
#   'FIGUEIREDO-RAMOS-ENFI-BELIAL': ['413895'],
#   'FLEURANCEAU Sarah': ['418543'],
#   'Falc-Arnould Yagoub': ['414345', '415533'],
#   'Fanny albanel': ['416758'],
#   u'Ferrand Tha\xefs': ['415136'],
#   u'Foudi ma\xefra': ['418467'],
#   'GATIEN, PONTHIER': ['417456', '412228'],
#   'GRAVELAT CHLOE': ['413916'],
#   'GUILLEMBET WILLIAM-JUNIOR': ['419041'],
#   'GUINAT': ['414017'],
#   'Gabrielle': ['420584'],
#   'Galerneau': ['416842'],
#   'General Clara': ['403239'],
#   'Goundoba, riziki': ['402539', '415258'],
#   'Gozillon Emma': ['414454'],
#   'HAUSER triquang': ['413262'],
#   'Hania Abdel Gawwad': ['416792'],
#   'Hannah': ['419663'],
#   'Harrydsha': ['415826'],
#   'Hderiaz001': ['417143'],
#   'Heiura Wong': ['413487'],
#   'Hinger laura': ['414210'],
#   'Hoffmann Justine': ['413002'],
#   'Hope Wilburn et Lucie Coiffard': ['419120', '418632'],
#   'Hope et Lucie': ['419120'],
#   'Hugo Gendron': ['415691'],
#   'Imanol Cartier': ['416148'],
#   'Imanol cartier': ['416148'],
#   u'In\xe8s': ['416125'],
#   u'In\xe8s Pigeot': ['415808'],
#   u'In\xe8s pigeot': ['415808'],
#   u'In\xe8s.p': ['415808'],
#   u'In\xe8slapeyre001 /eepaud002': ['413291', '414403'],
#   'Irati': ['415149'],
#   'Irati URREIZTI': ['415149'],
#   'Irati Urreizti': ['415149'],
#   'Isasti Ludivine': ['416085'],
#   'J.Lavaud': ['416038'],
#   'Jade CHRISTOPHE': ['414981'],
#   'Jade Christophe': ['414981'],
#   'Jade Hazera': ['414101'],
#   'Jayson faucheux': ['400000'],
#   'Jeanne Grand-Jean': ['417730'],
#   'Jeanne Lasnier': ['396182'],
#   'Jeanne Mina': ['373611'],
#   'Jennifer Lesueur': ['419162'],
#   'Jgonzalez': ['414967'],
#   'Joana Marques': ['415143'],
#   u'Joana Marques et L\xe9os Giret': ['413211', '415143'],
#   'Joana Marques et Marine Orset': ['415143', '413202'],
#   'Joana et Loann': ['415143', '411916'],
#   'Jocelyn mbilima': ['416328'],
#   'Joseph atkin': ['416596'],
#   'JosephAtkin': ['416596'],
#   'Jouanmiqueou Emma': ['414283'],
#   'Joye Masson': ['413201'],
#   'Julia gonzalez': ['414967'],
#   'Julie-Marie': ['401388'],
#   'Julie-Marie Berlon': ['401388'],
#   'Juliette Roussel': ['417822'],
#   'Justine A klelia A': ['412072'],
#   'Justine Alphonsine': ['397859'],
#   'Justine Andrieux': ['416801'],
#   'Justine Andrieuxx': ['416801'],
#   'Justine Lavaud': ['416038'],
#   'Justine Parent': ['416906'],
#   u'J\xe9riel': ['419152'],
#   'KaeliaGirol': ['351536'],
#   'Karine Barsacq': ['416502'],
#   'Kellian': ['406806'],
#   'Khysanth Laporte': ['417392'],
#   'Killian Adrover': ['415014'],
#   'Kimberley Boquillon': ['411934'],
#   'Kirkorian': ['418372'],
#   u'Kl\xe9lia ANTOINETTE': ['412072'],
#   'Kolar': ['416026'],
#   'Kristina': ['419651'],
#   'L.CHAMPERNAU': ['323999'],
#   'L.Champernau': ['323999'],
#   'LEBLAIN': ['415886'],
#   'Ladji Saidou Doumbia': ['411994'],
#   'Ladji saidou Doumbia': ['411994'],
#   'Lajus Kali': ['413269'],
#   u'Lamarque No\xe9mie': ['416090'],
#   u'Lamouroux Chlo\xe9': ['412398'],
#   'Laura Bagnolini': ['402514'],
#   'Laura EDOUARD': ['413643'],
#   'Laura hinger': ['414210'],
#   'Laure Garnaud': ['414877'],
#   'Laurine Marrel': ['414603'],
#   'Laurine marrel': ['414603'],
#   'Lavialle Marie': ['412991'],
#   'Le car - aguirre': ['414055'],
#   'Lehobey': ['401449'],
#   'Lehobey, lachehab gros': ['401449', '416438'],
#   'Lehobey, lachehab gros,': ['401449', '416438'],
#   'Lena Regazzoni': ['411861'],
#   'Lena Roucou': ['417786'],
#   'Lena Roucou, Baptiste Bakri': ['417786', '413439'],
#   'LenaRoucou': ['417786'],
#   'Lenny mussard-benabdelkader': ['412931'],
#   'Lilly Boutelet': ['387089'],
#   'Lilly Boutelet 001': ['387089'],
#   'Lilly Boutelet 1': ['387089'],
#   'Lilou SANCHO': ['414464'],
#   'Lilou Samson': ['413833'],
#   'Lilou Samson et JiancHao Wang': ['413833', '414000'],
#   'Lilou Samson et Juliette Autor': ['413833', '415791'],
#   'Lilou Sancho': ['414464'],
#   'Lisa Brettes': ['415598'],
#   'Lisa Brt': ['415598'],
#   'Lisa Villepontoux': ['414030'],
#   'LisaB': ['415598'],
#   'Lise': ['417575'],
#   'Lise Baron': ['417575'],
#   'Loann Pailhes': ['411916'],
#   'Loann Pailhes et Marine Orset': ['411916', '413202'],
#   'Logan': ['418489'],
#   'Logan charneau': ['418489'],
#   'Lolli Natasha': ['412227'],
#   'Loona Dieu': ['413093'],
#   'Loquet Mathilde': ['415368'],
#   'Loste lou-anne': ['413966'],
#   'Lou Anne Lhermitte': ['416530'],
#   'Lou Falc-Arnould': ['414345'],
#   'Louann': ['412308'],
#   'Louann Hours': ['412308'],
#   'Louisa': ['396567'],
#   u'Lo\xefse Hollaender Adrien Delluc': ['414434', '415209'],
#   'Lucas Muguruza': ['403161'],
#   'Lucia CAMPANERUTTO': ['417531'],
#   'Lucie Coiffard': ['418632'],
#   'Lucile': ['413321'],
#   'Lucy': ['419573'],
#   'Ludovic Leconte': ['384868'],
#   u'L\xe9a Caumes': ['412372'],
#   u'L\xe9a Hardouin': ['413012'],
#   u'L\xe9a Maniaci': ['415356'],
#   u'L\xe9a Maniaci1': ['415356'],
#   u'L\xe9a M\xe9mon': ['416406'],
#   u'L\xe9a Sainpaul': ['413553'],
#   u'L\xe9a Sainpaul (ordi)': ['413553'],
#   u'L\xe9na Favre': ['416564'],
#   u'L\xe9onie': ['412772'],
#   u'L\xe9onie Turb\xe9': ['412772'],
#   u'L\xe9os Giret': ['413211'],
#   'MARCELLIN Hugo': ['399179'],
#   'MARTY Louise': ['418883'],
#   'Mailley Melissa Marie': ['416955'],
#   'Malik Lachehab Gros': ['416438'],
#   'Manon Bernede': ['415466'],
#   'Manon bernede': ['415466'],
#   'Marcellin Hugo': ['399179'],
#   'Margaux Morin': ['414077'],
#   'Maria': ['411936'],
#   'Maria Saindou': ['411936'],
#   'Marie Lavialle': ['412991'],
#   'Marine Orset': ['413202'],
#   'Marrel Laurine': ['414603'],
#   'Mathilde Breuils': ['415694'],
#   'Mathilde DA CUNHA': ['415439'],
#   'Mathilde Loquet': ['415368'],
#   'Mathilde Paulet': ['413961'],
#   'Mathilde Pon': ['380572'],
#   'Mathis Chapeau': ['413874'],
#   'MathisChapeau': ['413874'],
#   'Matias neyrinck': ['417559'],
#   u'Matt\xe9o Coutou': ['414878'],
#   u'Mat\xe9o Natario': ['413925'],
#   'Maxine Martineau': ['413026'],
#   u'Ma\xebline': ['417965'],
#   u'Ma\xebline hosteins': ['417965'],
#   u'Ma\xeblle Duran': ['399338'],
#   u'Ma\xeblle Yagoub': ['415533'],
#   u'Ma\xeflysse Robarraud': ['416203'],
#   'Melinka': ['403569'],
#   'Meunier Theo': ['414747'],
#   u'Meyrignac-Platon Cl\xe9lia': ['408800'],
#   'Michaux Flore': ['412314'],
#   'Mila Poirier': ['416157'],
#   'Mina Feuillois': ['373611'],
#   'Morin Margaux': ['414077'],
#   'Morvan Camille': ['413395'],
#   u'M\xe9linka': ['403569'],
#   'Nawell Bachani': ['414683'],
#   'Nawell Bachani 2': ['414683'],
#   u'Na\xefda': ['417479'],
#   'Neugebauer Yohan': ['414060'],
#   'Ninon Renou': ['416705'],
#   'Nkoghe': ['416004'],
#   u'N\xe9mati': ['413350'],
#   'OYE NTOUTOUME Reve': ['408717'],
#   u'Oc\xe9ane Hondagneu Td10': ['415920'],
#   'Orlane Galland': ['416381'],
#   'Ornella Martin': ['400802'],
#   'PAILHES Loann': ['411916'],
#   'PAILLASSA Sofia': ['412891'],
#   'PARENT Justine': ['416906'],
#   'PARENT Justine + LEBLAIN': ['416906', '415886'],
#   'PEGORER Emma': ['416129'],
#   'PONTHIER Fidji': ['412228'],
#   'PONTHIER, GATIEN, URREIZTI': ['412228', '417456', '415149'],
#   'PONTHIER, LOVELACE': ['403643', '412228'],
#   'Panechou Priscilla': ['413009'],
#   'Papadacci/Morin': ['413048', '414077'],
#   'Pardo Emma': ['413735'],
#   'Parent Justine': ['416906'],
#   'Paul B': ['414024'],
#   'Paul bnf': ['414024'],
#   'Paul bonnefon': ['414024'],
#   'Pauline Sorel': ['412484'],
#   'Pegorer Emma': ['416129'],
#   'Peleja': ['415773'],
#   u'Pelus Chlo\xe9': ['413571'],
#   'Pierre-Marie bitot': ['418113'],
#   u'Piveteau Oc\xe9ane': ['412145'],
#   'Raffin Loanne': ['415516'],
#   u'Rapha\xebl Thiollier': ['415521'],
#   'Rio Emma': ['413268'],
#   'Romane HAMON': ['413546'],
#   'Roncato Marine': ['418724'],
#   'Roucou Lena': ['417786'],
#   'Roucou Lena, Loste Lou-Anne': ['417786', '413966'],
#   'Ruby Roussel': ['417822'],
#   u'R\xe9mi Tronel': ['415701'],
#   'S. Denoyelle': ['413073'],
#   'SOATTO Tania': ['414952'],
#   'SOATTO Tania - MARONGIN Sophie': ['405421', '414952'],
#   'SUZIE BLEMER': ['402638'],
#   'Sandy Bigey': ['415860'],
#   'Sarah Anton': ['418476'],
#   'Serena': ['415714'],
#   'Shirley': ['416087'],
#   'Sihame Fappani': ['415099'],
#   'Simon': ['413050'],
#   'Simon SAINTARAILLES': ['413050'],
#   'Simon et Jeanne': ['413050'],
#   'Soatto Tania': ['414952'],
#   u'Soilihi N\xe9mati': ['413350'],
#   'Sombre Denoyelle': ['413073'],
#   'Sophie MARONGIN': ['405421'],
#   'Sovieri Ambre': ['402017'],
#   'Suzie Blemer': ['402638'],
#   u'S\xf6ren': ['412396'],
#   u'S\xf6ren Benazet': ['412396'],
#   u'TAPSOBA M\xe9lika': ['418310'],
#   u'Tejerizo La\xefs et Honore Emmy': ['414261', '401188'],
#   u'Tha\xefs': ['415136'],
#   u'Tha\xefs Ferrand': ['415136'],
#   'Theo Albrespy': ['414118'],
#   'Theo alb': ['414118'],
#   'Thomas Casanova': ['413481'],
#   'Thomas Casanova 1': ['413481'],
#   'Thomas Fayolle': ['398605'],
#   u'Th\xe9o Forestier': ['414539'],
#   u'Th\xe9o Joffre': ['415169'],
#   u'Th\xe9o Pr\xe9vot': ['413245'],
#   'Tia Maeva Vespuce Michel': ['416851'],
#   u'Titouan Bouch\xe9': ['419051'],
#   'Tjappa': ['415826'],
#   'Tom dablemont': ['415077'],
#   'URREIZTI et GATIEN': ['415149', '417456'],
#   'URREIZTI irati': ['415149'],
#   'URREIZTI, GATIEN': ['415149', '417456'],
#   'VILLAGEOIS ANNE EMMANUELLE': ['421063'],
#   'VILLAGEOIS ANNE-EMMANUELLE': ['421063'],
#   'VSR': ['417001'],
#   'Vadim Olivan': ['414257'],
#   'Vergnes claire': ['413133'],
#   'Vicentini et Appadoo': ['415269', '412653'],
#   'Victor Samuel Richardson': ['417001'],
#   'Virion lorick': ['369443'],
#   'Waeghemacker': ['401460'],
#   'Waeghemacker Guillaume': ['401460'],
#   'Wang JiangHao': ['414000'],
#   'Wang JiangHao Atkin Joseph': ['414000', '416596'],
#   'WangJiangHao': ['414000'],
#   'Weina Zado': ['412906'],
#   'Wendy et Priscilla': ['415223', '413009'],
#   'William': ['419041'],
#   'Y.auger': ['415389'],
#   'YARDIN-APPADOO Gwenaelle': ['412653'],
#   u'Yagoub--Beaus\xe9jour': ['415533'],
#   u'Yagoub--Beaus\xe9jour Ma\xeblle': ['415533'],
#   'Yardin-Appado': ['412653'],
#   'Yardin-Appadoo Gwenaelle': ['412653'],
#   'Yohan Neugebauer': ['414060'],
#   u'Zo\xe9': ['396936'],
#   u'Zo\xe9 Samson': ['396936'],
#   'abarriere004': ['402714'],
#   'alarroque005': ['417920'],
#   u'ana\xefs zappino': ['413303'],
#   'andrea mautre cassandre deneka': ['413543', '400271'],
#   'bayart': ['413397'],
#   'csaintavi001': ['415962'],
#   'csaintavi001 ebismes001': ['415962', '413429'],
#   'ebismes': ['413429'],
#   'ebismes coline': ['413429'],
#   'ebismes csaintavit001': ['413429', '415962'],
#   'ebismes001': ['413429'],
#   'ebismes001 et csaintavi001': ['413429', '415962'],
#   'eepaud002': ['414403'],
#   'eepaud002 jaguilar003': ['417623', '414403'],
#   'egary002': ['415194'],
#   'eleana': ['414688'],
#   'eleana klein': ['414688'],
#   'eliane': ['413748'],
#   'eliane.M': ['413748'],
#   'elisa f': ['417890'],
#   'elisa ferreira': ['417890'],
#   'emma.lilli': ['414146'],
#   'emmalilli': ['414146'],
#   'epetit009': ['412189'],
#   'esimonell001': ['413159'],
#   'esteban bento': ['415618'],
#   'esteban.bento': ['415618'],
#   'eva doussan': ['416247'],
#   'evaj mathildel': ['412425', '415368'],
#   'evajosephine': ['412425'],
#   'hannah': ['419663'],
#   'ilapeyre001': ['413291'],
#   'ilapeyre001 / eepaud002': ['413291', '414403'],
#   'jchinarro001': ['323516'],
#   'jeanne lapeyre': ['415732'],
#   'jnais001': ['417410'],
#   'june': ['416415'],
#   'lalou.naves': ['415893'],
#   u'la\xefs': ['401188'],
#   u'la\xefs tejerizo': ['401188'],
#   'lchampern': ['323999'],
#   'lchampern001': ['323999'],
#   'lenny valmy': ['414714'],
#   'lnaves001': ['415893'],
#   'louisa': ['396567'],
#   u'l\xe9na martins': ['412885'],
#   'm.cantin': ['416125'],
#   'm.cantin001': ['416125'],
#   'mariam fath': ['416862'],
#   'marylou': ['416541'],
#   u'mar\xe9va durqu\xe9ty': ['418392'],
#   u'mar\xe9va durqu\xe9ty / hazera manon': ['418392', '414076'],
#   'mathis melendez': ['414896'],
#   'mathis melendez 2': ['414896'],
#   u'ma\xeblle pate': ['417735'],
#   'mcantin': ['416125'],
#   'mcantin001': ['416125'],
#   'mdupont015': ['414742'],
#   'melendez barnole': ['414896', '413653'],
#   'melendez mathis': ['414896'],
#   'mila': ['416157'],
#   'mmelendez003': ['414896'],
#   u'm\xe9line': ['414203'],
#   'nawell bachani': ['414683'],
#   'nchahirou001': ['417479'],
#   'nrenou001': ['416705'],
#   'odavid002': ['416347'],
#   'ohiana Fougeray': ['416012'],
#   'oriane.szwertak': ['418797'],
#   'paul_bnf_': ['414024'],
#   'paulineguinle': ['397050'],
#   'psene003': ['413716'],
#   'rose mayor': ['413529'],
#   'scherlinger amandine': ['416365'],
#   'sdenoyell001': ['413073'],
#   'shirley': ['416087'],
#   'sofia paillassa': ['412891'],
#   'szwertak': ['418797'],
#   u'tia-ma\xe9va.vespuce--michel': ['416851'],
#   'tia.vespuce- clelia.meyrignac': ['408800', '416851'],
#   'tostain jade': ['385552'],
#   'wilburn, Hope': ['419120'],
#   'zappino': ['413303']},
#  'etu2alias': {'323516': ['jchinarro001'],
#   '323999': ['lchampern',
#    u'CHAMPERNAU_L\xe9andre',
#    'lchampern001',
#    'L.Champernau',
#    'L.CHAMPERNAU'],
#   '335539': ['Emi Altava'],
#   '351536': ['KaeliaGirol'],
#   '369443': ['Virion lorick'],
#   '370384': ['Eva Hery', 'Eva hery'],
#   '373611': ['Jeanne Mina', 'Mina Feuillois'],
#   '380572': ['Mathilde Pon'],
#   '384868': ['Ludovic Leconte'],
#   '385552': ['tostain jade'],
#   '387089': ['Boutelet Lilly',
#    'Lilly Boutelet',
#    'Lilly Boutelet 1',
#    'Lilly Boutelet 001'],
#   '396182': ['Jeanne Lasnier'],
#   '396567': ['Bennadjema', 'louisa', 'Louisa'],
#   '396761': ['Emeline E', 'Emeline'],
#   '396936': [u'Zo\xe9', u'Zo\xe9 Samson'],
#   '397050': ['paulineguinle'],
#   '397207': ['Cassy'],
#   '397324': ['De Sousa Rodrigues Pedro'],
#   '397359': ['Alicia PARISET', 'Alicia PARISET Axel Hennebert'],
#   '397427': ['Archi', 'Archibald Schmidt'],
#   '397598': ['Abigail raguraj'],
#   '397859': ['Justine Alphonsine'],
#   '398003': [u'Am\xe9lie Martin', 'Amelie Martin'],
#   '398357': ['Agathe Corbier'],
#   '398605': ['Thomas Fayolle'],
#   '398735': ['Aude-Lise Ledentu', 'Aude-Lise'],
#   '398743': ['Emma galiana'],
#   '398903': ['Delage et Saint-Joanis', 'Elliot (Lena) SAINT JOANIS'],
#   '399179': ['MARCELLIN Hugo', 'Marcellin Hugo'],
#   '399338': [u'Ma\xeblle Duran'],
#   '400000': ['Jayson faucheux'],
#   '400271': ['andrea mautre cassandre deneka'],
#   '400421': ['Alice Dupouy', 'Alice'],
#   '400802': ['Ornella Martin'],
#   '401188': [u'la\xefs tejerizo',
#    u'Tejerizo La\xefs et Honore Emmy',
#    u'la\xefs'],
#   '401388': ['Julie-Marie Berlon', 'Julie-Marie'],
#   '401449': ['Lehobey', 'Lehobey, lachehab gros', 'Lehobey, lachehab gros,'],
#   '401460': ['Waeghemacker', 'Waeghemacker Guillaume'],
#   '402017': ['Ambre Sovieri', 'Sovieri Ambre'],
#   '402514': ['Laura Bagnolini'],
#   '402539': ['Goundoba, riziki'],
#   '402638': ['Suzie Blemer', 'SUZIE BLEMER'],
#   '402714': [u'Astrid barri\xe8re', 'abarriere004', u'Astrid Barri\xe8re'],
#   '403161': ['Lucas Muguruza'],
#   '403239': ['General Clara', 'Clara General'],
#   '403569': [u'M\xe9linka', 'Melinka'],
#   '403643': ['PONTHIER, LOVELACE'],
#   '404379': ['BOTROS'],
#   '405421': ['SOATTO Tania - MARONGIN Sophie', 'Sophie MARONGIN'],
#   '405648': ['Damien Guerrero'],
#   '406806': ['Kellian'],
#   '408717': ['OYE NTOUTOUME Reve'],
#   '408800': [u'Meyrignac-Platon Cl\xe9lia', 'tia.vespuce- clelia.meyrignac'],
#   '410131': ['Emma Laujac'],
#   '411861': ['Lena Regazzoni'],
#   '411880': ['Dylan GABORIAU'],
#   '411916': ['Cotentin, Pailhes',
#    'Joana et Loann',
#    'Loann Pailhes et Marine Orset',
#    'Loann Pailhes',
#    'PAILHES Loann'],
#   '411934': ['Kimberley Boquillon'],
#   '411936': ['Maria Saindou', 'Maria'],
#   '411946': ['Colline Cherel'],
#   '411994': ['Ladji saidou Doumbia', 'Ladji Saidou Doumbia'],
#   '412072': [u'Kl\xe9lia ANTOINETTE', 'Justine A klelia A'],
#   '412145': [u'Piveteau Oc\xe9ane'],
#   '412189': ['epetit009'],
#   '412227': ['Lolli Natasha'],
#   '412228': ['PONTHIER, GATIEN, URREIZTI',
#    'GATIEN, PONTHIER',
#    'PONTHIER, LOVELACE',
#    'PONTHIER Fidji'],
#   '412308': ['Louann', 'Louann Hours'],
#   '412314': ['Michaux Flore'],
#   '412341': ['Agleizes001'],
#   '412372': [u'L\xe9a Caumes'],
#   '412396': [u'S\xf6ren', u'S\xf6ren Benazet'],
#   '412398': ['Chloe Lamouroux', u'Lamouroux Chlo\xe9', u'Chlo\xe9 l'],
#   '412425': ['evajosephine', 'evaj mathildel'],
#   '412484': ['Pauline Sorel'],
#   '412653': ['Appadoo et Vicentini',
#    'APPADOO et VICENTINI',
#    'Appadoo',
#    'Vicentini et Appadoo',
#    'YARDIN-APPADOO Gwenaelle',
#    'Yardin-Appado',
#    'Yardin-Appadoo Gwenaelle'],
#   '412746': [u'DEPLUCHE Le\xefla', u'Depluche Le\xefla'],
#   '412772': [u'L\xe9onie Turb\xe9', u'L\xe9onie'],
#   '412885': [u'l\xe9na martins'],
#   '412887': ['Camille v'],
#   '412891': ['sofia paillassa', 'PAILLASSA Sofia'],
#   '412906': ['Weina Zado'],
#   '412931': ['Lenny mussard-benabdelkader'],
#   '412991': ['Lavialle Marie', 'Marie Lavialle'],
#   '413002': ['Hoffmann Justine'],
#   '413009': ['Panechou Priscilla', 'Delage et Panechou', 'Wendy et Priscilla'],
#   '413012': [u'L\xe9a Hardouin'],
#   '413018': ['Claire Vancostenoble'],
#   '413026': ['Maxine Martineau'],
#   '413048': ['Papadacci/Morin', 'Bonvarlet/ Papadacci'],
#   '413050': ['Simon et Jeanne', 'Simon SAINTARAILLES', 'Simon'],
#   '413073': ['Sombre Denoyelle', 'S. Denoyelle', 'sdenoyell001'],
#   '413093': ['Aaron Dieu', 'Loona Dieu'],
#   '413128': ['Enji ghirardelli'],
#   '413133': ['Claire vergnes', 'Vergnes claire'],
#   '413159': ['esimonell001'],
#   '413201': ['Joye Masson'],
#   '413202': ['Marine Orset',
#    'Loann Pailhes et Marine Orset',
#    'Joana Marques et Marine Orset'],
#   '413211': [u'L\xe9os Giret', u'Joana Marques et L\xe9os Giret'],
#   '413245': [u'Th\xe9o Pr\xe9vot'],
#   '413262': ['HAUSER triquang'],
#   '413268': ['Rio Emma'],
#   '413269': ['Lajus Kali'],
#   '413291': ['ilapeyre001',
#    'ilapeyre001 / eepaud002',
#    u'In\xe8slapeyre001 /eepaud002'],
#   '413297': ['Emma Luzinski'],
#   '413303': ['zappino', u'ana\xefs zappino'],
#   '413321': ['Lucile'],
#   '413323': ['Crampe marie'],
#   '413350': [u'Soilihi N\xe9mati', u'N\xe9mati'],
#   '413395': ['Morvan Camille', 'Camille morvan'],
#   '413397': ['bayart'],
#   '413429': ['ebismes coline',
#    'ebismes001',
#    'csaintavi001 ebismes001',
#    'ebismes001 et csaintavi001',
#    'ebismes csaintavit001',
#    'ebismes'],
#   '413439': ['Lena Roucou, Baptiste Bakri',
#    'Baptiste',
#    'Baptistebakri',
#    'Claire & Baptiste',
#    'Baptiste Bakri'],
#   '413481': ['Thomas Casanova', 'Casanova Thomas', 'Thomas Casanova 1'],
#   '413487': ['Heiura Wong'],
#   '413501': ['Colinegoursaud21',
#    'Colinegoursaud',
#    'Coline G',
#    'Coline GOURSAUD'],
#   '413510': [u'Clo\xe9 DiSotto', u'Clo\xe9 Di Sotto'],
#   '413529': ['rose mayor'],
#   '413543': ['andrea mautre cassandre deneka', 'Deneka--Collin Cassandre'],
#   '413546': ['Romane HAMON'],
#   '413553': [u'L\xe9a Sainpaul (ordi)', u'L\xe9a Sainpaul'],
#   '413571': [u'Pelus Chlo\xe9'],
#   '413643': ['Edouard et Campanerutto', 'Laura EDOUARD'],
#   '413653': ['melendez barnole',
#    u'Barnole Myl\xe9nie',
#    u'BARNOLE Myl\xe9nie',
#    'Barnole Mylenie'],
#   '413687': [u'Ana\xefs Bernou', 'Anais Bernou'],
#   '413716': ['psene003'],
#   '413735': ['Pardo Emma'],
#   '413748': ['eliane.M', 'eliane', 'Eliane m'],
#   '413822': [u'Cl\xe9mence Labbe'],
#   '413833': ['Lilou Samson et JiancHao Wang',
#    'Lilou Samson',
#    'Lilou Samson et Juliette Autor'],
#   '413874': ['Mathis Chapeau', 'MathisChapeau'],
#   '413895': ['FIGUEIREDO-RAMOS-ENFI-BELIAL', 'FIGUEIREDO-RAMOS'],
#   '413916': [u'Chlo\xe9 Gravelat', 'GRAVELAT CHLOE'],
#   '413925': [u'Mat\xe9o Natario'],
#   '413961': ['Mathilde Paulet'],
#   '413966': ['Roucou Lena, Loste Lou-Anne', 'Loste lou-anne'],
#   '414000': ['Wang JiangHao Atkin Joseph',
#    'WangJiangHao',
#    'Wang JiangHao',
#    'Lilou Samson et JiancHao Wang'],
#   '414017': ['GUINAT'],
#   '414024': ['Paul B', 'Paul bonnefon', 'Paul bnf', 'paul_bnf_'],
#   '414030': ['Lisa Villepontoux'],
#   '414055': ['Charlynelecar', 'Le car - aguirre'],
#   '414060': ['Neugebauer Yohan', 'Yohan Neugebauer'],
#   '414076': [u'mar\xe9va durqu\xe9ty / hazera manon'],
#   '414077': ['Morin Margaux', 'Margaux Morin', 'Papadacci/Morin'],
#   '414101': ['Jade Hazera'],
#   '414118': ['Theo Albrespy', 'Theo alb'],
#   '414146': ['emma.lilli', 'emmalilli'],
#   '414180': ['Cotentin, Pailhes', 'Cotentin Amandine', 'COTENTIN Amandine'],
#   '414202': ['Axel Hennebert', 'Alicia PARISET Axel Hennebert'],
#   '414203': [u'm\xe9line'],
#   '414210': ['Laura hinger', 'Hinger laura'],
#   '414222': ['Chrystal', 'Duthilleul Chrystal'],
#   '414227': ['Aure girard', 'Aure'],
#   '414257': ['Vadim Olivan'],
#   '414261': [u'Tejerizo La\xefs et Honore Emmy'],
#   '414283': ['Jouanmiqueou Emma'],
#   '414345': ['Lou Falc-Arnould', 'Falc-Arnould Yagoub'],
#   '414403': ['ilapeyre001 / eepaud002',
#    u'In\xe8slapeyre001 /eepaud002',
#    'eepaud002 jaguilar003',
#    'eepaud002'],
#   '414416': ['Elisa joly', 'Elisa J'],
#   '414434': [u'Lo\xefse Hollaender Adrien Delluc'],
#   '414454': ['Gozillon Emma', 'Emma Gozillon'],
#   '414464': ['Lilou SANCHO', 'Lilou Sancho'],
#   '414527': ['Elsa PICARD'],
#   '414539': [u'Th\xe9o Forestier'],
#   '414603': ['Laurine marrel', 'Laurine Marrel', 'Marrel Laurine'],
#   '414683': ['nawell bachani', 'Nawell Bachani 2', 'Nawell Bachani'],
#   '414688': ['eleana klein', 'eleana'],
#   '414705': ['Coline Labat', 'Coline Lbt'],
#   '414714': ['lenny valmy'],
#   '414742': ['mdupont015'],
#   '414747': ['Meunier Theo'],
#   '414807': ['Alexis peyen'],
#   '414854': ['BENZONI Enzo'],
#   '414877': ['Laure Garnaud'],
#   '414878': [u'Coutou Matt\xe9o', u'Matt\xe9o Coutou'],
#   '414896': ['melendez barnole',
#    'mmelendez003',
#    'mathis melendez',
#    'mathis melendez 2',
#    'melendez mathis'],
#   '414952': ['SOATTO Tania', 'SOATTO Tania - MARONGIN Sophie', 'Soatto Tania'],
#   '414967': ['Jgonzalez', 'Julia gonzalez'],
#   '414981': ['Jade Christophe', 'Jade CHRISTOPHE'],
#   '415014': ['Killian Adrover'],
#   '415077': ['Tom dablemont'],
#   '415098': ['Aiden Bertin'],
#   '415099': ['Sihame Fappani'],
#   '415136': [u'Ferrand Tha\xefs', u'Tha\xefs', u'Tha\xefs Ferrand'],
#   '415143': ['Joana Marques',
#    'Joana et Loann',
#    u'Joana Marques et L\xe9os Giret',
#    'Joana Marques et Marine Orset'],
#   '415149': ['Irati Urreizti',
#    'PONTHIER, GATIEN, URREIZTI',
#    'URREIZTI irati',
#    'URREIZTI, GATIEN',
#    'URREIZTI et GATIEN',
#    'Irati URREIZTI',
#    'Irati'],
#   '415169': [u'Th\xe9o Joffre'],
#   '415194': ['egary002'],
#   '415209': [u'Lo\xefse Hollaender Adrien Delluc'],
#   '415223': ['Delage et Saint-Joanis',
#    'Delage et Panechou',
#    'Wendy et Priscilla'],
#   '415258': ['Goundoba, riziki'],
#   '415269': ['Appadoo et Vicentini',
#    'APPADOO et VICENTINI',
#    'Vicentini et Appadoo',
#    'Carla Vicentini'],
#   '415356': [u'L\xe9a Maniaci1', u'L\xe9a Maniaci'],
#   '415368': ['evaj mathildel', 'Loquet Mathilde', 'Mathilde Loquet'],
#   '415389': ['Y.auger'],
#   '415398': [u'Artaud Aliz\xe9e', u'Aliz\xe9e Artaud'],
#   '415439': ['Mathilde DA CUNHA', 'DA CUNHA Mathilde'],
#   '415449': [u'Castello-- Iturria Na\xefa'],
#   '415466': ['Manon bernede', 'Bernede Manon', 'Manon Bernede'],
#   '415516': ['Raffin Loanne'],
#   '415521': [u'Rapha\xebl Thiollier'],
#   '415533': [u'Ma\xeblle Yagoub',
#    u'Yagoub--Beaus\xe9jour Ma\xeblle',
#    'Falc-Arnould Yagoub',
#    u'Yagoub--Beaus\xe9jour'],
#   '415539': ['Amblard Juline'],
#   '415598': ['Lisa Brt', 'Lisa Brettes', 'LisaB'],
#   '415613': ['Cazenave Laura'],
#   '415618': ['Esteban BENTO', 'esteban bento', 'esteban.bento'],
#   '415691': ['Hugo Gendron'],
#   '415694': ['Mathilde Breuils', 'Breuils Mathilde'],
#   '415701': [u'R\xe9mi Tronel'],
#   '415714': ['Serena'],
#   '415732': ['jeanne lapeyre'],
#   '415747': ['Charlotte', 'Chavier Charlotte'],
#   '415773': ['Peleja', 'Afonso Peleja'],
#   '415791': ['Lilou Samson et Juliette Autor'],
#   '415808': [u'In\xe8s.p', u'In\xe8s pigeot', u'In\xe8s Pigeot'],
#   '415818': ['Amine elhaloui', 'Elhaloui amine', 'Amine Elhaloui'],
#   '415826': ['Harrydsha', 'Tjappa'],
#   '415860': ['Sandy Bigey'],
#   '415886': ['LEBLAIN', 'PARENT Justine + LEBLAIN'],
#   '415893': ['lalou.naves', 'lnaves001'],
#   '415920': [u'Oc\xe9ane Hondagneu Td10'],
#   '415962': ['csaintavi001 ebismes001',
#    'ebismes001 et csaintavi001',
#    'Coline Camille Saint-Avit',
#    'ebismes csaintavit001',
#    'csaintavi001'],
#   '416004': ['Nkoghe'],
#   '416012': ['ohiana Fougeray'],
#   '416026': ['Kolar'],
#   '416038': ['Justine Lavaud', 'J.Lavaud'],
#   '416062': ['Dupouy Manon'],
#   '416085': ['Isasti Ludivine'],
#   '416087': ['Shirley', 'shirley', 'Banizette shirley'],
#   '416090': [u'Lamarque No\xe9mie'],
#   '416125': [u'In\xe8s', 'mcantin001', 'm.cantin001', 'mcantin', 'm.cantin'],
#   '416129': ['Pegorer Emma', 'PEGORER Emma'],
#   '416148': ['Imanol Cartier', 'Imanol cartier'],
#   '416157': ['mila', 'Mila Poirier'],
#   '416203': [u'Ma\xeflysse Robarraud'],
#   '416247': ['Doussan Eva', 'eva doussan'],
#   '416328': ['Jocelyn mbilima'],
#   '416347': ['odavid002'],
#   '416365': ['scherlinger amandine'],
#   '416381': ['Orlane Galland'],
#   '416406': [u'L\xe9a M\xe9mon'],
#   '416415': ['june'],
#   '416438': ['Malik Lachehab Gros',
#    'Lehobey, lachehab gros',
#    'Lehobey, lachehab gros,'],
#   '416502': ['Karine Barsacq'],
#   '416527': ['Bonvarlet', 'Bonvarlet/ Papadacci'],
#   '416530': ['Lou Anne Lhermitte'],
#   '416541': ['marylou', 'Banaszak'],
#   '416564': [u'L\xe9na Favre', u'FAVRE L\xe9na'],
#   '416596': ['Wang JiangHao Atkin Joseph', 'Joseph atkin', 'JosephAtkin'],
#   '416671': ['Aurel@700', 'Aurelm7000'],
#   '416705': ['Ninon Renou', 'nrenou001'],
#   '416713': ['Carla-Marie', 'Carla-Marie BARTOLOMUCCI'],
#   '416758': ['Fanny albanel'],
#   '416792': ['Hania Abdel Gawwad'],
#   '416801': ['Justine Andrieuxx', 'Justine Andrieux'],
#   '416842': ['Galerneau'],
#   '416851': ['Tia Maeva Vespuce Michel',
#    u'tia-ma\xe9va.vespuce--michel',
#    'tia.vespuce- clelia.meyrignac'],
#   '416862': ['mariam fath'],
#   '416867': ['Corentin MORTIER'],
#   '416906': ['PARENT Justine',
#    'Justine Parent',
#    'Parent Justine',
#    'PARENT Justine + LEBLAIN'],
#   '416926': ['Descamp steve', 'Descamp Steve'],
#   '416955': ['Mailley Melissa Marie'],
#   '416982': ['Clemence BEGAY'],
#   '417001': ['Victor Samuel Richardson', 'VSR'],
#   '417143': ['Hderiaz001'],
#   '417162': ['C.Desmond', 'Carla.D'],
#   '417392': ['Khysanth Laporte'],
#   '417410': ['jnais001'],
#   '417456': ['PONTHIER, GATIEN, URREIZTI',
#    'GATIEN, PONTHIER',
#    u'Anna\xeblle Gatien',
#    'URREIZTI, GATIEN',
#    'URREIZTI et GATIEN'],
#   '417479': [u'Na\xefda', 'nchahirou001'],
#   '417531': ['Edouard et Campanerutto', 'Lucia CAMPANERUTTO'],
#   '417559': ['Matias neyrinck'],
#   '417575': ['Lise', 'Lise Baron'],
#   '417623': ['eepaud002 jaguilar003'],
#   '417682': ['Carla Dos Santos', 'Dos Santos carla', 'Dos santos carla'],
#   '417705': ['Chambaud', 'Angele'],
#   '417730': ['Jeanne Grand-Jean'],
#   '417735': [u'ma\xeblle pate'],
#   '417786': ['Lena Roucou, Baptiste Bakri',
#    'Roucou Lena',
#    'LenaRoucou',
#    'Roucou Lena, Loste Lou-Anne',
#    'Lena Roucou'],
#   '417797': ['Blanchard Laura'],
#   '417822': ['Ruby Roussel', 'Juliette Roussel'],
#   '417876': ['Bastien Aroztegui'],
#   '417890': ['elisa f', 'elisa ferreira'],
#   '417920': ['Abel', 'alarroque005'],
#   '417965': [u'Ma\xebline', u'Ma\xebline hosteins'],
#   '417982': ['Cyrielle Tavera'],
#   '418113': ['Pierre-Marie bitot'],
#   '418155': ['Elisa mel'],
#   '418310': [u'TAPSOBA M\xe9lika'],
#   '418372': ['Kirkorian'],
#   '418392': [u'mar\xe9va durqu\xe9ty',
#    u'mar\xe9va durqu\xe9ty / hazera manon'],
#   '418398': ['Eleanor'],
#   '418467': [u'Foudi ma\xefra'],
#   '418476': ['Sarah Anton'],
#   '418489': ['Logan', 'Logan charneau'],
#   '418543': ['FLEURANCEAU Sarah'],
#   '418584': [u'Ana\xefs AURIAULT'],
#   '418632': ['Lucie Coiffard', 'Hope Wilburn et Lucie Coiffard'],
#   '418716': ['Eva Belanger'],
#   '418724': ['Roncato Marine'],
#   '418797': ['oriane.szwertak', 'szwertak', 'Deysse'],
#   '418807': ['CHOQUET Lisa'],
#   '418829': ['Camille Alvarez'],
#   '418883': ['MARTY Louise'],
#   '419041': ['GUILLEMBET WILLIAM-JUNIOR', 'William'],
#   '419051': [u'Titouan Bouch\xe9'],
#   '419120': ['Hope et Lucie',
#    'Hope Wilburn et Lucie Coiffard',
#    'wilburn, Hope'],
#   '419152': [u'J\xe9riel'],
#   '419162': ['Jennifer Lesueur'],
#   '419530': ['Daria'],
#   '419573': ['Lucy'],
#   '419651': ['Kristina'],
#   '419663': ['hannah', 'Hannah'],
#   '420093': ['Denisa'],
#   '420584': ['Gabrielle'],
#   '421063': ['Anne-Emmanuelle',
#    'VILLAGEOIS ANNE-EMMANUELLE',
#    'VILLAGEOIS ANNE EMMANUELLE']}}

# %%
with codecs.open(fAliasQDLE, 'w', encoding="utf8") as outfile:
    yaml.safe_dump(correspondances, outfile, default_flow_style=False)

# %% [markdown]
# # Calcul des notes
# Attention au nombre de questions

# %%
nbQ=6.0

# %%
def aliasQuizz(pseudo):
    result=None
    if pseudo in alias:
        result=alias[pseudo]
    return result

def noteQuizz(points):   
    result=8
    if points>0:
        result=int(round(10*(1+points/nbQ),0))
    return result
        
        

lQuizz["id"]=lQuizz["pseudo"].apply(aliasQuizz)
lQuizz["note"]=lQuizz["points"].apply(noteQuizz)

# %%
def splitPseudo1(id):
    result=None
    if id and len(id)>0:
        result=id[0]
    return result

def splitPseudo2(id):
    result=None
    if id and len(id)>1:
        result=id[1]
    return result

def splitPseudo3(id):
    result=None
    if id and len(id)>2:
        result=id[2]
    return result

lQuizz["id1"]=lQuizz["id"].apply(splitPseudo1)
lQuizz["id2"]=lQuizz["id"].apply(splitPseudo2)
lQuizz["id3"]=lQuizz["id"].apply(splitPseudo3)

lQuizz
# Out:
#                        pseudo  points   temps                id  note     id1  \
# 0               laïs tejerizo       5  104.53          [401188]    18  401188
# 1     csaintavi001 ebismes001       5  221.52  [415962, 413429]    18  415962
# 2               Emma Luzinski       5  245.84          [413297]    18  413297
# 3              Chloé Gravelat       5  302.20          [413916]    18  413916
# 4           FLEURANCEAU Sarah       5  313.92          [418543]    18  418543
# 5                L.Champernau       4  133.98          [323999]    17  323999
# 6     Meyrignac-Platon Clélia       4  175.02          [408800]    17  408800
# 7                Léa Hardouin       4  189.54          [413012]    17  413012
# 8               Thaïs Ferrand       4  201.02          [415136]    17  415136
# 9         Simon SAINTARAILLES       4  223.39          [413050]    17  413050
# 10     Waeghemacker Guillaume       4  238.07          [401460]    17  401460
# 11             Lena Regazzoni       4  240.40          [411861]    17  411861
# 12               jchinarro001       4  249.67          [323516]    17  323516
# 13             nawell bachani       4  281.54          [414683]    17  414683
# 14                       Théo       4  295.91              None    17    None
# 15                     Serena       4  312.61          [415714]    17  415714
# 16                      Marie       3   88.59              None    15    None
# 17              Joana Marques       3   95.63          [415143]    15  415143
# 18             Dylan GABORIAU       3  122.66          [411880]    15  411880
# 19                lalou.naves       3  128.07          [415893]    15  415893
# 20                Jade Hazera       3  138.76          [414101]    15  414101
# 21               Vadim Olivan       3  143.46          [414257]    15  414257
# 22            Annaëlle Gatien       3  150.67          [417456]    15  417456
# 23               Alexis peyen       3  161.30          [414807]    15  414807
# 24           Carla Dos Santos       3  185.32          [417682]    15  417682
# 25          Lisa Villepontoux       3  194.12          [414030]    15  414030
# 26                KaeliaGirol       3  210.77          [351536]    15  351536
# 27              Manon Bernede       3  213.02          [415466]    15  415466
# 28             Laurine marrel       3  220.09          [414603]    15  414603
# 29             PONTHIER Fidji       3  233.52          [412228]    15  412228
# ..                        ...     ...     ...               ...   ...     ...
# 85             Karine Barsacq       1   54.00          [416502]    12  416502
# 86                    zappino       1   58.52          [413303]    12  413303
# 87               Hugo Gendron       1   58.58          [415691]    12  415691
# 88                 mdupont015       1   80.26          [414742]    12  414742
# 89                Lena Roucou       1  113.37          [417786]    12  417786
# 90              Amelie Martin       1  138.06          [398003]    12  398003
# 91                     Romane       1  151.59              None    12    None
# 92      Océane Hondagneu Td10       1  162.48          [415920]    12  415920
# 93                   Eva Hery       1  170.58          [370384]    12  370384
# 94              Pauline Sorel       1  183.87          [412484]    12  412484
# 95              Laura EDOUARD       1  224.63          [413643]    12  413643
# 96       Vicentini et Appadoo       1  225.39  [415269, 412653]    12  415269
# 97                   camilleS       1  227.24              None    12    None
# 98            Sophie MARONGIN       1  237.36          [405421]    12  405421
# 99                      minou       1  250.73              None    12    None
# 100           Thomas Casanova       0    0.00          [413481]     8  413481
# 101                   marylou       0    0.00          [416541]     8  416541
# 102                      Sasa       0    0.00              None     8    None
# 103          Juliette Roussel       0   17.58          [417822]     8  417822
# 104  Deneka--Collin Cassandre       0   35.66          [413543]     8  413543
# 105                      Sali       0   36.44              None     8    None
# 106               Julie-Marie       0   47.08          [401388]     8  401388
# 107                    Peleja       0  119.77          [415773]     8  415773
# 108                     Naïda       0  152.04          [417479]     8  417479
# 109              Meunier Theo       0  160.79          [414747]     8  414747
# 110              Pegorer Emma       0  168.94          [416129]     8  416129
# 111           Cyrielle Tavera       0  211.16          [417982]     8  417982
# 112           Astrid Barrière       0  212.33          [402714]     8  402714
# 113         Cotentin Amandine       0  213.80          [414180]     8  414180
# 114                  Rio Emma       0  259.98          [413268]     8  413268
#
#         id2   id3
# 0      None  None
# 1    413429  None
# 2      None  None
# 3      None  None
# 4      None  None
# 5      None  None
# 6      None  None
# 7      None  None
# 8      None  None
# 9      None  None
# 10     None  None
# 11     None  None
# 12     None  None
# 13     None  None
# 14     None  None
# 15     None  None
# 16     None  None
# 17     None  None
# 18     None  None
# 19     None  None
# 20     None  None
# 21     None  None
# 22     None  None
# 23     None  None
# 24     None  None
# 25     None  None
# 26     None  None
# 27     None  None
# 28     None  None
# 29     None  None
# ..      ...   ...
# 85     None  None
# 86     None  None
# 87     None  None
# 88     None  None
# 89     None  None
# 90     None  None
# 91     None  None
# 92     None  None
# 93     None  None
# 94     None  None
# 95     None  None
# 96   412653  None
# 97     None  None
# 98     None  None
# 99     None  None
# 100    None  None
# 101    None  None
# 102    None  None
# 103    None  None
# 104    None  None
# 105    None  None
# 106    None  None
# 107    None  None
# 108    None  None
# 109    None  None
# 110    None  None
# 111    None  None
# 112    None  None
# 113    None  None
# 114    None  None
#
# [115 rows x 8 columns]

# %%
df1=lQuizz[["pseudo","note","temps","id1"]].dropna()
df2=lQuizz[["pseudo","note","temps","id2"]].dropna()
df3=lQuizz[["pseudo","note","temps","id3"]].dropna()
df1.columns=["pseudo","note","temps","id"]
df2.columns=["pseudo","note","temps","id"]
df3.columns=["pseudo","note","temps","id"]

# %%
df123=pd.concat([df1,df2,df3]).sort_values(["note","temps"],ascending=[False,True])
df123
# Out:
#                              pseudo  note   temps      id
# 0                     laïs tejerizo    18  104.53  401188
# 1           csaintavi001 ebismes001    18  221.52  415962
# 1           csaintavi001 ebismes001    18  221.52  413429
# 2                     Emma Luzinski    18  245.84  413297
# 3                    Chloé Gravelat    18  302.20  413916
# 4                 FLEURANCEAU Sarah    18  313.92  418543
# 5                      L.Champernau    17  133.98  323999
# 6           Meyrignac-Platon Clélia    17  175.02  408800
# 7                      Léa Hardouin    17  189.54  413012
# 8                     Thaïs Ferrand    17  201.02  415136
# 9               Simon SAINTARAILLES    17  223.39  413050
# 10           Waeghemacker Guillaume    17  238.07  401460
# 11                   Lena Regazzoni    17  240.40  411861
# 12                     jchinarro001    17  249.67  323516
# 13                   nawell bachani    17  281.54  414683
# 15                           Serena    17  312.61  415714
# 17                    Joana Marques    15   95.63  415143
# 18                   Dylan GABORIAU    15  122.66  411880
# 19                      lalou.naves    15  128.07  415893
# 20                      Jade Hazera    15  138.76  414101
# 21                     Vadim Olivan    15  143.46  414257
# 22                  Annaëlle Gatien    15  150.67  417456
# 23                     Alexis peyen    15  161.30  414807
# 24                 Carla Dos Santos    15  185.32  417682
# 25                Lisa Villepontoux    15  194.12  414030
# 26                      KaeliaGirol    15  210.77  351536
# 27                    Manon Bernede    15  213.02  415466
# 28                   Laurine marrel    15  220.09  414603
# 29                   PONTHIER Fidji    15  233.52  412228
# 30                   Lavialle Marie    15  238.74  412991
# ..                              ...   ...     ...     ...
# 79   Loïse Hollaender Adrien Delluc    13  315.89  415209
# 80                Thomas Casanova 1    13  323.62  413481
# 82                 Mathilde Breuils    12   16.76  415694
# 83                        Aude-Lise    12   29.45  398735
# 85                   Karine Barsacq    12   54.00  416502
# 86                          zappino    12   58.52  413303
# 87                     Hugo Gendron    12   58.58  415691
# 88                       mdupont015    12   80.26  414742
# 89                      Lena Roucou    12  113.37  417786
# 90                    Amelie Martin    12  138.06  398003
# 92            Océane Hondagneu Td10    12  162.48  415920
# 93                         Eva Hery    12  170.58  370384
# 94                    Pauline Sorel    12  183.87  412484
# 95                    Laura EDOUARD    12  224.63  413643
# 96             Vicentini et Appadoo    12  225.39  415269
# 96             Vicentini et Appadoo    12  225.39  412653
# 98                  Sophie MARONGIN    12  237.36  405421
# 100                 Thomas Casanova     8    0.00  413481
# 101                         marylou     8    0.00  416541
# 103                Juliette Roussel     8   17.58  417822
# 104        Deneka--Collin Cassandre     8   35.66  413543
# 106                     Julie-Marie     8   47.08  401388
# 107                          Peleja     8  119.77  415773
# 108                           Naïda     8  152.04  417479
# 109                    Meunier Theo     8  160.79  414747
# 110                    Pegorer Emma     8  168.94  416129
# 111                 Cyrielle Tavera     8  211.16  417982
# 112                 Astrid Barrière     8  212.33  402714
# 113               Cotentin Amandine     8  213.80  414180
# 114                        Rio Emma     8  259.98  413268
#
# [104 rows x 4 columns]

# %%
dfNotes=df123.groupby("id").max().sort_values("note",ascending=False)
dfNotes.to_csv(fNotes,sep="\t",encoding="utf8")
