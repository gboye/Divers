# %%
import codecs,unidecode,yaml,glob,os,shutil,re
import itertools as it
import pandas as pd
from cellbell import ding
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-0c07a7e2c37b> in <module>()
#       2 import itertools as it
#       3 import pandas as pd
# ----> 4 from cellbell import ding
#
# ImportError: No module named cellbell

# %% [raw]
# nQuizz=10
# fEtudiants=u"/Users/gilles/Desktop/18-L1-Quizz.csv"
# fEtudiantsNew=u"/Users/gilles/Desktop/LNS1U4-LNS1T2-Liste.csv"
# fQuizzoodle=u"/Users/gilles/Desktop/Quizz%d.csv"%nQuizz
# fAliasQDLE=u"/Users/gilles/Desktop/Quizz-Alias.yaml"
# fNotes=fQuizzoodle.replace(u".csv",u"-Notes.csv")

# %%
nQuizz=1
# fEtudiants=u"/Users/gilles/Desktop/19-Morpho1-Quizz.csv"
# fEtudiantsNew=u"/Users/gilles/Desktop/19-LNS2U2-Liste.csv"
# fQuizzoodle=u"/Users/gilles/Desktop/Quizz%02d.csv"%nQuizz
# fAliasQDLE=u"/Users/gilles/Desktop/Quizz-Alias.yaml"
fMajeure=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Majeure.csv"
fMineure=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Mineure.csv"
fCM=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/CM.csv"
fAliasQDLE=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Quizz-Alias.yaml"
fQuizzoodle=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/01-NotesQuizz/Quizz%02d.csv"%nQuizz
fQuizzoodle=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-UE4-Morphologie/20-Quizz/Quizz%02d.csv"%nQuizz
fNotes=fQuizzoodle.replace(u".csv",u"-Notes.csv")

# %%
oldNotes={}
if os.path.isfile(fNotes):
    with codecs.open(fNotes,"r",encoding="utf8") as inFile:
        lNotes=inFile.readlines()
    for l in lNotes[1:]:
        lEls=l.strip().split("\t")
        oldNotes["\t".join(lEls[:2])]=int(lEls[2])
    fNotesOld=fNotes.replace(u"-Notes.csv",u"-Notes-old.csv")
    if not os.path.isfile(fNotesOld):
        shutil.copyfile(fNotes,fNotesOld)
oldNotes
# Out:
# {}

# %%
sep=u"\t"
nbQuestionQuizz={i:(7 if i<7 else 6) for i in range(1,nQuizz+1)}
nbQuestionQuizz={i:6 for i in range(1,nQuizz+1)}
nbQuestionQuizz
# Out:
# {1: 6}

# %%
try:
    with codecs.open(fAliasQDLE, 'r', encoding="utf8") as inFile:
        correspondances=yaml.safe_load(inFile)
    alias=correspondances["alias2etu"]
except:
    alias={}
alias
# Out:
# {'001lherfouf': ['lherfouf001'],
#  '04247454': [],
#  '138': [],
#  '28150417': [],
#  '38 27 56': ['eherrera001'],
#  '380908': ['bsalman001'],
#  '390305': ['lmagit001'],
#  '49814523': [],
#  '56416920': [],
#  '70207082': [],
#  '777': [],
#  '7925871': ['?'],
#  '92317548': [],
#  'a.cornillier': ['acornilli001'],
#  'aanny': ['?'],
#  'abailly003': ['abailly003'],
#  'abeccacci001': ['abeccacci001'],
#  'abertrand014': ['?'],
#  'abottin001': ['abottin001'],
#  'acornillier': ['acornilli001'],
#  'acourrege002': ['acourrege002'],
#  'ada': ['?'],
#  'adartigue': ['adartigue004'],
#  'adeline pacot': ['apacot001'],
#  'adeniaud002': ['adeniaud002'],
#  'adiarra001 + cbeauvais004': ['adiarra001', 'cbeauvais004'],
#  'adinne001': ['adinne001'],
#  'adinne001 bowicz001': ['adinne001', 'pzubowicz001'],
#  'adinne001 lepinoux001': ['adinne001', 'lepinoux001'],
#  'adutour001': ['adutour001'],
#  'aguichon002': ['aguichon002'],
#  'alabinal001': ['alabinal001'],
#  'alauret005': ['alauret005'],
#  'amachefer001': ['amachefer001'],
#  'amariehe001': ['amarieheb001'],
#  'amartosre001': ['amartosre001'],
#  'amauran002': ['amauran002'],
#  'amele002': ['?'],
#  'aminat': ['?'],
#  'aminat oluwamago': ['aoluwamag001'],
#  'amy rodriguez': ['arodrigue025'],
#  'anais moncoucy': ['amoncoucy001'],
#  'andrea': [],
#  'andreterr001': ['tandreter001'],
#  'anihouarn001/jlaugt002': ['jlaugt002', 'anihouarn001'],
#  'anna': ['?'],
#  'aoluwamag001': ['aoluwamag001'],
#  'aouafi002/tgodard002': ['aouafi002', 'tgodard002'],
#  'apacot001': ['apacot001'],
#  'apirritano001': ['apirritan001'],
#  'apirritano001 ldrochon001': ['apirritan001', 'ldrochon001'],
#  'arielle zana': ['azana001'],
#  'asolsona001': ['asolsona001'],
#  'astasica001': ['astasica001'],
#  'audreyweitmann': [],
#  'averral001,eroofthoo001': ['averral001', 'eroofthoo001'],
#  'azana001': ['azana001'],
#  'bee': ['?'],
#  'bgaultier001': ['bgaultier001'],
#  'bgaultier001, mreyjulli001': ['bgaultier001', 'mreyjulli001'],
#  'bidou': [],
#  'bill stew': [],
#  'billard002': ['tbillard002'],
#  'bjorn': [],
#  'bjorn hougen': ['bhougen001'],
#  'blandine005': [],
#  'bonade001': ['ebonade001'],
#  'boue1': ['?'],
#  'bruh': ['?'],
#  'camero': [],
#  'cami.lefmar': ['clefevrem001'],
#  'camille theillout': ['ctheillou001'],
#  'camille.lavigne': ['clavigne004'],
#  'capucine': [],
#  'cbeauvais004': ['cbeauvais004'],
#  'cbeauvais004   mmurat004': ['cbeauvais004', 'mmurat004'],
#  'cbourdet002': ['cbourdet002'],
#  'cdemontou001': ['cdemontou001'],
#  'cdemontou001111': ['cdemontou001'],
#  'cdemontou01': ['cdemontou001'],
#  'cdepetro001 lcaillabe001': ['cdepetro001', 'lcaillabe001'],
#  'cdrilhole01': ['cdrilhole001'],
#  'cduval007': ['cduval007'],
#  'cesperoup001': ['cesperoup001'],
#  'cgibault002': ['cgibault002'],
#  'cgroussea001/aouafi002': ['cgroussea001', 'aouafi002'],
#  'cha': [],
#  'charlotte': ['?'],
#  'charlotte henquinet': ['chenquine001'],
#  u'chlo\xe94/7': [],
#  'choenig001, ebigot001': ['choenig001', 'ebigot001'],
#  'choenig001, ldanis001': ['choenig001', 'ldanis001'],
#  'chugueny001': ['chugueny001'],
#  'clara': [],
#  'clara001': [],
#  'claraa001': [],
#  'claranoye474': ['cnoye001'],
#  'claranoye47400': ['cnoye001'],
#  'clavergne001': ['clavergne005'],
#  'clavergne005': ['clavergne005'],
#  'clefevrem001, ehetzel001': ['clefevrem001', 'ehetzel001'],
#  'cmodiano': ['cmodiano002'],
#  'comas001': ['mcomas001'],
#  'condamin laurie': ['lcondamin001'],
#  'cpetit015 et eroofthoo001': ['cpetit015', 'eroofthoo001'],
#  'cpoulain': ['cpoulain004'],
#  'cpoulain004': ['cpoulain004'],
#  'cuhalde001': ['cuhalde001'],
#  'darti': ['?'],
#  'ddomingue002': ['ddomingue002'],
#  'decaen': ['edecaen001'],
#  'dgazarian001': ['dgazarian001'],
#  'di carlo 001': ['ldicarlo001'],
#  'dieu': ['?'],
#  'dmilement001': ['dmilement001'],
#  'dutour': ['adutour001'],
#  'e.bonade001': ['ebonade001'],
#  'ebonade': ['ebonade001'],
#  'edecaen': ['edecaen001'],
#  'edupontta001': ['edupontta001'],
#  'efath': ['efath001'],
#  'efath001': ['efath001'],
#  'efrancese': ['efrancese001'],
#  'efrancese001': ['efrancese001'],
#  'eguillot004, ahalgand002': ['eguillot004', 'ahalgand002'],
#  'eguillot004, jmocaer001': ['eguillot004', 'jmocaer001'],
#  'eguillot004,ahalgand002': ['eguillot004', 'ahalgand002'],
#  'eguillot004,jmocaer001': ['eguillot004', 'jmocaer001'],
#  'ek': ['?'],
#  'el ultimo mejor': [],
#  'eleclerem': ['eleclerem001'],
#  'eliot': [],
#  'emeline': ['?'],
#  'emie': [],
#  'emma': ['?'],
#  'emma rodrigues': ['erodrigue014'],
#  'emmaleclerem001': ['eleclerem001'],
#  'enicolasj': ['enicolasj001'],
#  'eren jeager': [],
#  'eren jeager est mort': [],
#  'erodrigue014': ['erodrigue014'],
#  'eschoefft01': ['eschoefft001'],
#  'evan': [],
#  'everdonma001': ['everdonma001'],
#  'fardoin002': ['fardoin002'],
#  'fbarrat001': ['fbarrat001'],
#  'fcordette001 - nnaprix001': ['fcordette001', 'nnaprix001'],
#  'fcordette001-nnaprix001': ['fcordette001', 'nnaprix001'],
#  'ferreira005': ['sferreira005'],
#  'fifjrj': [],
#  'fionab002': [],
#  'flo26': ['flecoeur001'],
#  'florian': ['?'],
#  'floriane cordette': ['fcordette001'],
#  'fmatte001': ['fmatte001'],
#  'francesca': ['fnetry001'],
#  'fuck kalaba': [],
#  'gaypard': ['?'],
#  'gguinee002, lbuelens001': ['gguinee002', 'lbuelens001'],
#  'ghaure001, mlemoal001': ['ghaure001', 'mlemoal001'],
#  'giorno giovanna': [],
#  'glegal001': ['glegal001'],
#  'guillaut, monnet': ['tguillaut001', 'mmonnet002'],
#  'hattie chatt': ['?'],
#  'hchatt001': [],
#  'henycams': ['?'],
#  'hey': [],
#  'heye': [],
#  'hougen': ['bhougen001'],
#  'hugo': [],
#  'hugo carnevale': ['hcarneval001'],
#  'hugo carnevale td02': ['hcarneval001'],
#  'iasseli001': ['iasselin001'],
#  'iasseli001/icoulais001': ['iasselin001', 'icoulais001'],
#  'icoulais001': ['icoulais001'],
#  'ideyres001': ['ideyres001'],
#  'ielgharbi': ['ielgharbi002'],
#  'ifischer001, jalexandr005': ['ifischer001', 'jalexandr005'],
#  'intrue': [],
#  'itori': ['?'],
#  'jbenesy001, eroofthoo001': ['jbenesy001', 'eroofthoo001'],
#  'jbenesy001,eroofthoo001': ['jbenesy001', 'eroofthoo001'],
#  'jbenesy001,roofthoo001': ['jbenesy001', 'eroofthoo001'],
#  'jcazette002': ['jcazette002'],
#  'jean demaggio': ['jdemaggio001'],
#  'jeandemaggio': ['jdemaggio001'],
#  'jeanne.l': [],
#  'jeanne3': [],
#  'jeanne33200': ['?'],
#  'jeannelandure': ['jlandure001'],
#  'jesus': ['?'],
#  'jgarcia019': ['jgarcia019'],
#  'jgueylard002, mschoonbe001': ['jgueylard002', 'mschoonbe001'],
#  'jhinsinge001': ['jhinsinge001'],
#  'jlacombe008 / lmarollea002': ['jlacombe008', 'lmarollea002'],
#  'jlaugt002/anihouarn001': ['jlaugt002', 'anihouarn001'],
#  'jlechat001 smechalakh001': ['jlechat001', 'smechalak001'],
#  'jmesnard001': ['jmesnard001'],
#  'jmetais001': ['jmetais001'],
#  'jmocaer001  ahalgand002': ['jmocaer001', 'ahalgand002'],
#  'jowanlele': ['jowanlele001'],
#  'jregazni1': ['jregazni001'],
#  'jsaputa001': ['jsaputa001'],
#  'jtm gile': [],
#  'ju': ['?'],
#  'julie': [],
#  'justine': ['?'],
#  'juu': ['?'],
#  'jvillesso': ['jvillesso001'],
#  u'jvous soul\xe8ve': [],
#  'kaeldori': ['?'],
#  'kalaba': ['?'],
#  'kate': ['?'],
#  'kav': [],
#  'kborde001': ['kborde001'],
#  'kchalus001': ['kchalus001'],
#  'kezzy england': ['kengland001'],
#  'kfigueres001': ['kfigueres001'],
#  'kgautier': ['kgautier001'],
#  'kgautier001': ['kgautier001'],
#  'kndjadi': ['kndjadi001'],
#  'kshigetom001': ['kshigetom001'],
#  'l': [],
#  'labinal001': ['alabinal001'],
#  'lavergne005': ['clavergne005'],
#  'lavigne camille': ['clavigne004'],
#  'lcaillab001': ['lcaillabe001'],
#  'lcaillabet001': ['lcaillabe001'],
#  'lcaillabet001   ljamme001': ['lcaillabe001', 'ljamme001'],
#  'lchassin': ['lchassin001'],
#  'lchassin001': ['lchassin001'],
#  'lchassin01': ['lchassin001'],
#  'lclaisse001': ['lclaisse001'],
#  'ldejeans001': ['ldejeans001'],
#  'ldelaflor': ['ldelaflor001'],
#  'ldelaflor001': ['ldelaflor001'],
#  'ldicarlo': ['ldicarlo001'],
#  'lducouret002': ['lducouret002'],
#  'le fils de gillou': [],
#  'le plus mignon': ['?'],
#  'lea djaroun': ['ldjaroun001'],
#  'lenocq': ['lenocq001'],
#  'leslie': ['mpalanica001'],
#  'lfixy001': ['lfixy001'],
#  'lgrattaro001': ['lgrattaro001'],
#  'lherfouf001': ['lherfouf001'],
#  'lherrera001.': ['lherrera001'],
#  'lhuet003': ['lhuet003'],
#  'licence 1': ['?'],
#  'lilas': [],
#  'lisa': [],
#  'llandreau002': ['llandreau002'],
#  'llastouil001 , mdieu002': ['llastouil001', 'mdieu002'],
#  'llaveist01, ecarcenac001': ['llaveist001', 'ecarcenac001'],
#  'lleite001': ['lleite001'],
#  'llepenven001': ['tlepenven001'],
#  'lmarolleau': ['lmarollea002'],
#  'long': ['?'],
#  'louanna': ['?'],
#  'louis pinson': ['lpinson001'],
#  'lpheulpin': ['lpheulpin001'],
#  'lprovost00': ['lprovost002'],
#  'lprovost002': ['lprovost002'],
#  'lpunginko001, llastouil001': ['lpunginko001', 'llastouil001'],
#  'lpunginko001, smartin028': ['lpunginko001', 'smartin028'],
#  'lraffy001': ['lraffy001'],
#  'lrives001': ['lrives001'],
#  'ltognazza001': ['ltognazza001'],
#  'lucas jamme': ['ljamme001'],
#  'lucile de la fuente': ['ldelafuen001'],
#  'luciledlf': [],
#  u'l\xe9o': [],
#  u'l\xe9onore dinety': ['ldinety001'],
#  'm': [],
#  'm.,': [],
#  'm.borderie002': ['mborderie002'],
#  'm.roudaut003 , v.place002': ['mroudaut003', 'vplace002'],
#  'mabdallah': ['mabdallah008'],
#  'mabdallah008': ['mabdallah008'],
#  'mabdallah008, mphinma001': ['mabdallah008', 'mphinma001'],
#  'mabdou005': ['mabdou005'],
#  'macces1': ['smacces001'],
#  'machefer001': ['amachefer001'],
#  'maelwenn fourcampre': ['mfourcamp001'],
#  'magic mushrooms': [],
#  'manon la guenon': [],
#  'manon la jeune fille': [],
#  'manon, maudemar001': ['maudemarj001'],
#  'manonrouard': ['mrouard001'],
#  'marginal': ['?'],
#  u'marginal b\xe9b\xe9': [],
#  'margot cazabat': ['mcazabatm001'],
#  'maria': ['mpalanica001'],
#  'marion': [],
#  'marion lafon': ['mlafon006'],
#  'martiiiiiiiiin le chien': [],
#  'marwan': ['?'],
#  'maude': [],
#  'maudemarj001 llastouil001': ['maudemarj001', 'llastouil001'],
#  'maudemarj001, llastouil001': ['maudemarj001', 'llastouil001'],
#  'maudier002 et ahalgand002': ['maudier002', 'ahalgand002'],
#  'maudran001': ['maudran001'],
#  'mbenbrahi002': ['mbenbrahi002'],
#  'mbenbrahim002': ['mbenbrahi002'],
#  'mblandie001': ['mblandie001'],
#  'mbringtown': ['mbringtow001'],
#  'mclarabon': ['mclarabon001'],
#  'mclave001': ['mclave001'],
#  'mcomas001': ['mcomas001'],
#  'mcontini00': ['mcontini001'],
#  'mdieu002 , llastouil001': ['mdieu002', 'llastouil001'],
#  'mdieu002 , smartin028': ['mdieu002', 'smartin028'],
#  'mdieu002 llastouil001': ['mdieu002', 'llastouil001'],
#  'mdieu002, llastouil001': ['mdieu002', 'llastouil001'],
#  'mdieu002,malizon001': ['mdieu002', 'malizon001'],
#  'mdiez06': ['mdiez003'],
#  'mdupebe003': ['mdupebe003'],
#  u'mdup\xe8be003': ['mdupebe003'],
#  'mgans001': ['mgans001'],
#  'mgibaru001': ['mgibaru001'],
#  'mgibaru001 , icoulais001': ['mgibaru001', 'icoulais001'],
#  'mgibaru001 , mmadid001': ['mgibaru001', 'mmadid001'],
#  'mia': [],
#  'mia moghraoui': ['mmoghraou001'],
#  'minarra001': ['minarra001'],
#  'mlafont003': ['mlafont003'],
#  'mlemoal001.ghaure001': ['mlemoal001', 'ghaure001'],
#  'mm': [],
#  'mmadid001': ['mmadid001'],
#  'mmartenot': ['mmartenot001'],
#  'mmontagne003': ['mmontagne003'],
#  'moi': ['?'],
#  'moncoucy': ['amoncoucy001'],
#  'monnet/guillaut': ['mmonnet002', 'tguillaut001'],
#  'mostrowsk001': ['mostrowsk001'],
#  'mpetitberg001': ['mpetitber001'],
#  'mphinma001': ['mphinma001'],
#  'mphinma001, mabdallah008': ['mphinma001', 'mabdallah008'],
#  'mprades1': ['mprades001'],
#  'mreyjulli001': ['mreyjulli001'],
#  'mreyjulli001, mgibaru001': ['mreyjulli001', 'mgibaru001'],
#  'mroudaut003': ['mroudaut003'],
#  'mroudaut003  vplace002': ['mroudaut003', 'vplace002'],
#  'mroudaut003, vplace002': ['mroudaut003', 'vplace002'],
#  'msarci001': ['msarci001'],
#  'mschoonbe001, nbesseruu001': ['mschoonbe001', 'nbesseruu001'],
#  'mstanek002': ['mstanek002'],
#  'mvilleneu006': ['mvilleneu006'],
#  'nedouard': ['nedouard001'],
#  'ngillet': ['ngillet002'],
#  'ngillet002 , malizon001': ['ngillet002', 'malizon001'],
#  'niklekalaba': [],
#  'niklekalabia': [],
#  'nlacheny001': ['nlachenyf001'],
#  'nlachenyfer001': ['nlachenyf001'],
#  'nlachenyg001': ['nlachenyf001'],
#  'nnaprix001 / fcordette001': ['nnaprix001', 'fcordette001'],
#  'nnaprix001-fcordette001': ['nnaprix001', 'fcordette001'],
#  'nora': ['ngillet002'],
#  u'no\xe9mie': ['?'],
#  'nude eco+': [],
#  'okamari no suzuki': [],
#  'pabrieu001': ['pabrieu001'],
#  'pacot adeline': ['apacot001'],
#  'pcayo': [],
#  'petitberg001': ['mpetitber001'],
#  'pirritano001': ['apirritan001'],
#  'pzubowicz': ['pzubowicz001'],
#  'quentin villars': ['qvillars001'],
#  'quizz s03': [],
#  'rastacouette': [],
#  'regardez toradora': [],
#  u'rolengadi001\U0001f451': ['rolengadi001'],
#  'rouard manon': ['mrouard001'],
#  'rtanji001': ['?'],
#  's.ferreira005': ['sferreira005'],
#  'samuel': ['?'],
#  'sandries001': ['sandries001'],
#  'sandries001, clavergne001': ['sandries001', 'clavergne005'],
#  'sandries001, clavergne005': ['sandries001', 'clavergne005'],
#  'sandro teixeira': ['steixeira003'],
#  'scamara002': ['scamara002'],
#  'scaraes001': ['scaraes001'],
#  'sdupuy': ['sdupuy008'],
#  'sdupuy008': ['sdupuy008'],
#  'sferreira005': ['sferreira005'],
#  'sliessi01': ['sliessi001'],
#  'smacces001': ['smacces001'],
#  'smarin004': ['smarin004'],
#  'smartin028, mdieu001': ['smartin028', 'mdieu002'],
#  'smechalak001, lpunginko001': ['smechalak001', 'lpunginko001'],
#  'smehl001': ['smehl001'],
#  'soraya': [],
#  'sosoya': [],
#  'sosoya3360': [],
#  'spommier004': ['spommier004'],
#  'ssenechau001': ['ssenechau001'],
#  'sserhane001 adutour001': ['sserhane001', 'adutour001'],
#  'sshmitt001': ['sschmitt001'],
#  'sslaoua': ['sslaoua001'],
#  'steph': [],
#  'stew': [],
#  'tandreterr001': ['tandreter001'],
#  'tbagur001': ['tbagur001'],
#  'tbrendelc001': ['tbrendelc001'],
#  'teo_guillaut': ['tguillaut001'],
#  'teo_guillauy': ['tguillaut001'],
#  'tgodard002': ['tgodard002'],
#  'tgodard002, amele002': ['tgodard002'],
#  'thuyngannguyendao': ['qnguyen004'],
#  'ubx': ['?'],
#  'v.mouchoux': ['vmouchoux001'],
#  'vgandillo001': ['vgandillo001'],
#  'vic': ['?'],
#  'vmouchoux': ['vmouchoux001'],
#  'vsamierja001': ['vsamierja001'],
#  'wlannel001': ['wlannel001'],
#  'yass': [],
#  'yhaettel001': ['yhaettel001'],
#  'ymetivier001': ['ymetivier001'],
#  'ymonmont001': ['ymonmont001'],
#  'yoann lacroix': ['ylacroix001'],
#  'yumi': [],
#  'zbenard001': ['zbenard001'],
#  'zpronost0001': ['zpronost001'],
#  'zpronost001': ['zpronost001'],
#  'zpronost001111': ['zpronost001'],
#  'zrelave001': ['zrelave001'],
#  'zsausse001': ['zsausse001']}

# %%
try:
    dfCM=pd.read_csv(filepath_or_buffer=fCM,sep="\t",encoding="utf8")
    dfCM.set_index(u"Identifiant",inplace=True)
except:
    dfMajeure=pd.read_csv(filepath_or_buffer=fMajeure,sep="\t",encoding="utf8")
    dfMajeure.set_index(u"Identifiant",inplace=True)
    dMajeure=dfMajeure[u"Code étudiant"].to_dict()
    dMajeure

    dfMineure=pd.read_csv(filepath_or_buffer=fMineure,sep="\t",encoding="utf8")
    dfMineure.set_index(u"Identifiant",inplace=True)
    dMineure=dfMineure[u"Code étudiant"].to_dict()
    dMineure

    dfCM=dfMajeure.append(dfMineure,sort=False)
    dfCM.to_csv(path_or_buf=fCM,sep="\t",encoding="utf8")
dfCM[u"Code étudiant"]=dfCM[u"Code étudiant"].astype(unicode)
dfCM
# Out:
#               Nom patronymique        Nom usuel        Prénom Code étudiant  \
# Identifiant
# mabdallah008          ABDALLAH              NaN        MAELIS        385180
# cabderreb001         ABDERREBI              NaN      CAMILLIA        374204
# mabdou005                ABDOU              NaN         MELOE        384307
# nandriant001  ANDRIANTSIFERANA              NaN   NANDRIANINA        384656
# sandries001            ANDRIES              NaN        SOPHIE        380354
# laranaz001              ARANAZ              NaN         LOUIS        385151
# iasselin001            ASSELIN              NaN       ISANDRE        385107
# maudran001              AUDRAN              NaN         MANON        380271
# aazouni002              AZOUNI              NaN         ANAIS        387238
# sbadi001                  BADI              NaN        SOPHIA        384841
# abailly003              BAILLY              NaN        ALEXIA        386579
# mbarbotin005          BARBOTIN              NaN         MANON        386909
# fbarrat001              BARRAT              NaN          FANY        380991
# cbeauvais004          BEAUVAIS              NaN       CAMILLE        381551
# abeccacci001         BECCACCIA              NaN        ANDREA        384802
# zbenard001              BENARD              NaN           ZOE        380191
# lberard006              BERARD              NaN         LOUIS        350705
# fbernard002            BERNARD              NaN         FIONA        385579
# mbirochau001          BIROCHAU              NaN  MARIE-AMELIE        388320
# mblandie001            BLANDIE              NaN       MELISSA        382957
# lbonneau006            BONNEAU              NaN          LISE        384439
# mborderie002          BORDERIE              NaN         MAEVA        381407
# abottin001              BOTTIN              NaN        ANDREA        383137
# jbouffard001          BOUFFARD              NaN          JADE        371834
# cbourdet002            BOURDET              NaN        CHIFIU        381808
# tbrendelc001           BRENDEL  BRENDEL-CANTAUT      TIMOTHEE        389538
# fcaget001                CAGET              NaN      FLORENCE        336879
# lcaillabe001         CAILLABET              NaN         LUCIE        382263
# lcantin001              CANTIN              NaN    LILAS-ROSE        387265
# lcaparros002          CAPARROS              NaN           LEA        380627
# ...                        ...              ...           ...           ...
# asopena001              SOPENA              NaN       AMAELLE        381228
# asoteras001            SOTERAS              NaN          AXEL        381341
# csoual001                SOUAL              NaN         CLARA        387012
# mstanek002              STANEK              NaN     MARY-ANNE        381350
# ystraehli001          STRAEHLI              NaN         YOANN        386900
# mtamby002                TAMBY              NaN      MARJORIE        382358
# steixeira003          TEIXEIRA              NaN        SANDRO        380763
# mthomas027              THOMAS              NaN       MATHIEU        365862
# ltognazza001          TOGNAZZA              NaN         LUCAS        383226
# ftoquin001              TOQUIN              NaN       FLORIAN        380569
# htronche001            TRONCHE              NaN       HELOISE        381485
# rvalton001              VALTON              NaN        ROXANE        386492
# cvanautry001       VAN AUTRYVE              NaN      CAPUCINE        384771
# avanbelli001      VANBELLINGEN              NaN        AXELLE        385409
# nveriteta001    VERITE--TAULET              NaN          NINA        383903
# yveron001                VERON              NaN         YLIAN        385661
# averral001              VERRAL              NaN       ANTHONY        381555
# avignaud004            VIGNAUD              NaN      AMANDINE        380976
# qvillars001            VILLARS              NaN       QUENTIN        384392
# jvillesso001         VILLESSOT              NaN        JULIEN        386686
# bvincent005            VINCENT              NaN       BASTIEN        385725
# bvincent004            VINCENT              NaN      BERENICE        384042
# gvion001                  VION              NaN       GREGORY        386851
# lviot001                  VIOT              NaN        LAURIC        372473
# lvo001                      VO              NaN          LONG        389124
# lweiss002                WEISS              NaN        LAURIE        380570
# pzubowicz001          ZUBOWICZ              NaN       PAULINE        380853
# cguest001                GUEST              NaN     CATHERINE        389566
# abajan001                BAJAN              NaN        ARTHUR        366287
# fkiefer001              KIEFER              NaN      FABIENNE        388888
#
#                                                            Mail  Note
# Identifiant
# mabdallah008        maelis.abdallah@etu.u-bordeaux-montaigne.fr   NaN
# cabderreb001     camillia.abderrebi@etu.u-bordeaux-montaigne.fr   NaN
# mabdou005               meloe.abdou@etu.u-bordeaux-montaigne.fr   NaN
# nandriant001  nandrianina.andriantsiferana@etu.u-bordeaux-mo...   NaN
# sandries001          sophie.andries@etu.u-bordeaux-montaigne.fr   NaN
# laranaz001             louis.aranaz@etu.u-bordeaux-montaigne.fr   NaN
# iasselin001         isandre.asselin@etu.u-bordeaux-montaigne.fr   NaN
# maudran001             manon.audran@etu.u-bordeaux-montaigne.fr   NaN
# aazouni002             anais.azouni@etu.u-bordeaux-montaigne.fr   NaN
# sbadi001                sophia.badi@etu.u-bordeaux-montaigne.fr   NaN
# abailly003           alexia.bailly1@etu.u-bordeaux-montaigne.fr   NaN
# mbarbotin005         manon.barbotin@etu.u-bordeaux-montaigne.fr   NaN
# fbarrat001              fany.barrat@etu.u-bordeaux-montaigne.fr   NaN
# cbeauvais004       camille.beauvais@etu.u-bordeaux-montaigne.fr   NaN
# abeccacci001       andrea.beccaccia@etu.u-bordeaux-montaigne.fr   NaN
# zbenard001               zoe.benard@etu.u-bordeaux-montaigne.fr   NaN
# lberard006             louis.berard@etu.u-bordeaux-montaigne.fr   NaN
# fbernard002          fiona.bernard1@etu.u-bordeaux-montaigne.fr   NaN
# mbirochau001  marie-amelie.birochau@etu.u-bordeaux-montaigne.fr   NaN
# mblandie001         melissa.blandie@etu.u-bordeaux-montaigne.fr   NaN
# lbonneau006            lise.bonneau@etu.u-bordeaux-montaigne.fr   NaN
# mborderie002         maeva.borderie@etu.u-bordeaux-montaigne.fr   NaN
# abottin001            andrea.bottin@etu.u-bordeaux-montaigne.fr   NaN
# jbouffard001          jade.bouffard@etu.u-bordeaux-montaigne.fr   NaN
# cbourdet002          chifiu.bourdet@etu.u-bordeaux-montaigne.fr   NaN
# tbrendelc001  timothee.brendel-cantaut@etu.u-bordeaux-montai...   NaN
# fcaget001            florence.caget@etu.u-bordeaux-montaigne.fr   NaN
# lcaillabe001        lucie.caillabet@etu.u-bordeaux-montaigne.fr   NaN
# lcantin001        lilas-rose.cantin@etu.u-bordeaux-montaigne.fr   NaN
# lcaparros002           lea.caparros@etu.u-bordeaux-montaigne.fr   NaN
# ...                                                         ...   ...
# asopena001           amaelle.sopena@etu.u-bordeaux-montaigne.fr   NaN
# asoteras001            axel.soteras@etu.u-bordeaux-montaigne.fr   NaN
# csoual001               clara.soual@etu.u-bordeaux-montaigne.fr   NaN
# mstanek002         mary-anne.stanek@etu.u-bordeaux-montaigne.fr   NaN
# ystraehli001         yoann.straehli@etu.u-bordeaux-montaigne.fr   NaN
# mtamby002            marjorie.tamby@etu.u-bordeaux-montaigne.fr   NaN
# steixeira003        sandro.teixeira@etu.u-bordeaux-montaigne.fr   NaN
# mthomas027           mathieu.thomas@etu.u-bordeaux-montaigne.fr   NaN
# ltognazza001         lucas.tognazza@etu.u-bordeaux-montaigne.fr   NaN
# ftoquin001           florian.toquin@etu.u-bordeaux-montaigne.fr   NaN
# htronche001         heloise.tronche@etu.u-bordeaux-montaigne.fr   NaN
# rvalton001            roxane.valton@etu.u-bordeaux-montaigne.fr   NaN
# cvanautry001   capucine.van-autryve@etu.u-bordeaux-montaigne.fr   NaN
# avanbelli001    axelle.vanbellingen@etu.u-bordeaux-montaigne.fr   NaN
# nveriteta001    nina.verite--taulet@etu.u-bordeaux-montaigne.fr   NaN
# yveron001               ylian.veron@etu.u-bordeaux-montaigne.fr   NaN
# averral001           anthony.verral@etu.u-bordeaux-montaigne.fr   NaN
# avignaud004        amandine.vignaud@etu.u-bordeaux-montaigne.fr   NaN
# qvillars001         quentin.villars@etu.u-bordeaux-montaigne.fr   NaN
# jvillesso001       julien.villessot@etu.u-bordeaux-montaigne.fr   NaN
# bvincent005         bastien.vincent@etu.u-bordeaux-montaigne.fr   NaN
# bvincent004        berenice.vincent@etu.u-bordeaux-montaigne.fr   NaN
# gvion001               gregory.vion@etu.u-bordeaux-montaigne.fr   NaN
# lviot001                lauric.viot@etu.u-bordeaux-montaigne.fr   NaN
# lvo001                      long.vo@etu.u-bordeaux-montaigne.fr   NaN
# lweiss002              laurie.weiss@etu.u-bordeaux-montaigne.fr   NaN
# pzubowicz001       pauline.zubowicz@etu.u-bordeaux-montaigne.fr   NaN
# cguest001           catherine.guest@etu.u-bordeaux-montaigne.fr   NaN
# abajan001              arthur.bajan@etu.u-bordeaux-montaigne.fr   NaN
# fkiefer001          fabienne.kiefer@etu.u-bordeaux-montaigne.fr   NaN
#
# [471 rows x 6 columns]

# %%
dfCM[dfCM.index.str.contains("laugt")]
# Out:
#             Nom patronymique Nom usuel Prénom Code étudiant  \
# Identifiant
# jlaugt002              LAUGT       NaN  JULIE        381437
#
#                                                 Mail  Note
# Identifiant
# jlaugt002    julie.laugt@etu.u-bordeaux-montaigne.fr   NaN

# %% [raw]
# def fusionnerDict(dict1, dict2):
#     result = dict1.copy()   # start with dict1's keys and values
#     result.update(dict2)    # modifies result with dict2's keys and values & returns None
#     return result
# dCM=fusionnerDict(dMajeure,dMineure)
# dCM

# %%
def chercherIdentifiant(chaine):
    print chaine
    codes=[]
    identifiants=[]
    nobody=False
    if chaine in alias:
        codes=[dfCM.loc[a,u"Code étudiant"] for a in alias[chaine] if a in dfCM.index]       
    else:
        while not codes and not nobody:
            chaineDecode=unidecode.unidecode(chaine).lower()
            saisie=raw_input(u"quels identifiants pour %s"%chaineDecode)
            saisie = unidecode.unidecode(saisie).lower()
            if saisie==u"?":
                identifiants=[u"?"]
                codes=[]
                nobody=True
                print codes or nobody
            elif u" " in saisie:
                identifiants=saisie.split(u" ")
                if not all((a in dfCM.index) or (a==u"?") for a in identifiants):
                    identifiants=[]
                    codes=[]
                else:
                    identifiants=[a if a in dfCM.index else u"?" for a in identifiants]
                    codes=[dfCM.loc[a,u"Code étudiant"] for a in identifiants if a in dfCM.index]
                    print identifiants,codes
            elif saisie in dfCM.index:
                identifiants=[saisie]
                codes=[dfCM.loc[saisie,u"Code étudiant"]]
    alias[chaine]=identifiants
    return codes

def decomposerNom(nom):
    result=[]
    m=re.findall(ur"(\w{5,9}\d{3})",nom)
    if m:
        for e in m:
            if e in dfCM.index:
                result.append(dfCM.loc[e,u"Code étudiant"])
            else:
                result.extend(chercherIdentifiant(e))
    else:
        result.extend(chercherIdentifiant(nom))
    return result

# %%
print "flo26" in alias
[dfCM.loc[a,u"Code étudiant"] for a in alias["flo26"] if a in dfCM.index]
# Out:
# True
# [u'382471']

# %% [raw]
# alias[u"rolengadi001👑"]=['rolengadi001']

# %% [raw]
# for nom in [u"rolengadi001👑"]:
#     print chercherIdentifiant(nom)

# %%
with codecs.open(fQuizzoodle,"r",encoding="utf8") as input:
    lQuizz=input.readlines()
    
nbBons={}
ansTimes={}
for ligne in lQuizz[1:]:
    if ligne.strip()!="":
        splits=ligne.strip().replace("&amp;","&").split(";")
        splits=ligne.strip().replace("&amp;","&").split(";")
        lenNoms=len(splits)-2
        nom=" ".join(splits[:lenNoms])
        bons=splits[lenNoms]
        temps=splits[lenNoms+1]
        nom=nom.strip().lower()
        if nom in dfCM.index:
            akas=[dfCM.loc[nom,u"Code étudiant"]]
        elif nom in alias:
            akas=[dfCM.loc[a,u"Code étudiant"] for a in alias[nom] if a in dfCM.index]
        else:
            akas=chercherIdentifiant(nom)
            alias[nom]=akas
#        print nom,akas,bons
        for aka in akas:
            if aka in nbBons:
                nbBons[aka]+=int(bons)
            else:
                nbBons[aka]=int(bons)
            if aka in ansTimes:
                ansTimes[aka]+=float(temps)
            else:
                ansTimes[aka]=float(temps)

#notes={aka:(round(float(nbBons[aka])/6*10+10) for aka in nbBons)}
ansTimes
# Out:
# stywel chevalier
# quels identifiants pour stywel chevalier381862
# /Users/gilles/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: Argument <type 'str'> is not an unicode object. Passing an encoded string will likely have unexpected results.
#   if sys.path[0] == '':
# quels identifiants pour stywel chevalierschevalie005
# lavigne
# quels identifiants pour lavigneclavigne004
# tina
# quels identifiants pour tina
# quels identifiants pour tina?
# True
# mabdou005 mmurat004
# quels identifiants pour mabdou005 mmurat004mabdou005 mmurat004
# [u'mabdou005', u'mmurat004'] [u'384307', u'372039']
# léonore dinéty
# quels identifiants pour leonore dinetyldinety001
# sa
# quels identifiants pour sa?
# True
# o.n
# quels identifiants pour o.n?
# True
# j
# quels identifiants pour j?
# True
# bogoss absolu
# quels identifiants pour bogoss absolu?
# True
# {u'348881': 107.28,
#  u'350705': 89.7,
#  u'365910': 72.79,
#  u'369000': 105.19,
#  u'370670': 100.4,
#  u'371353': 134.54,
#  u'372039': 113.98,
#  u'380103': 135.7,
#  u'380146': 88.13,
#  u'380150': 103.24,
#  u'380189': 151.74,
#  u'380191': 128.44,
#  u'380282': 90.31,
#  u'380354': 96.02,
#  u'380685': 87.11,
#  u'380705': 102.86,
#  u'380846': 52.87,
#  u'380991': 160.32,
#  u'381009': 96.84,
#  u'381195': 51.42,
#  u'381209': 135.58,
#  u'381377': 169.51,
#  u'381382': 80.62,
#  u'381407': 141.83,
#  u'381535': 150.75,
#  u'381551': 117.02,
#  u'381756': 126.75,
#  u'381862': 96.78,
#  u'381876': 63.09,
#  u'381978': 115.8,
#  u'381980': 86.26,
#  u'382128': 133.31,
#  u'382259': 146.78,
#  u'382527': 55.65,
#  u'382756': 98.85,
#  u'382781': 74.17,
#  u'382788': 108.23,
#  u'382821': 87.73,
#  u'383063': 78.76,
#  u'383074': 127.94,
#  u'383344': 112.2,
#  u'383420': 120.53,
#  u'383431': 121.25,
#  u'383481': 144.3,
#  u'383565': 155.53,
#  u'383649': 107.94,
#  u'383742': 157.99,
#  u'383882': 143.78,
#  u'383998': 81.86,
#  u'384204': 126.59,
#  u'384307': 113.98,
#  u'384492': 127.05,
#  u'384802': 55.48,
#  u'384919': 105.2,
#  u'385042': 79.68,
#  u'385180': 108.23,
#  u'385183': 125.15,
#  u'385410': 119.42,
#  u'385551': 147.68,
#  u'385708': 141.21}

# %%
dfCM#.set_index("Identifiant")
# for id in nbBons:
#     dfCM.loc[id,"note"]=nbBons[id]
# Out:
#               Nom patronymique        Nom usuel        Prénom Code étudiant  \
# Identifiant
# mabdallah008          ABDALLAH              NaN        MAELIS        385180
# cabderreb001         ABDERREBI              NaN      CAMILLIA        374204
# mabdou005                ABDOU              NaN         MELOE        384307
# nandriant001  ANDRIANTSIFERANA              NaN   NANDRIANINA        384656
# sandries001            ANDRIES              NaN        SOPHIE        380354
# laranaz001              ARANAZ              NaN         LOUIS        385151
# iasselin001            ASSELIN              NaN       ISANDRE        385107
# maudran001              AUDRAN              NaN         MANON        380271
# aazouni002              AZOUNI              NaN         ANAIS        387238
# sbadi001                  BADI              NaN        SOPHIA        384841
# abailly003              BAILLY              NaN        ALEXIA        386579
# mbarbotin005          BARBOTIN              NaN         MANON        386909
# fbarrat001              BARRAT              NaN          FANY        380991
# cbeauvais004          BEAUVAIS              NaN       CAMILLE        381551
# abeccacci001         BECCACCIA              NaN        ANDREA        384802
# zbenard001              BENARD              NaN           ZOE        380191
# lberard006              BERARD              NaN         LOUIS        350705
# fbernard002            BERNARD              NaN         FIONA        385579
# mbirochau001          BIROCHAU              NaN  MARIE-AMELIE        388320
# mblandie001            BLANDIE              NaN       MELISSA        382957
# lbonneau006            BONNEAU              NaN          LISE        384439
# mborderie002          BORDERIE              NaN         MAEVA        381407
# abottin001              BOTTIN              NaN        ANDREA        383137
# jbouffard001          BOUFFARD              NaN          JADE        371834
# cbourdet002            BOURDET              NaN        CHIFIU        381808
# tbrendelc001           BRENDEL  BRENDEL-CANTAUT      TIMOTHEE        389538
# fcaget001                CAGET              NaN      FLORENCE        336879
# lcaillabe001         CAILLABET              NaN         LUCIE        382263
# lcantin001              CANTIN              NaN    LILAS-ROSE        387265
# lcaparros002          CAPARROS              NaN           LEA        380627
# ...                        ...              ...           ...           ...
# asopena001              SOPENA              NaN       AMAELLE        381228
# asoteras001            SOTERAS              NaN          AXEL        381341
# csoual001                SOUAL              NaN         CLARA        387012
# mstanek002              STANEK              NaN     MARY-ANNE        381350
# ystraehli001          STRAEHLI              NaN         YOANN        386900
# mtamby002                TAMBY              NaN      MARJORIE        382358
# steixeira003          TEIXEIRA              NaN        SANDRO        380763
# mthomas027              THOMAS              NaN       MATHIEU        365862
# ltognazza001          TOGNAZZA              NaN         LUCAS        383226
# ftoquin001              TOQUIN              NaN       FLORIAN        380569
# htronche001            TRONCHE              NaN       HELOISE        381485
# rvalton001              VALTON              NaN        ROXANE        386492
# cvanautry001       VAN AUTRYVE              NaN      CAPUCINE        384771
# avanbelli001      VANBELLINGEN              NaN        AXELLE        385409
# nveriteta001    VERITE--TAULET              NaN          NINA        383903
# yveron001                VERON              NaN         YLIAN        385661
# averral001              VERRAL              NaN       ANTHONY        381555
# avignaud004            VIGNAUD              NaN      AMANDINE        380976
# qvillars001            VILLARS              NaN       QUENTIN        384392
# jvillesso001         VILLESSOT              NaN        JULIEN        386686
# bvincent005            VINCENT              NaN       BASTIEN        385725
# bvincent004            VINCENT              NaN      BERENICE        384042
# gvion001                  VION              NaN       GREGORY        386851
# lviot001                  VIOT              NaN        LAURIC        372473
# lvo001                      VO              NaN          LONG        389124
# lweiss002                WEISS              NaN        LAURIE        380570
# pzubowicz001          ZUBOWICZ              NaN       PAULINE        380853
# cguest001                GUEST              NaN     CATHERINE        389566
# abajan001                BAJAN              NaN        ARTHUR        366287
# fkiefer001              KIEFER              NaN      FABIENNE        388888
#
#                                                            Mail  Note
# Identifiant
# mabdallah008        maelis.abdallah@etu.u-bordeaux-montaigne.fr   NaN
# cabderreb001     camillia.abderrebi@etu.u-bordeaux-montaigne.fr   NaN
# mabdou005               meloe.abdou@etu.u-bordeaux-montaigne.fr   NaN
# nandriant001  nandrianina.andriantsiferana@etu.u-bordeaux-mo...   NaN
# sandries001          sophie.andries@etu.u-bordeaux-montaigne.fr   NaN
# laranaz001             louis.aranaz@etu.u-bordeaux-montaigne.fr   NaN
# iasselin001         isandre.asselin@etu.u-bordeaux-montaigne.fr   NaN
# maudran001             manon.audran@etu.u-bordeaux-montaigne.fr   NaN
# aazouni002             anais.azouni@etu.u-bordeaux-montaigne.fr   NaN
# sbadi001                sophia.badi@etu.u-bordeaux-montaigne.fr   NaN
# abailly003           alexia.bailly1@etu.u-bordeaux-montaigne.fr   NaN
# mbarbotin005         manon.barbotin@etu.u-bordeaux-montaigne.fr   NaN
# fbarrat001              fany.barrat@etu.u-bordeaux-montaigne.fr   NaN
# cbeauvais004       camille.beauvais@etu.u-bordeaux-montaigne.fr   NaN
# abeccacci001       andrea.beccaccia@etu.u-bordeaux-montaigne.fr   NaN
# zbenard001               zoe.benard@etu.u-bordeaux-montaigne.fr   NaN
# lberard006             louis.berard@etu.u-bordeaux-montaigne.fr   NaN
# fbernard002          fiona.bernard1@etu.u-bordeaux-montaigne.fr   NaN
# mbirochau001  marie-amelie.birochau@etu.u-bordeaux-montaigne.fr   NaN
# mblandie001         melissa.blandie@etu.u-bordeaux-montaigne.fr   NaN
# lbonneau006            lise.bonneau@etu.u-bordeaux-montaigne.fr   NaN
# mborderie002         maeva.borderie@etu.u-bordeaux-montaigne.fr   NaN
# abottin001            andrea.bottin@etu.u-bordeaux-montaigne.fr   NaN
# jbouffard001          jade.bouffard@etu.u-bordeaux-montaigne.fr   NaN
# cbourdet002          chifiu.bourdet@etu.u-bordeaux-montaigne.fr   NaN
# tbrendelc001  timothee.brendel-cantaut@etu.u-bordeaux-montai...   NaN
# fcaget001            florence.caget@etu.u-bordeaux-montaigne.fr   NaN
# lcaillabe001        lucie.caillabet@etu.u-bordeaux-montaigne.fr   NaN
# lcantin001        lilas-rose.cantin@etu.u-bordeaux-montaigne.fr   NaN
# lcaparros002           lea.caparros@etu.u-bordeaux-montaigne.fr   NaN
# ...                                                         ...   ...
# asopena001           amaelle.sopena@etu.u-bordeaux-montaigne.fr   NaN
# asoteras001            axel.soteras@etu.u-bordeaux-montaigne.fr   NaN
# csoual001               clara.soual@etu.u-bordeaux-montaigne.fr   NaN
# mstanek002         mary-anne.stanek@etu.u-bordeaux-montaigne.fr   NaN
# ystraehli001         yoann.straehli@etu.u-bordeaux-montaigne.fr   NaN
# mtamby002            marjorie.tamby@etu.u-bordeaux-montaigne.fr   NaN
# steixeira003        sandro.teixeira@etu.u-bordeaux-montaigne.fr   NaN
# mthomas027           mathieu.thomas@etu.u-bordeaux-montaigne.fr   NaN
# ltognazza001         lucas.tognazza@etu.u-bordeaux-montaigne.fr   NaN
# ftoquin001           florian.toquin@etu.u-bordeaux-montaigne.fr   NaN
# htronche001         heloise.tronche@etu.u-bordeaux-montaigne.fr   NaN
# rvalton001            roxane.valton@etu.u-bordeaux-montaigne.fr   NaN
# cvanautry001   capucine.van-autryve@etu.u-bordeaux-montaigne.fr   NaN
# avanbelli001    axelle.vanbellingen@etu.u-bordeaux-montaigne.fr   NaN
# nveriteta001    nina.verite--taulet@etu.u-bordeaux-montaigne.fr   NaN
# yveron001               ylian.veron@etu.u-bordeaux-montaigne.fr   NaN
# averral001           anthony.verral@etu.u-bordeaux-montaigne.fr   NaN
# avignaud004        amandine.vignaud@etu.u-bordeaux-montaigne.fr   NaN
# qvillars001         quentin.villars@etu.u-bordeaux-montaigne.fr   NaN
# jvillesso001       julien.villessot@etu.u-bordeaux-montaigne.fr   NaN
# bvincent005         bastien.vincent@etu.u-bordeaux-montaigne.fr   NaN
# bvincent004        berenice.vincent@etu.u-bordeaux-montaigne.fr   NaN
# gvion001               gregory.vion@etu.u-bordeaux-montaigne.fr   NaN
# lviot001                lauric.viot@etu.u-bordeaux-montaigne.fr   NaN
# lvo001                      long.vo@etu.u-bordeaux-montaigne.fr   NaN
# lweiss002              laurie.weiss@etu.u-bordeaux-montaigne.fr   NaN
# pzubowicz001       pauline.zubowicz@etu.u-bordeaux-montaigne.fr   NaN
# cguest001           catherine.guest@etu.u-bordeaux-montaigne.fr   NaN
# abajan001              arthur.bajan@etu.u-bordeaux-montaigne.fr   NaN
# fkiefer001          fabienne.kiefer@etu.u-bordeaux-montaigne.fr   NaN
#
# [471 rows x 6 columns]

# %% [raw]
# with codecs.open(fQuizzoodle,"r",encoding="utf8") as input:
#     lQuizz=input.readlines()
#
# nbBons={}
# ansTimes={}
#
# for ligne in lQuizz[1:]:
#     if ligne.strip()!="":
#         nom,bons,temps=ligne.strip().replace("&amp;","&").split(";")
#         nom=nom.strip()
#         if nom in alias:
#             akas=alias[nom]
#         else:
#             akas=chercheAlias(nom)
#             alias[nom]=akas
#         for aka in akas:
#             if aka in nbBons:
#                 nbBons[aka]+=int(bons)
#             else:
#                 nbBons[aka]=int(bons)
#             if aka in ansTimes:
#                 ansTimes[aka]+=float(temps)
#             else:
#                 ansTimes[aka]=float(temps)
#
# #notes={aka:(round(float(nbBons[aka])/6*10+10) for aka in nbBons)

# %%
nbQuestions=nbQuestionQuizz[nQuizz]
def noteEtu(etus):
    notes=[]
    for etu in etus:
        note=int(round(float(nbBons[etu])/nbQuestions*10+10))
        if note==10 and ansTimes[etu]<10:
            note=8.0
        print etu,note
        notes.append(note)
    return notes

# %%
print len(nbBons)
ansTimes
# Out:
# 60
# {u'348881': 107.28,
#  u'350705': 89.7,
#  u'365910': 72.79,
#  u'369000': 105.19,
#  u'370670': 100.4,
#  u'371353': 134.54,
#  u'372039': 113.98,
#  u'380103': 135.7,
#  u'380146': 88.13,
#  u'380150': 103.24,
#  u'380189': 151.74,
#  u'380191': 128.44,
#  u'380282': 90.31,
#  u'380354': 96.02,
#  u'380685': 87.11,
#  u'380705': 102.86,
#  u'380846': 52.87,
#  u'380991': 160.32,
#  u'381009': 96.84,
#  u'381195': 51.42,
#  u'381209': 135.58,
#  u'381377': 169.51,
#  u'381382': 80.62,
#  u'381407': 141.83,
#  u'381535': 150.75,
#  u'381551': 117.02,
#  u'381756': 126.75,
#  u'381862': 96.78,
#  u'381876': 63.09,
#  u'381978': 115.8,
#  u'381980': 86.26,
#  u'382128': 133.31,
#  u'382259': 146.78,
#  u'382527': 55.65,
#  u'382756': 98.85,
#  u'382781': 74.17,
#  u'382788': 108.23,
#  u'382821': 87.73,
#  u'383063': 78.76,
#  u'383074': 127.94,
#  u'383344': 112.2,
#  u'383420': 120.53,
#  u'383431': 121.25,
#  u'383481': 144.3,
#  u'383565': 155.53,
#  u'383649': 107.94,
#  u'383742': 157.99,
#  u'383882': 143.78,
#  u'383998': 81.86,
#  u'384204': 126.59,
#  u'384307': 113.98,
#  u'384492': 127.05,
#  u'384802': 55.48,
#  u'384919': 105.2,
#  u'385042': 79.68,
#  u'385180': 108.23,
#  u'385183': 125.15,
#  u'385410': 119.42,
#  u'385551': 147.68,
#  u'385708': 141.21}

# %%
print "Quizz",nQuizz
with codecs.open(fNotes,"w",encoding="utf8") as output:
    output.write(u"%s\t%s\t%s\t%s"%("NOM\tPRENOM","NOTE","TEMPS","ID")+"\n")
    for etu in sorted(nbBons):
        print etu
        idEtu=dfCM[dfCM[u"Code étudiant"]==etu].index.values[0]
        note=int(round(float(nbBons[etu])/nbQuestions*10+10))
        if note==10 and ansTimes[etu]<10:
            note=8.0
        if idEtu in dfCM.index:
            num=etu
            nomEtu=dfCM.loc[idEtu,u"Nom patronymique"]
            prenomEtu=dfCM.loc[idEtu,u"Prénom"]
            nom=u"%s\t%s"%(nomEtu,prenomEtu)
            timeEtu=ansTimes[etu]
        else:
            num="???"
        if etu=="?": 
            nom="?\t?"
#         else:
#             nom=etu
        if not etu in oldNotes or oldNotes[etu]!=int(note):
            print u"%s\t%d\t%.2f\t%s"%(nom,note,timeEtu,etu)
        output.write(u'%s\t%d\t%.2f\t%s'%(nom,note,timeEtu,num)+"\n")
# Out:
# Quizz 1
# 348881
# POULAIN	CELINE	10	107.28	348881
# 350705
# BERARD	LOUIS	13	89.70	350705
# 365910
# MILEME NTSALA	DEMERCIA	13	72.79	365910
# 369000
# SOLSONA	ADELE	15	105.19	369000
# 370670
# DEMAGGIO	JEAN	13	100.40	370670
# 371353
# LAVIGNE	CAMILLE	13	134.54	371353
# 372039
# MURAT	MAUDE	12	113.98	372039
# 380103
# DUPEBE	MAYLIS	15	135.70	380103
# 380146
# RIVES	LYSA	15	88.13	380146
# 380150
# OUAFI	AMELE	10	103.24	380150
# 380189
# CHASSIN	LAURA	15	151.74	380189
# 380191
# BENARD	ZOE	13	128.44	380191
# 380282
# DUVAL	CLEMENT	13	90.31	380282
# 380354
# ANDRIES	SOPHIE	13	96.02	380354
# 380685
# CARNEVALE	HUGO	12	87.11	380685
# 380705
# DELAFLOR	LEA	13	102.86	380705
# 380846
# MADID	MAHA	13	52.87	380846
# 380991
# BARRAT	FANY	10	160.32	380991
# 381009
# VAUTARD	MARION	12	96.84	381009
# 381195
# LAFONT	MARIE-OCEANE	13	51.42	381195
# 381209
# GIBARU	MORGANE	10	135.58	381209
# 381377
# RAFFY	LOU	13	169.51	381377
# 381382
# CAZETTE	JULIE	13	80.62	381382
# 381407
# BORDERIE	MAEVA	12	141.83	381407
# 381535
# LANDREAU	LEA	12	150.75	381535
# 381551
# BEAUVAIS	CAMILLE	13	117.02	381551
# 381756
# FRANCESENA	ELORRI	12	126.75	381756
# 381862
# CHEVALIER	STYWEL	13	96.78	381862
# 381876
# HINSINGER	JULIE	12	63.09	381876
# 381978
# DUPONT--TABEL	ELEA	13	115.80	381978
# 381980
# PIRRITANO	ALYSSA	13	86.26	381980
# 382128
# FIGUERES	KLEA	15	133.31	382128
# 382259
# METAIS	JULIENNE	12	146.78	382259
# 382527
# RIVERON	ALBANE	10	55.65	382527
# 382756
# HERRERA	ELUNA	12	98.85	382756
# 382781
# CLAVE	MANON	12	74.17	382781
# 382788
# PHINMA	MAELLE	13	108.23	382788
# 382821
# NOYE	CLARA	18	87.73	382821
# 383063
# MONTAGNE	MARIE	12	78.76	383063
# 383074
# INARRA	MAITENA	13	127.94	383074
# 383344
# LE MOAL	MARINE	13	112.20	383344
# 383420
# MARTOS--REYROLLES	ANNA	15	120.53	383420
# 383431
# VILLENEUVE	MATHILDE	13	121.25	383431
# 383481
# DEYRES	INES	13	144.30	383481
# 383565
# POMMIER	SARAH	15	155.53	383565
# 383649
# RIVAT	NOLWENN	12	107.94	383649
# 383742
# MAURAN	ANDREA	10	157.99	383742
# 383882
# UHALDE	CHARLOTTE	12	143.78	383882
# 383998
# REY-JULLIAND	MAILYS	13	81.86	383998
# 384204
# GIBAULT	CAPUCINE	15	126.59	384204
# 384307
# ABDOU	MELOE	12	113.98	384307
# 384492
# HUET	LEA	13	127.05	384492
# 384802
# BECCACCIA	ANDREA	15	55.48	384802
# 384919
# GAULTIER DE CARVILLE	BLANDINE	12	105.20	384919
# 385042
# DINETY	LEONORE	10	79.68	385042
# 385180
# ABDALLAH	MAELIS	13	108.23	385180
# 385183
# DUPUY	SANDRA	10	125.15	385183
# 385410
# HUGUENY	CLARA	12	119.42	385410
# 385551
# DENIAUD	AGNES	15	147.68	385551
# 385708
# MATTE	FLORINE	13	141.21	385708

# %%
dfCM[dfCM.index.str.contains("fle")]
# Out:
#             Nom patronymique Nom usuel   Prénom Code étudiant  \
# Identifiant
# flecoeur001          LECOEUR       NaN  FLORIAN        382471
#
#                                                     Mail  Note
# Identifiant
# flecoeur001  florian.lecoeur@etu.u-bordeaux-montaigne.fr   NaN

# %%
dfCM[dfCM[u"Code étudiant"]=="385180"].index.values[0]
# Out:
# u'mabdallah008'

# %% [raw]
# aliasBis={}
# for nom in alias:
#     aliasBis[nom]=[]
#     for e in alias[nom]:
#         if isinstance(e,int):
#             aliasBis[nom].append(dfCM[dfCM[u"Code étudiant"]==unicode(e)].index.values[0])
#         else:
#             aliasBis[nom].append(e)
# aliasBis

# %%
'''https://stackoverflow.com/a/35491326/3986209'''
def invert_dict(d): 
    inverse = dict() 
    for key in d: 
        # Go through the list that is saved in the dict:
        for item in d[key]:
            # Check if in the inverted dict the key exists
            if item not in inverse: 
                # If not create a new list
                inverse[item] = [key] 
            else: 
                inverse[item].append(key) 
    return inverse

# %%
invAlias=invert_dict(alias)
#invAlias[385732]=[u'adiarra001, cbeauvais004']
correspondances={"alias2etu":alias,"etu2alias":invAlias}
correspondances
# Out:
# {'alias2etu': {'001lherfouf': ['lherfouf001'],
#   '04247454': [],
#   '138': [],
#   '28150417': [],
#   '38 27 56': ['eherrera001'],
#   '380908': ['bsalman001'],
#   '390305': ['lmagit001'],
#   '49814523': [],
#   '56416920': [],
#   '70207082': [],
#   '777': [],
#   '7925871': ['?'],
#   '92317548': [],
#   'a.cornillier': ['acornilli001'],
#   'aanny': ['?'],
#   'abailly003': ['abailly003'],
#   'abeccacci001': ['abeccacci001'],
#   'abertrand014': ['?'],
#   'abottin001': ['abottin001'],
#   'acornillier': ['acornilli001'],
#   'acourrege002': ['acourrege002'],
#   'ada': ['?'],
#   'adartigue': ['adartigue004'],
#   'adeline pacot': ['apacot001'],
#   'adeniaud002': ['adeniaud002'],
#   'adiarra001 + cbeauvais004': ['adiarra001', 'cbeauvais004'],
#   'adinne001': ['adinne001'],
#   'adinne001 bowicz001': ['adinne001', 'pzubowicz001'],
#   'adinne001 lepinoux001': ['adinne001', 'lepinoux001'],
#   'adutour001': ['adutour001'],
#   'aguichon002': ['aguichon002'],
#   'alabinal001': ['alabinal001'],
#   'alauret005': ['alauret005'],
#   'amachefer001': ['amachefer001'],
#   'amariehe001': ['amarieheb001'],
#   'amartosre001': ['amartosre001'],
#   'amauran002': ['amauran002'],
#   'amele002': ['?'],
#   'aminat': ['?'],
#   'aminat oluwamago': ['aoluwamag001'],
#   'amy rodriguez': ['arodrigue025'],
#   'anais moncoucy': ['amoncoucy001'],
#   'andrea': [],
#   'andreterr001': ['tandreter001'],
#   'anihouarn001/jlaugt002': ['jlaugt002', 'anihouarn001'],
#   'anna': ['?'],
#   'aoluwamag001': ['aoluwamag001'],
#   'aouafi002/tgodard002': ['aouafi002', 'tgodard002'],
#   'apacot001': ['apacot001'],
#   'apirritano001': ['apirritan001'],
#   'apirritano001 ldrochon001': ['apirritan001', 'ldrochon001'],
#   'arielle zana': ['azana001'],
#   'asolsona001': ['asolsona001'],
#   'astasica001': ['astasica001'],
#   'audreyweitmann': [],
#   'averral001,eroofthoo001': ['averral001', 'eroofthoo001'],
#   'azana001': ['azana001'],
#   'bee': ['?'],
#   'bgaultier001': ['bgaultier001'],
#   'bgaultier001, mreyjulli001': ['bgaultier001', 'mreyjulli001'],
#   'bidou': [],
#   'bill stew': [],
#   'billard002': ['tbillard002'],
#   'bjorn': [],
#   'bjorn hougen': ['bhougen001'],
#   'blandine005': [],
#   u'bogoss absolu': [],
#   'bonade001': ['ebonade001'],
#   'boue1': ['?'],
#   'bruh': ['?'],
#   'camero': [],
#   'cami.lefmar': ['clefevrem001'],
#   'camille theillout': ['ctheillou001'],
#   'camille.lavigne': ['clavigne004'],
#   'capucine': [],
#   'cbeauvais004': ['cbeauvais004'],
#   'cbeauvais004   mmurat004': ['cbeauvais004', 'mmurat004'],
#   'cbourdet002': ['cbourdet002'],
#   'cdemontou001': ['cdemontou001'],
#   'cdemontou001111': ['cdemontou001'],
#   'cdemontou01': ['cdemontou001'],
#   'cdepetro001 lcaillabe001': ['cdepetro001', 'lcaillabe001'],
#   'cdrilhole01': ['cdrilhole001'],
#   'cduval007': ['cduval007'],
#   'cesperoup001': ['cesperoup001'],
#   'cgibault002': ['cgibault002'],
#   'cgroussea001/aouafi002': ['cgroussea001', 'aouafi002'],
#   'cha': [],
#   'charlotte': ['?'],
#   'charlotte henquinet': ['chenquine001'],
#   u'chlo\xe94/7': [],
#   'choenig001, ebigot001': ['choenig001', 'ebigot001'],
#   'choenig001, ldanis001': ['choenig001', 'ldanis001'],
#   'chugueny001': ['chugueny001'],
#   'clara': [],
#   'clara001': [],
#   'claraa001': [],
#   'claranoye474': ['cnoye001'],
#   'claranoye47400': ['cnoye001'],
#   'clavergne001': ['clavergne005'],
#   'clavergne005': ['clavergne005'],
#   'clefevrem001, ehetzel001': ['clefevrem001', 'ehetzel001'],
#   'cmodiano': ['cmodiano002'],
#   'comas001': ['mcomas001'],
#   'condamin laurie': ['lcondamin001'],
#   'cpetit015 et eroofthoo001': ['cpetit015', 'eroofthoo001'],
#   'cpoulain': ['cpoulain004'],
#   'cpoulain004': ['cpoulain004'],
#   'cuhalde001': ['cuhalde001'],
#   'darti': ['?'],
#   'ddomingue002': ['ddomingue002'],
#   'decaen': ['edecaen001'],
#   'dgazarian001': ['dgazarian001'],
#   'di carlo 001': ['ldicarlo001'],
#   'dieu': ['?'],
#   'dmilement001': ['dmilement001'],
#   'dutour': ['adutour001'],
#   'e.bonade001': ['ebonade001'],
#   'ebonade': ['ebonade001'],
#   'edecaen': ['edecaen001'],
#   'edupontta001': ['edupontta001'],
#   'efath': ['efath001'],
#   'efath001': ['efath001'],
#   'efrancese': ['efrancese001'],
#   'efrancese001': ['efrancese001'],
#   'eguillot004, ahalgand002': ['eguillot004', 'ahalgand002'],
#   'eguillot004, jmocaer001': ['eguillot004', 'jmocaer001'],
#   'eguillot004,ahalgand002': ['eguillot004', 'ahalgand002'],
#   'eguillot004,jmocaer001': ['eguillot004', 'jmocaer001'],
#   'ek': ['?'],
#   'el ultimo mejor': [],
#   'eleclerem': ['eleclerem001'],
#   'eliot': [],
#   'emeline': ['?'],
#   'emie': [],
#   'emma': ['?'],
#   'emma rodrigues': ['erodrigue014'],
#   'emmaleclerem001': ['eleclerem001'],
#   'enicolasj': ['enicolasj001'],
#   'eren jeager': [],
#   'eren jeager est mort': [],
#   'erodrigue014': ['erodrigue014'],
#   'eschoefft01': ['eschoefft001'],
#   'evan': [],
#   'everdonma001': ['everdonma001'],
#   'fardoin002': ['fardoin002'],
#   'fbarrat001': ['fbarrat001'],
#   'fcordette001 - nnaprix001': ['fcordette001', 'nnaprix001'],
#   'fcordette001-nnaprix001': ['fcordette001', 'nnaprix001'],
#   'ferreira005': ['sferreira005'],
#   'fifjrj': [],
#   'fionab002': [],
#   'flo26': ['flecoeur001'],
#   'florian': ['?'],
#   'floriane cordette': ['fcordette001'],
#   'fmatte001': ['fmatte001'],
#   'francesca': ['fnetry001'],
#   'fuck kalaba': [],
#   'gaypard': ['?'],
#   'gguinee002, lbuelens001': ['gguinee002', 'lbuelens001'],
#   'ghaure001, mlemoal001': ['ghaure001', 'mlemoal001'],
#   'giorno giovanna': [],
#   'glegal001': ['glegal001'],
#   'guillaut, monnet': ['tguillaut001', 'mmonnet002'],
#   'hattie chatt': ['?'],
#   'hchatt001': [],
#   'henycams': ['?'],
#   'hey': [],
#   'heye': [],
#   'hougen': ['bhougen001'],
#   'hugo': [],
#   'hugo carnevale': ['hcarneval001'],
#   'hugo carnevale td02': ['hcarneval001'],
#   'iasseli001': ['iasselin001'],
#   'iasseli001/icoulais001': ['iasselin001', 'icoulais001'],
#   'icoulais001': ['icoulais001'],
#   'ideyres001': ['ideyres001'],
#   'ielgharbi': ['ielgharbi002'],
#   'ifischer001, jalexandr005': ['ifischer001', 'jalexandr005'],
#   'intrue': [],
#   'itori': ['?'],
#   u'j': [],
#   'jbenesy001, eroofthoo001': ['jbenesy001', 'eroofthoo001'],
#   'jbenesy001,eroofthoo001': ['jbenesy001', 'eroofthoo001'],
#   'jbenesy001,roofthoo001': ['jbenesy001', 'eroofthoo001'],
#   'jcazette002': ['jcazette002'],
#   'jean demaggio': ['jdemaggio001'],
#   'jeandemaggio': ['jdemaggio001'],
#   'jeanne.l': [],
#   'jeanne3': [],
#   'jeanne33200': ['?'],
#   'jeannelandure': ['jlandure001'],
#   'jesus': ['?'],
#   'jgarcia019': ['jgarcia019'],
#   'jgueylard002, mschoonbe001': ['jgueylard002', 'mschoonbe001'],
#   'jhinsinge001': ['jhinsinge001'],
#   'jlacombe008 / lmarollea002': ['jlacombe008', 'lmarollea002'],
#   'jlaugt002/anihouarn001': ['jlaugt002', 'anihouarn001'],
#   'jlechat001 smechalakh001': ['jlechat001', 'smechalak001'],
#   'jmesnard001': ['jmesnard001'],
#   'jmetais001': ['jmetais001'],
#   'jmocaer001  ahalgand002': ['jmocaer001', 'ahalgand002'],
#   'jowanlele': ['jowanlele001'],
#   'jregazni1': ['jregazni001'],
#   'jsaputa001': ['jsaputa001'],
#   'jtm gile': [],
#   'ju': ['?'],
#   'julie': [],
#   'justine': ['?'],
#   'juu': ['?'],
#   'jvillesso': ['jvillesso001'],
#   u'jvous soul\xe8ve': [],
#   'kaeldori': ['?'],
#   'kalaba': ['?'],
#   'kate': ['?'],
#   'kav': [],
#   'kborde001': ['kborde001'],
#   'kchalus001': ['kchalus001'],
#   'kezzy england': ['kengland001'],
#   'kfigueres001': ['kfigueres001'],
#   'kgautier': ['kgautier001'],
#   'kgautier001': ['kgautier001'],
#   'kndjadi': ['kndjadi001'],
#   'kshigetom001': ['kshigetom001'],
#   'l': [],
#   'labinal001': ['alabinal001'],
#   'lavergne005': ['clavergne005'],
#   u'lavigne': [u'371353'],
#   'lavigne camille': ['clavigne004'],
#   'lcaillab001': ['lcaillabe001'],
#   'lcaillabet001': ['lcaillabe001'],
#   'lcaillabet001   ljamme001': ['lcaillabe001', 'ljamme001'],
#   'lchassin': ['lchassin001'],
#   'lchassin001': ['lchassin001'],
#   'lchassin01': ['lchassin001'],
#   'lclaisse001': ['lclaisse001'],
#   'ldejeans001': ['ldejeans001'],
#   'ldelaflor': ['ldelaflor001'],
#   'ldelaflor001': ['ldelaflor001'],
#   'ldicarlo': ['ldicarlo001'],
#   'lducouret002': ['lducouret002'],
#   'le fils de gillou': [],
#   'le plus mignon': ['?'],
#   'lea djaroun': ['ldjaroun001'],
#   'lenocq': ['lenocq001'],
#   'leslie': ['mpalanica001'],
#   'lfixy001': ['lfixy001'],
#   'lgrattaro001': ['lgrattaro001'],
#   'lherfouf001': ['lherfouf001'],
#   'lherrera001.': ['lherrera001'],
#   'lhuet003': ['lhuet003'],
#   'licence 1': ['?'],
#   'lilas': [],
#   'lisa': [],
#   'llandreau002': ['llandreau002'],
#   'llastouil001 , mdieu002': ['llastouil001', 'mdieu002'],
#   'llaveist01, ecarcenac001': ['llaveist001', 'ecarcenac001'],
#   'lleite001': ['lleite001'],
#   'llepenven001': ['tlepenven001'],
#   'lmarolleau': ['lmarollea002'],
#   'long': ['?'],
#   'louanna': ['?'],
#   'louis pinson': ['lpinson001'],
#   'lpheulpin': ['lpheulpin001'],
#   'lprovost00': ['lprovost002'],
#   'lprovost002': ['lprovost002'],
#   'lpunginko001, llastouil001': ['lpunginko001', 'llastouil001'],
#   'lpunginko001, smartin028': ['lpunginko001', 'smartin028'],
#   'lraffy001': ['lraffy001'],
#   'lrives001': ['lrives001'],
#   'ltognazza001': ['ltognazza001'],
#   'lucas jamme': ['ljamme001'],
#   'lucile de la fuente': ['ldelafuen001'],
#   'luciledlf': [],
#   u'l\xe9o': [],
#   u'l\xe9onore dinety': ['ldinety001'],
#   u'l\xe9onore din\xe9ty': [u'385042'],
#   'm': [],
#   'm.,': [],
#   'm.borderie002': ['mborderie002'],
#   'm.roudaut003 , v.place002': ['mroudaut003', 'vplace002'],
#   'mabdallah': ['mabdallah008'],
#   'mabdallah008': ['mabdallah008'],
#   'mabdallah008, mphinma001': ['mabdallah008', 'mphinma001'],
#   'mabdou005': ['mabdou005'],
#   u'mabdou005 mmurat004': [u'384307', u'372039'],
#   'macces1': ['smacces001'],
#   'machefer001': ['amachefer001'],
#   'maelwenn fourcampre': ['mfourcamp001'],
#   'magic mushrooms': [],
#   'manon la guenon': [],
#   'manon la jeune fille': [],
#   'manon, maudemar001': ['maudemarj001'],
#   'manonrouard': ['mrouard001'],
#   'marginal': ['?'],
#   u'marginal b\xe9b\xe9': [],
#   'margot cazabat': ['mcazabatm001'],
#   'maria': ['mpalanica001'],
#   'marion': [],
#   'marion lafon': ['mlafon006'],
#   'martiiiiiiiiin le chien': [],
#   'marwan': ['?'],
#   'maude': [],
#   'maudemarj001 llastouil001': ['maudemarj001', 'llastouil001'],
#   'maudemarj001, llastouil001': ['maudemarj001', 'llastouil001'],
#   'maudier002 et ahalgand002': ['maudier002', 'ahalgand002'],
#   'maudran001': ['maudran001'],
#   'mbenbrahi002': ['mbenbrahi002'],
#   'mbenbrahim002': ['mbenbrahi002'],
#   'mblandie001': ['mblandie001'],
#   'mbringtown': ['mbringtow001'],
#   'mclarabon': ['mclarabon001'],
#   'mclave001': ['mclave001'],
#   'mcomas001': ['mcomas001'],
#   'mcontini00': ['mcontini001'],
#   'mdieu002 , llastouil001': ['mdieu002', 'llastouil001'],
#   'mdieu002 , smartin028': ['mdieu002', 'smartin028'],
#   'mdieu002 llastouil001': ['mdieu002', 'llastouil001'],
#   'mdieu002, llastouil001': ['mdieu002', 'llastouil001'],
#   'mdieu002,malizon001': ['mdieu002', 'malizon001'],
#   'mdiez06': ['mdiez003'],
#   'mdupebe003': ['mdupebe003'],
#   u'mdup\xe8be003': ['mdupebe003'],
#   'mgans001': ['mgans001'],
#   'mgibaru001': ['mgibaru001'],
#   'mgibaru001 , icoulais001': ['mgibaru001', 'icoulais001'],
#   'mgibaru001 , mmadid001': ['mgibaru001', 'mmadid001'],
#   'mia': [],
#   'mia moghraoui': ['mmoghraou001'],
#   'minarra001': ['minarra001'],
#   'mlafont003': ['mlafont003'],
#   'mlemoal001.ghaure001': ['mlemoal001', 'ghaure001'],
#   'mm': [],
#   'mmadid001': ['mmadid001'],
#   'mmartenot': ['mmartenot001'],
#   'mmontagne003': ['mmontagne003'],
#   'moi': ['?'],
#   'moncoucy': ['amoncoucy001'],
#   'monnet/guillaut': ['mmonnet002', 'tguillaut001'],
#   'mostrowsk001': ['mostrowsk001'],
#   'mpetitberg001': ['mpetitber001'],
#   'mphinma001': ['mphinma001'],
#   'mphinma001, mabdallah008': ['mphinma001', 'mabdallah008'],
#   'mprades1': ['mprades001'],
#   'mreyjulli001': ['mreyjulli001'],
#   'mreyjulli001, mgibaru001': ['mreyjulli001', 'mgibaru001'],
#   'mroudaut003': ['mroudaut003'],
#   'mroudaut003  vplace002': ['mroudaut003', 'vplace002'],
#   'mroudaut003, vplace002': ['mroudaut003', 'vplace002'],
#   'msarci001': ['msarci001'],
#   'mschoonbe001, nbesseruu001': ['mschoonbe001', 'nbesseruu001'],
#   'mstanek002': ['mstanek002'],
#   'mvilleneu006': ['mvilleneu006'],
#   'nedouard': ['nedouard001'],
#   'ngillet': ['ngillet002'],
#   'ngillet002 , malizon001': ['ngillet002', 'malizon001'],
#   'niklekalaba': [],
#   'niklekalabia': [],
#   'nlacheny001': ['nlachenyf001'],
#   'nlachenyfer001': ['nlachenyf001'],
#   'nlachenyg001': ['nlachenyf001'],
#   'nnaprix001 / fcordette001': ['nnaprix001', 'fcordette001'],
#   'nnaprix001-fcordette001': ['nnaprix001', 'fcordette001'],
#   'nora': ['ngillet002'],
#   u'no\xe9mie': ['?'],
#   'nude eco+': [],
#   u'o.n': [],
#   'okamari no suzuki': [],
#   'pabrieu001': ['pabrieu001'],
#   'pacot adeline': ['apacot001'],
#   'pcayo': [],
#   'petitberg001': ['mpetitber001'],
#   'pirritano001': ['apirritan001'],
#   'pzubowicz': ['pzubowicz001'],
#   'quentin villars': ['qvillars001'],
#   'quizz s03': [],
#   'rastacouette': [],
#   'regardez toradora': [],
#   u'rolengadi001\U0001f451': ['rolengadi001'],
#   'rouard manon': ['mrouard001'],
#   'rtanji001': ['?'],
#   's.ferreira005': ['sferreira005'],
#   u'sa': [],
#   'samuel': ['?'],
#   'sandries001': ['sandries001'],
#   'sandries001, clavergne001': ['sandries001', 'clavergne005'],
#   'sandries001, clavergne005': ['sandries001', 'clavergne005'],
#   'sandro teixeira': ['steixeira003'],
#   'scamara002': ['scamara002'],
#   'scaraes001': ['scaraes001'],
#   'sdupuy': ['sdupuy008'],
#   'sdupuy008': ['sdupuy008'],
#   'sferreira005': ['sferreira005'],
#   'sliessi01': ['sliessi001'],
#   'smacces001': ['smacces001'],
#   'smarin004': ['smarin004'],
#   'smartin028, mdieu001': ['smartin028', 'mdieu002'],
#   'smechalak001, lpunginko001': ['smechalak001', 'lpunginko001'],
#   'smehl001': ['smehl001'],
#   'soraya': [],
#   'sosoya': [],
#   'sosoya3360': [],
#   'spommier004': ['spommier004'],
#   'ssenechau001': ['ssenechau001'],
#   'sserhane001 adutour001': ['sserhane001', 'adutour001'],
#   'sshmitt001': ['sschmitt001'],
#   'sslaoua': ['sslaoua001'],
#   'steph': [],
#   'stew': [],
#   u'stywel chevalier': [u'381862'],
#   'tandreterr001': ['tandreter001'],
#   'tbagur001': ['tbagur001'],
#   'tbrendelc001': ['tbrendelc001'],
#   'teo_guillaut': ['tguillaut001'],
#   'teo_guillauy': ['tguillaut001'],
#   'tgodard002': ['tgodard002'],
#   'tgodard002, amele002': ['tgodard002'],
#   'thuyngannguyendao': ['qnguyen004'],
#   u'tina': [],
#   'ubx': ['?'],
#   'v.mouchoux': ['vmouchoux001'],
#   'vgandillo001': ['vgandillo001'],
#   'vic': ['?'],
#   'vmouchoux': ['vmouchoux001'],
#   'vsamierja001': ['vsamierja001'],
#   'wlannel001': ['wlannel001'],
#   'yass': [],
#   'yhaettel001': ['yhaettel001'],
#   'ymetivier001': ['ymetivier001'],
#   'ymonmont001': ['ymonmont001'],
#   'yoann lacroix': ['ylacroix001'],
#   'yumi': [],
#   'zbenard001': ['zbenard001'],
#   'zpronost0001': ['zpronost001'],
#   'zpronost001': ['zpronost001'],
#   'zpronost001111': ['zpronost001'],
#   'zrelave001': ['zrelave001'],
#   'zsausse001': ['zsausse001']},
#  'etu2alias': {u'371353': [u'lavigne'],
#   u'372039': [u'mabdou005 mmurat004'],
#   u'381862': [u'stywel chevalier'],
#   u'384307': [u'mabdou005 mmurat004'],
#   u'385042': [u'l\xe9onore din\xe9ty'],
#   '?': ['juu',
#    'kate',
#    'bruh',
#    'le plus mignon',
#    'samuel',
#    'hattie chatt',
#    'aminat',
#    'boue1',
#    'bee',
#    'ju',
#    'louanna',
#    u'no\xe9mie',
#    'vic',
#    'licence 1',
#    'marginal',
#    'rtanji001',
#    'emeline',
#    '7925871',
#    'moi',
#    'abertrand014',
#    'amele002',
#    'itori',
#    'florian',
#    'aanny',
#    'ada',
#    'emma',
#    'marwan',
#    'ek',
#    'anna',
#    'ubx',
#    'gaypard',
#    'justine',
#    'jesus',
#    'long',
#    'henycams',
#    'kaeldori',
#    'jeanne33200',
#    'charlotte',
#    'kalaba',
#    'darti',
#    'dieu'],
#   'abailly003': ['abailly003'],
#   'abeccacci001': ['abeccacci001'],
#   'abottin001': ['abottin001'],
#   'acornilli001': ['acornillier', 'a.cornillier'],
#   'acourrege002': ['acourrege002'],
#   'adartigue004': ['adartigue'],
#   'adeniaud002': ['adeniaud002'],
#   'adiarra001': ['adiarra001 + cbeauvais004'],
#   'adinne001': ['adinne001 lepinoux001', 'adinne001', 'adinne001 bowicz001'],
#   'adutour001': ['sserhane001 adutour001', 'dutour', 'adutour001'],
#   'aguichon002': ['aguichon002'],
#   'ahalgand002': ['maudier002 et ahalgand002',
#    'jmocaer001  ahalgand002',
#    'eguillot004, ahalgand002',
#    'eguillot004,ahalgand002'],
#   'alabinal001': ['labinal001', 'alabinal001'],
#   'alauret005': ['alauret005'],
#   'amachefer001': ['machefer001', 'amachefer001'],
#   'amarieheb001': ['amariehe001'],
#   'amartosre001': ['amartosre001'],
#   'amauran002': ['amauran002'],
#   'amoncoucy001': ['moncoucy', 'anais moncoucy'],
#   'anihouarn001': ['anihouarn001/jlaugt002', 'jlaugt002/anihouarn001'],
#   'aoluwamag001': ['aoluwamag001', 'aminat oluwamago'],
#   'aouafi002': ['cgroussea001/aouafi002', 'aouafi002/tgodard002'],
#   'apacot001': ['adeline pacot', 'pacot adeline', 'apacot001'],
#   'apirritan001': ['apirritano001 ldrochon001',
#    'apirritano001',
#    'pirritano001'],
#   'arodrigue025': ['amy rodriguez'],
#   'asolsona001': ['asolsona001'],
#   'astasica001': ['astasica001'],
#   'averral001': ['averral001,eroofthoo001'],
#   'azana001': ['azana001', 'arielle zana'],
#   'bgaultier001': ['bgaultier001', 'bgaultier001, mreyjulli001'],
#   'bhougen001': ['bjorn hougen', 'hougen'],
#   'bsalman001': ['380908'],
#   'cbeauvais004': ['cbeauvais004',
#    'cbeauvais004   mmurat004',
#    'adiarra001 + cbeauvais004'],
#   'cbourdet002': ['cbourdet002'],
#   'cdemontou001': ['cdemontou001', 'cdemontou01', 'cdemontou001111'],
#   'cdepetro001': ['cdepetro001 lcaillabe001'],
#   'cdrilhole001': ['cdrilhole01'],
#   'cduval007': ['cduval007'],
#   'cesperoup001': ['cesperoup001'],
#   'cgibault002': ['cgibault002'],
#   'cgroussea001': ['cgroussea001/aouafi002'],
#   'chenquine001': ['charlotte henquinet'],
#   'choenig001': ['choenig001, ldanis001', 'choenig001, ebigot001'],
#   'chugueny001': ['chugueny001'],
#   'clavergne005': ['clavergne005',
#    'clavergne001',
#    'lavergne005',
#    'sandries001, clavergne001',
#    'sandries001, clavergne005'],
#   'clavigne004': ['lavigne camille', 'camille.lavigne'],
#   'clefevrem001': ['clefevrem001, ehetzel001', 'cami.lefmar'],
#   'cmodiano002': ['cmodiano'],
#   'cnoye001': ['claranoye474', 'claranoye47400'],
#   'cpetit015': ['cpetit015 et eroofthoo001'],
#   'cpoulain004': ['cpoulain004', 'cpoulain'],
#   'ctheillou001': ['camille theillout'],
#   'cuhalde001': ['cuhalde001'],
#   'ddomingue002': ['ddomingue002'],
#   'dgazarian001': ['dgazarian001'],
#   'dmilement001': ['dmilement001'],
#   'ebigot001': ['choenig001, ebigot001'],
#   'ebonade001': ['bonade001', 'ebonade', 'e.bonade001'],
#   'ecarcenac001': ['llaveist01, ecarcenac001'],
#   'edecaen001': ['edecaen', 'decaen'],
#   'edupontta001': ['edupontta001'],
#   'efath001': ['efath', 'efath001'],
#   'efrancese001': ['efrancese', 'efrancese001'],
#   'eguillot004': ['eguillot004,jmocaer001',
#    'eguillot004, jmocaer001',
#    'eguillot004, ahalgand002',
#    'eguillot004,ahalgand002'],
#   'eherrera001': ['38 27 56'],
#   'ehetzel001': ['clefevrem001, ehetzel001'],
#   'eleclerem001': ['eleclerem', 'emmaleclerem001'],
#   'enicolasj001': ['enicolasj'],
#   'erodrigue014': ['erodrigue014', 'emma rodrigues'],
#   'eroofthoo001': ['cpetit015 et eroofthoo001',
#    'jbenesy001,roofthoo001',
#    'jbenesy001,eroofthoo001',
#    'jbenesy001, eroofthoo001',
#    'averral001,eroofthoo001'],
#   'eschoefft001': ['eschoefft01'],
#   'everdonma001': ['everdonma001'],
#   'fardoin002': ['fardoin002'],
#   'fbarrat001': ['fbarrat001'],
#   'fcordette001': ['nnaprix001 / fcordette001',
#    'fcordette001-nnaprix001',
#    'floriane cordette',
#    'nnaprix001-fcordette001',
#    'fcordette001 - nnaprix001'],
#   'flecoeur001': ['flo26'],
#   'fmatte001': ['fmatte001'],
#   'fnetry001': ['francesca'],
#   'gguinee002': ['gguinee002, lbuelens001'],
#   'ghaure001': ['ghaure001, mlemoal001', 'mlemoal001.ghaure001'],
#   'glegal001': ['glegal001'],
#   'hcarneval001': ['hugo carnevale', 'hugo carnevale td02'],
#   'iasselin001': ['iasseli001', 'iasseli001/icoulais001'],
#   'icoulais001': ['iasseli001/icoulais001',
#    'mgibaru001 , icoulais001',
#    'icoulais001'],
#   'ideyres001': ['ideyres001'],
#   'ielgharbi002': ['ielgharbi'],
#   'ifischer001': ['ifischer001, jalexandr005'],
#   'jalexandr005': ['ifischer001, jalexandr005'],
#   'jbenesy001': ['jbenesy001,roofthoo001',
#    'jbenesy001,eroofthoo001',
#    'jbenesy001, eroofthoo001'],
#   'jcazette002': ['jcazette002'],
#   'jdemaggio001': ['jeandemaggio', 'jean demaggio'],
#   'jgarcia019': ['jgarcia019'],
#   'jgueylard002': ['jgueylard002, mschoonbe001'],
#   'jhinsinge001': ['jhinsinge001'],
#   'jlacombe008': ['jlacombe008 / lmarollea002'],
#   'jlandure001': ['jeannelandure'],
#   'jlaugt002': ['anihouarn001/jlaugt002', 'jlaugt002/anihouarn001'],
#   'jlechat001': ['jlechat001 smechalakh001'],
#   'jmesnard001': ['jmesnard001'],
#   'jmetais001': ['jmetais001'],
#   'jmocaer001': ['eguillot004,jmocaer001',
#    'eguillot004, jmocaer001',
#    'jmocaer001  ahalgand002'],
#   'jowanlele001': ['jowanlele'],
#   'jregazni001': ['jregazni1'],
#   'jsaputa001': ['jsaputa001'],
#   'jvillesso001': ['jvillesso'],
#   'kborde001': ['kborde001'],
#   'kchalus001': ['kchalus001'],
#   'kengland001': ['kezzy england'],
#   'kfigueres001': ['kfigueres001'],
#   'kgautier001': ['kgautier', 'kgautier001'],
#   'kndjadi001': ['kndjadi'],
#   'kshigetom001': ['kshigetom001'],
#   'lbuelens001': ['gguinee002, lbuelens001'],
#   'lcaillabe001': ['lcaillabet001',
#    'cdepetro001 lcaillabe001',
#    'lcaillab001',
#    'lcaillabet001   ljamme001'],
#   'lchassin001': ['lchassin01', 'lchassin', 'lchassin001'],
#   'lclaisse001': ['lclaisse001'],
#   'lcondamin001': ['condamin laurie'],
#   'ldanis001': ['choenig001, ldanis001'],
#   'ldejeans001': ['ldejeans001'],
#   'ldelaflor001': ['ldelaflor', 'ldelaflor001'],
#   'ldelafuen001': ['lucile de la fuente'],
#   'ldicarlo001': ['ldicarlo', 'di carlo 001'],
#   'ldinety001': [u'l\xe9onore dinety'],
#   'ldjaroun001': ['lea djaroun'],
#   'ldrochon001': ['apirritano001 ldrochon001'],
#   'lducouret002': ['lducouret002'],
#   'lenocq001': ['lenocq'],
#   'lepinoux001': ['adinne001 lepinoux001'],
#   'lfixy001': ['lfixy001'],
#   'lgrattaro001': ['lgrattaro001'],
#   'lherfouf001': ['001lherfouf', 'lherfouf001'],
#   'lherrera001': ['lherrera001.'],
#   'lhuet003': ['lhuet003'],
#   'ljamme001': ['lucas jamme', 'lcaillabet001   ljamme001'],
#   'llandreau002': ['llandreau002'],
#   'llastouil001': ['maudemarj001 llastouil001',
#    'maudemarj001, llastouil001',
#    'mdieu002, llastouil001',
#    'mdieu002 , llastouil001',
#    'mdieu002 llastouil001',
#    'llastouil001 , mdieu002',
#    'lpunginko001, llastouil001'],
#   'llaveist001': ['llaveist01, ecarcenac001'],
#   'lleite001': ['lleite001'],
#   'lmagit001': ['390305'],
#   'lmarollea002': ['jlacombe008 / lmarollea002', 'lmarolleau'],
#   'lpheulpin001': ['lpheulpin'],
#   'lpinson001': ['louis pinson'],
#   'lprovost002': ['lprovost00', 'lprovost002'],
#   'lpunginko001': ['lpunginko001, smartin028',
#    'lpunginko001, llastouil001',
#    'smechalak001, lpunginko001'],
#   'lraffy001': ['lraffy001'],
#   'lrives001': ['lrives001'],
#   'ltognazza001': ['ltognazza001'],
#   'mabdallah008': ['mabdallah008, mphinma001',
#    'mabdallah',
#    'mabdallah008',
#    'mphinma001, mabdallah008'],
#   'mabdou005': ['mabdou005'],
#   'malizon001': ['ngillet002 , malizon001', 'mdieu002,malizon001'],
#   'maudemarj001': ['maudemarj001 llastouil001',
#    'maudemarj001, llastouil001',
#    'manon, maudemar001'],
#   'maudier002': ['maudier002 et ahalgand002'],
#   'maudran001': ['maudran001'],
#   'mbenbrahi002': ['mbenbrahim002', 'mbenbrahi002'],
#   'mblandie001': ['mblandie001'],
#   'mborderie002': ['m.borderie002'],
#   'mbringtow001': ['mbringtown'],
#   'mcazabatm001': ['margot cazabat'],
#   'mclarabon001': ['mclarabon'],
#   'mclave001': ['mclave001'],
#   'mcomas001': ['mcomas001', 'comas001'],
#   'mcontini001': ['mcontini00'],
#   'mdieu002': ['mdieu002 , smartin028',
#    'smartin028, mdieu001',
#    'mdieu002, llastouil001',
#    'mdieu002 , llastouil001',
#    'mdieu002 llastouil001',
#    'mdieu002,malizon001',
#    'llastouil001 , mdieu002'],
#   'mdiez003': ['mdiez06'],
#   'mdupebe003': ['mdupebe003', u'mdup\xe8be003'],
#   'mfourcamp001': ['maelwenn fourcampre'],
#   'mgans001': ['mgans001'],
#   'mgibaru001': ['mgibaru001',
#    'mgibaru001 , mmadid001',
#    'mgibaru001 , icoulais001',
#    'mreyjulli001, mgibaru001'],
#   'minarra001': ['minarra001'],
#   'mlafon006': ['marion lafon'],
#   'mlafont003': ['mlafont003'],
#   'mlemoal001': ['ghaure001, mlemoal001', 'mlemoal001.ghaure001'],
#   'mmadid001': ['mgibaru001 , mmadid001', 'mmadid001'],
#   'mmartenot001': ['mmartenot'],
#   'mmoghraou001': ['mia moghraoui'],
#   'mmonnet002': ['guillaut, monnet', 'monnet/guillaut'],
#   'mmontagne003': ['mmontagne003'],
#   'mmurat004': ['cbeauvais004   mmurat004'],
#   'mostrowsk001': ['mostrowsk001'],
#   'mpalanica001': ['leslie', 'maria'],
#   'mpetitber001': ['mpetitberg001', 'petitberg001'],
#   'mphinma001': ['mabdallah008, mphinma001',
#    'mphinma001',
#    'mphinma001, mabdallah008'],
#   'mprades001': ['mprades1'],
#   'mreyjulli001': ['bgaultier001, mreyjulli001',
#    'mreyjulli001',
#    'mreyjulli001, mgibaru001'],
#   'mrouard001': ['rouard manon', 'manonrouard'],
#   'mroudaut003': ['mroudaut003',
#    'mroudaut003, vplace002',
#    'mroudaut003  vplace002',
#    'm.roudaut003 , v.place002'],
#   'msarci001': ['msarci001'],
#   'mschoonbe001': ['jgueylard002, mschoonbe001', 'mschoonbe001, nbesseruu001'],
#   'mstanek002': ['mstanek002'],
#   'mvilleneu006': ['mvilleneu006'],
#   'nbesseruu001': ['mschoonbe001, nbesseruu001'],
#   'nedouard001': ['nedouard'],
#   'ngillet002': ['nora', 'ngillet002 , malizon001', 'ngillet'],
#   'nlachenyf001': ['nlachenyg001', 'nlacheny001', 'nlachenyfer001'],
#   'nnaprix001': ['nnaprix001 / fcordette001',
#    'fcordette001-nnaprix001',
#    'nnaprix001-fcordette001',
#    'fcordette001 - nnaprix001'],
#   'pabrieu001': ['pabrieu001'],
#   'pzubowicz001': ['pzubowicz', 'adinne001 bowicz001'],
#   'qnguyen004': ['thuyngannguyendao'],
#   'qvillars001': ['quentin villars'],
#   'rolengadi001': [u'rolengadi001\U0001f451'],
#   'sandries001': ['sandries001',
#    'sandries001, clavergne001',
#    'sandries001, clavergne005'],
#   'scamara002': ['scamara002'],
#   'scaraes001': ['scaraes001'],
#   'sdupuy008': ['sdupuy', 'sdupuy008'],
#   'sferreira005': ['sferreira005', 's.ferreira005', 'ferreira005'],
#   'sliessi001': ['sliessi01'],
#   'smacces001': ['smacces001', 'macces1'],
#   'smarin004': ['smarin004'],
#   'smartin028': ['mdieu002 , smartin028',
#    'lpunginko001, smartin028',
#    'smartin028, mdieu001'],
#   'smechalak001': ['jlechat001 smechalakh001', 'smechalak001, lpunginko001'],
#   'smehl001': ['smehl001'],
#   'spommier004': ['spommier004'],
#   'sschmitt001': ['sshmitt001'],
#   'ssenechau001': ['ssenechau001'],
#   'sserhane001': ['sserhane001 adutour001'],
#   'sslaoua001': ['sslaoua'],
#   'steixeira003': ['sandro teixeira'],
#   'tandreter001': ['tandreterr001', 'andreterr001'],
#   'tbagur001': ['tbagur001'],
#   'tbillard002': ['billard002'],
#   'tbrendelc001': ['tbrendelc001'],
#   'tgodard002': ['tgodard002, amele002', 'tgodard002', 'aouafi002/tgodard002'],
#   'tguillaut001': ['teo_guillaut',
#    'teo_guillauy',
#    'guillaut, monnet',
#    'monnet/guillaut'],
#   'tlepenven001': ['llepenven001'],
#   'vgandillo001': ['vgandillo001'],
#   'vmouchoux001': ['vmouchoux', 'v.mouchoux'],
#   'vplace002': ['mroudaut003, vplace002',
#    'mroudaut003  vplace002',
#    'm.roudaut003 , v.place002'],
#   'vsamierja001': ['vsamierja001'],
#   'wlannel001': ['wlannel001'],
#   'yhaettel001': ['yhaettel001'],
#   'ylacroix001': ['yoann lacroix'],
#   'ymetivier001': ['ymetivier001'],
#   'ymonmont001': ['ymonmont001'],
#   'zbenard001': ['zbenard001'],
#   'zpronost001': ['zpronost001111', 'zpronost001', 'zpronost0001'],
#   'zrelave001': ['zrelave001'],
#   'zsausse001': ['zsausse001']}}

# %%
with codecs.open(fAliasQDLE, 'w', encoding="utf8") as outfile:
    yaml.safe_dump(correspondances, outfile, default_flow_style=False)

# %%
ding()

# %% [markdown]
# # FIN

# %%
newAlias={}
for k,v in alias.iteritems():
    if v:
        newV=[]
        for e in v:
            m=re.match(ur"\d+",e)
            if m:
                idEtu=dfCM[dfCM[u"Code étudiant"]==e].index.values[0]
                print k,idEtu
                newV.append(idEtu)
            else:
                newV.append(e)
        newAlias[k]=newV
    else:
        newAlias[k]=[]
newAlias
# Out:
# {'001lherfouf': ['lherfouf001'],
#  '04247454': [],
#  '138': [],
#  '28150417': [],
#  '38 27 56': ['eherrera001'],
#  '380908': ['bsalman001'],
#  '390305': ['lmagit001'],
#  '49814523': [],
#  '56416920': [],
#  '70207082': [],
#  '777': [],
#  '7925871': ['?'],
#  '92317548': [],
#  'a.cornillier': ['acornilli001'],
#  'aanny': ['?'],
#  'abailly003': ['abailly003'],
#  'abeccacci001': ['abeccacci001'],
#  'abertrand014': ['?'],
#  'abottin001': ['abottin001'],
#  'acornillier': ['acornilli001'],
#  'acourrege002': ['acourrege002'],
#  'ada': ['?'],
#  'adartigue': ['adartigue004'],
#  'adeline pacot': ['apacot001'],
#  'adeniaud002': ['adeniaud002'],
#  'adiarra001 + cbeauvais004': ['adiarra001', 'cbeauvais004'],
#  'adinne001': ['adinne001'],
#  'adinne001 bowicz001': ['adinne001', 'pzubowicz001'],
#  'adinne001 lepinoux001': ['adinne001', 'lepinoux001'],
#  'adutour001': ['adutour001'],
#  'aguichon002': ['aguichon002'],
#  'alabinal001': ['alabinal001'],
#  'alauret005': ['alauret005'],
#  'amachefer001': ['amachefer001'],
#  'amariehe001': ['amarieheb001'],
#  'amartosre001': ['amartosre001'],
#  'amauran002': ['amauran002'],
#  'amele002': ['?'],
#  'aminat': ['?'],
#  'aminat oluwamago': ['aoluwamag001'],
#  'amy rodriguez': ['arodrigue025'],
#  'anais moncoucy': ['amoncoucy001'],
#  'andrea': [],
#  'andreterr001': ['tandreter001'],
#  'anihouarn001/jlaugt002': ['jlaugt002', 'anihouarn001'],
#  'anna': ['?'],
#  'aoluwamag001': ['aoluwamag001'],
#  'aouafi002/tgodard002': ['aouafi002', 'tgodard002'],
#  'apacot001': ['apacot001'],
#  'apirritano001': ['apirritan001'],
#  'apirritano001 ldrochon001': ['apirritan001', 'ldrochon001'],
#  'arielle zana': ['azana001'],
#  'asolsona001': ['asolsona001'],
#  'astasica001': ['astasica001'],
#  'audreyweitmann': [],
#  'averral001,eroofthoo001': ['averral001', 'eroofthoo001'],
#  'azana001': ['azana001'],
#  'bee': ['?'],
#  'bgaultier001': ['bgaultier001'],
#  'bgaultier001, mreyjulli001': ['bgaultier001', 'mreyjulli001'],
#  'bidou': [],
#  'bill stew': [],
#  'billard002': ['tbillard002'],
#  'bjorn': [],
#  'bjorn hougen': ['bhougen001'],
#  'blandine005': [],
#  'bonade001': ['ebonade001'],
#  'boue1': ['?'],
#  'bruh': ['?'],
#  'camero': [],
#  'cami.lefmar': ['clefevrem001'],
#  'camille theillout': ['ctheillou001'],
#  'camille.lavigne': ['clavigne004'],
#  'capucine': [],
#  'cbeauvais004': ['cbeauvais004'],
#  'cbeauvais004   mmurat004': ['cbeauvais004', 'mmurat004'],
#  'cbourdet002': ['cbourdet002'],
#  'cdemontou001': ['cdemontou001'],
#  'cdemontou001111': ['cdemontou001'],
#  'cdemontou01': ['cdemontou001'],
#  'cdepetro001 lcaillabe001': ['cdepetro001', 'lcaillabe001'],
#  'cdrilhole01': ['cdrilhole001'],
#  'cduval007': ['cduval007'],
#  'cesperoup001': ['cesperoup001'],
#  'cgibault002': ['cgibault002'],
#  'cgroussea001/aouafi002': ['cgroussea001', 'aouafi002'],
#  'cha': [],
#  'charlotte': ['?'],
#  'charlotte henquinet': ['chenquine001'],
#  u'chlo\xe94/7': [],
#  'choenig001, ebigot001': ['choenig001', 'ebigot001'],
#  'choenig001, ldanis001': ['choenig001', 'ldanis001'],
#  'chugueny001': ['chugueny001'],
#  'clara': [],
#  'clara001': [],
#  'claraa001': [],
#  'claranoye474': ['cnoye001'],
#  'claranoye47400': ['cnoye001'],
#  'clavergne001': ['clavergne005'],
#  'clavergne005': ['clavergne005'],
#  'clefevrem001, ehetzel001': ['clefevrem001', 'ehetzel001'],
#  'cmodiano': ['cmodiano002'],
#  'comas001': ['mcomas001'],
#  'condamin laurie': ['lcondamin001'],
#  'cpetit015 et eroofthoo001': ['cpetit015', 'eroofthoo001'],
#  'cpoulain': ['cpoulain004'],
#  'cpoulain004': ['cpoulain004'],
#  'cuhalde001': ['cuhalde001'],
#  'darti': ['?'],
#  'ddomingue002': ['ddomingue002'],
#  'decaen': ['edecaen001'],
#  'dgazarian001': ['dgazarian001'],
#  'di carlo 001': ['ldicarlo001'],
#  'dieu': ['?'],
#  'dmilement001': ['dmilement001'],
#  'dutour': ['adutour001'],
#  'e.bonade001': ['ebonade001'],
#  'ebonade': ['ebonade001'],
#  'edecaen': ['edecaen001'],
#  'edupontta001': ['edupontta001'],
#  'efath': ['efath001'],
#  'efath001': ['efath001'],
#  'efrancese': ['efrancese001'],
#  'efrancese001': ['efrancese001'],
#  'eguillot004, ahalgand002': ['eguillot004', 'ahalgand002'],
#  'eguillot004, jmocaer001': ['eguillot004', 'jmocaer001'],
#  'eguillot004,ahalgand002': ['eguillot004', 'ahalgand002'],
#  'eguillot004,jmocaer001': ['eguillot004', 'jmocaer001'],
#  'ek': ['?'],
#  'el ultimo mejor': [],
#  'eleclerem': ['eleclerem001'],
#  'eliot': [],
#  'emeline': ['?'],
#  'emie': [],
#  'emma': ['?'],
#  'emma rodrigues': ['erodrigue014'],
#  'emmaleclerem001': ['eleclerem001'],
#  'enicolasj': ['enicolasj001'],
#  'eren jeager': [],
#  'eren jeager est mort': [],
#  'erodrigue014': ['erodrigue014'],
#  'eschoefft01': ['eschoefft001'],
#  'evan': [],
#  'everdonma001': ['everdonma001'],
#  'fardoin002': ['fardoin002'],
#  'fbarrat001': ['fbarrat001'],
#  'fcordette001 - nnaprix001': ['fcordette001', 'nnaprix001'],
#  'fcordette001-nnaprix001': ['fcordette001', 'nnaprix001'],
#  'ferreira005': ['sferreira005'],
#  'fifjrj': [],
#  'fionab002': [],
#  'flo26': ['flecoeur001'],
#  'florian': ['?'],
#  'floriane cordette': ['fcordette001'],
#  'fmatte001': ['fmatte001'],
#  'francesca': ['fnetry001'],
#  'fuck kalaba': [],
#  'gaypard': ['?'],
#  'gguinee002, lbuelens001': ['gguinee002', 'lbuelens001'],
#  'ghaure001, mlemoal001': ['ghaure001', 'mlemoal001'],
#  'giorno giovanna': [],
#  'glegal001': ['glegal001'],
#  'guillaut, monnet': ['tguillaut001', 'mmonnet002'],
#  'hattie chatt': ['?'],
#  'hchatt001': [],
#  'henycams': ['?'],
#  'hey': [],
#  'heye': [],
#  'hougen': ['bhougen001'],
#  'hugo': [],
#  'hugo carnevale': ['hcarneval001'],
#  'hugo carnevale td02': ['hcarneval001'],
#  'iasseli001': ['iasselin001'],
#  'iasseli001/icoulais001': ['iasselin001', 'icoulais001'],
#  'icoulais001': ['icoulais001'],
#  'ideyres001': ['ideyres001'],
#  'ielgharbi': ['ielgharbi002'],
#  'ifischer001, jalexandr005': ['ifischer001', 'jalexandr005'],
#  'intrue': [],
#  'itori': ['?'],
#  'jbenesy001, eroofthoo001': ['jbenesy001', 'eroofthoo001'],
#  'jbenesy001,eroofthoo001': ['jbenesy001', 'eroofthoo001'],
#  'jbenesy001,roofthoo001': ['jbenesy001', 'eroofthoo001'],
#  'jcazette002': ['jcazette002'],
#  'jean demaggio': ['jdemaggio001'],
#  'jeandemaggio': ['jdemaggio001'],
#  'jeanne.l': [],
#  'jeanne3': [],
#  'jeanne33200': ['?'],
#  'jeannelandure': ['jlandure001'],
#  'jesus': ['?'],
#  'jgarcia019': ['jgarcia019'],
#  'jgueylard002, mschoonbe001': ['jgueylard002', 'mschoonbe001'],
#  'jhinsinge001': ['jhinsinge001'],
#  'jlacombe008 / lmarollea002': ['jlacombe008', 'lmarollea002'],
#  'jlaugt002/anihouarn001': ['jlaugt002', 'anihouarn001'],
#  'jlechat001 smechalakh001': ['jlechat001', 'smechalak001'],
#  'jmesnard001': ['jmesnard001'],
#  'jmetais001': ['jmetais001'],
#  'jmocaer001  ahalgand002': ['jmocaer001', 'ahalgand002'],
#  'jowanlele': ['jowanlele001'],
#  'jregazni1': ['jregazni001'],
#  'jsaputa001': ['jsaputa001'],
#  'jtm gile': [],
#  'ju': ['?'],
#  'julie': [],
#  'justine': ['?'],
#  'juu': ['?'],
#  'jvillesso': ['jvillesso001'],
#  u'jvous soul\xe8ve': [],
#  'kaeldori': ['?'],
#  'kalaba': ['?'],
#  'kate': ['?'],
#  'kav': [],
#  'kborde001': ['kborde001'],
#  'kchalus001': ['kchalus001'],
#  'kezzy england': ['kengland001'],
#  'kfigueres001': ['kfigueres001'],
#  'kgautier': ['kgautier001'],
#  'kgautier001': ['kgautier001'],
#  'kndjadi': ['kndjadi001'],
#  'kshigetom001': ['kshigetom001'],
#  'l': [],
#  'labinal001': ['alabinal001'],
#  'lavergne005': ['clavergne005'],
#  'lavigne camille': ['clavigne004'],
#  'lcaillab001': ['lcaillabe001'],
#  'lcaillabet001': ['lcaillabe001'],
#  'lcaillabet001   ljamme001': ['lcaillabe001', 'ljamme001'],
#  'lchassin': ['lchassin001'],
#  'lchassin001': ['lchassin001'],
#  'lchassin01': ['lchassin001'],
#  'lclaisse001': ['lclaisse001'],
#  'ldejeans001': ['ldejeans001'],
#  'ldelaflor': ['ldelaflor001'],
#  'ldelaflor001': ['ldelaflor001'],
#  'ldicarlo': ['ldicarlo001'],
#  'lducouret002': ['lducouret002'],
#  'le fils de gillou': [],
#  'le plus mignon': ['?'],
#  'lea djaroun': ['ldjaroun001'],
#  'lenocq': ['lenocq001'],
#  'leslie': ['mpalanica001'],
#  'lfixy001': ['lfixy001'],
#  'lgrattaro001': ['lgrattaro001'],
#  'lherfouf001': ['lherfouf001'],
#  'lherrera001.': ['lherrera001'],
#  'lhuet003': ['lhuet003'],
#  'licence 1': ['?'],
#  'lilas': [],
#  'lisa': [],
#  'llandreau002': ['llandreau002'],
#  'llastouil001 , mdieu002': ['llastouil001', 'mdieu002'],
#  'llaveist01, ecarcenac001': ['llaveist001', 'ecarcenac001'],
#  'lleite001': ['lleite001'],
#  'llepenven001': ['tlepenven001'],
#  'lmarolleau': ['lmarollea002'],
#  'long': ['?'],
#  'louanna': ['?'],
#  'louis pinson': ['lpinson001'],
#  'lpheulpin': ['lpheulpin001'],
#  'lprovost00': ['lprovost002'],
#  'lprovost002': ['lprovost002'],
#  'lpunginko001, llastouil001': ['lpunginko001', 'llastouil001'],
#  'lpunginko001, smartin028': ['lpunginko001', 'smartin028'],
#  'lraffy001': ['lraffy001'],
#  'lrives001': ['lrives001'],
#  'ltognazza001': ['ltognazza001'],
#  'lucas jamme': ['ljamme001'],
#  'lucile de la fuente': ['ldelafuen001'],
#  'luciledlf': [],
#  u'l\xe9o': [],
#  u'l\xe9onore dinety': ['ldinety001'],
#  'm': [],
#  'm.,': [],
#  'm.borderie002': ['mborderie002'],
#  'm.roudaut003 , v.place002': ['mroudaut003', 'vplace002'],
#  'mabdallah': ['mabdallah008'],
#  'mabdallah008': ['mabdallah008'],
#  'mabdallah008, mphinma001': ['mabdallah008', 'mphinma001'],
#  'mabdou005': ['mabdou005'],
#  'macces1': ['smacces001'],
#  'machefer001': ['amachefer001'],
#  'maelwenn fourcampre': ['mfourcamp001'],
#  'magic mushrooms': [],
#  'manon la guenon': [],
#  'manon la jeune fille': [],
#  'manon, maudemar001': ['maudemarj001'],
#  'manonrouard': ['mrouard001'],
#  'marginal': ['?'],
#  u'marginal b\xe9b\xe9': [],
#  'margot cazabat': ['mcazabatm001'],
#  'maria': ['mpalanica001'],
#  'marion': [],
#  'marion lafon': ['mlafon006'],
#  'martiiiiiiiiin le chien': [],
#  'marwan': ['?'],
#  'maude': [],
#  'maudemarj001 llastouil001': ['maudemarj001', 'llastouil001'],
#  'maudemarj001, llastouil001': ['maudemarj001', 'llastouil001'],
#  'maudier002 et ahalgand002': ['maudier002', 'ahalgand002'],
#  'maudran001': ['maudran001'],
#  'mbenbrahi002': ['mbenbrahi002'],
#  'mbenbrahim002': ['mbenbrahi002'],
#  'mblandie001': ['mblandie001'],
#  'mbringtown': ['mbringtow001'],
#  'mclarabon': ['mclarabon001'],
#  'mclave001': ['mclave001'],
#  'mcomas001': ['mcomas001'],
#  'mcontini00': ['mcontini001'],
#  'mdieu002 , llastouil001': ['mdieu002', 'llastouil001'],
#  'mdieu002 , smartin028': ['mdieu002', 'smartin028'],
#  'mdieu002 llastouil001': ['mdieu002', 'llastouil001'],
#  'mdieu002, llastouil001': ['mdieu002', 'llastouil001'],
#  'mdieu002,malizon001': ['mdieu002', 'malizon001'],
#  'mdiez06': ['mdiez003'],
#  'mdupebe003': ['mdupebe003'],
#  u'mdup\xe8be003': ['mdupebe003'],
#  'mgans001': ['mgans001'],
#  'mgibaru001': ['mgibaru001'],
#  'mgibaru001 , icoulais001': ['mgibaru001', 'icoulais001'],
#  'mgibaru001 , mmadid001': ['mgibaru001', 'mmadid001'],
#  'mia': [],
#  'mia moghraoui': ['mmoghraou001'],
#  'minarra001': ['minarra001'],
#  'mlafont003': ['mlafont003'],
#  'mlemoal001.ghaure001': ['mlemoal001', 'ghaure001'],
#  'mm': [],
#  'mmadid001': ['mmadid001'],
#  'mmartenot': ['mmartenot001'],
#  'mmontagne003': ['mmontagne003'],
#  'moi': ['?'],
#  'moncoucy': ['amoncoucy001'],
#  'monnet/guillaut': ['mmonnet002', 'tguillaut001'],
#  'mostrowsk001': ['mostrowsk001'],
#  'mpetitberg001': ['mpetitber001'],
#  'mphinma001': ['mphinma001'],
#  'mphinma001, mabdallah008': ['mphinma001', 'mabdallah008'],
#  'mprades1': ['mprades001'],
#  'mreyjulli001': ['mreyjulli001'],
#  'mreyjulli001, mgibaru001': ['mreyjulli001', 'mgibaru001'],
#  'mroudaut003': ['mroudaut003'],
#  'mroudaut003  vplace002': ['mroudaut003', 'vplace002'],
#  'mroudaut003, vplace002': ['mroudaut003', 'vplace002'],
#  'msarci001': ['msarci001'],
#  'mschoonbe001, nbesseruu001': ['mschoonbe001', 'nbesseruu001'],
#  'mstanek002': ['mstanek002'],
#  'mvilleneu006': ['mvilleneu006'],
#  'nedouard': ['nedouard001'],
#  'ngillet': ['ngillet002'],
#  'ngillet002 , malizon001': ['ngillet002', 'malizon001'],
#  'niklekalaba': [],
#  'niklekalabia': [],
#  'nlacheny001': ['nlachenyf001'],
#  'nlachenyfer001': ['nlachenyf001'],
#  'nlachenyg001': ['nlachenyf001'],
#  'nnaprix001 / fcordette001': ['nnaprix001', 'fcordette001'],
#  'nnaprix001-fcordette001': ['nnaprix001', 'fcordette001'],
#  'nora': ['ngillet002'],
#  u'no\xe9mie': ['?'],
#  'nude eco+': [],
#  'okamari no suzuki': [],
#  'pabrieu001': ['pabrieu001'],
#  'pacot adeline': ['apacot001'],
#  'pcayo': [],
#  'petitberg001': ['mpetitber001'],
#  'pirritano001': ['apirritan001'],
#  'pzubowicz': ['pzubowicz001'],
#  'quentin villars': ['qvillars001'],
#  'quizz s03': [],
#  'rastacouette': [],
#  'regardez toradora': [],
#  u'rolengadi001\U0001f451': ['rolengadi001'],
#  'rouard manon': ['mrouard001'],
#  'rtanji001': ['?'],
#  's.ferreira005': ['sferreira005'],
#  'samuel': ['?'],
#  'sandries001': ['sandries001'],
#  'sandries001, clavergne001': ['sandries001', 'clavergne005'],
#  'sandries001, clavergne005': ['sandries001', 'clavergne005'],
#  'sandro teixeira': ['steixeira003'],
#  'scamara002': ['scamara002'],
#  'scaraes001': ['scaraes001'],
#  'sdupuy': ['sdupuy008'],
#  'sdupuy008': ['sdupuy008'],
#  'sferreira005': ['sferreira005'],
#  'sliessi01': ['sliessi001'],
#  'smacces001': ['smacces001'],
#  'smarin004': ['smarin004'],
#  'smartin028, mdieu001': ['smartin028', 'mdieu002'],
#  'smechalak001, lpunginko001': ['smechalak001', 'lpunginko001'],
#  'smehl001': ['smehl001'],
#  'soraya': [],
#  'sosoya': [],
#  'sosoya3360': [],
#  'spommier004': ['spommier004'],
#  'ssenechau001': ['ssenechau001'],
#  'sserhane001 adutour001': ['sserhane001', 'adutour001'],
#  'sshmitt001': ['sschmitt001'],
#  'sslaoua': ['sslaoua001'],
#  'steph': [],
#  'stew': [],
#  'tandreterr001': ['tandreter001'],
#  'tbagur001': ['tbagur001'],
#  'tbrendelc001': ['tbrendelc001'],
#  'teo_guillaut': ['tguillaut001'],
#  'teo_guillauy': ['tguillaut001'],
#  'tgodard002': ['tgodard002'],
#  'tgodard002, amele002': ['tgodard002'],
#  'thuyngannguyendao': ['qnguyen004'],
#  'ubx': ['?'],
#  'v.mouchoux': ['vmouchoux001'],
#  'vgandillo001': ['vgandillo001'],
#  'vic': ['?'],
#  'vmouchoux': ['vmouchoux001'],
#  'vsamierja001': ['vsamierja001'],
#  'wlannel001': ['wlannel001'],
#  'yass': [],
#  'yhaettel001': ['yhaettel001'],
#  'ymetivier001': ['ymetivier001'],
#  'ymonmont001': ['ymonmont001'],
#  'yoann lacroix': ['ylacroix001'],
#  'yumi': [],
#  'zbenard001': ['zbenard001'],
#  'zpronost0001': ['zpronost001'],
#  'zpronost001': ['zpronost001'],
#  'zpronost001111': ['zpronost001'],
#  'zrelave001': ['zrelave001'],
#  'zsausse001': ['zsausse001']}

# %%
for k,v in newAlias.iteritems():
    print k,v
    print alias[k]
    print
# Out:
# lenocq ['lenocq001']
# ['lenocq001']
#
# lhuet003 ['lhuet003']
# ['lhuet003']
#
# jtm gile []
# []
#
# mroudaut003 ['mroudaut003']
# ['mroudaut003']
#
# marion []
# []
#
# thuyngannguyendao ['qnguyen004']
# ['qnguyen004']
#
# francesca ['fnetry001']
# ['fnetry001']
#
# lprovost00 ['lprovost002']
# ['lprovost002']
#
# kchalus001 ['kchalus001']
# ['kchalus001']
#
# kate ['?']
# ['?']
#
# eguillot004,jmocaer001 ['eguillot004', 'jmocaer001']
# ['eguillot004', 'jmocaer001']
#
# jlacombe008 / lmarollea002 ['jlacombe008', 'lmarollea002']
# ['jlacombe008', 'lmarollea002']
#
# llandreau002 ['llandreau002']
# ['llandreau002']
#
# nora ['ngillet002']
# ['ngillet002']
#
# teo_guillaut ['tguillaut001']
# ['tguillaut001']
#
# vmouchoux ['vmouchoux001']
# ['vmouchoux001']
#
# okamari no suzuki []
# []
#
# le plus mignon ['?']
# ['?']
#
# anihouarn001/jlaugt002 ['jlaugt002', 'anihouarn001']
# ['jlaugt002', 'anihouarn001']
#
# amy rodriguez ['arodrigue025']
# ['arodrigue025']
#
# lmarolleau ['lmarollea002']
# ['lmarollea002']
#
# hattie chatt ['?']
# ['?']
#
# sandro teixeira ['steixeira003']
# ['steixeira003']
#
# adeline pacot ['apacot001']
# ['apacot001']
#
# eguillot004, jmocaer001 ['eguillot004', 'jmocaer001']
# ['eguillot004', 'jmocaer001']
#
# manon la jeune fille []
# []
#
# fbarrat001 ['fbarrat001']
# ['fbarrat001']
#
# spommier004 ['spommier004']
# ['spommier004']
#
# flo26 ['flecoeur001']
# ['flecoeur001']
#
# boue1 ['?']
# ['?']
#
# hugo carnevale ['hcarneval001']
# ['hcarneval001']
#
# machefer001 ['amachefer001']
# ['amachefer001']
#
# blandine005 []
# []
#
# lpunginko001, smartin028 ['lpunginko001', 'smartin028']
# ['lpunginko001', 'smartin028']
#
# zsausse001 ['zsausse001']
# ['zsausse001']
#
# choenig001, ldanis001 ['choenig001', 'ldanis001']
# ['choenig001', 'ldanis001']
#
# cdemontou001 ['cdemontou001']
# ['cdemontou001']
#
# apirritano001 ldrochon001 ['apirritan001', 'ldrochon001']
# ['apirritan001', 'ldrochon001']
#
# camille.lavigne ['clavigne004']
# ['clavigne004']
#
# lherrera001. ['lherrera001']
# ['lherrera001']
#
# 28150417 []
# []
#
# nlacheny001 ['nlachenyf001']
# ['nlachenyf001']
#
# lcaillabet001 ['lcaillabe001']
# ['lcaillabe001']
#
# condamin laurie ['lcondamin001']
# ['lcondamin001']
#
# louanna ['?']
# ['?']
#
# lea djaroun ['ldjaroun001']
# ['ldjaroun001']
#
# mmartenot ['mmartenot001']
# ['mmartenot001']
#
# lchassin01 ['lchassin001']
# ['lchassin001']
#
# noémie ['?']
# ['?']
#
# mmontagne003 ['mmontagne003']
# ['mmontagne003']
#
# fardoin002 ['fardoin002']
# ['fardoin002']
#
# vic ['?']
# ['?']
#
# floriane cordette ['fcordette001']
# ['fcordette001']
#
# clavergne005 ['clavergne005']
# ['clavergne005']
#
# marginal ['?']
# ['?']
#
# julie []
# []
#
# jeandemaggio ['jdemaggio001']
# ['jdemaggio001']
#
# clavergne001 ['clavergne005']
# ['clavergne005']
#
# rtanji001 ['?']
# ['?']
#
# jbenesy001,roofthoo001 ['jbenesy001', 'eroofthoo001']
# ['jbenesy001', 'eroofthoo001']
#
# bgaultier001, mreyjulli001 ['bgaultier001', 'mreyjulli001']
# ['bgaultier001', 'mreyjulli001']
#
# abottin001 ['abottin001']
# ['abottin001']
#
# eren jeager []
# []
#
# cbeauvais004 ['cbeauvais004']
# ['cbeauvais004']
#
# marion lafon ['mlafon006']
# ['mlafon006']
#
# emeline ['?']
# ['?']
#
# 001lherfouf ['lherfouf001']
# ['lherfouf001']
#
# camero []
# []
#
# mcomas001 ['mcomas001']
# ['mcomas001']
#
# cmodiano ['cmodiano002']
# ['cmodiano002']
#
# jean demaggio ['jdemaggio001']
# ['jdemaggio001']
#
# vsamierja001 ['vsamierja001']
# ['vsamierja001']
#
# teo_guillauy ['tguillaut001']
# ['tguillaut001']
#
# 7925871 ['?']
# ['?']
#
# jgarcia019 ['jgarcia019']
# ['jgarcia019']
#
# mm []
# []
#
# vgandillo001 ['vgandillo001']
# ['vgandillo001']
#
# ideyres001 ['ideyres001']
# ['ideyres001']
#
# chugueny001 ['chugueny001']
# ['chugueny001']
#
# mroudaut003  vplace002 ['mroudaut003', 'vplace002']
# ['mroudaut003', 'vplace002']
#
# andreterr001 ['tandreter001']
# ['tandreter001']
#
# jeannelandure ['jlandure001']
# ['jlandure001']
#
# hugo []
# []
#
# sosoya3360 []
# []
#
# s.ferreira005 ['sferreira005']
# ['sferreira005']
#
# ngillet002 , malizon001 ['ngillet002', 'malizon001']
# ['ngillet002', 'malizon001']
#
# mpetitberg001 ['mpetitber001']
# ['mpetitber001']
#
# adinne001 lepinoux001 ['adinne001', 'lepinoux001']
# ['adinne001', 'lepinoux001']
#
# intrue []
# []
#
# erodrigue014 ['erodrigue014']
# ['erodrigue014']
#
# lucas jamme ['ljamme001']
# ['ljamme001']
#
# mclarabon ['mclarabon001']
# ['mclarabon001']
#
# llepenven001 ['tlepenven001']
# ['tlepenven001']
#
# sserhane001 adutour001 ['sserhane001', 'adutour001']
# ['sserhane001', 'adutour001']
#
# mblandie001 ['mblandie001']
# ['mblandie001']
#
# giorno giovanna []
# []
#
# smehl001 ['smehl001']
# ['smehl001']
#
# moncoucy ['amoncoucy001']
# ['amoncoucy001']
#
# asolsona001 ['asolsona001']
# ['asolsona001']
#
# mabdallah ['mabdallah008']
# ['mabdallah008']
#
# claraa001 []
# []
#
# jmesnard001 ['jmesnard001']
# ['jmesnard001']
#
# lraffy001 ['lraffy001']
# ['lraffy001']
#
# mreyjulli001 ['mreyjulli001']
# ['mreyjulli001']
#
# 138 []
# []
#
# ebonade ['ebonade001']
# ['ebonade001']
#
# v.mouchoux ['vmouchoux001']
# ['vmouchoux001']
#
# enicolasj ['enicolasj001']
# ['enicolasj001']
#
# manonrouard ['mrouard001']
# ['mrouard001']
#
# justine ['?']
# ['?']
#
# a.cornillier ['acornilli001']
# ['acornilli001']
#
# camille theillout ['ctheillou001']
# ['ctheillou001']
#
# decaen ['edecaen001']
# ['edecaen001']
#
# mdieu002 , llastouil001 ['mdieu002', 'llastouil001']
# ['mdieu002', 'llastouil001']
#
# mabdou005 ['mabdou005']
# ['mabdou005']
#
# marwan ['?']
# ['?']
#
# jgueylard002, mschoonbe001 ['jgueylard002', 'mschoonbe001']
# ['jgueylard002', 'mschoonbe001']
#
# l []
# []
#
# apacot001 ['apacot001']
# ['apacot001']
#
# 56416920 []
# []
#
# kfigueres001 ['kfigueres001']
# ['kfigueres001']
#
# charlotte henquinet ['chenquine001']
# ['chenquine001']
#
# dgazarian001 ['dgazarian001']
# ['dgazarian001']
#
# mvilleneu006 ['mvilleneu006']
# ['mvilleneu006']
#
# dmilement001 ['dmilement001']
# ['dmilement001']
#
# ek ['?']
# ['?']
#
# jlechat001 smechalakh001 ['jlechat001', 'smechalak001']
# ['jlechat001', 'smechalak001']
#
# jbenesy001, eroofthoo001 ['jbenesy001', 'eroofthoo001']
# ['jbenesy001', 'eroofthoo001']
#
# marginal bébé []
# []
#
# mcontini00 ['mcontini001']
# ['mcontini001']
#
# sferreira005 ['sferreira005']
# ['sferreira005']
#
# ldejeans001 ['ldejeans001']
# ['ldejeans001']
#
# lilas []
# []
#
# 49814523 []
# []
#
# mschoonbe001, nbesseruu001 ['mschoonbe001', 'nbesseruu001']
# ['mschoonbe001', 'nbesseruu001']
#
# e.bonade001 ['ebonade001']
# ['ebonade001']
#
# pacot adeline ['apacot001']
# ['apacot001']
#
# abeccacci001 ['abeccacci001']
# ['abeccacci001']
#
# bjorn hougen ['bhougen001']
# ['bhougen001']
#
# m.roudaut003 , v.place002 ['mroudaut003', 'vplace002']
# ['mroudaut003', 'vplace002']
#
# rastacouette []
# []
#
# acourrege002 ['acourrege002']
# ['acourrege002']
#
# zpronost0001 ['zpronost001']
# ['zpronost001']
#
# nlachenyg001 ['nlachenyf001']
# ['nlachenyf001']
#
# emmaleclerem001 ['eleclerem001']
# ['eleclerem001']
#
# iasseli001/icoulais001 ['iasselin001', 'icoulais001']
# ['iasselin001', 'icoulais001']
#
# lisa []
# []
#
# efrancese001 ['efrancese001']
# ['efrancese001']
#
# mgibaru001 , mmadid001 ['mgibaru001', 'mmadid001']
# ['mgibaru001', 'mmadid001']
#
# niklekalaba []
# []
#
# cdemontou01 ['cdemontou001']
# ['cdemontou001']
#
# jvous soulève []
# []
#
# mprades1 ['mprades001']
# ['mprades001']
#
# louis pinson ['lpinson001']
# ['lpinson001']
#
# ielgharbi ['ielgharbi002']
# ['ielgharbi002']
#
# alauret005 ['alauret005']
# ['alauret005']
#
# nude eco+ []
# []
#
# cgroussea001/aouafi002 ['cgroussea001', 'aouafi002']
# ['cgroussea001', 'aouafi002']
#
# amauran002 ['amauran002']
# ['amauran002']
#
# jesus ['?']
# ['?']
#
# bjorn []
# []
#
# billard002 ['tbillard002']
# ['tbillard002']
#
# mostrowsk001 ['mostrowsk001']
# ['mostrowsk001']
#
# cpoulain ['cpoulain004']
# ['cpoulain004']
#
# ymetivier001 ['ymetivier001']
# ['ymetivier001']
#
# ifischer001, jalexandr005 ['ifischer001', 'jalexandr005']
# ['ifischer001', 'jalexandr005']
#
# mclave001 ['mclave001']
# ['mclave001']
#
# bill stew []
# []
#
# bidou []
# []
#
# maudran001 ['maudran001']
# ['maudran001']
#
# comas001 ['mcomas001']
# ['mcomas001']
#
# llastouil001 , mdieu002 ['llastouil001', 'mdieu002']
# ['llastouil001', 'mdieu002']
#
# sliessi01 ['sliessi001']
# ['sliessi001']
#
# choenig001, ebigot001 ['choenig001', 'ebigot001']
# ['choenig001', 'ebigot001']
#
# ngillet ['ngillet002']
# ['ngillet002']
#
# rolengadi001👑 ['rolengadi001']
# ['rolengadi001']
#
# azana001 ['azana001']
# ['azana001']
#
# 92317548 []
# []
#
# magic mushrooms []
# []
#
# ferreira005 ['sferreira005']
# ['sferreira005']
#
# adartigue ['adartigue004']
# ['adartigue004']
#
# m.borderie002 ['mborderie002']
# ['mborderie002']
#
# capucine []
# []
#
# bee ['?']
# ['?']
#
# jeanne33200 ['?']
# ['?']
#
# hugo carnevale td02 ['hcarneval001']
# ['hcarneval001']
#
# charlotte ['?']
# ['?']
#
# niklekalabia []
# []
#
# pirritano001 ['apirritan001']
# ['apirritan001']
#
# 04247454 []
# []
#
# adutour001 ['adutour001']
# ['adutour001']
#
# ldelaflor001 ['ldelaflor001']
# ['ldelaflor001']
#
# di carlo 001 ['ldicarlo001']
# ['ldicarlo001']
#
# chloé4/7 []
# []
#
# mabdallah008 ['mabdallah008']
# ['mabdallah008']
#
# adinne001 bowicz001 ['adinne001', 'pzubowicz001']
# ['adinne001', 'pzubowicz001']
#
# florian ['?']
# ['?']
#
# sslaoua ['sslaoua001']
# ['sslaoua001']
#
# sandries001, clavergne005 ['sandries001', 'clavergne005']
# ['sandries001', 'clavergne005']
#
# amariehe001 ['amarieheb001']
# ['amarieheb001']
#
# kalaba ['?']
# ['?']
#
# 777 []
# []
#
# mreyjulli001, mgibaru001 ['mreyjulli001', 'mgibaru001']
# ['mreyjulli001', 'mgibaru001']
#
# mlemoal001.ghaure001 ['mlemoal001', 'ghaure001']
# ['mlemoal001', 'ghaure001']
#
# monnet/guillaut ['mmonnet002', 'tguillaut001']
# ['mmonnet002', 'tguillaut001']
#
# anais moncoucy ['amoncoucy001']
# ['amoncoucy001']
#
# kav []
# []
#
# kaeldori ['?']
# ['?']
#
# smechalak001, lpunginko001 ['smechalak001', 'lpunginko001']
# ['smechalak001', 'lpunginko001']
#
# jeanne.l []
# []
#
# clara001 []
# []
#
# m []
# []
#
# lchassin001 ['lchassin001']
# ['lchassin001']
#
# mmadid001 ['mmadid001']
# ['mmadid001']
#
# arielle zana ['azana001']
# ['azana001']
#
# hougen ['bhougen001']
# ['bhougen001']
#
# regardez toradora []
# []
#
# lpheulpin ['lpheulpin001']
# ['lpheulpin001']
#
# ldelaflor ['ldelaflor001']
# ['ldelaflor001']
#
# smacces001 ['smacces001']
# ['smacces001']
#
# mdieu002 , smartin028 ['mdieu002', 'smartin028']
# ['mdieu002', 'smartin028']
#
# mia moghraoui ['mmoghraou001']
# ['mmoghraou001']
#
# clefevrem001, ehetzel001 ['clefevrem001', 'ehetzel001']
# ['clefevrem001', 'ehetzel001']
#
# cbourdet002 ['cbourdet002']
# ['cbourdet002']
#
# abailly003 ['abailly003']
# ['abailly003']
#
# lavigne camille ['clavigne004']
# ['clavigne004']
#
# ddomingue002 ['ddomingue002']
# ['ddomingue002']
#
# maudemarj001 llastouil001 ['maudemarj001', 'llastouil001']
# ['maudemarj001', 'llastouil001']
#
# licence 1 ['?']
# ['?']
#
# mabdallah008, mphinma001 ['mabdallah008', 'mphinma001']
# ['mabdallah008', 'mphinma001']
#
# samuel ['?']
# ['?']
#
# lducouret002 ['lducouret002']
# ['lducouret002']
#
# aminat ['?']
# ['?']
#
# labinal001 ['alabinal001']
# ['alabinal001']
#
# cpetit015 et eroofthoo001 ['cpetit015', 'eroofthoo001']
# ['cpetit015', 'eroofthoo001']
#
# ghaure001, mlemoal001 ['ghaure001', 'mlemoal001']
# ['ghaure001', 'mlemoal001']
#
# aguichon002 ['aguichon002']
# ['aguichon002']
#
# bgaultier001 ['bgaultier001']
# ['bgaultier001']
#
# scamara002 ['scamara002']
# ['scamara002']
#
# efath ['efath001']
# ['efath001']
#
# everdonma001 ['everdonma001']
# ['everdonma001']
#
# kgautier ['kgautier001']
# ['kgautier001']
#
# tandreterr001 ['tandreter001']
# ['tandreter001']
#
# maudier002 et ahalgand002 ['maudier002', 'ahalgand002']
# ['maudier002', 'ahalgand002']
#
# jvillesso ['jvillesso001']
# ['jvillesso001']
#
# lclaisse001 ['lclaisse001']
# ['lclaisse001']
#
# cesperoup001 ['cesperoup001']
# ['cesperoup001']
#
# cduval007 ['cduval007']
# ['cduval007']
#
# claranoye474 ['cnoye001']
# ['cnoye001']
#
# leslie ['mpalanica001']
# ['mpalanica001']
#
# 390305 ['lmagit001']
# ['lmagit001']
#
# jcazette002 ['jcazette002']
# ['jcazette002']
#
# wlannel001 ['wlannel001']
# ['wlannel001']
#
# efath001 ['efath001']
# ['efath001']
#
# mbenbrahim002 ['mbenbrahi002']
# ['mbenbrahi002']
#
# yass []
# []
#
# manon, maudemar001 ['maudemarj001']
# ['maudemarj001']
#
# llaveist01, ecarcenac001 ['llaveist001', 'ecarcenac001']
# ['llaveist001', 'ecarcenac001']
#
# sdupuy ['sdupuy008']
# ['sdupuy008']
#
# eleclerem ['eleclerem001']
# ['eleclerem001']
#
# yumi []
# []
#
# ju ['?']
# ['?']
#
# edecaen ['edecaen001']
# ['edecaen001']
#
# acornillier ['acornilli001']
# ['acornilli001']
#
# kezzy england ['kengland001']
# ['kengland001']
#
# cdepetro001 lcaillabe001 ['cdepetro001', 'lcaillabe001']
# ['cdepetro001', 'lcaillabe001']
#
# nnaprix001 / fcordette001 ['nnaprix001', 'fcordette001']
# ['nnaprix001', 'fcordette001']
#
# pcayo []
# []
#
# quizz s03 []
# []
#
# smartin028, mdieu001 ['smartin028', 'mdieu002']
# ['smartin028', 'mdieu002']
#
# fifjrj []
# []
#
# adeniaud002 ['adeniaud002']
# ['adeniaud002']
#
# mroudaut003, vplace002 ['mroudaut003', 'vplace002']
# ['mroudaut003', 'vplace002']
#
# iasseli001 ['iasselin001']
# ['iasselin001']
#
# fcordette001-nnaprix001 ['fcordette001', 'nnaprix001']
# ['fcordette001', 'nnaprix001']
# kborde001 ['kborde001']
# ['kborde001']
#
# rouard manon ['mrouard001']
# ['mrouard001']
#
# kndjadi ['kndjadi001']
# ['kndjadi001']
#
# edupontta001 ['edupontta001']
# ['edupontta001']
#
# léo []
# []
#
# pabrieu001 ['pabrieu001']
# ['pabrieu001']
#
# jbenesy001,eroofthoo001 ['jbenesy001', 'eroofthoo001']
# ['jbenesy001', 'eroofthoo001']
#
# soraya []
# []
#
# bonade001 ['ebonade001']
# ['ebonade001']
#
# mgibaru001 , icoulais001 ['mgibaru001', 'icoulais001']
# ['mgibaru001', 'icoulais001']
#
# le fils de gillou []
# []
#
# lherfouf001 ['lherfouf001']
# ['lherfouf001']
#
# guillaut, monnet ['tguillaut001', 'mmonnet002']
# ['tguillaut001', 'mmonnet002']
#
# hchatt001 []
# []
#
# lucile de la fuente ['ldelafuen001']
# ['ldelafuen001']
#
# andrea []
# []
#
# tgodard002, amele002 ['tgodard002']
# ['tgodard002']
#
# jmetais001 ['jmetais001']
# ['jmetais001']
#
# heye []
# []
#
# kshigetom001 ['kshigetom001']
# ['kshigetom001']
#
# léonore dinety ['ldinety001']
# ['ldinety001']
#
# jeanne3 []
# []
#
# msarci001 ['msarci001']
# ['msarci001']
#
# abertrand014 ['?']
# ['?']
#
# nnaprix001-fcordette001 ['nnaprix001', 'fcordette001']
# ['nnaprix001', 'fcordette001']
#
# tbrendelc001 ['tbrendelc001']
# ['tbrendelc001']
#
# glegal001 ['glegal001']
# ['glegal001']
#
# claranoye47400 ['cnoye001']
# ['cnoye001']
#
# fmatte001 ['fmatte001']
# ['fmatte001']
#
# gguinee002, lbuelens001 ['gguinee002', 'lbuelens001']
# ['gguinee002', 'lbuelens001']
#
# sosoya []
# []
#
# 70207082 []
# []
#
# astasica001 ['astasica001']
# ['astasica001']
#
# 380908 ['bsalman001']
# ['bsalman001']
#
# itori ['?']
# ['?']
#
# mdieu002, llastouil001 ['mdieu002', 'llastouil001']
# ['mdieu002', 'llastouil001']
#
# fuck kalaba []
# []
#
# tbagur001 ['tbagur001']
# ['tbagur001']
#
# henycams ['?']
# ['?']
#
# ldicarlo ['ldicarlo001']
# ['ldicarlo001']
#
# el ultimo mejor []
# []
#
# lcaillab001 ['lcaillabe001']
# ['lcaillabe001']
#
# aoluwamag001 ['aoluwamag001']
# ['aoluwamag001']
#
# mia []
# []
#
# cuhalde001 ['cuhalde001']
# ['cuhalde001']
#
# margot cazabat ['mcazabatm001']
# ['mcazabatm001']
#
# sandries001, clavergne001 ['sandries001', 'clavergne005']
# ['sandries001', 'clavergne005']
#
# zbenard001 ['zbenard001']
# ['zbenard001']
#
# ltognazza001 ['ltognazza001']
# ['ltognazza001']
#
# mdiez06 ['mdiez003']
# ['mdiez003']
#
# fcordette001 - nnaprix001 ['fcordette001', 'nnaprix001']
# ['fcordette001', 'nnaprix001']
#
# alabinal001 ['alabinal001']
# ['alabinal001']
#
# ada ['?']
# ['?']
#
# minarra001 ['minarra001']
# ['minarra001']
#
# lavergne005 ['clavergne005']
# ['clavergne005']
#
# zpronost001111 ['zpronost001']
# ['zpronost001']
#
# yhaettel001 ['yhaettel001']
# ['yhaettel001']
#
# clara []
# []
#
# lprovost002 ['lprovost002']
# ['lprovost002']
#
# mdupèbe003 ['mdupebe003']
# ['mdupebe003']
#
# cbeauvais004   mmurat004 ['cbeauvais004', 'mmurat004']
# ['cbeauvais004', 'mmurat004']
#
# maelwenn fourcampre ['mfourcamp001']
# ['mfourcamp001']
#
# moi ['?']
# ['?']
#
# cpoulain004 ['cpoulain004']
# ['cpoulain004']
#
# 38 27 56 ['eherrera001']
# ['eherrera001']
#
# emma ['?']
# ['?']
#
# cgibault002 ['cgibault002']
# ['cgibault002']
#
# jhinsinge001 ['jhinsinge001']
# ['jhinsinge001']
#
# steph []
# []
#
# dutour ['adutour001']
# ['adutour001']
#
# jregazni1 ['jregazni001']
# ['jregazni001']
#
# mbringtown ['mbringtow001']
# ['mbringtow001']
#
# aminat oluwamago ['aoluwamag001']
# ['aoluwamag001']
#
# lleite001 ['lleite001']
# ['lleite001']
#
# jmocaer001  ahalgand002 ['jmocaer001', 'ahalgand002']
# ['jmocaer001', 'ahalgand002']
#
# mdieu002 llastouil001 ['mdieu002', 'llastouil001']
# ['mdieu002', 'llastouil001']
#
# kgautier001 ['kgautier001']
# ['kgautier001']
#
# zpronost001 ['zpronost001']
# ['zpronost001']
#
# zrelave001 ['zrelave001']
# ['zrelave001']
#
# mbenbrahi002 ['mbenbrahi002']
# ['mbenbrahi002']
#
# averral001,eroofthoo001 ['averral001', 'eroofthoo001']
# ['averral001', 'eroofthoo001']
#
# cami.lefmar ['clefevrem001']
# ['clefevrem001']
#
# manon la guenon []
# []
#
# jlaugt002/anihouarn001 ['jlaugt002', 'anihouarn001']
# ['jlaugt002', 'anihouarn001']
#
# anna ['?']
# ['?']
#
# mdupebe003 ['mdupebe003']
# ['mdupebe003']
#
# quentin villars ['qvillars001']
# ['qvillars001']
#
# cha []
# []
#
# audreyweitmann []
# []
#
# darti ['?']
# ['?']
#
# gaypard ['?']
# ['?']
#
# stew []
# []
#
# jsaputa001 ['jsaputa001']
# ['jsaputa001']
#
# martiiiiiiiiin le chien []
# []
#
# mgans001 ['mgans001']
# ['mgans001']
#
# tgodard002 ['tgodard002']
# ['tgodard002']
#
# smarin004 ['smarin004']
# ['smarin004']
#
# cdrilhole01 ['cdrilhole001']
# ['cdrilhole001']
#
# eguillot004, ahalgand002 ['eguillot004', 'ahalgand002']
# ['eguillot004', 'ahalgand002']
#
# maude []
# []
#
# aanny ['?']
# ['?']
#
# efrancese ['efrancese001']
# ['efrancese001']
#
# mphinma001 ['mphinma001']
# ['mphinma001']
#
# mstanek002 ['mstanek002']
# ['mstanek002']
#
# macces1 ['smacces001']
# ['smacces001']
#
# adiarra001 + cbeauvais004 ['adiarra001', 'cbeauvais004']
# ['adiarra001', 'cbeauvais004']
#
# adinne001 ['adinne001']
# ['adinne001']
#
# yoann lacroix ['ylacroix001']
# ['ylacroix001']
#
# scaraes001 ['scaraes001']
# ['scaraes001']
#
# hey []
# []
#
# long ['?']
# ['?']
#
# fionab002 []
# []
#
# bruh ['?']
# ['?']
#
# maria ['mpalanica001']
# ['mpalanica001']
#
# sshmitt001 ['sschmitt001']
# ['sschmitt001']
#
# lcaillabet001   ljamme001 ['lcaillabe001', 'ljamme001']
# ['lcaillabe001', 'ljamme001']
#
# juu ['?']
# ['?']
#
# apirritano001 ['apirritan001']
# ['apirritan001']
#
# lchassin ['lchassin001']
# ['lchassin001']
#
# eren jeager est mort []
# []
#
# lpunginko001, llastouil001 ['lpunginko001', 'llastouil001']
# ['lpunginko001', 'llastouil001']
#
# petitberg001 ['mpetitber001']
# ['mpetitber001']
#
# emie []
# []
#
# maudemarj001, llastouil001 ['maudemarj001', 'llastouil001']
# ['maudemarj001', 'llastouil001']
#
# pzubowicz ['pzubowicz001']
# ['pzubowicz001']
#
# sdupuy008 ['sdupuy008']
# ['sdupuy008']
#
# emma rodrigues ['erodrigue014']
# ['erodrigue014']
#
# amartosre001 ['amartosre001']
# ['amartosre001']
#
# m., []
# []
#
# aouafi002/tgodard002 ['aouafi002', 'tgodard002']
# ['aouafi002', 'tgodard002']
#
# sandries001 ['sandries001']
# ['sandries001']
#
# amele002 ['?']
# ['?']
#
# cdemontou001111 ['cdemontou001']
# ['cdemontou001']
#
# eliot []
# []
#
# mdieu002,malizon001 ['mdieu002', 'malizon001']
# ['mdieu002', 'malizon001']
#
# ymonmont001 ['ymonmont001']
# ['ymonmont001']
#
# lgrattaro001 ['lgrattaro001']
# ['lgrattaro001']
#
# ssenechau001 ['ssenechau001']
# ['ssenechau001']
#
# mphinma001, mabdallah008 ['mphinma001', 'mabdallah008']
# ['mphinma001', 'mabdallah008']
#
# lfixy001 ['lfixy001']
# ['lfixy001']
#
# luciledlf []
# []
#
# mgibaru001 ['mgibaru001']
# ['mgibaru001']
#
# jowanlele ['jowanlele001']
# ['jowanlele001']
#
# eschoefft01 ['eschoefft001']
# ['eschoefft001']
#
# ubx ['?']
# ['?']
#
# dieu ['?']
# ['?']
#
# evan []
# []
#
# amachefer001 ['amachefer001']
# ['amachefer001']
#
# nlachenyfer001 ['nlachenyf001']
# ['nlachenyf001']
#
# icoulais001 ['icoulais001']
# ['icoulais001']
#
# mlafont003 ['mlafont003']
# ['mlafont003']
#
# eguillot004,ahalgand002 ['eguillot004', 'ahalgand002']
# ['eguillot004', 'ahalgand002']
#
# nedouard ['nedouard001']
# ['nedouard001']
#
# lrives001 ['lrives001']
# ['lrives001']

# %%
alias=newAlias

# %%
alias
# Out:
# {'001lherfouf': ['lherfouf001'],
#  '04247454': [],
#  '138': [],
#  '28150417': [],
#  '38 27 56': ['eherrera001'],
#  '380908': ['bsalman001'],
#  '390305': ['lmagit001'],
#  '49814523': [],
#  '56416920': [],
#  '70207082': [],
#  '777': [],
#  '7925871': ['?'],
#  '92317548': [],
#  'a.cornillier': ['acornilli001'],
#  'aanny': ['?'],
#  'abailly003': ['abailly003'],
#  'abeccacci001': ['abeccacci001'],
#  'abertrand014': ['?'],
#  'abottin001': ['abottin001'],
#  'acornillier': ['acornilli001'],
#  'acourrege002': ['acourrege002'],
#  'ada': ['?'],
#  'adartigue': ['adartigue004'],
#  'adeline pacot': ['apacot001'],
#  'adeniaud002': ['adeniaud002'],
#  'adiarra001 + cbeauvais004': ['adiarra001', 'cbeauvais004'],
#  'adinne001': ['adinne001'],
#  'adinne001 bowicz001': ['adinne001', 'pzubowicz001'],
#  'adinne001 lepinoux001': ['adinne001', 'lepinoux001'],
#  'adutour001': ['adutour001'],
#  'aguichon002': ['aguichon002'],
#  'alabinal001': ['alabinal001'],
#  'alauret005': ['alauret005'],
#  'amachefer001': ['amachefer001'],
#  'amariehe001': ['amarieheb001'],
#  'amartosre001': ['amartosre001'],
#  'amauran002': ['amauran002'],
#  'amele002': ['?'],
#  'aminat': ['?'],
#  'aminat oluwamago': ['aoluwamag001'],
#  'amy rodriguez': ['arodrigue025'],
#  'anais moncoucy': ['amoncoucy001'],
#  'andrea': [],
#  'andreterr001': ['tandreter001'],
#  'anihouarn001/jlaugt002': ['jlaugt002', 'anihouarn001'],
#  'anna': ['?'],
#  'aoluwamag001': ['aoluwamag001'],
#  'aouafi002/tgodard002': ['aouafi002', 'tgodard002'],
#  'apacot001': ['apacot001'],
#  'apirritano001': ['apirritan001'],
#  'apirritano001 ldrochon001': ['apirritan001', 'ldrochon001'],
#  'arielle zana': ['azana001'],
#  'asolsona001': ['asolsona001'],
#  'astasica001': ['astasica001'],
#  'audreyweitmann': [],
#  'averral001,eroofthoo001': ['averral001', 'eroofthoo001'],
#  'azana001': ['azana001'],
#  'bee': ['?'],
#  'bgaultier001': ['bgaultier001'],
#  'bgaultier001, mreyjulli001': ['bgaultier001', 'mreyjulli001'],
#  'bidou': [],
#  'bill stew': [],
#  'billard002': ['tbillard002'],
#  'bjorn': [],
#  'bjorn hougen': ['bhougen001'],
#  'blandine005': [],
#  'bonade001': ['ebonade001'],
#  'boue1': ['?'],
#  'bruh': ['?'],
#  'camero': [],
#  'cami.lefmar': ['clefevrem001'],
#  'camille theillout': ['ctheillou001'],
#  'camille.lavigne': ['clavigne004'],
#  'capucine': [],
#  'cbeauvais004': ['cbeauvais004'],
#  'cbeauvais004   mmurat004': ['cbeauvais004', 'mmurat004'],
#  'cbourdet002': ['cbourdet002'],
#  'cdemontou001': ['cdemontou001'],
#  'cdemontou001111': ['cdemontou001'],
#  'cdemontou01': ['cdemontou001'],
#  'cdepetro001 lcaillabe001': ['cdepetro001', 'lcaillabe001'],
#  'cdrilhole01': ['cdrilhole001'],
#  'cduval007': ['cduval007'],
#  'cesperoup001': ['cesperoup001'],
#  'cgibault002': ['cgibault002'],
#  'cgroussea001/aouafi002': ['cgroussea001', 'aouafi002'],
#  'cha': [],
#  'charlotte': ['?'],
#  'charlotte henquinet': ['chenquine001'],
#  u'chlo\xe94/7': [],
#  'choenig001, ebigot001': ['choenig001', 'ebigot001'],
#  'choenig001, ldanis001': ['choenig001', 'ldanis001'],
#  'chugueny001': ['chugueny001'],
#  'clara': [],
#  'clara001': [],
#  'claraa001': [],
#  'claranoye474': ['cnoye001'],
#  'claranoye47400': ['cnoye001'],
#  'clavergne001': ['clavergne005'],
#  'clavergne005': ['clavergne005'],
#  'clefevrem001, ehetzel001': ['clefevrem001', 'ehetzel001'],
#  'cmodiano': ['cmodiano002'],
#  'comas001': ['mcomas001'],
#  'condamin laurie': ['lcondamin001'],
#  'cpetit015 et eroofthoo001': ['cpetit015', 'eroofthoo001'],
#  'cpoulain': ['cpoulain004'],
#  'cpoulain004': ['cpoulain004'],
#  'cuhalde001': ['cuhalde001'],
#  'darti': ['?'],
#  'ddomingue002': ['ddomingue002'],
#  'decaen': ['edecaen001'],
#  'dgazarian001': ['dgazarian001'],
#  'di carlo 001': ['ldicarlo001'],
#  'dieu': ['?'],
#  'dmilement001': ['dmilement001'],
#  'dutour': ['adutour001'],
#  'e.bonade001': ['ebonade001'],
#  'ebonade': ['ebonade001'],
#  'edecaen': ['edecaen001'],
#  'edupontta001': ['edupontta001'],
#  'efath': ['efath001'],
#  'efath001': ['efath001'],
#  'efrancese': ['efrancese001'],
#  'efrancese001': ['efrancese001'],
#  'eguillot004, ahalgand002': ['eguillot004', 'ahalgand002'],
#  'eguillot004, jmocaer001': ['eguillot004', 'jmocaer001'],
#  'eguillot004,ahalgand002': ['eguillot004', 'ahalgand002'],
#  'eguillot004,jmocaer001': ['eguillot004', 'jmocaer001'],
#  'ek': ['?'],
#  'el ultimo mejor': [],
#  'eleclerem': ['eleclerem001'],
#  'eliot': [],
#  'emeline': ['?'],
#  'emie': [],
#  'emma': ['?'],
#  'emma rodrigues': ['erodrigue014'],
#  'emmaleclerem001': ['eleclerem001'],
#  'enicolasj': ['enicolasj001'],
#  'eren jeager': [],
#  'eren jeager est mort': [],
#  'erodrigue014': ['erodrigue014'],
#  'eschoefft01': ['eschoefft001'],
#  'evan': [],
#  'everdonma001': ['everdonma001'],
#  'fardoin002': ['fardoin002'],
#  'fbarrat001': ['fbarrat001'],
#  'fcordette001 - nnaprix001': ['fcordette001', 'nnaprix001'],
#  'fcordette001-nnaprix001': ['fcordette001', 'nnaprix001'],
#  'ferreira005': ['sferreira005'],
#  'fifjrj': [],
#  'fionab002': [],
#  'flo26': ['flecoeur001'],
#  'florian': ['?'],
#  'floriane cordette': ['fcordette001'],
#  'fmatte001': ['fmatte001'],
#  'francesca': ['fnetry001'],
#  'fuck kalaba': [],
#  'gaypard': ['?'],
#  'gguinee002, lbuelens001': ['gguinee002', 'lbuelens001'],
#  'ghaure001, mlemoal001': ['ghaure001', 'mlemoal001'],
#  'giorno giovanna': [],
#  'glegal001': ['glegal001'],
#  'guillaut, monnet': ['tguillaut001', 'mmonnet002'],
#  'hattie chatt': ['?'],
#  'hchatt001': [],
#  'henycams': ['?'],
#  'hey': [],
#  'heye': [],
#  'hougen': ['bhougen001'],
#  'hugo': [],
#  'hugo carnevale': ['hcarneval001'],
#  'hugo carnevale td02': ['hcarneval001'],
#  'iasseli001': ['iasselin001'],
#  'iasseli001/icoulais001': ['iasselin001', 'icoulais001'],
#  'icoulais001': ['icoulais001'],
#  'ideyres001': ['ideyres001'],
#  'ielgharbi': ['ielgharbi002'],
#  'ifischer001, jalexandr005': ['ifischer001', 'jalexandr005'],
#  'intrue': [],
#  'itori': ['?'],
#  'jbenesy001, eroofthoo001': ['jbenesy001', 'eroofthoo001'],
#  'jbenesy001,eroofthoo001': ['jbenesy001', 'eroofthoo001'],
#  'jbenesy001,roofthoo001': ['jbenesy001', 'eroofthoo001'],
#  'jcazette002': ['jcazette002'],
#  'jean demaggio': ['jdemaggio001'],
#  'jeandemaggio': ['jdemaggio001'],
#  'jeanne.l': [],
#  'jeanne3': [],
#  'jeanne33200': ['?'],
#  'jeannelandure': ['jlandure001'],
#  'jesus': ['?'],
#  'jgarcia019': ['jgarcia019'],
#  'jgueylard002, mschoonbe001': ['jgueylard002', 'mschoonbe001'],
#  'jhinsinge001': ['jhinsinge001'],
#  'jlacombe008 / lmarollea002': ['jlacombe008', 'lmarollea002'],
#  'jlaugt002/anihouarn001': ['jlaugt002', 'anihouarn001'],
#  'jlechat001 smechalakh001': ['jlechat001', 'smechalak001'],
#  'jmesnard001': ['jmesnard001'],
#  'jmetais001': ['jmetais001'],
#  'jmocaer001  ahalgand002': ['jmocaer001', 'ahalgand002'],
#  'jowanlele': ['jowanlele001'],
#  'jregazni1': ['jregazni001'],
#  'jsaputa001': ['jsaputa001'],
#  'jtm gile': [],
#  'ju': ['?'],
#  'julie': [],
#  'justine': ['?'],
#  'juu': ['?'],
#  'jvillesso': ['jvillesso001'],
#  u'jvous soul\xe8ve': [],
#  'kaeldori': ['?'],
#  'kalaba': ['?'],
#  'kate': ['?'],
#  'kav': [],
#  'kborde001': ['kborde001'],
#  'kchalus001': ['kchalus001'],
#  'kezzy england': ['kengland001'],
#  'kfigueres001': ['kfigueres001'],
#  'kgautier': ['kgautier001'],
#  'kgautier001': ['kgautier001'],
#  'kndjadi': ['kndjadi001'],
#  'kshigetom001': ['kshigetom001'],
#  'l': [],
#  'labinal001': ['alabinal001'],
#  'lavergne005': ['clavergne005'],
#  'lavigne camille': ['clavigne004'],
#  'lcaillab001': ['lcaillabe001'],
#  'lcaillabet001': ['lcaillabe001'],
#  'lcaillabet001   ljamme001': ['lcaillabe001', 'ljamme001'],
#  'lchassin': ['lchassin001'],
#  'lchassin001': ['lchassin001'],
#  'lchassin01': ['lchassin001'],
#  'lclaisse001': ['lclaisse001'],
#  'ldejeans001': ['ldejeans001'],
#  'ldelaflor': ['ldelaflor001'],
#  'ldelaflor001': ['ldelaflor001'],
#  'ldicarlo': ['ldicarlo001'],
#  'lducouret002': ['lducouret002'],
#  'le fils de gillou': [],
#  'le plus mignon': ['?'],
#  'lea djaroun': ['ldjaroun001'],
#  'lenocq': ['lenocq001'],
#  'leslie': ['mpalanica001'],
#  'lfixy001': ['lfixy001'],
#  'lgrattaro001': ['lgrattaro001'],
#  'lherfouf001': ['lherfouf001'],
#  'lherrera001.': ['lherrera001'],
#  'lhuet003': ['lhuet003'],
#  'licence 1': ['?'],
#  'lilas': [],
#  'lisa': [],
#  'llandreau002': ['llandreau002'],
#  'llastouil001 , mdieu002': ['llastouil001', 'mdieu002'],
#  'llaveist01, ecarcenac001': ['llaveist001', 'ecarcenac001'],
#  'lleite001': ['lleite001'],
#  'llepenven001': ['tlepenven001'],
#  'lmarolleau': ['lmarollea002'],
#  'long': ['?'],
#  'louanna': ['?'],
#  'louis pinson': ['lpinson001'],
#  'lpheulpin': ['lpheulpin001'],
#  'lprovost00': ['lprovost002'],
#  'lprovost002': ['lprovost002'],
#  'lpunginko001, llastouil001': ['lpunginko001', 'llastouil001'],
#  'lpunginko001, smartin028': ['lpunginko001', 'smartin028'],
#  'lraffy001': ['lraffy001'],
#  'lrives001': ['lrives001'],
#  'ltognazza001': ['ltognazza001'],
#  'lucas jamme': ['ljamme001'],
#  'lucile de la fuente': ['ldelafuen001'],
#  'luciledlf': [],
#  u'l\xe9o': [],
#  u'l\xe9onore dinety': ['ldinety001'],
#  'm': [],
#  'm.,': [],
#  'm.borderie002': ['mborderie002'],
#  'm.roudaut003 , v.place002': ['mroudaut003', 'vplace002'],
#  'mabdallah': ['mabdallah008'],
#  'mabdallah008': ['mabdallah008'],
#  'mabdallah008, mphinma001': ['mabdallah008', 'mphinma001'],
#  'mabdou005': ['mabdou005'],
#  'macces1': ['smacces001'],
#  'machefer001': ['amachefer001'],
#  'maelwenn fourcampre': ['mfourcamp001'],
#  'magic mushrooms': [],
#  'manon la guenon': [],
#  'manon la jeune fille': [],
#  'manon, maudemar001': ['maudemarj001'],
#  'manonrouard': ['mrouard001'],
#  'marginal': ['?'],
#  u'marginal b\xe9b\xe9': [],
#  'margot cazabat': ['mcazabatm001'],
#  'maria': ['mpalanica001'],
#  'marion': [],
#  'marion lafon': ['mlafon006'],
#  'martiiiiiiiiin le chien': [],
#  'marwan': ['?'],
#  'maude': [],
#  'maudemarj001 llastouil001': ['maudemarj001', 'llastouil001'],
#  'maudemarj001, llastouil001': ['maudemarj001', 'llastouil001'],
#  'maudier002 et ahalgand002': ['maudier002', 'ahalgand002'],
#  'maudran001': ['maudran001'],
#  'mbenbrahi002': ['mbenbrahi002'],
#  'mbenbrahim002': ['mbenbrahi002'],
#  'mblandie001': ['mblandie001'],
#  'mbringtown': ['mbringtow001'],
#  'mclarabon': ['mclarabon001'],
#  'mclave001': ['mclave001'],
#  'mcomas001': ['mcomas001'],
#  'mcontini00': ['mcontini001'],
#  'mdieu002 , llastouil001': ['mdieu002', 'llastouil001'],
#  'mdieu002 , smartin028': ['mdieu002', 'smartin028'],
#  'mdieu002 llastouil001': ['mdieu002', 'llastouil001'],
#  'mdieu002, llastouil001': ['mdieu002', 'llastouil001'],
#  'mdieu002,malizon001': ['mdieu002', 'malizon001'],
#  'mdiez06': ['mdiez003'],
#  'mdupebe003': ['mdupebe003'],
#  u'mdup\xe8be003': ['mdupebe003'],
#  'mgans001': ['mgans001'],
#  'mgibaru001': ['mgibaru001'],
#  'mgibaru001 , icoulais001': ['mgibaru001', 'icoulais001'],
#  'mgibaru001 , mmadid001': ['mgibaru001', 'mmadid001'],
#  'mia': [],
#  'mia moghraoui': ['mmoghraou001'],
#  'minarra001': ['minarra001'],
#  'mlafont003': ['mlafont003'],
#  'mlemoal001.ghaure001': ['mlemoal001', 'ghaure001'],
#  'mm': [],
#  'mmadid001': ['mmadid001'],
#  'mmartenot': ['mmartenot001'],
#  'mmontagne003': ['mmontagne003'],
#  'moi': ['?'],
#  'moncoucy': ['amoncoucy001'],
#  'monnet/guillaut': ['mmonnet002', 'tguillaut001'],
#  'mostrowsk001': ['mostrowsk001'],
#  'mpetitberg001': ['mpetitber001'],
#  'mphinma001': ['mphinma001'],
#  'mphinma001, mabdallah008': ['mphinma001', 'mabdallah008'],
#  'mprades1': ['mprades001'],
#  'mreyjulli001': ['mreyjulli001'],
#  'mreyjulli001, mgibaru001': ['mreyjulli001', 'mgibaru001'],
#  'mroudaut003': ['mroudaut003'],
#  'mroudaut003  vplace002': ['mroudaut003', 'vplace002'],
#  'mroudaut003, vplace002': ['mroudaut003', 'vplace002'],
#  'msarci001': ['msarci001'],
#  'mschoonbe001, nbesseruu001': ['mschoonbe001', 'nbesseruu001'],
#  'mstanek002': ['mstanek002'],
#  'mvilleneu006': ['mvilleneu006'],
#  'nedouard': ['nedouard001'],
#  'ngillet': ['ngillet002'],
#  'ngillet002 , malizon001': ['ngillet002', 'malizon001'],
#  'niklekalaba': [],
#  'niklekalabia': [],
#  'nlacheny001': ['nlachenyf001'],
#  'nlachenyfer001': ['nlachenyf001'],
#  'nlachenyg001': ['nlachenyf001'],
#  'nnaprix001 / fcordette001': ['nnaprix001', 'fcordette001'],
#  'nnaprix001-fcordette001': ['nnaprix001', 'fcordette001'],
#  'nora': ['ngillet002'],
#  u'no\xe9mie': ['?'],
#  'nude eco+': [],
#  'okamari no suzuki': [],
#  'pabrieu001': ['pabrieu001'],
#  'pacot adeline': ['apacot001'],
#  'pcayo': [],
#  'petitberg001': ['mpetitber001'],
#  'pirritano001': ['apirritan001'],
#  'pzubowicz': ['pzubowicz001'],
#  'quentin villars': ['qvillars001'],
#  'quizz s03': [],
#  'rastacouette': [],
#  'regardez toradora': [],
#  u'rolengadi001\U0001f451': ['rolengadi001'],
#  'rouard manon': ['mrouard001'],
#  'rtanji001': ['?'],
#  's.ferreira005': ['sferreira005'],
#  'samuel': ['?'],
#  'sandries001': ['sandries001'],
#  'sandries001, clavergne001': ['sandries001', 'clavergne005'],
#  'sandries001, clavergne005': ['sandries001', 'clavergne005'],
#  'sandro teixeira': ['steixeira003'],
#  'scamara002': ['scamara002'],
#  'scaraes001': ['scaraes001'],
#  'sdupuy': ['sdupuy008'],
#  'sdupuy008': ['sdupuy008'],
#  'sferreira005': ['sferreira005'],
#  'sliessi01': ['sliessi001'],
#  'smacces001': ['smacces001'],
#  'smarin004': ['smarin004'],
#  'smartin028, mdieu001': ['smartin028', 'mdieu002'],
#  'smechalak001, lpunginko001': ['smechalak001', 'lpunginko001'],
#  'smehl001': ['smehl001'],
#  'soraya': [],
#  'sosoya': [],
#  'sosoya3360': [],
#  'spommier004': ['spommier004'],
#  'ssenechau001': ['ssenechau001'],
#  'sserhane001 adutour001': ['sserhane001', 'adutour001'],
#  'sshmitt001': ['sschmitt001'],
#  'sslaoua': ['sslaoua001'],
#  'steph': [],
#  'stew': [],
#  'tandreterr001': ['tandreter001'],
#  'tbagur001': ['tbagur001'],
#  'tbrendelc001': ['tbrendelc001'],
#  'teo_guillaut': ['tguillaut001'],
#  'teo_guillauy': ['tguillaut001'],
#  'tgodard002': ['tgodard002'],
#  'tgodard002, amele002': ['tgodard002'],
#  'thuyngannguyendao': ['qnguyen004'],
#  'ubx': ['?'],
#  'v.mouchoux': ['vmouchoux001'],
#  'vgandillo001': ['vgandillo001'],
#  'vic': ['?'],
#  'vmouchoux': ['vmouchoux001'],
#  'vsamierja001': ['vsamierja001'],
#  'wlannel001': ['wlannel001'],
#  'yass': [],
#  'yhaettel001': ['yhaettel001'],
#  'ymetivier001': ['ymetivier001'],
#  'ymonmont001': ['ymonmont001'],
#  'yoann lacroix': ['ylacroix001'],
#  'yumi': [],
#  'zbenard001': ['zbenard001'],
#  'zpronost0001': ['zpronost001'],
#  'zpronost001': ['zpronost001'],
#  'zpronost001111': ['zpronost001'],
#  'zrelave001': ['zrelave001'],
#  'zsausse001': ['zsausse001']}

# %% [raw]
# for a in alias:
#     aIdEtu=alias[a]
#     if not isinstance(aIdEtu,list):
#         print "alias n'est pas une liste", a, aIdEtu
#     else:
#         newId=[]
#         for e in aIdEtu:
#             if e not in dfCM.index:
#                 if "?" not in e:
#                     newId.append(dfCM[dfCM[u"Code étudiant"]==e].index.values[0])
#         if newId!=[]:
#             alias[a]=newId
# #         m=re.match(ur"\d*",unicode(aIdEtu))
# #         if m:
# #             alias[a]=
# #         if a[dfCM.loc[e,u"Code étudiant"] for e in alias[a] if e in dfCM.index]

# %% [raw]
# dfCM[dfCM[u"Code étudiant"]=="390398"]

# %% [raw]
# alias["anihouarn001/jlaugt002"]=['jlaugt002', 'anihouarn001']

# %% [raw]
# sorted(invAlias["?"])

# %% [raw]
# chercheAlias(u'nora')

# %% [raw]
# for q in lQuizz:
#     if "nora" in q:
#         print q

# %% [raw]
# alias["francesca"]#=["fnetry001"]

# %% [raw]
# lQuizz[1:]

# %% [raw]
# int(round(float(3)/nbQuestions*10+10))

# %% [markdown]
# # Chercher les noms des étudiants

# %% [raw]
# def assemblerNoms(nom,sep=";"):
#     noms=nom.replace(" ",sep).replace("-",sep).replace("'",sep).split(sep)
#     result=[]
#     for ordre in it.permutations(noms):
#         result.append("".join(ordre))
#     return result

# %% [raw]
# with codecs.open(fEtudiants,"r",encoding="utf8") as inFile:
#     lEtudiants=inFile.readlines()
# etudiants={}
# numeros={}
# for ligne in lEtudiants[1:]:
#     numero,nom=ligne.strip().split("\t",1)
#     numeros[nom]=numero
#     for etudiant in assemblerNoms(nom,sep):
#         etudiants[etudiant]=nom
# etudiants

# %% [raw]
# nbQuestions=nbQuestionQuizz[nQuizz]
# def noteEtu(etus):
#     notes=[]
#     for etu in etus:
#         note=int(round(float(nbBons[etu])/nbQuestions*10+10))
#         if note==10 and ansTimes[etu]<10:
#             note=8.0
#         print etu,note
#         notes.append(note)
#     return notes

# %% [raw]
# noteEtu([u'WEITMANN\tAUDREY']),nQuizz

# %% [raw]
# len(nbBons)

# %% [raw]
# print "Quizz",nQuizz
# with codecs.open(fNotes,"w",encoding="utf8") as output:
#     output.write(u"%s\t%s\t%s\t%s"%("NOM\tPRENOM","NOTE","TEMPS","ID")+"\n")
#     for etu in sorted(nbBons):
#         note=int(round(float(nbBons[etu])/nbQuestions*10+10))
#         if note==10 and ansTimes[etu]<10:
#             note=8.0
#         if etu in numeros:
#             num=numeros[etu]
#         else:
#             num="???"
#         if etu=="?":
#             nom="?\t?"
#         else:
#             nom=etu
#         if not etu in oldNotes or oldNotes[etu]!=int(note):
#             print u"%s\t\t%d"%(nom,note)
#         output.write(u"%s\t%d\t%.2f\t%s"%(nom,note,ansTimes[etu],num)+"\n")

# %% [raw]
# with codecs.open(fEtudiantsNew,"r",encoding="utf8") as inFile:
#     lEtudiants=inFile.readlines()
# for ligne in lEtudiants[1:]:
#     numero,nom=ligne.strip().split("\t",1)
#     if not nom in numeros:
#         numeros[nom]=numero
#         print nom
#         for etudiant in assemblerNoms(nom,sep):
#             etudiants[etudiant]=nom
# #etudiants

# %% [raw]
# def chercheAlias(nom):
#     alias=[]
#     chaine=unidecode.unidecode(nom).replace(" ","").replace("-","").upper()
#     if chaine in etudiants:
#         alias=[etudiants[chaine]]
#     else:
#         while not alias:
#             saisie=raw_input("quel nom pour %s"%chaine)
#             saisie = unidecode.unidecode(saisie).upper()
#             if saisie=="?":
#                 alias=["?"]
#             elif " " in saisie:
#                 alias=saisie.split(" ")
#                 if not all((a in etudiants) or (a=="?") for a in alias):
#                     alias=[]
#                 else:
#                     alias=[etudiants[a] if a in etudiants else "?" for a in alias]
#                     print alias
#             elif saisie in etudiants:
#                 alias=[etudiants[saisie]]
#     return alias
