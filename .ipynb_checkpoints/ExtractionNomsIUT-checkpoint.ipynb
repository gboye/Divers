# %% [markdown]
# ##Importations
# - codecs pour les encodages
# - pandas et numpy pour les calculs sur tableaux
# - matplotlib pour les graphiques
# - itertools pour les itérateurs sophistiqués (paires sur liste, ...)

# %%
# -*- coding: utf8 -*-
import codecs
#import features
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools as it
#%pylab inline
#pd.options.display.mpl_style = 'default'
debug=False

# %%
bdlexiqueIn = unicode(u"èò")
bdlexiqueNum = [ord(char) for char in bdlexiqueIn]
neutreOut = unicode(u"EO")
neutralise = dict(zip(bdlexiqueNum, neutreOut))

# %%
def recoder(chaine,table=neutralise):
    if type(chaine)==str:
        temp=unicode(chaine.decode('utf8')).translate(table)
        result=temp.encode('utf8')
    elif type(chaine)==unicode:
        result=chaine.translate(table)
    return result

# %% [markdown]
# #Préparation du tableau de VERBES

# %% [markdown]
# ###Lecture du lexique

# %%
nomLexique="/Users/gilles/Copy/Python/phonemisation/bdlexique-PDM-Resync.txt"
bdlexique=pd.read_csv(nomLexique,sep=";",names=["ortho","phono","ext","cs","ms","vs","lexeme","L23","lemmeFrantext","lemmeFilms","formeFrantext","formeFilms"],encoding="utf8")

# %% [markdown]
# ###Définition des cases
# - principales pour le paradigme courant
# - secondaires pour les cases rares
# - totales pour le tout

# %%
casesExtraites=[
        'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 
        'ps1S', 'ps2S', 'ps3S', 'ps1P', 'ps2P', 'ps3P'
]
casesPrincipales= [
        'inf', 'pi1S', 'pi2S', 'pi3S', 'pi1P', 'pi2P', 'pi3P', 'ii1S',
        'ii2S', 'ii3S', 'ii1P', 'ii2P', 'ii3P', 
        'fi1S', 'fi2S', 'fi3S', 'fi1P', 'fi2P',
        'fi3P', 'pI2S', 'pI1P', 'pI2P', 'ps1S', 'ps2S', 'ps3S', 'ps1P',
        'ps2P', 'ps3P', 
        'pc1S', 'pc2S', 'pc3S', 'pc1P', 'pc2P', 'pc3P', 'pP'
            ]
casesSecondaires= [
       'ai1S', 'ai2S', 'ai3S', 'ai1P', 'ai2P', 'ai3P', 'is1S', 'is2S', 'is3S', 'is1P', 'is2P', 'is3P'
            ]
casesTotales=casesPrincipales+casesSecondaires

# %% [markdown]
# ###Création de la colonne de fréquence *freq*
# - fréquence positive : 10.f
# - fréquence nulle : 5
# - fréquence inexistante : 1

# %%
bdlexique["freq"]=bdlexique[bdlexique["formeFrantext"]!="***"]["formeFrantext"].astype(float)*10
bdlexique.loc[bdlexique["formeFrantext"]=="0","freq"]=5
bdlexique.loc[bdlexique["formeFrantext"]=="***","freq"]=1

# %% [markdown]
# ###Extraction des formes verbales dans une structure *verbes*

# %%
verbes=bdlexique[bdlexique["cs"]=="V"].copy()

# %%
verbes["phono"]=verbes["phono"].apply(lambda x: recoder(x))

# %% [markdown]
# ###Ajout d'une colonne *case*
# - remplir les *ms* vide pour permettre la concaténation sans erreur
# - *case* est la concaténation de *vs* et *ms*

# %%
verbes["ms"]=verbes["ms"].fillna("")
verbes["case"]=verbes["vs"]+verbes["ms"]

# %% [markdown]
# ###Ajout d'une colonne *prob* pour la fréquence relative

# %% [markdown]
# #Echantillonage

# %%
nombreVerbesFrequents=50

# %%
selectionCases=verbes[verbes["case"].isin(casesExtraites)].copy()

# %%
selectionCases["lemmeFrantext"]=selectionCases[selectionCases["lemmeFrantext"]!="***"]["lemmeFrantext"].astype(float)*10
selectionCases.loc[selectionCases["lemmeFrantext"]==0,"lemmeFrantext"]=5

# %%
selectionCases["lemmeFrantext"]=selectionCases["lemmeFrantext"].fillna(1)
selectionCases.sort(["lemmeFrantext"],ascending=False,inplace=True)

# %%
freqLemmeSelection=selectionCases.groupby("lexeme")[["lemmeFrantext"]].apply(lambda x: max(x["lemmeFrantext"]))
freqLemmeSelection.sort(["lemmeFrantext"],ascending=False,inplace=True)
freqLemmeSelection[:nombreVerbesFrequents]
# Out:
# lexeme
# être          32236500
# avoir         13572580
# aller          9992770
# faire          8813480
# dire           5946150
# pouvoir        5524470
# vouloir        5249300
# savoir         4516710
# voir           4119430
# devoir         3232570
# venir          2763820
# suivre         2090540
# parler         1970550
# prendre        1913830
# croire         1711990
# aimer          1655070
# falloir        1653760
# passer         1495490
# penser         1485470
# attendre       1351460
# trouver        1335490
# laisser        1334100
# arriver        1252420
# donner         1209670
# regarder       1197290
# appeler        1165480
# partir         1111970
# mettre         1004830
# rester         1003560
# arrêter         993790
# connaître       961030
# tuer            928060
# mourir          916400
# demander        909770
# comprendre      893510
# sortir          884260
# entendre        728670
# chercher        712460
# aider           688710
# essayer         670400
# revenir         618620
# plaire          607210
# jouer           570120
# finir           557610
# perdre          546080
# sentir          535400
# rentrer         532510
# vivre           510190
# rendre          508810
# tenir           504690
# dtype: float64

# %%
selectionVerbes=selectionCases[selectionCases["lemmeFrantext"]>500]
selectionVerbes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-998f7158fae6> in <module>()
# ----> 1 selectionVerbes=selectionCases[selectionCases["lemmeFrantext"]>500]
#       2 selectionVerbes
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     482     def __getitem__(self, key):
#     483         try:
# --> 484             result = self.index.get_value(self, key)
#     485
#     486             if not np.isscalar(result):
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_value(self, series, key)
#    1194
#    1195         try:
# -> 1196             return self._engine.get_value(s, k)
#    1197         except KeyError as e1:
#    1198             if len(self) > 0 and self.inferred_type in ['integer','boolean']:
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_value (pandas/index.c:2993)()
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_value (pandas/index.c:2808)()
#
# /Users/gilles/anaconda/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3583)()
#
# KeyError: 'lemmeFrantext'

# %%
homophones=pd.pivot_table(selectionVerbes, values='ortho', index=['phono', 'lexeme'], columns=['ms'], aggfunc=lambda x: [y for y in set(x)])
homophones
# Out:
# ms                                               1P             1S  \
# phono       lexeme
# 6fOriz      euphoriser                          NaN    [euphorise]
# 6fOrize     euphoriser                          NaN            NaN
# 6fOrizje    euphoriser                          NaN            NaN
# 6fOrizjô    euphoriser               [euphorisions]            NaN
# 6fOrizô     euphoriser                [euphorisons]            NaN
# 6j6tOn      oeilletonner                        NaN  [oeilletonne]
# 6j6tOne     oeilletonner                        NaN            NaN
# 6j6tOnje    oeilletonner                        NaN            NaN
# 6j6tOnjô    oeilletonner           [oeilletonnions]            NaN
# 6j6tOnô     oeilletonner            [oeilletonnons]            NaN
# 6rOpEaniz   européaniser                        NaN  [européanise]
# 6rOpEanize  européaniser                        NaN            NaN
# 6rOpEanizje européaniser                        NaN            NaN
# 6rOpEanizjô européaniser           [européanisions]            NaN
# 6rOpEanizô  européaniser            [européanisons]            NaN
# 6vre        oeuvrer                             NaN            NaN
# 6vrje       oeuvrer                             NaN            NaN
# 6vrjô       oeuvrer                     [oeuvrions]            NaN
# 6vrô        oeuvrer                      [oeuvrons]            NaN
# 9rt         heurter                             NaN       [heurte]
# 9rte        heurter                             NaN            NaN
# 9rtje       heurter                             NaN            NaN
# 9rtjô       heurter                     [heurtions]            NaN
# 9rtô        heurter                      [heurtons]            NaN
# 9vr         oeuvrer                             NaN       [oeuvre]
# E           avoir                               NaN      [ai, aie]
#             haïr                                NaN         [hais]
#             être                                NaN            NaN
# ES          escher                              NaN        [esche]
# ES6lOn      échelonner                          NaN    [échelonne]
# ...                                             ...            ...
# êvâtOrije   inventorier                         NaN            NaN
# êvâtOrijô   inventorier             [inventoriions]            NaN
# êvâtOrje    inventorier                         NaN            NaN
# êvâtOrjô    inventorier              [inventorions]            NaN
# êvâte       inventer                            NaN            NaN
# êvâtje      inventer                            NaN            NaN
# êvâtjô      inventer                   [inventions]            NaN
# êvâtô       inventer                    [inventons]            NaN
# ô           avoir                               NaN            NaN
# ôbr         ombrer                              NaN        [ombre]
# ôbraZ       ombrager                            NaN      [ombrage]
# ôbraZe      ombrager                            NaN            NaN
# ôbraZje     ombrager                            NaN            NaN
# ôbraZjô     ombrager                   [ombragions]            NaN
# ôbraZô      ombrager                   [ombrageons]            NaN
# ôbre        ombrer                              NaN            NaN
# ôbrje       ombrer                              NaN            NaN
# ôbrjô       ombrer                       [ombrions]            NaN
# ôbrô        ombrer                        [ombrons]            NaN
# ôdwa        ondoyer                             NaN       [ondoie]
# ôdwaje      ondoyer                             NaN            NaN
# ôdwajô      ondoyer           [ondoyons, ondoyions]            NaN
# ôdyl        onduler                             NaN       [ondule]
# ôdyle       onduler                             NaN            NaN
# ôdylje      onduler                             NaN            NaN
# ôdyljô      onduler                     [ondulions]            NaN
# ôdylô       onduler                      [ondulons]            NaN
# ôgrwa       hongroyer                           NaN     [hongroie]
# ôgrwaje     hongroyer                           NaN            NaN
# ôgrwajô     hongroyer     [hongroyions, hongroyons]            NaN
#
# ms                                             2P              2S  \
# phono       lexeme
# 6fOriz      euphoriser                        NaN    [euphorises]
# 6fOrize     euphoriser               [euphorisez]             NaN
# 6fOrizje    euphoriser              [euphorisiez]             NaN
# 6fOrizjô    euphoriser                        NaN             NaN
# 6fOrizô     euphoriser                        NaN             NaN
# 6j6tOn      oeilletonner                      NaN  [oeilletonnes]
# 6j6tOne     oeilletonner           [oeilletonnez]             NaN
# 6j6tOnje    oeilletonner          [oeilletonniez]             NaN
# 6j6tOnjô    oeilletonner                      NaN             NaN
# 6j6tOnô     oeilletonner                      NaN             NaN
# 6rOpEaniz   européaniser                      NaN  [européanises]
# 6rOpEanize  européaniser           [européanisez]             NaN
# 6rOpEanizje européaniser          [européanisiez]             NaN
# 6rOpEanizjô européaniser                      NaN             NaN
# 6rOpEanizô  européaniser                      NaN             NaN
# 6vre        oeuvrer                     [oeuvrez]             NaN
# 6vrje       oeuvrer                    [oeuvriez]             NaN
# 6vrjô       oeuvrer                           NaN             NaN
# 6vrô        oeuvrer                           NaN             NaN
# 9rt         heurter                           NaN       [heurtes]
# 9rte        heurter                     [heurtez]             NaN
# 9rtje       heurter                    [heurtiez]             NaN
# 9rtjô       heurter                           NaN             NaN
# 9rtô        heurter                           NaN             NaN
# 9vr         oeuvrer                           NaN       [oeuvres]
# E           avoir                             NaN          [aies]
#             haïr                              NaN          [hais]
#             être                              NaN            [es]
# ES          escher                            NaN        [esches]
# ES6lOn      échelonner                        NaN    [échelonnes]
# ...                                           ...             ...
# êvâtOrije   inventorier            [inventoriiez]             NaN
# êvâtOrijô   inventorier                       NaN             NaN
# êvâtOrje    inventorier             [inventoriez]             NaN
# êvâtOrjô    inventorier                       NaN             NaN
# êvâte       inventer                   [inventez]             NaN
# êvâtje      inventer                  [inventiez]             NaN
# êvâtjô      inventer                          NaN             NaN
# êvâtô       inventer                          NaN             NaN
# ô           avoir                             NaN             NaN
# ôbr         ombrer                            NaN        [ombres]
# ôbraZ       ombrager                          NaN      [ombrages]
# ôbraZe      ombrager                   [ombragez]             NaN
# ôbraZje     ombrager                  [ombragiez]             NaN
# ôbraZjô     ombrager                          NaN             NaN
# ôbraZô      ombrager                          NaN             NaN
# ôbre        ombrer                       [ombrez]             NaN
# ôbrje       ombrer                      [ombriez]             NaN
# ôbrjô       ombrer                            NaN             NaN
# ôbrô        ombrer                            NaN             NaN
# ôdwa        ondoyer                           NaN       [ondoies]
# ôdwaje      ondoyer           [ondoyiez, ondoyez]             NaN
# ôdwajô      ondoyer                           NaN             NaN
# ôdyl        onduler                           NaN       [ondules]
# ôdyle       onduler                     [ondulez]             NaN
# ôdylje      onduler                    [onduliez]             NaN
# ôdyljô      onduler                           NaN             NaN
# ôdylô       onduler                           NaN             NaN
# ôgrwa       hongroyer                         NaN     [hongroies]
# ôgrwaje     hongroyer     [hongroyez, hongroyiez]             NaN
# ôgrwajô     hongroyer                         NaN             NaN
#
# ms                                     3P             3S
# phono       lexeme
# 6fOriz      euphoriser      [euphorisent]    [euphorise]
# 6fOrize     euphoriser                NaN            NaN
# 6fOrizje    euphoriser                NaN            NaN
# 6fOrizjô    euphoriser                NaN            NaN
# 6fOrizô     euphoriser                NaN            NaN
# 6j6tOn      oeilletonner  [oeilletonnent]  [oeilletonne]
# 6j6tOne     oeilletonner              NaN            NaN
# 6j6tOnje    oeilletonner              NaN            NaN
# 6j6tOnjô    oeilletonner              NaN            NaN
# 6j6tOnô     oeilletonner              NaN            NaN
# 6rOpEaniz   européaniser  [européanisent]  [européanise]
# 6rOpEanize  européaniser              NaN            NaN
# 6rOpEanizje européaniser              NaN            NaN
# 6rOpEanizjô européaniser              NaN            NaN
# 6rOpEanizô  européaniser              NaN            NaN
# 6vre        oeuvrer                   NaN            NaN
# 6vrje       oeuvrer                   NaN            NaN
# 6vrjô       oeuvrer                   NaN            NaN
# 6vrô        oeuvrer                   NaN            NaN
# 9rt         heurter            [heurtent]       [heurte]
# 9rte        heurter                   NaN            NaN
# 9rtje       heurter                   NaN            NaN
# 9rtjô       heurter                   NaN            NaN
# 9rtô        heurter                   NaN            NaN
# 9vr         oeuvrer            [oeuvrent]       [oeuvre]
# E           avoir                 [aient]          [ait]
#             haïr                      NaN         [hait]
#             être                      NaN          [est]
# ES          escher              [eschent]        [esche]
# ES6lOn      échelonner      [échelonnent]    [échelonne]
# ...                                   ...            ...
# êvâtOrije   inventorier               NaN            NaN
# êvâtOrijô   inventorier               NaN            NaN
# êvâtOrje    inventorier               NaN            NaN
# êvâtOrjô    inventorier               NaN            NaN
# êvâte       inventer                  NaN            NaN
# êvâtje      inventer                  NaN            NaN
# êvâtjô      inventer                  NaN            NaN
# êvâtô       inventer                  NaN            NaN
# ô           avoir                   [ont]            NaN
# ôbr         ombrer              [ombrent]        [ombre]
# ôbraZ       ombrager          [ombragent]      [ombrage]
# ôbraZe      ombrager                  NaN            NaN
# ôbraZje     ombrager                  NaN            NaN
# ôbraZjô     ombrager                  NaN            NaN
# ôbraZô      ombrager                  NaN            NaN
# ôbre        ombrer                    NaN            NaN
# ôbrje       ombrer                    NaN            NaN
# ôbrjô       ombrer                    NaN            NaN
# ôbrô        ombrer                    NaN            NaN
# ôdwa        ondoyer            [ondoient]       [ondoie]
# ôdwaje      ondoyer                   NaN            NaN
# ôdwajô      ondoyer                   NaN            NaN
# ôdyl        onduler            [ondulent]       [ondule]
# ôdyle       onduler                   NaN            NaN
# ôdylje      onduler                   NaN            NaN
# ôdyljô      onduler                   NaN            NaN
# ôdylô       onduler                   NaN            NaN
# ôgrwa       hongroyer        [hongroient]     [hongroie]
# ôgrwaje     hongroyer                 NaN            NaN
# ôgrwajô     hongroyer                 NaN            NaN
#
# [32173 rows x 6 columns]

# %% [markdown]
# ##Tirage incrémental des formes disponibles
# - increment : taille de chaque tirage
# - nombre : nombre de tirages
#
# np.random.choice donne une liste d'index de formes tirées dans l'ordre du tirage
#
# on découpe la liste en morceaux de la taille de l'incrément

# %%
nombre=10
increment=25
tirage=np.random.choice(selectionVerbes.index,size=nombre*increment,p=selectionVerbes["prob"],replace=False)
tirages=[tirage[increment*x:increment*(x+1)] for x in range(len(tirage)/increment+(len(tirage)%increment!=0))]

# %%
selectionVerbes.ix[np.sort(np.concatenate(tirages[0:nombre]))]
# Out:
#              ortho   phono  ext cs  ms  vs      lexeme     freq  case  \
# 3035       accepte  aksEpt    @  V  3S  pi    accepter    38410  pi3S
# 4382      accroche   akrOS    @  V  1S  pi   accrocher    16390  pi1S
# 10622         agit     aZi   t"  V  3S  pi        agir   105020  pi3S
# 11756        aides      Ed    @  V  2S  pi       aider    19220  pi2S
# 11782         aide      Ed    @  V  1S  ps       aider   119690  ps1S
# 11784         aide      Ed    @  V  3S  ps       aider   119690  ps3S
# 12235         aime      Em    @  V  1S  pi       aimer   751290  pi1S
# 12237         aime      Em    @  V  3S  pi       aimer   751290  pi3S
# 12262         aime      Em    @  V  1S  ps       aimer   751290  ps1S
# 12264         aime      Em    @  V  3S  ps       aimer   751290  ps3S
# 14107         vais      vE   z"  V  1S  pi       aller  1644990  pi1S
# 14108          vas      va   z"  V  2S  pi       aller  1009220  pi2S
# 14109           va      va  NaN  V  3S  pi       aller  3382550  pi3S
# 14110       allons     alô   z"  V  1P  pi       aller   500210  pi1P
# 14111        allez     ale   z"  V  2P  pi       aller  1414850  pi2P
# 14136        aille      aj    @  V  3S  ps       aller    89810  ps3S
# 14431       allume    alym    @  V  1S  ps     allumer    19220  ps1S
# 21794      appelle    apEl    @  V  1S  pi     appeler   485770  pi1S
# 21796      appelle    apEl    @  V  3S  pi     appeler   485770  pi3S
# 21823      appelle    apEl    @  V  3S  ps     appeler   485770  ps3S
# 22320      apporte   apOrt    @  V  1S  pi    apporter    65970  pi1S
# 22759     approche   aprOS    @  V  1S  pi   approcher    44170  pi1S
# 25316       arrête    arEt    @  V  1S  pi     arrêter   456590  pi1S
# 25320      arrêtez   arEte   z"  V  2P  pi     arrêter   174120  pi2P
# 25603       arrive    ariv    @  V  3S  pi     arriver   525100  pi3S
# 25628       arrive    ariv    @  V  1S  ps     arriver   525100  ps1S
# 29115     attaches    ataS    @  V  2S  pi    attacher      820  pi2S
# 29204      attaque    atak    @  V  1S  ps    attaquer    16630  ps1S
# 29400      attends     atâ   z"  V  1S  pi    attendre   478320  pi1S
# 29404     attendez   atâde   z"  V  2P  pi    attendre   230660  pi2P
# ...            ...     ...  ... ..  ..  ..         ...      ...   ...
# 392321        sors     sOr  NaN  V  2S  pi      sortir   156130  pi2S
# 392323     sortons   sOrtô   z"  V  1P  pi      sortir    13570  pi1P
# 392922     souffre    sufr    @  V  3S  pi    souffrir    31520  pi3S
# 393046    souhaite    suEt    @  V  3S  pi   souhaiter    39980  pi3S
# 393071    souhaite    suEt    @  V  1S  ps   souhaiter    39980  ps1S
# 395167    souviens   suvjê   z"  V  1S  pi    souvenir   198300  pi1S
# 395168    souviens   suvjê   z"  V  2S  pi    souvenir   198300  pi2S
# 395195  souviennes  suvjEn    @  V  2S  ps    souvenir     1580  ps2S
# 400920        suis     sHi   z"  V  1S  pi      suivre  1819440  pi1S
# 400921        suis     sHi   z"  V  2S  pi      suivre  1819440  pi2S
# 401848     supplie   sypli  NaN  V  3S  ps    supplier    37380  ps3S
# 401968     suppose   sypoz    @  V  1S  ps    supposer    89070  ps1S
# 405564      survit   syrvi   t"  V  3S  pi    survivre     3880  pi3S
# 405734     suscite   sysit    @  V  3S  pi    susciter     1080  pi3S
# 417118      touche     tuS    @  V  3S  ps     toucher    91910  ps3S
# 417809     tournez   turne   z"  V  2P  pi     tourner    15820  pi2P
# 419004      traite    trEt    @  V  1S  pi     traiter    24080  pi1S
# 421485   travaille  travaj    @  V  3S  ps  travailler   149220  ps3S
# 425415     trouves    truv    @  V  2S  ps     trouver    70050  ps2S
# 431037       viens     vjê   z"  V  1S  pi       venir   944810  pi1S
# 431038       viens     vjê   z"  V  2S  pi       venir   944810  pi2S
# 431039       vient     vjê   t"  V  3S  pi       venir   352240  pi3S
# 435742        vois     vwa   z"  V  1S  pi        voir   689750  pi1S
# 435743        vois     vwa   z"  V  2S  pi        voir   689750  pi2S
# 435744        voit     vwa   t"  V  3S  pi        voir   181980  pi3S
# 435745      voyons   vwajô   z"  V  1P  pi        voir   127930  pi1P
# 436678        veux      v2   z"  V  1S  pi     vouloir  2486930  pi1S
# 436679        veux      v2   z"  V  2S  pi     vouloir  2486930  pi2S
# 436680        veut      v2   t"  V  3S  pi     vouloir   701190  pi3S
# 436683     veulent     v9l  @t"  V  3P  pi     vouloir   142380  pi3P
#
#             prob
# 3035    0.000188
# 4382    0.000080
# 10622   0.000515
# 11756   0.000094
# 11782   0.000587
# 11784   0.000587
# 12235   0.003682
# 12237   0.003682
# 12262   0.003682
# 12264   0.003682
# 14107   0.008061
# 14108   0.004946
# 14109   0.016576
# 14110   0.002451
# 14111   0.006933
# 14136   0.000440
# 14431   0.000094
# 21794   0.002380
# 21796   0.002380
# 21823   0.002380
# 22320   0.000323
# 22759   0.000216
# 25316   0.002237
# 25320   0.000853
# 25603   0.002573
# 25628   0.002573
# 29115   0.000004
# 29204   0.000081
# 29400   0.002344
# 29404   0.001130
# ...          ...
# 392321  0.000765
# 392323  0.000066
# 392922  0.000154
# 393046  0.000196
# 393071  0.000196
# 395167  0.000972
# 395168  0.000972
# 395195  0.000008
# 400920  0.008916
# 400921  0.008916
# 401848  0.000183
# 401968  0.000436
# 405564  0.000019
# 405734  0.000005
# 417118  0.000450
# 417809  0.000078
# 419004  0.000118
# 421485  0.000731
# 425415  0.000343
# 431037  0.004630
# 431038  0.004630
# 431039  0.001726
# 435742  0.003380
# 435743  0.003380
# 435744  0.000892
# 435745  0.000627
# 436678  0.012187
# 436679  0.012187
# 436680  0.003436
# 436683  0.000698
#
# [250 rows x 10 columns]
