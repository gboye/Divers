# %%
import re, collections, codecs

# %%
def words(text): 
    return re.findall('[a-zéùèàâêîôûç]+', text.lower())

# %%
def train(features):
    model = collections.defaultdict(lambda: 1)
    for f in features:
        model[f] += 1
    return model

# %%
NWORDS = train(words(file('../../Copy/Python/phonemisation/BouvardPecuchet.txt').read()))

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyzéùèàâêîôûç'

# %%
def edits1(word):
   splits     = [(word[:i], word[i:]) for i in range(len(word) + 1)]
   deletes    = [a + b[1:] for a, b in splits if b]
   transposes = [a + b[1] + b[0] + b[2:] for a, b in splits if len(b)>1]
   replaces   = [a + c + b[1:] for a, b in splits for c in alphabet if b]
   inserts    = [a + c + b     for a, b in splits for c in alphabet]
   return set(deletes + transposes + replaces + inserts)

# %%
def known_edits2(word):
    return set(e2 for e1 in edits1(word) for e2 in edits1(e1) if e2 in NWORDS)

# %%
def known(words): return set(w for w in words if w in NWORDS)

# %%
def correct(word):
    candidates = known([word]) or known(edits1(word)) or known_edits2(word) or [word]
    return max(candidates, key=NWORDS.get)

# %%
print correct("reveille")
# Out:
# revaille

# %%
NWORDS
# Out:
# defaultdict(<function <lambda> at 0x1048585f0>, {u'anordir': 2, u'anordis': 6, u'vang': 256, u'anordit': 3, u'unanimiste': 3, u'administrerons': 4, u'gavas': 2, u'administreront': 2, u'tacheur': 11, u'cosserons': 3, u'spiders': 2, u'foufous': 2, u'dansott': 6, u'caner': 5, u'canes': 36, u'crasais': 47, u'canez': 3, u'sumassiez': 3, u'amatirent': 2, u'compissaient': 2, u'affectionnes': 3, u'affectionnez': 3, u'vann': 34, u'orfroi': 2, u'naturopathie': 2, u'morflasses': 2, u'aguerriraient': 2, u'enseveli': 2, u'fiions': 21, u'obligeance': 85, u'grenadiers': 11, u'replacer': 42, u'pigment': 20, u'kinoises': 2, u'touristes': 2063, u'marginasse': 2, u'glorifiassions': 2, u'pochassent': 3, u'ouatasses': 2, u'rattrappaient': 2, u'humections': 3, u'gerbille': 30, u'faufil': 15, u'paillettent': 3, u'glandassent': 2, u'assignats': 16, u'amplifications': 3, u'composions': 3, u'empalerions': 2, u'mieront': 2, u'mierons': 2, u'replacez': 53, u'polygala': 2, u'chaussure': 1250, u'revendiques': 3, u'targu': 8, u'vicomtesse': 4, u'alliions': 3, u'audimat': 138, u'constitutionnalisions': 3, u'prolongeons': 3, u'nardes': 3, u'targe': 41, u'merderait': 3, u'rencaissaient': 2, u'machinistes': 3, u'dialogu': 8, u'estragons': 2, u'gressassiez': 2, u'enquiquines': 47, u'enquiquiner': 13, u'consulat': 378, u'papaut': 3, u'chuchot': 7, u'vrerez': 3, u'circoncisses': 2, u'crasait': 47, u'rocque': 6, u'entraits': 2, u'octuplas': 2, u'rocqua': 2, u'fleuretas': 2, u'octuplai': 2, u'calligraphions': 3, u'stationnass