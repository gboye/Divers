# %%
from lxml import etree
import math,re,codecs
debug=False

# %%
parser = etree.XMLParser(remove_blank_text=True)

# %%
nomLoc="/Users/gilles/Downloads/5832845.gpx"
wptChildren=["name","urlname"]

# %%
def localName(element):
    return etree.QName(element).localname

# %%
def Dec2Min(coord):
    degreSign=""
    decDegres,intDegres=math.modf(coord)
    minutes=abs(decDegres)*60
    return "%d%s %5.3f"%(intDegres,degreSign,minutes)

# %%
def CoordDec2Min(lat,lon):
    sep=" "
    coordLat=Dec2Min(lat)
    coordLon=Dec2Min(lon)
    if coordLat.startswith("-"):
        coordLat="S"+coordLat[1:]
    else:
        coordLat="N"+coordLat
    if coordLon.startswith("-"):
        coordLon="W"+coordLon[1:]
    else:
        coordLon="E"+coordLon
    return "%s%s%s"%(coordLat,sep,coordLon)

# %%
def dictLatLon2Coord(dictLatLon):
    return CoordDec2Min(float(dictLatLon["lat"]),float(dictLatLon["lon"]))

# %%
Dec2Min(-1.57305)
# Out:
# '-1 34.383'

# %%
tree = etree.parse(nomLoc)
root = tree.getroot()
nsRoot=root.nsmap[None]
nsGC="http://www.groundspeak.com/cache/1/0/1"
print root.tag
# Out:
# {http://www.topografix.com/GPX/1/0}gpx

# %%
listeLogs=[]
noNum=0
noNumIndex="abcdefghijklmnopqrstuvwxyz"
for wpt in root.findall("{%s}wpt"%nsRoot):
    cacheName=wpt.find("{%s}desc"%nsRoot).text
    cache=wpt.find("{%s}cache"%nsGC)
    logs=cache.find("{%s}logs"%nsGC)
    logList=logs.findall("{%s}log"%nsGC)
    for log in logList: 
        logType=log.find("{%s}type"%nsGC)
        if logType.text in ["Found it","Attended"]:
            logText=log.find("{%s}text"%nsGC)
            texteLog=logText.text
            m=re.search("(#\s?\**|\[pink\]|\[b\])(\d+)",texteLog)
            if m:
                numLog=int(m.group(2))
            else:
                print "============================="
                numLog=noNumIndex[noNum]
                noNum+=1
                logDate=log.find("{%s}date"%nsGC).text.split("T")[0]
                print logDate,cacheName,"pas de numéro =>",numLog
                
#            print (numLog,cacheName,texteLog)
            listeLogs.append([numLog,cacheName,texteLog])
# Out:
# =============================
# 2013-07-10 54 - 64 et 1000 km plus tard... by huntersam, Event Cache (1/1.5) pas de numéro => a
# =============================
# 2016-06-17 Castets : la salle des fêtes by DorisBear, Traditional Cache (1.5/1.5) pas de numéro => b
# =============================
# 2017-05-26 GTAQ Saison 3 - Episode 2 : La Chalosse by GTAQ, Event Cache (1/1) pas de numéro => c
# =============================
# 2012-04-07 L'event Basque : A vos marques, prêts, partez !  by Peyo64, Event Cache (1/1) pas de numéro => d
# =============================
# 2014-08-30 Villodas: Puente Romano by kasiMEGA TEAM, Unknown Cache (2/1.5) pas de numéro => e
# =============================
# 2011-11-11 Le 11 Landais by Lanowar, Event Cache (1/1) pas de numéro => f
# =============================
# 2011-04-20 Les Vents de Foehn # Teberne # 4 by ossau64, Traditional Cache (1.5/3) pas de numéro => g

# %%
logsSpeciaux={u"54 - 64 et 1000 km plus tard... by huntersam, Event Cache (1/1.5)":1452,
              u"Castets : la salle des fêtes by DorisBear, Traditional Cache (1.5/1.5)":2957,
              u"GTAQ Saison 3 - Episode 2 : La Chalosse by GTAQ, Event Cache (1/1)":3500,
              u"L'event Basque : A vos marques, prêts, partez !  by Peyo64, Event Cache (1/1)":413,
              u"Villodas: Puente Romano by kasiMEGA TEAM, Unknown Cache (2/1.5)":2111,
              u"Le 11 Landais by Lanowar, Event Cache (1/1)":335,
              u"Les Vents de Foehn # Teberne # 4 by ossau64, Traditional Cache (1.5/3)":177,
              u"Détruit par les ducs de Joyeuse by Padington, Traditional Cache (2/1.5)":459,
              u"64 102 - Pyrénées Atlantique by gilles64, Unknown Cache (2/1.5)":3900
             }

# %%
for log in listeLogs:
    if log[1] in logsSpeciaux:
        log[0]=logsSpeciaux[log[1]]
listeLogs.sort(key=lambda x: x[0])

# %%
n=3500
print listeLogs[n][1],listeLogs[n][0]
print listeLogs[n][2]
# Out:
# mairie de bénesse-les dax by lauki3940, Traditional Cache (1.5/1.5) 3503
# ### #3503. ###
# ### 📢 Alerte ! Alerte ! Alerte ! 📢 ###
# ### Tout le monde à son poste ! ###
#
# Beaucoup de retard au démarrage. Finalement, c'est à la royale suggestion de Peyo64 👑 que nous faisons un petit détour en chemin vers l'event des Luso-Mosellans 🇵🇹. L'espoir de trouver un clog immaculé 🗒 est faible après presque deux jours d'attente. Ludo 🚒 s'arrête sur le parking voisin 🅿️ et les explorateurs 🌗👑 se jettent dans la recherche. La prison n'est pas loin, le petit pot 🍯 apparaît bientôt dans les mains de la moitié. Une spécialité locale 🦆 qui rappellera des souvenirs aux afficionados des résolutions difficiles qui ont même donné lieu à un event spécial 🎉...
#
# Pour loguer 📝, tout le confort était là, une table pour sigler ❤️💛💚 tranquilles, des massifs de fleurs 💐 pour la séance photo et même de l'ombre... Et surtout, `ô surprise, un clog tout neuf 🗒...!  Petite cérémonie de co-FTF avec le Reyo, mais sans Fonce ❤️, Trouve 💛 et Fête 💚, avant de repartir pour le rendez-vous annuel des mosellans dacquois. MPLC, milesker lauki3940 😄
#
# ---
#
# “FTF ALERT! (FTF) ALERT! FTF ALERT! Everyone proceed to their station” Mark called the team to attention.
#
# Mark's call was not followed by any action for a long while. It was on our way to the event on the other side of Dax that our King suggested a stop. It had already been almost two days and plenty of people have had the opportunity to visit the cache before us but as nobody had logged there was still a chance...
#
# So Ludo parked on the lot in front of the town hall and the chasers jumped out in pursuit of the fugitive. They found it in the shade as the hint indicated. Our BH brought the little box to the neighbouring table and we proceeded with the signing ceremony. Thanks for the opportunity to fulfil our July obligation right away... TFTC
#
# In : pingouin luge — Out : hippo transat

# %% [markdown]
# ## Filtrages

# %%
smileys={u"[:I]":u"😳",u"[8D]":u"😎",u"[:P]":u"😋",u"[;)]":u"😉",u"[8)]":u"🤭",
         u"[:)]":u"😀",u"[:(]":u"🤢",u"[xx(]":u"😵",u"[|)]":u"😴",u"[:D]":u"😁",
         u"[^]":u"🤩",u"[}:)]":u"😈"}
smileysMatch="|".join([re.escape(k) for k in smileys.keys()])

def continuRe(listeLogs):
    fini=True
    for log in listeLogs:
        m=re.search(ur"(This entry was edited by .* on .* at \d?\d:\d\d:\d\d\s*((AM|PM)? UTC)?.)",log[2])
        if m:
            print "replacing edited by"
            log[2]=log[2].replace(m.group(1),"")
            fini=False
        m=re.findall(ur"(\[url=(.*?)\](.*?)\[/url\])",log[2])
        if m:
            print "replacing all [url]"
            for element in m:
                log[2]=log[2].replace(element[0],u"\\href{%s}{%s}"%(element[1],element[2]))
            fini=False
        m=re.findall(ur"(\[(blue|yellow|red|pink|orange|green|white)\](.*?)\[/\2\])",log[2])
        if m:
            print "replacing all color"
            for element in m:
                log[2]=log[2].replace(element[0],u"\\color{%s}%s\\color{black}"%(element[1],element[2]))
            fini=False
        m=re.findall(ur"(\[(blue|yellow|red|pink|orange|green|white)\](.*?)\[/\2\])",log[2])
        if m:
            print "replacing all color"
            for element in m:
                log[2]=log[2].replace(element[0],u"\\color{%s}%s\\color{black}"%(element[1],element[2]))
            fini=False
        m=re.findall(ur"(\[size=(\d)\](.*?)\[/\2\])",log[2])
        if m:
            print "replacing all size"
            for element in m:
                size=element[1]
                if size=="4":
                    log[2]=log[2].replace(element[0],u"{\\LARGE{}%s}"%element[2])
                elif size=="3":
                    log[2]=log[2].replace(element[0],u"{\\Large{}%s}"%element[2])
                elif size=="2":
                    log[2]=log[2].replace(element[0],u"{\\large{}%s}"%element[2])
                else:
                    log[2]=log[2].replace(element[0],element[2])
            fini=False
        m=re.search(ur"(\[b\](.*)\[/b\])",log[2])
        if m:
            print "replacing [bold]"
            log[2]=log[2].replace(m.group(1),u"{\\bfseries{}%s}"%(m.group(2)))
            fini=False
        m=re.search(ur"(\*\*(.*)\*\*)",log[2])
        if m:
            print "replacing **bold**"
            log[2]=log[2].replace(m.group(1),u"{\\bfseries{}%s}"%(m.group(2)))
            fini=False
        m=re.search(ur"(\[i\]([^[]*)\[/i\])",log[2])
        if m:
            print "replacing [italics]"
            log[2]=log[2].replace(m.group(1),u"{\\itshape{}%s}"%(m.group(2)))
            fini=False
        m=re.search(ur"(\*(.*)\*)",log[2])
        if m:
            print "replacing *italics*"
            log[2]=log[2].replace(m.group(1),u"{\\itshape{}%s}"%(m.group(2)))
            fini=False
        m=re.search(ur"(%s)"%smileysMatch,log[2])
        if m:
            print "replacing smileys"
            print m.group(1)
            log[2]=log[2].replace(m.group(1),smileys["%s"%m.group(1)])
            fini=False
        m=re.search(ur"(###\s*(.*?)\s*###)",log[2])
        if m:
            print "replacing ### ###"
            log[2]=log[2].replace(m.group(1),u"{\\centering\\color{green}%s\\color{black}}"%m.group(2))
            fini=False
        m=re.search(ur"(##\s*(.*)\s*##)",log[2])
        if m:
            print "replacing ## ##"
            log[2]=log[2].replace(m.group(1),u"{\large\\centering{}%s}"%m.group(2))
            fini=False
        m=re.search(ur"(#\s*(.*)\s*#)",log[2])
        if m:
            print "replacing # #"
            log[2]=log[2].replace(m.group(1),u"{\Large\\centering{}%s}"%m.group(2))
            fini=False
        result=fini
    return (listeLogs, result)

# %%
fini=False
while not fini:
    (listeLogs,fini)=continuRe(listeLogs)
# Out:
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [xx(]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:P]
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [xx(]
# replacing edited by
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [:P]
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [|)]
# replacing edited by
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing ### ###
# replacing ## ##
# replacing # #
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [xx(]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [8D]
# replacing # #
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [|)]
# replacing smileys
# [:I]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8)]
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [:D]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [:I]
# replacing smileys
# [xx(]
# replacing edited by
# replacing smileys
# [:P]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [:(]
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing all [url]
# replacing smileys
# [;)]
# replacing edited by
# replacing all [url]
# replacing smileys
# [;)]
# replacing edited by
# replacing all [url]
# replacing smileys
# [;)]
# replacing edited by
# replacing all [url]
# replacing smileys
# [:(]
# replacing all [url]
# replacing smileys
# [:)]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [^]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing smileys
# [:D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing all color
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [8)]
# replacing edited by
# replacing all color
# replacing smileys
# [8)]
# replacing edited by
# replacing *italics*
# replacing smileys
# [}:)]
# replacing smileys
# [:D]
# replacing smileys
# [:I]
# replacing *italics*
# replacing smileys
# [:(]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [:D]
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all [url]
# replacing all color
# replacing smileys
# [:I]
# replacing all [url]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all [url]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all [url]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing *italics*
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing [italics]
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing [italics]
# replacing smileys
# [:I]
# replacing all [url]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all [url]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing *italics*
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing all [url]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [:)]
# replacing all [url]
# replacing all color
# replacing smileys
# [8)]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8)]
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing [italics]
# replacing smileys
# [:D]
# replacing *italics*
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing smileys
# [8D]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing *italics*
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing edited by
# replacing all [url]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [8D]
# replacing all [url]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [^]
# replacing all [url]
# replacing all [url]
# replacing smileys
# [:)]
# replacing all [url]
# replacing all color
# replacing all [url]
# replacing all [url]
# replacing smileys
# [:D]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing *italics*
# replacing all [url]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing all [url]
# replacing all [url]
# replacing *italics*
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing edited by
# replacing edited by
# replacing all [url]
# replacing edited by
# replacing edited by
# replacing all [url]
# replacing smileys
# [^]
# replacing all [url]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing edited by
# replacing all [url]
# replacing all [url]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing all [url]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing all [url]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing all [url]
# replacing edited by
# replacing all [url]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing [italics]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing edited by
# replacing [bold]
# replacing *italics*
# replacing edited by
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing edited by
# replacing all [url]
# replacing *italics*
# replacing edited by
# replacing all color
# replacing edited by
# replacing all [url]
# replacing all color
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing all color
# replacing smileys
# [^]
# replacing edited by
# replacing all color
# replacing *italics*
# replacing smileys
# [:D]
# replacing edited by
# replacing all color
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing *italics*
# replacing *italics*
# replacing [italics]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing *italics*
# replacing smileys
# [:D]
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing smileys
# [8D]
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing edited by
# replacing all color
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing all color
# replacing edited by
# replacing all color
# replacing *italics*
# replacing edited by
# replacing all color
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [:P]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing edited by
# replacing [italics]
# replacing [italics]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing [italics]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing [italics]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all color
# replacing smileys
# [^]
# replacing [italics]
# replacing edited by
# replacing all [url]
# replacing [italics]
# replacing edited by
# replacing edited by
# replacing [italics]
# replacing [bold]
# replacing edited by
# replacing all color
# replacing smileys
# [8D]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing edited by
# replacing all color
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing smileys
# [:I]
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing [italics]
# replacing smileys
# [8D]
# replacing [italics]
# replacing edited by
# replacing all color
# replacing *italics*
# replacing [italics]
# replacing all color
# replacing *italics*
# replacing edited by
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing [italics]
# replacing edited by
# replacing smileys
# [xx(]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing all [url]
# replacing smileys
# [:P]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing all [url]
# replacing edited by
# replacing [italics]
# replacing smileys
# [;)]
# replacing all [url]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing [italics]
# replacing smileys
# [|)]
# replacing smileys
# [xx(]
# replacing [italics]
# replacing edited by
# replacing all color
# replacing smileys
# [:)]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing smileys
# [:(]
# replacing all [url]
# replacing [italics]
# replacing [italics]
# replacing all [url]
# replacing edited by
# replacing [italics]
# replacing smileys
# [;)]
# replacing all [url]
# replacing [italics]
# replacing edited by
# replacing all color
# replacing [bold]
# replacing smileys
# [^]
# replacing [italics]
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing all [url]
# replacing *italics*
# replacing all [url]
# replacing [italics]
# replacing all [url]
# replacing [italics]
# replacing *italics*
# replacing all color
# replacing all [url]
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [8)]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing edited by
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing all color
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing smileys
# [:I]
# replacing [italics]
# replacing all [url]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [8D]
# replacing smileys
# [8)]
# replacing smileys
# [:P]
# replacing [italics]
# replacing [italics]
# replacing all color
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing [italics]
# replacing [italics]
# replacing smileys
# [8)]
# replacing all color
# replacing [italics]
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [:P]
# replacing all color
# replacing all color
# replacing smileys
# [:D]
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing [italics]
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [;)]
# replacing *italics*
# replacing smileys
# [:P]
# replacing smileys
# [}:)]
# replacing smileys
# [:P]
# replacing *italics*
# replacing *italics*
# replacing smileys
# [;)]
# replacing [italics]
# replacing [italics]
# replacing all color
# replacing [italics]
# replacing all color
# replacing *italics*
# replacing *italics*
# replacing smileys
# [^]
# replacing *italics*
# replacing [italics]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [}:)]
# replacing *italics*
# replacing all color
# replacing *italics*
# replacing smileys
# [:I]
# replacing *italics*
# replacing [italics]
# replacing smileys
# [xx(]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [;)]
# replacing edited by
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing all color
# replacing all [url]
# replacing smileys
# [:P]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing edited by
# replacing smileys
# [xx(]
# replacing smileys
# [8D]
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [:P]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing # #
# replacing [italics]
# replacing smileys
# [:P]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing all [url]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing # #
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing edited by
# replacing [italics]
# replacing smileys
# [:)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing smileys
# [xx(]
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [8D]
# replacing # #
# replacing [bold]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing [italics]
# replacing edited by
# replacing smileys
# [:I]
# replacing all [url]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [:D]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing all [url]
# replacing [italics]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:I]
# replacing [italics]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [8D]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing all color
# replacing [italics]
# replacing *italics*
# replacing smileys
# [:I]
# replacing smileys
# [xx(]
# replacing all [url]
# replacing [italics]
# replacing smileys
# [:)]
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing all color
# replacing edited by
# replacing all color
# replacing smileys
# [:P]
# replacing all [url]
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing smileys
# [|)]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [xx(]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing all [url]
# replacing all color
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [|)]
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing edited by
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing all color
# replacing smileys
# [}:)]
# replacing all color
# replacing [italics]
# replacing smileys
# [8D]
# replacing [italics]
# replacing edited by
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all [url]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing # #
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing # #
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing *italics*
# replacing smileys
# [;)]
# replacing # #
# replacing [bold]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing all color
# replacing all color
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [;)]
# replacing all [url]
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing smileys
# [:(]
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing smileys
# [xx(]
# replacing edited by
# replacing all color
# replacing edited by
# replacing all [url]
# replacing all color
# replacing edited by
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing edited by
# replacing all color
# replacing smileys
# [xx(]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing smileys
# [:I]
# replacing edited by
# replacing all color
# replacing smileys
# [;)]
# replacing edited by
# replacing all color
# replacing smileys
# [:P]
# replacing edited by
# replacing all color
# replacing smileys
# [8)]
# replacing all color
# replacing smileys
# [:D]
# replacing smileys
# [xx(]
# replacing all color
# replacing smileys
# [:D]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [xx(]
# replacing all [url]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [:D]
# replacing smileys
# [8)]
# replacing smileys
# [^]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [}:)]
# replacing smileys
# [:D]
# replacing smileys
# [xx(]
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [|)]
# replacing smileys
# [xx(]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all [url]
# replacing all color
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing # #
# replacing [italics]
# replacing smileys
# [:I]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [;)]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [|)]
# replacing smileys
# [|)]
# replacing edited by
# replacing smileys
# [:I]
# replacing all color
# replacing [italics]
# replacing smileys
# [:I]
# replacing smileys
# [:P]
# replacing all color
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing all color
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [|)]
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing [bold]
# replacing *italics*
# replacing smileys
# [;)]
# replacing edited by
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing # #
# replacing smileys
# [;)]
# replacing # #
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [^]
# replacing all color
# replacing [bold]
# replacing smileys
# [xx(]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [|)]
# replacing all [url]
# replacing [italics]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing edited by
# replacing all [url]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing all [url]
# replacing all color
# replacing *italics*
# replacing smileys
# [:(]
# replacing # #
# replacing all [url]
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [|)]
# replacing smileys
# [|)]
# replacing smileys
# [:P]
# replacing all [url]
# replacing smileys
# [^]
# replacing all color
# replacing [italics]
# replacing smileys
# [8)]
# replacing [bold]
# replacing smileys
# [;)]
# replacing [bold]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [:P]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:)]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [xx(]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [xx(]
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [:I]
# replacing smileys
# [8)]
# replacing smileys
# [:P]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [8D]
# replacing # #
# replacing smileys
# [:I]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing all [url]
# replacing all color
# replacing smileys
# [8D]
# replacing smileys
# [|)]
# replacing all [url]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [:D]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [}:)]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [8D]
# replacing smileys
# [:P]
# replacing all [url]
# replacing smileys
# [xx(]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [}:)]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [xx(]
# replacing [italics]
# replacing smileys
# [8)]
# replacing smileys
# [:I]
# replacing smileys
# [:P]
# replacing smileys
# [8D]
# replacing smileys
# [:(]
# replacing smileys
# [8D]
# replacing [bold]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [:P]
# replacing [bold]
# replacing smileys
# [xx(]
# replacing smileys
# [:I]
# replacing all [url]
# replacing smileys
# [8)]
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [:P]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [8D]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [}:)]
# replacing smileys
# [8)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [^]
# replacing smileys
# [}:)]
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing smileys
# [:P]
# replacing smileys
# [}:)]
# replacing smileys
# [8D]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [xx(]
# replacing all color
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:I]
# replacing smileys
# [:I]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [:)]
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [|)]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [}:)]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [}:)]
# replacing all color
# replacing [bold]
# replacing smileys
# [|)]
# replacing edited by
# replacing all color
# replacing [bold]
# replacing smileys
# [|)]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [:I]
# replacing smileys
# [8D]
# replacing smileys
# [|)]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing all color
# replacing [italics]
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [8D]
# replacing all [url]
# replacing all color
# replacing smileys
# [:D]
# replacing smileys
# [8)]
# replacing smileys
# [^]
# replacing all [url]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing [bold]
# replacing smileys
# [:I]
# replacing edited by
# replacing [italics]
# replacing smileys
# [xx(]
# replacing [italics]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [:P]
# replacing [italics]
# replacing smileys
# [|)]
# replacing all color
# replacing [bold]
# replacing smileys
# [xx(]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [}:)]
# replacing smileys
# [8D]
# replacing all color
# replacing [bold]
# replacing smileys
# [8D]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:P]
# replacing edited by
# replacing *italics*
# replacing edited by
# replacing [italics]
# replacing smileys
# [:D]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [}:)]
# replacing smileys
# [:I]
# replacing smileys
# [8)]
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [xx(]
# replacing smileys
# [|)]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [}:)]
# replacing smileys
# [}:)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing [italics]
# replacing smileys
# [:P]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing [bold]
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing all [url]
# replacing smileys
# [:D]
# replacing # #
# replacing all [url]
# replacing [italics]
# replacing smileys
# [:D]
# replacing # #
# replacing all [url]
# replacing smileys
# [:D]
# replacing # #
# replacing smileys
# [8)]
# replacing # #
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [;)]
# replacing all [url]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [;)]
# replacing **bold**
# replacing *italics*
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing # #
# replacing all color
# replacing [bold]
# replacing smileys
# [8D]
# replacing # #
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [^]
# replacing smileys
# [8)]
# replacing smileys
# [:P]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [xx(]
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [8D]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing all [url]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing [bold]
# replacing smileys
# [8)]
# replacing all color
# replacing [bold]
# replacing smileys
# [^]
# replacing edited by
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [8)]
# replacing edited by
# replacing smileys
# [:)]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing smileys
# [}:)]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing # #
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [:D]
# replacing [italics]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing smileys
# [8D]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [}:)]
# replacing all [url]
# replacing [italics]
# replacing smileys
# [^]
# replacing all color
# replacing [bold]
# replacing smileys
# [:(]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [|)]
# replacing smileys
# [;)]
# replacing smileys
# [:(]
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [}:)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing smileys
# [:P]
# replacing smileys
# [}:)]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [:I]
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing edited by
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [:P]
# replacing all [url]
# replacing all color
# replacing smileys
# [:)]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [;)]
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [}:)]
# replacing all color
# replacing smileys
# [xx(]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [|)]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [:D]
# replacing smileys
# [8)]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing edited by
# replacing all color
# replacing smileys
# [^]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing [bold]
# replacing smileys
# [8)]
# replacing all color
# replacing [bold]
# replacing smileys
# ...
# [:)]
# replacing **bold**
# replacing *italics*
# replacing smileys
# [:)]
# replacing ### ###
# replacing ## ##
# replacing # #
# replacing smileys
# [}:)]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing **bold**
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing # #
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:)]
# replacing # #
# replacing **bold**
# replacing *italics*
# replacing smileys
# [xx(]
# replacing smileys
# [:)]
# replacing **bold**
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing **bold**
# replacing **bold**
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [;)]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:P]
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:I]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [8)]
# replacing *italics*
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [:P]
# replacing *italics*
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [:I]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [|)]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [xx(]
# replacing smileys
# [:P]
# replacing smileys
# [|)]
# replacing smileys
# [xx(]
# replacing smileys
# [:I]
# replacing smileys
# [:P]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing *italics*
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [^]
# replacing smileys
# [}:)]
# replacing *italics*
# replacing smileys
# [:P]
# replacing smileys
# [:(]
# replacing smileys
# [:D]
# replacing # #
# replacing smileys
# [:(]
# replacing smileys
# [xx(]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [8)]
# replacing smileys
# [:I]
# replacing smileys
# [:P]
# replacing smileys
# [:P]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [^]
# replacing smileys
# [:(]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [}:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [|)]
# replacing smileys
# [|)]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [bold]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:(]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [}:)]
# replacing smileys
# [:P]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [xx(]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing smileys
# [8)]
# replacing smileys
# [}:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing **bold**
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [8)]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:I]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [xx(]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [^]
# replacing **bold**
# replacing *italics*
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [8)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [:P]
# replacing *italics*
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:P]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing **bold**
# replacing *italics*
# replacing ### ###
# replacing ## ##
# replacing # #
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing **bold**
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:P]
# replacing smileys
# [8D]
# replacing *italics*
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [|)]
# replacing *italics*
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:D]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:D]
# replacing *italics*
# replacing smileys
# [:(]
# replacing *italics*
# replacing smileys
# [|)]
# replacing smileys
# [:D]
# replacing smileys
# [:I]
# replacing smileys
# [:(]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing *italics*
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [:D]
# replacing smileys
# [xx(]
# replacing smileys
# [:D]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [^]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [8)]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing *italics*
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [xx(]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [}:)]
# replacing smileys
# [8)]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [:P]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [}:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing **bold**
# replacing *italics*
# replacing ### ###
# replacing # #
# replacing *italics*
# replacing smileys
# [8)]
# replacing *italics*
# replacing smileys
# [:(]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [xx(]
# replacing smileys
# [;)]
# replacing smileys
# [xx(]
# replacing smileys
# [}:)]
# replacing smileys
# [:D]
# replacing *italics*
# replacing smileys
# [8)]
# replacing [italics]
# replacing smileys
# [:P]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [}:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [8)]
# replacing *italics*
# replacing smileys
# [:(]
# replacing smileys
# [8)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing **bold**
# replacing *italics*
# replacing *italics*
# replacing smileys
# [xx(]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [}:)]
# replacing *italics*
# replacing smileys
# [}:)]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing *italics*
# replacing smileys
# [8)]
# replacing smileys
# [:P]
# replacing **bold**
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:D]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing [italics]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [8)]
# replacing *italics*
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [xx(]
# replacing *italics*
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:(]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*

# %%
def continuReplace(listeLogs):
    fini=True
    for log in listeLogs:
        m=re.search(ur"(\[([^[]*)\]\(([^(]*)\))",log[2])
        if m:
            print "replacing [text](url)"
            log[2]=log[2].replace(m.group(1),u"\\href{%s}{%s}"%(m.group(3),m.group(2)))
            fini=False
        m=re.search(ur"(#(\d+\.?))",log[2])
        if m:
            print "replacing #num."
            log[2]=log[2].replace(m.group(1),u"\\Number{}%s"%m.group(2))
            fini=False
        m=re.search(ur"(#(%d|{\\bfseries|\s*\\color|MMCXI))"%log[0],log[2])
        if m:
            print "replacing #num."
            log[2]=log[2].replace(m.group(1),u"%s"%m.group(2))
            fini=False
        log[1]=log[1].replace(u"&nbsp;",ur" ").replace("#","\\Number{}").replace("&","\\And{}").replace("^","\\textasciicircum")
        log[2]=log[2].replace(u"&nbsp;",ur" ").replace("&","\\And{}").replace("^","\\textasciicircum").replace("$","\\textdollar{}").replace("%","\\Percent{}")
    result=fini
    return (listeLogs, result)

# %%
fini=False
while not fini:
    (listeLogs,fini)=continuReplace(listeLogs)
# Out:
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# ...
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)

# %%
lines=[]
for l in listeLogs:
    lines.append(u"\\cacheNumber{%s}"%l[0])
    lines.append(u"\\cacheName{%s}"%l[1])
    lines.append(u"\\begin{cacheText}")
    lines.append(l[2].strip())
    lines.append(u"\\end{cacheText}\n\n")

# %%
print len(lines)
# Out:
# 19995

# %%
with codecs.open("TextesLog2.tex","w",encoding='utf8') as output:
    output.writelines(lines[:5000])
    output.writelines(lines[5000:10000])
    output.writelines(lines[10000:15000])
    output.writelines(lines[15000:])

# %%
with codecs.open("TextesLog2.tex","w",encoding='utf8') as output:
    for l in listeLogs:
#        output.write("%d\n"%l[0])
        output.write(u"\\cacheNumber{%s}\n"%l[0])
        output.write(u"\\cacheName{%s}\n"%l[1])
        output.write(u"\\begin{cacheText}\n%s\n\\end{cacheText}\n\n\n"%l[2])

# %%
m=re.findall(ur"(###(.*?)###)",u"### #210. ###\n### test ###\n# tester #\n",)
m
# Out:
# [(u'### #210. ###', u' #210. '), (u'### test ###', u' test ')]
