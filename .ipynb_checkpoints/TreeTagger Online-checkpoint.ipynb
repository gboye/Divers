# %% [markdown]
# # Taguer un fichier avec TreeTagger Online depuis Python

# %%
import mechanicalsoup, codecs

# %%
treetaggerURL="http://cental.fltr.ucl.ac.be/treetagger/"
fichierBrut="test.txt"

# %%
browser = mechanicalsoup.Browser()

# %%
# request TT home page. the result is a requests.Response object http://docs.python-requests.org/en/latest/user/quickstart/#response-content
accueil = browser.get(treetaggerURL)

# %% [markdown]
# Dans la réponse *accueil*, il y a un formulaire qui permet d'envoyer le fichier qu'on veut taguer :
# - treetagger_form

# %%
print accueil.soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
# <html>
# <!-- sessionKey= loginguid= -->
# <!-- Variables du bandeau PreExecute -->
# <!--tmp-fr/cental.html--> <!--tmp-fr/cental.html--> <head><!-- PageID 44005 - published by RedDot 7.5 - 7.5.2.17 - 14445 -->
# <title>Treetagger</title>
# <!-- Modele de page : page_deux_colonnes ; date_publ: 20090712T2047 -->
# <!--domaine_code=cental-->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="http://purl.org/DC/elements/1.1/" rel="schema.DC"/>
# <meta content="Recherche au Cental" name="DC.Title"/>
# <meta content="Isabelle Lecroart" name="DC.Creator"/>
# <meta content="Université catholique de Louvain" name="DC.Subject"/>
# <meta content="" name="DC.Description"/>
# <meta content="Isabelle Lecroart" name="DC.Publisher"/>
# <meta content="" name="DC.Contributor"/>
# <meta content="9/03/2009" name="DC.Date"/>
# <meta content="text" name="DC.Type"/>
# <meta content="text/html" name="DC.Format"/>
# <meta content="http://www.uclouvain.be/cental-recherche.html" name="DC.Identifier"/>
# <meta content="FRB" name="DC.Language"/>
# <meta content="Public" name="DC.Audience"/>
# <meta content="CENTAL,traitement automatique du langage,TAL,TALN,linguistique informatique,linguistique computationnelle,concordanciers,corpus,dictionnaires électroniques,NLP,natural language processing,human language technologies,HLT," name="keywords"/>
# <meta content="Copyright 2009 Université catholique de Louvain" name="copyright"/>
# <script src="http://www.uclouvain.be/cps/ucl/scripts/utilitaires.js" type="text/javascript"></script>
# <!--tmp-fr/cental.html--><link href="http://www.uclouvain.be/cps/ucl/styles/fltr_page.css" rel="stylesheet" type="text/css"/>
# <link href="http://www.uclouvain.be/cps/ucl/styles/ucl_page_print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <center>
# <div id="container">
# <div id="intro">
# </div>
# <div id="header">
# <!-- Debut outils -->
# <div class="non-imprime" id="outils">
# <span class="option2">| </span>
# <a class="option1" href="http://www2.adcp.ucl.ac.be/cal/intro.htm" target="_blank">agenda</a>
# <span class="option2"> | </span>
# <a class="option1" href="http://www.uclouvain.be/repertoires.html">répertoires</a>
# <span class="option2"> | </span>
# <a class="option1" href="http://www.bib.ucl.ac.be/" target="_blank">bibliothèques</a>
# <span class="option2"> | </span>
# <a class="option1" href="http://www.uclouvain.be/emploi-offres.html">offres d'emploi</a>
# <span class="option2"> | </span>
# <a class="option1" href="http://www.uclouvain.be/acces.html">plan d'accès</a>
# <span class="option2"> | </span>
# <form action="http://uclouvain.be/67374bis.html" class="forme" id="recherche" method="get" name="recherche" onsubmit='this.q.value = this.q.value.replace (new RegExp("\"","g"),"\\\"")' target="_blank">
#      <input border="0" name="sa" src="/cps/ucl/doc/ucl/images/icones/bouton_recherche.png" type="image" value="submit"/>
# <input class="entree-boite" name="q" onfocus="this.value='';" size="20" type="text" value="votre recherche..."/>
# </form>
# </div>
# <!-- Fin outils -->
# <!-- Debut identification -->
# <div class="non-imprime" id="identification">
# <span class="option1">| </span><a class="option2" href="http://www.uclouvain.be/onglet_bureau.html">mon bureau</a>
# <span class="option1"> | </span><a class="option2" href="http://www.uclouvain.be/page_connexion.html">s'identifier</a>
# <span class="option1"> |</span>
# </div>
# <!-- Fin identification -->
# <!--tmp-fr/cental.html--><!-- Debut bandeau ID: 97392-->
# <div id="bandeau">
# <img alt="" height="110" src="http://www.uclouvain.be/cps/ucl/doc/ucl/images/bandeaux/BandeauN_fltr.jpg"/>
# <div class="non-imprime" id="bandeauUcl">
# <a href="http://www.uclouvain.be/index.html"><img alt="" border="0" height="70" src="http://www.uclouvain.be/cps/ucl/doc/ucl/images/icones/espace.gif" width="295"/></a>
# </div>
# <div id="bandeauDomaines">
# <p></p>
# <p><a class="bandeau-domaine" href="http://www.uclouvain.be/cental.html">Centre de traitement automatique du langage</a></p>
# </div>
# <div id="bandeauSecteur">
# </div>
# </div>
# <!-- Fin bandeau --> <div class="option1" id="breadCrump">
# <span class="option3">&gt; <a href="http://www.uclouvain.be/index.html">UCL</a> </span>
# <span class="option3">&gt; <a href="http://www.uclouvain.be/208781.html">Les plateformes technologiques</a> </span>
# <span class="option1">&gt; <a href="http://www.uclouvain.be/cental.html">Centre de traitement automatique du langage</a> </span>
# <span class="option2">&gt; </span><span class="option1">Recherche</span>
#                       </div>
# <div class="non-imprime option1" id="langues">
# <div align="right">
# </div>
# </div>
# </div>
# <table id="main">
# <!-- Debut contenu -->
# <tr>
# <td class="non-imprime" id="menu">
# <!--tmp-fr/cental.html-->
# <table border="0" cellpadding="0" cellspacing="0" class="menu-table">
# <tr><td class="menu-titre" colspan="5"><a href="http://www.uclouvain.be/cental.html">&gt; Centre de traitement automatique du langage</a></td></tr>
# <tr class="menu-separateur"><td colspan="5"> </td></tr>
# <tr class="menu-ligne">
# <td class="menu-colun"> </td><td class="menu-signet">&gt;</td>
# <td class="menu-td" colspan="3" width="160px"><a href="http://www.uclouvain.be/cental.html" title="">Accueil</a></td>
# </tr>
# </table>
# <div class="menu-separateur"> </div>
# <!-- tmp-fr/cental.html-->
# <br/><img alt="" height="1" src="/cps/ucl/doc/ucl/images/icones/espace.gif" width="175"/>
# </td>
# <td id="content2">
# <div id="IORD_OpenPage">
# </div>
# <div>
# <h1 class="cache">Recherche au Cental</h1>
# <div class="texte-base"><table align="right" border="0" cellpadding="0" cellspacing="0" height="122" width="100%">
# </table>
# <h1>&gt; Étiqueter un texte en français grâce à <em>TreeTagger</em></h1>
# <br/>
# <br/>
# <!-- AFFICHAGE DU FORMULAIRE -->
# <form action="index.html" enctype="multipart/form-data" method="POST" name="treetagger_form">
# <table cellpadding="2px" cellspacing="5px">
# <tbody>
# <tr>
# <td>
#                Texte à étiqueter :
#             </td>
# <td>
# <input name="file_to_tag" size="50/" type="file"/>
# </td>
# </tr>
# <tr>
# <td>
# </td>
# <td>
# <input name="submit" type="submit"/>
# </td>
# </tr>
# </tbody>
# </table>
# </form>
# <br/><br/>
#
# (Attention, le traitement peut prendre un certain temps.)
#
# <br/><br/>
# Pour plus d'informations sur Treetagger, consultez le site de <a href="http://www.ims.uni-stuttgart.de/projekte/corplex/TreeTagger/">TreeTagger</a>.
#
# <!-- FIN DE L'AFFICHAGE DU FORMULAIRE -->
# </div></div></td>
# <td width="25"> </td>
# </tr><tr valign="top">
# <td class="non-imprime" width="25"> </td>
# <td width="175">
# </td>
# </tr>
# </table></div></center></body></html>

# %% [markdown]
# accueil.soup is a BeautifulSoup object http://www.crummy.com/software/BeautifulSoup/bs4/doc/#beautifulsoup
# we grab the treetagger_form in *formulaire*

# %%
formulaire = accueil.soup.select("form[name=treetagger_form]")[0]

# %% [markdown]
# to use the form, we need to make it a mechanicalsoup.Form
# and set the **file_to_tag** form field to the name of our file

# %%
form=mechanicalsoup.Form(formulaire)
form.set('file_to_tag', fichierBrut)

# %% [markdown]
# the filled form can now be uploaded with a browser.submit
# the resulting page is put in *upload*

# %%
upload=browser.submit(form,url="http://cental.fltr.ucl.ac.be/treetagger/")

# %% [markdown]
# the *upload.soup* contains the extension pointing to the resulting file on the site

# %%
print upload.soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
# <html>
# <!-- sessionKey= loginguid= -->
# <!-- Variables du bandeau PreExecute -->
# <!--tmp-fr/cental.html--> <!--tmp-fr/cental.html--> <head><!-- PageID 44005 - published by RedDot 7.5 - 7.5.2.17 - 14445 -->
# <title>Treetagger</title>
# <!-- Modele de page : page_deux_colonnes ; date_publ: 20090712T2047 -->
# <!--domaine_code=cental-->
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="http://purl.org/DC/elements/1.1/" rel="schema.DC"/>
# <meta content="Recherche au Cental" name="DC.Title"/>
# <meta content="Isabelle Lecroart" name="DC.Creator"/>
# <meta content="Université catholique de Louvain" name="DC.Subject"/>
# <meta content="" name="DC.Description"/>
# <meta content="Isabelle Lecroart" name="DC.Publisher"/>
# <meta content="" name="DC.Contributor"/>
# <meta content="9/03/2009" name="DC.Date"/>
# <meta content="text" name="DC.Type"/>
# <meta content="text/html" name="DC.Format"/>
# <meta content="http://www.uclouvain.be/cental-recherche.html" name="DC.Identifier"/>
# <meta content="FRB" name="DC.Language"/>
# <meta content="Public" name="DC.Audience"/>
# <meta content="CENTAL,traitement automatique du langage,TAL,TALN,linguistique informatique,linguistique computationnelle,concordanciers,corpus,dictionnaires électroniques,NLP,natural language processing,human language technologies,HLT," name="keywords"/>
# <meta content="Copyright 2009 Université catholique de Louvain" name="copyright"/>
# <script src="http://www.uclouvain.be/cps/ucl/scripts/utilitaires.js" type="text/javascript"></script>
# <!--tmp-fr/cental.html--><link href="http://www.uclouvain.be/cps/ucl/styles/fltr_page.css" rel="stylesheet" type="text/css"/>
# <link href="http://www.uclouvain.be/cps/ucl/styles/ucl_page_print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <center>
# <div id="container">
# <div id="intro">
# </div>
# <div id="header">
# <!-- Debut outils -->
# <div class="non-imprime" id="outils">
# <span class="option2">| </span>
# <a class="option1" href="http://www2.adcp.ucl.ac.be/cal/intro.htm" target="_blank">agenda</a>
# <span class="option2"> | </span>
# <a class="option1" href="http://www.uclouvain.be/repertoires.html">répertoires</a>
# <span class="option2"> | </span>
# <a class="option1" href="http://www.bib.ucl.ac.be/" target="_blank">bibliothèques</a>
# <span class="option2"> | </span>
# <a class="option1" href="http://www.uclouvain.be/emploi-offres.html">offres d'emploi</a>
# <span class="option2"> | </span>
# <a class="option1" href="http://www.uclouvain.be/acces.html">plan d'accès</a>
# <span class="option2"> | </span>
# <form action="http://uclouvain.be/67374bis.html" class="forme" id="recherche" method="get" name="recherche" onsubmit='this.q.value = this.q.value.replace (new RegExp("\"","g"),"\\\"")' target="_blank">
#      <input border="0" name="sa" src="/cps/ucl/doc/ucl/images/icones/bouton_recherche.png" type="image" value="submit"/>
# <input class="entree-boite" name="q" onfocus="this.value='';" size="20" type="text" value="votre recherche..."/>
# </form>
# </div>
# <!-- Fin outils -->
# <!-- Debut identification -->
# <div class="non-imprime" id="identification">
# <span class="option1">| </span><a class="option2" href="http://www.uclouvain.be/onglet_bureau.html">mon bureau</a>
# <span class="option1"> | </span><a class="option2" href="http://www.uclouvain.be/page_connexion.html">s'identifier</a>
# <span class="option1"> |</span>
# </div>
# <!-- Fin identification -->
# <!--tmp-fr/cental.html--><!-- Debut bandeau ID: 97392-->
# <div id="bandeau">
# <img alt="" height="110" src="http://www.uclouvain.be/cps/ucl/doc/ucl/images/bandeaux/BandeauN_fltr.jpg"/>
# <div class="non-imprime" id="bandeauUcl">
# <a href="http://www.uclouvain.be/index.html"><img alt="" border="0" height="70" src="http://www.uclouvain.be/cps/ucl/doc/ucl/images/icones/espace.gif" width="295"/></a>
# </div>
# <div id="bandeauDomaines">
# <p></p>
# <p><a class="bandeau-domaine" href="http://www.uclouvain.be/cental.html">Centre de traitement automatique du langage</a></p>
# </div>
# <div id="bandeauSecteur">
# </div>
# </div>
# <!-- Fin bandeau --> <div class="option1" id="breadCrump">
# <span class="option3">&gt; <a href="http://www.uclouvain.be/index.html">UCL</a> </span>
# <span class="option3">&gt; <a href="http://www.uclouvain.be/208781.html">Les plateformes technologiques</a> </span>
# <span class="option1">&gt; <a href="http://www.uclouvain.be/cental.html">Centre de traitement automatique du langage</a> </span>
# <span class="option2">&gt; </span><span class="option1">Recherche</span>
#                       </div>
# <div class="non-imprime option1" id="langues">
# <div align="right">
# </div>
# </div>
# </div>
# <table id="main">
# <!-- Debut contenu -->
# <tr>
# <td class="non-imprime" id="menu">
# <!--tmp-fr/cental.html-->
# <table border="0" cellpadding="0" cellspacing="0" class="menu-table">
# <tr><td class="menu-titre" colspan="5"><a href="http://www.uclouvain.be/cental.html">&gt; Centre de traitement automatique du langage</a></td></tr>
# <tr class="menu-separateur"><td colspan="5"> </td></tr>
# <tr class="menu-ligne">
# <td class="menu-colun"> </td><td class="menu-signet">&gt;</td>
# <td class="menu-td" colspan="3" width="160px"><a href="http://www.uclouvain.be/cental.html" title="">Accueil</a></td>
# </tr>
# </table>
# <div class="menu-separateur"> </div>
# <!-- tmp-fr/cental.html-->
# <br/><img alt="" height="1" src="/cps/ucl/doc/ucl/images/icones/espace.gif" width="175"/>
# </td>
# <td id="content2">
# <div id="IORD_OpenPage">
# </div>
# <div>
# <h1 class="cache">Recherche au Cental</h1>
# <div class="texte-base"><table align="right" border="0" cellpadding="0" cellspacing="0" height="122" width="100%">
# </table>
# <h1>&gt; Étiqueter un texte en français grâce à <em>TreeTagger</em></h1>
# <br/>
# <!-- TRAITEMENT DU FICHIER ET AFFICHAGE DU TÉLÉCHARGEMENT -->
# <p>&gt; <a content="text/plain;charset=UTF-8" href="tmp/jGG5UD0UKL.txt" http-equiv="Content-Type">Télécharger le fichier étiqueté</a> <i>(Clic droit -&gt; Enregistrer sous...)</i></p>
# <p>&gt; <a href="index.html">Étiqueter un autre texte</a></p>
# <p>Fairon C., Klein J. et Paumier S. (2006), SMS pour la science. Corpus de 30.000 SMS et logiciel de consultation, Presses universitaires de Louvain, Louvain-la-Neuve. Cahiers du CENTAL, 3.2.</p>
# <!-- FIN D'AFFICHAGE DU TÉLÉCHARGEMENT -->
# </div></div></td>
# <td width="25"> </td>
# </tr><tr valign="top">
# <td class="non-imprime" width="25"> </td>
# <td width="175">
# </td>
# </tr>
# </table></div></center></body></html>

# %%
for div in upload.soup.findAll('div',attrs={"class":u"texte-base"}):
    for link in div.findAll("a",attrs={"content":"text/plain;charset=UTF-8"}):
        resultURL=treetaggerURL+link.attrs["href"]
        print resultURL
# Out:
# http://cental.fltr.ucl.ac.be/treetagger/tmp/jGG5UD0UKL.txt

# %%
result = browser.get(resultURL)

# %% [markdown]
# le fichier étiqueté est disponible dans *result.content* (plutôt que *result.soup* puisque c'est du texte brut et pas du HTML)
# **Attention** le résultat est encodé en *utf8* mais stocké dans une *str*, il faut faire un *decode("utf8")* pour l'obtenir en unicode.

# %%
resultLines=result.content.decode("utf8")
print resultLines
# Out:
# Nous	PRO:PER	nous
# étions	VER:impf	être
# à	PRP	à
# l'	DET:ART	le
# Étude	NOM	étude
# ,	PUN	,
# quand	KON	quand
# le	DET:ART	le
# Proviseur	NOM	proviseur
# entra	VER:simp	entrer
# ,	PUN	,
# suivi	VER:pper	suivre
# d'	PRP	de
# un	DET:ART	un
# nouveau	ADJ	nouveau
# habillé	VER:pper	habiller
# en	PRP	en
# bourgeois	NOM	bourgeois
# et	KON	et
# d'	PRP	de
# un	DET:ART	un
# garçon	NOM	garçon
# de	PRP	de
# classe	NOM	classe
# qui	PRO:REL	qui
# portait	VER:impf	porter
# un	DET:ART	un
# grand	ADJ	grand
# pupitre	NOM	pupitre
# .	SENT	.
# Ceux	PRO:DEM	celui
# qui	PRO:REL	qui
# dormaient	VER:impf	dormir
# se	PRO:PER	se
# réveillèrent	VER:simp	réveiller
# ,	PUN	,
# et	KON	et
# chacun	PRO:IND	chacun
# se	PRO:PER	se
# leva	VER:simp	lever
# comme	ADV	comme
# surpris	VER:pper	surprendre
# dans	PRP	dans
# son	DET:POS	son
# travail	NOM	travail
# .	SENT	.
# Le	DET:ART	le
# Proviseur	NOM	proviseur
# nous	PRO:PER	nous
# fit	VER:simp	faire
# signe	NOM	signe
# de	PRP	de
# nous	PRO:PER	nous
# rasseoir	VER:infi	rasseoir
# ;	PUN	;
# puis	ADV	puis
# ,	PUN	,
# se	PRO:PER	se
# tournant	VER:ppre	tourner
# vers	PRP	vers
# le	DET:ART	le
# maître	NOM	maître
# d'	PRP	de
# études	NOM	étude
# :	PUN	:
# --	PUN	--
# Monsieur	NOM	monsieur
# Roger	NAM	Roger
# ,	PUN	,
# lui	PRO:PER	lui
# dit	VER:pres	dire
# -il	PRO:PER	il
# à	PRP	à
# demi-voix	ADV	demi-voix
# ,	PUN	,
# voici	ADV	voici
# un	DET:ART	un
# élève	NOM	élève
# que	PRO:REL	que
# je	PRO:PER	je
# vous	PRO:PER	vous
# recommande	VER:pres	recommander
# ,	PUN	,
# il	PRO:PER	il
# entre	VER:subp	entrer
# en	PRP	en
# cinquième	NOM	cinquième
# .	SENT	.
# Si	KON	si
# son	DET:POS	son
# travail	NOM	travail
# et	KON	et
# sa	DET:POS	son
# conduite	NOM	conduite
# sont	VER:pres	être
# méritoires	ADJ	méritoire
# ,	PUN	,
# il	PRO:PER	il
# passera	VER:futu	passer
# dans	PRP	dans
# les	DET:ART	le
# grands	ADJ	grand
# ,	PUN	,
# où	PRO:REL	où
# l'	PRO:PER	la|le
# appelle	VER:pres	appeler
# son	DET:POS	son
# âge	NOM	âge
# .	SENT	.
# Resté	VER:pper	rester
# dans	PRP	dans
# l'	DET:ART	le
# angle	NOM	angle
# ,	PUN	,
# derrière	PRP	derrière
# la	DET:ART	le
# porte	NOM	porte
# ,	PUN	,
# si	KON	si
# bien	ADV	bien
# qu'	KON	que
# on	PRO:PER	on
# l'	PRO:PER	la|le
# apercevait	VER:impf	apercevoir
# à	PRP	à
# peine	NOM	peine
# ,	PUN	,
# le	DET:ART	le
# nouveau	ADJ	nouveau
# était	VER:impf	être
# un	DET:ART	un
# gars	NOM	gars
# de	PRP	de
# la	DET:ART	le
# campagne	NOM	campagne
# ,	PUN	,
# d'	PRP	de
# une	DET:ART	un
# quinzaine	NOM	quinzaine
# d'	PRP	de
# années	NOM	année
# environ	ADV	environ
# ,	PUN	,
# et	KON	et
# plus	ADV	plus
# haut	ADV	haut
# de	PRP	de
# taille	NOM	taille
# qu'	KON	que
# aucun	PRO:IND	aucun
# de	PRP	de
# nous	PRO:PER	nous
# tous	NOM	tous
# .	SENT	.
# Il	PRO:PER	il
# avait	VER:impf	avoir
# les	DET:ART	le
# cheveux	NOM	cheveu
# coupés	VER:pper	couper
# droit	ADJ	droit
# sur	PRP	sur
# le	DET:ART	le
# front	NOM	front
# ,	PUN	,
# comme	KON	comme
# un	DET:ART	un
# chantre	NOM	chantre
# de	PRP	de
# village	NOM	village
# ,	PUN	,
# l'	DET:ART	le
# air	NOM	air
# raisonnable	ADJ	raisonnable
# et	KON	et
# fort	ADV	fort
# embarrassé	VER:pper	embarrasser
# .	SENT	.
# Quoiqu'il	NAM	<unknown>
# ne	ADV	ne
# fût	VER:subi	être
# pas	ADV	pas
# large	ADJ	large
# des	PRP:det	du
# épaules	NOM	épaule
# ,	PUN	,
# son	DET:POS	son
# habit-veste	NOM	habit-veste
# de	PRP	de
# drap	NOM	drap
# vert	ADJ	vert
# à	PRP	à
# boutons	NOM	bouton
# noirs	ADJ	noir
# devait	VER:impf	devoir
# le	PRO:PER	le
# gêner	VER:infi	gêner
# aux	PRP:det	au
# entournures	NOM	entournure
# et	KON	et
# laissait	VER:impf	laisser
# voir	VER:infi	voir
# ,	PUN	,
# par	PRP	par
# la	DET:ART	le
# fente	NOM	fente
# des	PRP:det	du
# parements	NOM	parement
# ,	PUN	,
# des	PRP:det	du
# poignets	NOM	poignet
# rouges	ADJ	rouge
# habitués	VER:pper	habituer
# à	PRP	à
# être	VER:infi	être
# nus	NOM	nu
# .	SENT	.
# Ses	DET:POS	son
# jambes	NOM	jambe
# ,	PUN	,
# en	PRP	en
# bas	ADV	bas
# bleus	ADJ	bleu
# ,	PUN	,
# sortaient	VER:impf	sortir
# d'	PRP	de
# un	DET:ART	un
# pantalon	NOM	pantalon
# jaunâtre	ADJ	jaunâtre
# très	ADV	très
# tiré	VER:pper	tirer
# par	PRP	par
# les	DET:ART	le
# bretelles	NOM	bretelle
# .	SENT	.
# Il	PRO:PER	il
# était	VER:impf	être
# chaussé	VER:pper	chausser
# de	PRP	de
# souliers	NOM	soulier
# forts	ADJ	fort
# ,	PUN	,
# mal	ADV	mal
# cirés	VER:pper	cirer
# ,	PUN	,
# garnis	VER:pper	garnir
# de	PRP	de
# clous	NOM	clou
# .	SENT	.
# On	PRO:PER	on
# commença	VER:simp	commencer
# la	DET:ART	le
# récitation	NOM	récitation
# des	PRP:det	du
# leçons	NOM	leçon
# .	SENT	.
# Il	PRO:PER	il
# les	PRO:PER	la|le
# écouta	VER:simp	écouter
# de	PRP	de
# toutes	PRO:IND	tout
# ses	DET:POS	son
# oreilles	NOM	oreille
# ,	PUN	,
# attentif	ADJ	attentif
# comme	KON	comme
# au	PRP:det	au
# sermon	NOM	sermon
# ,	PUN	,
# n'	ADV	ne
# osant	VER:ppre	oser
# même	ADV	même
# croiser	VER:infi	croiser
# les	DET:ART	le
# cuisses	NOM	cuisse
# ,	PUN	,
# ni	KON	ni
# s'	PRO:PER	se
# appuyer	VER:infi	appuyer
# sur	PRP	sur
# le	DET:ART	le
# coude	NOM	coude
# ,	PUN	,
# et	KON	et
# ,	PUN	,
# à	PRP	à
# deux	NUM	deux
# heures	NOM	heure
# ,	PUN	,
# quand	KON	quand
# la	DET:ART	le
# cloche	NOM	cloche
# sonna	VER:simp	sonner
# ,	PUN	,
# le	DET:ART	le
# maître	NOM	maître
# d'	PRP	de
# études	NOM	étude
# fut	VER:simp	être
# obligé	VER:pper	obliger
# de	PRP	de
# l'	PRO:PER	la|le
# avertir	VER:infi	avertir
# ,	PUN	,
# pour	KON	pour
# qu'	KON	que
# il	PRO:PER	il
# se	PRO:PER	se
# mît	VER:subi	mettre
# avec	PRP	avec
# nous	PRO:PER	nous
# dans	PRP	dans
# les	DET:ART	le
# rangs	NOM	rang
# .	SENT	.
# Nous	PRO:PER	nous
# avions	VER:impf	avoir
# l'	DET:ART	le
# habitude	NOM	habitude
# ,	PUN	,
# en	PRO:PER	en
# entrant	VER:ppre	entrer
# en	PRP	en
# classe	NOM	classe
# ,	PUN	,
# de	PRP	de
# jeter	VER:infi	jeter
# nos	DET:POS	notre
# casquettes	NOM	casquette
# par	PRP	par
# terre	NOM	terre
# ,	PUN	,
# afin	KON	afin
# d'	PRP	de
# avoir	VER:infi	avoir
# ensuite	ADV	ensuite
# nos	DET:POS	notre
# mains	NOM	main
# plus	ADV	plus
# libres	ADJ	libre
# ;	PUN	;
# il	PRO:PER	il
# fallait	VER:impf	falloir
# ,	PUN	,
# dès	PRP	dès
# le	DET:ART	le
# seuil	NOM	seuil
# de	PRP	de
# la	DET:ART	le
# porte	NOM	porte
# ,	PUN	,
# les	DET:ART	le
# lancer	NOM	lancer
# sous	PRP	sous
# le	DET:ART	le
# banc	NOM	banc
# ,	PUN	,
# de	PRP	de
# façon	NOM	façon
# à	PRP	à
# frapper	VER:infi	frapper
# contre	PRP	contre
# la	DET:ART	le
# muraille	NOM	muraille
# en	PRP	en
# faisant	VER:ppre	faire
# beaucoup	ADV	beaucoup
# de	PRP	de
# poussière	NOM	poussière
# ;	PUN	;
# c'	PRO:DEM	ce
# était	VER:impf	être
# là	ADV	là
# le	DET:ART	le
# genre	NOM	genre
# .	SENT	.
# Mais	KON	mais
# ,	PUN	,
# soit	KON	soit
# qu'	KON	que
# il	PRO:PER	il
# n'	ADV	ne
# eût	VER:subi	avoir
# pas	ADV	pas
# remarqué	VER:pper	remarquer
# cette	PRO:DEM	ce
# manoeuvre	VER:pres	manuvrer
# ou	KON	ou
# qu'	KON	que
# il	PRO:PER	il
# n'	ADV	ne
# eut	VER:simp	avoir
# osé	VER:pper	oser
# s'	PRO:PER	se
# y	PRO:PER	y
# soumettre	VER:infi	soumettre
# ,	PUN	,
# la	DET:ART	le
# prière	NOM	prière
# était	VER:impf	être
# finie	VER:pper	finir
# que	KON	que
# le	DET:ART	le
# nouveau	ADJ	nouveau
# tenait	VER:impf	tenir
# encore	ADV	encore
# sa	DET:POS	son
# casquette	NOM	casquette
# sur	PRP	sur
# ses	DET:POS	son
# deux	NUM	deux
# genoux	NOM	genou
# .	SENT	.
# C'	PRO:DEM	ce
# était	VER:impf	être
# une	NUM	un
# de	PRP	de
# ces	PRO:DEM	ce
# coiffures	NOM	coiffure
# d'	PRP	de
# ordre	NOM	ordre
# composite	ADJ	composite
# ,	PUN	,
# où	PRO:REL	où
# l'	DET:ART	le
# on	PRO:PER	on
# retrouve	VER:pres	retrouver
# les	DET:ART	le
# éléments	NOM	élément
# du	PRP:det	du
# bonnet	NOM	bonnet
# à	PRP	à
# poil	NOM	poil
# ,	PUN	,
# du	PRP:det	du
# chapska	NOM	chapska
# ,	PUN	,
# du	PRP:det	du
# chapeau	NOM	chapeau
# rond	ADJ	rond
# ,	PUN	,
# de	PRP	de
# la	DET:ART	le
# casquette	NOM	casquette
# de	PRP	de
# loutre	NOM	loutre
# et	KON	et
# du	PRP:det	du
# bonnet	NOM	bonnet
# de	PRP	de
# coton	NOM	coton
# ,	PUN	,
# une	NUM	un
# de	PRP	de
# ces	PRO:DEM	ce
# pauvres	ADJ	pauvre
# choses	NOM	chose
# ,	PUN	,
# enfin	ADV	enfin
# ,	PUN	,
# dont	PRO:REL	dont
# la	DET:ART	le
# laideur	NOM	laideur
# muette	ADJ	muet
# a	VER:pres	avoir
# des	PRP:det	du
# profondeurs	NOM	profondeur
# d'	PRP	de
# expression	NOM	expression
# comme	KON	comme
# le	DET:ART	le
# visage	NOM	visage
# d'	PRP	de
# un	DET:ART	un
# imbécile	NOM	imbécile
# .	SENT	.
# Ovoïde	ADJ	ovoïde
# et	KON	et
# renflée	VER:pper	renfler
# de	PRP	de
# baleines	NOM	baleine
# ,	PUN	,
# elle	PRO:PER	elle
# commençait	VER:impf	commencer
# par	PRP	par
# trois	NUM	trois
# boudins	NOM	boudin
# circulaires	ADJ	circulaire
# ;	PUN	;
# puis	ADV	puis
# s'	PRO:PER	se
# alternaient	VER:impf	alterner
# ,	PUN	,
# séparés	VER:pper	séparer
# par	PRP	par
# une	DET:ART	un
# bande	NOM	bande
# rouge	ADJ	rouge
# ,	PUN	,
# des	PRP:det	du
# losanges	NOM	losange
# de	PRP	de
# velours	NOM	velours
# et	KON	et
# de	PRP	de
# poils	NOM	poil
# de	PRP	de
# lapin	NOM	lapin
# ;	PUN	;
# venait	VER:impf	venir
# ensuite	ADV	ensuite
# une	DET:ART	un
# façon	NOM	façon
# de	PRP	de
# sac	NOM	sac
# qui	PRO:REL	qui
# se	PRO:PER	se
# terminait	VER:impf	terminer
# par	PRP	par
# un	DET:ART	un
# polygone	NOM	polygone
# cartonné	VER:pper	cartonner
# ,	PUN	,
# couvert	VER:pper	couvrir
# d'	PRP	de
# une	DET:ART	un
# broderie	NOM	broderie
# en	PRP	en
# soutache	NOM	soutache
# compliquée	VER:pper	compliquer
# ,	PUN	,
# et	KON	et
# d'	PRP	de
# où	PRO:REL	où
# pendait	VER:impf	pendre
# ,	PUN	,
# au	PRP:det	au
# bout	NOM	bout
# d'	PRP	de
# un	DET:ART	un
# long	ADJ	long
# cordon	NOM	cordon
# trop	ADV	trop
# mince	ADJ	mince
# ,	PUN	,
# un	DET:ART	un
# petit	ADJ	petit
# croisillon	NOM	croisillon
# de	PRP	de
# fils	NOM	fil|fils
# d'	PRP	de
# or	NOM	or
# ,	PUN	,
# en	PRP	en
# manière	NOM	manière
# de	PRP	de
# gland	NOM	gland
# .	SENT	.
# Elle	PRO:PER	elle
# était	VER:impf	être
# neuve	ADJ	neuf
# ;	PUN	;
# la	DET:ART	le
# visière	NOM	visière
# brillait	VER:impf	briller
# .	SENT	.
# --	PUN	--
# Levez	VER:pres	lever
# -vous	PRO:PER	vous
# ,	PUN	,
# dit	VER:pres	dire
# le	DET:ART	le
# professeur	NOM	professeur
# .	SENT	.
# Il	PRO:PER	il
# se	PRO:PER	se
# leva	VER:simp	lever
# ;	PUN	;
# sa	DET:POS	son
# casquette	NOM	casquette
# tomba	VER:simp	tomber
# .	SENT	.
# Toute	PRO:IND	tout
# la	DET:ART	le
# classe	NOM	classe
# se	PRO:PER	se
# mit	VER:simp	mettre
# à	PRP	à
# rire	VER:infi	rire
# .	SENT	.
# Il	PRO:PER	il
# se	PRO:PER	se
# baissa	VER:simp	baisser
# pour	PRP	pour
# la	PRO:PER	la
# reprendre	VER:infi	reprendre
# .	SENT	.
# Un	DET:ART	un
# voisin	NOM	voisin
# la	PRO:PER	la
# fit	VER:simp	faire
# tomber	VER:infi	tomber
# d'	PRP	de
# un	DET:ART	un
# coup	NOM	coup
# de	PRP	de
# coude	NOM	coude
# ,	PUN	,
# il	PRO:PER	il
# la	PRO:PER	la
# ramassa	VER:simp	ramasser
# encore	ADV	encore
# une	DET:ART	un
# fois	NOM	foi|fois
# .	SENT	.
# --	PUN	--
# Débarrassez	VER:pres	débarrasser
# -vous	PRO:PER	vous
# donc	ADV	donc
# de	PRP	de
# votre	DET:POS	votre
# casque	NOM	casque
# ,	PUN	,
# dit	VER:pres	dire
# le	DET:ART	le
# professeur	NOM	professeur
# ,	PUN	,
# qui	PRO:REL	qui
# était	VER:impf	être
# un	DET:ART	un
# homme	NOM	homme
# d'	PRP	de
# esprit	NOM	esprit
# .	SENT	.
# Il	PRO:PER	il
# y	PRO:PER	y
# eut	VER:simp	avoir
# un	DET:ART	un
# rire	NOM	rire
# éclatant	VER:ppre	éclater
# des	PRP:det	du
# écoliers	NOM	écolier
# qui	PRO:REL	qui
# décontenança	VER:simp	décontenancer
# le	DET:ART	le
# pauvre	ADJ	pauvre
# garçon	NOM	garçon
# ,	PUN	,
# si	KON	si
# bien	ADV	bien
# qu'	KON	que
# il	PRO:PER	il
# ne	ADV	ne
# savait	VER:impf	savoir
# s'	PRO:PER	se
# il	PRO:PER	il
# fallait	VER:impf	falloir
# garder	VER:infi	garder
# sa	DET:POS	son
# casquette	NOM	casquette
# à	PRP	à
# la	DET:ART	le
# main	NOM	main
# ,	PUN	,
# la	PRO:PER	la
# laisser	VER:infi	laisser
# par	PRP	par
# terre	NOM	terre
# ou	KON	ou
# la	PRO:PER	la
# mettre	VER:infi	mettre
# sur	PRP	sur
# sa	DET:POS	son
# tête	NOM	tête
# .	SENT	.
# Il	PRO:PER	il
# se	PRO:PER	se
# rassit	VER:pres	rassir
# et	KON	et
# la	PRO:PER	la
# posa	VER:simp	poser
# sur	PRP	sur
# ses	DET:POS	son
# genoux	NOM	genou
# .	SENT	.
# --	PUN	--
# Levez	VER:pres	lever
# -vous	PRO:PER	vous
# ,	PUN	,
# reprit	VER:simp	reprendre
# le	DET:ART	le
# professeur	NOM	professeur
# ,	PUN	,
# et	KON	et
# dites	VER:pres	dire
# -moi	PRO:PER	moi
# votre	DET:POS	votre
# nom	NOM	nom
# .	SENT	.
# Le	DET:ART	le
# nouveau	NOM	nouveau
# articula	VER:simp	articuler
# ,	PUN	,
# d'	PRP	de
# une	DET:ART	un
# voix	NOM	voix
# bredouillante	ADJ	bredouillant
# ,	PUN	,
# un	DET:ART	un
# nom	NOM	nom
# inintelligible	ADJ	inintelligible
# .	SENT	.
# --	PUN	--
# Répétez	NAM	<unknown>
# !	SENT	!
# Le	DET:ART	le
# même	ADJ	même
# bredouillement	NOM	bredouillement
# de	PRP	de
# syllabes	NOM	syllabe
# se	PRO:PER	se
# fit	VER:simp	faire
# entendre	VER:infi	entendre
# ,	PUN	,
# couvert	VER:pper	couvrir
# par	PRP	par
# les	DET:ART	le
# huées	NOM	huée
# de	PRP	de
# la	DET:ART	le
# classe	NOM	classe
# .	SENT	.
# --	PUN	--
# Plus	NOM	<unknown>
# haut	ADJ	haut
# !	SENT	!
# cria	VER:simp	crier
# le	DET:ART	le
# maître	NOM	maître
# ,	PUN	,
# plus	ADV	plus
# haut	ADJ	haut
# !	SENT	!
# Le	DET:ART	le
# nouveau	ADJ	nouveau
# ,	PUN	,
# prenant	VER:ppre	prendre
# alors	ADV	alors
# une	DET:ART	un
# résolution	NOM	résolution
# extrême	ADJ	extrême
# ,	PUN	,
# ouvrit	VER:simp	ouvrir
# une	DET:ART	un
# bouche	NOM	bouche
# démesurée	ADJ	démesuré
# et	KON	et
# lança	VER:simp	lancer
# à	PRP	à
# pleins	ADJ	plein
# poumons	NOM	poumon
# ,	PUN	,
# comme	ADV	comme
# pour	PRP	pour
# appeler	VER:infi	appeler
# quelqu'un	PRO:IND	quelqu'un
# ,	PUN	,
# ce	PRO:DEM	ce
# mot	NOM	mot
# :	PUN	:
# Charbovari	NOM	<unknown>
# .	SENT	.
# Ce	PRO:DEM	ce
# fut	VER:simp	être
# un	DET:ART	un
# vacarme	NOM	vacarme
# qui	PRO:REL	qui
# s'	PRO:PER	se
# élança	VER:simp	élancer
# d'	PRP	de
# un	DET:ART	un
# bond	NOM	bond
# ,	PUN	,
# monta	VER:simp	monter
# en	PRP	en
# crescendo	ADV	crescendo
# ,	PUN	,
# avec	PRP	avec
# des	PRP:det	du
# éclats	NOM	éclat
# de	PRP	de
# voix	NOM	voix
# aigus	ADJ	aigu
# (	PUN	(
# on	PRO:PER	on
# hurlait	VER:impf	hurler
# ,	PUN	,
# on	PRO:PER	on
# aboyait	VER:impf	aboyer
# ,	PUN	,
# on	PRO:PER	on
# trépignait	VER:impf	trépigner
# ,	PUN	,
# on	PRO:PER	on
# répétait	VER:impf	répéter
# :	PUN	:
# Charbovari	NOM	<unknown>
# !	SENT	!
# Charbovari	NOM	<unknown>
# !	SENT	!
# )	PUN	)
# ,	PUN	,
# puis	ADV	puis
# qui	PRO:REL	qui
# roula	VER:simp	rouler
# en	PRP	en
# notes	NOM	note
# isolées	ADJ	isolé
# ,	PUN	,
# se	PRO:PER	se
# calmant	VER:ppre	calmer
# à	PRP	à
# grand-peine	ADV	grand-peine
# ,	PUN	,
# et	KON	et
# parfois	ADV	parfois
# qui	PRO:REL	qui
# reprenait	VER:impf	reprendre
# tout	ADV	tout
# à	PRP	à
# coup	NOM	coup
# sur	PRP	sur
# la	DET:ART	le
# ligne	NOM	ligne
# d'	PRP	de
# un	DET:ART	un
# banc	NOM	banc
# où	PRO:REL	où
# saillissait	VER:impf	<unknown>
# encore	ADV	encore
# çà	ADV	çà
# et	KON	et
# là	ADV	là
# ,	PUN	,
# comme	KON	comme
# un	DET:ART	un
# pétard	NOM	pétard
# mal	ADV	mal
# éteint	VER:pper	éteindre
# ,	PUN	,
# quelque	PRO:IND	quelque
# rire	NOM	rire
# étouffé	VER:pper	étouffer
# .	SENT	.
# Cependant	ADV	cependant
# ,	PUN	,
# sous	PRP	sous
# la	DET:ART	le
# pluie	NOM	pluie
# des	PRP:det	du
# pensums	NOM	pensum
# ,	PUN	,
# l'	DET:ART	le
# ordre	NOM	ordre
# peu	ADV	peu
# à	PRP	à
# peu	ADV	peu
# se	PRO:PER	se
# rétablit	VER:pres	rétablir
# dans	PRP	dans
# la	DET:ART	le
# classe	NOM	classe
# ,	PUN	,
# et	KON	et
# le	DET:ART	le
# professeur	NOM	professeur
# ,	PUN	,
# parvenu	VER:pper	parvenir
# à	PRP	à
# saisir	VER:infi	saisir
# le	DET:ART	le
# nom	NOM	nom
# de	PRP	de
# Charles	NAM	Charles
# Bovary	NAM	<unknown>
# ,	PUN	,
# se	PRO:PER	se
# l'	PRO:PER	la|le
# étant	VER:ppre	être
# fait	VER:pper	faire
# dicter	VER:infi	dicter
# ,	PUN	,
# épeler	VER:infi	épeler
# et	KON	et
# relire	VER:infi	relire
# ,	PUN	,
# commanda	VER:simp	commander
# tout	ADV	tout
# de	PRP	de
# suite	NOM	suite
# au	PRP:det	au
# pauvre	ADJ	pauvre
# diable	NOM	diable
# d'	PRP	de
# aller	VER:infi	aller
# s'	PRO:PER	se
# asseoir	VER:infi	asseoir
# sur	PRP	sur
# le	DET:ART	le
# banc	NOM	banc
# de	PRP	de
# paresse	NOM	paresse
# ,	PUN	,
# au	PRP:det	au
# pied	NOM	pied
# de	PRP	de
# la	DET:ART	le
# chaire	NOM	chaire
# .	SENT	.
# Il	PRO:PER	il
# se	PRO:PER	se
# mit	VER:simp	mettre
# en	PRP	en
# mouvement	NOM	mouvement
# ,	PUN	,
# mais	KON	mais
# ,	PUN	,
# avant	PRP	avant
# de	PRP	de
# partir	VER:infi	partir
# ,	PUN	,
# hésita	VER:simp	hésiter
# .	SENT	.
# --	PUN	--
# Que	NAM	<unknown>
# cherchez	VER:pres	chercher
# -vous	PRO:PER	vous
# ?	SENT	?
# demanda	VER:simp	demander
# le	DET:ART	le
# professeur	NOM	professeur
# .	SENT	.
# --	PUN	--
# Ma	VER:simp	<unknown>
# cas	NOM	cas
# ...	PUN	...
# fit	VER:simp	faire
# timidement	ADV	timidement
# le	DET:ART	le
# nouveau	ADJ	nouveau
# ,	PUN	,
# promenant	VER:ppre	promener
# autour	ADV	autour
# de	PRP	de
# lui	PRO:PER	lui
# des	PRP:det	du
# regards	NOM	regard
# inquiets	ADJ	inquiet
# .	SENT	.
# --	PUN	--
# Cinq	NAM	<unknown>
# cents	NOM	cent
# vers	PRP	vers
# à	PRP	à
# toute	PRO:IND	tout
# la	DET:ART	le
# classe	NOM	classe
# !	SENT	!
# exclamé	VER:pper	exclamer
# d'	PRP	de
# une	DET:ART	un
# voix	NOM	voix
# furieuse	ADJ	furieux
# ,	PUN	,
# arrêta	VER:simp	arrêter
# ,	PUN	,
# comme	KON	comme
# le	DET:ART	le
# _Quos	NOM	<unknown>
# ego_	NOM	<unknown>
# ,	PUN	,
# une	DET:ART	un
# bourrasque	NOM	bourrasque
# nouvelle	ADJ	nouveau
# .	SENT	.
# --	PUN	--
# Restez	VER:pres	rester
# donc	ADV	donc
# tranquilles	ADJ	tranquille
# !	SENT	!
# continuait	VER:impf	continuer
# le	DET:ART	le
# professeur	NOM	professeur
# indigné	ADJ	indigné
# ,	PUN	,
# et	KON	et
# s'	PRO:PER	se
# essuyant	VER:ppre	essuyer
# le	DET:ART	le
# front	NOM	front
# avec	PRP	avec
# son	DET:POS	son
# mouchoir	NOM	mouchoir
# qu'	PRO:REL	que
# il	PRO:PER	il
# venait	VER:impf	venir
# de	PRP	de
# prendre	VER:infi	prendre
# dans	PRP	dans
# sa	DET:POS	son
# toque	NOM	toque
# :	PUN	:
# Quant	PRP	quant
# à	PRP	à
# vous	PRO:PER	vous
# ,	PUN	,
# le	DET:ART	le
# nouveau	ADJ	nouveau
# ,	PUN	,
# vous	PRO:PER	vous
# me	PRO:PER	me
# copierez	VER:futu	copier
# vingt	NUM	vingt
# fois	NOM	foi|fois
# le	DET:ART	le
# verbe	NOM	verbe
# _ridiculus	NOM	<unknown>
# sum_	ADJ	<unknown>
# .	SENT	.
# Puis	ADV	puis
# ,	PUN	,
# d'	PRP	de
# une	DET:ART	un
# voix	NOM	voix
# plus	ADV	plus
# douce	ADJ	doux
# :	PUN	:
# --	PUN	--
# Eh	NAM	<unknown>
# !	SENT	!
# vous	PRO:PER	vous
# la	PRO:PER	la
# retrouverez	VER:futu	retrouver
# ,	PUN	,
# votre	DET:POS	votre
# casquette	NOM	casquette
# ;	PUN	;
# on	PRO:PER	on
# ne	ADV	ne
# vous	PRO:PER	vous
# l'	PRO:PER	la|le
# a	VER:pres	avoir
# pas	ADV	pas
# volée	VER:pper	voler
# !	SENT	!
# Tout	PRO:IND	tout
# reprit	VER:simp	reprendre
# son	DET:POS	son
# calme	NOM	calme
# .	SENT	.
# Les	DET:ART	le
# têtes	NOM	tête
# se	PRO:PER	se
# courbèrent	VER:simp	courber
# sur	PRP	sur
# les	DET:ART	le
# cartons	NOM	carton
# ,	PUN	,
# et	KON	et
# le	DET:ART	le
# nouveau	NOM	nouveau
# resta	VER:simp	rester
# pendant	PRP	pendant
# deux	NUM	deux
# heures	NOM	heure
# dans	PRP	dans
# une	DET:ART	un
# tenue	NOM	tenue
# exemplaire	ADJ	exemplaire
# ,	PUN	,
# quoiqu'il	ADJ	<unknown>
# y	PRO:PER	y
# eût	VER:subi	avoir
# bien	ADV	bien
# ,	PUN	,
# de	PRP	de
# temps	NOM	temps
# à	PRP	à
# autre	ADJ	autre
# ,	PUN	,
# quelque	PRO:IND	quelque
# boulette	NOM	boulette
# de	PRP	de
# papier	NOM	papier
# lancée	VER:pper	lancer
# d'	PRP	de
# un	DET:ART	un
# bec	NOM	bec
# de	PRP	de
# plume	NOM	plume
# qui	PRO:REL	qui
# vînt	VER:subi	venir
# s'	PRO:PER	se
# éclabousser	VER:infi	éclabousser
# sur	PRP	sur
# sa	DET:POS	son
# figure	NOM	figure
# .	SENT	.
# Mais	KON	mais
# il	PRO:PER	il
# s'	PRO:PER	se
# essuyait	VER:impf	essuyer
# avec	PRP	avec
# la	DET:ART	le
# main	NOM	main
# ,	PUN	,
# et	KON	et
# demeurait	VER:impf	demeurer
# immobile	ADJ	immobile
# ,	PUN	,
# les	DET:ART	le
# yeux	NOM	il
# baissés	VER:pper	baisser
# .	SENT	.
# Le	DET:ART	le
# soir	NOM	soir
# ,	PUN	,
# à	PRP	à
# l'	DET:ART	le
# Étude	NOM	étude
# ,	PUN	,
# il	PRO:PER	il
# tira	VER:simp	tirer
# ses	DET:POS	son
# bouts	NOM	bout
# de	PRP	de
# manches	NOM	manche
# de	PRP	de
# son	DET:POS	son
# pupitre	NOM	pupitre
# ,	PUN	,
# mit	VER:simp	mettre
# en	PRP	en
# ordre	NOM	ordre
# ses	DET:POS	son
# petites	ADJ	petit
# affaires	NOM	affaire
# ,	PUN	,
# régla	VER:simp	régler
# soigneusement	ADV	soigneusement
# son	DET:POS	son
# papier	NOM	papier
# .	SENT	.
# Nous	PRO:PER	nous
# le	PRO:PER	le
# vîmes	VER:simp	voir
# qui	PRO:REL	qui
# travaillait	VER:impf	travailler
# en	PRP	en
# conscience	NOM	conscience
# ,	PUN	,
# cherchant	VER:ppre	chercher
# tous	PRO:IND	tout
# les	DET:ART	le
# mots	NOM	mot
# dans	PRP	dans
# le	DET:ART	le
# dictionnaire	NOM	dictionnaire
# et	KON	et
# se	PRO:PER	se
# donnant	VER:ppre	donner
# beaucoup	ADV	beaucoup
# de	PRP	de
# mal	NOM	mal
# .	SENT	.
# Grâce	NOM	grâce
# ,	PUN	,
# sans	PRP	sans
# doute	NOM	doute
# ,	PUN	,
# à	PRP	à
# cette	PRO:DEM	ce
# bonne	ADJ	bon
# volonté	NOM	volonté
# dont	PRO:REL	dont
# il	PRO:PER	il
# fit	VER:simp	faire
# preuve	NOM	preuve
# ,	PUN	,
# il	PRO:PER	il
# dut	VER:simp	devoir
# de	PRP	de
# ne	ADV	ne
# pas	ADV	pas
# descendre	VER:infi	descendre
# dans	PRP	dans
# la	DET:ART	le
# classe	NOM	classe
# inférieure	ADJ	inférieur
# ;	PUN	;
# car	KON	car
# ,	PUN	,
# s'	PRO:PER	se
# il	PRO:PER	il
# savait	VER:impf	savoir
# passablement	ADV	passablement
# ses	DET:POS	son
# règles	NOM	règle|règles
# ,	PUN	,
# il	PRO:PER	il
# n'	ADV	ne
# avait	VER:impf	avoir
# guère	ADV	guère
# d'	PRP	de
# élégance	NOM	élégance
# dans	PRP	dans
# les	DET:ART	le
# tournures	NOM	tournure
# .	SENT	.
# C'	PRO:DEM	ce
# était	VER:impf	être
# le	DET:ART	le
# curé	NOM	curé
# de	PRP	de
# son	DET:POS	son
# village	NOM	village
# qui	PRO:REL	qui
# lui	PRO:PER	lui
# avait	VER:impf	avoir
# commencé	VER:pper	commencer
# le	DET:ART	le
# latin	NOM	latin
# ,	PUN	,
# ses	DET:POS	son
# parents	NOM	parent|parents
# ,	PUN	,
# par	PRP	par
# économie	NOM	économie
# ,	PUN	,
# ne	ADV	ne
# l'	PRO:PER	la|le
# ayant	VER:ppre	avoir
# envoyé	VER:pper	envoyer
# au	PRP:det	au
# collège	NOM	collège
# que	KON	que
# le	DET:ART	le
# plus	ADV	plus
# tard	ADV	tard
# possible	ADJ	possible
# .	SENT	.
# Son	DET:POS	son
# père	NOM	père
# ,	PUN	,
# M.	NOM	monsieur
# Charles-Denis-Bartholomé	NAM	<unknown>
# Bovary	NAM	<unknown>
# ,	PUN	,
# ancien	ADJ	ancien
# aide-	NOM	<unknown>
# chirurgien-major	NOM	<unknown>
# ,	PUN	,
# compromis	VER:pper	compromettre
# ,	PUN	,
# vers	PRP	vers
# 1812	NUM	@card@
# ,	PUN	,
# dans	PRP	dans
# des	PRP:det	du
# affaires	NOM	affaire
# de	PRP	de
# conscription	NOM	conscription
# ,	PUN	,
# et	KON	et
# forcé	VER:pper	forcer
# ,	PUN	,
# vers	PRP	vers
# cette	PRO:DEM	ce
# époque	NOM	époque
# ,	PUN	,
# de	PRP	de
# quitter	VER:infi	quitter
# le	DET:ART	le
# service	NOM	service
# ,	PUN	,
# avait	VER:impf	avoir
# alors	ADV	alors
# profité	VER:pper	profiter
# de	PRP	de
# ses	DET:POS	son
# avantages	NOM	avantage
# personnels	ADJ	personnel
# pour	PRP	pour
# saisir	VER:infi	saisir
# au	PRP:det	au
# passage	NOM	passage
# une	DET:ART	un
# dot	NOM	dot
# de	PRP	de
# soixante	NUM	soixante
# mille	NUM	mille
# francs	NOM	franc
# ,	PUN	,
# qui	PRO:REL	qui
# s'	PRO:PER	se
# offrait	VER:impf	offrir
# en	PRP	en
# la	DET:ART	le
# fille	NOM	fille
# d'	PRP	de
# un	DET:ART	un
# marchand	ADJ	marchand
# bonnetier	NOM	bonnetier
# ,	PUN	,
# devenue	VER:pper	devenir
# amoureuse	ADJ	amoureux
# de	PRP	de
# sa	DET:POS	son
# tournure	NOM	tournure
# .	SENT	.
# Bel	ADJ	beau
# homme	NOM	homme
# ,	PUN	,
# hâbleur	ADJ	hâbleur
# ,	PUN	,
# faisant	VER:ppre	faire
# sonner	VER:infi	sonner
# haut	ADV	haut
# ses	DET:POS	son
# éperons	NOM	éperon
# ,	PUN	,
# portant	VER:ppre	porter
# des	PRP:det	du
# favoris	NOM	favori
# rejoints	VER:pper	rejoindre
# aux	PRP:det	au
# moustaches	NOM	moustache
# ,	PUN	,
# les	DET:ART	le
# doigts	NOM	doigt
# toujours	ADV	toujours
# garnis	VER:pper	garnir
# de	PRP	de
# bagues	NOM	bague|bagues
# et	KON	et
# habillé	VER:pper	habiller
# de	PRP	de
# couleurs	NOM	couleur
# voyantes	ADJ	voyant
# ,	PUN	,
# il	PRO:PER	il
# avait	VER:impf	avoir
# l'	DET:ART	le
# aspect	NOM	aspect
# d'	PRP	de
# un	DET:ART	un
# brave	ADJ	brave
# ,	PUN	,
# avec	PRP	avec
# l'	DET:ART	le
# entrain	NOM	entrain
# facile	ADJ	facile
# d'	PRP	de
# un	DET:ART	un
# commis	NOM	commis
# voyageur	ADJ	voyageur
# .	SENT	.
# Une	DET:ART	un
# fois	NOM	foi|fois
# marié	VER:pper	marier
# ,	PUN	,
# il	PRO:PER	il
# vécut	VER:simp	vivre
# deux	NUM	deux
# ou	KON	ou
# trois	NUM	trois
# ans	NOM	an
# sur	PRP	sur
# la	DET:ART	le
# fortune	NOM	fortune
# de	PRP	de
# sa	DET:POS	son
# femme	NOM	femme
# ,	PUN	,
# dînant	VER:ppre	dîner
# bien	ADV	bien
# ,	PUN	,
# se	PRO:PER	se
# levant	VER:ppre	lever
# tard	ADV	tard
# ,	PUN	,
# fumant	VER:ppre	fumer
# dans	PRP	dans
# de	PRP	de
# grandes	ADJ	grand
# pipes	NOM	pipe
# en	PRP	en
# porcelaine	NOM	porcelaine
# ,	PUN	,
# ne	ADV	ne
# rentrant	VER:ppre	rentrer
# le	DET:ART	le
# soir	NOM	soir
# qu'	KON	que
# après	PRP	après
# le	DET:ART	le
# spectacle	NOM	spectacle
# et	KON	et
# fréquentant	VER:ppre	fréquenter
# les	DET:ART	le
# cafés	NOM	café
# .	SENT	.
# Le	DET:ART	le
# beau-père	NOM	beau-père
# mourut	VER:simp	mourir
# et	KON	et
# laissa	VER:simp	laisser
# peu	ADV	peu
# de	PRP	de
# chose	NOM	chose
# ;	PUN	;
# il	PRO:PER	il
# en	PRO:PER	en
# fut	VER:simp	être
# indigné	VER:pper	indigner
# ,	PUN	,
# se	PRO:PER	se
# lança	VER:simp	lancer
# dans	PRP	dans
# la	DET:ART	le
# fabrique	NOM	fabrique
# ,	PUN	,
# y	PRO:PER	y
# perdit	VER:simp	perdre
# quelque	PRO:IND	quelque
# argent	NOM	argent
# ,	PUN	,
# puis	ADV	puis
# se	PRO:PER	se
# retira	VER:simp	retirer
# dans	PRP	dans
# la	DET:ART	le
# campagne	NOM	campagne
# ,	PUN	,
# où	PRO:REL	où
# il	PRO:PER	il
# voulut	VER:simp	vouloir
# faire	VER:infi	faire
# valoir	VER:infi	valoir
# .	SENT	.
# Mais	KON	mais
# ,	PUN	,
# comme	KON	comme
# il	PRO:PER	il
# ne	ADV	ne
# s'	PRO:PER	se
# entendait	VER:impf	entendre
# guère	ADV	guère
# plus	ADV	plus
# en	PRP	en
# culture	NOM	culture
# qu'	KON	que
# en	PRP	en
# indiennes	NOM	indien|indienne
# ,	PUN	,
# qu'	PRO:REL	que
# il	PRO:PER	il
# montait	VER:impf	monter
# ses	DET:POS	son
# chevaux	NOM	cheval
# au	PRP:det	au
# lieu	NOM	lieu
# de	PRP	de
# les	PRO:PER	la|le
# envoyer	VER:infi	envoyer
# au	PRP:det	au
# labour	NOM	labour
# ,	PUN	,
# buvait	VER:impf	boire
# son	DET:POS	son
# cidre	NOM	cidre
# en	PRP	en
# bouteilles	NOM	bouteille
# au	PRP:det	au
# lieu	NOM	lieu
# de	PRP	de
# le	PRO:PER	le
# vendre	VER:infi	vendre
# en	PRP	en
# barriques	NOM	barrique
# ,	PUN	,
# mangeait	VER:impf	manger
# les	DET:ART	le
# plus	ADV	plus
# belles	ADJ	beau
# volailles	NOM	volaille
# de	PRP	de
# sa	DET:POS	son
# cour	NOM	cour
# et	KON	et
# graissait	VER:impf	graisser
# ses	DET:POS	son
# souliers	NOM	soulier
# de	PRP	de
# chasse	NOM	chasse
# avec	PRP	avec
# le	DET:ART	le
# lard	NOM	lard
# de	PRP	de
# ses	DET:POS	son
# cochons	NOM	cochon
# ,	PUN	,
# il	PRO:PER	il
# ne	ADV	ne
# tarda	VER:simp	tarder
# point	ADV	point
# à	PRP	à
# s'	PRO:PER	se
# apercevoir	VER:infi	apercevoir
# qu'	KON	que
# il	PRO:PER	il
# valait	VER:impf	valoir
# mieux	ADV	mieux
# planter	VER:infi	planter
# là	ADV	là
# toute	PRO:IND	tout
# spéculation	NOM	spéculation
# .	SENT	.
# Moyennant	PRP	moyennant
# deux	NUM	deux
# cents	NOM	cent
# francs	ADJ	franc
# par	PRP	par
# an	NOM	an
# ,	PUN	,
# il	PRO:PER	il
# trouva	VER:simp	trouver
# donc	ADV	donc
# à	PRP	à
# louer	VER:infi	louer
# dans	PRP	dans
# un	DET:ART	un
# village	NOM	village
# ,	PUN	,
# sur	PRP	sur
# les	DET:ART	le
# confins	NOM	confins
# du	PRP:det	du
# pays	NOM	pays
# de	PRP	de
# Caux	NAM	<unknown>
# et	KON	et
# de	PRP	de
# la	DET:ART	le
# Picardie	NAM	Picardie
# ,	PUN	,
# une	DET:ART	un
# sorte	NOM	sorte
# de	PRP	de
# logis	NOM	logis
# moitié	NOM	moitié
# ferme	ADJ	ferme
# ,	PUN	,
# moitié	NOM	moitié
# maison	NOM	maison
# de	PRP	de
# maître	NOM	maître
# ;	PUN	;
# et	KON	et
# ,	PUN	,
# chagrin	ADJ	chagrin
# ,	PUN	,
# rongé	VER:pper	ronger
# de	PRP	de
# regrets	NOM	regret
# ,	PUN	,
# accusant	VER:ppre	accuser
# le	DET:ART	le
# ciel	NOM	ciel
# ,	PUN	,
# jaloux	ADJ	jaloux
# contre	PRP	contre
# tout	PRO:IND	tout
# le	DET:ART	le
# monde	NOM	monde
# ,	PUN	,
# il	PRO:PER	il
# s'	PRO:PER	se
# enferma	VER:simp	enfermer
# dès	PRP	dès
# l'	DET:ART	le
# âge	NOM	âge
# de	PRP	de
# quarante-cinq	NUM	quarante-cinq
# ans	NOM	an
# ,	PUN	,
# dégoûté	VER:pper	dégoûter
# des	PRP:det	du
# hommes	NOM	homme
# ,	PUN	,
# disait	VER:impf	dire
# -il	PRO:PER	il
# ,	PUN	,
# et	KON	et
# décidé	VER:pper	décider
# à	PRP	à
# vivre	VER:infi	vivre
# en	PRP	en
# paix	NOM	paix
# .	SENT	.
# Sa	DET:POS	son
# femme	NOM	femme
# avait	VER:impf	avoir
# été	VER:pper	être
# folle	ADJ	folle|fou
# de	PRP	de
# lui	PRO:PER	lui
# autrefois	ADV	autrefois
# ;	PUN	;
# elle	PRO:PER	elle
# l'	PRO:PER	la|le
# avait	VER:impf	avoir
# aimé	VER:pper	aimer
# avec	PRP	avec
# mille	NUM	mille
# servilités	NOM	servilité
# qui	PRO:REL	qui
# l'	PRO:PER	la|le
# avaient	VER:impf	avoir
# détaché	VER:pper	détacher
# d'	PRP	de
# elle	PRO:PER	elle
# encore	ADV	encore
# davantage	ADV	davantage
# .	SENT	.
# Enjouée	ADJ	enjoué
# jadis	ADV	jadis
# ,	PUN	,
# expansive	ADJ	expansif
# et	KON	et
# tout	ADV	tout
# aimante	ADJ	aimant
# ,	PUN	,
# elle	PRO:PER	elle
# était	VER:impf	être
# ,	PUN	,
# en	PRO:PER	en
# vieillissant	VER:ppre	vieillir
# ,	PUN	,
# devenue	VER:pper	devenir
# (	PUN	(
# à	PRP	à
# la	DET:ART	le
# façon	NOM	façon
# du	PRP:det	du
# vin	NOM	vin
# éventé	ADJ	éventé
# qui	PRO:REL	qui
# se	PRO:PER	se
# tourne	VER:pres	tourner
# en	PRP	en
# vinaigre	NOM	vinaigre
# )	PUN	)
# d'	PRP	de
# humeur	NOM	humeur
# difficile	ADJ	difficile
# ,	PUN	,
# piaillarde	ADJ	piaillard
# ,	PUN	,
# nerveuse	ADJ	nerveux
# .	SENT	.
# Elle	PRO:PER	elle
# avait	VER:impf	avoir
# tant	ADV	tant
# souffert	VER:pper	souffrir
# ,	PUN	,
# sans	PRP	sans
# se	PRO:PER	se
# plaindre	VER:infi	plaindre
# ,	PUN	,
# d'abord	ADV	d'abord
# ,	PUN	,
# quand	KON	quand
# elle	PRO:PER	elle
# le	PRO:PER	le
# voyait	VER:impf	voir
# courir	VER:infi	courir
# après	PRP	après
# toutes	PRO:IND	tout
# les	DET:ART	le
# gotons	NOM	goton
# de	PRP	de
# village	NOM	village
# et	KON	et
# que	KON	que
# vingt	NUM	vingt
# mauvais	ADJ	mauvais
# lieux	NOM	lieu
# le	PRO:PER	le
# lui	PRO:PER	lui
# renvoyaient	VER:impf	renvoyer
# le	DET:ART	le
# soir	NOM	soir
# ,	PUN	,
# blasé	ADJ	blasé
# et	KON	et
# puant	VER:ppre	puer
# l'	DET:ART	le
# ivresse	NOM	ivresse
# !	SENT	!
# Puis	ADV	puis
# l'	DET:ART	le
# orgueil	NOM	orgueil
# s'	PRO:PER	se
# était	VER:impf	être
# révolté	VER:pper	révolter
# .	SENT	.
# Alors	ADV	alors
# elle	PRO:PER	elle
# s'	PRO:PER	se
# était	VER:impf	être
# tue	VER:pper	taire
# ,	PUN	,
# avalant	VER:ppre	avaler
# sa	DET:POS	son
# rage	NOM	rage
# dans	PRP	dans
# un	DET:ART	un
# stoïcisme	NOM	stoïcisme
# muet	ADJ	muet
# ,	PUN	,
# qu'	PRO:REL	que
# elle	PRO:PER	elle
# garda	VER:simp	garder
# jusqu'	PRP	jusque
# à	PRP	à
# sa	DET:POS	son
# mort	NOM	mort
# .	SENT	.
# Elle	PRO:PER	elle
# était	VER:impf	être
# sans	PRP	sans
# cesse	NOM	cesse
# en	PRP	en
# courses	NOM	course
# ,	PUN	,
# en	PRP	en
# affaires	NOM	affaire
# .	SENT	.
# Elle	PRO:PER	elle
# allait	VER:impf	aller
# chez	PRP	chez
# les	DET:ART	le
# avoués	NOM	avoué
# ,	PUN	,
# chez	PRP	chez
# le	DET:ART	le
# président	NOM	président
# ,	PUN	,
# se	PRO:PER	se
# rappelait	VER:impf	rappeler
# l'	DET:ART	le
# échéance	NOM	échéance
# des	PRP:det	du
# billets	NOM	billet
# ,	PUN	,
# obtenait	VER:impf	obtenir
# des	PRP:det	du
# retards	NOM	retard
# ;	PUN	;
# et	KON	et
# ,	PUN	,
# à	PRP	à
# la	DET:ART	le
# maison	NOM	maison
# ,	PUN	,
# repassait	VER:impf	repasser
# ,	PUN	,
# cousait	VER:impf	coudre
# ,	PUN	,
# blanchissait	VER:impf	blanchir
# ,	PUN	,
# surveillait	VER:impf	surveiller
# les	DET:ART	le
# ouvriers	NOM	ouvrier
# ,	PUN	,
# soldait	VER:impf	solder
# les	DET:ART	le
# mémoires	NOM	mémoire
# ,	PUN	,
# tandis	KON	tandis
# que	KON	que
# ,	PUN	,
# sans	PRP	sans
# s'	PRO:PER	se
# inquiéter	VER:infi	inquiéter
# de	PRP	de
# rien	NOM	rien
# ,	PUN	,
# Monsieur	NOM	monsieur
# ,	PUN	,
# continuellement	ADV	continuellement
# engourdi	VER:pper	engourdir
# dans	PRP	dans
# une	DET:ART	un
# somnolence	NOM	somnolence
# boudeuse	ADJ	boudeur
# dont	PRO:REL	dont
# il	PRO:PER	il
# ne	ADV	ne
# se	PRO:PER	se
# réveillait	VER:impf	réveiller
# que	KON	que
# pour	PRP	pour
# lui	PRO:PER	lui
# dire	VER:infi	dire
# des	PRP:det	du
# choses	NOM	chose
# désobligeantes	ADJ	désobligeant
# ,	PUN	,
# restait	VER:impf	rester
# à	PRP	à
# fumer	VER:infi	fumer
# au	PRP:det	au
# coin	NOM	coin
# du	PRP:det	du
# feu	NOM	feu
# ,	PUN	,
# en	PRO:PER	en
# crachant	VER:ppre	cracher
# dans	PRP	dans
# les	DET:ART	le
# cendres	NOM	cendre
# .	SENT	.
# Quand	KON	quand
# elle	PRO:PER	elle
# eut	VER:simp	avoir
# un	DET:ART	un
# enfant	NOM	enfant
# ,	PUN	,
# il	PRO:PER	il
# le	PRO:PER	le
# fallut	VER:simp	falloir
# mettre	VER:infi	mettre
# en	PRP	en
# nourrice	NOM	nourrice
# .	SENT	.
# Rentré	VER:pper	rentrer
# chez	PRP	chez
# eux	PRO:PER	eux
# ,	PUN	,
# le	DET:ART	le
# marmot	NOM	marmot
# fut	VER:simp	être
# gâté	VER:pper	gâter
# comme	ADV	comme
# un	DET:ART	un
# prince	NOM	prince
# .	SENT	.
# Sa	DET:POS	son
# mère	NOM	mère
# le	PRO:PER	le
# nourrissait	VER:impf	nourrir
# de	PRP	de
# confitures	NOM	confiture
# ;	PUN	;
# son	DET:POS	son
# père	NOM	père
# le	PRO:PER	le
# laissait	VER:impf	laisser
# courir	VER:infi	courir
# sans	PRP	sans
# souliers	NOM	soulier
# ,	PUN	,
# et	KON	et
# ,	PUN	,
# pour	PRP	pour
# faire	VER:infi	faire
# le	DET:ART	le
# philosophe	NOM	philosophe
# ,	PUN	,
# disait	VER:impf	dire
# même	ADV	même
# qu'	KON	que
# il	PRO:PER	il
# pouvait	VER:impf	pouvoir
# bien	ADV	bien
# aller	VER:infi	aller
# tout	PRO:IND	tout
# nu	NOM	nu
# ,	PUN	,
# comme	KON	comme
# les	DET:ART	le
# enfants	NOM	enfant
# des	PRP:det	du
# bêtes	NOM	bête
# .	SENT	.
# À	PRP	à
# l'	DET:ART	le
# encontre	ADV	encontre
# des	PRP:det	du
# tendances	NOM	tendance
# maternelles	ADJ	maternel
# ,	PUN	,
# il	PRO:PER	il
# avait	VER:impf	avoir
# en	PRP	en
# tête	NOM	tête
# un	DET:ART	un
# certain	ADJ	certain
# idéal	NOM	idéal
# viril	ADJ	viril
# de	PRP	de
# l'	DET:ART	le
# enfance	NOM	enfance
# ,	PUN	,
# d'après	ADV	d'après
# lequel	PRO:REL	lequel
# il	PRO:PER	il
# tâchait	VER:impf	tâcher
# de	PRP	de
# former	VER:infi	former
# son	DET:POS	son
# fils	NOM	fil|fils
# ,	PUN	,
# voulant	VER:ppre	vouloir
# qu'	KON	que
# on	PRO:PER	on
# l'	PRO:PER	la|le
# élevât	VER:subi	élever
# durement	ADV	durement
# ,	PUN	,
# à	PRP	à
# la	DET:ART	le
# spartiate	NOM	spartiate
# ,	PUN	,
# pour	PRP	pour
# lui	PRO:PER	lui
# faire	VER:infi	faire
# une	DET:ART	un
# bonne	ADJ	bon
# constitution	NOM	constitution
# .	SENT	.
# Il	PRO:PER	il
# l'	PRO:PER	la|le
# envoyait	VER:impf	envoyer
# se	PRO:PER	se
# coucher	VER:infi	coucher
# sans	PRP	sans
# feu	NOM	feu
# ,	PUN	,
# lui	PRO:PER	lui
# apprenait	VER:impf	apprendre
# à	PRP	à
# boire	VER:infi	boire
# de	PRP	de
# grands	ADJ	grand
# coups	NOM	coup
# de	PRP	de
# rhum	NOM	rhum
# et	KON	et
# à	PRP	à
# insulter	VER:infi	insulter
# les	DET:ART	le
# processions	NOM	procession
# .	SENT	.
# Mais	KON	mais
# ,	PUN	,
# naturellement	ADV	naturellement
# paisible	ADJ	paisible
# ,	PUN	,
# le	DET:ART	le
# petit	ADJ	petit
# répondait	VER:impf	répondre
# mal	ADV	mal
# à	PRP	à
# ses	DET:POS	son
# efforts	NOM	effort
# .	SENT	.
# Sa	DET:POS	son
# mère	NOM	mère
# le	PRO:PER	le
# traînait	VER:impf	traîner
# toujours	ADV	toujours
# après	PRP	après
# elle	PRO:PER	elle
# ;	PUN	;
# elle	PRO:PER	elle
# lui	PRO:PER	lui
# découpait	VER:impf	découper
# des	PRP:det	du
# cartons	NOM	carton
# ,	PUN	,
# lui	PRO:PER	lui
# racontait	VER:impf	raconter
# des	PRP:det	du
# histoires	NOM	histoire
# ,	PUN	,
# s'	PRO:PER	se
# entretenait	VER:impf	entretenir
# avec	PRP	avec
# lui	PRO:PER	lui
# dans	PRP	dans
# des	PRP:det	du
# monologues	NOM	monologue
# sans	PRP	sans
# fin	NOM	fin
# ,	PUN	,
# pleins	ADJ	plein
# de	PRP	de
# gaietés	NOM	gaieté
# mélancoliques	ADJ	mélancolique
# et	KON	et
# de	PRP	de
# chatteries	NOM	chatterie
# babillardes	ADJ	babillard
# .	SENT	.
# Dans	PRP	dans
# l'	DET:ART	le
# isolement	NOM	isolement
# de	PRP	de
# sa	DET:POS	son
# vie	NOM	vie
# ,	PUN	,
# elle	PRO:PER	elle
# reporta	VER:simp	reporter
# sur	PRP	sur
# cette	PRO:DEM	ce
# tête	NOM	tête
# d'	PRP	de
# enfant	NOM	enfant
# toutes	PRO:IND	tout
# ses	DET:POS	son
# vanités	NOM	vanité
# éparses	ADJ	épars
# ,	PUN	,
# brisées	VER:pper	briser
# .	SENT	.
# Elle	PRO:PER	elle
# rêvait	VER:impf	rêver
# de	PRP	de
# hautes	ADJ	haut
# positions	NOM	position
# ,	PUN	,
# elle	PRO:PER	elle
# le	PRO:PER	le
# voyait	VER:impf	voir
# déjà	ADV	déjà
# grand	ADJ	grand
# ,	PUN	,
# beau	ADJ	beau
# ,	PUN	,
# spirituel	ADJ	spirituel
# ,	PUN	,
# établi	VER:pper	établir
# ,	PUN	,
# dans	PRP	dans
# les	DET:ART	le
# ponts	NOM	pont
# et	KON	et
# chaussées	NOM	chaussée
# ou	KON	ou
# dans	PRP	dans
# la	DET:ART	le
# magistrature	NOM	magistrature
# .	SENT	.
# Elle	PRO:PER	elle
# lui	PRO:PER	lui
# apprit	VER:simp	apprendre
# à	PRP	à
# lire	VER:infi	lire
# ,	PUN	,
# et	KON	et
# même	ADV	même
# lui	PRO:PER	lui
# enseigna	VER:simp	enseigner
# ,	PUN	,
# sur	PRP	sur
# un	DET:ART	un
# vieux	ADJ	vieux
# piano	NOM	piano
# qu'	PRO:REL	que
# elle	PRO:PER	elle
# avait	VER:impf	avoir
# ,	PUN	,
# à	PRP	à
# chanter	VER:infi	chanter
# deux	NUM	deux
# ou	KON	ou
# trois	NUM	trois
# petites	ADJ	petit
# romances	NOM	romance
# .	SENT	.
# Mais	KON	mais
# ,	PUN	,
# à	PRP	à
# tout	ADV	tout
# cela	PRO:DEM	cela
# ,	PUN	,
# M.	NOM	monsieur
# Bovary	NAM	<unknown>
# ,	PUN	,
# peu	ADV	peu
# soucieux	ADJ	soucieux
# des	PRP:det	du
# lettres	NOM	lettre
# ,	PUN	,
# disait	VER:impf	dire
# que	KON	que
# ce	PRO:DEM	ce
# n'	ADV	ne
# était	VER:impf	être
# pas	ADV	pas
# la	DET:ART	le
# peine	NOM	peine
# !	SENT	!
# Auraient	VER:cond	avoir
# -ils	PRO:PER	il
# jamais	ADV	jamais
# de	PRP	de
# quoi	PRO	quoi
# l'	PRO:PER	la|le
# entretenir	VER:infi	entretenir
# dans	PRP	dans
# les	DET:ART	le
# écoles	NOM	école
# du	PRP:det	du
# gouvernement	NOM	gouvernement
# ,	PUN	,
# lui	PRO:PER	lui
# acheter	VER:infi	acheter
# une	DET:ART	un
# charge	NOM	charge
# ou	KON	ou
# un	DET:ART	un
# fonds	NOM	fond|fonds
# de	PRP	de
# commerce	NOM	commerce
# ?	SENT	?
# D'ailleurs	ADV	d'ailleurs
# ,	PUN	,
# avec	PRP	avec
# du	PRP:det	du
# toupet	NOM	toupet
# ,	PUN	,
# un	DET:ART	un
# homme	NOM	homme
# réussit	VER:pres	réussir
# toujours	ADV	toujours
# dans	PRP	dans
# le	DET:ART	le
# monde	NOM	monde
# .	SENT	.
# Madame	NAM	Madame
# Bovary	NAM	<unknown>
# se	PRO:PER	se
# mordait	VER:impf	mordre
# les	DET:ART	le
# lèvres	NOM	lèvre
# ,	PUN	,
# et	KON	et
# l'	DET:ART	le
# enfant	NOM	enfant
# vagabondait	VER:impf	vagabonder
# dans	PRP	dans
# le	DET:ART	le
# village	NOM	village
# .	SENT	.
# Il	PRO:PER	il
# suivait	VER:impf	suivre
# les	DET:ART	le
# laboureurs	NOM	laboureur
# ,	PUN	,
# et	KON	et
# chassait	VER:impf	chasser
# ,	PUN	,
# à	PRP	à
# coups	NOM	coup
# de	PRP	de
# motte	NOM	motte
# de	PRP	de
# terre	NOM	terre
# ,	PUN	,
# les	DET:ART	le
# corbeaux	NOM	corbeau
# qui	PRO:REL	qui
# s'	PRO:PER	se
# envolaient	VER:impf	envoler
# .	SENT	.
# Il	PRO:PER	il
# mangeait	VER:impf	manger
# des	PRP:det	du
# mûres	NOM	mûre
# le	DET:ART	le
# long	NOM	long
# des	PRP:det	du
# fossés	NOM	fossé
# ,	PUN	,
# gardait	VER:impf	garder
# les	DET:ART	le
# dindons	NOM	dindon
# avec	PRP	avec
# une	DET:ART	un
# gaule	NOM	gaule
# ,	PUN	,
# fanait	VER:impf	faner
# à	PRP	à
# la	DET:ART	le
# moisson	NOM	moisson
# ,	PUN	,
# courait	VER:impf	courir
# dans	PRP	dans
# le	DET:ART	le
# bois	NOM	bois
# ,	PUN	,
# jouait	VER:impf	jouer
# à	PRP	à
# la	DET:ART	le
# marelle	NOM	marelle
# sous	PRP	sous
# le	DET:ART	le
# porche	NOM	porche
# de	PRP	de
# l'	DET:ART	le
# église	NOM	église
# les	DET:ART	le
# jours	NOM	jour
# de	PRP	de
# pluie	NOM	pluie
# ,	PUN	,
# et	KON	et
# ,	PUN	,
# aux	PRP:det	au
# grandes	ADJ	grand
# fêtes	NOM	fête
# ,	PUN	,
# suppliait	VER:impf	supplier
# le	DET:ART	le
# bedeau	NOM	bedeau
# de	PRP	de
# lui	PRO:PER	lui
# laisser	VER:infi	laisser
# sonner	VER:infi	sonner
# les	DET:ART	le
# cloches	NOM	cloche
# ,	PUN	,
# pour	PRP	pour
# se	PRO:PER	se
# pendre	VER:infi	pendre
# de	PRP	de
# tout	PRO:IND	tout
# son	DET:POS	son
# corps	NOM	corps
# à	PRP	à
# la	DET:ART	le
# grande	ADJ	grand
# corde	NOM	corde
# et	KON	et
# se	PRO:PER	se
# sentir	VER:infi	sentir
# emporter	VER:infi	emporter
# par	PRP	par
# elle	PRO:PER	elle
# dans	PRP	dans
# sa	DET:POS	son
# volée	NOM	volée
# .	SENT	.
# Aussi	ADV	aussi
# poussa	VER:simp	pousser
# -t-il	PRO:PER	il
# comme	ADV	comme
# un	DET:ART	un
# chêne	NOM	chêne
# .	SENT	.
# Il	PRO:PER	il
# acquit	VER:simp	acquérir
# de	PRP	de
# fortes	ADJ	fort
# mains	NOM	main
# ,	PUN	,
# de	PRP	de
# belles	ADJ	beau
# couleurs	NOM	couleur
# .	SENT	.
# À	PRP	à
# douze	NUM	douze
# ans	NOM	an
# ,	PUN	,
# sa	DET:POS	son
# mère	NOM	mère
# obtint	VER:simp	obtenir
# que	KON	que
# l'	PRO:PER	la|le
# on	PRO:PER	on
# commençât	VER:subi	commencer
# ses	DET:POS	son
# études	NOM	étude
# .	SENT	.
# On	PRO:PER	on
# en	PRO:PER	en
# chargea	VER:simp	charger
# le	DET:ART	le
# curé	NOM	curé
# .	SENT	.
# Mais	KON	mais
# les	DET:ART	le
# leçons	NOM	leçon
# étaient	VER:impf	être
# si	ADV	si
# courtes	ADJ	court
# et	KON	et
# si	ADV	si
# mal	ADV	mal
# suivies	VER:pper	suivre
# ,	PUN	,
# qu'	KON	que
# elles	PRO:PER	elle
# ne	ADV	ne
# pouvaient	VER:impf	pouvoir
# servir	VER:infi	servir
# à	PRP	à
# grand-chose	NOM	grand-chose
# .	SENT	.
# C'	PRO:DEM	ce
# était	VER:impf	être
# aux	PRP:det	au
# moments	NOM	moment
# perdus	ADJ	perdu
# qu'	PRO:REL	que
# elles	PRO:PER	elle
# se	PRO:PER	se
# donnaient	VER:impf	donner
# ,	PUN	,
# dans	PRP	dans
# la	DET:ART	le
# sacristie	NOM	sacristie
# ,	PUN	,
# debout	ADV	debout
# ,	PUN	,
# à	PRP	à
# la	DET:ART	le
# hâte	NOM	hâte
# ,	PUN	,
# entre	PRP	entre
# un	DET:ART	un
# baptême	NOM	baptême
# et	KON	et
# un	DET:ART	un
# enterrement	NOM	enterrement
# ;	PUN	;
# ou	KON	ou
# bien	ADV	bien
# le	DET:ART	le
# curé	NOM	curé
# envoyait	VER:impf	envoyer
# chercher	VER:infi	chercher
# son	DET:POS	son
# élève	NOM	élève
# après	PRP	après
# l'	DET:ART	le
# Angélus	NAM	<unknown>
# ,	PUN	,
# quand	KON	quand
# il	PRO:PER	il
# n'	ADV	ne
# avait	VER:impf	avoir
# pas	ADV	pas
# à	PRP	à
# sortir	VER:infi	sortir
# .	SENT	.
# On	PRO:PER	on
# montait	VER:impf	monter
# dans	PRP	dans
# sa	DET:POS	son
# chambre	NOM	chambre
# ,	PUN	,
# on	PRO:PER	on
# s'	PRO:PER	se
# installait	VER:impf	installer
# :	PUN	:
# les	DET:ART	le
# moucherons	NOM	moucheron
# et	KON	et
# les	DET:ART	le
# papillons	NOM	papillon
# de	PRP	de
# nuit	NOM	nuit
# tournoyaient	VER:impf	tournoyer
# autour	ADV	autour
# de	PRP	de
# la	DET:ART	le
# chandelle	NOM	chandelle
# .	SENT	.
# Il	PRO:PER	il
# faisait	VER:impf	faire
# chaud	ADJ	chaud
# ,	PUN	,
# l'	DET:ART	le
# enfant	NOM	enfant
# s'	PRO:PER	se
# endormait	VER:impf	endormir
# ;	PUN	;
# et	KON	et
# le	DET:ART	le
# bonhomme	NOM	bonhomme
# ,	PUN	,
# s'	PRO:PER	se
# assoupissant	VER:ppre	assoupir
# les	DET:ART	le
# mains	NOM	main
# sur	PRP	sur
# son	DET:POS	son
# ventre	NOM	ventre
# ,	PUN	,
# ne	ADV	ne
# tardait	VER:impf	tarder
# pas	ADV	pas
# à	PRP	à
# ronfler	VER:infi	ronfler
# ,	PUN	,
# la	DET:ART	le
# bouche	NOM	bouche
# ouverte	ADJ	ouvert
# .	SENT	.
# D'	PRP	de
# autres	ADJ	autre
# fois	NOM	foi|fois
# ,	PUN	,
# quand	KON	quand
# M.	NOM	monsieur
# le	DET:ART	le
# curé	NOM	curé
# ,	PUN	,
# revenant	VER:ppre	revenir
# de	PRP	de
# porter	VER:infi	porter
# le	DET:ART	le
# viatique	NOM	viatique
# à	PRP	à
# quelque	PRO:IND	quelque
# malade	NOM	malade
# des	PRP:det	du
# environs	NOM	environ|environs
# ,	PUN	,
# apercevait	VER:impf	apercevoir
# Charles	NAM	Charles
# qui	PRO:REL	qui
# polissonnait	VER:impf	polissonner
# dans	PRP	dans
# la	DET:ART	le
# campagne	NOM	campagne
# ,	PUN	,
# il	PRO:PER	il
# l'	PRO:PER	la|le
# appelait	VER:impf	appeler
# ,	PUN	,
# le	PRO:PER	le
# sermonnait	VER:impf	sermonner
# un	DET:ART	un
# quart	NOM	quart
# d'	PRP	de
# heure	NOM	heure
# et	KON	et
# profitait	VER:impf	profiter
# de	PRP	de
# l'	DET:ART	le
# occasion	NOM	occasion
# pour	PRP	pour
# lui	PRO:PER	lui
# faire	VER:infi	faire
# conjuguer	VER:infi	conjuguer
# son	DET:POS	son
# verbe	NOM	verbe
# au	PRP:det	au
# pied	NOM	pied
# d'	PRP	de
# un	DET:ART	un
# arbre	NOM	arbre
# .	SENT	.
# La	DET:ART	le
# pluie	NOM	pluie
# venait	VER:impf	venir
# les	PRO:PER	la|le
# interrompre	VER:infi	interrompre
# ,	PUN	,
# ou	KON	ou
# une	DET:ART	un
# connaissance	NOM	connaissance
# qui	PRO:REL	qui
# passait	VER:impf	passer
# .	SENT	.
# Du	PRP:det	du
# reste	NOM	reste
# ,	PUN	,
# il	PRO:PER	il
# était	VER:impf	être
# toujours	ADV	toujours
# content	ADJ	content
# de	PRP	de
# lui	PRO:PER	lui
# ,	PUN	,
# disait	VER:impf	dire
# même	ADV	même
# que	KON	que
# le	DET:ART	le
# jeune	ADJ	jeune
# homme	NOM	homme
# avait	VER:impf	avoir
# beaucoup	ADV	beaucoup
# de	PRP	de
# mémoire	NOM	mémoire
# .	SENT	.
# Charles	NAM	Charles
# ne	ADV	ne
# pouvait	VER:impf	pouvoir
# en	PRO:PER	en
# rester	VER:infi	rester
# là	ADV	là
# .	SENT	.
# Madame	NAM	Madame
# fut	VER:simp	être
# énergique	ADJ	énergique
# .	SENT	.
# Honteux	ADJ	honteux
# ,	PUN	,
# ou	KON	ou
# fatigué	VER:pper	fatiguer
# plutôt	ADV	plutôt
# ,	PUN	,
# Monsieur	NAM	Monsieur
# céda	VER:simp	céder
# sans	PRP	sans
# résistance	NOM	résistance
# ,	PUN	,
# et	KON	et
# l'	PRO:PER	la|le
# on	PRO:PER	on
# attendit	VER:simp	attendre
# encore	ADV	encore
# un	DET:ART	un
# an	NOM	an
# que	KON	que
# le	DET:ART	le
# gamin	NOM	gamin
# eût	VER:subi	avoir
# fait	VER:pper	faire
# sa	DET:POS	son
# première	NUM	premier
# communion	NOM	communion
# .	SENT	.
# Six	NUM	six
# mois	NOM	moi|mois
# se	PRO:PER	se
# passèrent	VER:simp	passer
# encore	ADV	encore
# ;	PUN	;
# et	KON	et
# ,	PUN	,
# l'	DET:ART	le
# année	NOM	année
# d'après	ADV	d'après
# ,	PUN	,
# Charles	NAM	Charles
# fut	VER:simp	être
# définitivement	ADV	définitivement
# envoyé	VER:pper	envoyer
# au	PRP:det	au
# collège	NOM	collège
# de	PRP	de
# Rouen	NAM	Rouen
# ,	PUN	,
# où	PRO:REL	où
# son	DET:POS	son
# père	NOM	père
# l'	PRO:PER	la|le
# amena	VER:simp	amener
# lui-même	PRO:PER	lui-même
# ,	PUN	,
# vers	PRP	vers
# la	DET:ART	le
# fin	NOM	fin
# d'	PRP	de
# octobre	NOM	octobre
# ,	PUN	,
# à	PRP	à
# l'	DET:ART	le
# époque	NOM	époque
# de	PRP	de
# la	DET:ART	le
# foire	NOM	foire
# Saint-	NAM	<unknown>
# Romain	NAM	Romain
# .	SENT	.
# Il	PRO:PER	il
# serait	VER:cond	être
# maintenant	ADV	maintenant
# impossible	ADJ	impossible
# à	PRP	à
# aucun	PRO:IND	aucun
# de	PRP	de
# nous	PRO:PER	nous
# de	PRP	de
# se	PRO:PER	se
# rien	ADV	rien
# rappeler	VER:infi	rappeler
# de	PRP	de
# lui	PRO:PER	lui
# .	SENT	.
# C'	PRO:DEM	ce
# était	VER:impf	être
# un	DET:ART	un
# garçon	NOM	garçon
# de	PRP	de
# tempérament	NOM	tempérament
# modéré	VER:pper	modérer
# ,	PUN	,
# qui	PRO:REL	qui
# jouait	VER:impf	jouer
# aux	PRP:det	au
# récréations	NOM	récréation
# ,	PUN	,
# travaillait	VER:impf	travailler
# à	PRP	à
# l'	DET:ART	le
# étude	NOM	étude
# ,	PUN	,
# écoutant	VER:ppre	écouter
# en	PRP	en
# classe	NOM	classe
# ,	PUN	,
# dormant	VER:ppre	dormir
# bien	ADV	bien
# au	PRP:det	au
# dortoir	NOM	dortoir
# ,	PUN	,
# mangeant	VER:ppre	manger
# bien	ADV	bien
# au	PRP:det	au
# réfectoire	NOM	réfectoire
# .	SENT	.
# Il	PRO:PER	il
# avait	VER:impf	avoir
# pour	PRP	pour
# correspondant	VER:ppre	correspondre
# un	DET:ART	un
# quincaillier	NOM	quincaillier
# en	PRP	en
# gros	ADJ	gros
# de	PRP	de
# la	DET:ART	le
# rue	NOM	rue
# Ganterie	NAM	<unknown>
# ,	PUN	,
# qui	PRO:REL	qui
# le	PRO:PER	le
# faisait	VER:impf	faire
# sortir	VER:infi	sortir
# une	DET:ART	un
# fois	NOM	foi|fois
# par	PRP	par
# mois	NOM	moi|mois
# ,	PUN	,
# le	DET:ART	le
# dimanche	NOM	dimanche
# ,	PUN	,
# après	KON	après
# que	KON	que
# sa	DET:POS	son
# boutique	NOM	boutique
# était	VER:impf	être
# fermée	VER:pper	fermer
# ,	PUN	,
# l'	PRO:PER	la|le
# envoyait	VER:impf	envoyer
# se	PRO:PER	se
# promener	VER:infi	promener
# sur	PRP	sur
# le	DET:ART	le
# port	NOM	port
# à	PRP	à
# regarder	VER:infi	regarder
# les	DET:ART	le
# bateaux	NOM	bateau
# ,	PUN	,
# puis	ADV	puis
# le	PRO:PER	le
# ramenait	VER:impf	ramener
# au	PRP:det	au
# collège	NOM	collège
# dès	PRP	dès
# sept	NUM	sept
# heures	NOM	heure
# ,	PUN	,
# avant	PRP	avant
# le	DET:ART	le
# souper	NOM	souper
# .	SENT	.
# Le	DET:ART	le
# soir	NOM	soir
# de	PRP	de
# chaque	PRO:IND	chaque
# jeudi	NOM	jeudi
# ,	PUN	,
# il	PRO:PER	il
# écrivait	VER:impf	écrire
# une	DET:ART	un
# longue	ADJ	longue
# lettre	NOM	lettre
# à	PRP	à
# sa	DET:POS	son
# mère	NOM	mère
# ,	PUN	,
# avec	PRP	avec
# de	PRP	de
# l'	DET:ART	le
# encre	NOM	encre
# rouge	ADJ	rouge
# et	KON	et
# trois	NUM	trois
# pains	NOM	pain
# à	PRP	à
# cacheter	VER:infi	cacheter
# ;	PUN	;
# puis	ADV	puis
# il	PRO:PER	il
# repassait	VER:impf	repasser
# ses	DET:POS	son
# cahiers	NOM	cahier
# d'	PRP	de
# histoire	NOM	histoire
# ,	PUN	,
# ou	KON	ou
# bien	ADV	bien
# lisait	VER:impf	lire|liser
# un	DET:ART	un
# vieux	ADJ	vieux
# volume	NOM	volume
# d'	PRP	de
# Anacharsis	NAM	<unknown>
# qui	PRO:REL	qui
# traînait	VER:impf	traîner
# dans	PRP	dans
# l'	DET:ART	le
# étude	NOM	étude
# .	SENT	.
# En	PRP	en
# promenade	NOM	promenade
# ,	PUN	,
# il	PRO:PER	il
# causait	VER:impf	causer
# avec	PRP	avec
# le	DET:ART	le
# domestique	ADJ	domestique
# ,	PUN	,
# qui	PRO:REL	qui
# était	VER:impf	être
# de	PRP	de
# la	DET:ART	le
# campagne	NOM	campagne
# comme	KON	comme
# lui	PRO:PER	lui
# .	SENT	.
# À	PRP	à
# force	NOM	force
# de	PRP	de
# s'	PRO:PER	se
# appliquer	VER:infi	appliquer
# ,	PUN	,
# il	PRO:PER	il
# se	PRO:PER	se
# maintint	VER:simp	maintenir
# toujours	ADV	toujours
# vers	PRP	vers
# le	DET:ART	le
# milieu	NOM	milieu
# de	PRP	de
# la	DET:ART	le
# classe	NOM	classe
# ;	PUN	;
# une	DET:ART	un
# fois	NOM	foi|fois
# même	ADJ	même
# ,	PUN	,
# il	PRO:PER	il
# gagna	VER:simp	gagner
# un	DET:ART	un
# premier	NUM	premier
# accessit	NOM	accessit
# d'	PRP	de
# histoire	NOM	histoire
# naturelle	ADJ	naturel
# .	SENT	.
# Mais	KON	mais
# à	PRP	à
# la	DET:ART	le
# fin	NOM	fin
# de	PRP	de
# sa	DET:POS	son
# troisième	NUM	troisième
# ,	PUN	,
# ses	DET:POS	son
# parents	NOM	parent|parents
# le	PRO:PER	le
# retirèrent	VER:simp	retirer
# du	PRP:det	du
# collège	NOM	collège
# pour	PRP	pour
# lui	PRO:PER	lui
# faire	VER:infi	faire
# étudier	VER:infi	étudier
# la	DET:ART	le
# médecine	NOM	médecine
# ,	PUN	,
# persuadés	VER:pper	persuader
# qu'	KON	que
# il	PRO:PER	il
# pourrait	VER:cond	pouvoir
# se	PRO:PER	se
# pousser	VER:infi	pousser
# seul	ADJ	seul
# jusqu'	PRP	jusque
# au	PRP:det	au
# baccalauréat	NOM	baccalauréat
# .	SENT	.
# Sa	DET:POS	son
# mère	NOM	mère
# lui	PRO:PER	lui
# choisit	VER:pres	choisir
# une	DET:ART	un
# chambre	NOM	chambre
# ,	PUN	,
# au	PRP:det	au
# quatrième	NUM	quatrième
# ,	PUN	,
# sur	PRP	sur
# l'	DET:ART	le
# Eau-de-Robec	NAM	<unknown>
# ,	PUN	,
# chez	PRP	chez
# un	DET:ART	un
# teinturier	NOM	teinturier
# de	PRP	de
# sa	DET:POS	son
# connaissance	NOM	connaissance
# :	PUN	:
# Elle	PRO:PER	elle
# conclut	VER:pres	conclure
# les	DET:ART	le
# arrangements	NOM	arrangement
# pour	PRP	pour
# sa	DET:POS	son
# pension	NOM	pension
# ,	PUN	,
# se	PRO:PER	se
# procura	VER:simp	procurer
# des	PRP:det	du
# meubles	NOM	meuble
# ,	PUN	,
# une	DET:ART	un
# table	NOM	table
# et	KON	et
# deux	NUM	deux
# chaises	NOM	chaise
# ,	PUN	,
# fit	VER:simp	faire
# venir	VER:infi	venir
# de	PRP	de
# chez	PRP	chez
# elle	PRO:PER	elle
# un	DET:ART	un
# vieux	ADJ	vieux
# lit	NOM	lit
# en	PRP	en
# merisier	NOM	merisier
# ,	PUN	,
# et	KON	et
# acheta	VER:simp	acheter
# de	PRP	de
# plus	ADV	plus
# un	DET:ART	un
# petit	ADJ	petit
# poêle	NOM	poêle
# en	PRP	en
# fonte	NOM	fonte
# ,	PUN	,
# avec	PRP	avec
# la	DET:ART	le
# provision	NOM	provision
# de	PRP	de
# bois	NOM	bois
# qui	PRO:REL	qui
# devait	VER:impf	devoir
# chauffer	VER:infi	chauffer
# son	DET:POS	son
# pauvre	ADJ	pauvre
# enfant	NOM	enfant
# .	SENT	.
# Puis	ADV	puis
# elle	PRO:PER	elle
# partit	VER:simp	partir
# au	PRP:det	au
# bout	NOM	bout
# de	PRP	de
# la	DET:ART	le
# semaine	NOM	semaine
# ,	PUN	,
# après	PRP	après
# mille	NUM	mille
# recommandations	NOM	recommandation
# de	PRP	de
# se	PRO:PER	se
# bien	ADV	bien
# conduire	VER:infi	conduire
# ,	PUN	,
# maintenant	ADV	maintenant
# qu'	KON	que
# il	PRO:PER	il
# allait	VER:impf	aller
# être	VER:infi	être
# abandonné	VER:pper	abandonner
# à	PRP	à
# lui-même	PRO:PER	lui-même
# .	SENT	.
# Le	DET:ART	le
# programme	NOM	programme
# des	PRP:det	du
# cours	NOM	cour|cours
# ,	PUN	,
# qu'	PRO:REL	que
# il	PRO:PER	il
# lut	VER:simp	lire
# sur	PRP	sur
# l'	DET:ART	le
# affiche	NOM	affiche
# ,	PUN	,
# lui	PRO:PER	lui
# fit	VER:simp	faire
# un	DET:ART	un
# effet	NOM	effet
# d'	PRP	de
# étourdissement	NOM	étourdissement
# :	PUN	:
# cours	NOM	cour|cours
# d'	PRP	de
# anatomie	NOM	anatomie
# ,	PUN	,
# cours	NOM	cour|cours
# de	PRP	de
# pathologie	NOM	pathologie
# ,	PUN	,
# cours	NOM	cour|cours
# de	PRP	de
# physiologie	NOM	physiologie
# ,	PUN	,
# cours	NOM	cour|cours
# de	PRP	de
# pharmacie	NOM	pharmacie
# ,	PUN	,
# cours	NOM	cour|cours
# de	PRP	de
# chimie	NOM	chimie
# ,	PUN	,
# et	KON	et
# de	PRP	de
# botanique	NOM	botanique
# ,	PUN	,
# et	KON	et
# de	PRP	de
# clinique	NOM	clinique
# ,	PUN	,
# et	KON	et
# de	PRP	de
# thérapeutique	NOM	thérapeutique
# ,	PUN	,
# sans	PRP	sans
# compter	VER:infi	compter
# l'	DET:ART	le
# hygiène	NOM	hygiène
# ni	KON	ni
# la	DET:ART	le
# matière	NOM	matière
# médicale	ADJ	médical
# ,	PUN	,
# tous	PRO:IND	tout
# noms	NOM	nom
# dont	PRO:REL	dont
# il	PRO:PER	il
# ignorait	VER:impf	ignorer
# les	DET:ART	le
# étymologies	NOM	étymologie
# et	KON	et
# qui	PRO:REL	qui
# étaient	VER:impf	être
# comme	ADV	comme
# autant	ADV	autant
# de	PRP	de
# portes	NOM	porte
# de	PRP	de
# sanctuaires	NOM	sanctuaire
# pleins	ADJ	plein
# d'	PRP	de
# augustes	ADJ	auguste
# ténèbres	NOM	ténèbre
# .	SENT	.
# Il	PRO:PER	il
# n'	ADV	ne
# y	PRO:PER	y
# comprit	VER:simp	comprendre
# rien	ADV	rien
# ;	PUN	;
# il	PRO:PER	il
# avait	VER:impf	avoir
# beau	ADJ	beau
# écouter	VER:infi	écouter
# ,	PUN	,
# il	PRO:PER	il
# ne	ADV	ne
# saisissait	VER:impf	saisir
# pas	ADV	pas
# .	SENT	.
# Il	PRO:PER	il
# travaillait	VER:impf	travailler
# pourtant	ADV	pourtant
# ,	PUN	,
# il	PRO:PER	il
# avait	VER:impf	avoir
# des	PRP:det	du
# cahiers	NOM	cahier
# reliés	VER:pper	relier
# ,	PUN	,
# il	PRO:PER	il
# suivait	VER:impf	suivre
# tous	PRO:IND	tout
# les	DET:ART	le
# cours	NOM	cour|cours
# ;	PUN	;
# il	PRO:PER	il
# ne	ADV	ne
# perdait	VER:impf	perdre
# pas	ADV	pas
# une	DET:ART	un
# seule	ADJ	seul
# visite	NOM	visite
# .	SENT	.
# Il	PRO:PER	il
# accomplissait	VER:impf	accomplir
# sa	DET:POS	son
# petite	ADJ	petit
# tâche	NOM	tâche
# quotidienne	ADJ	quotidien
# à	PRP	à
# la	DET:ART	le
# manière	NOM	manière
# du	PRP:det	du
# cheval	NOM	cheval
# ...
# .	SENT	.
# Elle	PRO:PER	elle
# avait	VER:impf	avoir
# pour	PRP	pour
# décoration	NOM	décoration
# une	DET:ART	un
# vieille	ADJ	vieux
# gravure	NOM	gravure
# de	PRP	de
# modes	NOM	mode
# collée	VER:pper	coller
# contre	PRP	contre
# un	DET:ART	un
# carreau	NOM	carreau
# et	KON	et
# un	DET:ART	un
# buste	NOM	buste
# de	PRP	de
# femme	NOM	femme
# en	PRP	en
# cire	NOM	cire
# ,	PUN	,
# dont	PRO:REL	dont
# les	DET:ART	le
# cheveux	NOM	cheveu
# étaient	VER:impf	être
# jaunes	ADJ	jaune
# .	SENT	.
# Lui	PRO:PER	lui
# aussi	ADV	aussi
# ,	PUN	,
# le	DET:ART	le
# perruquier	NOM	perruquier
# ,	PUN	,
# il	PRO:PER	il
# se	PRO:PER	se
# lamentait	VER:impf	lamenter
# de	PRP	de
# sa	DET:POS	son
# vocation	NOM	vocation
# arrêtée	ADJ	arrêté
# ,	PUN	,
# de	PRP	de
# son	DET:POS	son
# avenir	NOM	avenir
# perdu	ADJ	perdu
# ,	PUN	,
# et	KON	et
# ,	PUN	,
# rêvant	VER:ppre	rêver
# quelque	PRO:IND	quelque
# boutique	NOM	boutique
# dans	PRP	dans
# une	DET:ART	un
# grande	ADJ	grand
# .	SENT	.
# ville	NOM	ville
# ,	PUN	,
# comme	ADV	comme
# à	PRP	à
# Rouen	NAM	Rouen
# par	PRP	par
# exemple	NOM	exemple
# ,	PUN	,
# sur	PRP	sur
# le	DET:ART	le
# port	NOM	port
# ,	PUN	,
# près	ADV	près
# du	PRP:det	du
# théâtre	NOM	théâtre
# ,	PUN	,
# il	PRO:PER	il
# restait	VER:impf	rester
# toute	PRO:IND	tout
# la	DET:ART	le
# journée	NOM	journée
# à	PRP	à
# se	PRO:PER	se
# promener	VER:infi	promener
# en	PRP	en
# long	NOM	long
# ,	PUN	,
# depuis	PRP	depuis
# la	DET:ART	le
# mairie	NOM	mairie
# jusqu'	PRP	jusque
# à	PRP	à
# l'	DET:ART	le
# église	NOM	église
# ,	PUN	,
# sombre	ADJ	sombre
# ,	PUN	,
# et	KON	et
# attendant	VER:ppre	attendre
# la	DET:ART	le
# clientèle	NOM	clientèle
# .	SENT	.
# Lorsque	KON	lorsque
# madame	NOM	madame
# Bovary	NAM	<unknown>
# levait	VER:impf	lever
# les	DET:ART	le
# yeux	NOM	il
# ,	PUN	,
# elle	PRO:PER	elle
# le	PRO:PER	le
# voyait	VER:impf	voir
# toujours	ADV	toujours
# là	ADV	là
# ,	PUN	,
# comme	KON	comme
# une	DET:ART	un
# sentinelle	NOM	sentinelle
# en	PRP	en
# faction	NOM	faction
# ,	PUN	,
# avec	PRP	avec
# son	DET:POS	son
# bonnet	NOM	bonnet
# grec	ADJ	grec
# sur	PRP	sur
# l'	DET:ART	le
# oreille	NOM	oreille
# et	KON	et
# sa	DET:POS	son
# veste	NOM	veste
# de	PRP	de
# lasting	NOM	lasting
# .	SENT	.
# Dans	PRP	dans
# l'	DET:ART	le
# après-midi	NOM	après-midi
# ,	PUN	,
# quelquefois	ADV	quelquefois
# ,	PUN	,
# une	DET:ART	un
# tête	NOM	tête
# d'	PRP	de
# homme	NOM	homme
# apparaissait	VER:impf	apparaître
# derrière	PRP	derrière
# les	DET:ART	le
# vitres	NOM	vitre
# de	PRP	de
# la	DET:ART	le
# salle	NOM	salle
# ,	PUN	,
# tête	NOM	tête
# hâlée	ADJ	hâlé
# ,	PUN	,
# à	PRP	à
# favoris	ADJ	favori
# noirs	NOM	noir
# ,	PUN	,
# et	KON	et
# qui	PRO:REL	qui
# souriait	VER:impf	sourire
# lentement	ADV	lentement
# d'	PRP	de
# un	DET:ART	un
# large	ADJ	large
# sourire	NOM	sourire
# doux	ADJ	doux
# à	PRP	à
# dents	NOM	dent
# blanches	ADJ	blanc
# .	SENT	.
# Une	DET:ART	un
# valse	NOM	valse
# aussitôt	ADV	aussitôt
# commençait	VER:impf	commencer
# ,	PUN	,
# et	KON	et
# ,	PUN	,
# sur	PRP	sur
# l'	DET:ART	le
# orgue	NOM	orgue
# ,	PUN	,
# dans	PRP	dans
# un	DET:ART	un
# petit	ADJ	petit
# salon	NOM	salon
# ,	PUN	,
# des	PRP:det	du
# danseurs	NOM	danseur
# hauts	ADJ	haut
# comme	KON	comme
# le	DET:ART	le
# doigt	NOM	doigt
# ,	PUN	,
# femmes	NOM	femme
# en	PRP	en
# turban	NOM	turban
# rose	ADJ	rose
# ,	PUN	,
# Tyroliens	NAM	<unknown>
# en	PRP	en
# jaquette	NOM	jaquette
# ,	PUN	,
# singes	NOM	singe
# en	PRP	en
# habit	NOM	habit
# noir	ADJ	noir
# ,	PUN	,
# messieurs	NOM	messieurs
# en	PRP	en
# culotte	NOM	culotte
# courte	ADJ	court
# ,	PUN	,
# tournaient	VER:impf	tourner
# ,	PUN	,
# tournaient	VER:impf	tourner
# entre	PRP	entre
# les	DET:ART	le
# fauteuils	NOM	fauteuil
# ,	PUN	,
# les	DET:ART	le
# canapés	NOM	canapé
# ,	PUN	,
# les	DET:ART	le
# consoles	NOM	console
# ,	PUN	,
# se	PRO:PER	se
# répétant	VER:ppre	répéter
# dans	PRP	dans
# les	DET:ART	le
# morceaux	NOM	morceau
# de	PRP	de
# miroir	NOM	miroir
# que	PRO:REL	que
# raccordait	VER:impf	raccorder
# à	PRP	à
# leurs	DET:POS	leur
# angles	NOM	angle
# un	DET:ART	un
# filet	NOM	filet
# de	PRP	de
# papier	NOM	papier
# doré	VER:pper	dorer
# .	SENT	.
# L'	DET:ART	le
# homme	NOM	homme
# faisait	VER:impf	faire
# aller	VER:infi	aller
# sa	DET:POS	son
# manivelle	NOM	manivelle
# ,	PUN	,
# regardant	VER:ppre	regarder
# à	PRP	à
# droite	NOM	droit|droite
# ,	PUN	,
# à	PRP	à
# gauche	ADJ	gauche
# et	KON	et
# vers	PRP	vers
# les	DET:ART	le
# fenêtres	NOM	fenêtre
# .	SENT	.
# De	PRP	de
# temps	NOM	temps
# à	PRP	à
# autre	ADJ	autre
# ,	PUN	,
# tout	ADV	tout
# en	PRP	en
# lançant	VER:ppre	lancer
# contre	PRP	contre
# la	DET:ART	le
# borne	NOM	borne
# un	DET:ART	un
# long	ADJ	long
# jet	NOM	jet
# de	PRP	de
# salive	NOM	salive
# brune	ADJ	brun
# ,	PUN	,
# il	PRO:PER	il
# soulevait	VER:impf	soulever
# du	PRP:det	du
# genou	NOM	genou
# son	DET:POS	son
# instrument	NOM	instrument
# ,	PUN	,
# dont	PRO:REL	dont
# la	DET:ART	le
# bretelle	NOM	bretelle
# dure	VER:subp	durer
# lui	PRO:PER	lui
# fatiguait	VER:impf	fatiguer
# l'	DET:ART	le
# épaule	NOM	épaule
# ;	PUN	;
# et	KON	et
# ,	PUN	,
# tantôt	ADV	tantôt
# dolente	ADJ	dolent
# et	KON	et
# traînarde	ADJ	traînard
# ,	PUN	,
# ou	KON	ou
# joyeuse	ADJ	joyeux
# et	KON	et
# précipitée	ADJ	précipité
# ,	PUN	,
# la	DET:ART	le
# musique	NOM	musique
# de	PRP	de
# la	DET:ART	le
# boîte	NOM	boîte
# s'	PRO:PER	se
# échappait	VER:impf	échapper
# en	PRP	en
# bourdonnant	VER:ppre	bourdonner
# à	PRP	à
# travers	NOM	travers
# un	DET:ART	un
# rideau	NOM	rideau
# de	PRP	de
# taffetas	NOM	taffetas
# rose	ADJ	rose
# ,	PUN	,
# sous	PRP	sous
# une	DET:ART	un
# grille	NOM	grille
# de	PRP	de
# cuivre	NOM	cuivre
# en	PRP	en
# arabesque	NOM	arabesque
# .	SENT	.
# C'	PRO:DEM	ce
# étaient	VER:impf	être
# des	PRP:det	du
# airs	NOM	air
# que	PRO:REL	que
# l'	DET:ART	le
# on	PRO:PER	on
# jouait	VER:impf	jouer
# ailleurs	ADV	ailleurs
# sur	PRP	sur
# les	DET:ART	le
# théâtres	NOM	théâtre
# ;	PUN	;
# que	KON	que
# l'	PRO:PER	la|le
# on	PRO:PER	on
# chantait	VER:impf	chanter
# dans	PRP	dans
# les	DET:ART	le
# salons	NOM	salon
# ,	PUN	,
# que	KON	que
# l'	PRO:PER	la|le
# on	PRO:PER	on
# dansait	VER:impf	danser
# le	DET:ART	le
# soir	NOM	soir
# sous	PRP	sous
# des	PRP:det	du
# lustres	NOM	lustre
# éclairés	VER:pper	éclairer
# ,	PUN	,
# échos	NOM	écho
# du	PRP:det	du
# monde	NOM	monde
# qui	PRO:REL	qui
# arrivaient	VER:impf	arriver
# jusqu'	PRP	jusque
# à	PRP	à
# Emma	NAM	Emma
# .	SENT	.
# Des	PRP:det	du
# sarabandes	NOM	sarabande
# à	PRP	à
# n'	ADV	ne
# en	PRP	en
# plus	ADV	plus
# finir	VER:infi	finir
# se	PRO:PER	se
# déroulaient	VER:impf	dérouler
# dans	PRP	dans
# sa	DET:POS	son
# tête	NOM	tête
# ;	PUN	;
# et	KON	et
# ,	PUN	,
# comme	ADV	comme
# une	DET:ART	un
# bayadère	NOM	bayadère
# sur	PRP	sur
# les	DET:ART	le
# fleurs	NOM	fleur
# d'	PRP	de
# un	DET:ART	un
# tapis	NOM	tapis
# ,	PUN	,
# sa	DET:POS	son
# pensée	NOM	pensée
# bondissait	VER:impf	bondir
# avec	PRP	avec
# les	DET:ART	le
# notes	NOM	note
# ,	PUN	,
# se	PRO:PER	se
# balançait	VER:impf	balancer
# de	PRP	de
# rêve	NOM	rêve
# en	PRP	en
# rêve	NOM	rêve
# ,	PUN	,
# de	PRP	de
# tristesse	NOM	tristesse
# en	PRP	en
# tristesse	NOM	tristesse
# .	SENT	.
# Quand	KON	quand
# l'	DET:ART	le
# homme	NOM	homme
# avait	VER:impf	avoir
# reçu	VER:pper	recevoir
# l'	DET:ART	le
# aumône	NOM	aumône
# dans	PRP	dans
# sa	DET:POS	son
# casquette	NOM	casquette
# ,	PUN	,
# il	PRO:PER	il
# rabattait	VER:impf	rabattre
# une	DET:ART	un
# vieille	ADJ	vieux
# couverture	NOM	couverture
# de	PRP	de
# laine	NOM	laine
# bleue	ADJ	bleu
# ,	PUN	,
# passait	VER:impf	passer
# son	DET:POS	son
# orgue	NOM	orgue
# sur	PRP	sur
# son	DET:POS	son
# dos	NOM	dos
# et	KON	et
# s'	PRO:PER	se
# éloignait	VER:impf	éloigner
# d'	PRP	de
# un	DET:ART	un
# pas	ADV	pas
# lourd	ADJ	lourd
# .	SENT	.
# Elle	PRO:PER	elle
# le	PRO:PER	le
# regardait	VER:impf	regarder
# partir	VER:infi	partir
# .	SENT	.
# Mais	KON	mais
# c'	PRO:DEM	ce
# était	VER:impf	être
# surtout	ADV	surtout
# aux	PRP:det	au
# heures	NOM	heure
# des	PRP:det	du
# repas	NOM	repas
# qu'	KON	que
# elle	PRO:PER	elle
# n'	ADV	ne
# en	PRO:PER	en
# pouvait	VER:impf	pouvoir
# plus	ADV	plus
# ,	PUN	,
# dans	PRP	dans
# cette	PRO:DEM	ce
# petite	ADJ	petit
# salle	NOM	salle
# au	PRP:det	au
# rez-de-chaussée	NOM	rez-de-chaussée
# ,	PUN	,
# avec	PRP	avec
# le	DET:ART	le
# poêle	NOM	poêle
# qui	PRO:REL	qui
# fumait	VER:impf	fumer
# ,	PUN	,
# la	DET:ART	le
# porte	NOM	porte
# qui	PRO:REL	qui
# criait	VER:impf	crier
# ,	PUN	,
# les	DET:ART	le
# murs	NOM	mur
# qui	PRO:REL	qui
# suintaient	VER:impf	suinter
# ,	PUN	,
# les	DET:ART	le
# pavés	NOM	pavé
# humides	ADJ	humide
# ;	PUN	;
# toute	PRO:IND	tout
# l'	DET:ART	le
# amertume	NOM	amertume
# de	PRP	de
# l'	DET:ART	le
# existence	NOM	existence
# ,	PUN	,
# lui	PRO:PER	lui
# semblait	VER:impf	sembler
# servie	VER:pper	servir
# sur	PRP	sur
# son	DET:POS	son
# assiette	NOM	assiette
# ,	PUN	,
# et	KON	et
# ,	PUN	,
# à	PRP	à
# la	DET:ART	le
# fumée	NOM	fumée
# du	PRP:det	du
# bouilli	NOM	bouilli
# ,	PUN	,
# il	PRO:PER	il
# montait	VER:impf	monter
# du	PRP:det	du
# fond	NOM	fond
# de	PRP	de
# son	DET:POS	son
# âme	NOM	âme
# comme	KON	comme
# d'	PRP	de
# autres	ADJ	autre
# bouffées	NOM	bouffée
# d'	PRP	de
# affadissement	NOM	affadissement
# .	SENT	.
# Charles	NAM	Charles
# était	VER:impf	être
# long	ADV	long
# à	PRP	à
# manger	VER:infi	manger
# ;	PUN	;
# elle	PRO:PER	elle
# grignotait	VER:impf	grignoter
# quelques	PRO:IND	quelque
# noisettes	NOM	noisette
# ,	PUN	,
# ou	KON	ou
# bien	ADV	bien
# ,	PUN	,
# appuyée	VER:pper	appuyer
# du	PRP:det	du
# coude	NOM	coude
# ,	PUN	,
# s'	PRO:PER	se
# amusait	VER:impf	amuser
# ,	PUN	,
# avec	PRP	avec
# la	DET:ART	le
# pointe	NOM	pointe
# de	PRP	de
# son	DET:POS	son
# couteau	NOM	couteau
# ,	PUN	,
# à	PRP	à
# faire	VER:infi	faire
# des	PRP:det	du
# raies	NOM	raie
# sur	PRP	sur
# la	DET:ART	le
# toile	NOM	toile
# cirée	VER:pper	cirer
# .	SENT	.
# Elle	PRO:PER	elle
# laissait	VER:impf	laisser
# maintenant	ADV	maintenant
# tout	ADV	tout
# aller	VER:infi	aller
# dans	PRP	dans
# son	DET:POS	son
# ménage	NOM	ménage
# ,	PUN	,
# et	KON	et
# madame	NOM	madame
# Bovary	NAM	<unknown>
# mère	ADJ	mère
# ,	PUN	,
# lorsqu'	KON	lorsque
# elle	PRO:PER	elle
# vint	VER:simp	venir
# passer	VER:infi	passer
# à	PRP	à
# Tostes	NAM	<unknown>
# une	DET:ART	un
# partie	NOM	partie
# du	PRP:det	du
# carême	NOM	carême
# ,	PUN	,
# s'	PRO:PER	se
# étonna	VER:simp	étonner
# fort	ADV	fort
# de	PRP	de
# ce	PRO:DEM	ce
# changement	NOM	changement
# .	SENT	.
# Elle	PRO:PER	elle
# ,	PUN	,
# en	PRP	en
# effet	NOM	effet
# ,	PUN	,
# si	ADV	si
# soigneuse	ADJ	soigneux
# autrefois	ADV	autrefois
# et	KON	et
# délicate	ADJ	délicat
# ,	PUN	,
# elle	PRO:PER	elle
# restait	VER:impf	rester
# à	PRP	à
# présent	NOM	présent
# des	PRP:det	du
# journées	NOM	journée
# entières	ADJ	entier
# sans	PRP	sans
# s'	PRO:PER	se
# habiller	VER:infi	habiller
# ,	PUN	,
# portait	VER:impf	porter
# des	PRP:det	du
# bas	NOM	bas
# de	PRP	de
# coton	NOM	coton
# gris	ADJ	gris
# ,	PUN	,
# s'	PRO:PER	se
# éclairait	VER:impf	éclairer
# à	PRP	à
# la	DET:ART	le
# chandelle	NOM	chandelle
# .	SENT	.
# Elle	PRO:PER	elle
# répétait	VER:impf	répéter
# qu'	KON	que
# il	PRO:PER	il
# fallait	VER:impf	falloir
# économiser	VER:infi	économiser
# ,	PUN	,
# puisqu'ils	NOM	<unknown>
# n'	ADV	ne
# étaient	VER:impf	être
# pas	ADV	pas
# riches	ADJ	riche
# ,	PUN	,
# ajoutant	VER:ppre	ajouter
# qu'	KON	que
# elle	PRO:PER	elle
# était	VER:impf	être
# très	ADV	très
# contente	ADJ	content
# ,	PUN	,
# très	ADV	très
# heureuse	ADJ	heureux
# ,	PUN	,
# que	KON	que
# Tostes	NAM	<unknown>
# lui	PRO:PER	lui
# plaisait	VER:impf	plaire
# beaucoup	ADV	beaucoup
# ,	PUN	,
# et	KON	et
# autres	ADJ	autre
# discours	NOM	discours
# nouveaux	ADJ	nouveau
# qui	PRO:REL	qui
# fermaient	VER:impf	fermer
# la	DET:ART	le
# bouche	NOM	bouche
# à	PRP	à
# la	DET:ART	le
# belle-mère	NOM	belle-mère
# .	SENT	.
# Du	PRP:det	du
# reste	NOM	reste
# ,	PUN	,
# Emma	NAM	Emma
# ne	ADV	ne
# semblait	VER:impf	sembler
# plus	ADV	plus
# disposée	VER:pper	disposer
# à	PRP	à
# suivre	VER:infi	suivre
# ses	DET:POS	son
# conseils	NOM	conseil
# ;	PUN	;
# une	DET:ART	un
# fois	NOM	foi|fois
# même	ADJ	même
# ,	PUN	,
# madame	NOM	madame
# Bovary	NAM	<unknown>
# s'	PRO:PER	se
# étant	VER:ppre	être
# avisée	VER:pper	aviser
# de	PRP	de
# prétendre	VER:infi	prétendre
# que	KON	que
# les	DET:ART	le
# maîtres	NOM	maître
# devaient	VER:impf	devoir
# surveiller	VER:infi	surveiller
# la	DET:ART	le
# religion	NOM	religion
# de	PRP	de
# leurs	DET:POS	leur
# domestiques	NOM	domestique
# ,	PUN	,
# elle	PRO:PER	elle
# lui	PRO:PER	lui
# avait	VER:impf	avoir
# répondu	VER:pper	répondre
# d'	PRP	de
# un	DET:ART	un
# oeil	NOM	il
# si	KON	si
# colère	NOM	colère
# et	KON	et
# avec	PRP	avec
# un	DET:ART	un
# sourire	NOM	sourire
# tellement	ADV	tellement
# froid	ADJ	froid
# ,	PUN	,
# que	KON	que
# la	DET:ART	le
# bonne	ADJ	bon
# femme	NOM	femme
# ne	ADV	ne
# s'	PRO:PER	se
# y	PRO:PER	y
# frotta	VER:simp	frotter
# plus	ADV	plus
# .	SENT	.
# Emma	NAM	Emma
# devenait	VER:impf	devenir
# difficile	ADJ	difficile
# ,	PUN	,
# capricieuse	ADJ	capricieux
# .	SENT	.
# Elle	PRO:PER	elle
# se	PRO:PER	se
# commandait	VER:impf	commander
# des	PRP:det	du
# plats	NOM	plat
# pour	PRP	pour
# elle	PRO:PER	elle
# ,	PUN	,
# n'	ADV	ne
# y	PRO:PER	y
# touchait	VER:impf	toucher
# point	ADV	point
# ,	PUN	,
# un	DET:ART	un
# jour	NOM	jour
# ne	ADV	ne
# buvait	VER:impf	boire
# que	ADV	que
# du	PRP:det	du
# lait	NOM	lait
# pur	ADJ	pur
# ,	PUN	,
# et	KON	et
# ,	PUN	,
# le	DET:ART	le
# lendemain	NOM	lendemain
# ,	PUN	,
# des	PRP:det	du
# tasses	NOM	tasse
# de	PRP	de
# thé	NOM	thé
# à	PRP	à
# la	DET:ART	le
# douzaine	NOM	douzaine
# .	SENT	.
# Souvent	ADV	souvent
# elle	PRO:PER	elle
# s'	PRO:PER	se
# obstinait	VER:impf	obstiner
# à	PRP	à
# ne	ADV	ne
# pas	ADV	pas
# sortir	VER:infi	sortir
# ,	PUN	,
# puis	ADV	puis
# elle	PRO:PER	elle
# suffoquait	VER:impf	suffoquer
# ,	PUN	,
# ouvrait	VER:impf	ouvrer|ouvrir
# les	DET:ART	le
# fenêtres	NOM	fenêtre
# ,	PUN	,
# s'	PRO:PER	se
# habillait	VER:impf	habiller
# en	PRP	en
# robe	NOM	robe
# légère	ADJ	léger
# .	SENT	.
# Lorsqu'	KON	lorsque
# elle	PRO:PER	elle
# avait	VER:impf	avoir
# bien	ADV	bien
# rudoyé	VER:pper	rudoyer
# sa	DET:POS	son
# servante	NOM	servante
# ,	PUN	,
# elle	PRO:PER	elle
# lui	PRO:PER	lui
# faisait	VER:impf	faire
# des	PRP:det	du
# cadeaux	NOM	cadeau
# ou	KON	ou
# l'	PRO:PER	la|le
# envoyait	VER:impf	envoyer
# se	PRO:PER	se
# promener	VER:infi	promener
# chez	PRP	chez
# les	DET:ART	le
# voisines	ADJ	voisin
# ,	PUN	,
# de	PRP	de
# même	ADV	même
# qu'	KON	que
# elle	PRO:PER	elle
# jetait	VER:impf	jeter
# parfois	ADV	parfois
# aux	PRP:det	au
# pauvres	NOM	pauvre
# toutes	PRO:IND	tout
# les	DET:ART	le
# pièces	NOM	pièce
# blanches	ADJ	blanc
# de	PRP	de
# sa	DET:POS	son
# bourse	NOM	bourse
# ,	PUN	,
# quoiqu'elle	NOM	<unknown>
# ne	ADV	ne
# fût	VER:subi	être
# guère	ADV	guère
# tendre	ADJ	tendre
# cependant	ADV	cependant
# ,	PUN	,
# ni	KON	ni
# facilement	ADV	facilement
# accessible	ADJ	accessible
# à	PRP	à
# l'	DET:ART	le
# émotion	NOM	émotion
# d'	PRP	de
# autrui	NOM	autrui
# ,	PUN	,
# comme	KON	comme
# la	DET:ART	le
# plupart	NOM	plupart
# des	PRP:det	du
# gens	NOM	gens
# issus	ADJ	issu
# de	PRP	de
# campagnards	NOM	campagnard
# ,	PUN	,
# qui	PRO:REL	qui
# gardent	VER:pres	garder
# toujours	ADV	toujours
# à	PRP	à
# l'	DET:ART	le
# âme	NOM	âme
# quelque	PRO:IND	quelque
# chose	NOM	chose
# de	PRP	de
# la	DET:ART	le
# callosité	NOM	callosité
# des	PRP:det	du
# mains	NOM	main
# paternelles	ADJ	paternel
# .	SENT	.
# Vers	PRP	vers
# la	DET:ART	le
# fin	NOM	fin
# de	PRP	de
# février	NOM	février
# ,	PUN	,
# le	DET:ART	le
# père	NOM	père
# Rouault	NAM	<unknown>
# ,	PUN	,
# en	PRP	en
# souvenir	VER:infi	souvenir
# de	PRP	de
# sa	DET:POS	son
# guérison	NOM	guérison
# ,	PUN	,
# apporta	VER:simp	apporter
# lui-même	PRO:PER	lui-même
# à	PRP	à
# son	DET:POS	son
# gendre	NOM	gendre
# une	DET:ART	un
# dinde	NOM	dinde
# superbe	ADJ	superbe
# ,	PUN	,
# et	KON	et
# il	PRO:PER	il
# resta	VER:simp	rester
# trois	NUM	trois
# jours	NOM	jour
# à	PRP	à
# Tostes	NAM	<unknown>
# .	SENT	.
# Charles	NAM	Charles
# étant	VER:ppre	être
# à	PRP	à
# ses	DET:POS	son
# malades	NOM	malade
# ,	PUN	,
# Emma	NAM	Emma
# lui	PRO:PER	lui
# tint	VER:simp	tenir
# compagnie	NOM	compagnie
# .	SENT	.
# Il	PRO:PER	il
# fuma	VER:simp	fumer
# dans	PRP	dans
# la	DET:ART	le
# chambre	NOM	chambre
# ,	PUN	,
# cracha	VER:simp	cracher
# sur	PRP	sur
# les	DET:ART	le
# chenets	NOM	<unknown>
# ,	PUN	,
# causa	VER:simp	causer
# culture	NOM	culture
# ,	PUN	,
# veaux	NOM	veau
# ,	PUN	,
# vaches	NOM	vache
# ,	PUN	,
# volailles	NOM	volaille
# et	KON	et
# conseil	NOM	conseil
# municipal	ADJ	municipal
# ;	PUN	;
# si	KON	si
# bien	ADV	bien
# qu'	KON	que
# elle	PRO:PER	elle
# referma	VER:simp	refermer
# la	DET:ART	le
# porte	NOM	porte
# ,	PUN	,
# quand	KON	quand
# il	PRO:PER	il
# fut	VER:simp	être
# parti	VER:pper	partir
# ,	PUN	,
# avec	PRP	avec
# un	DET:ART	un
# sentiment	NOM	sentiment
# de	PRP	de
# satisfaction	NOM	satisfaction
# qui	PRO:REL	qui
# la	PRO:PER	la
# surprit	VER:simp	surprendre
# elle-même	PRO:PER	elle-même
# .	SENT	.
# D'ailleurs	ADV	d'ailleurs
# ,	PUN	,
# elle	PRO:PER	elle
# ne	ADV	ne
# cachait	VER:impf	cacher
# plus	ADV	plus
# son	DET:POS	son
# mépris	NOM	mépris
# pour	PRP	pour
# rien	NOM	rien
# ,	PUN	,
# ni	KON	ni
# pour	PRP	pour
# personne	NOM	personne
# ;	PUN	;
# et	KON	et
# elle	PRO:PER	elle
# se	PRO:PER	se
# mettait	VER:impf	mettre
# quelquefois	ADV	quelquefois
# à	PRP	à
# exprimer	VER:infi	exprimer
# des	PRP:det	du
# opinions	NOM	opinion
# singulières	ADJ	singulier
# ,	PUN	,
# blâmant	VER:ppre	blâmer
# ce	PRO:DEM	ce
# que	PRO:REL	que
# l'	DET:ART	le
# on	PRO:PER	on
# approuvait	VER:impf	approuver
# ,	PUN	,
# et	KON	et
# approuvant	VER:ppre	approuver
# des	PRP:det	du
# choses	NOM	chose
# perverses	ADJ	pervers
# ou	KON	ou
# immorales	ADJ	immoral
# :	PUN	:
# ce	PRO:DEM	ce
# qui	PRO:REL	qui
# faisait	VER:impf	faire
# ouvrir	VER:infi	ouvrir
# de	PRP	de
# grands	ADJ	grand
# yeux	NOM	il
# à	PRP	à
# son	DET:POS	son
# mari	NOM	mari
# .	SENT	.

# %%
with codecs.open(fichierBrut.replace(".txt","-TT.txt"),"w",encoding="utf8") as outFile:
    outFile.write(resultLines)
