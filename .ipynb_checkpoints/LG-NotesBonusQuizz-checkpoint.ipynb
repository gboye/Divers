# %%
import pandas as pd
import numpy as np

# %%
debug=0

# %% [raw]
# notesNom="/Users/gilles/Downloads/LNS1M41 Notes-Majeure.csv"
# notesNom=u"/Users/gilles/Downloads/LNS1U4-LNS1T2-NotesMineures.csv"
# notesNom=u"/Users/gilles/Downloads/LNS1U4-LNS1T2-NotesMajeure.csv"
# notesNom=u"/Users/gilles/Downloads/LNS2U2-QuizzBonus.csv"
# dfNotes=pd.read_csv(notesNom,sep="\t",encoding="utf8")
#
# dfNotes.set_index([u'Nom', u'Prénom'],inplace=True)

# %% [markdown]
# ⚠️ Attention à fournir un fichier XLSX

# %%
notesNom=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/19-LNS1U4-LNS1T2-eCampus-Majeure.xlsx"
notesNom=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/19-LNS1U4-LNS1T2-eCampus-Mineures.xlsx"
notesNom=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/19-Session2-LNS1U4-LNS1T2-eCampus-Majeure.xlsx"
# notesNom=u"/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/19-Session2-LNS1U4-LNS1T2-eCampus-Mineures-Final.xlsx"

# %%
xls = pd.ExcelFile(notesNom)
xls.sheet_names
# Out:
# [u'Calculs']

# %%
dfNotes=pd.read_excel(notesNom,encoding="utf8")
dfNotes = pd.read_excel(xls, sheet_name=u'Calculs',encoding="utf8")
dfNotes.set_index([u'Nom', u'Prénom'],inplace=True)

# %%
dfNotes
# Out:
#                                Numéro d'identification   Numéro INE Prasi1  \
# Nom              Prénom
# ABDALLAH         MAELIS                         385180  070418694AJ   12.5
# ABDERREBI        CAMILLIA                       374204  153335178KE      -
# ABDOU            MELOE                          384307  1308014432T      -
# ANDRIANTSIFERANA NANDRIANINA                    384656  0756AT03I86      -
# ANDRIES          SOPHIE                         380354  070384906EA   4.31
# ASSELIN          ISANDRE                        385107  153334070DJ   4.17
# AUDRAN           MANON                          380271  082001200HJ   8.61
# AZOUNI           ANAIS                          387238  0110029001R      -
# BADI             SOPHIA                         384841  080028834EG   3.96
# BAILLY           ALEXIA                         386579  070877230JJ      0
# BARBOTIN         MANON                          386909  1309005417A   3.06
# BARRAT           FANY                           380991  0410001698V   17.5
# BEAUVAIS         CAMILLE                        381551  153332923CB   3.06
# BECCACCIA        ANDREA                         384802  0409043187K  16.46
# BENARD           ZOE                            380191  080943540FA  16.67
# BERARD           LOUIS                          350705  0411043212A  15.42
# BERNARD          FIONA                          385579  071925605JK      0
# BIROCHAU         MARIE-AMELIE                   388320  080927915FJ      -
# BLANDIE          MELISSA                        382957  070654801KG  12.08
# BONNEAU          LISE                           384439  060801972FD      -
# BORDERIE         MAEVA                          381407  070746845AJ  18.75
# BOTTIN           ANDREA                         383137  061151088EA  13.33
# BOUFFARD         JADE                           371834  050141741JB   0.42
# BOURDET          CHIFIU                         381808  050148603AK   1.25
# BRENDEL-CANTAUT  TIMOTHEE                       389538  111045607KA   8.33
# CAILLABET        LUCIE                          382263  060885109EF  18.75
# CANTIN           LILAS-ROSE                     387265  080691807GJ   1.25
# CAPARROS         LEA                            380627  0408021073S  11.25
# CARAES           SALOME                         386807  070129661HJ      0
# CARNEVALE        HUGO                           380685  040032017HH  12.08
# ...                                                ...          ...    ...
# PUCH             ANTOINE                        365436  0409024417H      -
# RAFFY            LOU                            381377  040028474DB  18.75
# REY-JULLIAND     MAILYS                         383998  153302069CK  12.92
# RIBEIRO FARROCO  DORIANE                        385083  070104755FF  16.67
# RIVAT            NOLWENN                        383649  080725080GG     10
# RIVERON          ALBANE                         382527  153313401EG  18.75
# RIVES            LYSA                           380146  080685564AG   2.08
# RODRIGUES        EMMA                           380475  8017002550G  10.42
# ROUDAUT          MARINE                         386948  123074628DK      0
# SALMAN           BETUL                          380908  090978657GJ      -
# SAMIER-JARLOV    VICTOIRE                       321693  0407003937J  13.54
# SAPUTA           JONATHAN                       368340  073ZQT00I42     10
# SCHMITT          SALOME                         385537  0809019485F      -
# SCHOEFFTER       ELOISE                         357449  0410006135T      -
# SELLAOUI         ABDELHALIM                     383619  110765402GC      -
# SENECHAU         SARAH                          371046  071663076DK   5.83
# SETINO           LEANA                          387384  081738946EE      -
# SHIGETOMI        KEALA                          319178  4108003235H      5
# SOLSONA          ADELE                          369000  073ZQT00OW6  18.75
# STASICA          ALEX                           380187  080125501JJ  16.67
# THEILLOUT        CAMILLE                        367984  070896842HA      -
# THOMAS           ALLAN                          388926  071842252CC      -
# TOTO             NOURDINE                       391436  113039345KA      -
# TRAUSCH          MELISSA                        381537  072127907DC      0
# TURPEAU          MARGAUX                        384250  100803807EJ   3.33
# UHALDE           CHARLOTTE                      383882  091102400KH      -
# VAUTARD          MARION                         381009  081810063CJ  17.08
# VEDRENNE         SOLENE                         368081  081956123FA   5.83
# VILLENEUVE       MATHILDE                       383431  071023978AE  16.25
# ZANA             ARIELLE                        381373  081149855FE  16.25
#
#                               Prasi2  Prasi  Yomig KartinV KartinT NemasV  \
# Nom              Prénom
# ABDALLAH         MAELIS        17.92  17.92  13.75   17.08   15.83  14.72
# ABDERREBI        CAMILLIA          -      -      -       -       -      -
# ABDOU            MELOE          5.14   5.14  11.11   11.67    5.83   4.17
# ANDRIANTSIFERANA NANDRIANINA       -      -      -       -       -      -
# ANDRIES          SOPHIE         5.42   5.42   2.92    4.44     2.5  10.83
# ASSELIN          ISANDRE        6.25   6.25   8.33   18.33   16.67     10
# AUDRAN           MANON         16.67  16.67  11.81   16.67    5.83  15.83
# AZOUNI           ANAIS             -      -      -       -       -      -
# BADI             SOPHIA        10.83  10.83  13.75   14.17       0  19.17
# BAILLY           ALEXIA            0      0      -       0    1.67      -
# BARBOTIN         MANON         11.67  11.67   8.13   10.83     2.5  18.33
# BARRAT           FANY              -   17.5     20   18.33    8.75     20
# BEAUVAIS         CAMILLE        2.92   3.06   6.67       -       -      -
# BECCACCIA        ANDREA            -  16.46  17.92   16.67   11.67  19.17
# BENARD           ZOE               -  16.67  14.58   19.17    17.5  19.17
# BERARD           LOUIS             -  15.42  18.75   19.17    4.17     20
# BERNARD          FIONA          8.75   8.75      -       -       -      -
# BIROCHAU         MARIE-AMELIE      -      -      -       -       -      -
# BLANDIE          MELISSA           -  12.08  16.67      15   18.33  19.17
# BONNEAU          LISE              -      -      -       -       -      -
# BORDERIE         MAEVA             -  18.75  16.25   19.17   19.17     20
# BOTTIN           ANDREA            -  13.33     10    17.5   11.67   17.5
# BOUFFARD         JADE           6.67   6.67   12.5   19.17    7.92     20
# BOURDET          CHIFIU         0.42   1.25      -    1.67       -      0
# BRENDEL-CANTAUT  TIMOTHEE       6.67   8.33  16.25    17.5   11.67  10.42
# CAILLABET        LUCIE             0  18.75  15.42   19.17   13.75  15.83
# CANTIN           LILAS-ROSE       15     15   12.5   16.67    12.5   12.5
# CAPARROS         LEA           15.83  15.83  15.83   15.83   11.67  16.67
# CARAES           SALOME         0.83   0.83      -       0       -      -
# CARNEVALE        HUGO              -  12.08  18.75   15.83   15.83  16.67
# ...                              ...    ...    ...     ...     ...    ...
# PUCH             ANTOINE           -      -      -       -       -      -
# RAFFY            LOU               -  18.75  17.08   16.67   14.58     20
# REY-JULLIAND     MAILYS            -     20   8.75   16.67    1.67  16.67
# RIBEIRO FARROCO  DORIANE          15  16.67  12.92       -   11.67      -
# RIVAT            NOLWENN       17.08  17.08   3.33   18.33   19.17  19.17
# RIVERON          ALBANE            -  18.75  16.25      20   14.17     20
# RIVES            LYSA          11.67  11.67  12.92      15    8.89  18.33
# RODRIGUES        EMMA           9.38  10.42  17.92      20    9.17  15.83
# ROUDAUT          MARINE            -      0      -       0       0   0.83
# SALMAN           BETUL             -      -      -       -       -      -
# SAMIER-JARLOV    VICTOIRE       5.83  13.54  15.83      20    9.17  18.33
# SAPUTA           JONATHAN       3.47     10   7.08    12.5   10.83      0
# SCHMITT          SALOME            -      -      -       -       -      -
# SCHOEFFTER       ELOISE        10.42     20   17.5   16.67   10.83  15.83
# SELLAOUI         ABDELHALIM        -      -      -       -       -      -
# SENECHAU         SARAH             -   5.83   17.5   19.17   18.33   17.5
# SETINO           LEANA             -      -      -       -       -      -
# SHIGETOMI        KEALA          8.75   8.75   5.42    12.5    4.17     15
# SOLSONA          ADELE             -  18.75  19.58   19.17   14.17     20
# STASICA          ALEX          10.42  16.67  15.83   19.17   14.17     20
# THEILLOUT        CAMILLE           -      -      -       -       -      -
# THOMAS           ALLAN             -      -      -       -       -      -
# TOTO             NOURDINE          -      -      -       -       -      -
# TRAUSCH          MELISSA           -      0      -       -       -      -
# TURPEAU          MARGAUX        7.71   7.71  11.88   16.67    3.33   17.5
# UHALDE           CHARLOTTE         -      -   0.83    3.33       0   4.17
# VAUTARD          MARION            -  17.08  18.75      20   11.67  19.17
# VEDRENNE         SOLENE        15.83  15.83  15.42   18.33   13.89  19.17
# VILLENEUVE       MATHILDE          -  16.25  14.17   13.33    5.83  19.17
# ZANA             ARIELLE           -  16.25   12.5    17.5    4.58  16.25
# RIVERON          ALBANE                                   1580291490  18.0
# RIVES            LYSA                                     1580291490  15.0
# RODRIGUES        EMMA                                     1580291490  14.0
# ROUDAUT          MARINE                                   1580291490   6.0
# SALMAN           BETUL                                    1580291490   NaN
# SAMIER-JARLOV    VICTOIRE                                 1580291490  15.0
# SAPUTA           JONATHAN                                 1580291490  11.0
# SCHMITT          SALOME                                   1580291490   NaN
# SCHOEFFTER       ELOISE                                   1580291490   9.0
# SELLAOUI         ABDELHALIM                               1580291490   NaN
# SENECHAU         SARAH                                    1580291490  16.0
# SETINO           LEANA                                    1580291490   NaN
# SHIGETOMI        KEALA                                    1580291490  10.0
# SOLSONA          ADELE                                    1580291490  18.0
# STASICA          ALEX                                     1580291490  18.0
# THEILLOUT        CAMILLE                                  1580291490   NaN
# THOMAS           ALLAN                                    1580291490   NaN
# TOTO             NOURDINE                                 1580291490   NaN
# TRAUSCH          MELISSA                                  1580291490   2.0
# TURPEAU          MARGAUX                                  1580291490  13.0
# UHALDE           CHARLOTTE                                1580291490  10.0
# VAUTARD          MARION                                   1580291490  17.0
# VEDRENNE         SOLENE                                   1580291490  14.0
# VILLENEUVE       MATHILDE                                 1580291490  15.0
# ZANA             ARIELLE                                  1580291490  13.0
#
#                               NoteCC Gain
# Nom              Prénom
# ABDALLAH         MAELIS           15  0.0
# ABDERREBI        CAMILLIA          0  NaN
# ABDOU            MELOE             8  3.0
# ANDRIANTSIFERANA NANDRIANINA       0  NaN
# ANDRIES          SOPHIE            6  4.0
# ASSELIN          ISANDRE          11  2.0
# AUDRAN           MANON            11  3.0
# AZOUNI           ANAIS             0  NaN
# BADI             SOPHIA           11  1.0
# BAILLY           ALEXIA            4  5.0
# BARBOTIN         MANON             9  0.0
# BARRAT           FANY             16  1.0
# BEAUVAIS         CAMILLE           3  5.0
# BECCACCIA        ANDREA           17  1.0
# BENARD           ZOE              13  2.0
# BERARD           LOUIS            16  1.0
# BERNARD          FIONA             1  2.0
# BIROCHAU         MARIE-AMELIE      0  NaN
# BLANDIE          MELISSA          15  1.0
# BONNEAU          LISE              0  NaN
# BORDERIE         MAEVA            18  1.0
# BOTTIN           ANDREA           12  3.0
# BOUFFARD         JADE             14  0.0
# BOURDET          CHIFIU            2  5.0
# BRENDEL-CANTAUT  TIMOTHEE         10  3.0
# CAILLABET        LUCIE            15  0.0
# CANTIN           LILAS-ROSE       12  1.0
# CAPARROS         LEA              14  0.0
# CARAES           SALOME            0  4.0
# CARNEVALE        HUGO             15  2.0
# ...                              ...  ...
# PUCH             ANTOINE           0  NaN
# RAFFY            LOU              15  2.0
# REY-JULLIAND     MAILYS            9  3.0
# RIBEIRO FARROCO  DORIANE           6  0.0
# RIVAT            NOLWENN          15  0.0
# RIVERON          ALBANE           18  0.0
# RIVES            LYSA             13  2.0
# RODRIGUES        EMMA             13  1.0
# ROUDAUT          MARINE            0  6.0
# SALMAN           BETUL             0  NaN
# SAMIER-JARLOV    VICTOIRE         12  3.0
# SAPUTA           JONATHAN          7  4.0
# SCHMITT          SALOME            0  NaN
# SCHOEFFTER       ELOISE            8  1.0
# SELLAOUI         ABDELHALIM        0  NaN
# SENECHAU         SARAH            16  0.0
# SETINO           LEANA             0  NaN
# SHIGETOMI        KEALA             9  1.0
# SOLSONA          ADELE            17  1.0
# STASICA          ALEX             18  0.0
# THEILLOUT        CAMILLE           0  NaN
# THOMAS           ALLAN             0  NaN
# TOTO             NOURDINE          0  NaN
# TRAUSCH          MELISSA           0  2.0
# TURPEAU          MARGAUX          12  1.0
# UHALDE           CHARLOTTE         6  4.0
# VAUTARD          MARION           16  1.0
# VEDRENNE         SOLENE           14  0.0
# VILLENEUVE       MATHILDE         12  3.0
# ZANA             ARIELLE          12  1.0
#
# [184 rows x 28 columns]

# %% [markdown]
# #### sélection des colonnes
# - notesCC pour le contrôle continu
# - notesQuizz pour les quizz en CM

# %%
notesCC=[u'Prasi', u'Yomig', u'KartinV', u'KartinT', u'NemasV', u'NemasT',
         u'CoupeMot', u'CoupeMorphe'
        ]
# notesCC=u"Morpho1 Morpho2 Bizar1 Bizar2 Phono Sem".split(" ")
# notesQuizz=sorted([u"Quizz%d"%(n+1) for n in range(2,8)]+[u"Quizz7b"])
notesQuizz=sorted([u"Q%02d"%(n+1) for n in range(10)])
# dfNotes=dfNotesXLS[notesCC+notesQuizz]
dfNotes.head()
# Out:
#                               Numéro d'identification   Numéro INE Prasi1  \
# Nom              Prénom
# ABDALLAH         MAELIS                        385180  070418694AJ   12.5
# ABDERREBI        CAMILLIA                      374204  153335178KE      -
# ABDOU            MELOE                         384307  1308014432T      -
# ANDRIANTSIFERANA NANDRIANINA                   384656  0756AT03I86      -
# ANDRIES          SOPHIE                        380354  070384906EA   4.31
#
#                              Prasi2  Prasi  Yomig KartinV KartinT NemasV  \
# Nom              Prénom
# ABDALLAH         MAELIS       17.92  17.92  13.75   17.08   15.83  14.72
# ABDERREBI        CAMILLIA         -      -      -       -       -      -
# ABDOU            MELOE         5.14   5.14  11.11   11.67    5.83   4.17
# ANDRIANTSIFERANA NANDRIANINA      -      -      -       -       -      -
# ANDRIES          SOPHIE        5.42   5.42   2.92    4.44     2.5  10.83
#
#                              NemasT ...  Q05 Q06 Q07 Q08 Q09 Q10  \
# Nom              Prénom             ...
# ABDALLAH         MAELIS       12.22 ...   11  14  13  13   -  12
# ABDERREBI        CAMILLIA         - ...    -   -   -   -   -   -
# ABDOU            MELOE         1.11 ...   11  14  12  15   -  10
# ANDRIANTSIFERANA NANDRIANINA      - ...    -   -   -   -   -   -
# ANDRIES          SOPHIE           0 ...    -  13  13  15  13  13
#
#                              Dernier téléchargement depuis ce cours  Note  \
# Nom              Prénom
# ABDALLAH         MAELIS                                  1580291490  15.0
# ABDERREBI        CAMILLIA                                1580291490   NaN
# ABDOU            MELOE                                   1580291490  11.0
# ANDRIANTSIFERANA NANDRIANINA                             1580291490   NaN
# ANDRIES          SOPHIE                                  1580291490  10.0
#
#                              NoteCC Gain
# Nom              Prénom
# ABDALLAH         MAELIS          15  0.0
# ABDERREBI        CAMILLIA         0  NaN
# ABDOU            MELOE            8  3.0
# ANDRIANTSIFERANA NANDRIANINA      0  NaN
# ANDRIES          SOPHIE           6  4.0
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Calcul des notes avec bonification
# Toutes les notes du CC (*nbCC*) comptent et on inclue aussi les *nbCC* meilleures notes des Quizz en partant de la meilleure une par une
# - *notes* contient toutes les moyennes calculées
# - on retourne le max de *notes*

# %%
def moyenneCC(x):
    if debug: print x.name
    xNotesCC=sorted([n for n in x[notesCC].tolist() if not (n=="-" or np.isnan(n))],reverse=True)
    sommeNotes=float(sum(xNotesCC))
    nbNotes=len(notesCC)
    moyenneInitiale=round(sommeNotes/nbNotes+.25)
    return moyenneInitiale

# %%
def bonus(x):
    if debug: print x.name
    xNotesCC=sorted([n for n in x[notesCC].tolist() if not (n=="-" or np.isnan(n))],reverse=True)
    sommeNotes=float(sum(xNotesCC))
    nbNotes=len(notesCC)
    moyenneInitiale=round(sommeNotes/nbNotes+.25)
    xNotesBonus=sorted([n for n in x[notesQuizz].tolist() if not (n=="-" or np.isnan(n))],reverse=True)
    if debug: print "Quizz",xNotesBonus
    if debug: print "CC",xNotesCC
    if xNotesCC:
        notes=[]
        nbCC=len(xNotesCC)
        bonusNotes=xNotesBonus
        if len(bonusNotes)>nbCC:
            bonusNotes=bonusNotes[:nbCC]
        notes.append(moyenneInitiale)
        if debug: print "somme", sommeNotes,"moyenne brut",sommeNotes/nbNotes
        if debug: print "moyenne initiale",moyenneInitiale,"bonus",bonusNotes
        for b in bonusNotes:
            sommeNotes+=b
            nbNotes+=1
            nouvelleMoyenne=round(float(sommeNotes)/nbNotes+.25)
            notes.append(nouvelleMoyenne)
            if debug: print b,sommeNotes,nbNotes, nouvelleMoyenne
        if debug: print notes
        return max(notes)
    else:
        return np.nan

# %% [markdown]
# ### Ajout de la colonne **Notes** à la structure et exportation
# - apply(lambda x: bonus(x), axis=1) permet d'appliquer la fonction bonus à chaque ligne
#  - la fonction bonus reçoit une ligne de données complète
#  - les valeurs sont accessibles par colonne
# - on ajoute 3 colonnes
#  - Note pour la note de contrôle continu avec les bonus de quizz
#  - NoteCC pour la note des exercices en ligne brute
#  - Gain pour la différence entre les deux notes

# %%
dfNotes.loc[:,"Note"]=dfNotes.loc[:,notesCC+notesQuizz].apply(lambda x: bonus(x),axis=1)
dfNotes.loc[:,"NoteCC"]=dfNotes.loc[:,notesCC].apply(lambda x: moyenneCC(x),axis=1)

# %%
dfNotes["Gain"]=dfNotes["Note"]-dfNotes["NoteCC"]

# %%
dfNotes["Gain"].mean()
# Out:
# 1.5806451612903225

# %%
dfNotes.to_excel(notesNom.replace(".xls","-Final.xls"),encoding="utf8")
