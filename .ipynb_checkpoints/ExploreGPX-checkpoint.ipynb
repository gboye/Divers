# %%
from lxml import etree
debug=False

# %%
parser = etree.XMLParser(remove_blank_text=True)

# %%
nomLoc="/Users/gilles/Downloads/18303005_ComtéduLabourd/18303005_ComtÇ du Labourd.gpx"
wptChildren=["name","urlname"]

# %%
def localName(element):
    return etree.QName(element).localname

# %%
def Dec2Min(coord):
    degreSign=""
    intDegres=int(coord)
    decDegres=coord%1
    minutes=decDegres*60
    return "%d%s %5.3f"%(intDegres,degreSign,minutes)

# %%
def CoordDec2Min(lat,lon):
    coordLat=Dec2Min(lat)
    coordLon=Dec2Min(lon)
    if coordLat.startswith("-"):
        coordLat="S"+coordLat[1:]
    else:
        coordLat="N"+coordLat
    if coordLon.startswith("-"):
        coordLon="W"+coordLon[1:]
    else:
        coordLon="E"+coordLon
    print coordLat,coordLon

# %%
def dictLatLon2Coord(dictLatLon):
    return CoordDec2Min(float(dictLatLon["lat"]),float(dictLatLon["lon"]))

# %%
CoordDec2Min(43.3019167,-1.57305)
# Out:
# N43 18.115 W1 25.617

# %%
tree = etree.parse(nomLoc)
root = tree.getroot()
print root.nsmap
# Out:
# {'xsi': 'http://www.w3.org/2001/XMLSchema-instance', None: 'http://www.topografix.com/GPX/1/0', 'xsd': 'http://www.w3.org/2001/XMLSchema'}

# %%
for wp in root.findall("{%s}wpt"%root.nsmap[None]):
    if debug: print localName(wp), 
    print dictLatLon2Coord(wp.attrib)
    for element in wp:
        print "\t",localName(element),element.text
        if len(element.attrib)>0:
            for attrib in element.attrib:
                print "\t - %s : %s,"%(attrib,element.attrib[attrib])
            print
        if len(element) >0:
            cache=element
            for node in cache:
                if not "description" in localName(node):
                    print "\t\t",localName(node),
                    if node.text:
                        print node.text.replace("\n"," "),
                    print
# Out:
# wpt N43 24.136 W1 25.617
# None
# 	time 2015-03-24T07:00:00Z
# 	name GC5Q1P4
# 	desc #L1-01 Ahetze - Le Comté du Labourd by gilles64, Multi-cache (1.5/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=924c6949-26cd-4f6d-9a3c-98852cf533ee
# 	urlname #L1-01 Ahetze - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 4893325,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L1-01 Ahetze - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 1.5
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Au pieds des 2 ! Relever l'indice sur le logbook
# 		logs
# 		travelbugs
# wpt N43 20.622 W1 22.833
# None
# 	time 2015-05-06T07:00:00Z
# 	name GC5TZE6
# 	desc #L1-02 Ascain - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=234fff06-dc17-4cfc-b582-a909a89bb988
# 	urlname #L1-02 Ascain - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 4980530,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L1-02 Ascain - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Bamboula au poteau !
# 		logs
# 		travelbugs
# wpt N43 25.603 W1 23.542
# None
# 	time 2015-05-15T07:00:00Z
# 	name GC5VHWJ
# 	desc #L1-05 Guéthary - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=0b38af29-bb0d-4711-9cfb-9e7b0c68b2a1
# 	urlname #L1-05 Guéthary - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 4998243,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L1-05 Guéthary - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Prendre le bon sens !
# 		logs
# 		travelbugs
# wpt N43 18.957 W1 24.919
# None
# 	time 2015-05-16T07:00:00Z
# 	name GC5VK6E
# 	desc #L1-09 Sare - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=b146215f-657a-4608-a84b-66424cad2b1b
# 	urlname #L1-09 Sare - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 4999510,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L1-09 Sare - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Une pose s'impose !
# 		logs
# 		travelbugs
# wpt N43 28.505 W1 47.799
# None
# 	time 2015-05-30T07:00:00Z
# 	name GC5WH9X
# 	desc #L2-01 Bardos - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=58c86657-ef4d-4a37-b1cd-519ff7f23ad5
# 	urlname #L2-01 Bardos - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5027486,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L2-01 Bardos - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Pendu !
# 		logs
# 		travelbugs
# wpt N43 31.166 W1 30.906
# None
# 	time 2015-06-01T07:00:00Z
# 	name GC5WPFC
# 	desc #L4-08 Boucau - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=2ccf32a7-20ed-4b05-af2f-78d7878bedd4
# 	urlname #L4-08 Boucau - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5032461,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L4-08 Boucau - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Dans la fente à gauche !
# 		logs
# 		travelbugs
# wpt N43 30.809 W1 47.981
# None
# 	time 2015-06-03T07:00:00Z
# 	name GC5WVAK
# 	desc #L2-03 Guiche - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=9b3bc978-cd4b-4fe6-9a38-b354a1719908
# 	urlname #L2-03 Guiche - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5036157,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L2-03 Guiche - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Au cœur !
# 		logs
# 		travelbugs
# wpt N43 29.676 W1 42.544
# None
# 	time 2015-06-14T07:00:00Z
# 	name GC5XGMY
# 	desc #L2-10 Urt - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=1ae11db2-0e8f-4f03-9aa5-f6122733273b
# 	urlname #L2-10 Urt - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5056658,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L2-10 Urt - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Troussoucaillou !
# 		logs
# 		travelbugs
# wpt N43 22.577 W1 34.515
# None
# 	time 2015-06-14T07:00:00Z
# 	name GC5XH1V
# 	desc #L3-05 Halsou - Le Comté du Labourd by gilles64, Multi-cache (1.5/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=5d1a34c7-fa2e-47e5-b409-1dce3cae6086
# 	urlname #L3-05 Halsou - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5057027,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L3-05 Halsou - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 1.5
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Roche et pierreSpoiler
# 		logs
# 		travelbugs
# wpt N43 26.744 W1 29.488
# None
# 	time 2015-06-16T07:00:00Z
# 	name GC5XMEE
# 	desc #L4-04 Bassussarry - Le Comté du Labourd by gilles64, Unknown Cache (2.5/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=9c46f5b6-ef9c-42f9-bf82-2347afa9dc33
# 	urlname #L4-04 Bassussarry - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Unknown Cache
# 	cache
#
# 	 - id : 5060301,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L4-04 Bassussarry - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Unknown Cache
# 		container Micro
# 		attributes
# 		difficulty 2.5
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints 1.8 m entre mes 2 !
# 		logs
# 		travelbugs
# wpt N43 23.128 W1 41.929
# None
# 	time 2015-06-17T07:00:00Z
# 	name GC5XPWE
# 	desc #L2-04 Hasparren - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=e1a2971c-d866-4b68-8f59-7ab7063a3a11
# 	urlname #L2-04 Hasparren - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5062626,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L2-04 Hasparren - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Sésame, ouvre-toi ! 2 m, en moi ! Sésame, referme-toi !
# 		logs
# 		travelbugs
# wpt N43 23.307 W1 34.291
# None
# 	time 2015-06-20T07:00:00Z
# 	name GC5XW15
# 	desc #L2-05 Jatxou - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=8dde409c-5346-4967-a10d-4846f58b2ce3
# 	urlname #L2-05 Jatxou - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5066616,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L2-05 Jatxou - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints 1,8 m au pieds du laurier pas assez épais pour en faire un bouchon. Spoiler
# 		logs
# 		travelbugs
# wpt N43 26.613 W1 40.087
# None
# 	time 2015-06-20T07:00:00Z
# 	name GC5XWEH
# 	desc #L2-02 Briscous - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=256c968c-743c-4b18-9fba-28b2e77de199
# 	urlname #L2-02 Briscous - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5067031,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L2-02 Briscous - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints C'est le pieds !Spoiler
# 		logs
# 		travelbugs
# wpt N43 19.051 W1 38.725
# None
# 	time 2015-06-21T07:00:00Z
# 	name GC5XYDD
# 	desc #L3-08 Louhossoa - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=27965fa8-ceb0-433a-a384-ff828a1e926f
# 	urlname #L3-08 Louhossoa - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5068918,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L3-08 Louhossoa - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Dans la fente !Spoiler
# 		logs
# 		travelbugs
# wpt N43 19.639 W1 40.713
# None
# 	time 2015-06-22T07:00:00Z
# 	name GC5Y093
# 	desc #L3-09 Macaye - Le Comté du Labourd by gilles64, Multi-cache (2.5/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=a379a55b-6d8a-49a5-a18c-4f36ba1cf52c
# 	urlname #L3-09 Macaye - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5070706,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L3-09 Macaye - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2.5
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Coiffée au poteau !
# 		logs
# 		travelbugs
# wpt N43 25.913 W1 26.961
# None
# 	time 2015-07-29T07:00:00Z
# 	name GC60D95
# 	desc #L4-02 Arbonne - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=b9a50c60-2993-41e3-98a8-531ba466963a
# 	urlname #L4-02 Arbonne - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5142783,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L4-02 Arbonne - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints 9, 31/61
# 		logs
# 		travelbugs
# wpt N43 23.560 W1 33.404
# None
# 	time 2015-08-05T07:00:00Z
# 	name GC60XNZ
# 	desc #L4-09 Ustaritz - Le Comté du Labourd by gilles64, Multi-cache (2.5/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=11b8ace3-09b7-4c33-9c61-5600774d96ef
# 	urlname #L4-09 Ustaritz - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5157595,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L4-09 Ustaritz - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2.5
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Préfère la gloire à la justice ! 1.5m
# 		logs
# 		travelbugs
# wpt N43 18.326 W1 30.916
# None
# 	time 2015-08-08T07:00:00Z
# 	name GC6145W
# 	desc #L3-01 Ainhoa - Le Comté du Labourd by gilles64, Multi-cache (3.5/3.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=81451c5e-d792-4909-84ef-8422ea696d5b
# 	urlname #L3-01 Ainhoa - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5163823,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L3-01 Ainhoa - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 3.5
# 		terrain 3.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Le passage par le géochecker est obligatoire Final Rocher Spoiler 3 et 4
# 		logs
# 		travelbugs
# wpt N43 26.182 W1 28.583
# None
# 	time 2015-08-09T07:00:00Z
# 	name GC61613
# 	desc #L4-03 Arcangues- Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=0c5715c9-afe2-4814-b9a9-916e74e459c0
# 	urlname #L4-03 Arcangues- Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5165597,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L4-03 Arcangues- Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Au pied du poteau !
# 		logs
# 		travelbugs
# wpt N43 22.315 W1 33.864
# None
# 	time 2015-08-14T07:00:00Z
# 	name GC61FTE
# 	desc #L3-07 Larressore - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=3fd8a053-3b0b-4aea-8bca-ff92ab8324cf
# 	urlname #L3-07 Larressore - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5175001,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L3-07 Larressore - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Dans le trou !
# 		logs
# 		travelbugs
# wpt N43 20.475 W1 31.584
# None
# 	time 2015-08-20T07:00:00Z
# 	name GC61XZ0
# 	desc #L3-11 Souraïde - Le Comté du Labourd by gilles64, Multi-cache (2/2)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=0cc7235b-a22a-4417-84cc-6d2669127d84
# 	urlname #L3-11 Souraïde - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5187635,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L3-11 Souraïde - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 2
# 		country France
# 		state Aquitaine
# 		encoded_hints Au pieds de Saint jacques !
# 		logs
# 		travelbugs
# wpt N43 20.014 W1 33.509
# None
# 	time 2015-08-21T07:00:00Z
# 	name GC620NM
# 	desc #L3-04 Espelette - Le Comté du Labourd by gilles64, Multi-cache (2.5/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=9e09e22d-cfcc-489a-af4b-23f3656ed7b1
# 	urlname #L3-04 Espelette - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5190259,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L3-04 Espelette - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Small
# 		attributes
# 		difficulty 2.5
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Au cœur !
# 		logs
# 		travelbugs
# wpt N43 22.392 W1 43.829
# None
# 	time 2015-08-22T07:00:00Z
# 	name GC621K4
# 	desc #L3-02 Bonloc - Le Comté du Labourd by gilles64, Multi-cache (2.5/2)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=0a6143d4-6bda-4362-95fd-59c03bf785b9
# 	urlname #L3-02 Bonloc - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5191142,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L3-02 Bonloc - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2.5
# 		terrain 2
# 		country France
# 		state Aquitaine
# 		encoded_hints La chèvre rit aux pieds !
# 		logs
# 		travelbugs
# wpt N43 20.863 W1 42.315
# None
# 	time 2015-08-26T07:00:00Z
# 	name GC62ACB
# 	desc #L3-10 Mendionde - Le Comté du Labourd by gilles64, Multi-cache (3/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=be94b708-0f62-4cc1-bc78-4718242421fb
# 	urlname #L3-10 Mendionde - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5199581,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L3-10 Mendionde - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 3
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Au pieds !
# 		logs
# 		travelbugs
# wpt N43 23.020 W1 19.481
# None
# 	time 2015-10-20T07:00:00Z
# 	name GC65E4Q
# 	desc #L1-04 Ciboure - Le Comté du Labourd by gilles64, Multi-cache (2.5/2)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=6eff2f47-c076-43ca-be72-8dbab1f78989
# 	urlname #L1-04 Ciboure - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5292562,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L1-04 Ciboure - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2.5
# 		terrain 2
# 		country France
# 		state Aquitaine
# 		encoded_hints Repose au coin !
# 		logs
# 		travelbugs
# wpt N43 23.972 W1 20.131
# None
# 	time 2015-10-28T07:00:00Z
# 	name GC65YFM
# 	desc #L1-07 Saint-Jean-de-Luz - Le Comté du Labourd by gilles64, Multi-cache (3/2)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=e05a1d78-fe09-4739-b089-73b75a608334
# 	urlname #L1-07 Saint-Jean-de-Luz - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5307315,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L1-07 Saint-Jean-de-Luz - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Small
# 		attributes
# 		difficulty 3
# 		terrain 2
# 		country France
# 		state Aquitaine
# 		encoded_hints Spoiler - Rocher !
# 		logs
# 		travelbugs
# wpt N43 19.973 W1 15.589
# None
# 	time 2015-11-22T08:00:00Z
# 	name GC6797B
# 	desc #L1-03 Biriatou - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=f9edb5fd-67a9-49c7-a97d-55acee47a52e
# 	urlname #L1-03 Biriatou - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5347420,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L1-03 Biriatou - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Lauburu !
# 		logs
# 		travelbugs
# wpt N43 27.686 W1 35.492
# None
# 	time 2015-11-26T08:00:00Z
# 	name GC67DY4
# 	desc #L2-07 Mouguerre - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=75e60e45-c68a-47b8-826d-eb6e009442fa
# 	urlname #L2-07 Mouguerre - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5351939,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L2-07 Mouguerre - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Bien fleuri !
# 		logs
# 		travelbugs
# wpt N43 21.532 W1 13.530
# None
# 	time 2015-12-01T08:00:00Z
# 	name GC67MGC
# 	desc #L1-06 Hendaye - Le Comté du Labourd by gilles64, Multi-cache (2/2)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=592889fc-9f74-4d53-bbac-d5d071598a98
# 	urlname #L1-06 Hendaye - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5358271,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L1-06 Hendaye - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 2
# 		country France
# 		state Aquitaine
# 		encoded_hints Mille feuilles !
# 		logs
# 		travelbugs
# wpt N43 21.552 W1 26.959
# None
# 	time 2015-12-08T08:00:00Z
# 	name GC67XQP
# 	desc #L1-08 Saint-Pée-sur-Nivelle - Le Comté du Labourd by gilles64, Multi-cache (2.5/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=2011865f-31ed-425c-927c-95ab41a70d2f
# 	urlname #L1-08 Saint-Pée-sur-Nivelle - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5366186,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L1-08 Saint-Pée-sur-Nivelle - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2.5
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Cherche la cerise ou fais-toi en une couronne si tu le mérites ! L'indice sera donné contre une photo envoyée à l'owner en MP pour preuve de passage...
# 		logs
# 		travelbugs
# wpt N43 19.681 W1 35.604
# None
# 	time 2015-12-24T08:00:00Z
# 	name GC68JC0
# 	desc #L3-06 Itxasou - Le Comté du Labourd by gilles64, Multi-cache (2.5/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=0855e42a-4982-4560-87f0-195be2f35895
# 	urlname #L3-06 Itxasou - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5386004,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L3-06 Itxasou - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2.5
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Faites les bons calculs, soyez à la hauteur et vous n'aurez pas la guigne comme diraient les Corses !
# 		logs
# 		travelbugs
# wpt N43 29.780 W1 31.526
# None
# 	time 2015-12-27T08:00:00Z
# 	name GC68Q53
# 	desc #L4-05 Bayonne - Le Comté du Labourd by gilles64, Multi-cache (3.5/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=950c0ffd-c7fe-4ef8-b264-d7c0e07b105a
# 	urlname #L4-05 Bayonne - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5390595,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L4-05 Bayonne - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 3.5
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Smiley au mouillage ! Spoiler
# 		logs
# 		travelbugs
# wpt N43 29.148 W1 39.980
# None
# 	time 2015-12-28T08:00:00Z
# 	name GC68QRT
# 	desc #L2-09 Urcuit - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=76ddb2d8-5853-493c-ba3a-b58666ce7c07
# 	urlname #L2-09 Urcuit - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5391206,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L2-09 Urcuit - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Prenez votre temps !
# 		logs
# 		travelbugs
# wpt N43 22.014 W1 18.067
# None
# 	time 2015-12-29T08:00:00Z
# 	name GC68TE4
# 	desc #L1-10 Urrugne - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=0ffef79f-8093-4ccd-87e5-0c43e390a20e
# 	urlname #L1-10 Urrugne - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5392797,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L1-10 Urrugne - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Celle là, il ne faut pas être branché pour la trouver mais dans la soupière ! Spoiler dans le checker
# 		logs
# 		travelbugs
# wpt N43 26.359 W1 33.075
# None
# 	time 2015-12-30T08:00:00Z
# 	name GC68WHD
# 	desc #L4-10 Villefranque - Le Comté du Labourd by gilles64, Multi-cache (2/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=7bf14e5e-3ecd-48b2-9bd8-273ce3daf842
# 	urlname #L4-10 Villefranque - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5394821,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L4-10 Villefranque - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Arbre au pied, voir spoiler
# 		logs
# 		travelbugs
# wpt N43 26.394 W1 24.541
# None
# 	time 2016-01-10T08:00:00Z
# 	name GC69GKT
# 	desc #L4-07 Bidart - Le Comté du Labourd by gilles64, Multi-cache (2.5/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=8e8f929b-13f6-4d60-aa63-7a5c98bb0b37
# 	urlname #L4-07 Bidart - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5414115,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L4-07 Bidart - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2.5
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Entre les 2 soupières ! Spoiler
# 		logs
# 		travelbugs
# wpt N43 29.193 W1 36.805
# None
# 	time 2016-01-19T08:00:00Z
# 	name GC69ZE2
# 	desc #L2-06 Lahonce - Le Comté du Labourd by gilles64, Multi-cache (2.5/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=5783be46-1e00-45de-9a19-dc0cb5746a55
# 	urlname #L2-06 Lahonce - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5427391,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L2-06 Lahonce - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2.5
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Soupières ! Spoiler
# 		logs
# 		travelbugs
# wpt N43 28.774 W1 32.371
# None
# 	time 2016-01-23T08:00:00Z
# 	name GC6A5X4
# 	desc #L2-08 Saint-Pierre-d'Irube - Le Comté du Labourd by gilles64, Multi-cache (2.5/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=79f3e9ac-9b20-47b3-b5b7-5551e9b8111f
# 	urlname #L2-08 Saint-Pierre-d'Irube - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5433593,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L2-08 Saint-Pierre-d'Irube - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2.5
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Sous toit ! 3/17
# 		logs
# 		travelbugs
# wpt N43 22.073 W1 36.431
# None
# 	time 2016-01-30T08:00:00Z
# 	name GC6AHVC
# 	desc #L3-03 Cambo-les-Bains - Le Comté du Labourd by gilles64, Multi-cache (2.5/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=c6aa8409-e051-470b-9fde-85edae8cc71a
# 	urlname #L3-03 Cambo-les-Bains - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5445071,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L3-03 Cambo-les-Bains - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Micro
# 		attributes
# 		difficulty 2.5
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Pot Haut Soupière !
# 		logs
# 		travelbugs
# wpt N43 21.351 W1 24.761
# None
# 	time 2016-05-24T07:00:00Z
# 	name GC6B82D
# 	desc #L1-Bonus - Le Comté du Labourd by gilles64, Unknown Cache (4/3)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=cc3d153b-fcb7-4774-9c9b-a1d47c8ca0df
# 	urlname #L1-Bonus - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Unknown Cache
# 	cache
#
# 	 - id : 5465470,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L1-Bonus - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Unknown Cache
# 		container Small
# 		attributes
# 		difficulty 4
# 		terrain 3
# 		country France
# 		state Aquitaine
# 		encoded_hints Au piquet pin !  Spoiler dans le Checker
# 		logs
# 		travelbugs
# wpt N43 28.755 W1 26.052
# None
# 	time 2016-03-29T07:00:00Z
# 	name GC6EG48
# 	desc #L4-06 Biarritz - Le Comté du Labourd by gilles64, Multi-cache (3/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=abc6b8ea-132e-4c5b-8edf-89b50dd1d404
# 	urlname #L4-06 Biarritz - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Multi-cache
# 	cache
#
# 	 - id : 5562588,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L4-06 Biarritz - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Multi-cache
# 		container Small
# 		attributes
# 		difficulty 3
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Spoiler, troudumur !
# 		logs
# 		travelbugs
# wpt N43 31.650 W1 28.720
# None
# 	time 2016-05-15T07:00:00Z
# 	name GC6HRR1
# 	desc #L4-01 Anglet - Le Comté du Labourd by gilles64, Unknown Cache (4/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=5f13763d-5f3a-4ec6-9589-83bbea781400
# 	urlname #L4-01 Anglet - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Unknown Cache
# 	cache
#
# 	 - id : 5660262,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L4-01 Anglet - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Unknown Cache
# 		container Micro
# 		attributes
# 		difficulty 4
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Pour la trouver il faut être sacrément tuyauté et avoir du spoiler !
# 		logs
# 		travelbugs
# wpt N43 24.636 W1 38.777
# None
# 	time 2016-05-24T07:00:00Z
# 	name GC6JDK5
# 	desc #L2-Bonus - Le Comté du Labourd  by gilles64, Unknown Cache (4/2)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=23e4826e-e86e-4e63-b0b2-5febf3239d3b
# 	urlname #L2-Bonus - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Unknown Cache
# 	cache
#
# 	 - id : 5679331,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L2-Bonus - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Unknown Cache
# 		container Small
# 		attributes
# 		difficulty 4
# 		terrain 2
# 		country France
# 		state Aquitaine
# 		encoded_hints Au poteau !  Spoiler dans le Checker
# 		logs
# 		travelbugs
# wpt N43 19.198 W1 34.840
# None
# 	time 2016-05-24T07:00:00Z
# 	name GC6JE4G
# 	desc #L3-Bonus - Le Comté du Labourd by gilles64, Unknown Cache (4/2.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=50d751be-4aca-4ac8-9994-ff355dcc9647
# 	urlname #L3-Bonus - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Unknown Cache
# 	cache
#
# 	 - id : 5679838,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L3-Bonus - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Unknown Cache
# 		container Small
# 		attributes
# 		difficulty 4
# 		terrain 2.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Soupière au piquet !  Spoiler dans Checker
# 		logs
# 		travelbugs
# wpt N43 28.610 W1 31.218
# None
# 	time 2016-05-24T07:00:00Z
# 	name GC6JE6G
# 	desc #L4-Bonus - Le Comté du Labourd by gilles64, Unknown Cache (4/1.5)
# 	url http://www.geocaching.com/seek/cache_details.aspx?guid=0331fcb0-6b2b-4508-957f-3b1080ebc052
# 	urlname #L4-Bonus - Le Comté du Labourd
# 	sym Geocache Found
# 	type Geocache|Unknown Cache
# 	cache
#
# 	 - id : 5679900,
# 	 - available : True,
# 	 - archived : False,
#
# 		name #L4-Bonus - Le Comté du Labourd
# 		placed_by gilles64
# 		owner gilles64
# 		type Unknown Cache
# 		container Small
# 		attributes
# 		difficulty 4
# 		terrain 1.5
# 		country France
# 		state Aquitaine
# 		encoded_hints Au gnouf !  Spoiler dans le Checker
# 		logs
# 		travelbugs

# %%
for child in root:
    print child.tag,child.attrib,child.text
    print child.findall("{%s}wpt"%root.nsmap[None])
# Out:
# {http://www.topografix.com/GPX/1/0}name {} LLeida
# []
# {http://www.topografix.com/GPX/1/0}desc {} Geocache file generated by Groundspeak
# []
# {http://www.topografix.com/GPX/1/0}author {} Groundspeak
# []
# {http://www.topografix.com/GPX/1/0}email {} contact@groundspeak.com
# []
# {http://www.topografix.com/GPX/1/0}time {} 2016-08-07T10:24:30.6882924Z
# []
# {http://www.topografix.com/GPX/1/0}keywords {} cache, geocache, groundspeak
# []
# {http://www.topografix.com/GPX/1/0}bounds {'minlat': '41.584183', 'maxlon': '0.65', 'minlon': '0.593417', 'maxlat': '41.635067'} None
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.61', 'lon': '0.62'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.609517', 'lon': '0.61765'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.60835', 'lon': '0.621233'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.612117', 'lon': '0.619367'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.609517', 'lon': '0.616817'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.612', 'lon': '0.6165'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.612833', 'lon': '0.623333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.609833', 'lon': '0.614567'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.614167', 'lon': '0.621667'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.608983', 'lon': '0.613917'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.613333', 'lon': '0.624667'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.614833', 'lon': '0.619167'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.611733', 'lon': '0.626983'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.613333', 'lon': '0.626667'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.616133', 'lon': '0.621867'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.604417', 'lon': '0.615917'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.6158', 'lon': '0.615883'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.616667', 'lon': '0.618333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.614833', 'lon': '0.626667'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.616667', 'lon': '0.616667'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.614983', 'lon': '0.627567'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.6174', 'lon': '0.617933'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.612583', 'lon': '0.629667'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.617667', 'lon': '0.621833'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.607217', 'lon': '0.630233'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.616', 'lon': '0.6275'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.618333', 'lon': '0.618333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.614183', 'lon': '0.62995'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.618833', 'lon': '0.618833'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.608333', 'lon': '0.631667'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.618167', 'lon': '0.624767'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.605', 'lon': '0.63'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.618183', 'lon': '0.627083'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.602783', 'lon': '0.610983'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.62', 'lon': '0.618917'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.62', 'lon': '0.618333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.619517', 'lon': '0.625917'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.606733', 'lon': '0.633467'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.621333', 'lon': '0.621333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.5995', 'lon': '0.61345'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.614717', 'lon': '0.6342'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.604433', 'lon': '0.633667'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.621667', 'lon': '0.62'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.621667', 'lon': '0.618333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.621667', 'lon': '0.621667'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.620017', 'lon': '0.628183'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.6207', 'lon': '0.62795'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.621283', 'lon': '0.613333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.622167', 'lon': '0.622833'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.619767', 'lon': '0.6088'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.61555', 'lon': '0.6356'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.606417', 'lon': '0.603333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.623333', 'lon': '0.618333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.623333', 'lon': '0.623333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.6205', 'lon': '0.6325'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.616583', 'lon': '0.636917'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.624167', 'lon': '0.622917'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.619017', 'lon': '0.634917'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.612383', 'lon': '0.638933'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.623722', 'lon': '0.625861'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.596283', 'lon': '0.614017'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.623017', 'lon': '0.6108'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.619167', 'lon': '0.635833'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.625', 'lon': '0.62'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.625', 'lon': '0.618333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.625', 'lon': '0.621667'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.594417', 'lon': '0.617833'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.619667', 'lon': '0.637333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.593217', 'lon': '0.62075'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.6268', 'lon': '0.614167'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.600033', 'lon': '0.639667'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.61175', 'lon': '0.64405'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.621417', 'lon': '0.640833'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.62725', 'lon': '0.631683'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.629333', 'lon': '0.6162'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.626517', 'lon': '0.63425'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.628333', 'lon': '0.63'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.616667', 'lon': '0.645'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.62995', 'lon': '0.618583'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.622983', 'lon': '0.640367'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.589533', 'lon': '0.620617'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.599817', 'lon': '0.6438'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.615', 'lon': '0.646667'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.620733', 'lon': '0.643917'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.628017', 'lon': '0.605317'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.63', 'lon': '0.63'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.62865', 'lon': '0.634183'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.631067', 'lon': '0.626817'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.62505', 'lon': '0.64125'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.631883', 'lon': '0.618717'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.631033', 'lon': '0.61035'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.6301', 'lon': '0.6329'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.61', 'lon': '0.65'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.608333', 'lon': '0.65'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.63135', 'lon': '0.6303'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.587117', 'lon': '0.619333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.632133', 'lon': '0.62895'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.633583', 'lon': '0.623017'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.627117', 'lon': '0.642333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.626533', 'lon': '0.596283'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.631017', 'lon': '0.603367'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.631983', 'lon': '0.634883'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.632983', 'lon': '0.63205'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.628633', 'lon': '0.642333'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.625833', 'lon': '0.646'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.635067', 'lon': '0.619'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.62875', 'lon': '0.642733'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.634817', 'lon': '0.628817'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.584183', 'lon': '0.616983'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.592933', 'lon': '0.593417'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.6347', 'lon': '0.632267'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.624833', 'lon': '0.649167'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.633583', 'lon': '0.635917'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.62815', 'lon': '0.594317'}
#
# []
# {http://www.topografix.com/GPX/1/0}wpt {'lat': '41.629167', 'lon': '0.645'}
#
# []
