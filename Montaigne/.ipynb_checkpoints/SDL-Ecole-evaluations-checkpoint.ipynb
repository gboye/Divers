# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from io import StringIO
import seaborn as sns

# %%
tableau='''Dimensions	Camille	Jeanne	3	4	5	Gaëlle	Léo	Coleen	9	Maureen	Maewenn	12	Elise	Laëtitia	Eléna	16	Sascha
Orthographe	M20/S16	20/18	20/18		20/18		20/16	20/16		20/16	20/17	20/16	20/15	20/17		20/16	20/16
Syntaxe		19/15				M:18/S:16	14/14	16/14							17 / 15		15/15
Cohérence		19/16	20/14		20/14	M:18/S:17	20/15	18/15		20/17	20/16	20/14				20/15	20/20
Connecteurs	M14/S16	18/14					16/14						17/17	14/17			
Conjugaison		19/17	20/17	20/14	18/16	M:18/S:15	20/17	20/16	20/16	20/15	20/16	20/15			18 / 14	20/15	20/17
Longueur des énoncés	M17/S17																
Graphie								15/17		18/19	19/17		17/19	18/19	19/19		14/18
Niveau de langue			12/18		12/19												
Variété du vocabulaire 			12/18		15/19					19/14	18/15	19/17				18/16	
Organisation du discours	M20/S20					M:18/S:18							17/18	17/18	18 / 16		
Homophones				20/20					20/20								
Accords				20/16					20/17								
Ponctuation				18/13		M:18/S:15			18/12	19/14	19/14	19/11				18/11	
Lisibilité	M17/S19			20/20					20/20				17/19	17/18			'''

# %%
df=pd.read_csv(StringIO(tableau),sep="\t")
df
# Out:
#                   Dimensions  Camille Jeanne      3      4      5     Gaëlle  \
# 0                Orthographe  M20/S16  20/18  20/18    NaN  20/18        NaN
# 1                    Syntaxe      NaN  19/15    NaN    NaN    NaN  M:18/S:16
# 2                  Cohérence      NaN  19/16  20/14    NaN  20/14  M:18/S:17
# 3                Connecteurs  M14/S16  18/14    NaN    NaN    NaN        NaN
# 4                Conjugaison      NaN  19/17  20/17  20/14  18/16  M:18/S:15
# 5       Longueur des énoncés  M17/S17    NaN    NaN    NaN    NaN        NaN
# 6                    Graphie      NaN    NaN    NaN    NaN    NaN        NaN
# 7           Niveau de langue      NaN    NaN  12/18    NaN  12/19        NaN
# 8    Variété du vocabulaire       NaN    NaN  12/18    NaN  15/19        NaN
# 9   Organisation du discours  M20/S20    NaN    NaN    NaN    NaN  M:18/S:18
# 10                Homophones      NaN    NaN    NaN  20/20    NaN        NaN
# 11                   Accords      NaN    NaN    NaN  20/16    NaN        NaN
# 12               Ponctuation      NaN    NaN    NaN  18/13    NaN  M:18/S:15
# 13                Lisibilité  M17/S19    NaN    NaN  20/20    NaN        NaN
#
#       Léo Coleen      9 Maureen Maewenn     12  Elise Laëtitia    Eléna  \
# 0   20/16  20/16    NaN   20/16   20/17  20/16  20/15    20/17      NaN
# 1   14/14  16/14    NaN     NaN     NaN    NaN    NaN      NaN  17 / 15
# 2   20/15  18/15    NaN   20/17   20/16  20/14    NaN      NaN      NaN
# 3   16/14    NaN    NaN     NaN     NaN    NaN  17/17    14/17      NaN
# 4   20/17  20/16  20/16   20/15   20/16  20/15    NaN      NaN  18 / 14
# 5     NaN    NaN    NaN     NaN     NaN    NaN    NaN      NaN      NaN
# 6     NaN  15/17    NaN   18/19   19/17    NaN  17/19    18/19    19/19
# 7     NaN    NaN    NaN     NaN     NaN    NaN    NaN      NaN      NaN
# 8     NaN    NaN    NaN   19/14   18/15  19/17    NaN      NaN      NaN
# 9     NaN    NaN    NaN     NaN     NaN    NaN  17/18    17/18  18 / 16
# 10    NaN    NaN  20/20     NaN     NaN    NaN    NaN      NaN      NaN
# 11    NaN    NaN  20/17     NaN     NaN    NaN    NaN      NaN      NaN
# 12    NaN    NaN  18/12   19/14   19/14  19/11    NaN      NaN      NaN
# 13    NaN    NaN  20/20     NaN     NaN    NaN  17/19    17/18      NaN
#
#        16 Sascha
# 0   20/16  20/16
# 1     NaN  15/15
# 2   20/15  20/20
# 3     NaN    NaN
# 4   20/15  20/17
# 5     NaN    NaN
# 6     NaN  14/18
# 7     NaN    NaN
# 8   18/16    NaN
# 9     NaN    NaN
# 10    NaN    NaN
# 11    NaN    NaN
# 12  18/11    NaN
# 13    NaN    NaN

# %%
df.Camille=df.Camille.str.replace("M","")
df.Camille=df.Camille.str.replace("S","")
df["Gaëlle"]=df["Gaëlle"].str.replace("M:","")
df["Gaëlle"]=df["Gaëlle"].str.replace("S:","")
df=df.set_index("Dimensions")
noms=df.columns.tolist()
df.head()
# Out:
#             Camille Jeanne      3      4      5 Gaëlle    Léo Coleen      9  \
# Dimensions
# Orthographe   20/16  20/18  20/18    NaN  20/18    NaN  20/16  20/16    NaN
# Syntaxe         NaN  19/15    NaN    NaN    NaN  18/16  14/14  16/14    NaN
# Cohérence       NaN  19/16  20/14    NaN  20/14  18/17  20/15  18/15    NaN
# Connecteurs   14/16  18/14    NaN    NaN    NaN    NaN  16/14    NaN    NaN
# Conjugaison     NaN  19/17  20/17  20/14  18/16  18/15  20/17  20/16  20/16
#
#             Maureen Maewenn     12  Elise Laëtitia    Eléna     16 Sascha
# Dimensions
# Orthographe   20/16   20/17  20/16  20/15    20/17      NaN  20/16  20/16
# Syntaxe         NaN     NaN    NaN    NaN      NaN  17 / 15    NaN  15/15
# Cohérence     20/17   20/16  20/14    NaN      NaN      NaN  20/15  20/20
# Connecteurs     NaN     NaN    NaN  17/17    14/17      NaN    NaN    NaN
# Conjugaison   20/15   20/16  20/15    NaN      NaN  18 / 14  20/15  20/17

# %%
cols=df.columns.tolist()
for c in cols:
    df[[c+"-M",c+"-S"]]=df[c].str.split('/', expand=True)

# %%
colsM=[c for c in df.columns if "-M" in c]
colsS=[c for c in df.columns if "-S" in c]

# %%
colsM
# Out:
# ['Camille-M',
#  'Jeanne-M',
#  '3-M',
#  '4-M',
#  '5-M',
#  'Gaëlle-M',
#  'Léo-M',
#  'Coleen-M',
#  '9-M',
#  'Maureen-M',
#  'Maewenn-M',
#  '12-M',
#  'Elise-M',
#  'Laëtitia-M',
#  'Eléna-M',
#  '16-M',
#  'Sascha-M']

# %%
notes={}
for nom in noms:
    dist={}
    cM=nom+"-M"
    cS=nom+"-S"
    rM=df[cM].T.astype("Int64")
    dM=rM.value_counts().to_dict()
    rS=df[cS].T.astype("Int64")
    dS=rS.value_counts().to_dict()
    for i in range(1,21):
        dist[i]=0
        if i in dM:
            dist[i]+=dM[i]
        if i in dS:
            dist[i]+=dS[i]
    notes[nom]=(rM.mean(),rM.std(),rS.mean(),rS.std(),dist)

# %%
dfNotes=pd.DataFrame(notes,index=["meanM","stdM","meanS","stdS","dist"]).T
dfDist=pd.json_normalize(dfNotes.dist)

# %%
bright=sns.color_palette("bright",16)

# %%
fig,axes=plt.subplots(figsize=(8,6),nrows=4, ncols=4)
fig.tight_layout()
for n in range(16):
    i=n//4
    j=n%4
    dfDist.iloc[n].plot(ax=axes[i,j],kind="bar",color=bright[n])
    axes[i,j].set_ylim([0, 6])
    axes[i,j].set_xlim([9, 20])
    axes[i,j].tick_params(axis='both',labelsize=6)

# %% [raw]
# for col in ["meanM","stdM","meanS","stdS"]:
#     dfNotes[col].sort_values().plot()
#     plt.xticks(rotation=45,ha='right')
#     plt.tick_params(axis='both',labelsize=6)
#     plt.show()

# %%
df[colsM]
# Out:
#                          Camille-M Jeanne-M  3-M  4-M  5-M Gaëlle-M Léo-M  \
# Dimensions
# Orthographe                     20       20   20  NaN   20      NaN    20
# Syntaxe                        NaN       19  NaN  NaN  NaN       18    14
# Cohérence                      NaN       19   20  NaN   20       18    20
# Connecteurs                     14       18  NaN  NaN  NaN      NaN    16
# Conjugaison                    NaN       19   20   20   18       18    20
# Longueur des énoncés            17      NaN  NaN  NaN  NaN      NaN   NaN
# Graphie                        NaN      NaN  NaN  NaN  NaN      NaN   NaN
# Niveau de langue               NaN      NaN   12  NaN   12      NaN   NaN
# Variété du vocabulaire         NaN      NaN   12  NaN   15      NaN   NaN
# Organisation du discours        20      NaN  NaN  NaN  NaN       18   NaN
# Homophones                     NaN      NaN  NaN   20  NaN      NaN   NaN
# Accords                        NaN      NaN  NaN   20  NaN      NaN   NaN
# Ponctuation                    NaN      NaN  NaN   18  NaN       18   NaN
# Lisibilité                      17      NaN  NaN   20  NaN      NaN   NaN
#
#                          Coleen-M  9-M Maureen-M Maewenn-M 12-M Elise-M  \
# Dimensions
# Orthographe                    20  NaN        20        20   20      20
# Syntaxe                        16  NaN       NaN       NaN  NaN     NaN
# Cohérence                      18  NaN        20        20   20     NaN
# Connecteurs                   NaN  NaN       NaN       NaN  NaN      17
# Conjugaison                    20   20        20        20   20     NaN
# Longueur des énoncés          NaN  NaN       NaN       NaN  NaN     NaN
# Graphie                        15  NaN        18        19  NaN      17
# Niveau de langue              NaN  NaN       NaN       NaN  NaN     NaN
# Variété du vocabulaire        NaN  NaN        19        18   19     NaN
# Organisation du discours      NaN  NaN       NaN       NaN  NaN      17
# Homophones                    NaN   20       NaN       NaN  NaN     NaN
# Accords                       NaN   20       NaN       NaN  NaN     NaN
# Ponctuation                   NaN   18        19        19   19     NaN
# Lisibilité                    NaN   20       NaN       NaN  NaN      17
#
#                          Laëtitia-M Eléna-M 16-M Sascha-M
# Dimensions
# Orthographe                      20     NaN   20       20
# Syntaxe                         NaN     17   NaN       15
# Cohérence                       NaN     NaN   20       20
# Connecteurs                      14     NaN  NaN      NaN
# Conjugaison                     NaN     18    20       20
# Longueur des énoncés            NaN     NaN  NaN      NaN
# Graphie                          18      19  NaN       14
# Niveau de langue                NaN     NaN  NaN      NaN
# Variété du vocabulaire          NaN     NaN   18      NaN
# Organisation du discours         17     18   NaN      NaN
# Homophones                      NaN     NaN  NaN      NaN
# Accords                         NaN     NaN  NaN      NaN
# Ponctuation                     NaN     NaN   18      NaN
# Lisibilité                       17     NaN  NaN      NaN

# %%
# fig,axes=plt.subplots(figsize=(6,6),nrows=2, ncols=3)
fig, axes = plt.subplot_mosaic("ABCCC;DEFFF",figsize=(10,6))
pastel=sns.color_palette("pastel")
labelsize=8

dfA=dfNotes["meanM"].groupby(pd.cut(dfNotes["meanM"],np.arange(14,21,1)),observed=False).count()
dfA.plot(ax=axes["A"],kind="bar",color=pastel[0])
axes["A"].tick_params(axis='both',labelsize=labelsize)
axes["A"].set_ylim([0, 10.5])

dfB=dfNotes["stdM"].groupby(pd.cut(dfNotes["stdM"],np.arange(0,5,1)),observed=False).count()
dfB.plot(ax=axes["B"],kind="bar",color=pastel[0])
axes["B"].tick_params(axis='both',labelsize=labelsize)
axes["B"].set_ylim([0, 10.5])

dfC=df[colsM].T.astype("Int64").std()
dfC.plot(ax=axes["C"],color=pastel[0])
axes["C"].tick_params(axis='both',labelsize=labelsize)
axes["C"].set_ylim([0, 3])

dfD=dfNotes["meanS"].groupby(pd.cut(dfNotes["meanS"],np.arange(14,21,1)),observed=False).count()
dfD.plot(ax=axes["D"],kind="bar",color=pastel[1])
axes["D"].tick_params(axis='both',labelsize=labelsize)
axes["D"].set_ylim([0, 10.5])

dfE=dfNotes["stdS"].groupby(pd.cut(dfNotes["stdS"],np.arange(0,5,1)),observed=False).count()
dfE.plot(ax=axes["E"],kind="bar",color=pastel[1])
axes["E"].tick_params(axis='both',labelsize=labelsize)
axes["E"].set_ylim([0, 10.5])

dfF=df[colsS].T.astype("Int64").std()
dfF.plot(ax=axes["F"],color=pastel[1])
axes["F"].tick_params(axis='both',labelsize=labelsize)
axes["F"].set_ylim([0, 3])

x=df.index
xMean="14-15 15-16 16-17 17-18 18-19 19-20".split(" ")
xStd="0-1 1-2 2-3 3-4".split(" ")
plt.sca(axes["A"])
plt.xticks(range(len(xMean)),xMean,rotation=45,ha='right')
plt.title("Moyennes Marie")
plt.xlabel("")
plt.ylabel("Nombre d'occurrences")
plt.sca(axes["B"])
plt.xticks(range(len(xStd)),xStd,rotation=45,ha='right')
plt.title("Écarts Marie")
plt.xlabel("")
plt.sca(axes["C"])
plt.xticks(range(len(x)),x,rotation=45,ha='right')
plt.title("Écarts Marie par critère")
plt.xlabel("")
plt.ylabel("Écart type\nentre les évaluations")
plt.sca(axes["D"])
plt.xticks(range(len(xMean)),xMean,rotation=45,ha='right')
plt.title("Moyennes Samantha")
plt.xlabel("")
plt.ylabel("Nombre d'occurrences")
plt.sca(axes["E"])
plt.xticks(range(len(xStd)),xStd,rotation=45,ha='right')
plt.title("Écarts Samantha")
plt.xlabel("")
plt.sca(axes["F"])
plt.xticks(range(len(x)),x,rotation=45,ha='right')
plt.title("Écarts Samantha par critère")
plt.xlabel("")
plt.ylabel("Écart type\nentre les évaluations")
fig.tight_layout()

# %%
fig,axes=plt.subplots(figsize=(10,6),nrows=4, ncols=4)
for n in range(len(x)):
    i=n//4
    j=n%4
    dfTemp=df[colsM].iloc[n].value_counts()
    for k in range(10,21):
        if str(k) not in dfTemp.index:
            dfTemp.loc[str(k)]=0
    dfTemp=dfTemp.sort_index()
    # dfTemp.index=dfTemp.index.astype("int")
    # dfTemp=dfTemp.sort_index()
    # # print(dfTemp.index)
    # print(dfTemp)
    dfTemp.plot(ax=axes[i,j],kind="bar",color=bright[n])
    # plt.sca(axes[i,j])
    # plt.xticks(range(10,21),[str(k) for k in range(10,21)])
    # axes[i,j].set_xlim([9, 20])
    axes[i,j].set_ylim([0, 12])
    axes[i,j].tick_params(axis='both',labelsize=labelsize)
fig.delaxes(axes[3,2])
fig.delaxes(axes[3,3])
fig.suptitle("Notes Marie")
fig.tight_layout()

# %%
fig,axes=plt.subplots(figsize=(10,6),nrows=4, ncols=4)
for n in range(len(x)):
    i=n//4
    j=n%4
    dfTemp=df[colsM].iloc[n].value_counts()
    for k in range(10,21):
        if str(k) not in dfTemp.index:
            dfTemp.loc[str(k)]=0
    dfTemp=dfTemp.sort_index()
    # dfTemp.index=dfTemp.index.astype("int")
    # dfTemp=dfTemp.sort_index()
    # # print(dfTemp.index)
    # print(dfTemp)
    dfTemp.plot(ax=axes[i,j],kind="bar",color=bright[n])
    # plt.sca(axes[i,j])
    # plt.xticks(range(10,21),[str(k) for k in range(10,21)])
    # axes[i,j].set_xlim([9, 20])
    axes[i,j].set_ylim([0, 12])
    axes[i,j].tick_params(axis='both',labelsize=labelsize)
fig.delaxes(axes[3,2])
fig.delaxes(axes[3,3])
fig.suptitle("Notes Marie")
fig.tight_layout()

# %%
dfTemp=df[colsM].iloc[2].value_counts()
for k in range(10,21):
    if str(k) not in dfTemp.index:
        dfTemp.loc[str(k)]=0
dfTemp=dfTemp.sort_index()
print(dfTemp)
ax=dfTemp.plot(kind="bar",color=bright[2])
# ax.set_ylim([0, 15])
# ax.set_xlim(9, 20)
# Out:
# Cohérence
# 10    0
# 11    0
# 12    0
# 13    0
# 14    0
# 15    0
# 16    0
# 17    0
# 18    2
# 19    1
# 20    8
# Name: count, dtype: int64
