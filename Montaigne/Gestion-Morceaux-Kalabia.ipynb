# %%
import re

# %%
annee=21
repertoire="/Users/gilles/ownCloud/Cours/Bordeaux/L1-LinguistiqueGenerale/00-ProjetKalaba/21-K5/"
puzzleComps=["%d-K5-Devoir-Comp-K%d.tex"%(annee,n+1) for n in range(5)]
puzzle="%d-K5-Devoir.tex"%(annee)

# %%
morceauFichier={}
with open(repertoire+puzzle) as inFile:
    lines=inFile.readlines()
    for line in lines:
        m=re.search(ur"page=(\d+)",line)
        if m:
            nMorceau=int(m.group(1))
            morceauFichier[nMorceau]=puzzle


for comp in puzzleComps:
    with open(repertoire+comp) as inFile:
        print comp
        lines=inFile.readlines()
        for line in lines:
            m=re.search(ur"page=(\d+)",line)
            if m:
                nMorceau=int(m.group(1))
                morceauFichier[nMorceau]=comp
                print nMorceau

for m in morceauFichier:
    print m, morceauFichier[m]
# Out:
# 21-K5-Devoir-Comp-K1.tex
# 49
# 44
# 60
# 32
# 50
# 63
# 16
# 90
# 45
# 21-K5-Devoir-Comp-K2.tex
# 80
# 94
# 43
# 31
# 28
# 42
# 27
# 61
# 26
# 21-K5-Devoir-Comp-K3.tex
# 48
# 78
# 46
# 62
# 33
# 81
# 59
# 4
# 69
# 21-K5-Devoir-Comp-K4.tex
# 93
# 68
# 15
# 92
# 25
# 91
# 3
# 79
# 21-K5-Devoir-Comp-K5.tex
# 65
# 1
# 13
# 67
# 2
# 66
# 30
# 14
# 1 21-K5-Devoir-Comp-K5.tex
# 2 21-K5-Devoir-Comp-K5.tex
# 3 21-K5-Devoir-Comp-K4.tex
# 4 21-K5-Devoir-Comp-K3.tex
# 5 21-K5-Devoir.tex
# 6 21-K5-Devoir.tex
# 7 21-K5-Devoir.tex
# 8 21-K5-Devoir.tex
# 9 21-K5-Devoir.tex
# 10 21-K5-Devoir.tex
# 11 21-K5-Devoir.tex
# 12 21-K5-Devoir.tex
# 13 21-K5-Devoir-Comp-K5.tex
# 14 21-K5-Devoir-Comp-K5.tex
# 15 21-K5-Devoir-Comp-K4.tex
# 16 21-K5-Devoir-Comp-K1.tex
# 17 21-K5-Devoir.tex
# 18 21-K5-Devoir.tex
# 19 21-K5-Devoir.tex
# 20 21-K5-Devoir.tex
# 21 21-K5-Devoir.tex
# 22 21-K5-Devoir.tex
# 23 21-K5-Devoir.tex
# 24 21-K5-Devoir.tex
# 25 21-K5-Devoir-Comp-K4.tex
# 26 21-K5-Devoir-Comp-K2.tex
# ...
