# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Budget Microstructures : 520 000 €
# - Participation des familles 70 % 365 000€
# - Participation PAJE de la CAF 17% 87 000€
# - Participation des communes 12,5% 65 000€
# - Participation du Conseil Départemental 40 0,5% 3 000€ (il n'y a plus le 64)

# %%
data=[
        (u"Participation des familles", 365000),
        (u"Participation PAJE de la CAF",87000),
        (u"Participation des communes",65000),
        (u"Participation du Conseil Départemental",3000),
     ]
df=pd.DataFrame.from_records(data,columns=[u"Parts",u"Budget"])
budget=df.Budget.sum()
df["autre"]=budget-df.Budget
df.set_index("Parts",inplace=True)
df
# Out:
#                                         Budget   autre
# Parts
# Participation des familles              365000  155000
# Participation PAJE de la CAF             87000  433000
# Participation des communes               65000  455000
# Participation du Conseil Départemental    3000  517000

# %%
couleurs=["#2D677E", "#4BA6D1", "#B0D3E8", "#C8E4F1"]

# %%
size = 1
radius=3.5
epsilon= 0.05

# %%
fig, ax = plt.subplots()

for b in range(4):
    wedges=ax.pie(df.iloc[b],colors=[couleurs[b],"w"],radius=radius+(size+epsilon)*b,
                         startangle=180,
#                          autopct='%1.1f%%',
                         wedgeprops=dict(width=size, edgecolor='w'))

#     bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
#     kw = dict(arrowprops=dict(arrowstyle="-"),
#               bbox=bbox_props, zorder=0, va="center")

#     for i, p in enumerate(wedges):
#         ang = (p.theta2 - p.theta1)/2. + p.theta1
#         y = np.sin(np.deg2rad(ang))
#         x = np.cos(np.deg2rad(ang))
#         horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
#         connectionstyle = "angle,angleA=0,angleB={}".format(ang)
#         kw["arrowprops"].update({"connectionstyle": connectionstyle})
#         ax.annotate(b, xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
#                     horizontalalignment=horizontalalignment, **kw)

ax.set(aspect="equal")
# Out:
# [None]

# %%
# %matplotlib inline
