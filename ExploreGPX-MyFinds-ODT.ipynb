# %%
from lxml import etree
import math,re,codecs
debug=False

# %%
parser = etree.XMLParser(remove_blank_text=True)

# %%
nomLoc="/Users/gilles/Downloads/5832845.gpx"
wptChildren=["name","urlname"]

# %%
def localName(element):
    return etree.QName(element).localname

# %%
def Dec2Min(coord):
    degreSign=""
    decDegres,intDegres=math.modf(coord)
    minutes=abs(decDegres)*60
    return "%d%s %5.3f"%(intDegres,degreSign,minutes)

# %%
def CoordDec2Min(lat,lon):
    sep=" "
    coordLat=Dec2Min(lat)
    coordLon=Dec2Min(lon)
    if coordLat.startswith("-"):
        coordLat="S"+coordLat[1:]
    else:
        coordLat="N"+coordLat
    if coordLon.startswith("-"):
        coordLon="W"+coordLon[1:]
    else:
        coordLon="E"+coordLon
    return "%s%s%s"%(coordLat,sep,coordLon)

# %%
def dictLatLon2Coord(dictLatLon):
    return CoordDec2Min(float(dictLatLon["lat"]),float(dictLatLon["lon"]))

# %%
Dec2Min(-1.57305)
# Out:
# '-1 34.383'

# %%
tree = etree.parse(nomLoc)
root = tree.getroot()
nsRoot=root.nsmap[None]
nsGC="http://www.groundspeak.com/cache/1/0/1"
print root.tag
# Out:
# {http://www.topografix.com/GPX/1/0}gpx

# %%
listeLogs=[]
noNum=0
noNumIndex="abcdefghijklmnopqrstuvwxyz"
for wpt in root.findall("{%s}wpt"%nsRoot):
    cacheName=wpt.find("{%s}desc"%nsRoot).text
    cache=wpt.find("{%s}cache"%nsGC)
    logs=cache.find("{%s}logs"%nsGC)
    logList=logs.findall("{%s}log"%nsGC)
    for log in logList: 
        logType=log.find("{%s}type"%nsGC)
        if logType.text in ["Found it","Attended"]:
            logText=log.find("{%s}text"%nsGC)
            texteLog=logText.text
            m=re.search("(#\s?\**|\[pink\]|\[b\])(\d+)",texteLog)
            if m:
                numLog=int(m.group(2))
            else:
                print "============================="
                numLog=noNumIndex[noNum]
                noNum+=1
                logDate=log.find("{%s}date"%nsGC).text.split("T")[0]
                print logDate,cacheName,"pas de numéro =>",numLog
                
#            print (numLog,cacheName,texteLog)
            listeLogs.append([numLog,cacheName,texteLog])
# Out:
# =============================
# 2013-07-10 54 - 64 et 1000 km plus tard... by huntersam, Event Cache (1/1.5) pas de numéro => a
# =============================
# 2016-06-17 Castets : la salle des fêtes by DorisBear, Traditional Cache (1.5/1.5) pas de numéro => b
# =============================
# 2017-05-26 GTAQ Saison 3 - Episode 2 : La Chalosse by GTAQ, Event Cache (1/1) pas de numéro => c
# =============================
# 2012-04-07 L'event Basque : A vos marques, prêts, partez !  by Peyo64, Event Cache (1/1) pas de numéro => d
# =============================
# 2014-08-30 Villodas: Puente Romano by kasiMEGA TEAM, Unknown Cache (2/1.5) pas de numéro => e
# =============================
# 2011-11-11 Le 11 Landais by Lanowar, Event Cache (1/1) pas de numéro => f
# =============================
# 2011-04-20 Les Vents de Foehn # Teberne # 4 by ossau64, Traditional Cache (1.5/3) pas de numéro => g

# %%
logsSpeciaux={u"54 - 64 et 1000 km plus tard... by huntersam, Event Cache (1/1.5)":1452,
              u"Castets : la salle des fêtes by DorisBear, Traditional Cache (1.5/1.5)":2957,
              u"GTAQ Saison 3 - Episode 2 : La Chalosse by GTAQ, Event Cache (1/1)":3500,
              u"L'event Basque : A vos marques, prêts, partez !  by Peyo64, Event Cache (1/1)":413,
              u"Villodas: Puente Romano by kasiMEGA TEAM, Unknown Cache (2/1.5)":2111,
              u"Le 11 Landais by Lanowar, Event Cache (1/1)":335,
              u"Les Vents de Foehn # Teberne # 4 by ossau64, Traditional Cache (1.5/3)":177,
              u"Détruit par les ducs de Joyeuse by Padington, Traditional Cache (2/1.5)":41,
              u"64 102 - Pyrénées Atlantique by gilles64, Unknown Cache (2/1.5)":3900,
              u"#32 Sentier du Littoral by Peyo64, Traditional Cache (1.5/1.5)":459,
              u"Le Lavoir de SAUBION by f8pkp, Traditional Cache (1/2)":142,
              u"You Fight Like A Cow... by taipan541, neodx09, Traditional Cache (1/1)":277,
              u"Oloronpoint bis by ossau64, Wherigo Cache (1.5/1.5)":602,
              u"Lendresse Gave 1 by nathalie64, Traditional Cache (2/2)":630,
              u"Lendresse Gave 2 by nathalie64, Traditional Cache (1.5/1.5)":631,
              u"MEUMEUZOZOZOZOZOZO by Lluis64, Unknown Cache (2/1.5)":632
             }

# %%
for log in listeLogs:
    if log[1] in logsSpeciaux:
        print log[1]
        log[0]=logsSpeciaux[log[1]]
listeLogs.sort(key=lambda x: x[0])
# Out:
# Détruit par les ducs de Joyeuse by Padington, Traditional Cache (2/1.5)
# Le Lavoir de SAUBION by f8pkp, Traditional Cache (1/2)
# Les Vents de Foehn # Teberne # 4 by ossau64, Traditional Cache (1.5/3)
# You Fight Like A Cow... by taipan541, neodx09, Traditional Cache (1/1)
# Le 11 Landais by Lanowar, Event Cache (1/1)
# L'event Basque : A vos marques, prêts, partez !  by Peyo64, Event Cache (1/1)
# #32 Sentier du Littoral by Peyo64, Traditional Cache (1.5/1.5)
# Oloronpoint bis by ossau64, Wherigo Cache (1.5/1.5)
# Lendresse Gave 1 by nathalie64, Traditional Cache (2/2)
# MEUMEUZOZOZOZOZOZO by Lluis64, Unknown Cache (2/1.5)
# Lendresse Gave 2 by nathalie64, Traditional Cache (1.5/1.5)
# 54 - 64 et 1000 km plus tard... by huntersam, Event Cache (1/1.5)
# Villodas: Puente Romano by kasiMEGA TEAM, Unknown Cache (2/1.5)
# Castets : la salle des fêtes by DorisBear, Traditional Cache (1.5/1.5)
# GTAQ Saison 3 - Episode 2 : La Chalosse by GTAQ, Event Cache (1/1)
# 64 102 - Pyrénées Atlantique by gilles64, Unknown Cache (2/1.5)

# %%
ajustement=0
for n in range(len(listeLogs)):
    if listeLogs[n][0]!=n+1+ajustement:
        print listeLogs[n][1],listeLogs[n][0],n
#        print listeLogs[n][2]
        ajustement=listeLogs[n][0]-n-1
# Out:
# Circuit des coteaux - 09 - Château Cluzel by Calimero33, Traditional Cache (2/2) 717 715
# Circuit des coteaux - 08 - Le pont by Calimero33, Traditional Cache (2.5/2) 718 717
# GR8#142 by Peyo64, Traditional Cache (2/1.5) 801 801
# GR8#143 by Peyo64, Traditional Cache (2/1.5) 822 821
# L'art dans la ville - 1- Plusieurs fois by piero1263, Multi-cache (1.5/1.5) 907 907
# GR10#133 by Peyo64, Traditional Cache (2/1.5) 915 914
# West End 1 - The Beatles by lisboa_bruno, Traditional Cache (3.5/1.5) 1206 1204
# Arriaga Antzokia. Teatro Arriaga. Arriaga Theater. by Izadi, Traditional Cache (3/1) 1557 1556
# Nocturno en Akarlanda 1 by igeie & izadi & kevincuitxaso, Unknown Cache (2/2) 1559 1557
# La hucha De Los Txikiteros by igeie, Traditional Cache (2.5/1.5) 1837 1836
# La Merced eliza. Bilborock by Izadi, Traditional Cache (2.5/1.5) 1839 1837
# Ruta Baquedano - Artaza 05 by kasiMEGA TEAM, Traditional Cache (1.5/1.5) 1905 1904
# Ruta Artaza - Baquedano 01 by kasiMEGA TEAM, Traditional Cache (1.5/1.5) 1905 1905
# Ruta Artaza - Baquedano 02 by kasiMEGA TEAM, Traditional Cache (1/1.5) 1908 1906
# Una de Romanos by kasiMEGA TEAM, Letterbox Hybrid (2/2.5) 2117 2116
# CELEDON by ISIDOROAMENO Y MAYTE, Wherigo Cache (2/2) 2119 2117
# A63 - Aire de repos Lugos Est by gilles64, Traditional Cache (1.5/1.5) 2717 2716
# #L1-03 Biriatou - Le Comté du Labourd by gilles64, Multi-cache (2/1.5) 2719 2717
# FTF by termite2712, Unknown Cache (1.5/2) 2774 2771
# Cuevas del moro: merendero by dudu_jenny, Traditional Cache (1.5/1.5) 3157 3155
# Le Casterar de Buros by LOANGO, Traditional Cache (1.5/2) 3159 3156
# Synagogue by Seresek / lophas / Dzsozy, Virtual Cache (1/1) 3599 3597
# Danube Promenade 10 - Március 15. tér by GCUjpest / fa-peti, Traditional Cache (2/1.5) 3800 3797
# 64 235 - Pyrénées Atlantique by gilles64, Unknown Cache (2/2) 3931 3929
# 64 234 - Pyrénées Atlantique by gilles64, Unknown Cache (2/2) 3931 3930
# 64233 - Pyrénées Atlantique by gilles64, Unknown Cache (2/2) 3931 3931
# J022	 - Géodyssée 40 64 by gilles64, Traditional Cache (1.5/1.5) 3935 3932

# %%
n=715
print listeLogs[n][1],listeLogs[n][0],n
print listeLogs[n][2]
# Out:
# Circuit des coteaux - 09 - Château Cluzel by Calimero33, Traditional Cache (2/2) 717 715
# #717. Expédition péri-bordelaise quasiment à la descente du train, juste le temps d'attraper Cachou et d'aller à Bouliac... Cachou tranquille à l'ombre, Stéphane nous amène sans problème à cette cache caliméric quasi-bordelaise. MPLC
#
# If you looked for the calimeric caches in Bordeaux you might some déjà vu or déjà bu depending on your taste/tasting... TFTC
#
# No Trade

# %%
listeLogs[-1]
# Out:
# [4001,
#  u'Estocdiken Cache #11 - For\xeat Castillon 5 by estocdiken, Traditional Cache (3/2.5)',
#  u"#4001. Apr\xe8s plusieurs tentatives mises en \xe9chec par l'eau \U0001f4a6 et la pluie \u2614\ufe0f, aujourd'hui c'\xe9tait le beau jour \u2600\ufe0f. Ludo \U0001f692 connaissait bien la route \xe0 force de venir pour rien [:(]. Il nous a laiss\xe9 au bout du chemin pr\xe8s des maisons \U0001f3d8 et tout de suite on a pu voir que le terrain avait bien maigri. Un r\xe9gime sans pluie \U0001f302 d'au moins une semaine \U0001f4c6 plus ou moins caniculaire \U0001f630 avait r\xe9duit la boue \xe0 quelques vagues flaques. Arriv\xe9s \xe0 la #10, on a jet\xe9 un coup d'\u0153il \U0001f441\U0001f441 et constat\xe9 que malheureusement la bo\xeete originale avait disparu pour laisser la place \xe0 un simple sac \xe0 clog (dommage).\n\nSur le chemin, les inondations et les d\xe9luges r\xe9p\xe9t\xe9s ont eu raison du passage \u26a0\ufe0f au coin du champ. Un petit \xe9boulement a emport\xe9 la voie normale mais on \U0001f40c peut encore facilement passer par au dessus. L'obstacle franchi, on a poursuivi jusqu'en bas, en passant au pied  de la cabane perch\xe9e \U0001f92b (sans la voir) puis le long du ruisseau. Les s\u0153ur Pilar \U0001f4cd, qui nous avaient d\xe9j\xe0 pr\xeat\xe9 main forte pour les \xe9boulis, ont repris du service pour le franchissement du ru et ensuite dans la bou\xe9e mar\xe9cageuse \U0001f573. Heureusement, la v\xe9g\xe9tation paresseuse \U0001f33f s'est couch\xe9e un peu partout et elle nous a fourni des tapis bien utiles pour avancer plut\xf4t que s'enfoncer. Aux abords du PZ \U0001f3af, un nouveau petit ru passait par l\xe0 mais cette fois nul besoin des Pilar pour nous tenir la main.\n\nL'indication nous a amen\xe9s directement vers de gros arbres \U0001f333\U0001f333\U0001f333 bien accueillant mais sans cache. Les ravages pluviaux visibles tout autour nous ont un peu inqui\xe9t\xe9s mais finalement la cache \xe9tait bien en place \U0001f3af, juste beaucoup plus bas que pr\xe9vu [8)]. Comme annonc\xe9 par les premiers venus \U0001f451\U0001f481\U0001f3fb, la bo\xeete \xe9tait facile \xe0 ouvrir mais moins ais\xe9e \xe0 loguer \U0001f914. La cl\xe9 du myst\xe8re ne s'est pas pr\xe9sent\xe9e tout de suite mais cette fois pas de bousillage (\U0001f5dd pardon pour la #10 [:I]). Le crochetage n'\xe9tant pas notre cr\xe9neau, on a essay\xe9 diff\xe9rentes options et apr\xe8s les avoir class\xe9es en taille [;)] et en difficult\xe9, la solution et le clog sont apparus.\n\nMerci pour cette cache qui nous aura donn\xe9 du fil (et un trombone \U0001f4ce) \xe0 retordre et on esp\xe8re les suivantes pour bient\xf4t... MPLC, milesker estocdiken \U0001f512 [:)].\n\n---\n\nWe had missed this one on several occasions, every time because of the weather, past or present. After a full week of sunshine and heat, we believed that this would be the right time for a find. Ludo knew the road by wheel, we followed the track to #10 and turned into the wood. We passed the crumbled path and walked down to the brook. We crossed to the GZ in the marshy undergrowth and reached some bigger trees that looked promising. After exploration, we felt a bit disappointed and started feeling that this would not be the day after all when we saw a whitish box near the foot of a sapling. There it was, fallen on soft times... We opened the box and found another one inside. Not a matriochka but a sort of field puzzle. We did not find the key at first (and neither at last) but after looking around we saw how to get what we needed.\n\nThanks for this entertaining cache, looking forward to the next ones. TFTC \U0001f512 estocdiken.\n\nIn : demi-bille \u2014 Out : peace and love."]

# %% [markdown]
# ## Filtrages

# %%
smileys={u"[:I]":u"😳",u"[8D]":u"😎",u"[:P]":u"😋",u"[;)]":u"😉",u"[8)]":u"🤭",
         u"[:)]":u"😀",u"[:(]":u"🤢",u"[xx(]":u"😵",u"[|)]":u"😴",u"[:D]":u"😁",
         u"[^]":u"🤩",u"[}:)]":u"😈"}
smileysMatch="|".join([re.escape(k) for k in smileys.keys()])

def continuRe(listeLogs):
    fini=True
    for log in listeLogs:
        m=re.search(ur"(This entry was edited by .* on .* at \d?\d:\d\d:\d\d\s*((AM|PM)? UTC)?.)",log[2])
        if m:
            print "replacing edited by"
            log[2]=log[2].replace(m.group(1),"")
            fini=False
        m=re.findall(ur"(\[url=(.*?)\](.*?)\[/url\])",log[2])
        if m:
            print "replacing all [url]"
            for element in m:
                log[2]=log[2].replace(element[0],u"\\href{%s}{%s}"%(element[1],element[2]))
            fini=False
        m=re.findall(ur"(\[(blue|yellow|red|pink|orange|green|white)\](.*?)\[/\2\])",log[2])
        if m:
            print "replacing all color"
            for element in m:
                log[2]=log[2].replace(element[0],u"\\color{%s}%s\\color{black}"%(element[1],element[2]))
            fini=False
        m=re.findall(ur"(\[(blue|yellow|red|pink|orange|green|white)\](.*?)\[/\2\])",log[2])
        if m:
            print "replacing all color"
            for element in m:
                log[2]=log[2].replace(element[0],u"\\color{%s}%s\\color{black}"%(element[1],element[2]))
            fini=False
        m=re.findall(ur"(\[size=(\d)\](.*?)\[/\2\])",log[2])
        if m:
            print "replacing all size"
            for element in m:
                size=element[1]
                if size=="4":
                    log[2]=log[2].replace(element[0],u"{\\LARGE{}%s}"%element[2])
                elif size=="3":
                    log[2]=log[2].replace(element[0],u"{\\Large{}%s}"%element[2])
                elif size=="2":
                    log[2]=log[2].replace(element[0],u"{\\large{}%s}"%element[2])
                else:
                    log[2]=log[2].replace(element[0],element[2])
            fini=False
        m=re.search(ur"(\[b\](.*)\[/b\])",log[2])
        if m:
            print "replacing [bold]"
            log[2]=log[2].replace(m.group(1),u"{\\bfseries{}%s}"%(m.group(2)))
            fini=False
        m=re.search(ur"(\*\*(.*)\*\*)",log[2])
        if m:
            print "replacing **bold**"
            log[2]=log[2].replace(m.group(1),u"{\\bfseries{}%s}"%(m.group(2)))
            fini=False
        m=re.search(ur"(\[i\]([^[]*)\[/i\])",log[2])
        if m:
            print "replacing [italics]"
            log[2]=log[2].replace(m.group(1),u"{\\itshape{}%s}"%(m.group(2)))
            fini=False
        m=re.search(ur"(\*(.*)\*)",log[2])
        if m:
            print "replacing *italics*"
            log[2]=log[2].replace(m.group(1),u"{\\itshape{}%s}"%(m.group(2)))
            fini=False
        m=re.search(ur"(%s)"%smileysMatch,log[2])
        if m:
            print "replacing smileys"
            print m.group(1)
            log[2]=log[2].replace(m.group(1),smileys["%s"%m.group(1)])
            fini=False
        m=re.search(ur"(###\s*(.*?)\s*###)",log[2])
        if m:
            print "replacing ### ###"
            log[2]=log[2].replace(m.group(1),u"{\\centering\\color{green}%s\\color{black}}"%m.group(2))
            fini=False
        m=re.search(ur"(##\s*(.*)\s*##)",log[2])
        if m:
            print "replacing ## ##"
            log[2]=log[2].replace(m.group(1),u"{\large\\centering{}%s}"%m.group(2))
            fini=False
        m=re.search(ur"(#\s*(.*)\s*#)",log[2])
        if m:
            print "replacing # #"
            log[2]=log[2].replace(m.group(1),u"{\Large\\centering{}%s}"%m.group(2))
            fini=False
        result=fini
    return (listeLogs, result)

# %%
fini=False
while not fini:
    (listeLogs,fini)=continuRe(listeLogs)
# Out:
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [xx(]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:P]
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [xx(]
# replacing edited by
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [:P]
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [|)]
# replacing edited by
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing ### ###
# replacing ## ##
# replacing # #
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [xx(]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [8D]
# replacing # #
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [|)]
# replacing smileys
# [:I]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8)]
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [:D]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [:I]
# replacing smileys
# [xx(]
# replacing edited by
# replacing smileys
# [:P]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [:(]
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing all [url]
# replacing smileys
# [;)]
# replacing edited by
# replacing all [url]
# replacing smileys
# [;)]
# replacing edited by
# replacing all [url]
# replacing smileys
# [;)]
# replacing edited by
# replacing all [url]
# replacing smileys
# [:(]
# replacing all [url]
# replacing smileys
# [:)]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [^]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing smileys
# [:D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing all color
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [8)]
# replacing edited by
# replacing all color
# replacing smileys
# [8)]
# replacing edited by
# replacing *italics*
# replacing smileys
# [}:)]
# replacing smileys
# [:D]
# replacing smileys
# [:I]
# replacing *italics*
# replacing smileys
# [:(]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [:D]
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all [url]
# replacing all color
# replacing smileys
# [:I]
# replacing all [url]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all [url]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all [url]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing *italics*
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing [italics]
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing [italics]
# replacing smileys
# [:I]
# replacing all [url]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all [url]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing *italics*
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing all [url]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [:)]
# replacing all [url]
# replacing all color
# replacing smileys
# [8)]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8)]
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing [italics]
# replacing smileys
# [:D]
# replacing *italics*
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing smileys
# [8D]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing *italics*
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing edited by
# replacing all [url]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [8D]
# replacing all [url]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [^]
# replacing all [url]
# replacing all [url]
# replacing smileys
# [:)]
# replacing all [url]
# replacing all color
# replacing all [url]
# replacing all [url]
# replacing smileys
# [:D]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing *italics*
# replacing all [url]
# replacing edited by
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing all [url]
# replacing all [url]
# replacing *italics*
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing edited by
# replacing edited by
# replacing all [url]
# replacing edited by
# replacing edited by
# replacing all [url]
# replacing smileys
# [^]
# replacing all [url]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing edited by
# replacing all [url]
# replacing all [url]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing all [url]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing all [url]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing all [url]
# replacing edited by
# replacing all [url]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing [italics]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing edited by
# replacing [bold]
# replacing *italics*
# replacing edited by
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing edited by
# replacing all [url]
# replacing *italics*
# replacing edited by
# replacing all color
# replacing edited by
# replacing all [url]
# replacing all color
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing all color
# replacing smileys
# [^]
# replacing edited by
# replacing all color
# replacing *italics*
# replacing smileys
# [:D]
# replacing edited by
# replacing all color
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing *italics*
# replacing *italics*
# replacing [italics]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing *italics*
# replacing smileys
# [:D]
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing smileys
# [8D]
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing all color
# replacing [bold]
# replacing *italics*
# replacing edited by
# replacing all color
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing all color
# replacing edited by
# replacing all color
# replacing *italics*
# replacing edited by
# replacing all color
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [:P]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing edited by
# replacing [italics]
# replacing [italics]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing [italics]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing [italics]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all [url]
# replacing all color
# replacing smileys
# [^]
# replacing [italics]
# replacing edited by
# replacing all [url]
# replacing [italics]
# replacing edited by
# replacing edited by
# replacing [italics]
# replacing [bold]
# replacing edited by
# replacing all color
# replacing smileys
# [8D]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing edited by
# replacing all color
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing smileys
# [:I]
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing [italics]
# replacing smileys
# [8D]
# replacing [italics]
# replacing edited by
# replacing all color
# replacing *italics*
# replacing [italics]
# replacing all color
# replacing *italics*
# replacing edited by
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing [italics]
# replacing edited by
# replacing smileys
# [xx(]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing edited by
# replacing all [url]
# replacing smileys
# [:P]
# replacing edited by
# replacing [italics]
# replacing edited by
# replacing all [url]
# replacing edited by
# replacing [italics]
# replacing smileys
# [;)]
# replacing all [url]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing [italics]
# replacing smileys
# [|)]
# replacing smileys
# [xx(]
# replacing [italics]
# replacing edited by
# replacing all color
# replacing smileys
# [:)]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing smileys
# [:(]
# replacing all [url]
# replacing [italics]
# replacing [italics]
# replacing all [url]
# replacing edited by
# replacing [italics]
# replacing smileys
# [;)]
# replacing all [url]
# replacing [italics]
# replacing edited by
# replacing all color
# replacing [bold]
# replacing smileys
# [^]
# replacing [italics]
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing all [url]
# replacing *italics*
# replacing all [url]
# replacing [italics]
# replacing all [url]
# replacing [italics]
# replacing *italics*
# replacing all color
# replacing all [url]
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [8)]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing edited by
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing all color
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing smileys
# [:I]
# replacing [italics]
# replacing all [url]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [8D]
# replacing smileys
# [8)]
# replacing smileys
# [:P]
# replacing [italics]
# replacing [italics]
# replacing all color
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing [italics]
# replacing [italics]
# replacing smileys
# [8)]
# replacing all color
# replacing [italics]
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [:P]
# replacing all color
# replacing all color
# replacing smileys
# [:D]
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing [italics]
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [;)]
# replacing *italics*
# replacing smileys
# [:P]
# replacing smileys
# [}:)]
# replacing smileys
# [:P]
# replacing *italics*
# replacing *italics*
# replacing smileys
# [;)]
# replacing [italics]
# replacing [italics]
# replacing all color
# replacing [italics]
# replacing all color
# replacing *italics*
# replacing *italics*
# replacing smileys
# [^]
# replacing *italics*
# replacing [italics]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [}:)]
# replacing *italics*
# replacing all color
# replacing *italics*
# replacing smileys
# [:I]
# replacing *italics*
# replacing [italics]
# replacing smileys
# [xx(]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [;)]
# replacing edited by
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing all color
# replacing all [url]
# replacing smileys
# [:P]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing edited by
# replacing smileys
# [8D]
# replacing edited by
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing edited by
# replacing smileys
# [xx(]
# replacing smileys
# [8D]
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [:P]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing # #
# replacing [italics]
# replacing smileys
# [:P]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing edited by
# replacing all [url]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing edited by
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing # #
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing edited by
# replacing [italics]
# replacing smileys
# [:)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing smileys
# [xx(]
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [8D]
# replacing # #
# replacing [bold]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing [italics]
# replacing edited by
# replacing smileys
# [:I]
# replacing all [url]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [:D]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing all [url]
# replacing [italics]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:I]
# replacing [italics]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [8D]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing all color
# replacing [italics]
# replacing *italics*
# replacing smileys
# [:I]
# replacing smileys
# [xx(]
# replacing all [url]
# replacing [italics]
# replacing smileys
# [:)]
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing all color
# replacing edited by
# replacing all color
# replacing smileys
# [:P]
# replacing all [url]
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing smileys
# [|)]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [xx(]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing all [url]
# replacing all color
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [|)]
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing edited by
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing all color
# replacing smileys
# [}:)]
# replacing all color
# replacing [italics]
# replacing smileys
# [8D]
# replacing [italics]
# replacing edited by
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:D]
# replacing all [url]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing # #
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing # #
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing *italics*
# replacing smileys
# [;)]
# replacing # #
# replacing [bold]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing all color
# replacing all color
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [;)]
# replacing all [url]
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing smileys
# [:(]
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [:I]
# replacing edited by
# replacing smileys
# [;)]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing smileys
# [xx(]
# replacing edited by
# replacing all color
# replacing edited by
# replacing all [url]
# replacing all color
# replacing edited by
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing edited by
# replacing all color
# replacing smileys
# [xx(]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing smileys
# [:I]
# replacing edited by
# replacing all color
# replacing smileys
# [;)]
# replacing edited by
# replacing all color
# replacing smileys
# [:P]
# replacing edited by
# replacing all color
# replacing smileys
# [8)]
# replacing all color
# replacing smileys
# [:D]
# replacing smileys
# [xx(]
# replacing all color
# replacing smileys
# [:D]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [xx(]
# replacing all [url]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [:D]
# replacing smileys
# [8)]
# replacing smileys
# [^]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [}:)]
# replacing smileys
# [:D]
# replacing smileys
# [xx(]
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [|)]
# replacing smileys
# [xx(]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all [url]
# replacing all color
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing # #
# replacing [italics]
# replacing smileys
# [:I]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [;)]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [|)]
# replacing smileys
# [|)]
# replacing edited by
# replacing smileys
# [:I]
# replacing all color
# replacing [italics]
# replacing smileys
# [:I]
# replacing smileys
# [:P]
# replacing all color
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing all color
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [|)]
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing [bold]
# replacing *italics*
# replacing smileys
# [;)]
# replacing edited by
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing # #
# replacing smileys
# [;)]
# replacing # #
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [^]
# replacing all color
# replacing [bold]
# replacing smileys
# [xx(]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [|)]
# replacing all [url]
# replacing [italics]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing edited by
# replacing all [url]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing all [url]
# replacing all color
# replacing *italics*
# replacing smileys
# [:(]
# replacing # #
# replacing all [url]
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [|)]
# replacing smileys
# [|)]
# replacing smileys
# [:P]
# replacing all [url]
# replacing smileys
# [^]
# replacing all color
# replacing [italics]
# replacing smileys
# [8)]
# replacing [bold]
# replacing smileys
# [;)]
# replacing [bold]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [:P]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [:)]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [xx(]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [xx(]
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [:I]
# replacing smileys
# [8)]
# replacing smileys
# [:P]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [8D]
# replacing # #
# replacing smileys
# [:I]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing all [url]
# replacing all color
# replacing smileys
# [8D]
# replacing smileys
# [|)]
# replacing all [url]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [:D]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [}:)]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [8D]
# replacing smileys
# [:P]
# replacing all [url]
# replacing smileys
# [xx(]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [}:)]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [xx(]
# replacing [italics]
# replacing smileys
# [8)]
# replacing smileys
# [:I]
# replacing smileys
# [:P]
# replacing smileys
# [8D]
# replacing smileys
# [:(]
# replacing smileys
# [8D]
# replacing [bold]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [:P]
# replacing [bold]
# replacing smileys
# [xx(]
# replacing smileys
# [:I]
# replacing all [url]
# replacing smileys
# [8)]
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing [italics]
# replacing smileys
# [:P]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [8D]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [}:)]
# replacing smileys
# [8)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [^]
# replacing smileys
# [}:)]
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing smileys
# [:P]
# replacing smileys
# [}:)]
# replacing smileys
# [8D]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [xx(]
# replacing all color
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:I]
# replacing smileys
# [:I]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [:)]
# replacing all color
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [|)]
# replacing [italics]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [}:)]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [}:)]
# replacing all color
# replacing [bold]
# replacing smileys
# [|)]
# replacing edited by
# replacing all color
# replacing [bold]
# replacing smileys
# [|)]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [:I]
# replacing smileys
# [8D]
# replacing smileys
# [|)]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing all color
# replacing [italics]
# replacing smileys
# [:I]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [8D]
# replacing all [url]
# replacing all color
# replacing smileys
# [:D]
# replacing smileys
# [8)]
# replacing smileys
# [^]
# replacing all [url]
# replacing all color
# replacing smileys
# [8D]
# replacing all color
# replacing [bold]
# replacing smileys
# [:I]
# replacing edited by
# replacing [italics]
# replacing smileys
# [xx(]
# replacing [italics]
# replacing smileys
# [8D]
# replacing [italics]
# replacing smileys
# [:P]
# replacing [italics]
# replacing smileys
# [|)]
# replacing all color
# replacing [bold]
# replacing smileys
# [xx(]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [}:)]
# replacing smileys
# [8D]
# replacing all color
# replacing [bold]
# replacing smileys
# [8D]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [:D]
# replacing all color
# replacing smileys
# [^]
# replacing edited by
# replacing smileys
# [:D]
# replacing edited by
# replacing smileys
# [:P]
# replacing edited by
# replacing *italics*
# replacing edited by
# replacing [italics]
# replacing smileys
# [:D]
# replacing [italics]
# replacing smileys
# [xx(]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [}:)]
# replacing smileys
# [:I]
# replacing smileys
# [8)]
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [xx(]
# replacing smileys
# [|)]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [}:)]
# replacing smileys
# [}:)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing [italics]
# replacing smileys
# [:P]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing [bold]
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing all [url]
# replacing smileys
# [:D]
# replacing # #
# replacing all [url]
# replacing [italics]
# replacing smileys
# [:D]
# replacing # #
# replacing all [url]
# replacing smileys
# [:D]
# replacing # #
# replacing smileys
# [8)]
# replacing # #
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [;)]
# replacing all [url]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [;)]
# replacing **bold**
# replacing *italics*
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing # #
# replacing all color
# replacing [bold]
# replacing smileys
# [8D]
# replacing # #
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [^]
# replacing smileys
# [8)]
# replacing smileys
# [:P]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [xx(]
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [8D]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing all [url]
# replacing all color
# replacing smileys
# [:I]
# replacing all color
# replacing [bold]
# replacing smileys
# [8)]
# replacing all color
# replacing [bold]
# replacing smileys
# [^]
# replacing edited by
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [8)]
# replacing edited by
# replacing smileys
# [:)]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing smileys
# [}:)]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing # #
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [8D]
# replacing all color
# replacing smileys
# [:D]
# replacing [italics]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing smileys
# [8D]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [}:)]
# replacing all [url]
# replacing [italics]
# replacing smileys
# [^]
# replacing all color
# replacing [bold]
# replacing smileys
# [:(]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [|)]
# replacing smileys
# [;)]
# replacing smileys
# [:(]
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [}:)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing smileys
# [:P]
# replacing smileys
# [}:)]
# replacing smileys
# [8D]
# replacing all [url]
# replacing smileys
# [:I]
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing edited by
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing all [url]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [:P]
# replacing all [url]
# replacing all color
# replacing smileys
# [:)]
# replacing edited by
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [;)]
# replacing all [url]
# replacing all color
# replacing [italics]
# replacing smileys
# [;)]
# replacing all color
# replacing [bold]
# replacing [italics]
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [}:)]
# replacing all color
# replacing smileys
# [xx(]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [|)]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all [url]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [:D]
# replacing smileys
# [8)]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing all color
# replacing smileys
# [^]
# replacing edited by
# replacing all color
# replacing smileys
# [^]
# replacing edited by
# replacing all color
# replacing [italics]
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing all color
# replacing [bold]
# replacing smileys
# [:P]
# replacing all color
# replacing [bold]
# replacing smileys
# [;)]
# replacing all color
# replacing smileys
# [;)]
# replacing all color
# replacing [bold]
# replacing smileys
# [8)]
# replacing all color
# replacing [bold]
# replacing smileys
# ...
# [:)]
# replacing **bold**
# replacing *italics*
# replacing smileys
# [:)]
# replacing ### ###
# replacing ## ##
# replacing # #
# replacing smileys
# [}:)]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing **bold**
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing # #
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:)]
# replacing # #
# replacing **bold**
# replacing *italics*
# replacing smileys
# [xx(]
# replacing smileys
# [:)]
# replacing **bold**
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing **bold**
# replacing **bold**
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [;)]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:P]
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:I]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing smileys
# [xx(]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [8)]
# replacing *italics*
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [:P]
# replacing *italics*
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [:I]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [;)]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [|)]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing smileys
# [:P]
# replacing smileys
# [xx(]
# replacing smileys
# [:P]
# replacing smileys
# [|)]
# replacing smileys
# [xx(]
# replacing smileys
# [:I]
# replacing smileys
# [:P]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing *italics*
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [;)]
# replacing [italics]
# replacing smileys
# [8D]
# replacing smileys
# [^]
# replacing smileys
# [}:)]
# replacing *italics*
# replacing smileys
# [:P]
# replacing smileys
# [:(]
# replacing smileys
# [:D]
# replacing # #
# replacing smileys
# [:(]
# replacing smileys
# [xx(]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [8)]
# replacing smileys
# [:I]
# replacing smileys
# [:P]
# replacing smileys
# [:P]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing smileys
# [^]
# replacing smileys
# [:(]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [}:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [^]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [|)]
# replacing smileys
# [|)]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing [bold]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:(]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [}:)]
# replacing smileys
# [:P]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [xx(]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing smileys
# [8)]
# replacing smileys
# [}:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing **bold**
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [8)]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:I]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [xx(]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [^]
# replacing **bold**
# replacing *italics*
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [8)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [:P]
# replacing *italics*
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:P]
# replacing smileys
# [:P]
# replacing smileys
# [:I]
# replacing **bold**
# replacing *italics*
# replacing ### ###
# replacing ## ##
# replacing # #
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing **bold**
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [:P]
# replacing smileys
# [8D]
# replacing *italics*
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [:)]
# replacing smileys
# [|)]
# replacing *italics*
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:D]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:D]
# replacing *italics*
# replacing smileys
# [:(]
# replacing *italics*
# replacing smileys
# [|)]
# replacing smileys
# [:D]
# replacing smileys
# [:I]
# replacing smileys
# [:(]
# replacing smileys
# [;)]
# replacing smileys
# [;)]
# replacing *italics*
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [:D]
# replacing smileys
# [xx(]
# replacing smileys
# [:D]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [^]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [8)]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing *italics*
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [xx(]
# replacing smileys
# [:D]
# replacing smileys
# [8D]
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [}:)]
# replacing smileys
# [8)]
# replacing smileys
# [:I]
# replacing smileys
# [;)]
# replacing smileys
# [8)]
# replacing smileys
# [:P]
# replacing smileys
# [:D]
# replacing smileys
# [:D]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:P]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:I]
# replacing smileys
# [}:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing **bold**
# replacing *italics*
# replacing ### ###
# replacing # #
# replacing *italics*
# replacing smileys
# [8)]
# replacing *italics*
# replacing smileys
# [:(]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [xx(]
# replacing smileys
# [;)]
# replacing smileys
# [xx(]
# replacing smileys
# [}:)]
# replacing smileys
# [:D]
# replacing *italics*
# replacing smileys
# [8)]
# replacing [italics]
# replacing smileys
# [:P]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [}:)]
# replacing smileys
# [;)]
# replacing smileys
# [:)]
# replacing smileys
# [8D]
# replacing *italics*
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [:(]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [}:)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing smileys
# [:I]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing smileys
# [8)]
# replacing *italics*
# replacing smileys
# [:(]
# replacing smileys
# [8)]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing **bold**
# replacing *italics*
# replacing *italics*
# replacing smileys
# [xx(]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing smileys
# [8D]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [;)]
# replacing smileys
# [^]
# replacing [italics]
# replacing smileys
# [}:)]
# replacing *italics*
# replacing smileys
# [}:)]
# replacing smileys
# [^]
# replacing smileys
# [^]
# replacing *italics*
# replacing smileys
# [^]
# replacing smileys
# [8D]
# replacing smileys
# [:)]
# replacing smileys
# [8)]
# replacing smileys
# [;)]
# replacing smileys
# [8D]
# replacing *italics*
# replacing smileys
# [8)]
# replacing smileys
# [:P]
# replacing **bold**
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:D]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing [italics]
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [8)]
# replacing *italics*
# replacing smileys
# [:D]
# replacing smileys
# [:)]
# replacing smileys
# [:)]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [xx(]
# replacing *italics*
# replacing smileys
# [:)]
# replacing *italics*
# replacing smileys
# [8D]
# replacing smileys
# [:D]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing smileys
# [:(]
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*
# replacing *italics*

# %%
def continuReplace(listeLogs):
    fini=True
    for log in listeLogs:
        m=re.search(ur"(\[([^[]*)\]\(([^(]*)\))",log[2])
        if m:
            print "replacing [text](url)"
            log[2]=log[2].replace(m.group(1),u"\\href{%s}{%s}"%(m.group(3),m.group(2)))
            fini=False
        m=re.search(ur"(#(\d+\.?))",log[2])
        if m:
            print "replacing #num."
            log[2]=log[2].replace(m.group(1),u"\\Number{}%s"%m.group(2))
            fini=False
        m=re.search(ur"(#(%d|{\\bfseries|\s*\\color|MMCXI))"%log[0],log[2])
        if m:
            print "replacing #num."
            log[2]=log[2].replace(m.group(1),u"%s"%m.group(2))
            fini=False
        log[1]=log[1].replace(u"&nbsp;",ur" ").replace("#","\\Number{}").replace("&","\\And{}").replace("^","\\textasciicircum")
        log[2]=log[2].replace(u"&nbsp;",ur" ").replace("&","\\And{}").replace("^","\\textasciicircum").replace("$","\\textdollar{}").replace("%","\\Percent{}")
    result=fini
    return (listeLogs, result)

# %%
fini=False
while not fini:
    (listeLogs,fini)=continuReplace(listeLogs)
# Out:
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# ...
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing #num.
# replacing #num.
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)
# replacing [text](url)

# %%
lines=[]
for l in listeLogs:
    lines.append(u"\\cacheNumber{%s}"%l[0])
    lines.append(u"\\cacheName{%s}"%l[1])
    lines.append(u"\\begin{cacheText}")
    lines.append(l[2].strip())
    lines.append(u"\\end{cacheText}\n\n")

# %%
print len(lines)
# Out:
# 19995

# %%
with codecs.open("TextesLog2.tex","w",encoding='utf8') as output:
    output.writelines(lines[:5000])
    output.writelines(lines[5000:10000])
    output.writelines(lines[10000:15000])
    output.writelines(lines[15000:])

# %%
with codecs.open("TextesLog2.tex","w",encoding='utf8') as output:
    for l in listeLogs:
#        output.write("%d\n"%l[0])
        output.write(u"\\cacheNumber{%s}\n"%l[0])
        output.write(u"\\cacheName{%s}\n"%l[1])
        output.write(u"\\begin{cacheText}\n%s\n\\end{cacheText}\n\n\n"%l[2])

# %%
from odf.opendocument import OpenDocumentText
from odf.style import Style, TextProperties
from odf.text import H, P, Span

textdoc = OpenDocumentText()
# Styles
s = textdoc.styles
h1style = Style(name="Heading 1", family="paragraph")
h1style.addElement(TextProperties(attributes={'fontsize':"24pt",'fontweight':"bold" }))
s.addElement(h1style)
# An automatic style
boldstyle = Style(name="Bold", family="text")
boldprop = TextProperties(fontweight="bold")
boldstyle.addElement(boldprop)
textdoc.automaticstyles.addElement(boldstyle)
# Text
h=H(outlinelevel=1, stylename=h1style, text="Writing the clogs")
textdoc.text.addElement(h)
p = P(text="Hello world. ")
boldpart = Span(stylename=boldstyle, text="This part is bold. ")
p.addElement(boldpart)
p.addText("This is after bold.")
textdoc.text.addElement(p)
textdoc.save("myfirstdocument.odt")
